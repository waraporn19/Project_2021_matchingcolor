# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/Project_2021_matchingcolor/blob/main/Set_2%263.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path = '/content/drive/My Drive/shadeimg'

# %%
os.listdir(path)
# Out:
# ['รูปฟัน07',
#  '9-10 7 2021',
#  '11 7 2021',
#  'ฟันสักอย่างจำวันไม่ได้',
#  '1 teeth .gsheet',
#  '16 8 2021',
#  '17 8 2021',
#  '2 teeth.gsheet',
#  '1 teeth .xlsx',
#  '2 teeth .xlsx']

# %%
file_path = os.path.join(path,'1 teeth .xlsx')
print(file_path)
# Out:
# /content/drive/My Drive/shadeimg/1 teeth .xlsx

# %%
table1 = pd.read_excel(file_path)

# %%
table1
# Out:
#                               ชื่อไฟล์ข้อมูล  ... ฉากหลัง
# 0   8158D745-0A6C-46A1-AA5B-EB9276AFC4C0.png  ...    สีดำ
# 1   47651682-0468-459F-92BC-B79B324E9A20.png  ...    สีดำ
# 2   B19786D4-3705-4F6C-B485-9473BE11AFDF.png  ...    สีดำ
# 3   1BA57134-5CDE-4E3F-B766-1870428477F8.png  ...    สีดำ
# 4   14C1EED0-BE16-4524-8D52-94F4FE77FEC0.png  ...    สีดำ
# 5   E90ED8DA-4E26-4B91-8C17-76EFCA43D72F.png  ...    สีดำ
# 6   03F73619-45CD-4219-B5F3-A91A68A37261.png  ...    สีดำ
# 7   7C801EA2-7D50-45BD-8DF2-516D06F2129D.png  ...    สีดำ
# 8   7BDCFCB2-E8BF-4C7D-A2E4-1FA647E814A9.png  ...    สีดำ
# 9   BDA3ADFD-3FB2-4FB9-905C-0E3A232F669B.png  ...    สีดำ
# 10  48B05535-5315-4B7C-9283-7ACBD853B5F2.png  ...    สีดำ
# 11  43B15911-2EAB-46F9-84E8-040DB98B8D52.png  ...    สีดำ
# 12  318B1141-0848-4816-A402-1E2E81525917.png  ...    สีดำ
# 13  49336DA1-728B-4916-B4A7-2BFA5095005E.png  ...    สีดำ
# 14  8C751D6E-48F9-4E05-9BA3-E3FD448700CC.png  ...    สีดำ
# ...

# %%
# !pip install azure-storage-blob==2.1.0
# Out:
# ...
#      |████████████████████████████████| 88 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 47 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 19.9 MB/s
# ...

# %%
from azure.storage.blob import BlockBlobService
import os

# %%
 blob_service_client = BlockBlobService(account_name='dent01', account_key='CuShY0B4TZJ84TjzPpaHxyrHOpO73aGXeCpdVq7x26OjIlQ1HOz+3DVc9pDEj9BdcEL8odFuTRF0mOAE+aCgiw==')

# %%
A101_2='43B3A559-D6CD-4759-863E-1335D3A137E4.png'
A105_2='DC8510EF-E12E-4050-9E3E-3B8338838FCE.png'
A110_2='A049F178-82F1-4F66-867D-062FADDD3B4C.png'
A201_2='C4A19F33-7E34-41A6-B42D-9F9767762069.png'
A205_2='D88790DD-D1DC-454C-A89A-4D74599DD49D.png'
A210_2='DF6D1913-EBA6-4A5C-B251-59770ADEC4C3.png'
A301_2='A1C601C4-15F3-4144-8466-1130AFD644B6.png'
A305_2='3B746A65-ABF7-49E5-BD52-335B55B395B3.png'
A3015_2='EF8B3D3A-6F00-44CB-8503-EA1EE9987AD4.png'
A30155_2='1FCE9E9E-D58B-4962-AE97-F9F8D2B1E7EA.png'
A401_2='2846A219-71AE-47E5-BA30-864644218F4A.png'
A405_2='4684F5E5-9EEF-4809-9113-9968607A1BAD.png'
B101_2='F6C182AD-F7FF-431A-96B0-BDAD65AFFD4D.png'
B105_2='F04463C1-A20F-4512-96FD-EBE0333AAB8B.png'
B201_2='25EB4D2D-09D8-4760-BFA7-222DE1616451.png'
B205_2='0727A73F-127B-4B52-B08F-F6759EA80153.png'
B301_2='408B131B-0A06-43EF-BC21-C67943304685.png'
B305_2='88731541-9797-4C72-870B-2E9DA4F6C843.png'
B403_2t='E961BF81-DBD6-4E0A-90C1-D04DDE51D746.png'
B405_2='E1378D74-77DF-4796-B43B-7127CF46E7C2.png'
A101='94D85F97-76D6-4CC7-9247-884D10F81533.png'
A105='E790A88B-78EF-48DE-B9F1-53F4C7778A80.png'
A201='89B25F4F-2747-4BB2-BBEC-3EA92874145D.png'
A205='E704427B-4E6C-43E3-A746-D2A4770F56D3.png'
A101_3='34972AB5-CAC7-472C-AC53-FBCA2BD69502.png'
A105_3='000407B1-BEB4-4C98-ACA0-D49BFE88F92F.png'
A201_3='4C64AD0D-6C55-440B-80DA-57846B41565C.png'
A205_3='0799DF93-D656-43FD-9334-1EFF7482DD4E.png'
A301_3='31EB0600-CADA-4CB0-980B-5A6E6211694E.png'
A305_3='EE2FAF87-E2C5-4766-A028-F4BA978B2D54.png'

# %%
full_path_to_file2 = os.path.join(A101) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(A101_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(A101_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(A201) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(A201_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(A205_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(A205_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(B403_2t) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(B405_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(A301_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(A305_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
import cv2
from matplotlib import pyplot as plt #การเรียกใช้คำสั่ง matplotlib เพื่อวาดกราฟ โดยแทนชื่อ matplotlib ด้วย plt
import matplotlib

# %%
#รูปที่ 0 A1
imgA101  = cv2.imread(A101)
RGB_imgA101= cv2.cvtColor(imgA101, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA101)#โชว์รูป

# %%
imgA101_2= cv2.imread(A101_2)
RGB_imgA101_2= cv2.cvtColor(imgA101_2, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA101_2)#โชว์รูป

# %%
imgA101_3= cv2.imread(A101_3)
RGB_imgA101_3= cv2.cvtColor(imgA101_3, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA101_3)#โชว์รูป

# %%
imgA201= cv2.imread(A201)
RGB_imgA201= cv2.cvtColor(imgA201, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA201)#โชว์รูป

# %%
imgA201_2= cv2.imread(A201_2)
RGB_imgA201_2= cv2.cvtColor(imgA201_2, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA201_2)#โชว์รูป

# %%
imgA205_2= cv2.imread(A205_2)
RGB_imgA205_2= cv2.cvtColor(imgA205_2, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA205_2)#โชว์รูป

# %%
imgA205_3= cv2.imread(A205_3)
RGB_imgA205_3= cv2.cvtColor(imgA205_3, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA205_3)#โชว์รูป

# %%
imgB403_2t= cv2.imread(B403_2t)
RGB_imgB403_2t= cv2.cvtColor(imgB403_2t, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgB403_2t)#โชว์รูป

# %%
imgA301_3= cv2.imread(A301_3)
RGB_imgA301_3= cv2.cvtColor(imgA301_3, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA301_3)#โชว์รูป

# %%
imgA305_3= cv2.imread(A305_3)
RGB_imgA305_3= cv2.cvtColor(imgA305_3, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_imgA305_3)#โชว์รูป

# %%
data = cv2.imread(A101)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA1= cv2.cvtColor(data, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA1)#โชว์รูป

# %%
dataA101_2 = cv2.imread(A101_2)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA101_2= cv2.cvtColor(dataA101_2, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA101_2)#โชว์รูป

# %%
dataA101_3 = cv2.imread(A101_3)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA101_3= cv2.cvtColor(dataA101_3, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA101_3)#โชว์รูป

# %%
dataA201= cv2.imread(A201)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA201= cv2.cvtColor(dataA201, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA201)#โชว์รูป

# %%
dataA201_2 = cv2.imread(A201_2)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA201_2= cv2.cvtColor(dataA201_2, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA201_2)#โชว์รูป

# %%
dataA205_2 = cv2.imread(A205_2)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA205_2= cv2.cvtColor(dataA205_2, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA205_2)#โชว์รูป

# %%
dataA205_3= cv2.imread(A205_3)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA205_3= cv2.cvtColor(dataA205_3, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA205_3)#โชว์รูป

# %%
dataA301_3= cv2.imread(A301_3)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA301_3= cv2.cvtColor(dataA301_3, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA301_3)#โชว์รูป

# %%
dataA305_3= cv2.imread(A305_3)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgA305_3= cv2.cvtColor(dataA305_3, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgA305_3)#โชว์รูป

# %%
dataB403_2t= cv2.imread(B403_2t)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgB403_2t= cv2.cvtColor(dataB403_2t, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgB403_2t)#โชว์รูป

# %%
dataB405_2= cv2.imread(B405_2)#อ่านรูปเข้ามา ให้เก็บไว้ในimg_A1
LAB_imgB405_2= cv2.cvtColor(dataB405_2, cv2.COLOR_BGR2LAB)#แปลง BGR เป็น LAB
plt.imshow(LAB_imgB405_2)#โชว์รูป

# %%
for i in range(LAB_imgA1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 1849 - 2101   ค่า j  ที่เข้ามาอยู่ระหว่าง 1799-2001
                    print(LAB_imgA1[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [214 124 151]
# [214 124 151]
# [214 125 149]
# [215 125 149]
# [214 125 149]
# [225 124 148]
# [225 124 148]
# [225 124 148]
# [224 124 148]
# [226 125 148]
# [225 124 148]
# [226 125 148]
# [226 125 148]
# [223 124 148]
# [223 124 148]
# [225 124 148]
# [224 124 148]
# [226 124 150]
# [226 124 150]
# [226 124 150]
# [226 124 150]
# [225 124 150]
# [225 124 150]
# [225 124 150]
# [225 124 150]
# [225 124 150]
# [224 124 149]
# [224 124 149]
# [224 124 149]
# [224 124 149]
# [224 124 149]
# [225 124 150]
# [225 124 150]
# [224 124 149]
# [223 124 150]
# [223 124 150]
# [223 124 150]
# [223 124 150]
# [223 124 150]
# [223 124 150]
# [224 124 149]
# [223 124 150]
# [223 124 150]
# [224 124 149]
# [224 124 149]
# [223 124 150]
# [223 124 150]
# [222 124 150]
# [222 124 150]
# [223 124 150]
# [223 124 150]
# [224 124 149]
# [223 124 150]
# [222 124 150]
# [221 124 150]
# [221 124 150]
# [222 124 150]
# [223 124 150]
# ...

# %%
for i in range(LAB_imgA101_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA101_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :#ถ้าค่า i ที่เข้ามาอยู่ระหว่าง 1849 - 2101   ค่า j  ที่เข้ามาอยู่ระหว่าง 1799-2001
                    print(LAB_imgA101_2[i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [197 127 149]
# [197 127 149]
# [197 127 149]
# [197 127 149]
# [197 127 149]
# [191 126 153]
# [191 126 153]
# [191 126 153]
# [191 126 153]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [191 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [191 126 154]
# [191 126 154]
# [191 126 154]
# [191 126 154]
# [191 126 154]
# [190 126 154]
# [190 126 154]
# [191 126 154]
# [191 126 154]
# [191 126 154]
# [191 126 154]
# [190 126 154]
# [190 126 154]
# [190 126 154]
# [191 126 154]
# [192 126 154]
# [191 126 154]
# [191 126 154]
# [191 126 153]
# [191 126 153]
# [191 126 153]
# [191 126 153]
# [191 126 153]
# [192 126 153]
# [192 126 153]
# [193 126 153]
# [193 126 153]
# ...

# %%
for i in range(LAB_imgA101_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_img
i][j])#ถ้าค่าอยู่ใน ij  จะให้แสดงค่าที่อยู่ตำแหน่งนั้นๆ
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# [190 127 161]
# [188 127 162]
# [187 129 160]
# [189 129 160]
# [189 129 160]
# [188 127 160]
# [188 127 160]
# [187 128 160]
# [188 128 160]
# [186 128 160]
# [187 128 160]
# [187 128 160]
# [188 128 160]
# [188 128 160]
# [188 128 160]
# [186 128 160]
# [185 128 160]
# [185 128 160]
# [185 128 160]
# [185 128 161]
# [186 128 161]
# [187 128 160]
# [187 128 160]
# [185 129 160]
# [183 129 161]
# [183 129 161]
# [184 129 161]
# [184 128 162]
# [184 128 162]
# [184 128 162]
# [184 128 162]
# [184 128 162]
# [185 128 162]
# [185 128 162]
# [185 128 162]
# [184 128 162]
# [184 128 162]
# [184 128 162]
# [185 128 162]
# [185 128 162]
# [185 128 162]
# [186 128 162]
# [186 128 162]
# [186 128 162]
# [185 128 162]
# [184 128 162]
# [185 128 162]
# [186 128 162]
# [186 128 162]
# [186 128 162]
# [186 128 162]
# [186 128 162]
# [185 128 162]
# [185 128 162]
# [185 128 162]
# [185 128 162]
# [186 128 162]
# [185 128 162]
# ...

# %%
import numpy as np

# %%
meanA1 = list() 
for i in range(LAB_imgA1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA1.append(LAB_imgA1[i][j])
meanA1= np.array(meanA1)

lab = list()
for i in range(3):
    lab.append(meanA1[:,i].mean())
lab
# Out:
# [221.43235127018912, 124.5560425290155, 148.84441197954712]

# %%
meanA101_2= list() 
for i in range(LAB_imgA101_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA101_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA101_2.append(LAB_imgA101_2[i][j])
meanA101_2 = np.array(meanA101_2)

lab = list()
for i in range(3):
    lab.append(meanA101_2[:,i].mean())
lab
# Out:
# [193.33300868436004, 126.14528041555069, 152.3710737764792]

# %%
meanA101_3 = list() 
for i in range(LAB_imgA101_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA101_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA101_3.append(LAB_imgA101_3[i][j])
meanA101_3 = np.array(meanA101_3)

lab = list()
for i in range(3):
    lab.append(meanA101_3[:,i].mean())
lab
# Out:
# [230.28642155669183, 126.79287395503611, 131.80099017936857]

# %%
meanA201 = list() 
for i in range(LAB_imgA201.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA201.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA201.append(LAB_imgA201[i][j])
meanA201 = np.array(meanA201)

lab = list()
for i in range(3):
    lab.append(meanA201[:,i].mean())
lab
# Out:
# [202.10331953575198, 126.41149257365474, 154.29185942699456]

# %%
meanA201_2 = list() 
for i in range(LAB_imgA201_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA201_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA201_2.append(LAB_imgA201_2[i][j])
meanA201_2 = np.array(meanA201_2)

lab = list()
for i in range(3):
    lab.append(meanA201_2[:,i].mean())
lab
# Out:
# [187.46010875740606, 127.99569840110381, 153.76511646781918]

# %%
meanA205_2 = list() 
for i in range(LAB_imgA205_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA205_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA205_2.append(LAB_imgA205_2[i][j])
meanA205_2 = np.array(meanA205_2)

lab = list()
for i in range(3):
    lab.append(meanA205_2[:,i].mean())
lab
# Out:
# [187.1357032708384, 128.1895138381625, 154.14008603197792]

# %%
meanA205_3 = list() 
for i in range(LAB_imgA205_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA205_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA205_3.append(LAB_imgA205_3[i][j])
meanA205_3 = np.array(meanA205_3)

lab = list()
for i in range(3):
    lab.append(meanA205_3[:,i].mean())
lab
# Out:
# [232.99586072559046, 126.25809593377161, 134.7894651408165]

# %%
meanA301_3 = list() 
for i in range(LAB_imgA301_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA301_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA301_3.append(LAB_imgA301_3[i][j])
meanA301_3= np.array(meanA301_3)

lab = list()
for i in range(3):
    lab.append(meanA301_3[:,i].mean())
lab
# Out:
# [232.4618943267592, 124.41149257365474, 143.56886616346077]

# %%
meanA305_3= list() 
for i in range(LAB_imgA305_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgA305_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanA305_3.append(LAB_imgA305_3[i][j])
meanA305_3= np.array(meanA305_3)

lab = list()
for i in range(3):
    lab.append(meanA305_3[:,i].mean())
lab
# Out:
# [228.39177014852692, 124.29007385764143, 143.22741660579499]

# %%
meanB403_2t = list() 
for i in range(LAB_imgB403_2t.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgB403_2t.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanB403_2t.append(LAB_imgB403_2t[i][j])
meanB403_2t= np.array(meanB403_2t)

lab = list()
for i in range(3):
    lab.append(meanB403_2t[:,i].mean())
lab
# Out:
# [233.20931742553364, 124.98831263696128, 162.19892865838813]

# %%
meanB405_2 = list() 
for i in range(LAB_imgB405_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(LAB_imgB405_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                    meanB405_2.append(LAB_imgB405_2[i][j])
meanB405_2= np.array(meanB405_2)

lab = list()
for i in range(3):
    lab.append(meanB405_2[:,i].mean())
lab
# Out:
# [187.98319941563184, 128.26929632335037, 160.92200308416525]

# %% [markdown]
# 1.เฉดเดียวกัน *เซตติ้งเดียวกัน*

# %%
from scipy.spatial import distance

# %%
meanA201_2 =[187.46010875740606, 127.99569840110381, 153.76511646781918]
meanA205_2 = [187.1357032708384, 128.1895138381625, 154.14008603197792]
meanA201_2,meanA205_2  

euclidean_distance = distance.euclidean(meanA201_2,meanA205_2 )
print('Euclidean Distance between', meanA201_2, 'and',  meanA205_2, 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [187.46010875740606, 127.99569840110381, 153.76511646781918] and [187.1357032708384, 128.1895138381625, 154.14008603197792] is:  0.5323584482309244

# %%
meanB403_2t=[233.20931742553364, 124.98831263696128, 162.19892865838813]
meanB405_2 =[187.98319941563184, 128.26929632335037, 160.92200308416525]
meanB403_2t,meanB405_2 

euclidean_distance = distance.euclidean(meanB403_2t,meanB405_2 )
print('Euclidean Distance between', meanB403_2t, 'and',  meanB405_2 , 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [233.20931742553364, 124.98831263696128, 162.19892865838813] and [187.98319941563184, 128.26929632335037, 160.92200308416525] is:  45.362949012580955

# %%
meanA301_3 = [232.4618943267592, 124.41149257365474, 143.56886616346077]
meanA305_3=[228.39177014852692, 124.29007385764143, 143.22741660579499]
meanA301_3,meanA305_3

euclidean_distance = distance.euclidean(meanA301_3,meanA305_3)
print('Euclidean Distance between', meanA301_3, 'and',  meanA305_3, 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [232.4618943267592, 124.41149257365474, 143.56886616346077] and [228.39177014852692, 124.29007385764143, 143.22741660579499] is:  4.086225780749205

# %% [markdown]
# 3.เฉดเดียวกัน คนละเซตติ้ง

# %%
meanA1 = [221.43235127018912, 124.5560425290155, 148.84441197954712]
meanA101_2= [193.33300868436004, 126.14528041555069, 152.3710737764792]
meanA1,meanA101_2

euclidean_distance = distance.euclidean(meanA1,meanA101_2)
print('Euclidean Distance between', meanA1, 'and',  meanA101_2, 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [221.43235127018912, 124.5560425290155, 148.84441197954712] and [193.33300868436004, 126.14528041555069, 152.3710737764792] is:  28.364345122807375

# %%
meanA1 = [221.43235127018912, 124.5560425290155, 148.84441197954712]
meanA101_3 =[230.28642155669183, 126.79287395503611, 131.80099017936857]
meanA1,meanA101_3 

euclidean_distance = distance.euclidean(meanA1,meanA101_3 )
print('Euclidean Distance between', meanA1, 'and',  meanA101_3 , 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [221.43235127018912, 124.5560425290155, 148.84441197954712] and [230.28642155669183, 126.79287395503611, 131.80099017936857] is:  19.33587862305629

# %%
meanA101_2= [193.33300868436004, 126.14528041555069, 152.3710737764792]
meanA101_3 =[230.28642155669183, 126.79287395503611, 131.80099017936857]
meanA101_2,meanA101_3 

euclidean_distance = distance.euclidean(meanA101_2,meanA101_3)
print('Euclidean Distance between', meanA101_2, 'and', meanA101_3  , 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [193.33300868436004, 126.14528041555069, 152.3710737764792] and [230.28642155669183, 126.79287395503611, 131.80099017936857] is:  42.29778291468148

# %%
meanA201= [202.10331953575198, 126.41149257365474, 154.29185942699456]
meanA205_2 =[187.1357032708384, 128.1895138381625, 154.14008603197792]
meanA201,meanA205_2

euclidean_distance = distance.euclidean(meanA201,meanA205_2)
print('Euclidean Distance between', meanA201, 'and', meanA205_2  , 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [202.10331953575198, 126.41149257365474, 154.29185942699456] and [187.1357032708384, 128.1895138381625, 154.14008603197792] is:  15.073617065395485

# %%
meanA201= [202.10331953575198, 126.41149257365474, 154.29185942699456]
meanA205_3= [232.99586072559046, 126.25809593377161, 134.7894651408165]
meanA201,meanA205_3

euclidean_distance = distance.euclidean(meanA201,meanA205_3)
print('Euclidean Distance between', meanA201, 'and', meanA205_3  , 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [202.10331953575198, 126.41149257365474, 154.29185942699456] and [232.99586072559046, 126.25809593377161, 134.7894651408165] is:  36.5337654039184

# %%
meanA205_2 =[187.1357032708384, 128.1895138381625, 154.14008603197792]
meanA205_3= [232.99586072559046, 126.25809593377161, 134.7894651408165]
meanA205_2 ,meanA205_3

euclidean_distance = distance.euclidean(meanA205_2 ,meanA205_3)
print('Euclidean Distance between', meanA205_2, 'and', meanA205_3  , 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [187.1357032708384, 128.1895138381625, 154.14008603197792] and [232.99586072559046, 126.25809593377161, 134.7894651408165] is:  49.81295961664499

# %% [markdown]
# 4. คนละเฉด คนละเซตติ้ง จับคู่กัน

# %%
meanA201=[202.10331953575198, 126.41149257365474, 154.29185942699456]
meanB403_2t =[233.20931742553364, 124.98831263696128, 162.19892865838813]
meanA201,meanB403_2t 

euclidean_distance = distance.euclidean(meanA201,meanB403_2t )
print('Euclidean Distance between', meanA201, 'and', B403_2t , 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [202.10331953575198, 126.41149257365474, 154.29185942699456] and E961BF81-DBD6-4E0A-90C1-D04DDE51D746.png is:  32.12678461473166

# %%
meanA205_2 =[187.1357032708384, 128.1895138381625, 154.14008603197792]
meanA305_3=[228.39177014852692, 124.29007385764143, 143.22741660579499]
meanA205_2 ,meanA305_3

euclidean_distance = distance.euclidean(meanA205_2 ,meanA305_3)
print('Euclidean Distance between', meanA205_2, 'and', meanA305_3  , 'is: ', euclidean_distance)
# Out:
# Euclidean Distance between [187.1357032708384, 128.1895138381625, 154.14008603197792] and [228.39177014852692, 124.29007385764143, 143.22741660579499] is:  42.85271333746722
