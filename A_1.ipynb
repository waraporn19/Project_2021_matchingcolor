# %% [markdown]
# <a href="https://colab.research.google.com/github/waraporn19/Project_2021_matchingcolor/blob/main/A_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/My Drive/shadeimg'

# %%
os.listdir(path)
# Out:
# ['รูปฟัน07',
#  '9-10 7 2021',
#  '11 7 2021',
#  'ฟันสักอย่างจำวันไม่ได้',
#  '1 teeth .gsheet',
#  '16 8 2021',
#  '17 8 2021',
#  '1 teeth .xlsx',
#  '2 teeth .xlsx',
#  '2 teeth.gsheet']

# %%
# !pip install azure-storage-blob==2.1.0

# %%
from azure.storage.blob import BlockBlobService
import os

# %%
blob_service_client = BlockBlobService(account_name='dent01', account_key='CuShY0B4TZJ84TjzPpaHxyrHOpO73aGXeCpdVq7x26OjIlQ1HOz+3DVc9pDEj9BdcEL8odFuTRF0mOAE+aCgiw==')

# %% [markdown]
# #1.สร้างตัวแปรเฉดไกด์

# %% [markdown]
# ##Set1

# %%
S1_doubleA1A1_1 = '219558E6-E67A-4672-9E46-3D084D0D2032.png'
S1_doubleA1A2_1 = '6D94544D-442A-4CFB-811D-FE7DC11D2ED2.png'
S1_doubleA1A3_1 = '7BF85808-DA35-4E17-B217-3872CF481063.png'
S1_doubleA1A3_51 = 'F8F3A06B-FA35-4279-8C60-CA55360B7179.png'
S1_doubleA1A4_1 = 'B7D67D95-6E1E-4FDB-9C86-BEC2876991A4.png'
S1_doubleA1B1_1 ='BD55E510-FC24-46F8-9057-F0FB833D77B3.png'
S1_doubleA1B2_1 = 'E74FAFC2-2346-41FE-86DC-74BA55784D10.png'
S1_doubleA1B3_1 ='98C5F545-74F1-4F79-9459-B78CD7323409.png'
S1_doubleA1B4_1 ='3F9C3FA1-74A0-4E1C-86C6-4A6ABCBF61E0.png'
S1_doubleA1C1_1 ='3F9C3FA1-74A0-4E1C-86C6-4A6ABCBF61E0.png'
S1_doubleA1C2_1 ='A9BD406D-9241-4529-8915-ACD914DE2114.png'
S1_doubleA1C3_1 ='3E2D92F5-C039-4375-8801-7177CE0C110B.png'
S1_doubleA1C4_1 ='A601DEF5-8194-4546-BAA2-E3CF2BC491A7.png'
S1_doubleA1D2_1 = '0CFB37BF-7362-44C7-8A5C-636AA66DADF1.png'
S1_doubleA1D3_1 ='276C4D35-B17B-4238-B730-5667F7993357.png'
S1_doubleA1D4_1 = '14BF11D2-5597-4D76-982D-6D73CA85D29C.png'

# %%
S1_doubleA1A1_2 = 'C88EF40F-E3F2-462F-9F7F-F2BACB0E4704.png'
S1_doubleA1A2_2 = 'DDC4DC8E-B6F3-4C8E-B168-D77C99A200B0.png'
S1_doubleA1A3_2  = 'D82BB03D-596F-4490-A11A-78CC339EF07E.png'
S1_doubleA1A3_52  = '01115472-EC3A-48C7-B1FB-263259578BD7.png'
S1_doubleA1A4_2  = 'A7B00E08-3ED6-4D0D-A76A-59936068AD40.png'
S1_doubleA1B1_2  = '7EE62CC1-C35A-4BD5-8B99-7A02F504FB92.png'
S1_doubleA1B2_2  = 'BEE4A20C-2B3A-4083-964D-EB3923B388F9.png'
S1_doubleA1B3_2  ='BF7F9C19-2AB0-4C4B-BBF5-EF32E953C0B7.png'
S1_doubleA1B4_2  = 'AAF41B6A-64A6-4300-9FE7-3E9652AA67F2.png'
S1_doubleA1C1_2  ='EBA0C742-6F93-40D7-BBDC-FDA0F7717CF5.png'
S1_doubleA1C2_2  ='EBA0C742-6F93-40D7-BBDC-FDA0F7717CF5.png'
S1_doubleA1C3_2  ='041A2217-2C1E-4183-940C-81AF1B7ADCEB.png'
S1_doubleA1C4_2  ='F228CEDF-9850-4974-955D-6A187146338E.png'
S1_doubleA1D2_2  = '59AD9845-D209-4929-8E83-5C3FCBD50C90.png'
S1_doubleA1D3_2  ='59AD9845-D209-4929-8E83-5C3FCBD50C90.png'
S1_doubleA1D4_2  = '630B56EB-1A02-4C39-8E72-401279881303.png'

# %%
S1_doubleA1A1_3 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1A2_3 = '9C42EB3E-DDE7-43A2-91AE-4DCE60FCDAA9.png'
S1_doubleA1A3_3 = '0E935DDC-4F2E-44CA-8761-D9EEF48FA184.png'
S1_doubleA1A3_53 = '6503F4C5-1138-4796-972C-5FF66EFD389B.png'
S1_doubleA1A4_3= '7BDDACC1-D18B-459A-BEE5-E1ECAF9BF9C2.png'
S1_doubleA1B1_3 ='82C9B7F8-9A33-48DF-B722-CD2CCE4DFDA4.png'
S1_doubleA1B2_3 = '5E756B9E-5B8B-4003-A2CC-32D244523EF5.png'
S1_doubleA1B3_3 ='0E6A8167-3381-4891-99D4-84EAAC995D0B.png'
S1_doubleA1B4_3 = '2D83B79D-5337-4378-832C-371721F97678.png'
S1_doubleA1C1_3 = '91D7D709-F23E-4AE3-A0A2-A445F61D67EB.png'
S1_doubleA1C2_3 ='781F2ECD-93CA-4AF4-9D79-49910BB1E07A.png'
S1_doubleA1C3_3 ='B6050550-B56E-4148-BF1E-CE9492B5334F.png'
S1_doubleA1C4_3 ='1A7C4C1D-67A6-4724-98D9-FFAFEED41437.png'
S1_doubleA1D2_3 = '75EABE86-EA46-42BC-88A7-90FF6F904B23.png'
S1_doubleA1D3_3 ='6E56B8EF-2517-4195-B91A-E5EFA20E81A0.png'
S1_doubleA1D4_3 = '839EA3F3-4256-44C3-9E4C-70E87B10CB38.png'

# %%
S1_doubleA1A1_4 = '07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'
S1_doubleA1A2_4 = '6305881D-3DFD-4ECE-BD1D-C5376038CD26.png'
S1_doubleA1A3_4 = 'B71E2B77-0A51-4D5C-A7CC-889C3295D37C.png'
S1_doubleA1A3_54 = '7F841DFC-287B-41C2-A4F5-49FA7331CBB0.png'
S1_doubleA1A4_4 = 'CEB5576D-ACE1-42A4-9540-B3F4FB29B6DA.png'
S1_doubleA1B1_4 ='07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'
S1_doubleA1B2_4 = '9AF472D2-DD0D-4A58-8DEE-747C9F852CAD.png'
S1_doubleA1B3_4 ='A31E86AB-D56C-47DA-A0A9-6715963F7A75.png'
S1_doubleA1B4_4 ='0DEED793-CF17-4B1A-A942-70848FF5C047.png'
S1_doubleA1C1_4 ='522CA5D0-1167-4A5B-A005-40F3DF60600F.png'
S1_doubleA1C2_4 ='11FC10FE-24D7-4815-8F28-FDA778DDBCC8.png'
S1_doubleA1C3_4 ='13F7D5C3-201D-4CB7-B3D8-718B60A8D012.png'
S1_doubleA1C4_4 ='0AB9EBD7-AEA7-4CC5-A604-30C0B2695D39.png'
S1_doubleA1B4_4 ='71185777-D048-455E-980E-311833CF5A88.png'
S1_doubleA1C1_4 ='71185777-D048-455E-980E-311833CF5A88.png'
S1_doubleA1C2_4 ='0AB9EBD7-AEA7-4CC5-A604-30C0B2695D39.png'
S1_doubleA1C3_4 ='0AB9EBD7-AEA7-4CC5-A604-30C0B2695D39.png'
S1_doubleA1C4_4 ='07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'
S1_doubleA1D2_4 = '07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'
S1_doubleA1D3_4 ='07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'
S1_doubleA1D4_4 = '07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'

# %%
S1_doubleA1A1_5 =  '07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'
S1_doubleA1A2_5 = '839EA3F3-4256-44C3-9E4C-70E87B10CB38.png'
S1_doubleA1A3_5 =  '75EABE86-EA46-42BC-88A7-90FF6F904B23.png'
S1_doubleA1A3_55 = '07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'
S1_doubleA1A4_5 = '07D1EFD7-B26D-41DE-AFC4-C1BACE8867A4.png'
S1_doubleA1B1_5 ='7F841DFC-287B-41C2-A4F5-49FA7331CBB0.png'
S1_doubleA1B2_5 = '6305881D-3DFD-4ECE-BD1D-C5376038CD26.png'
S1_doubleA1B3_5 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1B4_5 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1C1_5 ='7F841DFC-287B-41C2-A4F5-49FA7331CBB0.png'
S1_doubleA1C2_5 ='6305881D-3DFD-4ECE-BD1D-C5376038CD26.png'
S1_doubleA1C3_5 ='6305881D-3DFD-4ECE-BD1D-C5376038CD26.png'
S1_doubleA1C4_5 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1D2_5 = '6305881D-3DFD-4ECE-BD1D-C5376038CD26.png'
S1_doubleA1D3_5 ='6305881D-3DFD-4ECE-BD1D-C5376038CD26.png'
S1_doubleA1D4_5 = '7F841DFC-287B-41C2-A4F5-49FA7331CBB0.png'

# %%
S1_doubleA1A1_6 =  '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1A2_6 = 'A601DEF5-8194-4546-BAA2-E3CF2BC491A7.png'
S1_doubleA1A3_6 = 'A601DEF5-8194-4546-BAA2-E3CF2BC491A7.png'
S1_doubleA1A3_56 ='1A7C4C1D-67A6-4724-98D9-FFAFEED41437.png' 
S1_doubleA1A4_6 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1B1_6 ='A601DEF5-8194-4546-BAA2-E3CF2BC491A7.png'
S1_doubleA1B2_6 = '1A7C4C1D-67A6-4724-98D9-FFAFEED41437.png'
S1_doubleA1B3_6 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1B4_6 ='2D83B79D-5337-4378-832C-371721F97678.png'
S1_doubleA1C1_6 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1C2_6 ='1A7C4C1D-67A6-4724-98D9-FFAFEED41437.png'
S1_doubleA1C3_6 ='2D83B79D-5337-4378-832C-371721F97678.png'
S1_doubleA1C4_6 ='2D83B79D-5337-4378-832C-371721F97678.png'
S1_doubleA1D2_6 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1D3_6 ='7F841DFC-287B-41C2-A4F5-49FA7331CBB0.png'
S1_doubleA1D4_6 = '7F841DFC-287B-41C2-A4F5-49FA7331CBB0.png'

# %%
S1_doubleA1A1_7 = '9664FAC5-C093-4C4E-9906-23DCC933C2BC.png'
S1_doubleA1A2_7 = '9C42EB3E-DDE7-43A2-91AE-4DCE60FCDAA9.png'
S1_doubleA1A3_7 = '0E935DDC-4F2E-44CA-8761-D9EEF48FA184.png'
S1_doubleA1A3_57 = '6503F4C5-1138-4796-972C-5FF66EFD389B.png'
S1_doubleA1A4_7= '7BDDACC1-D18B-459A-BEE5-E1ECAF9BF9C2.png'
S1_doubleA1B1_7='82C9B7F8-9A33-48DF-B722-CD2CCE4DFDA4.png'
S1_doubleA1B2_7 = '5E756B9E-5B8B-4003-A2CC-32D244523EF5.png'
S1_doubleA1B3_7 ='0E6A8167-3381-4891-99D4-84EAAC995D0B.png'
S1_doubleA1B4_7 = '2D83B79D-5337-4378-832C-371721F97678.png'
S1_doubleA1C1_7 = '91D7D709-F23E-4AE3-A0A2-A445F61D67EB.png'
S1_doubleA1C2_7 ='781F2ECD-93CA-4AF4-9D79-49910BB1E07A.png'
S1_doubleA1C3_7 ='B6050550-B56E-4148-BF1E-CE9492B5334F.png'
S1_doubleA1C4_7 ='1A7C4C1D-67A6-4724-98D9-FFAFEED41437.png'
S1_doubleA1D2_7 = '75EABE86-EA46-42BC-88A7-90FF6F904B23.png'
S1_doubleA1D3_7='6E56B8EF-2517-4195-B91A-E5EFA20E81A0.png'
S1_doubleA1D4_7 = '839EA3F3-4256-44C3-9E4C-70E87B10CB38.png'

# %%
S1_doubleA1A1_8 = 'C88EF40F-E3F2-462F-9F7F-F2BACB0E4704.png'
S1_doubleA1A2_8 = 'DDC4DC8E-B6F3-4C8E-B168-D77C99A200B0.png'
S1_doubleA1A3_8  = 'D82BB03D-596F-4490-A11A-78CC339EF07E.png'
S1_doubleA1A3_58  = '01115472-EC3A-48C7-B1FB-263259578BD7.png'
S1_doubleA1A4_8  = 'A7B00E08-3ED6-4D0D-A76A-59936068AD40.png'
S1_doubleA1B1_8  = '7EE62CC1-C35A-4BD5-8B99-7A02F504FB92.png'
S1_doubleA1B2_8  = 'BEE4A20C-2B3A-4083-964D-EB3923B388F9.png'
S1_doubleA1B3_8  ='BF7F9C19-2AB0-4C4B-BBF5-EF32E953C0B7.png'
S1_doubleA1B4_8  = 'AAF41B6A-64A6-4300-9FE7-3E9652AA67F2.png'
S1_doubleA1C1_8  ='EBA0C742-6F93-40D7-BBDC-FDA0F7717CF5.png'
S1_doubleA1C2_8  ='EBA0C742-6F93-40D7-BBDC-FDA0F7717CF5.png'
S1_doubleA1C3_8  ='041A2217-2C1E-4183-940C-81AF1B7ADCEB.png'
S1_doubleA1C4_8  ='F228CEDF-9850-4974-955D-6A187146338E.png'
S1_doubleA1D2_8  = '59AD9845-D209-4929-8E83-5C3FCBD50C90.png'
S1_doubleA1D3_8  ='59AD9845-D209-4929-8E83-5C3FCBD50C90.png'
S1_doubleA1D4_8  = '630B56EB-1A02-4C39-8E72-401279881303.png'

# %%
S1_doubleA1A1_9 = 'C88EF40F-E3F2-462F-9F7F-F2BACB0E4704.png'
S1_doubleA1A2_9 = 'DDC4DC8E-B6F3-4C8E-B168-D77C99A200B0.png'
S1_doubleA1A3_9  = 'D82BB03D-596F-4490-A11A-78CC339EF07E.png'
S1_doubleA1A3_59  = '01115472-EC3A-48C7-B1FB-263259578BD7.png'
S1_doubleA1A4_9  = 'A7B00E08-3ED6-4D0D-A76A-59936068AD40.png'
S1_doubleA1B1_9  = '7EE62CC1-C35A-4BD5-8B99-7A02F504FB92.png'
S1_doubleA1B2_9  = 'BEE4A20C-2B3A-4083-964D-EB3923B388F9.png'
S1_doubleA1B3_9  ='BF7F9C19-2AB0-4C4B-BBF5-EF32E953C0B7.png'
S1_doubleA1B4_9  = 'AAF41B6A-64A6-4300-9FE7-3E9652AA67F2.png'
S1_doubleA1C1_9  ='EBA0C742-6F93-40D7-BBDC-FDA0F7717CF5.png'
S1_doubleA1C2_9  ='EBA0C742-6F93-40D7-BBDC-FDA0F7717CF5.png'
S1_doubleA1C3_9  ='041A2217-2C1E-4183-940C-81AF1B7ADCEB.png'
S1_doubleA1C4_9  ='F228CEDF-9850-4974-955D-6A187146338E.png'
S1_doubleA1D2_9  = '59AD9845-D209-4929-8E83-5C3FCBD50C90.png'
S1_doubleA1D3_9  ='59AD9845-D209-4929-8E83-5C3FCBD50C90.png'
S1_doubleA1D4_9  = '630B56EB-1A02-4C39-8E72-401279881303.png'

# %%
S1_doubleA1A1_10 = 'C88EF40F-E3F2-462F-9F7F-F2BACB0E4704.png'
S1_doubleA1A2_10 = 'DDC4DC8E-B6F3-4C8E-B168-D77C99A200B0.png'
S1_doubleA1A3_10  = 'D82BB03D-596F-4490-A11A-78CC339EF07E.png'
S1_doubleA1A3_510  = '01115472-EC3A-48C7-B1FB-263259578BD7.png'
S1_doubleA1A4_10  = 'A7B00E08-3ED6-4D0D-A76A-59936068AD40.png'
S1_doubleA1B1_10  = '7EE62CC1-C35A-4BD5-8B99-7A02F504FB92.png'
S1_doubleA1B2_10  = 'BEE4A20C-2B3A-4083-964D-EB3923B388F9.png'
S1_doubleA1B3_10  ='BF7F9C19-2AB0-4C4B-BBF5-EF32E953C0B7.png'
S1_doubleA1B4_10  = 'AAF41B6A-64A6-4300-9FE7-3E9652AA67F2.png'
S1_doubleA1C1_10  ='EBA0C742-6F93-40D7-BBDC-FDA0F7717CF5.png'
S1_doubleA1C2_10  ='EBA0C742-6F93-40D7-BBDC-FDA0F7717CF5.png'
S1_doubleA1C3_10  ='041A2217-2C1E-4183-940C-81AF1B7ADCEB.png'
S1_doubleA1C4_10  ='F228CEDF-9850-4974-955D-6A187146338E.png'
S1_doubleA1D2_10  = '59AD9845-D209-4929-8E83-5C3FCBD50C90.png'
S1_doubleA1D3_10  ='59AD9845-D209-4929-8E83-5C3FCBD50C90.png'
S1_doubleA1D4_10  = '630B56EB-1A02-4C39-8E72-401279881303.png'

# %% [markdown]
# ##Set2

# %%
S2_doubleA1A1_1 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1A2_1 = 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_1 = 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_51 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_1 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_1 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_1 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_1 = 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_1 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_1 = 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_1 = 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_1 = '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_1 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1D2_1 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_1 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_1 = 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_2 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_2= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_2= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_52 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_2 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_2 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_2 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_2 = 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_2 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_2 = 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_2= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_2= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_2 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_2 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_2 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_2 = 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_3 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_3= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_3= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_53 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_3 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_3 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_3 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_3 = 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_3 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_3 = 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_3= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_3= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_3 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_3 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_3 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_3 = 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_4 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_4= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_4= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_54 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_4 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_4 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_4 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_4 = 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_4 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_4 = 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_4= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_4= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_4 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_4 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_4 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_4 = 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_5 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_5= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_5= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_55 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_5= '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_5 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_5 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_5 = 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_5 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_5= 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_5= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_5= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_5 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_5 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_5= 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_5 = 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_6 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_6= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_6= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_56 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_6 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_6 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_6 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_6 = 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_6 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_6 = 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_6= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_6= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_6 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_6 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_6 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_6= 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_7 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_7= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_7= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_57 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_7 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_7 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_7= '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_7 = 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_7 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_7 = 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_7= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_7= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_7 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_7 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_7 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_7 = 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_8 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_8= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_8= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_58 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_8 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_8 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_8 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_8= 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_8 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_8= 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_8= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_8= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_8 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_8 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_8 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_8= 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_9 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_9= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_9= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_59 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_9 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_9= '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_9 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_9 = 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_9 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_9 = 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_9= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_9= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_9 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_9 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_9 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_9 = 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %%
S2_doubleA1A1_10 = '4DCAC53D-53D8-4E07-A30F-8EAD67E34DA4.png'
S2_doubleA1A2_10= 'AEBFAF3C-11C4-4EF2-8260-5838F8F52013.png'
S2_doubleA1A3_10= 'CE6B785F-8B23-4F7D-8BB6-8E63EBC72E6C.png'
S2_doubleA1A3_510 = '45233628-36DE-4FEE-B7CB-661E14EA313F.png'
S2_doubleA1A4_10 = '1FBF4A8E-0006-44D2-9C08-61D87D8952A8.png'
S2_doubleA1B1_10 = '1BFDB4C3-F7BE-4F15-B871-6B99CC85141B.png'
S2_doubleA1B2_10 = '23C045CF-EE31-494D-8B99-BE985CE3725E.png'
S2_doubleA1B3_10= 'DBFDD2AC-0191-4C0D-AD17-0637A470462E.png'
S2_doubleA1B4_10 = '56F27ADF-51AE-4EDB-828A-2F1C5F94583D.png'
S2_doubleA1C1_10 = 'ABB8000F-17B5-47FB-85C2-716229841F14.png'
S2_doubleA1C2_10= 'A5FF2537-07B9-4280-BEBF-9D9E952E882B.png'
S2_doubleA1C3_10= '02CEA581-8594-4689-AB73-61778735FA7A.png'
S2_doubleA1C4_10 = '34F0629C-69B1-4125-85F4-7E496A7847A0.png'
S2_doubleA1D2_10 = '79C85FCC-1A21-47FD-B903-3C9B74CB7A12.png'
S2_doubleA1D3_10 = 'EB090E23-38A2-49E5-ACE0-C0F500AA9102.png'
S2_doubleA1D4_10 = 'C69798C5-16B6-4A23-BD0A-0A6B4EC9B5CE.png'

# %% [markdown]
# ##Set3

# %%
S3_doubleA1A1_1 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_1 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_1 = '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_51 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_1 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_1 = 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_1 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_1 = '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_1 = '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_1 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_1 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_1 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_1 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_1 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_1 = '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_1 = 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_2 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_2 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_2 = '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_52 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_2 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_2 = 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_2 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_2 = '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_2 = '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_2 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_2 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_2 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_2 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_2 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_2= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_2 = 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_3 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_3 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_3= '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_53 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_3 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_3 = 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_3 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_3 = '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_3= '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_3 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_3 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_3 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_3 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_3 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_3= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_3 = 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_4 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_4 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_4 = '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_54 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_4 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_4 = 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_4 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_4= '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_4 = '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_4 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_4 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_4 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_4 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_4 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_4= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_4 = 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_5 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_5 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_5 = '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_55 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_5 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_5= 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_5 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_5= '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_5 = '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_5 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_5 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_5 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_5 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_5 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_5= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_5 = 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_6 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_6 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_6= '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_56 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_6 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_6= 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_6 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_6= '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_6 = '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_6 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_6 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_6 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_6 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_6 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_6= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_6= 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_7 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_7 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_7= '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_57 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_7 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_7 = 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_7 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_7= '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_7 = '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_7 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_7 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_7 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_7 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_7 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_7= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_7 = 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_8 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_8 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_8 = '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_58 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_8 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_8 = 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_8 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_8 = '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_8= '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_8 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_8= '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_8 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_8 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_8 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_8= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_8 = 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_9 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_9 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_9 = '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_59 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_9 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_9 = 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_9 = 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_9 = '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_9 = '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_9 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_9 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_9 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_9= '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_9 = 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_9= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_9 = 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %%
S3_doubleA1A1_10 = '6CF2D4E8-1C13-4476-96FB-D618BCB119B7.png'
S3_doubleA1A2_10 = '464DBB6E-8D53-41EC-89E3-09269D750F86.png'
S3_doubleA1A3_10 = '1D1C00BB-399B-4D94-80A1-3265036A98A8.png'
S3_doubleA1A3_510 = 'C925DC00-E29E-47F6-9BB5-8C641EC1871C.png'
S3_doubleA1A4_10 = '2E6D7DC3-E901-4470-9EC3-4EFB37E4C99C.png'
S3_doubleA1B1_10= 'B0254C1B-A034-453B-8194-23B84EDC85BB.png'
S3_doubleA1B2_10= 'CB28F551-0BCC-4650-80CE-0683F9345235.png'
S3_doubleA1B3_10= '0BAC5F9E-D191-44AC-906B-83F55EEE5408.png'
S3_doubleA1B4_10= '71D35775-7DD2-4B6E-9923-F369DD4C7122.png'
S3_doubleA1C1_10 = '792DFC5D-B478-4676-88BF-B27DA22BCD00.png'
S3_doubleA1C2_10 = '22CE3934-3E63-4B67-8414-1378D1E33513.png'
S3_doubleA1C3_10 = '043D02F0-F919-42FC-900C-EA61D154F7F3.png'
S3_doubleA1C4_10 = '6AA17A82-8A03-4963-AED4-F52CF63E955B.png'
S3_doubleA1D2_10= 'E6696409-77B9-44AF-B6F8-4A4F0A0337DD.png'
S3_doubleA1D3_10= '7C182FF2-8AB9-46AC-8DC5-479ECDA47B76.png'
S3_doubleA1D4_10= 'EF26E1BB-3878-4366-8F27-1D0E712AFC27.png'

# %% [markdown]
# ##Set4

# %%
S4_doubleA1A1_1 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_1 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_1 = '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_51 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_1 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_1 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_1 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_1 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_1 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_1 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_1 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_1 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_1 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_1 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_1 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_1 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_2 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_2 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_2 = '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_52 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_2 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_2 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_2 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_2 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_2 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_2 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_2 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_2= '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_2 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_2 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_2 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_2 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_3= 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_3 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_3 = '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_53 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_3 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_3 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_3 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_3 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_3 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_3= 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_3 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_3 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_3 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_3 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_3 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_3 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_4 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_4 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_4 = '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_54 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_4 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_4 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_4 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_4 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_4 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_4 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_4 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_4 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_4 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_4 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_4 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_4 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_5 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_5 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_5= '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_55 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_5 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_5 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_5 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_5= '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_5 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_5 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_5 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_5 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_5 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_5 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_5 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_5 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_6 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_6 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_6 = '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_56 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_6 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_6 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_6 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_6 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_6 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_6 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_6 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_6 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_6 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_6 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_6 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_6 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_7 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_7 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_7 = '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_57 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_7 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_7 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_7= '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_7 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_7 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_7 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_7 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_7 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_7 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_7 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_7= '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_7 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_8 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_8 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_8 = '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_58 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_8 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_8 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_8 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_8 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_8 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_8 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_8 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_8 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_8 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_8 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_8 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_8 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_9 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_9= '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_9= '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_59 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_9 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_9= '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_9 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_9 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_9 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_9 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_9= '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_9 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_9 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_9 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_9 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_9 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %%
S4_doubleA1A1_10 = 'C3752024-70F6-407B-B596-E214E55D43EB.png'
S4_doubleA1A2_10 = '953E3485-ACFA-4EDA-B270-F9AA84853C94.png'
S4_doubleA1A3_10 = '83B80683-3A06-474F-90E6-62391CB7A3F6.png'
S4_doubleA1A3_510 = '01BD2023-D6A1-4AAA-A5A6-F507208F8E54.png'
S4_doubleA1A4_10 = '372CFE56-E625-434C-A2DC-0FEEB167DDBA.png'
S4_doubleA1B1_10 = '35484F9C-7BCF-4C31-A381-CCC85035B5FE.png'
S4_doubleA1B2_10 = '29140CD3-A1A5-448C-B825-7BCBA9431B85.png'
S4_doubleA1B3_10 = '123A90E7-21CE-4D56-B992-62F16D74A8FE.png'
S4_doubleA1B4_10 = 'E561F380-5A2D-496F-B9F3-4B9907F020D6.png'
S4_doubleA1C1_10 = 'F3E98998-3329-49D5-8439-80F6AF00BFE3.png'
S4_doubleA1C2_10 = '56D069F6-8B47-48B3-9C6E-25AD8751779A.png'
S4_doubleA1C3_10 = '2F670532-3760-42FC-A982-1670FEE99E66.png'
S4_doubleA1C4_10 = 'A40A09DE-DC0F-4A00-A891-F3D66A2F7CB5.png'
S4_doubleA1D2_10 = 'E4566E8E-9E0D-4531-9712-5B47AE5386DE.png'
S4_doubleA1D3_10 = '23C5E347-A9A1-466C-917D-E969268302DA.png'
S4_doubleA1D4_10 = 'EFB719A3-D16E-42A3-861D-363E24755F58.png'

# %% [markdown]
# #2. ดึงรูป

# %%
import cv2
from matplotlib import pyplot as plt #การเรียกใช้คำสั่ง matplotlib เพื่อวาดกราฟ โดยแทนชื่อ matplotlib ด้วย plt
import matplotlib

# %% [markdown]
# ##Set1

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_51) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 2

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_52) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 3

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_53) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 4

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_54) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 5

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_55) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 6

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_56) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 7

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_57) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 8

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_58) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 9

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_59) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 10

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A3_510) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1A4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1B4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1C4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S1_doubleA1D4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ##Set2

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_51) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 2

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_52) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 3

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_53) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 4

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_54) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 5

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_55) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
  full_path_to_file2 = os.path.join(S2_doubleA1B3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 6

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_56) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 7

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_57) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 8

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_58) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 9

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_59) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 10

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A3_510) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1A4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1C4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1D4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ##Set3

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_51) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 2

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_52) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 3

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_53) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S2_doubleA1B3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 4

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_54) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 5

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_55) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 6

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_56) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 7

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_57) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 8

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_58) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 9

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_59) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 10

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A3_510) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1A4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1B4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1C4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S3_doubleA1D4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ##Set4

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_51) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_1) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 2

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_52) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_2) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 3

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_53) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_3) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 4

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_54) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_4) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 5

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_55) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_5) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 6

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_56) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_6) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 7

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_57) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_7) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 8

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_58) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_8) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 9

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_59) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_9) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# ###Img 10

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A3_510) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1A4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1B4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C1_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1C4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D2_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D3_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %%
full_path_to_file2 = os.path.join(S4_doubleA1D4_10) 
blob_service_client.get_blob_to_path('shadeimg', full_path_to_file2, full_path_to_file2)

# %% [markdown]
# #3. BGR to RGB

# %%
import cv2
from matplotlib import pyplot as plt #การเรียกใช้คำสั่ง matplotlib เพื่อวาดกราฟ โดยแทนชื่อ matplotlib ด้วย plt
import matplotlib

# %% [markdown]
# ##Set1

# %%
imgS1_A1A1_1  = cv2.imread(S1_doubleA1A1_1)
S1RGB_imgA1A1_1= cv2.cvtColor(imgS1_A1A1_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_1  = cv2.imread(S1_doubleA1A2_1)
S1RGB_imgA1A2_1= cv2.cvtColor(imgS1_A1A2_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_1  = cv2.imread(S1_doubleA1A3_1)
S1RGB_imgA1A3_1= cv2.cvtColor(imgS1_A1A3_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_51  = cv2.imread(S1_doubleA1A3_51)
S1RGB_imgA1A3_51= cv2.cvtColor(imgS1_A1A3_51, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_1  = cv2.imread(S1_doubleA1A4_1)
S1RGB_imgA1A4_1= cv2.cvtColor(imgS1_A1A4_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_1  = cv2.imread(S1_doubleA1B1_1)
S1RGB_imgA1B1_1= cv2.cvtColor(imgS1_A1B1_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_1  = cv2.imread(S1_doubleA1B2_1)
S1RGB_imgA1B2_1= cv2.cvtColor(imgS1_A1B2_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_1  = cv2.imread(S1_doubleA1A3_1)
S1RGB_imgA1B3_1= cv2.cvtColor(imgS1_A1A3_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_1  = cv2.imread(S1_doubleA1B4_1)
S1RGB_imgA1B4_1= cv2.cvtColor(imgS1_A1B4_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_1  = cv2.imread(S1_doubleA1C1_1)
S1RGB_imgA1C1_1= cv2.cvtColor(imgS1_A1C1_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_1  = cv2.imread(S1_doubleA1C2_1)
S1RGB_imgA1C2_1= cv2.cvtColor(imgS1_A1C2_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_1  = cv2.imread(S1_doubleA1C3_1)
S1RGB_imgA1C3_1= cv2.cvtColor(imgS1_A1C3_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_1  = cv2.imread(S1_doubleA1C4_1)
S1RGB_imgA1C4_1= cv2.cvtColor(imgS1_A1C4_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_1  = cv2.imread(S1_doubleA1D2_1)
S1RGB_imgA1D2_1= cv2.cvtColor(imgS1_A1D2_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_1  = cv2.imread(S1_doubleA1D3_1)
S1RGB_imgA1D3_1= cv2.cvtColor(imgS1_A1D3_1, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_1  = cv2.imread(S1_doubleA1D4_1)
S1RGB_imgA1D4_1= cv2.cvtColor(imgS1_A1D4_1, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 2

# %%
imgS1_A1A1_2 = cv2.imread(S1_doubleA1A1_2)
S1RGB_imgA1A1_2= cv2.cvtColor(imgS1_A1A1_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_2 = cv2.imread(S1_doubleA1A2_2)
S1RGB_imgA1A2_2= cv2.cvtColor(imgS1_A1A2_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_2= cv2.imread(S1_doubleA1A3_2)
S1RGB_imgA1A3_2= cv2.cvtColor(imgS1_A1A3_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_52  = cv2.imread(S1_doubleA1A3_52)
S1RGB_imgA1A3_52= cv2.cvtColor(imgS1_A1A3_52, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_2 = cv2.imread(S1_doubleA1A4_2)
S1RGB_imgA1A4_2= cv2.cvtColor(imgS1_A1A4_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_2= cv2.imread(S1_doubleA1B1_2)
S1RGB_imgA1B1_= cv2.cvtColor(imgS1_A1B1_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_2 = cv2.imread(S1_doubleA1B2_2)
S1RGB_imgA1B2_2= cv2.cvtColor(imgS1_A1B2_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_2  = cv2.imread(S1_doubleA1B3_2)
S1RGB_imgA1B3_2= cv2.cvtColor(imgS1_A1B3_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_2 = cv2.imread(S1_doubleA1B4_2)
S1RGB_imgA1B4_2= cv2.cvtColor(imgS1_A1B4_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_2  = cv2.imread(S1_doubleA1C1_2)
S1RGB_imgA1C1_2= cv2.cvtColor(imgS1_A1C1_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_2  = cv2.imread(S1_doubleA1C2_2)
S1RGB_imgA1C2_2= cv2.cvtColor(imgS1_A1C2_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_2  = cv2.imread(S1_doubleA1C3_2)
S1RGB_imgA1C3_2= cv2.cvtColor(imgS1_A1C3_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_2 = cv2.imread(S1_doubleA1C4_2)
S1RGB_imgA1C4_2= cv2.cvtColor(imgS1_A1C4_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_2 = cv2.imread(S1_doubleA1D2_2)
S1RGB_imgA1D2_2= cv2.cvtColor(imgS1_A1D2_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_2 = cv2.imread(S1_doubleA1D3_2)
S1RGB_imgA1D3_2= cv2.cvtColor(imgS1_A1D3_2, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_2  = cv2.imread(S1_doubleA1D4_2)
S1RGB_imgA1D4_2= cv2.cvtColor(imgS1_A1D4_2, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 3

# %%
imgS1_A1A1_3= cv2.imread(S1_doubleA1A1_3)
S1RGB_imgA1A1_3= cv2.cvtColor(imgS1_A1A1_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_3 = cv2.imread(S1_doubleA1A2_3)
S1RGB_imgA1A2_3= cv2.cvtColor(imgS1_A1A2_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_3= cv2.imread(S1_doubleA1A3_3)
S1RGB_imgA1A3_3= cv2.cvtColor(imgS1_A1A3_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_53  = cv2.imread(S1_doubleA1A3_53)
S1RGB_imgA1A3_53= cv2.cvtColor(imgS1_A1A3_53, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_3  = cv2.imread(S1_doubleA1A4_3)
S1RGB_imgA1A4_3= cv2.cvtColor(imgS1_A1A4_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_3  = cv2.imread(S1_doubleA1B1_3)
S1RGB_imgA1B1_3= cv2.cvtColor(imgS1_A1B1_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_3 = cv2.imread(S1_doubleA1B2_3)
S1RGB_imgA1B2_3= cv2.cvtColor(imgS1_A1B2_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_3  = cv2.imread(S1_doubleA1B3_3)
S1RGB_imgA1B3_3= cv2.cvtColor(imgS1_A1B3_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_3  = cv2.imread(S1_doubleA1B4_3)
S1RGB_imgA1B4_3= cv2.cvtColor(imgS1_A1B4_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_3  = cv2.imread(S1_doubleA1C1_3)
S1RGB_imgA1C1_3= cv2.cvtColor(imgS1_A1C1_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_3  = cv2.imread(S1_doubleA1C2_3)
S1RGB_imgA1C2_3= cv2.cvtColor(imgS1_A1C2_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_3  = cv2.imread(S1_doubleA1C3_3)
S1RGB_imgA1C3_3= cv2.cvtColor(imgS1_A1C3_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_3 = cv2.imread(S1_doubleA1C4_3)
S1RGB_imgA1C4_3= cv2.cvtColor(imgS1_A1C4_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_3  = cv2.imread(S1_doubleA1D2_3)
S1RGB_imgA1D2_3= cv2.cvtColor(imgS1_A1D2_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_3 = cv2.imread(S1_doubleA1D3_3)
S1RGB_imgA1D3_3= cv2.cvtColor(imgS1_A1D3_3, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_3  = cv2.imread(S1_doubleA1D4_3)
S1RGB_imgA1D4_3= cv2.cvtColor(imgS1_A1D4_3, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 4

# %%
imgS1_A1A1_4 = cv2.imread(S1_doubleA1A1_4)
S1RGB_imgA1A1_4= cv2.cvtColor(imgS1_A1A1_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_4  = cv2.imread(S1_doubleA1A2_4)
S1RGB_imgA1A2_4= cv2.cvtColor(imgS1_A1A2_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_4= cv2.imread(S1_doubleA1A3_4)
S1RGB_imgA1A3_4= cv2.cvtColor(imgS1_A1A3_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_54  = cv2.imread(S1_doubleA1A3_54)
S1RGB_imgA1A3_54= cv2.cvtColor(imgS1_A1A3_54, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_4  = cv2.imread(S1_doubleA1A4_4)
S1RGB_imgA1A4_4= cv2.cvtColor(imgS1_A1A4_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_4  = cv2.imread(S1_doubleA1B1_4)
S1RGB_imgA1B1_4= cv2.cvtColor(imgS1_A1B1_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_4 = cv2.imread(S1_doubleA1B2_4)
S1RGB_imgA1B2_4= cv2.cvtColor(imgS1_A1B2_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_  = cv2.imread(S1_doubleA1B3_4)
S1RGB_imgA1B3_= cv2.cvtColor(imgS1_A1B3_, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_4  = cv2.imread(S1_doubleA1B4_4)
S1RGB_imgA1B4_4= cv2.cvtColor(imgS1_A1B4_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_4 = cv2.imread(S1_doubleA1C1_4)
S1RGB_imgA1C1_4= cv2.cvtColor(imgS1_A1C1_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_4  = cv2.imread(S1_doubleA1C2_4)
S1RGB_imgA1C2_4= cv2.cvtColor(imgS1_A1C2_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_4 = cv2.imread(S1_doubleA1C3_4)
S1RGB_imgA1C3_4= cv2.cvtColor(imgS1_A1C3_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_4  = cv2.imread(S1_doubleA1C4_4)
S1RGB_imgA1C4_4= cv2.cvtColor(imgS1_A1C4_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_4  = cv2.imread(S1_doubleA1D2_4)
S1RGB_imgA1D2_4= cv2.cvtColor(imgS1_A1D2_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_4  = cv2.imread(S1_doubleA1D3_4)
S1RGB_imgA1D3_4= cv2.cvtColor(imgS1_A1D3_4, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_4 = cv2.imread(S1_doubleA1D4_4)
S1RGB_imgA1D4_4= cv2.cvtColor(imgS1_A1D4_4, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 5

# %%
imgS1_A1A1_5 = cv2.imread(S1_doubleA1A1_5)
S1RGB_imgA1A1_5= cv2.cvtColor(imgS1_A1A1_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_5 = cv2.imread(S1_doubleA1A2_5)
S1RGB_imgA1A2_5= cv2.cvtColor(imgS1_A1A2_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_5= cv2.imread(S1_doubleA1A3_5)
S1RGB_imgA1A3_5= cv2.cvtColor(imgS1_A1A3_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_55  = cv2.imread(S1_doubleA1A3_55)
S1RGB_imgA1A3_55= cv2.cvtColor(imgS1_A1A3_55, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_5  = cv2.imread(S1_doubleA1A4_5)
S1RGB_imgA1A4_5= cv2.cvtColor(imgS1_A1A4_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_5  = cv2.imread(S1_doubleA1B1_5)
S1RGB_imgA1B1_5= cv2.cvtColor(imgS1_A1B1_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_5  = cv2.imread(S1_doubleA1B2_5)
S1RGB_imgA1B2_5= cv2.cvtColor(imgS1_A1B2_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_5  = cv2.imread(S1_doubleA1B3_5)
S1RGB_imgA1B3_5= cv2.cvtColor(imgS1_A1B3_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_5  = cv2.imread(S1_doubleA1B4_5)
S1RGB_imgA1B4_5= cv2.cvtColor(imgS1_A1B4_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_5 = cv2.imread(S1_doubleA1C1_5)
S1RGB_imgA1C1_5= cv2.cvtColor(imgS1_A1C1_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_5  = cv2.imread(S1_doubleA1C2_5)
S1RGB_imgA1C2_5= cv2.cvtColor(imgS1_A1C2_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_5  = cv2.imread(S1_doubleA1C3_5)
S1RGB_imgA1C3_5= cv2.cvtColor(imgS1_A1C3_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_5= cv2.imread(S1_doubleA1C4_5)
S1RGB_imgA1C4_5= cv2.cvtColor(imgS1_A1C4_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_5 = cv2.imread(S1_doubleA1D2_5)
S1RGB_imgA1D2_5= cv2.cvtColor(imgS1_A1D2_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_5  = cv2.imread(S1_doubleA1D3_5)
S1RGB_imgA1D3_5= cv2.cvtColor(imgS1_A1D3_5, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_5  = cv2.imread(S1_doubleA1D4_5)
S1RGB_imgA1D4_5= cv2.cvtColor(imgS1_A1D4_5, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 6

# %%
imgS1_A1A1_6 = cv2.imread(S1_doubleA1A1_6)
S1RGB_imgA1A1_6= cv2.cvtColor(imgS1_A1A1_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_6  = cv2.imread(S1_doubleA1A2_6)
S1RGB_imgA1A2_6= cv2.cvtColor(imgS1_A1A2_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_6= cv2.imread(S1_doubleA1A3_6)
S1RGB_imgA1A3_6= cv2.cvtColor(imgS1_A1A3_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_56  = cv2.imread(S1_doubleA1A3_56)
S1RGB_imgA1A3_56= cv2.cvtColor(imgS1_A1A3_56, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_6= cv2.imread(S1_doubleA1A4_6)
S1RGB_imgA1A4_6= cv2.cvtColor(imgS1_A1A4_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_6  = cv2.imread(S1_doubleA1B1_6)
S1RGB_imgA1B1_6= cv2.cvtColor(imgS1_A1B1_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_6  = cv2.imread(S1_doubleA1B2_6)
S1RGB_imgA1B2_6= cv2.cvtColor(imgS1_A1B2_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_6 = cv2.imread(S1_doubleA1B3_6)
S1RGB_imgA1B3_6= cv2.cvtColor(imgS1_A1B3_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_6 = cv2.imread(S1_doubleA1B4_6)
S1RGB_imgA1B4_6= cv2.cvtColor(imgS1_A1B4_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_6  = cv2.imread(S1_doubleA1C1_6)
S1RGB_imgA1C1_6= cv2.cvtColor(imgS1_A1C1_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_6  = cv2.imread(S1_doubleA1C2_6)
S1RGB_imgA1C2_6= cv2.cvtColor(imgS1_A1C2_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_6 = cv2.imread(S1_doubleA1C3_6)
S1RGB_imgA1C3_6= cv2.cvtColor(imgS1_A1C3_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_6 = cv2.imread(S1_doubleA1C4_6)
S1RGB_imgA1C4_6= cv2.cvtColor(imgS1_A1C4_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_6  = cv2.imread(S1_doubleA1D2_6)
S1RGB_imgA1D2_6= cv2.cvtColor(imgS1_A1D2_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_6  = cv2.imread(S1_doubleA1D3_6)
S1RGB_imgA1D3_6= cv2.cvtColor(imgS1_A1D3_6, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_6  = cv2.imread(S1_doubleA1D4_6)
S1RGB_imgA1D4_6= cv2.cvtColor(imgS1_A1D4_6, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 7

# %%
imgS1_A1A1_7 = cv2.imread(S1_doubleA1A1_7)
S1RGB_imgA1A1_7= cv2.cvtColor(imgS1_A1A1_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_7  = cv2.imread(S1_doubleA1A2_7)
S1RGB_imgA1A2_7= cv2.cvtColor(imgS1_A1A2_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_7= cv2.imread(S1_doubleA1A3_7)
S1RGB_imgA1A3_7= cv2.cvtColor(imgS1_A1A3_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_57  = cv2.imread(S1_doubleA1A3_57)
S1RGB_imgA1A3_57= cv2.cvtColor(imgS1_A1A3_57, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_7  = cv2.imread(S1_doubleA1A4_7)
S1RGB_imgA1A4_7= cv2.cvtColor(imgS1_A1A4_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_7 = cv2.imread(S1_doubleA1B1_7)
S1RGB_imgA1B1_7= cv2.cvtColor(imgS1_A1B1_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_7 = cv2.imread(S1_doubleA1B2_7)
S1RGB_imgA1B2_7= cv2.cvtColor(imgS1_A1B2_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_7= cv2.imread(S1_doubleA1B3_7)
S1RGB_imgA1B3_7= cv2.cvtColor(imgS1_A1B3_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_7  = cv2.imread(S1_doubleA1B4_7)
S1RGB_imgA1B4_7= cv2.cvtColor(imgS1_A1B4_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_7 = cv2.imread(S1_doubleA1C1_7)
S1RGB_imgA1C1_7= cv2.cvtColor(imgS1_A1C1_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_7 = cv2.imread(S1_doubleA1C2_7)
S1RGB_imgA1C2_7= cv2.cvtColor(imgS1_A1C2_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_7  = cv2.imread(S1_doubleA1C3_7)
S1RGB_imgA1C3_7= cv2.cvtColor(imgS1_A1C3_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_7  = cv2.imread(S1_doubleA1C4_7)
S1RGB_imgA1C4_7= cv2.cvtColor(imgS1_A1C4_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_7 = cv2.imread(S1_doubleA1D2_7)
S1RGB_imgA1D2_7= cv2.cvtColor(imgS1_A1D2_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_7  = cv2.imread(S1_doubleA1D3_7)
S1RGB_imgA1D3_7= cv2.cvtColor(imgS1_A1D3_7, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_7  = cv2.imread(S1_doubleA1D4_7)
S1RGB_imgA1D4_7= cv2.cvtColor(imgS1_A1D4_7, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 8

# %%
imgS1_A1A1_8 = cv2.imread(S1_doubleA1A1_8)
S1RGB_imgA1A1_8= cv2.cvtColor(imgS1_A1A1_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_8  = cv2.imread(S1_doubleA1A2_8)
S1RGB_imgA1A2_8= cv2.cvtColor(imgS1_A1A2_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_8= cv2.imread(S1_doubleA1A3_8)
S1RGB_imgA1A3_8= cv2.cvtColor(imgS1_A1A3_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_58  = cv2.imread(S1_doubleA1A3_58)
S1RGB_imgA1A3_58= cv2.cvtColor(imgS1_A1A3_58, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_8  = cv2.imread(S1_doubleA1A4_8)
S1RGB_imgA1A4_8= cv2.cvtColor(imgS1_A1A4_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_8  = cv2.imread(S1_doubleA1B1_8)
S1RGB_imgA1B1_8= cv2.cvtColor(imgS1_A1B1_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_8  = cv2.imread(S1_doubleA1B2_8)
S1RGB_imgA1B2_8= cv2.cvtColor(imgS1_A1B2_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_8  = cv2.imread(S1_doubleA1B3_8)
S1RGB_imgA1B3_8= cv2.cvtColor(imgS1_A1B3_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_8  = cv2.imread(S1_doubleA1B4_8)
S1RGB_imgA1B4_8= cv2.cvtColor(imgS1_A1B4_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_8 = cv2.imread(S1_doubleA1C1_8)
S1RGB_imgA1C1_8= cv2.cvtColor(imgS1_A1C1_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_8 = cv2.imread(S1_doubleA1C2_8)
S1RGB_imgA1C2_8= cv2.cvtColor(imgS1_A1C2_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_8  = cv2.imread(S1_doubleA1C3_8)
S1RGB_imgA1C3_8= cv2.cvtColor(imgS1_A1C3_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_8  = cv2.imread(S1_doubleA1C4_8)
S1RGB_imgA1C4_8= cv2.cvtColor(imgS1_A1C4_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_8  = cv2.imread(S1_doubleA1D2_8)
S1RGB_imgA1D2_8= cv2.cvtColor(imgS1_A1D2_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_8 = cv2.imread(S1_doubleA1D3_8)
S1RGB_imgA1D3_8= cv2.cvtColor(imgS1_A1D3_8, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_8= cv2.imread(S1_doubleA1D4_8)
S1RGB_imgA1D4_8= cv2.cvtColor(imgS1_A1D4_8, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 9

# %%
imgS1_A1A1_9= cv2.imread(S1_doubleA1A1_9)
S1RGB_imgA1A1_9= cv2.cvtColor(imgS1_A1A1_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_9  = cv2.imread(S1_doubleA1A2_9)
S1RGB_imgA1A2_9= cv2.cvtColor(imgS1_A1A2_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_9= cv2.imread(S1_doubleA1A3_9)
S1RGB_imgA1A3_9= cv2.cvtColor(imgS1_A1A3_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_59  = cv2.imread(S1_doubleA1A3_59)
S1RGB_imgA1A3_59= cv2.cvtColor(imgS1_A1A3_59, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_9  = cv2.imread(S1_doubleA1A4_9)
S1RGB_imgA1A4_9= cv2.cvtColor(imgS1_A1A4_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_9  = cv2.imread(S1_doubleA1B1_9)
S1RGB_imgA1B1_9= cv2.cvtColor(imgS1_A1B1_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_9  = cv2.imread(S1_doubleA1B2_9)
S1RGB_imgA1B2_9= cv2.cvtColor(imgS1_A1B2_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_9  = cv2.imread(S1_doubleA1B3_9)
S1RGB_imgA1B3_9= cv2.cvtColor(imgS1_A1B3_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_9 = cv2.imread(S1_doubleA1B4_9)
S1RGB_imgA1B4_9= cv2.cvtColor(imgS1_A1B4_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_9  = cv2.imread(S1_doubleA1C1_9)
S1RGB_imgA1C1_9= cv2.cvtColor(imgS1_A1C1_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_9  = cv2.imread(S1_doubleA1C2_9)
S1RGB_imgA1C2_9= cv2.cvtColor(imgS1_A1C2_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_9  = cv2.imread(S1_doubleA1C3_9)
S1RGB_imgA1C3_9= cv2.cvtColor(imgS1_A1C3_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_9 = cv2.imread(S1_doubleA1C4_9)
S1RGB_imgA1C4_9= cv2.cvtColor(imgS1_A1C4_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_9 = cv2.imread(S1_doubleA1D2_9)
S1RGB_imgA1D2_9= cv2.cvtColor(imgS1_A1D2_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_9 = cv2.imread(S1_doubleA1D3_9)
S1RGB_imgA1D3_9= cv2.cvtColor(imgS1_A1D3_9, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_9 = cv2.imread(S1_doubleA1D4_9)
S1RGB_imgA1D4_9= cv2.cvtColor(imgS1_A1D4_9, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 10

# %%
imgS1_A1A1_10 = cv2.imread(S1_doubleA1A1_10)
S1RGB_imgA1A1_10= cv2.cvtColor(imgS1_A1A1_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A2_10  = cv2.imread(S1_doubleA1A2_10)
S1RGB_imgA1A2_10= cv2.cvtColor(imgS1_A1A2_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_10= cv2.imread(S1_doubleA1A3_10)
S1RGB_imgA1A3_10= cv2.cvtColor(imgS1_A1A3_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A3_510 = cv2.imread(S1_doubleA1A3_510)
S1RGB_imgA1A3_510= cv2.cvtColor(imgS1_A1A3_510, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1A4_10 = cv2.imread(S1_doubleA1A4_10)
S1RGB_imgA1A4_10= cv2.cvtColor(imgS1_A1A4_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B1_10  = cv2.imread(S1_doubleA1B1_10)
S1RGB_imgA1B1_10= cv2.cvtColor(imgS1_A1B1_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B2_10  = cv2.imread(S1_doubleA1B2_10)
S1RGB_imgA1B2_10= cv2.cvtColor(imgS1_A1B2_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B3_10  = cv2.imread(S1_doubleA1B3_10)
S1RGB_imgA1B3_10= cv2.cvtColor(imgS1_A1B3_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1B4_10 = cv2.imread(S1_doubleA1B4_10)
S1RGB_imgA1B4_10= cv2.cvtColor(imgS1_A1B4_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C1_10  = cv2.imread(S1_doubleA1C1_10)
S1RGB_imgA1C1_10= cv2.cvtColor(imgS1_A1C1_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C2_10  = cv2.imread(S1_doubleA1C2_10)
S1RGB_imgA1C2_10= cv2.cvtColor(imgS1_A1C2_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C3_10  = cv2.imread(S1_doubleA1C3_10)
S1RGB_imgA1C3_10= cv2.cvtColor(imgS1_A1C3_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1C4_10 = cv2.imread(S1_doubleA1C4_10)
S1RGB_imgA1C4_10= cv2.cvtColor(imgS1_A1C4_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D2_10 = cv2.imread(S1_doubleA1D2_10)
S1RGB_imgA1D2_10= cv2.cvtColor(imgS1_A1D2_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D3_10  = cv2.imread(S1_doubleA1D3_10)
S1RGB_imgA1D3_10= cv2.cvtColor(imgS1_A1D3_10, cv2.COLOR_BGR2RGB)

# %%
imgS1_A1D4_10  = cv2.imread(S1_doubleA1D4_10)
S1RGB_imgA1D4_10= cv2.cvtColor(imgS1_A1D4_10, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ##Set2

# %%
imgS2_A1A1_1  = cv2.imread(S2_doubleA1A1_1)
S2RGB_imgA1A1_1= cv2.cvtColor(imgS2_A1A1_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_1  = cv2.imread(S2_doubleA1A2_1)
S2RGB_imgA1A2_1= cv2.cvtColor(imgS2_A1A2_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_1  = cv2.imread(S2_doubleA1A3_1)
S2RGB_imgA1A3_1= cv2.cvtColor(imgS2_A1A3_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_51  = cv2.imread(S2_doubleA1A3_51)
S2RGB_imgA1A3_51= cv2.cvtColor(imgS2_A1A3_51, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_1  = cv2.imread(S2_doubleA1A4_1)
S2RGB_imgA1A4_1= cv2.cvtColor(imgS2_A1A4_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_1  = cv2.imread(S2_doubleA1B1_1)
S2RGB_imgA1B1_1= cv2.cvtColor(imgS2_A1B1_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_1  = cv2.imread(S2_doubleA1B2_1)
S2RGB_imgA1B2_1= cv2.cvtColor(imgS2_A1B2_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_1  = cv2.imread(S2_doubleA1B3_1)
S2RGB_imgA1B3_1= cv2.cvtColor(imgS2_A1B3_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_1  = cv2.imread(S2_doubleA1B4_1)
S2RGB_imgA1B4_1= cv2.cvtColor(imgS2_A1B4_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_1  = cv2.imread(S2_doubleA1C1_1)
S2RGB_imgA1C1_1= cv2.cvtColor(imgS2_A1C1_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_1  = cv2.imread(S2_doubleA1C2_1)
S2RGB_imgA1C2_1= cv2.cvtColor(imgS2_A1C2_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_1  = cv2.imread(S2_doubleA1C3_1)
S2RGB_imgA1C3_1= cv2.cvtColor(imgS2_A1C3_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_1  = cv2.imread(S2_doubleA1C4_1)
S2RGB_imgA1C4_1= cv2.cvtColor(imgS2_A1C4_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_1  = cv2.imread(S2_doubleA1D2_1)
S2RGB_imgA1D2_1= cv2.cvtColor(imgS2_A1D2_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_1  = cv2.imread(S2_doubleA1D3_1)
S2RGB_imgA1D3_1= cv2.cvtColor(imgS2_A1D3_1, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_1  = cv2.imread(S2_doubleA1D4_1)
S2RGB_imgA1D4_1= cv2.cvtColor(imgS2_A1D4_1, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 2

# %%
imgS2_A1A1_2 = cv2.imread(S2_doubleA1A1_2)
S2RGB_imgA1A1_2= cv2.cvtColor(imgS2_A1A1_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_2 = cv2.imread(S2_doubleA1A2_2)
S2RGB_imgA1A2_2= cv2.cvtColor(imgS2_A1A2_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_2= cv2.imread(S2_doubleA1A3_2)
S2RGB_imgA1A3_2= cv2.cvtColor(imgS2_A1A3_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_52  = cv2.imread(S2_doubleA1A3_52)
S2RGB_imgA1A3_52= cv2.cvtColor(imgS2_A1A3_52, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_2 = cv2.imread(S2_doubleA1A4_2)
S2RGB_imgA1A4_2= cv2.cvtColor(imgS2_A1A4_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_2= cv2.imread(S2_doubleA1B1_2)
S2RGB_imgA1B1_= cv2.cvtColor(imgS2_A1B1_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_2 = cv2.imread(S2_doubleA1B2_2)
S2RGB_imgA1B2_2= cv2.cvtColor(imgS2_A1B2_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_2  = cv2.imread(S2_doubleA1B3_2)
S2RGB_imgA1B3_2= cv2.cvtColor(imgS2_A1B3_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_2 = cv2.imread(S2_doubleA1B4_2)
S2RGB_imgA1B4_2= cv2.cvtColor(imgS2_A1B4_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_2  = cv2.imread(S2_doubleA1C1_2)
S2RGB_imgA1C1_2= cv2.cvtColor(imgS2_A1C1_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_2  = cv2.imread(S2_doubleA1C2_2)
S2RGB_imgA1C2_2= cv2.cvtColor(imgS2_A1C2_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_2  = cv2.imread(S2_doubleA1C3_2)
S2RGB_imgA1C3_2= cv2.cvtColor(imgS2_A1C3_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_2 = cv2.imread(S2_doubleA1C4_2)
S2RGB_imgA1C4_2= cv2.cvtColor(imgS2_A1C4_, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_2 = cv2.imread(S2_doubleA1D2_2)
S2RGB_imgA1D2_2= cv2.cvtColor(imgS2_A1D2_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_2 = cv2.imread(S2_doubleA1D3_2)
S2RGB_imgA1D3_2= cv2.cvtColor(imgS2_A1D3_2, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_2  = cv2.imread(S2_doubleA1D4_2)
S2RGB_imgA1D4_2= cv2.cvtColor(imgS2_A1D4_2, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 3

# %%
imgS2_A1A1_3= cv2.imread(S2_doubleA1A1_3)
S2RGB_imgA1A1_3= cv2.cvtColor(imgS2_A1A1_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_3 = cv2.imread(S2_doubleA1A2_3)
S2RGB_imgA1A2_3= cv2.cvtColor(imgS2_A1A2_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_3= cv2.imread(S2_doubleA1A3_3)
S2RGB_imgA1A3_3= cv2.cvtColor(imgS2_A1A3_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_53  = cv2.imread(S2_doubleA1A3_53)
S2RGB_imgA1A3_53= cv2.cvtColor(imgS2_A1A3_53, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_3  = cv2.imread(S2_doubleA1A4_3)
S2RGB_imgA1A4_3= cv2.cvtColor(imgS2_A1A4_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_3  = cv2.imread(S2_doubleA1B1_3)
S2RGB_imgA1B1_3= cv2.cvtColor(imgS2_A1B1_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_3 = cv2.imread(S2_doubleA1B2_3)
S2RGB_imgA1B2_3= cv2.cvtColor(imgS2_A1B2_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_3  = cv2.imread(S2_doubleA1B3_3)
S2RGB_imgA1B3_3= cv2.cvtColor(imgS2_A1B3_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_3  = cv2.imread(S2_doubleA1B4_3)
S2GB_imgA1B4_3= cv2.cvtColor(imgS2_A1B4_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_3  = cv2.imread(S2_doubleA1C1_3)
S2RGB_imgA1C1_3= cv2.cvtColor(imgS2_A1C1_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_3  = cv2.imread(S2_doubleA1C2_3)
S2RGB_imgA1C2_3= cv2.cvtColor(imgS2_A1C2_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_3  = cv2.imread(S2_doubleA1C3_3)
S2RGB_imgA1C3_3= cv2.cvtColor(imgS2_A1C3_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_3 = cv2.imread(S2_doubleA1C4_3)
S2RGB_imgA1C4_3= cv2.cvtColor(imgS2_A1C4_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_3  = cv2.imread(S2_doubleA1D2_3)
S2RGB_imgA1D2_3= cv2.cvtColor(imgS2_A1D2_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_3 = cv2.imread(S2_doubleA1D3_3)
S2RGB_imgA1D3_3= cv2.cvtColor(imgS2_A1D3_3, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_3  = cv2.imread(S2_doubleA1D4_3)
S2RGB_imgA1D4_3= cv2.cvtColor(imgS2_A1D4_3, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 4

# %%
imgS2_A1A1_4 = cv2.imread(S2_doubleA1A1_4)
S2RGB_imgA1A1_4= cv2.cvtColor(imgS2_A1A1_, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_4  = cv2.imread(S2_doubleA1A2_4)
S2RGB_imgA1A2_4= cv2.cvtColor(imgS2_A1A2_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_4= cv2.imread(S2_doubleA1A3_4)
S2RGB_imgA1A3_4= cv2.cvtColor(imgS2_A1A3_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_54  = cv2.imread(S2_doubleA1A3_54)
S2RGB_imgA1A3_54= cv2.cvtColor(imgS2_A1A3_54, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_4  = cv2.imread(S2_doubleA1A4_4)
S2RGB_imgA1A4_4= cv2.cvtColor(imgS2_A1A4_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_4  = cv2.imread(S2_doubleA1B1_4)
S2RGB_imgA1B1_4= cv2.cvtColor(imgS2_A1B1_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_4 = cv2.imread(S2_doubleA1B2_4)
S2RGB_imgA1B2_4= cv2.cvtColor(imgS2_A1B2_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_  = cv2.imread(S2_doubleA1B3_4)
S2RGB_imgA1B3_= cv2.cvtColor(imgS2_A1B3_, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_4  = cv2.imread(S2_doubleA1B41)
S2RGB_imgA1B4_4= cv2.cvtColor(imgS2_A1B4_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_4 = cv2.imread(S2_doubleA1C1_4)
S2RGB_imgA1C1_4= cv2.cvtColor(imgS2_A1C1_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_4  = cv2.imread(S2_doubleA1C2_4)
S2RGB_imgA1C2_4= cv2.cvtColor(imgS2_A1C2_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_4 = cv2.imread(S2_doubleA1C3_4)
S2RGB_imgA1C3_4= cv2.cvtColor(imgS2_A1C3_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_4  = cv2.imread(S2_doubleA1C4_4)
S2RGB_imgA1C4_4= cv2.cvtColor(imgS2_A1C4_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_4  = cv2.imread(S2_doubleA1D2_4)
S2RGB_imgA1D2_4= cv2.cvtColor(imgS2_A1D2_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_4  = cv2.imread(S2doubleA1D3_4)
S2RGB_imgA1D3_4= cv2.cvtColor(imgS2_A1D3_4, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_4 = cv2.imread(S2_doubleA1D4_4)
S2RGB_imgA1D4_4= cv2.cvtColor(imgS2_A1D4_4, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 5

# %%
imgS2_A1A1_5 = cv2.imread(S2_doubleA1A1_5)
S2RGB_imgA1A1_5= cv2.cvtColor(imgS2_A1A1_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_5 = cv2.imread(S2_doubleA1A2_5)
S2RGB_imgA1A2_5= cv2.cvtColor(imgS2_A1A2_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_5= cv2.imread(S2_doubleA1A3_5)
S2RGB_imgA1A3_5= cv2.cvtColor(imgS2_A1A3_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_55  = cv2.imread(S2_doubleA1A3_55)
S2RGB_imgA1A3_55= cv2.cvtColor(imgS2_A1A3_55, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_5  = cv2.imread(S2_doubleA1A4_5)
S2RGB_imgA1A4_5= cv2.cvtColor(imgS2_A1A4_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_5  = cv2.imread(S2_doubleA1B1_5)
S2RGB_imgA1B1_5= cv2.cvtColor(imgS2_A1B1_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_5  = cv2.imread(S2_doubleA1B2_5)
S2RGB_imgA1B2_5= cv2.cvtColor(imgS2_A1B2_, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_5  = cv2.imread(S2_doubleA1B3_5)
S2RGB_imgA1B3_5= cv2.cvtColor(imgS2_A1B3_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_5  = cv2.imread(S2_doubleA1B41)
S2RGB_imgA1B4_5= cv2.cvtColor(imgS2_A1B4_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_5 = cv2.imread(S2_doubleA1C1_5)
S2RGB_imgA1C1_5= cv2.cvtColor(imgS2_A1C1_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_5  = cv2.imread(S2_doubleA1C2_5)
S2RGB_imgA1C2_5= cv2.cvtColor(imgS2_A1C2_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_5  = cv2.imread(S2_doubleA1C3_5)
S2RGB_imgA1C3_5= cv2.cvtColor(imgS2_A1C3_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_5= cv2.imread(S2_doubleA1C4_5)
S2RGB_imgA1C4_5= cv2.cvtColor(imgS2_A1C4_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_5 = cv2.imread(S2_doubleA1D2_5)
S2RGB_imgA1D2_5= cv2.cvtColor(imgS2_A1D2_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_5  = cv2.imread(S_2doubleA1D3_5)
S2RGB_imgA1D3_5= cv2.cvtColor(imgS2_A1D3_5, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_5  = cv2.imread(S2_doubleA1D4_5)
S2RGB_imgA1D4_5= cv2.cvtColor(imgS2_A1D4_5, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 6

# %%
imgS2_A1A1_6 = cv2.imread(S2_doubleA1A1_6)
S2RGB_imgA1A1_6= cv2.cvtColor(imgS2_A1A1_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_6  = cv2.imread(S2_doubleA1A2_6)
S2RGB_imgA1A2_6= cv2.cvtColor(imgS2_A1A2_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_6= cv2.imread(S2_doubleA1A3_6)
S2RGB_imgA1A3_6= cv2.cvtColor(imgS2_A1A3_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_56  = cv2.imread(S2_doubleA1A3_56)
S2RGB_imgA1A3_56= cv2.cvtColor(imgS2_A1A3_56, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_6= cv2.imread(S2_doubleA1A4_6)
S2RGB_imgA1A4_6= cv2.cvtColor(imgS2_A1A4_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_6  = cv2.imread(S2_doubleA1B1_6)
S2RGB_imgA1B1_6= cv2.cvtColor(imgS2_A1B1_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_6  = cv2.imread(S2_doubleA1B2_6)
S2RGB_imgA1B2_6= cv2.cvtColor(imgS2_A1B2_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_6 = cv2.imread(S2_doubleA1B3_6)
S2RGB_imgA1B3_6= cv2.cvtColor(imgS2_A1B3_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_6 = cv2.imread(S2_doubleA1B4_6)
S2RGB_imgA1B4_6= cv2.cvtColor(imgS2_A1B4_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_6  = cv2.imread(S2_doubleA1C1_6)
S2RGB_imgA1C1_6= cv2.cvtColor(imgS2_A1C1_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_6  = cv2.imread(S2_doubleA1C2_6)
S2RGB_imgA1C2_6= cv2.cvtColor(imgS2_A1C2_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_6 = cv2.imread(S2_doubleA1C3_6)
S2RGB_imgA1C3_6= cv2.cvtColor(imgS2_A1C3_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_6 = cv2.imread(S2_doubleA1C4_6)
S2RGB_imgA1C4_6= cv2.cvtColor(imgS2_A1C4_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_6  = cv2.imread(S2_doubleA1D2_6)
S2RGB_imgA1D2_6= cv2.cvtColor(imgS2_A1D2_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_6  = cv2.imread(S2_doubleA1D3_6)
S2RGB_imgA1D3_6= cv2.cvtColor(imgS2_A1D3_6, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_6  = cv2.imread(S2_doubleA1D4_6)
S2RGB_imgA1D4_6= cv2.cvtColor(imgS2_A1D4_6, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 7

# %%
imgS2_A1A1_7 = cv2.imread(S2_doubleA1A1_7)
S2RGB_imgA1A1_7= cv2.cvtColor(imgS2_A1A1_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_7  = cv2.imread(S2_doubleA1A2_7)
S2RGB_imgA1A2_7= cv2.cvtColor(imgS2_A1A2_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_7= cv2.imread(S2_doubleA1A3_7)
S2RGB_imgA1A3_7= cv2.cvtColor(imgS2_A1A3_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_57  = cv2.imread(S2doubleA1A3_57)
S2RGB_imgA1A3_57= cv2.cvtColor(imgS2_A1A3_57, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_7  = cv2.imread(S2_doubleA1A4_7)
S2RGB_imgA1A4_7= cv2.cvtColor(imgS2_A1A4_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_7 = cv2.imread(S2_doubleA1B1_7)
S2RGB_imgA1B1_7= cv2.cvtColor(imgS2_A1B1_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_7 = cv2.imread(S2_doubleA1B2_7)
S2RGB_imgA1B2_7= cv2.cvtColor(imgS2_A1B2_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_7= cv2.imread(S2_doubleA1B3_7)
S2RGB_imgA1B3_7= cv2.cvtColor(imgS2_A1B3_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_7  = cv2.imread(S2_doubleA1B4_7)
S2RGB_imgA1B4_7= cv2.cvtColor(imgS2_A1B4_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_7 = cv2.imread(S2_doubleA1C1_7)
S2RGB_imgA1C1_7= cv2.cvtColor(imgS2_A1C1_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_7 = cv2.imread(S2_doubleA1C2_7)
S2RGB_imgA1C2_7= cv2.cvtColor(imgS2_A1C2_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_7  = cv2.imread(S2_doubleA1C3_7)
S2RGB_imgA1C3_7= cv2.cvtColor(imgS2_A1C3_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_7  = cv2.imread(S2_doubleA1C4_7)
S2RGB_imgA1C4_7= cv2.cvtColor(imgS2_A1C4_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_7 = cv2.imread(S2_doubleA1D2_7)
S2RGB_imgA1D2_7= cv2.cvtColor(imgS2_A1D2_7, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_7  = cv2.imread(S2_doubleA1D3_7)
S2RGB_imgA1D3_7= cv2.cvtColor(imgS2_A1D3_7, cv2.COLOR_BGR2RGB)

# %%
imgS_A1D4_7  = cv2.imread(S_doubleA1D4_7)
SRGB_imgA1D4_7= cv2.cvtColor(imgS_A1D4_7, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 8

# %%
imgS2_A1A1_8 = cv2.imread(S2_doubleA1A1_8)
S2RGB_imgA1A1_8= cv2.cvtColor(imgS2_A1A1_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_8  = cv2.imread(S2_doubleA1A2_8)
S2RGB_imgA1A2_8= cv2.cvtColor(imgS2_A1A2_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_8= cv2.imread(S2_doubleA1A3_8)
S2RGB_imgA1A3_8= cv2.cvtColor(imgS2_A1A3_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_58  = cv2.imread(S2_doubleA1A3_58)
S2RGB_imgA1A3_58= cv2.cvtColor(imgS2_A1A3_58, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_8  = cv2.imread(S2_doubleA1A4_8)
S2RGB_imgA1A4_8= cv2.cvtColor(imgS2_A1A4_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_8  = cv2.imread(S2_doubleA1B1_8)
S2RGB_imgA1B1_8= cv2.cvtColor(imgS2_A1B1_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_8  = cv2.imread(S2_doubleA1B2_8)
S2RGB_imgA1B2_8= cv2.cvtColor(imgS2_A1B2_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_8  = cv2.imread(S2_doubleA1B3_8)
S2RGB_imgA1B3_8= cv2.cvtColor(imgS2_A1B3_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_8  = cv2.imread(S2_doubleA1B4_8)
S2RGB_imgA1B4_8= cv2.cvtColor(imgS2_A1B4_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_8 = cv2.imread(S2_doubleA1C1_8)
S2RGB_imgA1C1_8= cv2.cvtColor(imgS2_A1C1_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_8 = cv2.imread(S2_doubleA1C2_8)
S2RGB_imgA1C2_8= cv2.cvtColor(imgS2_A1C2_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_8  = cv2.imread(S2_doubleA1C3_8)
S2RGB_imgA1C3_8= cv2.cvtColor(imgS2_A1C3_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_8  = cv2.imread(S2_doubleA1C4_8)
S2RGB_imgA1C4_8= cv2.cvtColor(imgS2_A1C4_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_8  = cv2.imread(S2_doubleA1D2_8)
S2RGB_imgA1D2_8= cv2.cvtColor(imgS2_A1D2_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_8 = cv2.imread(S2_doubleA1D3_8)
S2RGB_imgA1D3_8= cv2.cvtColor(imgS2_A1D3_8, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_8= cv2.imread(S2_doubleA1D4_8)
S2RGB_imgA1D4_8= cv2.cvtColor(imgS2_A1D4_8, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 9

# %%
imgS2_A1A1_9= cv2.imread(S2_doubleA1A1_9)
S2RGB_imgA1A1_9= cv2.cvtColor(imgS2_A1A1_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_9  = cv2.imread(S2_doubleA1A2_9)
S2RGB_imgA1A2_9= cv2.cvtColor(imgS2_A1A2_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_9= cv2.imread(S2_doubleA1A3_9)
S2RGB_imgA1A3_9= cv2.cvtColor(imgS2_A1A3_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_59  = cv2.imread(S2_doubleA1A3_59)
S2RGB_imgA1A3_59= cv2.cvtColor(imgS2_A1A3_59, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_9  = cv2.imread(S2_doubleA1A4_9)
S2RGB_imgA1A4_9= cv2.cvtColor(imgS2_A1A4_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_9  = cv2.imread(S2_doubleA1B1_9)
S2RGB_imgA1B1_9= cv2.cvtColor(imgS2_A1B1_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_9  = cv2.imread(S2_doubleA1B2_9)
S2RGB_imgA1B2_9= cv2.cvtColor(imgS2_A1B2_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_9  = cv2.imread(S2_doubleA1B3_9)
S2RGB_imgA1B3_9= cv2.cvtColor(imgS2_A1B3_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_9 = cv2.imread(S2_doubleA1B4_9)
S2RGB_imgA1B4_9= cv2.cvtColor(imgS2_A1B4_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_9  = cv2.imread(S2_doubleA1C1_9)
S2RGB_imgA1C1_9= cv2.cvtColor(imgS2_A1C1_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_9  = cv2.imread(S2_doubleA1C2_9)
S2RGB_imgA1C2_9= cv2.cvtColor(imgS2_A1C2_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_9  = cv2.imread(S2_doubleA1C3_9)
S2RGB_imgA1C3_9= cv2.cvtColor(imgS2_A1C3_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_9 = cv2.imread(S2_doubleA1C4_9)
S2RGB_imgA1C4_9= cv2.cvtColor(imgS2_A1C4_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_9 = cv2.imread(S2_doubleA1D2_9)
S2RGB_imgA1D2_9= cv2.cvtColor(imgS2_A1D2_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_9 = cv2.imread(S2_doubleA1D3_9)
S2RGB_imgA1D3_9= cv2.cvtColor(imgS2_A1D3_9, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_9 = cv2.imread(S2_doubleA1D4_9)
S2RGB_imgA1D4_9= cv2.cvtColor(imgS2_A1D4_9, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 10

# %%
imgS2_A1A1_10 = cv2.imread(S2_doubleA1A1_10)
S2RGB_imgA1A1_10= cv2.cvtColor(imgS2_A1A1_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A2_10  = cv2.imread(S2_doubleA1A2_10)
S2RGB_imgA1A2_10= cv2.cvtColor(imgS2_A1A2_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_10= cv2.imread(S2_doubleA1A3_10)
S2RGB_imgA1A3_10= cv2.cvtColor(imgS2_A1A3_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A3_510 = cv2.imread(S2_doubleA1A3_510)
S2RGB_imgA1A3_510= cv2.cvtColor(imgS2_A1A3_510, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1A4_10 = cv2.imread(S2_doubleA1A4_10)
S2RGB_imgA1A4_10= cv2.cvtColor(imgS2_A1A4_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B1_10  = cv2.imread(S2_doubleA1B1_10)
S2RGB_imgA1B1_10= cv2.cvtColor(imgS2_A1B1_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B2_10  = cv2.imread(S2_doubleA1B2_10)
S2RGB_imgA1B2_10= cv2.cvtColor(imgS2_A1B2_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B3_10  = cv2.imread(S2_doubleA1B3_10)
S2RGB_imgA1B3_10= cv2.cvtColor(imgS2_A1B3_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1B4_10 = cv2.imread(S2_doubleA1B4_10)
S2RGB_imgA1B4_10= cv2.cvtColor(imgS2_A1B4_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C1_10  = cv2.imread(S2_doubleA1C1_10)
S2RGB_imgA1C1_10= cv2.cvtColor(imgS2_A1C1_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C2_10  = cv2.imread(S2_doubleA1C2_10)
S2RGB_imgA1C2_10= cv2.cvtColor(imgS2_A1C2_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C3_10  = cv2.imread(S2_doubleA1C3_10)
S2RGB_imgA1C3_10= cv2.cvtColor(imgS2_A1C3_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1C4_10 = cv2.imread(S2_doubleA1C4_10)
S2RGB_imgA1C4_10= cv2.cvtColor(imgS2_A1C4_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D2_10 = cv2.imread(S2_doubleA1D2_10)
S2RGB_imgA1D2_10= cv2.cvtColor(imgS2_A1D2_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D3_10  = cv2.imread(S2_doubleA1D3_10)
S2RGB_imgA1D3_10= cv2.cvtColor(imgS2_A1D3_10, cv2.COLOR_BGR2RGB)

# %%
imgS2_A1D4_10  = cv2.imread(S2_doubleA1D4_10)
S2RGB_imgA1D4_10= cv2.cvtColor(imgS2_A1D4_10, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Set3

# %%
imgS3_A1A1_1  = cv2.imread(S3_doubleA1A1_1)
S3RGB_imgA1A1_1= cv2.cvtColor(imgS3_A1A1_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_1  = cv2.imread(S3_doubleA1A2_1)
S3RGB_imgA1A2_1= cv2.cvtColor(imgS3_A1A2_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_1  = cv2.imread(S3_doubleA1A3_1)
S3RGB_imgA1A3_1= cv2.cvtColor(imgS3_A1A3_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_51  = cv2.imread(S3_doubleA1A3_51)
S3RGB_imgA1A3_51= cv2.cvtColor(imgS3_A1A3_51, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_1  = cv2.imread(S3_doubleA1A4_1)
S3RGB_imgA1A4_1= cv2.cvtColor(imgS3_A1A4_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_1  = cv2.imread(S3_doubleA1B1_1)
S3RGB_imgA1B1_1= cv2.cvtColor(imgS3_A1B1_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_1  = cv2.imread(S3_doubleA1B2_1)
S3RGB_imgA1B2_1= cv2.cvtColor(imgS3_A1B2_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_1  = cv2.imread(S3_doubleA1B3_1)
S3RGB_imgA1B3_1= cv2.cvtColor(imgS3_A1B3_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_1  = cv2.imread(S3_doubleA1B4_1)
S3RGB_imgA1B4_1= cv2.cvtColor(imgS3_A1B4_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_1  = cv2.imread(S3_doubleA1C1_1)
S3RGB_imgA1C1_1= cv2.cvtColor(imgS3_A1C1_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_1  = cv2.imread(S3_doubleA1C2_1)
S3RGB_imgA1C2_1= cv2.cvtColor(imgS3_A1C2_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_1  = cv2.imread(S3_doubleA1C3_1)
S3RGB_imgA1C3_1= cv2.cvtColor(imgS3_A1C3_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_1  = cv2.imread(S3_doubleA1C4_1)
S3RGB_imgA1C4_1= cv2.cvtColor(imgS3_A1C4_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_1  = cv2.imread(S3_doubleA1D2_1)
S3RGB_imgA1D2_1= cv2.cvtColor(imgS3_A1D2_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_1  = cv2.imread(S3_doubleA1D3_1)
S3RGB_imgA1D3_1= cv2.cvtColor(imgS3_A1D3_1, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_1  = cv2.imread(S3_doubleA1D4_1)
S3RGB_imgA1D4_1= cv2.cvtColor(imgS3_A1D4_1, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 2

# %%
imgS3_A1A1_2 = cv2.imread(S3_doubleA1A1_2)
S3RGB_imgA1A1_2= cv2.cvtColor(imgS3_A1A1_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_2 = cv2.imread(S3_doubleA1A2_2)
S3RGB_imgA1A2_2= cv2.cvtColor(imgS3_A1A2_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_2= cv2.imread(S3_doubleA1A3_2)
S3RGB_imgA1A3_2= cv2.cvtColor(imgS3_A1A3_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_52  = cv2.imread(S3_doubleA1A3_52)
S3RGB_imgA1A3_52= cv2.cvtColor(imgS3_A1A3_52, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_2 = cv2.imread(S3_doubleA1A4_2)
S3RGB_imgA1A4_2= cv2.cvtColor(imgS3_A1A4_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_2= cv2.imread(S3_doubleA1B1_2)
S3RGB_imgA1B1_= cv2.cvtColor(imgS3_A1B1_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_2 = cv2.imread(S3_doubleA1B2_2)
S3RGB_imgA1B2_2= cv2.cvtColor(imgS3_A1B2_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_2  = cv2.imread(S3_doubleA1B3_2)
S3RGB_imgA1B3_2= cv2.cvtColor(imgS3_A1B3_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_2 = cv2.imread(S3_doubleA1B4_2)
S3RGB_imgA1B4_2= cv2.cvtColor(imgS3_A1B4_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_2  = cv2.imread(S3_doubleA1C1_2)
S3RGB_imgA1C1_2= cv2.cvtColor(imgS3_A1C1_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_2  = cv2.imread(S3_doubleA1C2_2)
S3RGB_imgA1C2_2= cv2.cvtColor(imgS3_A1C2_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_2  = cv2.imread(S3_doubleA1C3_2)
S3RGB_imgA1C3_2= cv2.cvtColor(imgS3_A1C3_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_2 = cv2.imread(S3_doubleA1C4_2)
S3RGB_imgA1C4_2= cv2.cvtColor(imgS3_A1C4_, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_2 = cv2.imread(S3_doubleA1D2_2)
S3RGB_imgA1D2_2= cv2.cvtColor(imgS3_A1D2_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_2 = cv2.imread(S3_doubleA1D3_2)
S3RGB_imgA1D3_2= cv2.cvtColor(imgS3_A1D3_2, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_2  = cv2.imread(S3_doubleA1D4_2)
S3RGB_imgA1D4_2= cv2.cvtColor(imgS3_A1D4_2, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 3

# %%
imgS3_A1A1_3= cv2.imread(S3_doubleA1A1_3)
S3RGB_imgA1A1_3= cv2.cvtColor(imgS3_A1A1_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_3 = cv2.imread(S3_doubleA1A2_3)
S3RGB_imgA1A2_3= cv2.cvtColor(imgS3_A1A2_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_3= cv2.imread(S3_doubleA1A3_3)
S3RGB_imgA1A3_3= cv2.cvtColor(imgS3_A1A3_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_53  = cv2.imread(S3_doubleA1A3_53)
S3RGB_imgA1A3_53= cv2.cvtColor(imgS3_A1A3_53, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_3  = cv2.imread(S3_doubleA1A4_3)
S3RGB_imgA1A4_3= cv2.cvtColor(imgS3_A1A4_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_3  = cv2.imread(S3_doubleA1B1_3)
S3RGB_imgA1B1_3= cv2.cvtColor(imgS3_A1B1_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_3 = cv2.imread(S3_doubleA1B2_3)
S3RGB_imgA1B2_3= cv2.cvtColor(imgS3_A1B2_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_3  = cv2.imread(S3_doubleA1B3_3)
S3RGB_imgA1B3_3= cv2.cvtColor(imgS3_A1B3_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_3  = cv2.imread(S3_doubleA1B4_3)
S3RGB_imgA1B4_3= cv2.cvtColor(imgS3_A1B4_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_3  = cv2.imread(S3_doubleA1C1_3)
S3RGB_imgA1C1_3= cv2.cvtColor(imgS3_A1C1_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_3  = cv2.imread(S3_doubleA1C2_3)
S3RGB_imgA1C2_3= cv2.cvtColor(imgS3_A1C2_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_3  = cv2.imread(S3_doubleA1C3_3)
S3RGB_imgA1C3_3= cv2.cvtColor(imgS3_A1C3_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_3 = cv2.imread(S3_doubleA1C4_3)
S3RGB_imgA1C4_3= cv2.cvtColor(imgS3_A1C4_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_3  = cv2.imread(S3_doubleA1D2_3)
S3RGB_imgA1D2_3= cv2.cvtColor(imgS3_A1D2_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_3 = cv2.imread(S3_doubleA1D3_3)
S3RGB_imgA1D3_3= cv2.cvtColor(imgS3_A1D3_3, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_3  = cv2.imread(S3_doubleA1D4_3)
S3RGB_imgA1D4_3= cv2.cvtColor(imgS3_A1D4_3, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 4

# %%
imgS3_A1A1_4 = cv2.imread(S3_doubleA1A1_4)
S3RGB_imgA1A1_4= cv2.cvtColor(imgS3_A1A1_, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_4  = cv2.imread(S3_doubleA1A2_4)
S3RGB_imgA1A2_4= cv2.cvtColor(imgS3_A1A2_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_4= cv2.imread(S3_doubleA1A3_4)
S3RGB_imgA1A3_4= cv2.cvtColor(imgS3_A1A3_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_54  = cv2.imread(S3_doubleA1A3_54)
S3RGB_imgA1A3_54= cv2.cvtColor(imgS3_A1A3_54, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_4  = cv2.imread(S3_doubleA1A4_4)
S3RGB_imgA1A4_4= cv2.cvtColor(imgS3_A1A4_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_4  = cv2.imread(S3_doubleA1B1_4)
S3RGB_imgA1B1_4= cv2.cvtColor(imgS3_A1B1_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_4 = cv2.imread(S3_doubleA1B2_4)
S3RGB_imgA1B2_4= cv2.cvtColor(imgS3_A1B2_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_  = cv2.imread(S3_doubleA1B3_4)
S3RGB_imgA1B3_= cv2.cvtColor(imgS3_A1B3_, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_4  = cv2.imread(S3_doubleA1B41)
S3RGB_imgA1B4_4= cv2.cvtColor(imgS3_A1B4_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_4 = cv2.imread(S3_doubleA1C1_4)
S3RGB_imgA1C1_4= cv2.cvtColor(imgS3_A1C1_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_4  = cv2.imread(S3_doubleA1C2_4)
S3RGB_imgA1C2_4= cv2.cvtColor(imgS3_A1C2_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_4 = cv2.imread(S3_doubleA1C3_4)
S3RGB_imgA1C3_4= cv2.cvtColor(imgS3_A1C3_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_4  = cv2.imread(S3_doubleA1C4_4)
S3RGB_imgA1C4_4= cv2.cvtColor(imgS3_A1C4_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_4  = cv2.imread(S3_doubleA1D2_4)
S3RGB_imgA1D2_4= cv2.cvtColor(imgS3_A1D2_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_4  = cv2.imread(S3_doubleA1D3_4)
S3RGB_imgA1D3_4= cv2.cvtColor(imgS3_A1D3_4, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_4 = cv2.imread(S3_doubleA1D4_4)
S3RGB_imgA1D4_4= cv2.cvtColor(imgS3_A1D4_4, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 5

# %%
imgS3_A1A1_5 = cv2.imread(S3_doubleA1A1_5)
S3RGB_imgA1A1_5= cv2.cvtColor(imgS3_A1A1_5, cv2.COLOR_BGR2RGB)

# %%
imgS_A1A2_5 = cv2.imread(S3_doubleA1A2_5)
SRGB_imgA1A2_5= cv2.cvtColor(imgS3_A1A2_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_5= cv2.imread(S3_doubleA1A3_5)
S3RGB_imgA1A3_5= cv2.cvtColor(imgS3_A1A3_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_55  = cv2.imread(S3_doubleA1A3_55)
S3RGB_imgA1A3_55= cv2.cvtColor(imgS3_A1A3_55, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_5  = cv2.imread(S3_doubleA1A4_5)
S3RGB_imgA1A4_5= cv2.cvtColor(imgS3_A1A4_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_5  = cv2.imread(S3_doubleA1B1_5)
S3RGB_imgA1B1_5= cv2.cvtColor(imgS3_A1B1_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_5  = cv2.imread(S3_doubleA1B2_5)
S3RGB_imgA1B2_5= cv2.cvtColor(imgS3_A1B2_, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_5  = cv2.imread(S3_doubleA1B3_5)
S3RGB_imgA1B3_5= cv2.cvtColor(imgS3_A1B3_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_5  = cv2.imread(S3_doubleA1B41)
S3RGB_imgA1B4_5= cv2.cvtColor(imgS3_A1B4_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_5 = cv2.imread(S3_doubleA1C1_5)
S3RGB_imgA1C1_5= cv2.cvtColor(imgS3_A1C1_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_5  = cv2.imread(S3_doubleA1C2_5)
S3RGB_imgA1C2_5= cv2.cvtColor(imgS3_A1C2_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_5  = cv2.imread(S3_doubleA1C3_5)
S3RGB_imgA1C3_5= cv2.cvtColor(imgS3_A1C3_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_5= cv2.imread(S3_doubleA1C4_5)
S3RGB_imgA1C4_5= cv2.cvtColor(imgS3_A1C4_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_5 = cv2.imread(S3_doubleA1D2_5)
S3RGB_imgA1D2_5= cv2.cvtColor(imgS3_A1D2_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_5  = cv2.imread(S3_doubleA1D3_5)
S3RGB_imgA1D3_5= cv2.cvtColor(imgS3_A1D3_5, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_5  = cv2.imread(S3_doubleA1D4_5)
S3RGB_imgA1D4_5= cv2.cvtColor(imgS3_A1D4_5, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 6

# %%
imgS_A1A1_6 = cv2.imread(S3_doubleA1A1_6)
S3RGB_imgA1A1_6= cv2.cvtColor(imgS3_A1A1_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_6  = cv2.imread(S3_doubleA1A2_6)
S3RGB_imgA1A2_6= cv2.cvtColor(imgS3_A1A2_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_6= cv2.imread(S3_doubleA1A3_6)
S3RGB_imgA1A3_6= cv2.cvtColor(imgS3_A1A3_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_56  = cv2.imread(S3_doubleA1A3_56)
SRGB_imgA1A3_56= cv2.cvtColor(imgS3_A1A3_56, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_6= cv2.imread(S3_doubleA1A4_6)
S3RGB_imgA1A4_6= cv2.cvtColor(imgS3_A1A4_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_6  = cv2.imread(S3_doubleA1B1_6)
S3RGB_imgA1B1_6= cv2.cvtColor(imgS3_A1B1_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_6  = cv2.imread(S3_doubleA1B2_6)
S3RGB_imgA1B2_6= cv2.cvtColor(imgS3_A1B2_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_6 = cv2.imread(S3_doubleA1B3_6)
S3RGB_imgA1B3_6= cv2.cvtColor(imgS3_A1B3_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_6 = cv2.imread(S3_doubleA1B4_6)
S3RGB_imgA1B4_6= cv2.cvtColor(imgS3_A1B4_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_6  = cv2.imread(S3_doubleA1C1_6)
S3RGB_imgA1C1_6= cv2.cvtColor(imgS3_A1C1_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_6  = cv2.imread(S3_doubleA1C2_6)
S3RGB_imgA1C2_6= cv2.cvtColor(imgS3_A1C2_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_6 = cv2.imread(S3_doubleA1C3_6)
S3RGB_imgA1C3_6= cv2.cvtColor(imgS3_A1C3_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_6 = cv2.imread(S3_doubleA1C4_6)
S3RGB_imgA1C4_6= cv2.cvtColor(imgS3_A1C4_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_6  = cv2.imread(S3_doubleA1D2_6)
S3RGB_imgA1D2_6= cv2.cvtColor(imgS3_A1D2_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_6  = cv2.imread(S3_doubleA1D3_6)
S3RGB_imgA1D3_6= cv2.cvtColor(imgS3_A1D3_6, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_6  = cv2.imread(S3_doubleA1D4_6)
S3RGB_imgA1D4_6= cv2.cvtColor(imgS3_A1D4_6, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 7

# %%
imgS3_A1A1_7 = cv2.imread(S3_doubleA1A1_7)
S3RGB_imgA1A1_7= cv2.cvtColor(imgS3_A1A1_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_7  = cv2.imread(S3_doubleA1A2_7)
S3RGB_imgA1A2_7= cv2.cvtColor(imgS3_A1A2_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_7= cv2.imread(S3_doubleA1A3_7)
S3RGB_imgA1A3_7= cv2.cvtColor(imgS3_A1A3_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_57  = cv2.imread(S3_doubleA1A3_57)
S3RGB_imgA1A3_57= cv2.cvtColor(imgS3_A1A3_57, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_7  = cv2.imread(S3_doubleA1A4_7)
S3RGB_imgA1A4_7= cv2.cvtColor(imgS3_A1A4_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_7 = cv2.imread(S3_doubleA1B1_7)
S3RGB_imgA1B1_7= cv2.cvtColor(imgS3_A1B1_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_7 = cv2.imread(S3_doubleA1B2_7)
S3RGB_imgA1B2_7= cv2.cvtColor(imgS3_A1B2_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_7= cv2.imread(S3_doubleA1B3_7)
S3RGB_imgA1B3_7= cv2.cvtColor(imgS3_A1B3_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_7  = cv2.imread(S3_doubleA1B4_7)
S3RGB_imgA1B4_7= cv2.cvtColor(imgS3_A1B4_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_7 = cv2.imread(S3_doubleA1C1_7)
S3RGB_imgA1C1_7= cv2.cvtColor(imgS3_A1C1_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_7 = cv2.imread(S3_doubleA1C2_7)
S3RGB_imgA1C2_7= cv2.cvtColor(imgS3_A1C2_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_7  = cv2.imread(S3_doubleA1C3_7)
S3RGB_imgA1C3_7= cv2.cvtColor(imgS3_A1C3_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_7  = cv2.imread(S3_doubleA1C4_7)
S3RGB_imgA1C4_7= cv2.cvtColor(imgS3_A1C4_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_7 = cv2.imread(S3_doubleA1D2_7)
S3RGB_imgA1D2_7= cv2.cvtColor(imgS3_A1D2_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_7  = cv2.imread(S3_doubleA1D3_7)
S3RGB_imgA1D3_7= cv2.cvtColor(imgS3_A1D3_7, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_7  = cv2.imread(S3_doubleA1D4_7)
S3RGB_imgA1D4_7= cv2.cvtColor(imgS3_A1D4_7, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 8

# %%
imgS3_A1A1_8 = cv2.imread(S3_doubleA1A1_8)
S3RGB_imgA1A1_8= cv2.cvtColor(imgS3_A1A1_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_8  = cv2.imread(S3_doubleA1A2_8)
S3RGB_imgA1A2_8= cv2.cvtColor(imgS3_A1A2_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_8= cv2.imread(S3_doubleA1A3_8)
S3RGB_imgA1A3_8= cv2.cvtColor(imgS3_A1A3_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_58  = cv2.imread(S3_doubleA1A3_58)
S3RGB_imgA1A3_58= cv2.cvtColor(imgS3_A1A3_58, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_8  = cv2.imread(S3_doubleA1A4_8)
S3RGB_imgA1A4_8= cv2.cvtColor(imgS3_A1A4_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_8  = cv2.imread(S3_doubleA1B1_8)
S3RGB_imgA1B1_8= cv2.cvtColor(imgS3_A1B1_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_8  = cv2.imread(S3_doubleA1B2_8)
S3RGB_imgA1B2_8= cv2.cvtColor(imgS3_A1B2_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_8  = cv2.imread(S3_doubleA1B3_8)
S3RGB_imgA1B3_8= cv2.cvtColor(imgS3_A1B3_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_8  = cv2.imread(S3_doubleA1B4_8)
S3RGB_imgA1B4_8= cv2.cvtColor(imgS3_A1B4_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_8 = cv2.imread(S3_doubleA1C1_8)
S3RGB_imgA1C1_8= cv2.cvtColor(imgS3_A1C1_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_8 = cv2.imread(S3_doubleA1C2_8)
S3RGB_imgA1C2_8= cv2.cvtColor(imgS3_A1C2_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_8  = cv2.imread(S3_doubleA1C3_8)
S3RGB_imgA1C3_8= cv2.cvtColor(imgS3_A1C3_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_8  = cv2.imread(S3_doubleA1C4_8)
S3RGB_imgA1C4_8= cv2.cvtColor(imgS3_A1C4_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_8  = cv2.imread(S3_doubleA1D2_8)
S3RGB_imgA1D2_8= cv2.cvtColor(imgS3_A1D2_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_8 = cv2.imread(S3_doubleA1D3_8)
S3RGB_imgA1D3_8= cv2.cvtColor(imgS3_A1D3_8, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_8= cv2.imread(S3_doubleA1D4_8)
S3RGB_imgA1D4_8= cv2.cvtColor(imgS3_A1D4_8, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 9

# %%
imgS3_A1A1_9= cv2.imread(S3_doubleA1A1_9)
S3RGB_imgA1A1_9= cv2.cvtColor(imgS3_A1A1_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_9  = cv2.imread(S3_doubleA1A2_9)
S3RGB_imgA1A2_9= cv2.cvtColor(imgS3_A1A2_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_9= cv2.imread(S3_doubleA1A3_9)
S3RGB_imgA1A3_9= cv2.cvtColor(imgS3_A1A3_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_59  = cv2.imread(S3_doubleA1A3_59)
S3RGB_imgA1A3_59= cv2.cvtColor(imgS3_A1A3_59, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_9  = cv2.imread(S3_doubleA1A4_9)
S3RGB_imgA1A4_9= cv2.cvtColor(imgS3_A1A4_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_9  = cv2.imread(S3_doubleA1B1_9)
S3RGB_imgA1B1_9= cv2.cvtColor(imgS3_A1B1_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_9  = cv2.imread(S3_doubleA1B2_9)
S3RGB_imgA1B2_9= cv2.cvtColor(imgS3_A1B2_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_9  = cv2.imread(S3_doubleA1B3_9)
S3RGB_imgA1B3_9= cv2.cvtColor(imgS3_A1B3_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_9 = cv2.imread(S_doubleA1B4_9)
S3RGB_imgA1B4_9= cv2.cvtColor(imgS_A1B4_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_9  = cv2.imread(S_doubleA1C1_9)
S3RGB_imgA1C1_9= cv2.cvtColor(imgS_A1C1_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_3A1C2_9  = cv2.imread(S3_doubleA1C2_9)
S3RGB_imgA1C2_9= cv2.cvtColor(imgS3_A1C2_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_9  = cv2.imread(S3_doubleA1C3_9)
S3RGB_imgA1C3_9= cv2.cvtColor(imgS3_A1C3_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_9 = cv2.imread(S3_doubleA1C4_9)
S3RGB_imgA1C4_9= cv2.cvtColor(imgS3_A1C4_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_9 = cv2.imread(S3_doubleA1D2_9)
S3RGB_imgA1D2_9= cv2.cvtColor(imgS3_A1D2_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_9 = cv2.imread(S3_doubleA1D3_9)
S3RGB_imgA1D3_9= cv2.cvtColor(imgS3_A1D3_9, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_9 = cv2.imread(S3_doubleA1D4_9)
S3RGB_imgA1D4_9= cv2.cvtColor(imgS3_A1D4_9, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 10

# %%
imgS3_A1A1_10 = cv2.imread(S3_doubleA1A1_10)
S3RGB_imgA1A1_10= cv2.cvtColor(imgS3_A1A1_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A2_10  = cv2.imread(S3_doubleA1A2_10)
S3RGB_imgA1A2_10= cv2.cvtColor(imgS3_A1A2_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_10= cv2.imread(S3_doubleA1A3_10)
S3RGB_imgA1A3_10= cv2.cvtColor(imgS3_A1A3_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A3_510 = cv2.imread(S3_doubleA1A3_510)
S3RGB_imgA1A3_510= cv2.cvtColor(imgS3_A1A3_510, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1A4_10 = cv2.imread(S3_doubleA1A4_10)
S3RGB_imgA1A4_10= cv2.cvtColor(imgS3_A1A4_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B1_10  = cv2.imread(S3_doubleA1B1_10)
S3RGB_imgA1B1_10= cv2.cvtColor(imgS3_A1B1_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B2_10  = cv2.imread(S3_doubleA1B2_10)
S3RGB_imgA1B2_10= cv2.cvtColor(imgS3_A1B2_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B3_10  = cv2.imread(S3_doubleA1B3_10)
S3RGB_imgA1B3_10= cv2.cvtColor(imgS3_A1B3_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1B4_10 = cv2.imread(S3_doubleA1B4_10)
S3RGB_imgA1B4_10= cv2.cvtColor(imgS3_A1B4_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C1_10  = cv2.imread(S3_doubleA1C1_10)
S3RGB_imgA1C1_10= cv2.cvtColor(imgS3_A1C1_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C2_10  = cv2.imread(S3_doubleA1C2_10)
S3RGB_imgA1C2_10= cv2.cvtColor(imgS3_A1C2_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C3_10  = cv2.imread(S3_doubleA1C3_10)
S3RGB_imgA1C3_10= cv2.cvtColor(imgS3_A1C3_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1C4_10 = cv2.imread(S3_doubleA1C4_10)
S3RGB_imgA1C4_10= cv2.cvtColor(imgS3_A1C4_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D2_10 = cv2.imread(S3_doubleA1D2_10)
S3RGB_imgA1D2_10= cv2.cvtColor(imgS3_A1D2_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D3_10  = cv2.imread(S3_doubleA1D3_10)
S3RGB_imgA1D3_10= cv2.cvtColor(imgS3_A1D3_10, cv2.COLOR_BGR2RGB)

# %%
imgS3_A1D4_10  = cv2.imread(S3_doubleA1D4_10)
S3RGB_imgA1D4_10= cv2.cvtColor(imgS3_A1D4_10, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ##Set 4

# %%
imgS4_A1A1_1  = cv2.imread(S4_doubleA1A1_1)
S4RGB_imgA1A1_1= cv2.cvtColor(imgS4_A1A1_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_1  = cv2.imread(S4_doubleA1A2_1)
S4RGB_imgA1A2_1= cv2.cvtColor(imgS4_A1A2_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_1  = cv2.imread(S4_doubleA1A3_1)
S4RGB_imgA1A3_1= cv2.cvtColor(imgS4_A1A3_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_51  = cv2.imread(S4_doubleA1A3_51)
S4RGB_imgA1A3_51= cv2.cvtColor(imgS4_A1A3_51, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_1  = cv2.imread(S4_doubleA1A4_1)
S4RGB_imgA1A4_1= cv2.cvtColor(imgS4_A1A4_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_1  = cv2.imread(S4_doubleA1B1_1)
S4RGB_imgA1B1_1= cv2.cvtColor(imgS4_A1B1_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_1  = cv2.imread(S4_doubleA1B2_1)
S4RGB_imgA1B2_1= cv2.cvtColor(imgS4_A1B2_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_1  = cv2.imread(S4_doubleA1B3_1)
S4RGB_imgA1B3_1= cv2.cvtColor(imgS4_A1B3_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_1  = cv2.imread(S4_doubleA1B4_1)
S4RGB_imgA1B4_1= cv2.cvtColor(imgS4_A1B4_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_1  = cv2.imread(S4_doubleA1C1_1)
S4RGB_imgA1C1_1= cv2.cvtColor(imgS4_A1C1_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_1  = cv2.imread(S4_doubleA1C2_1)
S4RGB_imgA1C2_1= cv2.cvtColor(imgS4_A1C2_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_1  = cv2.imread(S4_doubleA1C3_1)
S4RGB_imgA1C3_1= cv2.cvtColor(imgS4_A1C3_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_1  = cv2.imread(S4_doubleA1C4_1)
S4RGB_imgA1C4_1= cv2.cvtColor(imgS4_A1C4_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_1  = cv2.imread(S4_doubleA1D2_1)
S4RGB_imgA1D2_1= cv2.cvtColor(imgS4_A1D2_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_1  = cv2.imread(S4_doubleA1D3_1)
S4RGB_imgA1D3_1= cv2.cvtColor(imgS4_A1D3_1, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_1  = cv2.imread(S4_doubleA1D4_1)
S4RGB_imgA1D4_1= cv2.cvtColor(imgS4_A1D4_1, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 2

# %%
imgS4_A1A1_2 = cv2.imread(S4_doubleA1A1_2)
S4RGB_imgA1A1_2= cv2.cvtColor(imgS4_A1A1_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_2 = cv2.imread(S4_doubleA1A2_2)
S4RGB_imgA1A2_2= cv2.cvtColor(imgS4_A1A2_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_2= cv2.imread(S4_doubleA1A3_2)
S4RGB_imgA1A3_2= cv2.cvtColor(imgS4_A1A3_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_52  = cv2.imread(S4_doubleA1A3_52)
S4RGB_imgA1A3_52= cv2.cvtColor(imgS4_A1A3_52, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_2 = cv2.imread(S4_doubleA1A4_2)
S4RGB_imgA1A4_2= cv2.cvtColor(imgS4_A1A4_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_2= cv2.imread(S4_doubleA1B1_2)
S4RGB_imgA1B1_= cv2.cvtColor(imgS4_A1B1_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_2 = cv2.imread(S4_doubleA1B2_2)
S4RGB_imgA1B2_2= cv2.cvtColor(imgS4_A1B2_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_2  = cv2.imread(S4_doubleA1B3_2)
S4RGB_imgA1B3_2= cv2.cvtColor(imgS4_A1B3_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_2 = cv2.imread(S4_doubleA1B4_2)
S4RGB_imgA1B4_2= cv2.cvtColor(imgS4_A1B4_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_2  = cv2.imread(S4_doubleA1C1_2)
S4RGB_imgA1C1_2= cv2.cvtColor(imgS4_A1C1_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_2  = cv2.imread(S4_doubleA1C2_2)
S4RGB_imgA1C2_2= cv2.cvtColor(imgS4_A1C2_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_2  = cv2.imread(S4_doubleA1C3_2)
S4RGB_imgA1C3_2= cv2.cvtColor(imgS4_A1C3_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_2 = cv2.imread(S4_doubleA1C4_2)
S4RGB_imgA1C4_2= cv2.cvtColor(imgS4_A1C4_, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_2 = cv2.imread(S4_doubleA1D2_2)
S4RGB_imgA1D2_2= cv2.cvtColor(imgS4_A1D2_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_2 = cv2.imread(S4_doubleA1D3_2)
S4RGB_imgA1D3_2= cv2.cvtColor(imgS4_A1D3_2, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_2  = cv2.imread(S4_doubleA1D4_2)
S4RGB_imgA1D4_2= cv2.cvtColor(imgS4_A1D4_2, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 3

# %%
imgS4_A1A1_3= cv2.imread(S4_doubleA1A1_3)
S4RGB_imgA1A1_3= cv2.cvtColor(imgS4_A1A1_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_3 = cv2.imread(S4_doubleA1A2_3)
S4RGB_imgA1A2_3= cv2.cvtColor(imgS4_A1A2_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_3= cv2.imread(S4_doubleA1A3_3)
S4RGB_imgA1A3_3= cv2.cvtColor(imgS4_A1A3_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_53  = cv2.imread(S4_doubleA1A3_53)
S4RGB_imgA1A3_53= cv2.cvtColor(imgS4_A1A3_53, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_3  = cv2.imread(S4_doubleA1A4_3)
S4RGB_imgA1A4_3= cv2.cvtColor(imgS4_A1A4_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_3  = cv2.imread(S4_doubleA1B1_3)
S4RGB_imgA1B1_3= cv2.cvtColor(imgS4_A1B1_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_3 = cv2.imread(S4_doubleA1B2_3)
S4RGB_imgA1B2_3= cv2.cvtColor(imgS4_A1B2_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_3  = cv2.imread(S4_doubleA1B3_3)
S4RGB_imgA1B3_3= cv2.cvtColor(imgS4_A1B3_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_3  = cv2.imread(S4_doubleA1B4_3)
S4RGB_imgA1B4_3= cv2.cvtColor(imgS4_A1B4_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_3  = cv2.imread(S4_doubleA1C1_3)
S4RGB_imgA1C1_3= cv2.cvtColor(imgS4_A1C1_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_3  = cv2.imread(S4_doubleA1C2_3)
S4RGB_imgA1C2_3= cv2.cvtColor(imgS4_A1C2_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_3  = cv2.imread(S4_doubleA1C3_3)
S4RGB_imgA1C3_3= cv2.cvtColor(imgS4_A1C3_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_3 = cv2.imread(S4_doubleA1C4_3)
S4RGB_imgA1C4_3= cv2.cvtColor(imgS4_A1C4_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_3  = cv2.imread(S4_doubleA1D2_3)
S4RGB_imgA1D2_3= cv2.cvtColor(imgS4_A1D2_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_3 = cv2.imread(S4_doubleA1D3_3)
S4RGB_imgA1D3_3= cv2.cvtColor(imgS4_A1D3_3, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_3  = cv2.imread(S4_doubleA1D4_3)
S4RGB_imgA1D4_3= cv2.cvtColor(imgS4_A1D4_3, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 4

# %%
imgS4_A1A1_4 = cv2.imread(S4_doubleA1A1_4)
S4RGB_imgA1A1_4= cv2.cvtColor(imgS4_A1A1_, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_4  = cv2.imread(S4_doubleA1A2_4)
S4RGB_imgA1A2_4= cv2.cvtColor(imgS4_A1A2_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_4= cv2.imread(S4_doubleA1A3_4)
S4RGB_imgA1A3_4= cv2.cvtColor(imgS4_A1A3_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_54  = cv2.imread(S4_doubleA1A3_54)
S4RGB_imgA1A3_54= cv2.cvtColor(imgS4_A1A3_54, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_4  = cv2.imread(S4_doubleA1A4_4)
S4RGB_imgA1A4_4= cv2.cvtColor(imgS4_A1A4_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_4  = cv2.imread(S4_doubleA1B1_4)
S4RGB_imgA1B1_4= cv2.cvtColor(imgS4_A1B1_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_4 = cv2.imread(S4_doubleA1B2_4)
S4RGB_imgA1B2_4= cv2.cvtColor(imgS4_A1B2_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_  = cv2.imread(S4_doubleA1B3_4)
S4RGB_imgA1B3_= cv2.cvtColor(imgS4_A1B3_, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_4  = cv2.imread(S4_doubleA1B41)
S4RGB_imgA1B4_4= cv2.cvtColor(imgS4_A1B4_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_4 = cv2.imread(S4_doubleA1C1_4)
S4RGB_imgA1C1_4= cv2.cvtColor(imgS4_A1C1_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_4  = cv2.imread(S4_doubleA1C2_4)
S4RGB_imgA1C2_4= cv2.cvtColor(imgS4_A1C2_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_4 = cv2.imread(S4_doubleA1C3_4)
S4RGB_imgA1C3_4= cv2.cvtColor(imgS4_A1C3_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_4  = cv2.imread(S4_doubleA1C4_4)
S4RGB_imgA1C4_4= cv2.cvtColor(imgS4_A1C4_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_4  = cv2.imread(S4_doubleA1D2_4)
S4RGB_imgA1D2_4= cv2.cvtColor(imgS4_A1D2_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_4  = cv2.imread(S4_doubleA1D3_4)
S4RGB_imgA1D3_4= cv2.cvtColor(imgS4_A1D3_4, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_4 = cv2.imread(S4_doubleA1D4_4)
S4RGB_imgA1D4_4= cv2.cvtColor(imgS4_A1D4_4, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 5

# %%
imgS4_A1A1_5 = cv2.imread(S4_doubleA1A1_5)
S4RGB_imgA1A1_5= cv2.cvtColor(imgS4_A1A1_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_5 = cv2.imread(S4_doubleA1A2_5)
S4RGB_imgA1A2_5= cv2.cvtColor(imgS4_A1A2_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_5= cv2.imread(S4_doubleA1A3_5)
S4RGB_imgA1A3_5= cv2.cvtColor(imgS4_A1A3_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_55  = cv2.imread(S4_doubleA1A3_55)
S4GB_imgA1A3_55= cv2.cvtColor(imgS4_A1A3_55, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_5  = cv2.imread(S4_doubleA1A4_5)
S4RGB_imgA1A4_5= cv2.cvtColor(imgS4_A1A4_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_5  = cv2.imread(S4_doubleA1B1_5)
S4RGB_imgA1B1_5= cv2.cvtColor(imgS4_A1B1_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_5  = cv2.imread(S4_doubleA1B2_5)
S4RGB_imgA1B2_5= cv2.cvtColor(imgS4_A1B2_, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_5  = cv2.imread(S4_doubleA1B3_5)
S4RGB_imgA1B3_5= cv2.cvtColor(imgS4_A1B3_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_5  = cv2.imread(S4_doubleA1B41)
S4RGB_imgA1B4_5= cv2.cvtColor(imgS4_A1B4_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_5 = cv2.imread(S4_doubleA1C1_5)
S4RGB_imgA1C1_5= cv2.cvtColor(imgS4_A1C1_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_5  = cv2.imread(S4_doubleA1C2_5)
S4RGB_imgA1C2_5= cv2.cvtColor(imgS4_A1C2_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_5  = cv2.imread(S4_doubleA1C3_5)
S4RGB_imgA1C3_5= cv2.cvtColor(imgS4_A1C3_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_5= cv2.imread(S4_doubleA1C4_5)
S4RGB_imgA1C4_5= cv2.cvtColor(imgS4_A1C4_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_5 = cv2.imread(S4_doubleA1D2_5)
S4RGB_imgA1D2_5= cv2.cvtColor(imgS4_A1D2_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_5  = cv2.imread(S4_doubleA1D3_5)
S4RGB_imgA1D3_5= cv2.cvtColor(imgS4_A1D3_5, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_5  = cv2.imread(S4_doubleA1D4_5)
S4RGB_imgA1D4_5= cv2.cvtColor(imgS4_A1D4_5, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 6

# %%
imgS4_A1A1_6 = cv2.imread(S4_doubleA1A1_6)
S4RGB_imgA1A1_6= cv2.cvtColor(imgS4_A1A1_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_6  = cv2.imread(S4_doubleA1A2_6)
S4RGB_imgA1A2_6= cv2.cvtColor(imgS4_A1A2_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_6= cv2.imread(S4_doubleA1A3_6)
S4RGB_imgA1A3_6= cv2.cvtColor(imgS4_A1A3_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_56  = cv2.imread(S4_doubleA1A3_56)
S4RGB_imgA1A3_56= cv2.cvtColor(imgS4_A1A3_56, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_6= cv2.imread(S4_doubleA1A4_6)
S4RGB_imgA1A4_6= cv2.cvtColor(imgS4_A1A4_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_6  = cv2.imread(S4_doubleA1B1_6)
S4RGB_imgA1B1_6= cv2.cvtColor(imgS4_A1B1_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_6  = cv2.imread(S4_doubleA1B2_6)
S4RGB_imgA1B2_6= cv2.cvtColor(imgS4_A1B2_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_6 = cv2.imread(S4_doubleA1B3_6)
S4RGB_imgA1B3_6= cv2.cvtColor(imgS4_A1B3_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_6 = cv2.imread(S4_doubleA1B4_6)
S4RGB_imgA1B4_6= cv2.cvtColor(imgS4_A1B4_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_6  = cv2.imread(S4_doubleA1C1_6)
S4RGB_imgA1C1_6= cv2.cvtColor(imgS4_A1C1_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_6  = cv2.imread(S4_doubleA1C2_6)
S4RGB_imgA1C2_6= cv2.cvtColor(imgS4_A1C2_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_6 = cv2.imread(S4_doubleA1C3_6)
S4RGB_imgA1C3_6= cv2.cvtColor(imgS4_A1C3_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_6 = cv2.imread(S4_doubleA1C4_6)
S4RGB_imgA1C4_6= cv2.cvtColor(imgS4_A1C4_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_6  = cv2.imread(S4_doubleA1D2_6)
S4RGB_imgA1D2_6= cv2.cvtColor(imgS4_A1D2_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_6  = cv2.imread(S4_doubleA1D3_6)
S4RGB_imgA1D3_6= cv2.cvtColor(imgS4_A1D3_6, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_6  = cv2.imread(S4_doubleA1D4_6)
S4RGB_imgA1D4_6= cv2.cvtColor(imgS4_A1D4_6, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 7

# %%
imgS4_A1A1_7 = cv2.imread(S4_doubleA1A1_7)
S4RGB_imgA1A1_7= cv2.cvtColor(imgS4_A1A1_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_7  = cv2.imread(S4_doubleA1A2_7)
S4RGB_imgA1A2_7= cv2.cvtColor(imgS4_A1A2_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_7= cv2.imread(S4_doubleA1A3_7)
S4RGB_imgA1A3_7= cv2.cvtColor(imgS4_A1A3_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_57  = cv2.imread(S4_doubleA1A3_57)
S4RGB_imgA1A3_57= cv2.cvtColor(imgS4_A1A3_57, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_7  = cv2.imread(S4_doubleA1A4_7)
S4RGB_imgA1A4_7= cv2.cvtColor(imgS4_A1A4_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_7 = cv2.imread(S4_doubleA1B1_7)
S4RGB_imgA1B1_7= cv2.cvtColor(imgS4_A1B1_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_7 = cv2.imread(S4_doubleA1B2_7)
S4RGB_imgA1B2_7= cv2.cvtColor(imgS4_A1B2_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_7= cv2.imread(S4_doubleA1B3_7)
S4RGB_imgA1B3_7= cv2.cvtColor(imgS4_A1B3_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_7  = cv2.imread(S4_doubleA1B4_7)
S4RGB_imgA1B4_7= cv2.cvtColor(imgS4_A1B4_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_7 = cv2.imread(S4_doubleA1C1_7)
S4RGB_imgA1C1_7= cv2.cvtColor(imgS4_A1C1_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_7 = cv2.imread(S4_doubleA1C2_7)
S4RGB_imgA1C2_7= cv2.cvtColor(imgS4_A1C2_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_7  = cv2.imread(S4_doubleA1C3_7)
S4RGB_imgA1C3_7= cv2.cvtColor(imgS4_A1C3_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_7  = cv2.imread(S4_doubleA1C4_7)
S4RGB_imgA1C4_7= cv2.cvtColor(imgS4_A1C4_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_7 = cv2.imread(S4_doubleA1D2_7)
S4RGB_imgA1D2_7= cv2.cvtColor(imgS4_A1D2_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_7  = cv2.imread(S4_doubleA1D3_7)
S4RGB_imgA1D3_7= cv2.cvtColor(imgS4_A1D3_7, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_7  = cv2.imread(S4_doubleA1D4_7)
S4RGB_imgA1D4_7= cv2.cvtColor(imgS4_A1D4_7, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ##Img 8

# %%
imgS4_A1A1_8 = cv2.imread(S4_doubleA1A1_8)
S4RGB_imgA1A1_8= cv2.cvtColor(imgS4_A1A1_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_8  = cv2.imread(S4_doubleA1A2_8)
S4RGB_imgA1A2_8= cv2.cvtColor(imgS4_A1A2_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_8= cv2.imread(S4_doubleA1A3_8)
S4RGB_imgA1A3_8= cv2.cvtColor(imgS4_A1A3_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_58  = cv2.imread(S4_doubleA1A3_58)
S4RGB_imgA1A3_58= cv2.cvtColor(imgS4_A1A3_58, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_8  = cv2.imread(S4_doubleA1A4_8)
S4RGB_imgA1A4_8= cv2.cvtColor(imgS4_A1A4_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_8  = cv2.imread(S4_doubleA1B1_8)
S4RGB_imgA1B1_8= cv2.cvtColor(imgS4_A1B1_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_8  = cv2.imread(S4_doubleA1B2_8)
S4RGB_imgA1B2_8= cv2.cvtColor(imgS4_A1B2_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_8  = cv2.imread(S4_doubleA1B3_8)
S4RGB_imgA1B3_8= cv2.cvtColor(imgS4_A1B3_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_8  = cv2.imread(S4_doubleA1B4_8)
S4RGB_imgA1B4_8= cv2.cvtColor(imgS4_A1B4_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_8 = cv2.imread(S4_doubleA1C1_8)
S4RGB_imgA1C1_8= cv2.cvtColor(imgS4_A1C1_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_8 = cv2.imread(S4_doubleA1C2_8)
S4RGB_imgA1C2_8= cv2.cvtColor(imgS4_A1C2_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_8  = cv2.imread(S4_doubleA1C3_8)
S4RGB_imgA1C3_8= cv2.cvtColor(imgS4_A1C3_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_8  = cv2.imread(S4_doubleA1C4_8)
S4RGB_imgA1C4_8= cv2.cvtColor(imgS4_A1C4_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_8  = cv2.imread(S4_doubleA1D2_8)
S4RGB_imgA1D2_8= cv2.cvtColor(imgS4_A1D2_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_8 = cv2.imread(S4_doubleA1D3_8)
S4RGB_imgA1D3_8= cv2.cvtColor(imgS4_A1D3_8, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_8= cv2.imread(S4_doubleA1D4_8)
S4RGB_imgA1D4_8= cv2.cvtColor(imgS4_A1D4_8, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 9

# %%
imgS4_A1A1_9= cv2.imread(S4_doubleA1A1_9)
S4RGB_imgA1A1_9= cv2.cvtColor(imgS4_A1A1_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_9  = cv2.imread(S4_doubleA1A2_9)
S4RGB_imgA1A2_9= cv2.cvtColor(imgS4_A1A2_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_9= cv2.imread(S4_doubleA1A3_9)
S4RGB_imgA1A3_9= cv2.cvtColor(imgS4_A1A3_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_59  = cv2.imread(S4_doubleA1A3_59)
S4RGB_imgA1A3_59= cv2.cvtColor(imgS4_A1A3_59, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_9  = cv2.imread(S4_doubleA1A4_9)
S4RGB_imgA1A4_9= cv2.cvtColor(imgS4_A1A4_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_9  = cv2.imread(S4_doubleA1B1_9)
S4RGB_imgA1B1_9= cv2.cvtColor(imgS4_A1B1_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_9  = cv2.imread(S4_doubleA1B2_9)
S4RGB_imgA1B2_9= cv2.cvtColor(imgS4_A1B2_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_9  = cv2.imread(S4_doubleA1B3_9)
S4RGB_imgA1B3_9= cv2.cvtColor(imgS4_A1B3_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_9 = cv2.imread(S4_doubleA1B4_9)
S4RGB_imgA1B4_9= cv2.cvtColor(imgS4_A1B4_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_9  = cv2.imread(S4_doubleA1C1_9)
S4RGB_imgA1C1_9= cv2.cvtColor(imgS4_A1C1_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_9  = cv2.imread(S4_doubleA1C2_9)
S4RGB_imgA1C2_9= cv2.cvtColor(imgS4_A1C2_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_9  = cv2.imread(S4_doubleA1C3_9)
S4RGB_imgA1C3_9= cv2.cvtColor(imgS4_A1C3_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_9 = cv2.imread(S_doubleA1C4_9)
S4RGB_imgA1C4_9= cv2.cvtColor(imgS_A1C4_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_9 = cv2.imread(S4_doubleA1D2_9)
S4RGB_imgA1D2_9= cv2.cvtColor(imgS4_A1D2_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_9 = cv2.imread(S4_doubleA1D3_9)
S4RGB_imgA1D3_9= cv2.cvtColor(imgS4_A1D3_9, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_9 = cv2.imread(S4_doubleA1D4_9)
S4RGB_imgA1D4_9= cv2.cvtColor(imgS4_A1D4_9, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ###Img 10

# %%
imgS4_A1A1_10 = cv2.imread(S4_doubleA1A1_10)
S4RGB_imgA1A1_10= cv2.cvtColor(imgS4_A1A1_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A2_10  = cv2.imread(S4_doubleA1A2_10)
S4RGB_imgA1A2_10= cv2.cvtColor(imgS4_A1A2_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_10= cv2.imread(S4_doubleA1A3_10)
S4RGB_imgA1A3_10= cv2.cvtColor(imgS4_A1A3_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A3_510 = cv2.imread(S4_doubleA1A3_510)
S4RGB_imgA1A3_510= cv2.cvtColor(imgS4_A1A3_510, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1A4_10 = cv2.imread(S4_doubleA1A4_10)
S4RGB_imgA1A4_10= cv2.cvtColor(imgS4_A1A4_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B1_10  = cv2.imread(S4_doubleA1B1_10)
S4RGB_imgA1B1_10= cv2.cvtColor(imgS4_A1B1_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B2_10  = cv2.imread(S4_doubleA1B2_10)
S4RGB_imgA1B2_10= cv2.cvtColor(imgS4_A1B2_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B3_10  = cv2.imread(S4_doubleA1B3_10)
S4RGB_imgA1B3_10= cv2.cvtColor(imgS4_A1B3_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1B4_10 = cv2.imread(S4_doubleA1B4_10)
S4RGB_imgA1B4_10= cv2.cvtColor(imgS4_A1B4_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C1_10  = cv2.imread(S4_doubleA1C1_10)
S4RGB_imgA1C1_10= cv2.cvtColor(imgS4_A1C1_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C2_10  = cv2.imread(S4_doubleA1C2_10)
S4RGB_imgA1C2_10= cv2.cvtColor(imgS4_A1C2_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C3_10  = cv2.imread(S4_doubleA1C3_10)
S4RGB_imgA1C3_10= cv2.cvtColor(imgS4_A1C3_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1C4_10 = cv2.imread(S4_doubleA1C4_10)
S4RGB_imgA1C4_10= cv2.cvtColor(imgS4_A1C4_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D2_10 = cv2.imread(S4_doubleA1D2_10)
S4RGB_imgA1D2_10= cv2.cvtColor(imgS4_A1D2_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D3_10  = cv2.imread(S4_doubleA1D3_10)
S4RGB_imgA1D3_10= cv2.cvtColor(imgS4_A1D3_10, cv2.COLOR_BGR2RGB)

# %%
imgS4_A1D4_10  = cv2.imread(S4_doubleA1D4_10)
S4RGB_imgA1D4_10= cv2.cvtColor(imgS4_A1D4_10, cv2.COLOR_BGR2RGB)

# %% [markdown]
# #4. ฺBGR TO HSV

# %% [markdown]
# ##Set1

# %%
S1_A1A1_1img  = cv2.imread(S1_doubleA1A1_1)
S1HSV_imgA1A1_1= cv2.cvtColor(S1_A1A1_1img, cv2.COLOR_BGR2HSV)
plt.imshow(S1HSV_imgA1A1_1)

# %%
S1_A1A2_1img  = cv2.imread(S1_doubleA1A2_1)
S1HSV_imgA1A2_1= cv2.cvtColor(S1_A1A2_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_1img  = cv2.imread(S1_doubleA1A3_1)
S1HSV_imgA1A3_1= cv2.cvtColor(S1_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_51img  = cv2.imread(S1_doubleA1A3_51)
S1HSV_imgA1A3_51= cv2.cvtColor(S1_A1A3_51img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_1img  = cv2.imread(S1_doubleA1A4_1)
S1HSV_imgA1A4_1= cv2.cvtColor(S1_A1A4_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_1img  = cv2.imread(S1_doubleA1B1_1)
S1HSV_imgA1B1_1= cv2.cvtColor(S1_A1B1_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_1img  = cv2.imread(S1_doubleA1B2_1)
S1HSV_imgA1B2_1= cv2.cvtColor(S1_A1B2_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_1img  = cv2.imread(S1_doubleA1B3_1)
S1HSV_imgA1B3_1= cv2.cvtColor(S1_A1B3_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_1img  = cv2.imread(S1_doubleA1B4_1)
S1HSV_imgA1B4_1= cv2.cvtColor(S1_A1B4_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_1img  = cv2.imread(S1_doubleA1C1_1)
S1HSV_imgA1C1_1= cv2.cvtColor(S1_A1C1_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_1img  = cv2.imread(S1_doubleA1C2_1)
S1HSV_imgA1C2_1= cv2.cvtColor(S1_A1C2_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_1img  = cv2.imread(S1_doubleA1C3_1)
S1HSV_imgA1C3_1= cv2.cvtColor(S1_A1C3_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_1img  = cv2.imread(S1_doubleA1C4_1)
S1HSV_imgA1C4_1= cv2.cvtColor(S1_A1C4_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_1img  = cv2.imread(S1_doubleA1D2_1)
S1HSV_imgA1D2_1= cv2.cvtColor(S1_A1D2_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_1img  = cv2.imread(S1_doubleA1D3_1)
S1HSV_imgA1D3_1= cv2.cvtColor(S1_A1D3_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_1img  = cv2.imread(S1_doubleA1D4_1)
S1HSV_imgA1D4_1= cv2.cvtColor(S1_A1D4_1img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 2

# %%
S1_A1A1_2img  = cv2.imread(S1_doubleA1A1_2)
S1HSV_imgA1A1_2= cv2.cvtColor(S1_A1A1_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_2img  = cv2.imread(S1_doubleA1A2_2)
S1HSV_imgA1A2_2= cv2.cvtColor(S1_A1A2_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_2img  = cv2.imread(S1_doubleA1A3_)
S1HSV_imgA1A3_2= cv2.cvtColor(S1_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_52img  = cv2.imread(S1_doubleA1A3_52)
S1HSV_imgA1A3_52= cv2.cvtColor(S1_A1A3_52img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_2img  = cv2.imread(S1_doubleA1A4_2)
S1HSV_imgA1A4_2= cv2.cvtColor(S1_A1A4_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_2img  = cv2.imread(S1_doubleA1B1_2)
S1HSV_imgA1B1_2= cv2.cvtColor(S1_A1B1_img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_2img  = cv2.imread(S1_doubleA1B2_2)
S1HSV_imgA1B2_2= cv2.cvtColor(S1_A1B2_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_2img  = cv2.imread(S1_doubleA1B3_2)
S1HSV_imgA1B3_2= cv2.cvtColor(S1_A1B3_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_2img  = cv2.imread(S1_doubleA1B4_2)
S1HSV_imgA1B4_2= cv2.cvtColor(S1_A1B4_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_2img  = cv2.imread(S1_doubleA1C1_2)
S1HSV_imgA1C1_2= cv2.cvtColor(S1_A1C1_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_2img  = cv2.imread(S1_doubleA1C2_2)
S1HSV_imgA1C2_2= cv2.cvtColor(S1_A1C2_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_2img  = cv2.imread(S1_doubleA1C3_2)
S1HSV_imgA1C3_2= cv2.cvtColor(S1_A1C3_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_2img  = cv2.imread(S1_doubleA1C4_2)
S1HSV_imgA1C4_2= cv2.cvtColor(S1_A1C4_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_2img  = cv2.imread(S1_doubleA1D2_2)
S1HSV_imgA1D2_2= cv2.cvtColor(S1_A1D2_2img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_2img  = cv2.imread(S1_doubleA1D3_)
S1HSV_imgA1D3_= cv2.cvtColor(S1_A1D3_img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_2img  = cv2.imread(S1_doubleA1D4_2)
S1HSV_imgA1D4_2= cv2.cvtColor(S1_A1D4_2img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 3

# %%
S1_A1A1_3img  = cv2.imread(S1_doubleA1A1_3)
S1HSV_imgA1A1_3= cv2.cvtColor(S1_A1A1_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_3img  = cv2.imread(S1_doubleA1A2_3)
S1HSV_imgA1A2_3= cv2.cvtColor(S1_A1A2_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_3img  = cv2.imread(S1_doubleA1A3_3)
S1HSV_imgA1A3_3= cv2.cvtColor(S1_A1A3_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_53img  = cv2.imread(S1_doubleA1A3_53)
S1HSV_imgA1A3_53= cv2.cvtColor(S1_A1A3_53img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_3img  = cv2.imread(S1_doubleA1A4_3)
S1HSV_imgA1A4_3= cv2.cvtColor(S1_A1A4_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_3img  = cv2.imread(S1_doubleA1B1_3)
S1HSV_imgA1B1_3= cv2.cvtColor(S1_A1B1_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_3img  = cv2.imread(S1_doubleA1B2_3)
S1HSV_imgA1B2_3= cv2.cvtColor(S1_A1B2_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_3img  = cv2.imread(S1_doubleA1B3_3)
S1HSV_imgA1B3_3= cv2.cvtColor(S1_A1B3_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_3img  = cv2.imread(S1_doubleA1B4_3)
S1HSV_imgA1B4_3= cv2.cvtColor(S1_A1B4_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_3img  = cv2.imread(S1_doubleA1C1_3)
S1HSV_imgA1C1_3= cv2.cvtColor(S1_A1C1_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_3img  = cv2.imread(S1_doubleA1C2_3)
S1HSV_imgA1C2_3= cv2.cvtColor(S1_A1C2_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_3img  = cv2.imread(S1_doubleA1C3_3)
S1HSV_imgA1C3_3= cv2.cvtColor(S1_A1C3_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_3img  = cv2.imread(S1_doubleA1C4_3)
S1HSV_imgA1C4_3= cv2.cvtColor(S1_A1C4_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_3img  = cv2.imread(S1_doubleA1D2_3)
S1HSV_imgA1D2_3= cv2.cvtColor(S1_A1D2_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_3img  = cv2.imread(S1_doubleA1D3_3)
S1HSV_imgA1D3_3= cv2.cvtColor(S1_A1D3_3img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_3img  = cv2.imread(S1_doubleA1D4_3)
S1HSV_imgA1D4_3= cv2.cvtColor(S1_A1D4_3img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 4

# %%
S1_A1A1_4img  = cv2.imread(S1_doubleA1A1_4)
S1HSV_imgA1A1_4= cv2.cvtColor(S1_A1A1_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_4img  = cv2.imread(S1_doubleA1A2_4)
S1HSV_imgA1A2_4= cv2.cvtColor(S1_A1A2_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_4img  = cv2.imread(S1_doubleA1A3_4)
S1HSV_imgA1A3_4= cv2.cvtColor(S1_A1A3_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_54img  = cv2.imread(S1_doubleA1A3_54)
S1HSV_imgA1A3_54= cv2.cvtColor(S1_A1A3_54img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_4img  = cv2.imread(S1_doubleA1A4_4)
S1HSV_imgA1A4_4= cv2.cvtColor(S1_A1A4_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_4img  = cv2.imread(S1_doubleA1B1_4)
S1HSV_imgA1B1_4= cv2.cvtColor(S1_A1B1_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_4img  = cv2.imread(S1_doubleA1B2_4)
S1HSV_imgA1B2_4= cv2.cvtColor(S1_A1B2_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_4img  = cv2.imread(S1_doubleA1B3_4)
S1HSV_imgA1B3_4= cv2.cvtColor(S1_A1B3_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_4img  = cv2.imread(S1_doubleA1B4_4)
S1HSV_imgA1B4_4= cv2.cvtColor(S1_A1B4_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_4img  = cv2.imread(S1_doubleA1C1_4)
S1HSV_imgA1C1_4= cv2.cvtColor(S1_A1C1_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_4img  = cv2.imread(S1_doubleA1C2_4)
S1HSV_imgA1C2_4= cv2.cvtColor(S1_A1C2_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_4img  = cv2.imread(S1_doubleA1C3_4)
S1HSV_imgA1C3_4= cv2.cvtColor(S1_A1C3_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_4img  = cv2.imread(S1_doubleA1C4_4)
S1HSV_imgA1C4_4= cv2.cvtColor(S1_A1C4_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_4img  = cv2.imread(S1_doubleA1D2_4)
S1HSV_imgA1D2_4= cv2.cvtColor(S1_A1D2_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_4img  = cv2.imread(S1_doubleA1D3_4)
S1HSV_imgA1D3_4= cv2.cvtColor(S1_A1D3_4img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_4img  = cv2.imread(S1_doubleA1D4_4)
S1HSV_imgA1D4_4= cv2.cvtColor(S1_A1D4_4img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 5

# %%
S1_A1A1_5img  = cv2.imread(S1_doubleA1A1_5)
S1HSV_imgA1A1_5= cv2.cvtColor(S1_A1A1_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_5img  = cv2.imread(S1_doubleA1A2_5)
S1HSV_imgA1A2_5= cv2.cvtColor(S1_A1A2_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_5img  = cv2.imread(S1_doubleA1A3_5)
S1HSV_imgA1A3_5= cv2.cvtColor(S1_A1A3_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_55img  = cv2.imread(S1_doubleA1A3_55)
S1HSV_imgA1A3_55= cv2.cvtColor(S1_A1A3_55img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_5img  = cv2.imread(S1_doubleA1A4_5)
S1HSV_imgA1A4_5= cv2.cvtColor(S1_A1A4_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_5img  = cv2.imread(S1_doubleA1B1_5)
S1HSV_imgA1B1_5= cv2.cvtColor(S1_A1B1_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_5img  = cv2.imread(S1_doubleA1B2_5)
S1HSV_imgA1B2_5= cv2.cvtColor(S1_A1B2_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_5img  = cv2.imread(S1_doubleA1B3_5)
S1HSV_imgA1B3_5= cv2.cvtColor(S1_A1B3_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_5img  = cv2.imread(S1_doubleA1B4_5)
S1HSV_imgA1B4_5= cv2.cvtColor(S1_A1B4_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_5img  = cv2.imread(S1_doubleA1C1_5)
S1HSV_imgA1C1_5= cv2.cvtColor(S1_A1C1_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_5img  = cv2.imread(S1_doubleA1C2_5)
S1HSV_imgA1C2_5= cv2.cvtColor(S1_A1C2_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_5img  = cv2.imread(S1_doubleA1C3_5)
S1HSV_imgA1C3_5= cv2.cvtColor(S1_A1C3_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_5img  = cv2.imread(S1_doubleA1C4_5)
S1HSV_imgA1C4_5= cv2.cvtColor(S1_A1C4_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_5img  = cv2.imread(S1_doubleA1D2_5)
S1HSV_imgA1D2_5= cv2.cvtColor(S1_A1D2_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_5img  = cv2.imread(S1_doubleA1D3_5)
S1HSV_imgA1D3_5= cv2.cvtColor(S1_A1D3_5img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_5img  = cv2.imread(S1_doubleA1D4_5)
S1HSV_imgA1D4_5= cv2.cvtColor(S1_A1D4_5img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 6

# %%
S1_A1A1_6img  = cv2.imread(S1_doubleA1A1_6)
S1HSV_imgA1A1_6= cv2.cvtColor(S1_A1A1_img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_6img  = cv2.imread(S1_doubleA1A2_6)
S1HSV_imgA1A2_6= cv2.cvtColor(S1_A1A2_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_6img  = cv2.imread(S1_doubleA1A3_6)
S1HSV_imgA1A3_6= cv2.cvtColor(S1_A1A3_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_56img  = cv2.imread(S1_doubleA1A3_56)
S1HSV_imgA1A3_56= cv2.cvtColor(S1_A1A3_56img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_6img  = cv2.imread(S1_doubleA1A4_)
S1HSV_imgA1A4_6= cv2.cvtColor(S1_A1A4_img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_6img  = cv2.imread(S1_doubleA1B1_6)
S1HSV_imgA1B1_6= cv2.cvtColor(S1_A1B1_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_6img  = cv2.imread(S1_doubleA1B2_6)
S1HSV_imgA1B2_6= cv2.cvtColor(S1_A1B2_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_6img  = cv2.imread(S1_doubleA1B3_6)
S1HSV_imgA1B3_6= cv2.cvtColor(S1_A1B3_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_6img  = cv2.imread(S1_doubleA1B4_6)
S1HSV_imgA1B4_6= cv2.cvtColor(S1_A1B4_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_6img  = cv2.imread(S1_doubleA1C1_6)
S1HSV_imgA1C1_6= cv2.cvtColor(S1_A1C1_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_6img  = cv2.imread(S1_doubleA1C2_6)
S1HSV_imgA1C2_6= cv2.cvtColor(S1_A1C2_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_6img  = cv2.imread(S1_doubleA1C3_6)
S1HSV_imgA1C3_6= cv2.cvtColor(S1_A1C3_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_6img  = cv2.imread(S1_doubleA1C4_)
S1HSV_imgA1C4_6= cv2.cvtColor(S1_A1C4_img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_6img  = cv2.imread(S1_doubleA1D2_6)
S1HSV_imgA1D2_6= cv2.cvtColor(S1_A1D2_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_6img  = cv2.imread(S1_doubleA1D3_6)
S1HSV_imgA1D3_6= cv2.cvtColor(S1_A1D3_6img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_6img  = cv2.imread(S1_doubleA1D4_6)
S1HSV_imgA1D4_6= cv2.cvtColor(S1_A1D4_6img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 7

# %%
S1_A1A1_7img  = cv2.imread(S1_doubleA1A1_7)
S1HSV_imgA1A1_7= cv2.cvtColor(S1_A1A1_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_7img  = cv2.imread(S1_doubleA1A2_7)
S1HSV_imgA1A2_7= cv2.cvtColor(S1_A1A2_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_7img  = cv2.imread(S1_doubleA1A3_)
S1HSV_imgA1A3_7= cv2.cvtColor(S1_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_57img  = cv2.imread(S1_doubleA1A3_57)
S1HSV_imgA1A3_57= cv2.cvtColor(S1_A1A3_57img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_7img  = cv2.imread(S1_doubleA1A4_7)
S1HSV_imgA1A4_7= cv2.cvtColor(S1_A1A4_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_7img  = cv2.imread(S1_doubleA1B1_7)
S1HSV_imgA1B1_7= cv2.cvtColor(S1_A1B1_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_7img  = cv2.imread(S1_doubleA1B2_7)
S1HSV_imgA1B2_7= cv2.cvtColor(S1_A1B2_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_7img  = cv2.imread(S1_doubleA1B3_7)
S1HSV_imgA1B3_7= cv2.cvtColor(S1_A1B3_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_7img  = cv2.imread(S1_doubleA1B4_7)
S1HSV_imgA1B4_7= cv2.cvtColor(S1_A1B4_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_7img  = cv2.imread(S1_doubleA1C1_7)
S1HSV_imgA1C1_7= cv2.cvtColor(S1_A1C1_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_7img  = cv2.imread(S1_doubleA1C2_7)
S1HSV_imgA1C2_7= cv2.cvtColor(S1_A1C2_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_7img  = cv2.imread(S1_doubleA1C3_7)
S1HSV_imgA1C3_7= cv2.cvtColor(S1_A1C3_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_7img  = cv2.imread(S1_doubleA1C4_7)
S1HSV_imgA1C4_7= cv2.cvtColor(S1_A1C4_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_7img  = cv2.imread(S1_doubleA1D2_7)
S1HSV_imgA1D2_7= cv2.cvtColor(S1_A1D2_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_7img  = cv2.imread(S1_doubleA1D3_7)
S1HSV_imgA1D3_7= cv2.cvtColor(S1_A1D3_7img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_7img  = cv2.imread(S1_doubleA1D4_7)
S1HSV_imgA1D4_7= cv2.cvtColor(S1_A1D4_7img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 8

# %%
S1_A1A1_8img  = cv2.imread(S1_doubleA1A1_8)
S1HSV_imgA1A1_8= cv2.cvtColor(S1_A1A1_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_8img  = cv2.imread(S1_doubleA1A2_8)
S1HSV_imgA1A2_8= cv2.cvtColor(S1_A1A2_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_8img  = cv2.imread(S1_doubleA1A3_8)
S1HSV_imgA1A3_8= cv2.cvtColor(S1_A1A3_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_58img  = cv2.imread(S1_doubleA1A3_58)
S1HSV_imgA1A3_58= cv2.cvtColor(S1_A1A3_58img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_8img  = cv2.imread(S1_doubleA1A4_8)
S1HSV_imgA1A4_8= cv2.cvtColor(S1_A1A4_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_8img  = cv2.imread(S1_doubleA1B1_8)
S1HSV_imgA1B1_8= cv2.cvtColor(S1_A1B1_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_8img  = cv2.imread(S1_doubleA1B2_8)
S1HSV_imgA1B2_8= cv2.cvtColor(S1_A1B2_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_8img  = cv2.imread(S1_doubleA1B3_8)
S1HSV_imgA1B3_8= cv2.cvtColor(S1_A1B3_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_8img  = cv2.imread(S1_doubleA1B4_8)
S1HSV_imgA1B4_8= cv2.cvtColor(S1_A1B4_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_8img  = cv2.imread(S1_doubleA1C1_8)
S1HSV_imgA1C1_8= cv2.cvtColor(S1_A1C1_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_8img  = cv2.imread(S1_doubleA1C2_8)
S1HSV_imgA1C2_8= cv2.cvtColor(S1_A1C2_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_8img  = cv2.imread(S1_doubleA1C3_8)
S1HSV_imgA1C3_8= cv2.cvtColor(S1_A1C3_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_8img  = cv2.imread(S1_doubleA1C4_8)
S1HSV_imgA1C4_8= cv2.cvtColor(S1_A1C4_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_8img  = cv2.imread(S1_doubleA1D2_8)
S1HSV_imgA1D2_8= cv2.cvtColor(S1_A1D2_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_8img  = cv2.imread(S1_doubleA1D3_8)
S1HSV_imgA1D3_8= cv2.cvtColor(S1_A1D3_8img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_8img  = cv2.imread(S1_doubleA1D4_8)
S1HSV_imgA1D4_8= cv2.cvtColor(S1_A1D4_8img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 9

# %%
S1_A1A1_9img  = cv2.imread(S1_doubleA1A1_9)
S1HSV_imgA1A1_9= cv2.cvtColor(S1_A1A1_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_9img  = cv2.imread(S1_doubleA1A2_9)
S1HSV_imgA1A2_9= cv2.cvtColor(S1_A1A2_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_9img  = cv2.imread(S1_doubleA1A3_9)
S1HSV_imgA1A3_9= cv2.cvtColor(S1_A1A3_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_59img  = cv2.imread(S1_doubleA1A3_59)
S1HSV_imgA1A3_59= cv2.cvtColor(S1_A1A3_59img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_9img  = cv2.imread(S1_doubleA1A4_9)
S1HSV_imgA1A4_9= cv2.cvtColor(S1_A1A4_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_9img  = cv2.imread(S1_doubleA1B1_9)
S1HSV_imgA1B1_9= cv2.cvtColor(S1_A1B1_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_9img  = cv2.imread(S1_doubleA1B2_9)
S1HSV_imgA1B2_9= cv2.cvtColor(S1_A1B2_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_9img  = cv2.imread(S1_doubleA1B3_9)
S1HSV_imgA1B3_9= cv2.cvtColor(S1_A1B3_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_9img  = cv2.imread(S1_doubleA1B4_9)
S1HSV_imgA1B4_9= cv2.cvtColor(S1_A1B4_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_9img  = cv2.imread(S1_doubleA1C1_9)
S1HSV_imgA1C1_9= cv2.cvtColor(S1_A1C1_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_9img  = cv2.imread(S1_doubleA1C2_9)
S1HSV_imgA1C2_9= cv2.cvtColor(S1_A1C2_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_9img  = cv2.imread(S1_doubleA1C3_9)
S1HSV_imgA1C3_9= cv2.cvtColor(S1_A1C3_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_9img  = cv2.imread(S1_doubleA1C4_9)
S1HSV_imgA1C4_9= cv2.cvtColor(S1_A1C4_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_9img  = cv2.imread(S1_doubleA1D2_9)
S1HSV_imgA1D2_9= cv2.cvtColor(S1_A1D2_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_9img  = cv2.imread(S1_doubleA1D3_9)
S1HSV_imgA1D3_9= cv2.cvtColor(S1_A1D3_9img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_9img  = cv2.imread(S1_doubleA1D4_9)
S1HSV_imgA1D4_9= cv2.cvtColor(S1_A1D4_9img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 10

# %%
S1_A1A1_10img  = cv2.imread(S1_doubleA1A1_10)
S1HSV_imgA1A1_10= cv2.cvtColor(S1_A1A1_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A2_10img  = cv2.imread(S1_doubleA1A2_10)
S1HSV_imgA1A2_10= cv2.cvtColor(S1_A1A2_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_10img  = cv2.imread(S1_doubleA1A3_10)
S1HSV_imgA1A3_10= cv2.cvtColor(S1_A1A3_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A3_510img  = cv2.imread(S1_doubleA1A3_510)
S1HSV_imgA1A3_510= cv2.cvtColor(S1_A1A3_510img, cv2.COLOR_BGR2HSV)

# %%
S1_A1A4_10img  = cv2.imread(S1_doubleA1A4_10)
S1HSV_imgA1A4_10= cv2.cvtColor(S1_A1A4_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B1_10img  = cv2.imread(S1_doubleA1B1_10)
S1HSV_imgA1B1_10= cv2.cvtColor(S1_A1B1_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B2_10img  = cv2.imread(S1_doubleA1B2_10)
S1HSV_imgA1B2_10= cv2.cvtColor(S1_A1B2_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B3_10img  = cv2.imread(S1_doubleA1B3_10)
S1HSV_imgA1B3_10= cv2.cvtColor(S1_A1B3_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1B4_10img  = cv2.imread(S1_doubleA1B4_10)
S1HSV_imgA1B4_10= cv2.cvtColor(S1_A1B4_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C1_10img  = cv2.imread(S1_doubleA1C1_10)
S1HSV_imgA1C1_10= cv2.cvtColor(S1_A1C1_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C2_10img  = cv2.imread(S1_doubleA1C2_10)
S1HSV_imgA1C2_10= cv2.cvtColor(S1_A1C2_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C3_10img  = cv2.imread(S1_doubleA1C3_10)
S1HSV_imgA1C3_10= cv2.cvtColor(S1_A1C3_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1C4_10img  = cv2.imread(S1_doubleA1C4_10)
S1HSV_imgA1C4_10= cv2.cvtColor(S1_A1C4_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D2_10img  = cv2.imread(S1_doubleA1D2_10)
S1HSV_imgA1D2_10= cv2.cvtColor(S1_A1D2_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D3_10img  = cv2.imread(S1_doubleA1D3_10)
S1HSV_imgA1D3_10= cv2.cvtColor(S1_A1D3_10img, cv2.COLOR_BGR2HSV)

# %%
S1_A1D4_10img  = cv2.imread(S1_doubleA1D4_10)
S1HSV_imgA1D4_10= cv2.cvtColor(S1_A1D4_10img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ##Set2

# %%
S2_A1A1_1img  = cv2.imread(S2_doubleA1A1_1)
S2HSV_imgA1A1_1= cv2.cvtColor(S2_A1A1_1img, cv2.COLOR_BGR2HSV)
plt.imshow(S2HSV_imgA1A1_1)

# %%
S2_A1A2_1img  = cv2.imread(S2_doubleA1A2_1)
S2HSV_imgA1A2_1= cv2.cvtColor(S2_A1A2_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_1img  = cv2.imread(S2_doubleA1A3_1)
S2HSV_imgA1A3_1= cv2.cvtColor(S2_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_51img  = cv2.imread(S2_doubleA1A3_51)
S2HSV_imgA1A3_51= cv2.cvtColor(S2_A1A3_51img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_1img  = cv2.imread(S2_doubleA1A4_1)
S2HSV_imgA1A4_1= cv2.cvtColor(S2_A1A4_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_1img  = cv2.imread(S2_doubleA1B1_1)
S2HSV_imgA1B1_1= cv2.cvtColor(S2_A1B1_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_1img  = cv2.imread(S2_doubleA1B2_1)
S2HSV_imgA1B2_1= cv2.cvtColor(S2_A1B2_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_1img  = cv2.imread(S2_doubleA1B3_1)
S2HSV_imgA1B3_1= cv2.cvtColor(S2_A1B3_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_1img  = cv2.imread(S2_doubleA1B4_1)
S2HSV_imgA1B4_1= cv2.cvtColor(S2_A1B4_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_1img  = cv2.imread(S2_doubleA1C1_1)
S2HSV_imgA1C1_1= cv2.cvtColor(S2_A1C1_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_1img  = cv2.imread(S2_doubleA1C2_1)
S2HSV_imgA1C2_1= cv2.cvtColor(S2_A1C2_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_1img  = cv2.imread(S2_doubleA1C3_1)
S2HSV_imgA1C3_1= cv2.cvtColor(S2_A1C3_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_1img  = cv2.imread(S2_doubleA1C4_1)
S2HSV_imgA1C4_1= cv2.cvtColor(S2_A1C4_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_1img  = cv2.imread(S2_doubleA1D2_1)
S2HSV_imgA1D2_1= cv2.cvtColor(S2_A1D2_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_1img  = cv2.imread(S2_doubleA1D3_1)
S2HSV_imgA1D3_1= cv2.cvtColor(S2_A1D3_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_1img  = cv2.imread(S2_doubleA1D4_1)
S2HSV_imgA1D4_1= cv2.cvtColor(S2_A1D4_1img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 2

# %%
S2_A1A1_2img  = cv2.imread(S2_doubleA1A1_2)
S2HSV_imgA1A1_2= cv2.cvtColor(S2_A1A1_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A2_2img  = cv2.imread(S2_doubleA1A2_2)
S2HSV_imgA1A2_2= cv2.cvtColor(S2_A1A2_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_2img  = cv2.imread(S2_doubleA1A3_2)
S2HSV_imgA1A3_2= cv2.cvtColor(S2_A1A3_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_52img  = cv2.imread(S2_doubleA1A3_52)
S2HSV_imgA1A3_52= cv2.cvtColor(S2_A1A3_52img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_2img  = cv2.imread(S2_doubleA1A4_2)
S2HSV_imgA1A4_2= cv2.cvtColor(S2_A1A4_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_2img  = cv2.imread(S2_doubleA1B1_2)
S2HSV_imgA1B1_2= cv2.cvtColor(S2_A1B1_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_2img  = cv2.imread(S2_doubleA1B2_2)
S2HSV_imgA1B2_2= cv2.cvtColor(S2_A1B2_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_2img  = cv2.imread(S2_doubleA1B3_2)
S2HSV_imgA1B3_2= cv2.cvtColor(S2_A1B3_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_2img  = cv2.imread(S2_doubleA1B4_2)
S2HSV_imgA1B4_2= cv2.cvtColor(S2_A1B4_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_2img  = cv2.imread(S2_doubleA1C1_2)
S2HSV_imgA1C1_2= cv2.cvtColor(S2_A1C1_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_2img  = cv2.imread(S2_doubleA1C2_2)
S2HSV_imgA1C2_2= cv2.cvtColor(S2_A1C2_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_2img  = cv2.imread(S2_doubleA1C3_2)
S2HSV_imgA1C3_2= cv2.cvtColor(S2_A1C3_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_2img  = cv2.imread(S2_doubleA1C4_2)
S2HSV_imgA1C4_2= cv2.cvtColor(S2_A1C4_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_2img  = cv2.imread(S2_doubleA1D2_2)
S2HSV_imgA1D2_2= cv2.cvtColor(S2_A1D2_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_2img  = cv2.imread(S2_doubleA1D3_2)
S2HSV_imgA1D3_2= cv2.cvtColor(S2_A1D3_2img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_2img  = cv2.imread(S2_doubleA1D4_2)
S2HSV_imgA1D4_2= cv2.cvtColor(S2_A1D4_2img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 3

# %%
S2_A1A1_3img  = cv2.imread(S2_doubleA1A1_3)
S2HSV_imgA1A1_3= cv2.cvtColor(S2_A1A1_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A2_3img  = cv2.imread(S2_doubleA1A2_3)
S2HSV_imgA1A2_3= cv2.cvtColor(S2_A1A2_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_3img  = cv2.imread(S2_doubleA1A3_3)
S2HSV_imgA1A3_3= cv2.cvtColor(S2_A1A3_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_53img  = cv2.imread(S2_doubleA1A3_53)
SHSV_imgA1A3_53= cv2.cvtColor(S2_A1A3_53img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_3img  = cv2.imread(S2_doubleA1A4_3)
S2HSV_imgA1A4_3= cv2.cvtColor(S2_A1A4_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_3img  = cv2.imread(S2_doubleA1B1_3)
S2HSV_imgA1B1_3= cv2.cvtColor(S2_A1B1_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_3img  = cv2.imread(S2_doubleA1B2_3)
S2HSV_imgA1B2_3= cv2.cvtColor(S2_A1B2_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_3img  = cv2.imread(S2_doubleA1B3_3)
S2HSV_imgA1B3_3= cv2.cvtColor(S2_A1B3_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_3img  = cv2.imread(S2_doubleA1B4_3)
S2HSV_imgA1B4_3= cv2.cvtColor(S2_A1B4_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_3img  = cv2.imread(S2_doubleA1C1_3)
S2HSV_imgA1C1_3= cv2.cvtColor(S2_A1C1_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_3img  = cv2.imread(S2_doubleA1C2_3)
S2HSV_imgA1C2_3= cv2.cvtColor(S2_A1C2_3img, cv2.COLOR_BGR2HSV)

# %%
S2A1C3_3img  = cv2.imread(S2_doubleA1C3_3)
S2HSV_imgA1C3_3= cv2.cvtColor(S2_A1C3_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_3img  = cv2.imread(S2_doubleA1C4_3)
S2HSV_imgA1C4_3= cv2.cvtColor(S2_A1C4_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_3img  = cv2.imread(S2_doubleA1D2_3)
S2HSV_imgA1D2_3= cv2.cvtColor(S2_A1D2_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_3img  = cv2.imread(S2_doubleA1D3_3)
S2HSV_imgA1D3_3= cv2.cvtColor(S2_A1D3_3img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_3img  = cv2.imread(S2_doubleA1D4_3)
S2HSV_imgA1D4_3= cv2.cvtColor(S2_A1D4_3img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 4

# %%
S2_A1A1_4img  = cv2.imread(S2_doubleA1A1_4)
S2HSV_imgA1A1_4= cv2.cvtColor(S2_A1A1_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A2_4img  = cv2.imread(S2_doubleA1A2_4)
S2HSV_imgA1A2_4= cv2.cvtColor(S2_A1A2_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_4img  = cv2.imread(S2_doubleA1A3_4)
S2HSV_imgA1A3_4= cv2.cvtColor(S2_A1A3_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_54img  = cv2.imread(S2_doubleA1A3_54)
S2HSV_imgA1A3_54= cv2.cvtColor(S2_A1A3_54img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_4img  = cv2.imread(S2_doubleA1A4_4)
S2HSV_imgA1A4_4= cv2.cvtColor(S2_A1A4_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_4img  = cv2.imread(S2_doubleA1B1_4)
S2HSV_imgA1B1_4= cv2.cvtColor(S2_A1B1_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_4img  = cv2.imread(S2_doubleA1B2_4)
S2HSV_imgA1B2_4= cv2.cvtColor(S2_A1B2_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_4img  = cv2.imread(S2_doubleA1B3_4)
S2HSV_imgA1B3_4= cv2.cvtColor(S2_A1B3_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_4img  = cv2.imread(S2_doubleA1B4_4)
S2HSV_imgA1B4_4= cv2.cvtColor(S2_A1B4_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_4img  = cv2.imread(S2_doubleA1C1_4)
S2HSV_imgA1C1_4= cv2.cvtColor(S2_A1C1_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_4img  = cv2.imread(S2_doubleA1C2_4)
S2HSV_imgA1C2_4= cv2.cvtColor(S2_A1C2_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_4img  = cv2.imread(S2_doubleA1C3_4)
S2HSV_imgA1C3_4= cv2.cvtColor(S2_A1C3_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_4img  = cv2.imread(S2_doubleA1C4_4)
S2HSV_imgA1C4_4= cv2.cvtColor(S2_A1C4_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_4img  = cv2.imread(S2_doubleA1D2_4)
S2HSV_imgA1D2_4= cv2.cvtColor(S2_A1D2_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_4img  = cv2.imread(S2_doubleA1D3_4)
S2HSV_imgA1D3_4= cv2.cvtColor(S2_A1D3_4img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_4img  = cv2.imread(S2_doubleA1D4_4)
S2HSV_imgA1D4_4= cv2.cvtColor(S2_A1D4_4img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 5

# %%
S2_A1A1_5img  = cv2.imread(S2_doubleA1A1_5)
S2HSV_imgA1A1_5= cv2.cvtColor(S2_A1A1_5img, cv2.COLOR_BGR2HSV)

# %%
S2A1A2_5img  = cv2.imread(S2_doubleA1A2_5)
S2HSV_imgA1A2_5= cv2.cvtColor(S2_A1A2_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_5img  = cv2.imread(S2_doubleA1A3_5)
S2HSV_imgA1A3_5= cv2.cvtColor(S2_A1A3_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_55img  = cv2.imread(S2_doubleA1A3_55)
S2HSV_imgA1A3_55= cv2.cvtColor(S2_A1A3_55img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_5img  = cv2.imread(S2_doubleA1A4_5)
S2HSV_imgA1A4_5= cv2.cvtColor(S2_A1A4_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_5img  = cv2.imread(S2_doubleA1B1_5)
S2HSV_imgA1B1_5= cv2.cvtColor(S2_A1B1_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_5img  = cv2.imread(S2_doubleA1B2_5)
S2HSV_imgA1B2_5= cv2.cvtColor(S2_A1B2_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_5img  = cv2.imread(S2_doubleA1B3_5)
S2HSV_imgA1B3_5= cv2.cvtColor(S2_A1B3_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_5img  = cv2.imread(S2_doubleA1B4_5)
S2HSV_imgA1B4_5= cv2.cvtColor(S2_A1B4_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_5img  = cv2.imread(S2_doubleA1C1_5)
S2HSV_imgA1C1_5= cv2.cvtColor(S2_A1C1_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_5img  = cv2.imread(S2_doubleA1C2_5)
S2HSV_imgA1C2_5= cv2.cvtColor(S2_A1C2_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_5img  = cv2.imread(S2_doubleA1C3_5)
S2HSV_imgA1C3_5= cv2.cvtColor(S2_A1C3_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_5img  = cv2.imread(S2_doubleA1C4_5)
S2HSV_imgA1C4_5= cv2.cvtColor(S2A1C4_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_5img  = cv2.imread(S2_doubleA1D2_5)
S2HSV_imgA1D2_5= cv2.cvtColor(S2_A1D2_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_5img  = cv2.imread(S2_doubleA1D3_5)
S2HSV_imgA1D3_5= cv2.cvtColor(S2_A1D3_5img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_5img  = cv2.imread(S2_doubleA1D4_5)
S2HSV_imgA1D4_5= cv2.cvtColor(S2_A1D4_5img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 6

# %%
S2_A1A1_6img  = cv2.imread(S2_doubleA1A1_6)
S2HSV_imgA1A1_6= cv2.cvtColor(S2_A1A1_img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A2_6img  = cv2.imread(S2_doubleA1A2_6)
S2HSV_imgA1A2_6= cv2.cvtColor(S2_A1A2_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_6img  = cv2.imread(S2_doubleA1A3_6)
S2HSV_imgA1A3_6= cv2.cvtColor(S2_A1A3_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_56img  = cv2.imread(S2_doubleA1A3_56)
S2HSV_imgA1A3_56= cv2.cvtColor(S2_A1A3_56img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_6img  = cv2.imread(S2_doubleA1A4_)
S2HSV_imgA1A4_6= cv2.cvtColor(S2_A1A4_img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_6img  = cv2.imread(S2_doubleA1B1_6)
S2HSV_imgA1B1_6= cv2.cvtColor(S2_A1B1_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_6img  = cv2.imread(S2_doubleA1B2_6)
S2HSV_imgA1B2_6= cv2.cvtColor(S2_A1B2_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_6img  = cv2.imread(S2_doubleA1B3_6)
S2HSV_imgA1B3_6= cv2.cvtColor(S2_A1B3_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_6img  = cv2.imread(S2_doubleA1B4_6)
S2HSV_imgA1B4_6= cv2.cvtColor(S2_A1B4_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_6img  = cv2.imread(S2_doubleA1C1_6)
S2HSV_imgA1C1_6= cv2.cvtColor(S2_A1C1_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_6img  = cv2.imread(S2_doubleA1C2_6)
S2HSV_imgA1C2_6= cv2.cvtColor(S2_A1C2_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_6img  = cv2.imread(S2_doubleA1C3_6)
S2HSV_imgA1C3_6= cv2.cvtColor(S2_A1C3_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_6img  = cv2.imread(S2_doubleA1C4_)
S2HSV_imgA1C4_6= cv2.cvtColor(S2_A1C4_img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_6img  = cv2.imread(S2_doubleA1D2_6)
S2HSV_imgA1D2_6= cv2.cvtColor(S2_A1D2_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_6img  = cv2.imread(S2_doubleA1D3_6)
S2HSV_imgA1D3_6= cv2.cvtColor(S2_A1D3_6img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_6img  = cv2.imread(S2_doubleA1D4_6)
S2HSV_imgA1D4_6= cv2.cvtColor(S2_A1D4_6img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 7

# %%
S2_A1A1_7img  = cv2.imread(S2_doubleA1A1_7)
S2HSV_imgA1A1_7= cv2.cvtColor(S2_A1A1_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A2_7img  = cv2.imread(S2_doubleA1A2_7)
S2HSV_imgA1A2_7= cv2.cvtColor(S2_A1A2_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_7img  = cv2.imread(S2_doubleA1A3_)
S2HSV_imgA1A3_7= cv2.cvtColor(S2_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_57img  = cv2.imread(S2_doubleA1A3_57)
S2HSV_imgA1A3_57= cv2.cvtColor(S2_A1A3_57img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_7img  = cv2.imread(S2_doubleA1A4_7)
S2HSV_imgA1A4_7= cv2.cvtColor(S2_A1A4_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_7img  = cv2.imread(S2_doubleA1B1_7)
S2HSV_imgA1B1_7= cv2.cvtColor(S2_A1B1_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_7img  = cv2.imread(S2_doubleA1B2_7)
S2HSV_imgA1B2_7= cv2.cvtColor(S2_A1B2_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_7img  = cv2.imread(S2_doubleA1B3_7)
S2HSV_imgA1B3_7= cv2.cvtColor(S2_A1B3_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_7img  = cv2.imread(S2_doubleA1B4_7)
S2HSV_imgA1B4_7= cv2.cvtColor(S2_A1B4_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_7img  = cv2.imread(S2_doubleA1C1_7)
S2HSV_imgA1C1_7= cv2.cvtColor(S2_A1C1_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_7img  = cv2.imread(S2_doubleA1C2_7)
S2HSV_imgA1C2_7= cv2.cvtColor(S2_A1C2_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_7img  = cv2.imread(S2_doubleA1C3_7)
S2HSV_imgA1C3_7= cv2.cvtColor(S2_A1C3_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_7img  = cv2.imread(S2_doubleA1C4_7)
S2HSV_imgA1C4_7= cv2.cvtColor(S2_A1C4_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_7img  = cv2.imread(S2_doubleA1D2_7)
S2HSV_imgA1D2_7= cv2.cvtColor(S2_A1D2_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_7img  = cv2.imread(S2_doubleA1D3_7)
S2HSV_imgA1D3_7= cv2.cvtColor(S2_A1D3_7img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_7img  = cv2.imread(S2_doubleA1D4_7)
S2HSV_imgA1D4_7= cv2.cvtColor(S2_A1D4_7img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 8

# %%
S2_A1A1_8img  = cv2.imread(S2_doubleA1A1_8)
S2HSV_imgA1A1_8= cv2.cvtColor(S2_A1A1_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A2_8img  = cv2.imread(S2_doubleA1A2_8)
S2HSV_imgA1A2_8= cv2.cvtColor(S2_A1A2_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_8img  = cv2.imread(S2_doubleA1A3_8)
S2HSV_imgA1A3_8= cv2.cvtColor(S2_A1A3_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_58img  = cv2.imread(S2_doubleA1A3_58)
S2HSV_imgA1A3_58= cv2.cvtColor(S2_A1A3_58img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_8img  = cv2.imread(S2_doubleA1A4_8)
S2HSV_imgA1A4_8= cv2.cvtColor(S2_A1A4_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_8img  = cv2.imread(S2_doubleA1B1_8)
S2HSV_imgA1B1_8= cv2.cvtColor(S2_A1B1_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_8img  = cv2.imread(S2_doubleA1B2_8)
S2HSV_imgA1B2_8= cv2.cvtColor(S2_A1B2_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_8img  = cv2.imread(S2_doubleA1B3_8)
S2HSV_imgA1B3_8= cv2.cvtColor(S2_A1B3_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_8img  = cv2.imread(S2_doubleA1B4_8)
S2HSV_imgA1B4_8= cv2.cvtColor(S2_A1B4_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_8img  = cv2.imread(S2_doubleA1C1_8)
S2HSV_imgA1C1_8= cv2.cvtColor(S2_A1C1_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_8img  = cv2.imread(S2_doubleA1C2_8)
S2HSV_imgA1C2_8= cv2.cvtColor(S2_A1C2_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_8img  = cv2.imread(S2_doubleA1C3_8)
S2HSV_imgA1C3_8= cv2.cvtColor(S2_A1C3_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_8img  = cv2.imread(S2_doubleA1C4_8)
S2HSV_imgA1C4_8= cv2.cvtColor(S2_A1C4_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_8img  = cv2.imread(S2_doubleA1D2_8)
S2HSV_imgA1D2_8= cv2.cvtColor(S2_A1D2_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_8img  = cv2.imread(S2_doubleA1D3_8)
S2HSV_imgA1D3_8= cv2.cvtColor(S2_A1D3_8img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_8img  = cv2.imread(S2_doubleA1D4_8)
S2HSV_imgA1D4_8= cv2.cvtColor(S2_A1D4_8img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 9

# %%
S2_A1A1_9img  = cv2.imread(S2_doubleA1A1_9)
S2HSV_imgA1A1_9= cv2.cvtColor(S2_A1A1_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A2_9img  = cv2.imread(S2_doubleA1A2_9)
S2HSV_imgA1A2_9= cv2.cvtColor(S2_A1A2_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_9img  = cv2.imread(S2_doubleA1A3_9)
S2HSV_imgA1A3_9= cv2.cvtColor(S2_A1A3_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_59img  = cv2.imread(S2_doubleA1A3_59)
S2HSV_imgA1A3_59= cv2.cvtColor(S2_A1A3_59img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_9img  = cv2.imread(S2_doubleA1A4_9)
S2HSV_imgA1A4_9= cv2.cvtColor(S2_A1A4_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_9img  = cv2.imread(S2_doubleA1B1_9)
S2HSV_imgA1B1_9= cv2.cvtColor(S2_A1B1_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_9img  = cv2.imread(S2_doubleA1B2_9)
S2HSV_imgA1B2_9= cv2.cvtColor(S2_A1B2_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_9img  = cv2.imread(S2_doubleA1B3_9)
S2HSV_imgA1B3_9= cv2.cvtColor(S2_A1B3_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_9img  = cv2.imread(S2_doubleA1B4_9)
S2HSV_imgA1B4_9= cv2.cvtColor(S2_A1B4_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_9img  = cv2.imread(S2_doubleA1C1_9)
S2HSV_imgA1C1_9= cv2.cvtColor(S2_A1C1_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_9img  = cv2.imread(S2_doubleA1C2_9)
S2HSV_imgA1C2_9= cv2.cvtColor(S2_A1C2_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_9img  = cv2.imread(S2_doubleA1C3_9)
S2HSV_imgA1C3_9= cv2.cvtColor(S2_A1C3_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_9img  = cv2.imread(S2_doubleA1C4_9)
S2HSV_imgA1C4_9= cv2.cvtColor(S2_A1C4_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_9img  = cv2.imread(S2_doubleA1D2_9)
S2HSV_imgA1D2_9= cv2.cvtColor(S2_A1D2_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_9img  = cv2.imread(S2_doubleA1D3_9)
S2HSV_imgA1D3_9= cv2.cvtColor(S2_A1D3_9img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_9img  = cv2.imread(S2_doubleA1D4_9)
S2HSV_imgA1D4_9= cv2.cvtColor(S2_A1D4_9img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 10

# %%
S2_A1A1_10img  = cv2.imread(S2_doubleA1A1_10)
S2HSV_imgA1A1_10= cv2.cvtColor(S2_A1A1_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A2_10img  = cv2.imread(S2_doubleA1A2_10)
S2HSV_imgA1A2_10= cv2.cvtColor(S2_A1A2_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_10img  = cv2.imread(S2_doubleA1A3_10)
S2HSV_imgA1A3_10= cv2.cvtColor(S2_A1A3_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A3_510img  = cv2.imread(S2_doubleA1A3_510)
S2HSV_imgA1A3_510= cv2.cvtColor(S2_A1A3_510img, cv2.COLOR_BGR2HSV)

# %%
S2_A1A4_10img  = cv2.imread(S2_doubleA1A4_10)
S2HSV_imgA1A4_10= cv2.cvtColor(S2_A1A4_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B1_10img  = cv2.imread(S2_doubleA1B1_10)
S2HSV_imgA1B1_10= cv2.cvtColor(S2_A1B1_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B2_10img  = cv2.imread(S2_doubleA1B2_10)
S2HSV_imgA1B2_10= cv2.cvtColor(S2_A1B2_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B3_10img  = cv2.imread(S2_doubleA1B3_10)
S2HSV_imgA1B3_10= cv2.cvtColor(S2_A1B3_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1B4_10img  = cv2.imread(S2_doubleA1B4_10)
S2HSV_imgA1B4_10= cv2.cvtColor(S2_A1B4_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C1_10img  = cv2.imread(S2_doubleA1C1_10)
S2HSV_imgA1C1_10= cv2.cvtColor(S2_A1C1_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C2_10img  = cv2.imread(S2_doubleA1C2_10)
S2HSV_imgA1C2_10= cv2.cvtColor(S2_A1C2_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C3_10img  = cv2.imread(S2_doubleA1C3_10)
S2HSV_imgA1C3_10= cv2.cvtColor(S2_A1C3_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1C4_10img  = cv2.imread(S2_doubleA1C4_10)
S2HSV_imgA1C4_10= cv2.cvtColor(S2_A1C4_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D2_10img  = cv2.imread(S2_doubleA1D2_10)
S2HSV_imgA1D2_10= cv2.cvtColor(S2_A1D2_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D3_10img  = cv2.imread(S2_doubleA1D3_10)
S2HSV_imgA1D3_10= cv2.cvtColor(S2_A1D3_10img, cv2.COLOR_BGR2HSV)

# %%
S2_A1D4_10img  = cv2.imread(S2_doubleA1D4_10)
S2HSV_imgA1D4_10= cv2.cvtColor(S2_A1D4_10img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ##Set3

# %%
S3_A1A1_1img  = cv2.imread(S3_doubleA1A1_1)
S3HSV_imgA1A1_1= cv2.cvtColor(S3_A1A1_1img, cv2.COLOR_BGR2HSV)
plt.imshow(S3HSV_imgA1A1_1)

# %%
S3_A1A2_1img  = cv2.imread(S3_doubleA1A2_1)
S3HSV_imgA1A2_1= cv2.cvtColor(S3_A1A2_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_1img  = cv2.imread(S3_doubleA1A3_1)
S3HSV_imgA1A3_1= cv2.cvtColor(S3_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_51img  = cv2.imread(S3_doubleA1A3_51)
S3HSV_imgA1A3_51= cv2.cvtColor(S3_A1A3_51img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_1img  = cv2.imread(S3_doubleA1A4_1)
S3HSV_imgA1A4_1= cv2.cvtColor(S3_A1A4_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_1img  = cv2.imread(S3_doubleA1B1_1)
S3HSV_imgA1B1_1= cv2.cvtColor(S3_A1B1_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_1img  = cv2.imread(S3_doubleA1B2_1)
S3HSV_imgA1B2_1= cv2.cvtColor(S3_A1B2_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_1img  = cv2.imread(S3_doubleA1B3_1)
S3HSV_imgA1B3_1= cv2.cvtColor(S3_A1B3_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_1img  = cv2.imread(S3_doubleA1B4_1)
S3HSV_imgA1B4_1= cv2.cvtColor(S3_A1B4_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_1img  = cv2.imread(S3_doubleA1C1_1)
S3HSV_imgA1C1_1= cv2.cvtColor(S3_A1C1_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_1img  = cv2.imread(S3_doubleA1C2_1)
S3HSV_imgA1C2_1= cv2.cvtColor(S3_A1C2_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_1img  = cv2.imread(S3_doubleA1C3_1)
S3HSV_imgA1C3_1= cv2.cvtColor(S3_A1C3_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_1img  = cv2.imread(S3_doubleA1C4_1)
S3HSV_imgA1C4_1= cv2.cvtColor(S3_A1C4_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_1img  = cv2.imread(S3_doubleA1D2_1)
S3HSV_imgA1D2_1= cv2.cvtColor(S3_A1D2_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_1img  = cv2.imread(S3_doubleA1D3_1)
S3HSV_imgA1D3_1= cv2.cvtColor(S3_A1D3_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_1img  = cv2.imread(S3_doubleA1D4_1)
S3HSV_imgA1D4_1= cv2.cvtColor(S3_A1D4_1img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 2

# %%
S3_A1A1_2img  = cv2.imread(S3_doubleA1A1_2)
S3HSV_imgA1A1_2= cv2.cvtColor(S3_A1A1_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A2_2img  = cv2.imread(S3_doubleA1A2_2)
S3HSV_imgA1A2_2= cv2.cvtColor(S3_A1A2_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_2img  = cv2.imread(S3_doubleA1A3_2)
S3HSV_imgA1A3_2= cv2.cvtColor(S3_A1A3_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_52img  = cv2.imread(S3_doubleA1A3_52)
S3HSV_imgA1A3_52= cv2.cvtColor(S3_A1A3_52img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_2img  = cv2.imread(S3_doubleA1A4_2)
S3HSV_imgA1A4_2= cv2.cvtColor(S3_A1A4_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_2img  = cv2.imread(S3_doubleA1B1_2)
S3HSV_imgA1B1_2= cv2.cvtColor(S3_A1B1_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_2img  = cv2.imread(S3_doubleA1B2_2)
S3HSV_imgA1B2_2= cv2.cvtColor(S3_A1B2_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_2img  = cv2.imread(S3_doubleA1B3_2)
S3HSV_imgA1B3_2= cv2.cvtColor(S3_A1B3_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_2img  = cv2.imread(S3_doubleA1B4_2)
S3HSV_imgA1B4_2= cv2.cvtColor(S3_A1B4_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_2img  = cv2.imread(S3_doubleA1C1_2)
S3HSV_imgA1C1_2= cv2.cvtColor(S3_A1C1_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_2img  = cv2.imread(S3_doubleA1C2_2)
S3HSV_imgA1C2_2= cv2.cvtColor(S3_A1C2_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_2img  = cv2.imread(S3_doubleA1C3_2)
S3HSV_imgA1C3_2= cv2.cvtColor(S3_A1C3_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_2img  = cv2.imread(S3_doubleA1C4_2)
SHSV_imgA1C4_2= cv2.cvtColor(S3_A1C4_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_2img  = cv2.imread(S3_doubleA1D2_2)
S3HSV_imgA1D2_2= cv2.cvtColor(S3_A1D2_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_2img  = cv2.imread(S3_doubleA1D3_2)
S3HSV_imgA1D3_2= cv2.cvtColor(S3_A1D3_2img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_2img  = cv2.imread(S3_doubleA1D4_2)
S3HSV_imgA1D4_2= cv2.cvtColor(S3_A1D4_2img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 3

# %%
S3_A1A1_3img  = cv2.imread(S3_doubleA1A1_3)
S3HSV_imgA1A1_3= cv2.cvtColor(S3_A1A1_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A2_3img  = cv2.imread(S3_doubleA1A2_3)
S3HSV_imgA1A2_3= cv2.cvtColor(S3_A1A2_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_3img  = cv2.imread(S3_doubleA1A3_3)
S3HSV_imgA1A3_3= cv2.cvtColor(S3_A1A3_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_53img  = cv2.imread(S3_doubleA1A3_53)
S3HSV_imgA1A3_53= cv2.cvtColor(S3_A1A3_53img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_3img  = cv2.imread(S3_doubleA1A4_3)
S3HSV_imgA1A4_3= cv2.cvtColor(S3_A1A4_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_3img  = cv2.imread(S3_doubleA1B1_3)
S3HSV_imgA1B1_3= cv2.cvtColor(S3_A1B1_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_3img  = cv2.imread(S3_doubleA1B2_3)
S3HSV_imgA1B2_3= cv2.cvtColor(S3_A1B2_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_3img  = cv2.imread(S3_doubleA1B3_3)
S3HSV_imgA1B3_3= cv2.cvtColor(S3_A1B3_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_3img  = cv2.imread(S3_doubleA1B4_3)
S3HSV_imgA1B4_3= cv2.cvtColor(S3_A1B4_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_3img  = cv2.imread(S3_doubleA1C1_3)
S3HSV_imgA1C1_3= cv2.cvtColor(S3_A1C1_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_3img  = cv2.imread(S3_doubleA1C2_3)
S3HSV_imgA1C2_3= cv2.cvtColor(S3_A1C2_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_3img  = cv2.imread(S3_doubleA1C3_3)
S3HSV_imgA1C3_3= cv2.cvtColor(S3_A1C3_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_3img  = cv2.imread(S3_doubleA1C4_3)
S3HSV_imgA1C4_3= cv2.cvtColor(S3_A1C4_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_3img  = cv2.imread(S3_doubleA1D2_3)
S3HSV_imgA1D2_3= cv2.cvtColor(S3_A1D2_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_3img  = cv2.imread(S3_doubleA1D3_3)
S3HSV_imgA1D3_3= cv2.cvtColor(S3_A1D3_3img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_3img  = cv2.imread(S3_doubleA1D4_3)
S3HSV_imgA1D4_3= cv2.cvtColor(S3_A1D4_3img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 4

# %%
S3_A1A1_4img  = cv2.imread(S3_doubleA1A1_4)
S3HSV_imgA1A1_4= cv2.cvtColor(S3_A1A1_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A2_4img  = cv2.imread(S3_doubleA1A2_4)
S3SV_imgA1A2_4= cv2.cvtColor(S3_A1A2_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_4img  = cv2.imread(S3_doubleA1A3_4)
S3HSV_imgA1A3_4= cv2.cvtColor(S3_A1A3_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_54img  = cv2.imread(S3_doubleA1A3_54)
S3HSV_imgA1A3_54= cv2.cvtColor(S3_A1A3_54img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_4img  = cv2.imread(S3_doubleA1A4_4)
S3HSV_imgA1A4_4= cv2.cvtColor(S3_A1A4_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_4img  = cv2.imread(S3_doubleA1B1_4)
S3HSV_imgA1B1_4= cv2.cvtColor(S3_A1B1_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_4img  = cv2.imread(S3_doubleA1B2_4)
S3HSV_imgA1B2_4= cv2.cvtColor(S3_A1B2_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_4img  = cv2.imread(S3_doubleA1B3_4)
S3HSV_imgA1B3_4= cv2.cvtColor(S3_A1B3_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_4img  = cv2.imread(S3_doubleA1B4_4)
S3HSV_imgA1B4_4= cv2.cvtColor(S3_A1B4_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_4img  = cv2.imread(S3_doubleA1C1_4)
S3HSV_imgA1C1_4= cv2.cvtColor(S3_A1C1_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_4img  = cv2.imread(S3_doubleA1C2_4)
S3HSV_imgA1C2_4= cv2.cvtColor(S3_A1C2_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_4img  = cv2.imread(S3_doubleA1C3_4)
S3HSV_imgA1C3_4= cv2.cvtColor(S3_A1C3_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_4img  = cv2.imread(S3_doubleA1C4_4)
S3HSV_imgA1C4_4= cv2.cvtColor(S3_A1C4_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_4img  = cv2.imread(S3_doubleA1D2_4)
S3HSV_imgA1D2_4= cv2.cvtColor(S3_A1D2_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_4img  = cv2.imread(S3_doubleA1D3_4)
S3HSV_imgA1D3_4= cv2.cvtColor(S3_A1D3_4img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_4img  = cv2.imread(S3_doubleA1D4_4)
S3HSV_imgA1D4_4= cv2.cvtColor(S3_A1D4_4img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 5

# %%
S3_A1A1_5img  = cv2.imread(S3_doubleA1A1_5)
S3HSV_imgA1A1_5= cv2.cvtColor(S3_A1A1_5img, cv2.COLOR_BGR2HSV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17fa0009218b> in <module>()
# ----> 1 S3_A1A1_5img  = cv2.imread(S3_doubleA1A1_5)
#       2 S3HSV_imgA1A1_5= cv2.cvtColor(S3_A1A1_5img, cv2.COLOR_BGR2HSV)
#
# NameError: name 'cv2' is not defined

# %%
S3_A1A2_5img  = cv2.imread(S3_doubleA1A2_5)
SHSV_imgA1A2_5= cv2.cvtColor(S3_A1A2_5img, cv2.COLOR_BGR2HSV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5e153dfdadb1> in <module>()
# ----> 1 S3_A1A2_5img  = cv2.imread(S3_doubleA1A2_5)
#       2 SHSV_imgA1A2_5= cv2.cvtColor(S3_A1A2_5img, cv2.COLOR_BGR2HSV)
#
# NameError: name 'cv2' is not defined

# %%
S3_A1A3_5img  = cv2.imread(S3_doubleA1A3_5)
S3HSV_imgA1A3_5= cv2.cvtColor(S3_A1A3_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_55img  = cv2.imread(S3_doubleA1A3_55)
S3HSV_imgA1A3_55= cv2.cvtColor(S3_A1A3_55img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_5img  = cv2.imread(S3_doubleA1A4_5)
S3HSV_imgA1A4_5= cv2.cvtColor(S3_A1A4_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_5img  = cv2.imread(S3_doubleA1B1_5)
S3HSV_imgA1B1_5= cv2.cvtColor(S3_A1B1_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_5img  = cv2.imread(S3_doubleA1B2_5)
S3HSV_imgA1B2_5= cv2.cvtColor(S3_A1B2_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_5img  = cv2.imread(S3_doubleA1B3_5)
S3HSV_imgA1B3_5= cv2.cvtColor(S3_A1B3_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_5img  = cv2.imread(S3_doubleA1B4_5)
S3HSV_imgA1B4_5= cv2.cvtColor(S3_A1B4_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_5img  = cv2.imread(S3_doubleA1C1_5)
S3HSV_imgA1C1_5= cv2.cvtColor(S3_A1C1_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_5img  = cv2.imread(S3_doubleA1C2_5)
S3HSV_imgA1C2_5= cv2.cvtColor(S3_A1C2_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_5img  = cv2.imread(S3_doubleA1C3_5)
S3HSV_imgA1C3_5= cv2.cvtColor(S3_A1C3_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_5img  = cv2.imread(S3_doubleA1C4_5)
S3HSV_imgA1C4_5= cv2.cvtColor(S3_A1C4_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_5img  = cv2.imread(S3_doubleA1D2_5)
S3HSV_imgA1D2_5= cv2.cvtColor(S3_A1D2_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_5img  = cv2.imread(S3_doubleA1D3_5)
S3HSV_imgA1D3_5= cv2.cvtColor(S3_A1D3_5img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_5img  = cv2.imread(S3_doubleA1D4_5)
S3HSV_imgA1D4_5= cv2.cvtColor(S3_A1D4_5img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 6

# %%
S3_A1A1_6img  = cv2.imread(S3_doubleA1A1_6)
S3HSV_imgA1A1_6= cv2.cvtColor(S3_A1A1_img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A2_6img  = cv2.imread(S3_doubleA1A2_6)
S3HSV_imgA1A2_6= cv2.cvtColor(S3_A1A2_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_6img  = cv2.imread(S3_doubleA1A3_6)
S3HSV_imgA1A3_6= cv2.cvtColor(S3_A1A3_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_56img  = cv2.imread(S3_doubleA1A3_56)
S3HSV_imgA1A3_56= cv2.cvtColor(S3_A1A3_56img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_6img  = cv2.imread(S3_doubleA1A4_)
S3HSV_imgA1A4_6= cv2.cvtColor(S3_A1A4_img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_6img  = cv2.imread(S3_doubleA1B1_6)
S3HSV_imgA1B1_6= cv2.cvtColor(S3_A1B1_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_6img  = cv2.imread(S3_doubleA1B2_6)
S3HSV_imgA1B2_6= cv2.cvtColor(S3_A1B2_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_6img  = cv2.imread(S3_doubleA1B3_6)
S3HSV_imgA1B3_6= cv2.cvtColor(S3_A1B3_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_6img  = cv2.imread(S3_doubleA1B4_6)
S3HSV_imgA1B4_6= cv2.cvtColor(S3_A1B4_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_6img  = cv2.imread(S3_doubleA1C1_6)
S3HSV_imgA1C1_6= cv2.cvtColor(S3_A1C1_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_6img  = cv2.imread(S3_doubleA1C2_6)
S3HSV_imgA1C2_6= cv2.cvtColor(S3_A1C2_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_6img  = cv2.imread(S3_doubleA1C3_6)
S3HSV_imgA1C3_6= cv2.cvtColor(S3_A1C3_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_6img  = cv2.imread(S3_doubleA1C4_)
S3HSV_imgA1C4_6= cv2.cvtColor(S3_A1C4_img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_6img  = cv2.imread(S3_doubleA1D2_6)
S3HSV_imgA1D2_6= cv2.cvtColor(S3_A1D2_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_6img  = cv2.imread(S3_doubleA1D3_6)
S3HSV_imgA1D3_6= cv2.cvtColor(S3_A1D3_6img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_6img  = cv2.imread(S3_doubleA1D4_6)
S3HSV_imgA1D4_6= cv2.cvtColor(S3_A1D4_6img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 7

# %%
S3_A1A1_7img  = cv2.imread(S3_doubleA1A1_7)
S3HSV_imgA1A1_7= cv2.cvtColor(S3_A1A1_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A2_7img  = cv2.imread(S3_doubleA1A2_7)
S3HSV_imgA1A2_7= cv2.cvtColor(S3_A1A2_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_7img  = cv2.imread(S3_doubleA1A3_)
S3HSV_imgA1A3_7= cv2.cvtColor(S3_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_57img  = cv2.imread(S3_doubleA1A3_57)
S3HSV_imgA1A3_57= cv2.cvtColor(S3_A1A3_57img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_7img  = cv2.imread(S3_doubleA1A4_7)
S3HSV_imgA1A4_7= cv2.cvtColor(S3_A1A4_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_7img  = cv2.imread(S3_doubleA1B1_7)
S3HSV_imgA1B1_7= cv2.cvtColor(S3_A1B1_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_7img  = cv2.imread(S3_doubleA1B2_7)
S3HSV_imgA1B2_7= cv2.cvtColor(S3_A1B2_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_7img  = cv2.imread(S3_doubleA1B3_7)
S3HSV_imgA1B3_7= cv2.cvtColor(S3_A1B3_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_7img  = cv2.imread(S3_doubleA1B4_7)
S3HSV_imgA1B4_7= cv2.cvtColor(S3_A1B4_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_7img  = cv2.imread(S3_doubleA1C1_7)
S3HSV_imgA1C1_7= cv2.cvtColor(S3_A1C1_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_7img  = cv2.imread(S3_doubleA1C2_7)
S3HSV_imgA1C2_7= cv2.cvtColor(S3_A1C2_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_7img  = cv2.imread(S3_doubleA1C3_7)
S3HSV_imgA1C3_7= cv2.cvtColor(S3_A1C3_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_7img  = cv2.imread(S3_doubleA1C4_7)
S3HSV_imgA1C4_7= cv2.cvtColor(S3_A1C4_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_7img  = cv2.imread(S3_doubleA1D2_7)
S3HSV_imgA1D2_7= cv2.cvtColor(S3_A1D2_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_7img  = cv2.imread(S3_doubleA1D3_7)
S3HSV_imgA1D3_7= cv2.cvtColor(S3_A1D3_7img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_7img  = cv2.imread(S3_doubleA1D4_7)
S3HSV_imgA1D4_7= cv2.cvtColor(S3_A1D4_7img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 8

# %%
S3_A1A1_8img  = cv2.imread(S3_doubleA1A1_8)
S3HSV_imgA1A1_8= cv2.cvtColor(S3_A1A1_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A2_8img  = cv2.imread(S3_doubleA1A2_8)
S3HSV_imgA1A2_8= cv2.cvtColor(S3_A1A2_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_8img  = cv2.imread(S3_doubleA1A3_8)
S3HSV_imgA1A3_8= cv2.cvtColor(S3_A1A3_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_58img  = cv2.imread(S3_doubleA1A3_58)
S3HSV_imgA1A3_58= cv2.cvtColor(S3_A1A3_58img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_8img  = cv2.imread(S3_doubleA1A4_8)
S3HSV_imgA1A4_8= cv2.cvtColor(S3_A1A4_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_8img  = cv2.imread(S3_doubleA1B1_8)
S3HSV_imgA1B1_8= cv2.cvtColor(S3_A1B1_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_8img  = cv2.imread(S3_doubleA1B2_8)
S3HSV_imgA1B2_8= cv2.cvtColor(S3_A1B2_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_8img  = cv2.imread(S3_doubleA1B3_8)
S3HSV_imgA1B3_8= cv2.cvtColor(S3_A1B3_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_8img  = cv2.imread(S3_doubleA1B4_8)
S3HSV_imgA1B4_8= cv2.cvtColor(S3_A1B4_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_8img  = cv2.imread(S3_doubleA1C1_8)
S3HSV_imgA1C1_8= cv2.cvtColor(S3_A1C1_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_8img  = cv2.imread(S3_doubleA1C2_8)
S3HSV_imgA1C2_8= cv2.cvtColor(S3_A1C2_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_8img  = cv2.imread(S3_doubleA1C3_8)
S3HSV_imgA1C3_8= cv2.cvtColor(S3_A1C3_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_8img  = cv2.imread(S3_doubleA1C4_8)
S3HSV_imgA1C4_8= cv2.cvtColor(S3_A1C4_8img, cv2.COLOR_BGR2HSV)

# %%
S3A1D2_8img  = cv2.imread(S3_doubleA1D2_8)
S3HSV_imgA1D2_8= cv2.cvtColor(S3_A1D2_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_8img  = cv2.imread(S3_doubleA1D3_8)
S3HSV_imgA1D3_8= cv2.cvtColor(S3_A1D3_8img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_8img  = cv2.imread(S3_doubleA1D4_8)
S3HSV_imgA1D4_8= cv2.cvtColor(S3_A1D4_8img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 9

# %%
S3_A1A1_9img  = cv2.imread(S3_doubleA1A1_9)
S3HSV_imgA1A1_9= cv2.cvtColor(S3_A1A1_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A2_9img  = cv2.imread(S3_doubleA1A2_9)
S3HSV_imgA1A2_9= cv2.cvtColor(S3_A1A2_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_9img  = cv2.imread(S3_doubleA1A3_9)
S3HSV_imgA1A3_9= cv2.cvtColor(S3_A1A3_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_59img  = cv2.imread(S3_doubleA1A3_59)
S3HSV_imgA1A3_59= cv2.cvtColor(S3_A1A3_59img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_9img  = cv2.imread(S3_doubleA1A4_9)
S3HSV_imgA1A4_9= cv2.cvtColor(S3_A1A4_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_9img  = cv2.imread(S3_doubleA1B1_9)
S3HSV_imgA1B1_9= cv2.cvtColor(S3_A1B1_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_9img  = cv2.imread(S3_doubleA1B2_9)
S3HSV_imgA1B2_9= cv2.cvtColor(S3_A1B2_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_9img  = cv2.imread(S3_doubleA1B3_9)
S3HSV_imgA1B3_9= cv2.cvtColor(S3_A1B3_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_9img  = cv2.imread(S3_doubleA1B4_9)
S3HSV_imgA1B4_9= cv2.cvtColor(S3_A1B4_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_9img  = cv2.imread(S3_doubleA1C1_9)
S3HSV_imgA1C1_9= cv2.cvtColor(S3_A1C1_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_9img  = cv2.imread(S3_doubleA1C2_9)
S3HSV_imgA1C2_9= cv2.cvtColor(S3_A1C2_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_9img  = cv2.imread(S3_doubleA1C3_9)
S3HSV_imgA1C3_9= cv2.cvtColor(S3_A1C3_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_9img  = cv2.imread(S3_doubleA1C4_9)
S3HSV_imgA1C4_9= cv2.cvtColor(S3_A1C4_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_9img  = cv2.imread(S3_doubleA1D2_9)
S3HSV_imgA1D2_9= cv2.cvtColor(S3_A1D2_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_9img  = cv2.imread(S3_doubleA1D3_9)
S3HSV_imgA1D3_9= cv2.cvtColor(S3_A1D3_9img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_9img  = cv2.imread(S3_doubleA1D4_9)
S3HSV_imgA1D4_9= cv2.cvtColor(S3_A1D4_9img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 10

# %%
S3_A1A1_10img  = cv2.imread(S3_doubleA1A1_10)
S3HSV_imgA1A1_10= cv2.cvtColor(S3_A1A1_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A2_10img  = cv2.imread(S3_doubleA1A2_10)
S3HSV_imgA1A2_10= cv2.cvtColor(S3_A1A2_10img, cv2.COLOR_BGR2HSV)

# %%
S_A1A3_10img  = cv2.imread(S3_doubleA1A3_10)
SHSV_imgA1A3_10= cv2.cvtColor(S3_A1A3_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A3_510img  = cv2.imread(S3_doubleA1A3_510)
S3HSV_imgA1A3_510= cv2.cvtColor(S3_A1A3_510img, cv2.COLOR_BGR2HSV)

# %%
S3_A1A4_10img  = cv2.imread(S3_doubleA1A4_10)
S3HSV_imgA1A4_10= cv2.cvtColor(S3_A1A4_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B1_10img  = cv2.imread(S3_doubleA1B1_10)
S3HSV_imgA1B1_10= cv2.cvtColor(S3_A1B1_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B2_10img  = cv2.imread(S3_doubleA1B2_10)
S3HSV_imgA1B2_10= cv2.cvtColor(S3_A1B2_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B3_10img  = cv2.imread(S3_doubleA1B3_10)
S3HSV_imgA1B3_10= cv2.cvtColor(S3_A1B3_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1B4_10img  = cv2.imread(S3_doubleA1B4_10)
S3HSV_imgA1B4_10= cv2.cvtColor(S3_A1B4_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C1_10img  = cv2.imread(S3_doubleA1C1_10)
S3HSV_imgA1C1_10= cv2.cvtColor(S3_A1C1_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C2_10img  = cv2.imread(S3_doubleA1C2_10)
S3HSV_imgA1C2_10= cv2.cvtColor(S3_A1C2_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C3_10img  = cv2.imread(S3_doubleA1C3_10)
S3HSV_imgA1C3_10= cv2.cvtColor(S3_A1C3_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1C4_10img  = cv2.imread(S3_doubleA1C4_10)
S3HSV_imgA1C4_10= cv2.cvtColor(S3_A1C4_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D2_10img  = cv2.imread(S3_doubleA1D2_10)
S3HSV_imgA1D2_10= cv2.cvtColor(S3_A1D2_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D3_10img  = cv2.imread(S3_doubleA1D3_10)
S3HSV_imgA1D3_10= cv2.cvtColor(S3_A1D3_10img, cv2.COLOR_BGR2HSV)

# %%
S3_A1D4_10img  = cv2.imread(S3_doubleA1D4_10)
S3HSV_imgA1D4_10= cv2.cvtColor(S3_A1D4_10img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ##Set4

# %%
S4_A1A1_1img  = cv2.imread(S4_doubleA1A1_1)
S4HSV_imgA1A1_1= cv2.cvtColor(S4_A1A1_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A2_1img  = cv2.imread(S4_doubleA1A2_1)
S4HSV_imgA1A2_1= cv2.cvtColor(S4_A1A2_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_1img  = cv2.imread(S4_doubleA1A3_1)
S4HSV_imgA1A3_1= cv2.cvtColor(S4_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_51img  = cv2.imread(S4_doubleA1A3_51)
S4HSV_imgA1A3_51= cv2.cvtColor(S4_A1A3_51img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_1img  = cv2.imread(S4_doubleA1A4_1)
S4HSV_imgA1A4_1= cv2.cvtColor(S4_A1A4_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_1img  = cv2.imread(S4_doubleA1B1_1)
S4HSV_imgA1B1_1= cv2.cvtColor(S4_A1B1_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_1img  = cv2.imread(S4_doubleA1B2_1)
S4HSV_imgA1B2_1= cv2.cvtColor(S4_A1B2_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_1img  = cv2.imread(S4_doubleA1B3_1)
S4HSV_imgA1B3_1= cv2.cvtColor(S4_A1B3_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_1img  = cv2.imread(S4_doubleA1B4_1)
S4HSV_imgA1B4_1= cv2.cvtColor(S4_A1B4_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_1img  = cv2.imread(S4_doubleA1C1_1)
S4HSV_imgA1C1_1= cv2.cvtColor(S4_A1C1_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_1img  = cv2.imread(S4_doubleA1C2_1)
S4HSV_imgA1C2_1= cv2.cvtColor(S4_A1C2_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_1img  = cv2.imread(S4_doubleA1C3_1)
S4HSV_imgA1C3_1= cv2.cvtColor(S4_A1C3_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_1img  = cv2.imread(S4_doubleA1C4_1)
S4HSV_imgA1C4_1= cv2.cvtColor(S4_A1C4_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_1img  = cv2.imread(S4_doubleA1D2_1)
S4HSV_imgA1D2_1= cv2.cvtColor(S4_A1D2_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_1img  = cv2.imread(S4_doubleA1D3_1)
S4HSV_imgA1D3_1= cv2.cvtColor(S4_A1D3_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_1img  = cv2.imread(S4_doubleA1D4_1)
S4HSV_imgA1D4_1= cv2.cvtColor(S4_A1D4_1img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 2

# %%
S4_A1A1_2img  = cv2.imread(S4_doubleA1A1_2)
S4HSV_imgA1A1_2= cv2.cvtColor(S4_A1A1_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A2_2img  = cv2.imread(S4_doubleA1A2_2)
S4HSV_imgA1A2_2= cv2.cvtColor(S4_A1A2_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_2img  = cv2.imread(S4_doubleA1A3_2)
S4HSV_imgA1A3_2= cv2.cvtColor(S4_A1A3_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_52img  = cv2.imread(S4_doubleA1A3_52)
S4HSV_imgA1A3_52= cv2.cvtColor(S4_A1A3_52img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_2img  = cv2.imread(S4_doubleA1A4_2)
S4HSV_imgA1A4_2= cv2.cvtColor(S4_A1A4_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_2img  = cv2.imread(S4_doubleA1B1_2)
S4HSV_imgA1B1_2= cv2.cvtColor(S4_A1B1_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_2img  = cv2.imread(S4_doubleA1B2_2)
S4HSV_imgA1B2_2= cv2.cvtColor(S4_A1B2_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_2img  = cv2.imread(S4_doubleA1B3_2)
S4HSV_imgA1B3_2= cv2.cvtColor(S4_A1B3_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_2img  = cv2.imread(S4_doubleA1B4_2)
S4HSV_imgA1B4_2= cv2.cvtColor(S4_A1B4_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_2img  = cv2.imread(S4_doubleA1C1_2)
S4HSV_imgA1C1_2= cv2.cvtColor(S4_A1C1_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_2img  = cv2.imread(S4_doubleA1C2_2)
S4HSV_imgA1C2_2= cv2.cvtColor(S4_A1C2_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_2img  = cv2.imread(S4_doubleA1C3_2)
S4HSV_imgA1C3_2= cv2.cvtColor(S4_A1C3_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_2img  = cv2.imread(S4_doubleA1C4_2)
S4HSV_imgA1C4_2= cv2.cvtColor(S4_A1C4_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_2img  = cv2.imread(S4_doubleA1D2_2)
S4HSV_imgA1D2_2= cv2.cvtColor(S4_A1D2_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_2img  = cv2.imread(S4doubleA1D3_2)
S4HSV_imgA1D3_2= cv2.cvtColor(S4_A1D3_2img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_2img  = cv2.imread(S4_doubleA1D4_2)
S4HSV_imgA1D4_2= cv2.cvtColor(S4_A1D4_2img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 3

# %%
S4_A1A1_3img  = cv2.imread(S4_doubleA1A1_3)
S4HSV_imgA1A1_3= cv2.cvtColor(S4_A1A1_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A2_3img  = cv2.imread(S4_doubleA1A2_3)
S4HSV_imgA1A2_3= cv2.cvtColor(S4_A1A2_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_3img  = cv2.imread(S4_doubleA1A3_3)
SHSV_imgA1A3_3= cv2.cvtColor(S4_A1A3_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_53img  = cv2.imread(S4_doubleA1A3_53)
S4HSV_imgA1A3_53= cv2.cvtColor(S4_A1A3_53img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_3img  = cv2.imread(S4_doubleA1A4_3)
S4HSV_imgA1A4_3= cv2.cvtColor(S4_A1A4_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_3img  = cv2.imread(S4_doubleA1B1_3)
S4HSV_imgA1B1_3= cv2.cvtColor(S4_A1B1_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_3img  = cv2.imread(S4_doubleA1B2_3)
S4HSV_imgA1B2_3= cv2.cvtColor(S4_A1B2_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_3img  = cv2.imread(S4_doubleA1B3_3)
S4HSV_imgA1B3_3= cv2.cvtColor(S4_A1B3_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_3img  = cv2.imread(S4_doubleA1B4_3)
S4HSV_imgA1B4_3= cv2.cvtColor(S4_A1B4_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_3img  = cv2.imread(S4_doubleA1C1_3)
S4HSV_imgA1C1_3= cv2.cvtColor(S4_A1C1_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_3img  = cv2.imread(S4_doubleA1C2_3)
S4HSV_imgA1C2_3= cv2.cvtColor(S4_A1C2_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_3img  = cv2.imread(S4_doubleA1C3_3)
S4HSV_imgA1C3_3= cv2.cvtColor(S4_A1C3_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_3img  = cv2.imread(S4_doubleA1C4_3)
S4HSV_imgA1C4_3= cv2.cvtColor(S4_A1C4_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_3img  = cv2.imread(S4_doubleA1D2_3)
S4HSV_imgA1D2_3= cv2.cvtColor(S4_A1D2_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_3img  = cv2.imread(S4_doubleA1D3_3)
S4HSV_imgA1D3_3= cv2.cvtColor(S4_A1D3_3img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_3img  = cv2.imread(S4_doubleA1D4_3)
S4HSV_imgA1D4_3= cv2.cvtColor(S4_A1D4_3img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 4

# %%
S4_A1A1_4img  = cv2.imread(S4_doubleA1A1_4)
S4HSV_imgA1A1_4= cv2.cvtColor(S4_A1A1_4img, cv2.COLOR_BGR2HSV)

# %%
S4A1A2_4img  = cv2.imread(S4_doubleA1A2_4)
S4HSV_imgA1A2_4= cv2.cvtColor(S4_A1A2_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_4img  = cv2.imread(S4_doubleA1A3_4)
S4HSV_imgA1A3_4= cv2.cvtColor(S4_A1A3_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_54img  = cv2.imread(S4_doubleA1A3_54)
S4HSV_imgA1A3_54= cv2.cvtColor(S4_A1A3_54img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_4img  = cv2.imread(S4_doubleA1A4_4)
S4HSV_imgA1A4_4= cv2.cvtColor(S4_A1A4_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_4img  = cv2.imread(S4doubleA1B1_4)
S4HSV_imgA1B1_4= cv2.cvtColor(S4_A1B1_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_4img  = cv2.imread(S4_doubleA1B2_4)
S4HSV_imgA1B2_4= cv2.cvtColor(S4_A1B2_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_4img  = cv2.imread(S4_doubleA1B3_4)
S4HSV_imgA1B3_4= cv2.cvtColor(S4_A1B3_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_4img  = cv2.imread(S4_doubleA1B4_4)
S4HSV_imgA1B4_4= cv2.cvtColor(S4_A1B4_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_4img  = cv2.imread(S4_doubleA1C1_4)
S4HSV_imgA1C1_4= cv2.cvtColor(S4_A1C1_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_4img  = cv2.imread(S4_doubleA1C2_4)
S4HSV_imgA1C2_4= cv2.cvtColor(S4_A1C2_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_4img  = cv2.imread(S4_doubleA1C3_4)
S4HSV_imgA1C3_4= cv2.cvtColor(S4_A1C3_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_4img  = cv2.imread(S4_doubleA1C4_4)
S4HSV_imgA1C4_4= cv2.cvtColor(S4_A1C4_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_4img  = cv2.imread(S4_doubleA1D2_4)
S4HSV_imgA1D2_4= cv2.cvtColor(S4_A1D2_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_4img  = cv2.imread(S4_doubleA1D3_4)
S4HSV_imgA1D3_4= cv2.cvtColor(S4_A1D3_4img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_4img  = cv2.imread(S4_doubleA1D4_4)
S4HSV_imgA1D4_4= cv2.cvtColor(S4_A1D4_4img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 5

# %%
S4_A1A1_5img  = cv2.imread(S4_doubleA1A1_5)
S4HSV_imgA1A1_5= cv2.cvtColor(S4_A1A1_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A2_5img  = cv2.imread(S4_doubleA1A2_5)
SHSV_imgA1A2_5= cv2.cvtColor(S4_A1A2_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_5img  = cv2.imread(S4_doubleA1A3_5)
S4HSV_imgA1A3_5= cv2.cvtColor(S4_A1A3_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_55img  = cv2.imread(S4_doubleA1A3_55)
S4HSV_imgA1A3_55= cv2.cvtColor(S4_A1A3_55img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_5img  = cv2.imread(S4_doubleA1A4_5)
S4HSV_imgA1A4_5= cv2.cvtColor(S4_A1A4_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_5img  = cv2.imread(S4_doubleA1B1_5)
S4HSV_imgA1B1_5= cv2.cvtColor(S4_A1B1_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_5img  = cv2.imread(S4_doubleA1B2_5)
S4HSV_imgA1B2_5= cv2.cvtColor(S4_A1B2_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_5img  = cv2.imread(S4_doubleA1B3_5)
S4HSV_imgA1B3_5= cv2.cvtColor(S4_A1B3_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_5img  = cv2.imread(S4_doubleA1B4_5)
S4HSV_imgA1B4_5= cv2.cvtColor(S4_A1B4_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_5img  = cv2.imread(S4_doubleA1C1_5)
S4HSV_imgA1C1_5= cv2.cvtColor(S4_A1C1_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_5img  = cv2.imread(S4_doubleA1C2_5)
S4HSV_imgA1C2_5= cv2.cvtColor(S4_A1C2_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_5img  = cv2.imread(S4_doubleA1C3_5)
S4HSV_imgA1C3_5= cv2.cvtColor(S4_A1C3_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_5img  = cv2.imread(S4_doubleA1C4_5)
S4HSV_imgA1C4_5= cv2.cvtColor(S4_A1C4_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_5img  = cv2.imread(S4_doubleA1D2_5)
S4HSV_imgA1D2_5= cv2.cvtColor(S4_A1D2_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_5img  = cv2.imread(S4_doubleA1D3_5)
S4HSV_imgA1D3_5= cv2.cvtColor(S4_A1D3_5img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_5img  = cv2.imread(S4_doubleA1D4_5)
S4HSV_imgA1D4_5= cv2.cvtColor(S4_A1D4_5img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 6

# %%
S4_A1A1_6img  = cv2.imread(S4_doubleA1A1_6)
S4HSV_imgA1A1_6= cv2.cvtColor(S4A1A1_img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A2_6img  = cv2.imread(S4_doubleA1A2_6)
S4HSV_imgA1A2_6= cv2.cvtColor(S4_A1A2_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_6img  = cv2.imread(S4_doubleA1A3_6)
S4HSV_imgA1A3_6= cv2.cvtColor(S4_A1A3_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_56img  = cv2.imread(S4_doubleA1A3_56)
S4HSV_imgA1A3_56= cv2.cvtColor(S4_A1A3_56img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_6img  = cv2.imread(S4_doubleA1A4_)
S4HSV_imgA1A4_6= cv2.cvtColor(S4_A1A4_img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_6img  = cv2.imread(S4_doubleA1B1_6)
S4HSV_imgA1B1_6= cv2.cvtColor(S4_A1B1_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_6img  = cv2.imread(S4_doubleA1B2_6)
S4HSV_imgA1B2_6= cv2.cvtColor(S4_A1B2_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_6img  = cv2.imread(S4_doubleA1B3_6)
S4HSV_imgA1B3_6= cv2.cvtColor(S4_A1B3_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_6img  = cv2.imread(S4_doubleA1B4_6)
S4HSV_imgA1B4_6= cv2.cvtColor(S4_A1B4_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_6img  = cv2.imread(S4_doubleA1C1_6)
S4HSV_imgA1C1_6= cv2.cvtColor(S4_A1C1_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_6img  = cv2.imread(S4_doubleA1C2_6)
S4HSV_imgA1C2_6= cv2.cvtColor(S4_A1C2_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_6img  = cv2.imread(S4_doubleA1C3_6)
S4HSV_imgA1C3_6= cv2.cvtColor(S4_A1C3_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_6img  = cv2.imread(S4_doubleA1C4_)
S4HSV_imgA1C4_6= cv2.cvtColor(S4_A1C4_img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_6img  = cv2.imread(S4_doubleA1D2_6)
S4HSV_imgA1D2_6= cv2.cvtColor(S4_A1D2_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_6img  = cv2.imread(S4_doubleA1D3_6)
S4HSV_imgA1D3_6= cv2.cvtColor(S4_A1D3_6img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_6img  = cv2.imread(S4_doubleA1D4_6)
S4HSV_imgA1D4_6= cv2.cvtColor(S4_A1D4_6img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 7

# %%
S4_A1A1_7img  = cv2.imread(S4_doubleA1A1_7)
S4HSV_imgA1A1_7= cv2.cvtColor(S4_A1A1_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A2_7img  = cv2.imread(S4_doubleA1A2_7)
S4HSV_imgA1A2_7= cv2.cvtColor(S4_A1A2_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_7img  = cv2.imread(S4_doubleA1A3_)
S4HSV_imgA1A3_7= cv2.cvtColor(S4_A1A3_1img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_57img  = cv2.imread(S4_doubleA1A3_57)
S4HSV_imgA1A3_57= cv2.cvtColor(S4_A1A3_57img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_7img  = cv2.imread(S4_doubleA1A4_7)
S4HSV_imgA1A4_7= cv2.cvtColor(S4_A1A4_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_7img  = cv2.imread(S4_doubleA1B1_7)
S4HSV_imgA1B1_7= cv2.cvtColor(S4_A1B1_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_7img  = cv2.imread(S4_doubleA1B2_7)
S4HSV_imgA1B2_7= cv2.cvtColor(S4_A1B2_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_7img  = cv2.imread(S4_doubleA1B3_7)
S4HSV_imgA1B3_7= cv2.cvtColor(S4_A1B3_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_7img  = cv2.imread(S4_doubleA1B4_7)
S4HSV_imgA1B4_7= cv2.cvtColor(S4_A1B4_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_7img  = cv2.imread(S4_doubleA1C1_7)
S4HSV_imgA1C1_7= cv2.cvtColor(S4_A1C1_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_7img  = cv2.imread(S4_doubleA1C2_7)
S4HSV_imgA1C2_7= cv2.cvtColor(S4

# %%
S4_A1C3_7img  = cv2.imread(S4_doubleA1C3_7)
S4HSV_imgA1C3_7= cv2.cvtColor(S4_A1C3_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_7img  = cv2.imread(S4_doubleA1C4_7)
S4HSV_imgA1C4_7= cv2.cvtColor(S4_A1C4_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_7img  = cv2.imread(S4_doubleA1D2_7)
S4HSV_imgA1D2_7= cv2.cvtColor(S4_A1D2_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_7img  = cv2.imread(S4_doubleA1D3_7)
S4HSV_imgA1D3_7= cv2.cvtColor(S4_A1D3_7img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_7img  = cv2.imread(S4_doubleA1D4_7)
S4HSV_imgA1D4_7= cv2.cvtColor(S4_A1D4_7img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 8

# %%
S4_A1A1_8img  = cv2.imread(S4_doubleA1A1_8)
S4HSV_imgA1A1_8= cv2.cvtColor(S4_A1A1_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A2_8img  = cv2.imread(S4_doubleA1A2_8)
S4HSV_imgA1A2_8= cv2.cvtColor(S4_A1A2_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_8img  = cv2.imread(S4_doubleA1A3_8)
S4HSV_imgA1A3_8= cv2.cvtColor(S4_A1A3_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_58img  = cv2.imread(S4_doubleA1A3_58)
S4HSV_imgA1A3_58= cv2.cvtColor(S4_A1A3_58img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_8img  = cv2.imread(S4_doubleA1A4_8)
S4HSV_imgA1A4_8= cv2.cvtColor(S4_A1A4_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_8img  = cv2.imread(S4_doubleA1B1_8)
S4HSV_imgA1B1_8= cv2.cvtColor(S4_A1B1_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_8img  = cv2.imread(S4_doubleA1B2_8)
S4HSV_imgA1B2_8= cv2.cvtColor(S4_A1B2_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_8img  = cv2.imread(S4_doubleA1B3_8)
S4HSV_imgA1B3_8= cv2.cvtColor(S4_A1B3_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_8img  = cv2.imread(S4_doubleA1B4_8)
S4HSV_imgA1B4_8= cv2.cvtColor(S4_A1B4_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_8img  = cv2.imread(S4_doubleA1C1_8)
S4HSV_imgA1C1_8= cv2.cvtColor(S4_A1C1_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_8img  = cv2.imread(S4_doubleA1C2_8)
S4HSV_imgA1C2_8= cv2.cvtColor(S4_A1C2_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_8img  = cv2.imread(S4_doubleA1C3_8)
S4HSV_imgA1C3_8= cv2.cvtColor(S4_A1C3_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_8img  = cv2.imread(S4_doubleA1C4_8)
S4HSV_imgA1C4_8= cv2.cvtColor(S4_A1C4_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_8img  = cv2.imread(S4_doubleA1D2_8)
S4HSV_imgA1D2_8= cv2.cvtColor(S4_A1D2_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_8img  = cv2.imread(S4_doubleA1D3_8)
S4HSV_imgA1D3_8= cv2.cvtColor(S4_A1D3_8img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_8img  = cv2.imread(S4_doubleA1D4_8)
S4HSV_imgA1D4_8= cv2.cvtColor(S4_A1D4_8img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 9

# %%
S4A1A1_9img  = cv2.imread(S4_doubleA1A1_9)
S4HSV_imgA1A1_9= cv2.cvtColor(S4_A1A1_9img, cv2.COLOR_BGR2HSV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-09bc9f8a4203> in <module>()
# ----> 1 S4A1A1_9img  = cv2.imread(S4_doubleA1A1_9)
#       2 S4HSV_imgA1A1_9= cv2.cvtColor(S4_A1A1_9img, cv2.COLOR_BGR2HSV)
#
# NameError: name 'cv2' is not defined

# %%
S4_A1A2_9img  = cv2.imread(S4_doubleA1A2_9)
S4HSV_imgA1A2_9= cv2.cvtColor(S4_A1A2_9img, cv2.COLOR_BGR2HSV)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8b03148fb782> in <module>()
# ----> 1 S4_A1A2_9img  = cv2.imread(S4_doubleA1A2_9)
#       2 S4HSV_imgA1A2_9= cv2.cvtColor(S4_A1A2_9img, cv2.COLOR_BGR2HSV)
#
# NameError: name 'cv2' is not defined

# %%
S4_A1A3_9img  = cv2.imread(S4_doubleA1A3_9)
S4HSV_imgA1A3_9= cv2.cvtColor(S4_A1A3_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_59img  = cv2.imread(S4_doubleA1A3_59)
S4HSV_imgA1A3_59= cv2.cvtColor(S4_A1A3_59img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_9img  = cv2.imread(S4_doubleA1A4_9)
S4HSV_imgA1A4_9= cv2.cvtColor(S4_A1A4_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_9img  = cv2.imread(S4_doubleA1B1_9)
S4HSV_imgA1B1_9= cv2.cvtColor(S4_A1B1_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_9img  = cv2.imread(S4_doubleA1B2_9)
S4HSV_imgA1B2_9= cv2.cvtColor(S4_A1B2_9img, cv2.COLOR_BGR2HSV)

# %%
S4A1B3_9img  = cv2.imread(S4_doubleA1B3_9)
S4HSV_imgA1B3_9= cv2.cvtColor(S4_A1B3_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_9img  = cv2.imread(S4_doubleA1B4_9)
S4HSV_imgA1B4_9= cv2.cvtColor(S4_A1B4_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_9img  = cv2.imread(S4_doubleA1C1_9)
S4HSV_imgA1C1_9= cv2.cvtColor(S4_A1C1_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C2_9img  = cv2.imread(S4_doubleA1C2_9)
S4HSV_imgA1C2_9= cv2.cvtColor(S4_A1C2_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_9img  = cv2.imread(S4_doubleA1C3_9)
S4HSV_imgA1C3_9= cv2.cvtColor(S4_A1C3_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_9img  = cv2.imread(S4_doubleA1C4_9)
S4HSV_imgA1C4_9= cv2.cvtColor(S4_A1C4_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_9img  = cv2.imread(S4_doubleA1D2_9)
S4HSV_imgA1D2_9= cv2.cvtColor(S4_A1D2_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_9img  = cv2.imread(S4_doubleA1D3_9)
S4HSV_imgA1D3_9= cv2.cvtColor(S4_A1D3_9img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_9img  = cv2.imread(S4_doubleA1D4_9)
S4HSV_imgA1D4_9= cv2.cvtColor(S4_A1D4_9img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# ###Img 10

# %%
S4_A1A1_10img  = cv2.imread(S4_doubleA1A1_10)
S4HSV_imgA1A1_10= cv2.cvtColor(S4_A1A1_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A2_10img  = cv2.imread(S4_doubleA1A2_10)
S4HSV_imgA1A2_10= cv2.cvtColor(S4_A1A2_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_10img  = cv2.imread(S4_doubleA1A3_10)
S4HSV_imgA1A3_10= cv2.cvtColor(S4_A1A3_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A3_510img  = cv2.imread(S4_doubleA1A3_510)
S4HSV_imgA1A3_510= cv2.cvtColor(S4_A1A3_510img, cv2.COLOR_BGR2HSV)

# %%
S4_A1A4_10img  = cv2.imread(S4_doubleA1A4_10)
S4HSV_imgA1A4_10= cv2.cvtColor(S4_A1A4_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B1_10img  = cv2.imread(S4_doubleA1B1_10)
S4HSV_imgA1B1_10= cv2.cvtColor(S4_A1B1_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B2_10img  = cv2.imread(S4_doubleA1B2_10)
S4HSV_imgA1B2_10= cv2.cvtColor(S4_A1B2_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B3_10img  = cv2.imread(S4_doubleA1B3_10)
S4HSV_imgA1B3_10= cv2.cvtColor(S4_A1B3_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1B4_10img  = cv2.imread(S4_doubleA1B4_10)
S4HSV_imgA1B4_10= cv2.cvtColor(S4_A1B4_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C1_10img  = cv2.imread(S4_doubleA1C1_10)
S4HSV_imgA1C1_10= cv2.cvtColor(S4_A1C1_10img, cv2.COLOR_BGR2HSV)

# %%
S_A1C2_10img  = cv2.imread(S4_doubleA1C2_10)
SHSV_imgA1C2_10= cv2.cvtColor(S4_A1C2_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C3_10img  = cv2.imread(S4_doubleA1C3_10)
S4HSV_imgA1C3_10= cv2.cvtColor(S4_A1C3_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1C4_10img  = cv2.imread(S4_doubleA1C4_10)
S4HSV_imgA1C4_10= cv2.cvtColor(S4_A1C4_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D2_10img  = cv2.imread(S4_doubleA1D2_10)
S4HSV_imgA1D2_10= cv2.cvtColor(S4_A1D2_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D3_10img  = cv2.imread(S4_doubleA1D3_10)
S4HSV_imgA1D3_10= cv2.cvtColor(S4_A1D3_10img, cv2.COLOR_BGR2HSV)

# %%
S4_A1D4_10img  = cv2.imread(S4_doubleA1D4_10)
S4HSV_imgA1D4_10= cv2.cvtColor(S4_A1D4_10img, cv2.COLOR_BGR2HSV)

# %% [markdown]
# #5. ดึงสี

# %% [markdown]
# ##Set1

# %% [markdown]
# ### RGB

# %%
S1A1_1= list()
S1A1_2 = list()
for i in range(S1RGB_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1.append(S1RGB_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_2.append(S1RGB_imgA1A1_1[i][j])

# %%
S1A1_3= list()
S1A2_1 = list()
for i in range(S1RGB_imgA1A2_1.shape[0]): 
     for j in range(S1RGB_imgA1A2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_3.append(S1RGB_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_1.append(S1RGB_imgA1A2_1[i][j])

# %%
S1A1_4= list()
S1A3_1 = list()
for i in range(S1RGB_imgA1A3_1.shape[0]): 
     for j in range(S1RGB_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_4.append(S1RGB_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_1.append(S1RGB_imgA1A3_1[i][j])

# %%
S1A1_5= list()
S1A3_51 = list()
for i in range(S1RGB_imgA1A3_51.shape[0]): 
     for j in range(S1RGB_imgA1A3_51.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_5.append(S1RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_51.append(S1RGB_imgA1A3_51[i][j])

# %%
S1A1_6= list()
S1A4_1 = list()
for i in range(S1RGB_imgA1A4_1.shape[0]): 
     for j in range(S1RGB_imgA1A4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_6.append(S1RGB_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_1.append(S1RGB_imgA1A4_1[i][j])

# %%
S1A1_7= list()
S1B1_1 = list()
for i in range(S1RGB_imgA1B1_1.shape[0]): 
     for j in range(S1RGB_imgA1B1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_7.append(S1RGB_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_1.append(S1RGB_imgA1B1_1[i][j])

# %%
S1A1_8= list()
S1B2_1 = list()
for i in range(S1RGB_imgA1B2_1.shape[0]): 
     for j in range(S1RGB_imgA1B2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_8.append(S1RGB_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_1.append(S1RGB_imgA1B2_1[i][j])

# %%
S1A1_9= list()
S1B3_1 = list()
for i in range(S1RGB_imgA1B3_1.shape[0]): 
     for j in range(S1RGB_imgA1B3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_9.append(S1RGB_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_1.append(S1RGB_imgA1B3_1[i][j])

# %%
S1A1_10= list()
S1B4_1 = list()
for i in range(S1RGB_imgA1B4_1.shape[0]): 
     for j in range(S1RGB_imgA1B4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_10.append(S1RGB_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_1.append(S1RGB_imgA1B4_1[i][j])

# %%
S1A1_11= list()
S1C1_2 = list()
for i in range(S1RGB_imgA1C1_1.shape[0]): 
     for j in range(S1RGB_imgA1C1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_11.append(S1RGB_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_2.append(S1RGB_imgA1C1_1[i][j])

# %%
S1A1_12= list()
S1C2_1 = list()
for i in range(S1RGB_imgA1C2_1.shape[0]): 
     for j in range(S1RGB_imgA1C2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_12.append(S1RGB_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_1.append(S1RGB_imgA1C2_1[i][j])

# %%
S1A1_13= list()
S1C3_1 = list()
for i in range(S1RGB_imgA1C3_1.shape[0]): 
     for j in range(S1RGB_imgA1C3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_13.append(S1RGB_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_1.append(S1RGB_imgA1C3_1[i][j])

# %%
S1A1_14= list()
S1C4_1 = list()
for i in range(S1RGB_imgA1C4_1.shape[0]): 
     for j in range(S1RGB_imgA1C4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_14.append(S1RGB_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_1.append(S1RGB_imgA1C4_1[i][j])

# %%
S1A1_15= list()
S1D2_1 = list()
for i in range(S1RGB_imgA1D2_1.shape[0]): 
     for j in range(S1RGB_imgA1D2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_15.append(S1RGB_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_1.append(S1RGB_imgA1D2_1[i][j])

# %%
S1A1_16= list()
S1D3_1 = list()
for i in range(S1RGB_imgA1D3_1.shape[0]): 
     for j in range(S1RGB_imgA1D3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_16.append(S1RGB_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_1.append(S1RGB_imgA1D3_1[i][j])

# %%
S1A1_17= list()
S1D4_1 = list()
for i in range(S1RGB_imgA1D4_1.shape[0]): 
     for j in range(S1RGB_imgA1D4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_17.append(S1RGB_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_1.append(S1RGB_imgA1D4_1[i][j])

# %% [markdown]
# ###Img 2

# %%
S1A1_102= list()
S1A1_202= list()
for i in range(S1RGB_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_102.append(S1RGB_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_202.append(S1RGB_imgA1A1_2[i][j])

# %%
S1A1_302= list()
S1A2_102 = list()
for i in range(S1RGB_imgA1A2_2.shape[0]): 
     for j in range(S1RGB_imgA1A2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_302.append(S1RGB_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_102.append(S1RGB_imgA1A2_2[i][j])

# %%
S1A1_402= list()
S1A3_102 = list()
for i in range(S1RGB_imgA1A3_2.shape[0]): 
     for j in range(S1RGB_imgA1A3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_402.append(S1RGB_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_102.append(S1RGB_imgA1A3_2[i][j])

# %%
S1A1_502= list()
S1A3_5102 = list()
for i in range(S1RGB_imgA1A3_52.shape[0]): 
     for j in range(S1RGB_imgA1A3_52.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_502.append(S1RGB_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5102.append(S1RGB_imgA1A3_52[i][j])

# %%
S1A1_602= list()
S1A4_102 = list()
for i in range(S1RGB_imgA1A4_2.shape[0]): 
     for j in range(S1RGB_imgA1A4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_602.append(S1RGB_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_102.append(S1RGB_imgA1A4_2[i][j])

# %%
S1A1_702= list()
S1B1_102 = list()
for i in range(S1RGB_imgA1B1_2.shape[0]): 
     for j in range(S1RGB_imgA1B1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_702.append(S1RGB_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_102.append(S1RGB_imgA1B1_2[i][j])

# %%
S1A1_80= list()
S1B2_10 = list()
for i in range(S1RGB_imgA1B2_.shape[0]): 
     for j in range(S1RGB_imgA1B2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_80.append(S1RGB_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_10.append(S1RGB_imgA1B2_[i][j])

# %%
S1A1_902= list()
S1B3_102 = list()
for i in range(S1RGB_imgA1B3_2.shape[0]): 
     for j in range(S1RGB_imgA1B3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_902.append(S1RGB_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_102.append(S1RGB_imgA1B3_2[i][j])

# %%
S1A1_1002= list()
S1B4_102 = list()
for i in range(S1RGB_imgA1B4_2.shape[0]): 
     for j in range(S1RGB_imgA1B4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1002.append(S1RGB_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_102.append(S1RGB_imgA1B4_2[i][j])

# %%
S1A1_1102= list()
S1C1_202 = list()
for i in range(S1RGB_imgA1C1_.2shape[0]): 
     for j in range(S1RGB_imgA1C1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1102.append(S1RGB_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_202.append(S1RGB_imgA1C1_2[i][j])

# %%
S1A1_1202= list()
S1C2_102 = list()
for i in range(S1RGB_imgA1C2_2.shape[0]): 
     for j in range(S1RGB_imgA1C2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1202.append(S1RGB_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_102.append(S1RGB_imgA1C2_2[i][j])

# %%
S1A1_1302= list()
S1C3_102 = list()
for i in range(S1RGB_imgA1C3_2.shape[0]): 
     for j in range(S1RGB_imgA1C3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1302.append(S1RGB_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_102.append(S1RGB_imgA1C3_2[i][j])

# %%
S1A1_1402= list()
S1C4_102 = list()
for i in range(S1RGB_imgA1C4_2.shape[0]): 
     for j in range(S1RGB_imgA1C4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1402.append(S1RGB_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_102.append(S1RGB_imgA1C4_2[i][j])

# %%
S1A1_1502= list()
S1D2_102 = list()
for i in range(S1RGB_imgA1D2_2.shape[0]): 
     for j in range(S1RGB_imgA1D2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1502.append(S1RGB_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_102.append(S1RGB_imgA1D2_2[i][j])

# %%
S1A1_1602= list()
S1D3_102 = list()
for i in range(S1RGB_imgA1D3_2.shape[0]): 
     for j in range(S1RGB_imgA1D3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1602.append(S1RGB_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_102.append(S1RGB_imgA1D3_2[i][j])

# %%
S1A1_1702= list()
S1D4_102 = list()
for i in range(S1RGB_imgA1D4_2.shape[0]): 
     for j in range(S1RGB_imgA1D4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1702.append(S1RGB_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_102.append(S1RGB_imgA1D4_2[i][j])

# %% [markdown]
# ###Img 3

# %%
S1A1_103= list()
S1A1_203= list()
for i in range(S1RGB_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_103.append(S1RGB_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_203.append(S1RGB_imgA1A1_3[i][j])

# %%
S1A1_303= list()
S1A2_103 = list()
for i in range(S1RGB_imgA1A2_3.shape[0]): 
     for j in range(S1RGB_imgA1A2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_303.append(S1RGB_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_103.append(S1RGB_imgA1A2_3[i][j])

# %%
S1A1_403= list()
S1A3_103 = list()
for i in range(S1RGB_imgA1A3_3.shape[0]): 
     for j in range(S1RGB_imgA1A3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_403.append(S1RGB_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_103.append(S1RGB_imgA1A3_3[i][j])

# %%
S1A1_503= list()
S1A3_5103= list()
for i in range(S1RGB_imgA1A3_53.shape[0]): 
     for j in range(S1RGB_imgA1A3_53.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_503.append(S1RGB_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5103.append(S1RGB_imgA1A3_53[i][j])

# %%
S1A1_603= list()
S1A4_103 = list()
for i in range(S1RGB_imgA1A4_.3shape[0]): 
     for j in range(S1RGB_imgA1A4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_603.append(S1RGB_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_103.append(S1RGB_imgA1A4_3[i][j])

# %%
S1A1_703= list()
S1B1_103 = list()
for i in range(S1RGB_imgA1B1_3.shape[0]): 
     for j in range(S1RGB_imgA1B1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_703.append(S1RGB_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_103.append(S1RGB_imgA1B1_3[i][j])

# %%
S1A1_803= list()
S1B2_103 = list()
for i in range(S1RGB_imgA1B2_3.shape[0]): 
     for j in range(S1RGB_imgA1B2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_803.append(S1RGB_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_103.append(S1RGB_imgA1B2_3[i][j])

# %%
S1A1_903= list()
S1B3_103 = list()
for i in range(S1RGB_imgA1B3_3.shape[0]): 
     for j in range(S1RGB_imgA1B3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_903.append(S1RGB_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_103.append(S1RGB_imgA1B3_3[i][j])

# %%
S1A1_100= list()
S1B4_10 = list()
for i in range(S1RGB_imgA1B4_.shape[0]): 
     for j in range(S1RGB_imgA1B4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_100.append(S1RGB_imgA1B4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_10.append(S1RGB_imgA1B4_[i][j])

# %%
S1A1_1103= list()
S1C1_203 = list()
for i in range(S1RGB_imgA1C1_3.shape[0]): 
     for j in range(S1RGB_imgA1C1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1103.append(S1RGB_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_203.append(S1RGB_imgA1C1_3[i][j])

# %%
S1A1_1203= list()
S1C2_103 = list()
for i in range(S1RGB_imgA1C2_3.shape[0]): 
     for j in range(S1RGB_imgA1C2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1203.append(S1RGB_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_103.append(S1RGB_imgA1C2_3[i][j])

# %%
S1A1_1303= list()
S1C3_103 = list()
for i in range(S1RGB_imgA1C3_3.shape[0]): 
     for j in range(S1RGB_imgA1C3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_130.append(S1RGB_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_10.append(S1RGB_imgA1C3_3[i][j])

# %%
S1A1_140= list()
S1C4_10 = list()
for i in range(S1RGB_imgA1C4_.shape[0]): 
     for j in range(S1RGB_imgA1C4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_140.append(S1RGB_imgA1C4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_10.append(S1RGB_imgA1C4_[i][j])

# %%
S1A1_150= list()
S1D2_10 = list()
for i in range(S1RGB_imgA1D2_.shape[0]): 
     for j in range(S1RGB_imgA1D2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_150.append(S1RGB_imgA1D2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_10.append(S1RGB_imgA1D2_[i][j])

# %%
S1A1_1603= list()
S1D3_103 = list()
for i in range(S1RGB_imgA1D3_3.shape[0]): 
     for j in range(S1RGB_imgA1D3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1603.append(S1RGB_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_103.append(S1RGB_imgA1D3_3[i][j])

# %%
S1A1_1703= list()
S1D4_103= list()
for i in range(S1RGB_imgA1D4_3.shape[0]): 
     for j in range(S1RGB_imgA1D4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1703.append(S1RGB_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_103.append(S1RGB_imgA1D4_3[i][j])

# %% [markdown]
# ###Img 4

# %%
S1A1_104= list()
S1A1_204= list()
for i in range(S1RGB_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_104.append(S1RGB_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_204.append(S1RGB_imgA1A1_4[i][j])

# %%
S1A1_304= list()
S1A2_104= list()
for i in range(S1RGB_imgA1A2_4.shape[0]): 
     for j in range(S1RGB_imgA1A2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_304.append(S1RGB_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_104.append(S1RGB_imgA1A2_4[i][j])

# %%
S1A1_404= list()
S1A3_104 = list()
for i in range(S1RGB_imgA1A3_4.shape[0]): 
     for j in range(S1RGB_imgA1A3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_404.append(S1RGB_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_104.append(S1RGB_imgA1A3_4[i][j])

# %%
S1A1_504= list()
S1A3_5104 = list()
for i in range(S1RGB_imgA1A3_54.shape[0]): 
     for j in range(S1RGB_imgA1A3_54.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_504.append(S1RGB_imgA1A3_514[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5104.append(S1RGB_imgA1A3_54[i][j])

# %%
S1A1_604= list()
S1A4_104 = list()
for i in range(S1RGB_imgA1A4_4.shape[0]): 
     for j in range(S1RGB_imgA1A4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_604.append(S1RGB_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_104.append(S1RGB_imgA1A4_4[i][j])

# %%
S1A1_704= list()
S1B1_104 = list()
for i in range(S1RGB_imgA1B1_4.shape[0]): 
     for j in range(S1RGB_imgA1B1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_704.append(S1RGB_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_104.append(S1RGB_imgA1B1_4[i][j])

# %%
S1A1_804= list()
S1B2_104 = list()
for i in range(S1RGB_imgA1B2_4.shape[0]): 
     for j in range(S1RGB_imgA1B2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_804.append(S1RGB_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_104.append(S1RGB_imgA1B2_4[i][j])

# %%
S1A1_90= list()
S1B3_10 = list()
for i in range(S1RGB_imgA1B3_.shape[0]): 
     for j in range(S1RGB_imgA1B3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_90.append(S1RGB_imgA1B3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_10.append(S1RGB_imgA1B3_[i][j])

# %%
S1A1_1004= list()
S1B4_104 = list()
for i in range(S1RGB_imgA1B4_4.shape[0]): 
     for j in range(S1RGB_imgA1B4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1004.append(S1RGB_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_104.append(S1RGB_imgA1B4_4[i][j])

# %%
S1A1_1104= list()
S1C1_204 = list()
for i in range(S1RGB_imgA1C1_4.shape[0]): 
     for j in range(S1RGB_imgA1C1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1104.append(S1RGB_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_204.append(S1RGB_imgA1C1_4[i][j])

# %%
S1A1_1204= list()
S1C2_104= list()
for i in range(S1RGB_imgA1C2_4.shape[0]): 
     for j in range(S1RGB_imgA1C2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1204.append(S1RGB_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_104.append(S1RGB_imgA1C2_4[i][j])

# %%
S1A1_1304= list()
S1C3_104 = list()
for i in range(S1RGB_imgA1C3_4.shape[0]): 
     for j in range(S1RGB_imgA1C3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1304.append(S1RGB_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_104.append(S1RGB_imgA1C3_4[i][j])

# %%
S1A1_1404= list()
S1C4_104 = list()
for i in range(S1RGB_imgA1C4_4.shape[0]): 
     for j in range(S1RGB_imgA1C4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1404.append(S1RGB_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_104.append(S1RGB_imgA1C4_4[i][j])

# %%
S1A1_1504= list()
S1D2_104 = list()
for i in range(S1RGB_imgA1D2_4.shape[0]): 
     for j in range(S1RGB_imgA1D2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1504.append(S1RGB_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_104.append(S1RGB_imgA1D2_4[i][j])

# %%
S1A1_1604= list()
S1D3_104 = list()
for i in range(S1RGB_imgA1D3_4.shape[0]): 
     for j in range(S1RGB_imgA1D3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1604.append(S1RGB_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_104.append(S1RGB_imgA1D3_4[i][j])

# %%
S1A1_1704= list()
S1D4_104 = list()
for i in range(S1RGB_imgA1D4_4.shape[0]): 
     for j in range(S1RGB_imgA1D4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1704.append(S1RGB_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_104.append(S1RGB_imgA1D4_4[i][j])

# %% [markdown]
# ###Img 5

# %%
S1A1_105= list()
S1A1_205= list()
for i in range(S1RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_105.append(S1RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_205.append(S1RGB_imgA1A1_5[i][j])

# %%
S1A1_305= list()
S1A2_105 = list()
for i in range(S1RGB_imgA1A2_5.shape[0]): 
     for j in range(S1RGB_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_305.append(S1RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_105.append(S1RGB_imgA1A2_5[i][j])

# %%
S1A1_405= list()
S1A3_105= list()
for i in range(S1RGB_imgA1A3_5.shape[0]): 
     for j in range(S1RGB_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_405.append(S1RGB_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_105.append(S1RGB_imgA1A3_5[i][j])

# %%
S1A1_505= list()
S1A3_5105 = list()
for i in range(S1RGB_5imgA1A3_5.shape[0]): 
     for j in range(S1RGB_5imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_505.append(S1RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5105.append(S1RGB_imgA1A3_55[i][j])

# %%
S1A1_605= list()
S1A4_105 = list()
for i in range(S1RGB_imgA1A4_5.shape[0]): 
     for j in range(S1RGB_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_605.append(S1RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_105.append(S1RGB_imgA1A4_5[i][j])

# %%
S1A1_705= list()
S1B1_105 = list()
for i in range(S1RGB_imgA1B1_5.shape[0]): 
     for j in range(S1RGB_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_705.append(S1RGB_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_105.append(S1RGB_imgA1B1_5[i][j])

# %%
S1A1_805= list()
S1B2_105 = list()
for i in range(S1RGB_imgA1B2_5.shape[0]): 
     for j in range(S1RGB_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_805.append(S1RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_105.append(S1RGB_imgA1B2_5[i][j])

# %%
S1A1_905= list()
S1B3_105 = list()
for i in range(S1RGB_imgA1B3_5.shape[0]): 
     for j in range(S1RGB_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_905.append(S1RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_105.append(S1RGB_imgA1B3_5[i][j])

# %%
S1A1_1005= list()
S1B4_105 = list()
for i in range(S1RGB_imgA1B4_5.shape[0]): 
     for j in range(S1RGB_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1005.append(S1RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_105.append(S1RGB_imgA1B4_5[i][j])

# %%
S1A1_1105= list()
S1C1_205 = list()
for i in range(S1RGB_imgA1C1_5.shape[0]): 
     for j in range(S1RGB_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1105.append(S1RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_205.append(S1RGB_imgA1C1_5[i][j])

# %%
S1A1_1205= list()
S1C2_105 = list()
for i in range(S1RGB_imgA1C2_5.shape[0]): 
     for j in range(S1RGB_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1205.append(S1RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_105.append(S1RGB_imgA1C2_5[i][j])

# %%
S1A1_1305= list()
S1C3_105 = list()
for i in range(S1RGB_imgA1C3_5.shape[0]): 
     for j in range(S1RGB_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1305.append(S1RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_105.append(S1RGB_imgA1C3_5[i][j])

# %%
S1A1_1405= list()
S1C4_105= list()
for i in range(S1RGB_imgA1C4_.shape[0]): 
     for j in range(S1RGB_imgA1C4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1405.append(S1RGB_imgA1C4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_105.append(S1RGB_imgA1C4_[i][j])

# %%
S1A1_1505= list()
S1D2_105 = list()
for i in range(S1RGB_imgA1D2_5.shape[0]): 
     for j in range(S1RGB_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1505.append(S1RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_105.append(S1RGB_imgA1D2_5[i][j])

# %%
S1A1_1605= list()
S1D3_105 = list()
for i in range(S1RGB_imgA1D3_5.shape[0]): 
     for j in range(S1RGB_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1605.append(S1RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_105.append(S1RGB_imgA1D3_5[i][j])

# %%
S1A1_1705= list()
S1D4_105 = list()
for i in range(S1RGB_imgA1D4_5.shape[0]): 
     for j in range(S1RGB_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1705.append(S1RGB_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_105.append(S1RGB_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 6

# %%
S1A1_105= list()
S1A1_205= list()
for i in range(S1RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_105.append(S1RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_205.append(S1RGB_imgA1A1_5[i][j])

# %%
S1A1_305= list()
S1A2_105 = list()
for i in range(S1RGB_imgA1A2_5.shape[0]): 
     for j in range(S1RGB_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_305.append(S1RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_105.append(S1RGB_imgA1A2_5[i][j])

# %%
S1A1_405= list()
S1A3_105 = list()
for i in range(S1RGB_imgA1A3_5.shape[0]): 
     for j in range(S1RGB_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_405.append(S1RGB_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_105.append(S1RGB_imgA1A3_5[i][j])

# %%
S1A1_505= list()
S1A3_5105 = list()
for i in range(S1RGB_imgA1A3_55.shape[0]): 
     for j in range(S1RGB_imgA1A3_55.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_505.append(S1RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5105.append(S1RGB_imgA1A3_55[i][j])

# %%
S1A1_605= list()
S1A4_105 = list()
for i in range(S1RGB_imgA1A4_5.shape[0]): 
     for j in range(S1RGB_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_605.append(S1RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_105.append(S1RGB_imgA1A4_5[i][j])

# %%
S1A1_705= list()
S1B1_105 = list()
for i in range(S1RGB_imgA1B1_5.shape[0]): 
     for j in range(S1RGB_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_705.append(S1RGB_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_105.append(S1RGB_imgA1B1_5[i][j])

# %%
S1A1_805= list()
S1B2_105 = list()
for i in range(S1RGB_imgA1B2_5.shape[0]): 
     for j in range(S1RGB_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_805.append(S1RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_105.append(S1RGB_imgA1B2_5[i][j])

# %%
S1A1_905= list()
S1B3_105 = list()
for i in range(S1RGB_imgA1B3_5.shape[0]): 
     for j in range(S1RGB_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_905.append(S1RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_105.append(S1RGB_imgA1B3_5[i][j])

# %%
S1A1_1005= list()
S1B4_105 = list()
for i in range(S1RGB_imgA1B4_5.shape[0]): 
     for j in range(S1RGB_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1005.append(S1RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_105.append(S1RGB_imgA1B4_5[i][j])

# %%
S1A1_1105= list()
S1C1_205 = list()
for i in range(S1RGB_imgA1C1_5.shape[0]): 
     for j in range(S1RGB_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1105.append(S1RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_205.append(S1RGB_imgA1C1_5[i][j])

# %%
S1A1_1205= list()
S1C2_105 = list()
for i in range(S1RGB_imgA1C2_5.shape[0]): 
     for j in range(S1RGB_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1205.append(S1RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_105.append(S1RGB_imgA1C2_5[i][j])

# %%
S1A1_1305= list()
S1C3_105 = list()
for i in range(S1RGB_imgA1C3_5.shape[0]): 
     for j in range(S1RGB_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1305.append(S1RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_105.append(S1RGB_imgA1C3_5[i][j])

# %%
S1A1_1405= list()
S1C4_105 = list()
for i in range(S1RGB_imgA1C4_5.shape[0]): 
     for j in range(S1RGB_imgA1C4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1405.append(S1RGB_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_105.append(S1RGB_imgA1C4_5[i][j])

# %%
S1A1_1505= list()
S1D2_105 = list()
for i in range(S1RGB_imgA1D2_5.shape[0]): 
     for j in range(S1RGB_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1505.append(S1RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_105.append(S1RGB_imgA1D2_5[i][j])

# %%
S1A1_1605= list()
S1D3_105 = list()
for i in range(S1RGB_imgA1D3_5.shape[0]): 
     for j in range(S1RGB_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1605.append(S1RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_105.append(S1RGB_imgA1D3_5[i][j])

# %%
S1A1_1705= list()
S1D4_105 = list()
for i in range(S1RGB_imgA1D4_5.shape[0]): 
     for j in range(S1RGB_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1705.append(S1RGB_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_105.append(S1RGB_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 7

# %%
S1A1_107= list()
S1A1_207= list()
for i in range(S1RGB_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_107.append(S1RGB_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_207.append(S1RGB_imgA1A1_7[i][j])

# %%
S1A1_30= list()
S1A2_10 = list()
for i in range(S1RGB_imgA1A2_.shape[0]): 
     for j in range(S1RGB_imgA1A2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_30.append(S1RGB_imgA1A2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_10.append(S1RGB_imgA1A2_[i][j])

# %%
S1A1_407= list()
S1A3_107 = list()
for i in range(S1RGB_imgA1A3_7.shape[0]): 
     for j in range(S1RGB_imgA1A3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_407.append(S1RGB_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_107.append(S1RGB_imgA1A3_7[i][j])

# %%
S1A1_507= list()
S1A3_5107 = list()
for i in range(S1RGB_imgA1A3_57.shape[0]): 
     for j in range(S1RGB_imgA1A3_57.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_507.append(S1RGB_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5107.append(S1RGB_imgA1A3_57[i][j])

# %%
S1A1_607= list()
S1A4_107 = list()
for i in range(S1RGB_imgA1A4_7.shape[0]): 
     for j in range(S1RGB_imgA1A4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_607.append(S1RGB_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_107.append(S1RGB_imgA1A4_7[i][j])

# %%
S1A1_707= list()
S1B1_107 = list()
for i in range(S1RGB_imgA1B1_7.shape[0]): 
     for j in range(S1RGB_imgA1B1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_707.append(S1RGB_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_107.append(S1RGB_imgA1B1_7[i][j])

# %%
S1A1_807= list()
S1B2_107 = list()
for i in range(S1RGB_imgA1B2_7.shape[0]): 
     for j in range(S1RGB_imgA1B2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_807.append(S1RGB_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_107.append(S1RGB_imgA1B2_7[i][j])

# %%
S1A1_907= list()
S1B3_107 = list()
for i in range(S1RGB_imgA1B3_7.shape[0]): 
     for j in range(S1RGB_imgA1B3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_907.append(S1RGB_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_107.append(S1RGB_imgA1B3_7[i][j])

# %%
S1A1_1007= list()
S1B4_107 = list()
for i in range(S1RGB_imgA1B4_7.shape[0]): 
     for j in range(S1RGB_imgA1B4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1007.append(S1RGB_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_107.append(S1RGB_imgA1B4_7[i][j])

# %%
S1A1_1107= list()
S1C1_207 = list()
for i in range(S1RGB_imgA1C1_7.shape[0]): 
     for j in range(S1RGB_imgA1C1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1107.append(S1RGB_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_207.append(S1RGB_imgA1C1_7[i][j])

# %%
S1A1_1207= list()
S1C2_107 = list()
for i in range(S1RGB_imgA1C2_7.shape[0]): 
     for j in range(S1RGB_imgA1C2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1207.append(S1RGB_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_107.append(S1RGB_imgA1C2_7[i][j])

# %%
S1A1_1307= list()
S1C3_107 = list()
for i in range(S1RGB_imgA1C3_7.shape[0]): 
     for j in range(S1RGB_imgA1C3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1307.append(S1RGB_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_107.append(S1RGB_imgA1C3_7[i][j])

# %%
S1A1_1407= list()
S1C4_107 = list()
for i in range(S1RGB_imgA1C4_7.shape[0]): 
     for j in range(S1RGB_imgA1C4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1407.append(S1RGB_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_107.append(S1RGB_imgA1C4_7[i][j])

# %%
S1A1_1507= list()
S1D2_107 = list()
for i in range(S1RGB_imgA1D2_7.shape[0]): 
     for j in range(S1RGB_imgA1D2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1507.append(S1RGB_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_107.append(S1RGB_imgA1D2_7[i][j])

# %%
S1A1_1607= list()
S1D3_107 = list()
for i in range(S1RGB_imgA1D3_7.shape[0]): 
     for j in range(S1RGB_imgA1D3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1607.append(S1RGB_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_107.append(S1RGB_imgA1D3_7[i][j])

# %%
S1A1_1707= list()
S1D4_107 = list()
for i in range(S1RGB_imgA1D4_7.shape[0]): 
     for j in range(S1RGB_imgA1D4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1707.append(S1RGB_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_107.append(S1RGB_imgA1D4_7[i][j])

# %% [markdown]
# ###Img 8

# %%
S1A1_108= list()
S1A1_208= list()
for i in range(S1RGB_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_108.append(S1RGB_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_208.append(S1RGB_imgA1A1_8[i][j])

# %%
S1A1_308= list()
S1A2_108 = list()
for i in range(S1RGB_imgA1A2_8.shape[0]): 
     for j in range(S1RGB_imgA1A2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_308.append(S1RGB_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_108.append(S1RGB_imgA1A2_8[i][j])

# %%
S1A1_408= list()
S1A3_108 = list()
for i in range(S1RGB_imgA1A3_8.shape[0]): 
     for j in range(S1RGB_imgA1A3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_408.append(S1RGB_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_108.append(S1RGB_imgA1A3_8[i][j])

# %%
S1A1_508= list()
S1A3_5108 = list()
for i in range(S1RGB_imgA1A3_58.shape[0]): 
     for j in range(S1RGB_imgA1A3_58.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_508.append(S1RGB_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5108.append(S1RGB_imgA1A3_58[i][j])

# %%
S1A1_608= list()
S1A4_108 = list()
for i in range(S1RGB_imgA1A4_8.shape[0]): 
     for j in range(S1RGB_imgA1A4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_608.append(S1RGB_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_108.append(S1RGB_imgA1A4_8[i][j])

# %%
S1A1_708= list()
S1B1_108 = list()
for i in range(S1RGB_imgA1B1_8.shape[0]): 
     for j in range(S1RGB_imgA1B1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_708.append(S1RGB_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_108.append(S1RGB_imgA1B1_8[i][j])

# %%
S1A1_808= list()
S1B2_108 = list()
for i in range(S1RGB_imgA1B2_8.shape[0]): 
     for j in range(S1RGB_imgA1B2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_80.append(S1RGB_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_10.append(S1RGB_imgA1B2_8[i][j])

# %%
S1A1_90= list()
S1B3_10 = list()
for i in range(S1RGB_imgA1B3_.shape[0]): 
     for j in range(S1RGB_imgA1B3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_908.append(S1RGB_imgA1B3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_108.append(S1RGB_imgA1B3_[i][j])

# %%
S1A1_1008= list()
S1B4_108 = list()
for i in range(S1RGB_imgA1B4_8.shape[0]): 
     for j in range(S1RGB_imgA1B4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1008.append(S1RGB_8imgA1B4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_108.append(S1RGB_imgA1B4_8[i][j])

# %%
S1A1_1108= list()
S1C1_208 = list()
for i in range(S1RGB_imgA1C1_8.shape[0]): 
     for j in range(S1RGB_imgA1C1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1108.append(S1RGB_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_208.append(S1RGB_imgA1C1_8[i][j])

# %%
S1A1_1208= list()
S1C2_108 = list()
for i in range(S1RGB_imgA1C2_8.shape[0]): 
     for j in range(S1RGB_imgA1C2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1208.append(S1RGB_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_108.append(S1RGB_imgA1C2_8[i][j])

# %%
S1A1_1308= list()
S1C3_108 = list()
for i in range(S1RGB_imgA1C3_8.shape[0]): 
     for j in range(S1RGB_imgA1C3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1308.append(S1RGB_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_108.append(S1RGB_imgA1C3_8[i][j])

# %%
S1A1_1408= list()
S1C4_108 = list()
for i in range(S1RGB_imgA1C4_8.shape[0]): 
     for j in range(S1RGB_imgA1C4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1408.append(S1RGB_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_108.append(S1RGB_imgA1C4_8[i][j])

# %%
S1A1_1508= list()
S1D2_108 = list()
for i in range(S1RGB_imgA1D2_8.shape[0]): 
     for j in range(S1RGB_imgA1D2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1508.append(S1RGB_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_108.append(S1RGB_imgA1D2_8[i][j])

# %%
S1A1_1608= list()
S1D3_108 = list()
for i in range(S1RGB_imgA1D3_8.shape[0]): 
     for j in range(S1RGB_imgA1D3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1608.append(S1RGB_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_108.append(S1RGB_imgA1D3_8[i][j])

# %%
S1A1_1708= list()
S1D4_108 = list()
for i in range(S1RGB_imgA1D4_8.shape[0]): 
     for j in range(S1RGB_imgA1D4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1708.append(S1RGB_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_108.append(S1RGB_imgA1D4_8[i][j])

# %% [markdown]
# ###Img 9

# %%
S1A1_109= list()
S1A1_209= list()
for i in range(S1RGB_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_109.append(S1RGB_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_209.append(S1RGB_imgA1A1_9[i][j])

# %%
S1A1_309= list()
S1A2_109 = list()
for i in range(S1RGB_imgA1A2_9.shape[0]): 
     for j in range(S1RGB_imgA1A2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_309.append(S1RGB_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_109.append(S1RGB_imgA1A2_9[i][j])

# %%
S1A1_409= list()
S1A3_109 = list()
for i in range(S1RGB_imgA1A3_9.shape[0]): 
     for j in range(S1RGB_imgA1A3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_409.append(S1RGB_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_109.append(S1RGB_imgA1A3_9[i][j])

# %%
S1A1_509= list()
S1A3_5109 = list()
for i in range(S1RGB_imgA1A3_59.shape[0]): 
     for j in range(S1RGB_imgA1A3_59.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_509.append(S1RGB_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5109.append(S1RGB_imgA1A3_59[i][j])

# %%
S1A1_609= list()
S1A4_109 = list()
for i in range(S1RGB_imgA1A4_9.shape[0]): 
     for j in range(S1RGB_imgA1A4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_609.append(S1RGB_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_109.append(S1RGB_imgA1A4_9[i][j])

# %%
S1A1_709= list() 
S1B1_109 = list()
for i in range(S1RGB_imgA1B1_9.shape[0]): 
     for j in range(S1RGB_imgA1B1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_709.append(S1RGB_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_109.append(S1RGB_imgA1B1_9[i][j])

# %%
S1A1_809= list()
S1B2_109 = list()
for i in range(S1RGB_imgA1B2_9.shape[0]): 
     for j in range(S1RGB_imgA1B2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_809.append(S1RGB_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_109.append(S1RGB_imgA1B2_9[i][j])

# %%
S1A1_909= list()
S1B3_109 = list()
for i in range(S1RGB_imgA1B3_9.shape[0]): 
     for j in range(S1RGB_imgA1B3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_909.append(S1RGB_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_109.append(S1RGB_imgA1B3_9[i][j])

# %%
S1A1_1009= list()
S1B4_109 = list()
for i in range(S1RGB_imgA1B4_9.shape[0]): 
     for j in range(S1RGB_imgA1B4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1009.append(S1RGB_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_109.append(S1RGB_imgA1B4_9[i][j])

# %%
S1A1_1109= list()
S1C1_209 = list()
for i in range(S1RGB_imgA1C1_9.shape[0]): 
     for j in range(S1RGB_imgA1C1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1109.append(S1RGB_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_209.append(S1RGB_imgA1C1_9[i][j])

# %%
S1A1_1209= list()
S1C2_109 = list()
for i in range(S1RGB_imgA1C2_9.shape[0]): 
     for j in range(S1RGB_imgA1C2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1209.append(S1RGB_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_109.append(S1RGB_imgA1C2_9[i][j])

# %%
S1A1_1309= list()
S1C3_109 = list()
for i in range(S1RGB_imgA1C3_9.shape[0]): 
     for j in range(S1RGB_imgA1C3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1309.append(S1RGB_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_109.append(S1RGB_imgA1C3_9[i][j])

# %%
S1A1_1409= list()
S1C4_109 = list()
for i in range(S1RGB_imgA1C4_9.shape[0]): 
     for j in range(S1RGB_imgA1C4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1409.append(S1RGB_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_109.append(S1RGB_imgA1C4_9[i][j])

# %%
S1A1_1509= list()
S1D2_109 = list()
for i in range(S1RGB_imgA1D2_9.shape[0]): 
     for j in range(S1RGB_imgA1D2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1509.append(S1RGB_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_109.append(S1RGB_imgA1D2_9[i][j])

# %%
S1A1_1609= list()
S1D3_109 = list()
for i in range(S1RGB_imgA1D3_9.shape[0]): 
     for j in range(S1RGB_imgA1D3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1609.append(S1RGB_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_109.append(S1RGB_imgA1D3_9[i][j])

# %%
S1A1_1709= list()
S1D4_109 = list()
for i in range(S1RGB_imgA1D4_9.shape[0]): 
     for j in range(S1RGB_imgA1D4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1709.append(S1RGB_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_109.append(S1RGB_imgA1D4_9[i][j])

# %% [markdown]
# ###Img 10

# %%
S1A1_110= list()
S1A1_210= list()
for i in range(S1RGB_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_110.append(S1RGB_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_210.append(S1RGB_imgA1A1_10[i][j])

# %%
S1A1_310= list()
S1A2_110 = list()
for i in range(S1RGB_imgA1A2_10.shape[0]): 
     for j in range(S1RGB_imgA1A2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_310.append(S1RGB_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_110.append(S1RGB_imgA1A2_10[i][j])

# %%
S1A1_410= list()
S1A3_110 = list()
for i in range(S1RGB_imgA1A3_10.shape[0]): 
     for j in range(S1RGB_imgA1A3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_410.append(S1RGB_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_110.append(S1RGB_imgA1A3_10[i][j])

# %%
S1A1_510= list()
S1A3_510 = list()
for i in range(S1RGB_imgA1A3_510.shape[0]): 
     for j in range(S1RGB_imgA1A3_510.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_510.append(S1RGB_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_510.append(S1RGB_imgA1A3_510[i][j])

# %%
S1A1_610= list()
S1A4_110 = list()
for i in range(S1RGB_imgA1A4_10.shape[0]): 
     for j in range(S1RGB_imgA1A4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_610.append(S1RGB_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_110.append(S1RGB_imgA1A4_10[i][j])

# %%
S1A1_710= list()
S1B1_110 = list()
for i in range(S1RGB_imgA1B1_10.shape[0]): 
     for j in range(S1RGB_imgA1B1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_710.append(S1RGB_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_110.append(S1RGB_imgA1B1_10[i][j])

# %%
S1A1_810= list()
S1B2_110 = list()
for i in range(S1RGB_imgA1B2_10.shape[0]): 
     for j in range(S1RGB_imgA1B2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_810.append(S1RGB_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_110.append(S1RGB_imgA1B2_10[i][j])

# %%
S1A1_910= list()
S1B3_110 = list()
for i in range(S1RGB_imgA1B3_10.shape[0]): 
     for j in range(S1RGB_imgA1B3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_910.append(S1RGB_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_110.append(S1RGB_imgA1B3_10[i][j])

# %%
S1A1_1010= list()
S1B4_110 = list()
for i in range(S1RGB_imgA1B4_10.shape[0]): 
     for j in range(S1RGB_imgA1B4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1010.append(S1RGB_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_110.append(S1RGB_imgA1B4_10[i][j])

# %%
S1A1_1110= list()
S1C1_210 = list()
for i in range(S1RGB_imgA1C1_10.shape[0]): 
     for j in range(S1RGB_imgA1C1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1110.append(S1RGB_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_210.append(S1RGB_imgA1C1_10[i][j])

# %%
S1A1_1210= list()
S1C2_110 = list()
for i in range(S1RGB_imgA1C2_10.shape[0]): 
     for j in range(S1RGB_imgA1C2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1210.append(S1RGB_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_110.append(S1RGB_imgA1C2_10[i][j])

# %%
S1A1_1310= list()
S1C3_110 = list()
for i in range(S1RGB_imgA1C3_10.shape[0]): 
     for j in range(S1RGB_imgA1C3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1310.append(S1RGB_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_110.append(S1RGB_imgA1C3_10[i][j])

# %%
S1A1_1410= list()
S1C4_110 = list()
for i in range(S1RGB_imgA1C4_10.shape[0]): 
     for j in range(S1RGB_imgA1C4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1410.append(S1RGB_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_110.append(S1RGB_imgA1C4_10[i][j])

# %%
S1A1_1510= list()
S1D2_110 = list()
for i in range(S1RGB_imgA1D2_10.shape[0]): 
     for j in range(S1RGB_imgA1D2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1510.append(S1RGB_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_110.append(S1RGB_imgA1D210_[i][j])

# %%
S1A1_1610= list()
S1D3_110 = list()
for i in range(S1RGB_imgA1D3_10.shape[0]): 
     for j in range(S1RGB_imgA1D3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1610.append(S1RGB_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_110.append(S1RGB_imgA1D3_10[i][j])

# %%
S1A1_1710= list()
S1D4_110 = list()
for i in range(S1RGB_imgA1D4_10.shape[0]): 
     for j in range(S1RGB_imgA1D4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1710.append(S1RGB_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_110.append(S1RGB_imgA1D4_10[i][j])

# %% [markdown]
# ###HSV

# %%
S1A1_1= list()
S1A1_2 = list()
for i in range(S1HSV_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1.append(S1HSV_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_2.append(S1HSV_imgA1A1_1[i][j])

# %%
S1A1_3= list()
S1A2_1 = list()
for i in range(S1HSV_imgA1A2_1.shape[0]): 
     for j in range(S1HSV_imgA1A2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_3.append(S1HSV_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_1.append(S1HSV_imgA1A2_1[i][j])

# %%
S1A1_4= list()
S1A3_1 = list()
for i in range(S1HSV_imgA1A3_1.shape[0]): 
     for j in range(S1HSV_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_4.append(S1HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_1.append(S1HSV_imgA1A3_1[i][j])

# %%
S1A1_5= list()
S1A3_51 = list()
for i in range(S1HSV_imgA1A3_51.shape[0]): 
     for j in range(S1HSV_imgA1A3_51.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_5.append(S1HSV_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_51.append(S1HSV_imgA1A3_51[i][j])

# %%
S1A1_6= list()
S1A4_1 = list()
for i in range(S1HSV_imgA1A4_1.shape[0]): 
     for j in range(S1HSV_imgA1A4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_6.append(S1HSV_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_1.append(S1HSV_imgA1A4_1[i][j])

# %%
S1A1_7= list()
S1B1_1 = list()
for i in range(S1HSV_imgA1B1_1.shape[0]): 
     for j in range(S1HSV_imgA1B1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_7.append(S1HSV_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_1.append(S1HSV_imgA1B1_1[i][j])

# %%
S1A1_8= list()
S1B2_1 = list()
for i in range(S1HSV_imgA1B2_1.shape[0]): 
     for j in range(S1HSV_imgA1B2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_8.append(S1HSV_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_1.append(S1HSV_imgA1B2_1[i][j])

# %%
S1A1_9= list()
S1B3_1 = list()
for i in range(S1HSV_imgA1B3_1.shape[0]): 
     for j in range(S1HSV_imgA1B3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_9.append(S1HSV_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_1.append(S1HSV_imgA1B3_1[i][j])

# %%
S1A1_10= list()
S1B4_1 = list()
for i in range(S1HSV_imgA1B4_1.shape[0]): 
     for j in range(S1HSV_imgA1B4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_10.append(S1HSV_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_1.append(S1HSV_imgA1B4_1[i][j])

# %%
S1A1_11= list()
S1C1_2 = list()
for i in range(S1HSV_imgA1C1_1.shape[0]): 
     for j in range(S1HSV_imgA1C1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_11.append(S1HSV_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_2.append(S1HSV_imgA1C1_1[i][j])

# %%
S1A1_12= list()
S1C2_1 = list()
for i in range(S1HSV_imgA1C2_1.shape[0]): 
     for j in range(S1HSV_imgA1C2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_12.append(S1HSV_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_1.append(S1HSV_imgA1C2_1[i][j])

# %%
S1A1_13= list()
S1C3_1 = list()
for i in range(S1HSV_imgA1C3_1.shape[0]): 
     for j in range(S1HSV_imgA1C3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_13.append(S1HSV_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_1.append(S1HSV_imgA1C3_1[i][j])

# %%
S1A1_14= list()
S1C4_1 = list()
for i in range(S1HSV_imgA1C4_1.shape[0]): 
     for j in range(S1HSV_imgA1C4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_14.append(S1HSV_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_1.append(S1HSV_imgA1C4_1[i][j])

# %%
S1A1_15= list()
S1D2_1 = list()
for i in range(S1HSV_imgA1D2_1.shape[0]): 
     for j in range(S1HSV_imgA1D2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_15.append(S1HSV_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_1.append(S1HSV_imgA1D2_1[i][j])

# %%
S1A1_16= list()
S1D3_1 = list()
for i in range(S1HSV_imgA1D3_1.shape[0]): 
     for j in range(S1HSV_imgA1D3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_16.append(S1HSV_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_1.append(S1HSV_imgA1D3_1[i][j])

# %%
S1A1_17= list()
S1D4_1 = list()
for i in range(S1HSV_imgA1D4_1.shape[0]): 
     for j in range(S1HSV_imgA1D4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_17.append(S1HSV_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_1.append(S1HSV_imgA1D4_1[i][j])

# %% [markdown]
# ###Img 2

# %%
S1A1_102= list()
S1A1_202 = list()
for i in range(S1HSV_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_102.append(S1HSV_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_202.append(S1HSV_imgA1A1_2[i][j])

# %%
S1A1_302= list()
S1A2_102= list()
for i in range(S1HSV_imgA1A2_2.shape[0]): 
     for j in range(S1HSV_imgA1A2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_302.append(S1HSV_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_102.append(S1HSV_imgA1A2_2[i][j])

# %%
S1A1_4= list()
S1A3_1 = list()
for i in range(S1HSV_imgA1A3_1.shape[0]): 
     for j in range(S1HSV_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_4.append(S1HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_1.append(S1HSV_imgA1A3_1[i][j])

# %%
S1A1_502= list()
S1A3_5102 = list()
for i in range(S1HSV_imgA1A3_52.shape[0]): 
     for j in range(S1HSV_imgA1A3_52.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_50.append(S1HSV_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_510.append(S1HSV_imgA1A3_52[i][j])

# %%
S1A1_602= list()
S1A4_102 = list()
for i in range(S1HSV_imgA1A4_2.shape[0]): 
     for j in range(S1HSV_imgA1A4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_602.append(S1HSV_2imgA1A4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_102.append(S1HSV_imgA1A4_2[i][j])

# %%
S1A1_702= list()
S1B1_102= list()
for i in range(S1HSV_imgA1B1_2.shape[0]): 
     for j in range(S1HSV_imgA1B1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_702.append(S1HSV_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_102.append(S1HSV_imgA1B1_2[i][j])

# %%
S1A1_802= list()
S1B2_102 = list()
for i in range(S1HSV_imgA1B2_2.shape[0]): 
     for j in range(S1HSV_imgA1B2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_802.append(S1HSV_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_102.append(S1HSV_imgA1B2_2[i][j])

# %%
S1A1_902= list()
S1B3_102 = list()
for i in range(S1HSV_imgA1B3_2.shape[0]): 
     for j in range(S1HSV_imgA1B3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_902.append(S1HSV_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_102.append(S1HSV_imgA1B3_2[i][j])

# %%
S1A1_1002= list()
S1B4_102= list()
for i in range(S1HSV_imgA1B4_2.shape[0]): 
     for j in range(S1HSV_imgA1B4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1002.append(S1HSV_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_102.append(S1HSV_imgA1B4_2[i][j])

# %%
S1A1_1102= list()
S1C1_202 = list()
for i in range(S1HSV_imgA1C1_2.shape[0]): 
     for j in range(S1HSV_imgA1C1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1102.append(S1HSV_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_202.append(S1HSV_imgA1C1_2[i][j])

# %%
S1A1_1202= list()
S1C2_102 = list()
for i in range(S1HSV_imgA1C2_2.shape[0]): 
     for j in range(S1HSV_imgA1C2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1202.append(S1HSV_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_102.append(S1HSV_imgA1C2_2[i][j])

# %%
S1A1_1302= list()
S1C3_102 = list()
for i in range(S1HSV_imgA1C3_2.shape[0]): 
     for j in range(S1HSV_imgA1C3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1302.append(S1HSV_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_102.append(S1HSV_imgA1C3_2[i][j])

# %%
S1A1_1402= list()
S1C4_102 = list()
for i in range(S1HSV_imgA1C4_2.shape[0]): 
     for j in range(S1HSV_imgA1C4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1402.append(S1HSV_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_102.append(S1HSV_imgA1C4_2[i][j])

# %%
S1A1_1502= list()
S1D2_102 = list()
for i in range(S1HSV_imgA1D2_2.shape[0]): 
     for j in range(S1HSV_imgA1D2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1502.append(S1HSV_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_102.append(S1HSV_imgA1D2_2[i][j])

# %%
S1A1_1602= list()
S1D3_102 = list()
for i in range(S1HSV_imgA1D3_2shape[0]): 
     for j in range(S1HSV_imgA1D3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1602.append(S1HSV_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_102.append(S1HSV_imgA1D3_2[i][j])

# %%
S1A1_1702= list()
S1D4_102 = list()
for i in range(S1HSV_imgA1D4_2.shape[0]): 
     for j in range(S1HSV_imgA1D4_2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1702.append(S1HSV_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_102.append(S1HSV_imgA1D4_2[i][j])

# %% [markdown]
# ###Img 3

# %%
S1A1_103= list()
S1A1_203 = list()
for i in range(S1HSV_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_103.append(S1HSV_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_203append(S1HSV_imgA1A1_3[i][j])

# %%
S1A1_303= list()
S1A2_103 = list()
for i in range(S1HSV_imgA1A2_3.shape[0]): 
     for j in range(S1HSV_imgA1A2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_303.append(S1HSV_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_103.append(S1HSV_imgA1A2_3[i][j])

# %%
S1A1_403= list()
S1A3_103 = list()
for i in range(S1HSV_imgA1A3_3.shape[0]): 
     for j in range(S1HSV_imgA1A3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_403.append(S1HSV_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_103.append(S1HSV_imgA1A3_3[i][j])

# %%
S1A1_503= list()
S1A3_5103 = list()
for i in range(S1HSV_imgA1A3_53.shape[0]): 
     for j in range(S1HSV_imgA1A3_53.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_503.append(S1HSV_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5103.append(S1HSV_imgA1A3_53[i][j])

# %%
S1A1_60= list()
S1A4_10 = list()
for i in range(S1HSV_imgA1A4_.shape[0]): 
     for j in range(S1HSV_imgA1A4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_60.append(S1HSV_imgA1A4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_10.append(S1HSV_imgA1A4_[i][j])

# %%
S1A1_703= list()
S1B1_103= list()
for i in range(S1HSV_imgA1B1_3.shape[0]): 
     for j in range(S1HSV_imgA1B1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_703.append(S1HSV_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_103.append(S1HSV_imgA1B1_3[i][j])

# %%
S1A1_803= list()
S1B2_103 = list()
for i in range(S1HSV_imgA1B2_3.shape[0]): 
     for j in range(S1HSV_imgA1B2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_803.append(S1HSV_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_103.append(S1HSV_imgA1B2_3[i][j])

# %%
S1A1_903= list()
S1B3_103 = list()
for i in range(S1HSV_imgA1B3_3.shape[0]): 
     for j in range(S1HSV_imgA1B3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_903.append(S1HSV_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_103.append(S1HSV_imgA1B3_3[i][j])

# %%
S1A1_1003= list()
S1B4_103 = list()
for i in range(S1HSV_imgA1B4_3.shape[0]): 
     for j in range(S1HSV_imgA1B4_.3shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1003.append(S1HSV_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_103.append(S1HSV_imgA1B4_3[i][j])

# %%
S1A1_1103= list()
S1C1_203 = list()
for i in range(S1HSV_imgA1C1_3.shape[0]): 
     for j in range(S1HSV_imgA1C1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1103.append(S1HSV_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_203.append(S1HSV_imgA1C1_3[i][j])

# %%
S1A1_1203= list()
S1C2_103 = list()
for i in range(S1HSV_imgA1C23_.shape[0]): 
     for j in range(S1HSV_imgA1C23_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1203.append(S1HSV_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_103.append(S1HSV_imgA1C2_3[i][j])

# %%
S1A1_1303= list()
S1C3_103 = list()
for i in range(S1HSV_imgA1C3_3.shape[0]): 
     for j in range(S1HSV_imgA1C3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1303.append(S1HSV_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_103.append(S1HSV_imgA1C3_3[i][j])

# %%
S1A1_1403= list()
S1C4_103= list()
for i in range(S1HSV_imgA1C4_3.shape[0]): 
     for j in range(S1HSV_imgA1C4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1403.append(S1HSV_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_103.append(S1HSV_imgA1C4_3[i][j])

# %%
S1A1_1503= list()
S1D2_103 = list()
for i in range(S1HSV_imgA1D2_3.shape[0]): 
     for j in range(S1HSV_imgA1D2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1503.append(S1HSV_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_103.append(S1HSV_imgA1D2_3[i][j])

# %%
S1A1_1603= list()
S1D3_103 = list()
for i in range(S1HSV_imgA1D3_3.shape[0]): 
     for j in range(S1HSV_imgA1D3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1603.append(S1HSV_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_103.append(S1HSV_imgA1D3_3[i][j])

# %%
S1A1_1703= list()
S1D4_103 = list()
for i in range(S1HSV_imgA1D4_3.shape[0]): 
     for j in range(S1HSV_imgA1D4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1703.append(S1HSV_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_103.append(S1HSV_imgA1D4_3[i][j])

# %% [markdown]
# ###Img 4

# %%
S1A1_104= list()
S1A1_204 = list()
for i in range(S1HSV_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_104.append(S1HSV_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_204.append(S1HSV_imgA1A1_4[i][j])

# %%
S1A1_304= list()
S1A2_104 = list()
for i in range(S1HSV_imgA1A2_4.shape[0]): 
     for j in range(S1HSV_imgA1A2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_304.append(S1HSV_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_104.append(S1HSV_imgA1A2_4[i][j])

# %%
S1A1_404= list()
S1A3_104 = list()
for i in range(S1HSV_imgA1A3_4.shape[0]): 
     for j in range(S1HSV_imgA1A3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_404.append(S1HSV_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_104.append(S1HSV_imgA1A3_4[i][j])

# %%
S1A1_504= list()
S1A3_5104 = list()
for i in range(S1HSV_imgA1A3_54.shape[0]): 
     for j in range(S1HSV_imgA1A3_54.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_504.append(S1HSV_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5104.append(S1HSV_imgA1A3_54[i][j])

# %%
S1A1_604= list()
S1A4_104 = list()
for i in range(S1HSV_imgA1A4_4.shape[0]): 
     for j in range(S1HSV_imgA1A4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_604.append(S1HSV_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_104.append(S1HSV_imgA1A4_4[i][j])

# %%
S1A1_704= list()
S1B1_104 = list()
for i in range(S1HSV_imgA1B1_4.shape[0]): 
     for j in range(S1HSV_imgA1B1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_704.append(S1HSV_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_104.append(S1HSV_imgA1B1_4[i][j])

# %%
S1A1_804= list()
S1B2_104 = list()
for i in range(S1HSV_imgA1B2_4.shape[0]): 
     for j in range(S1HSV_imgA1B2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_804.append(S1HSV_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_104.append(S1HSV_imgA1B2_4[i][j])

# %%
S1A1_904= list()
S1B3_104 = list()
for i in range(S1HSV_imgA1B3_4.shape[0]): 
     for j in range(S1HSV_imgA1B3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_904.append(S1HSV_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_104.append(S1HSV_imgA1B3_4[i][j])

# %%
S1A1_1004= list()
S1B4_104 = list()
for i in range(S1HSV_imgA1B4_4.shape[0]): 
     for j in range(S1HSV_imgA1B4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1004.append(S1HSV_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_104.append(S1HSV_imgA1B4_4[i][j])

# %%
S1A1_1104= list()
S1C1_204= list()
for i in range(S1HSV_imgA1C1_4.shape[0]): 
     for j in range(S1HSV_imgA1C1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1104.append(S1HSV_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_204.append(S1HSV_imgA1C1_4[i][j])

# %%
S1A1_1204= list()
S1C2_104 = list()
for i in range(S1HSV_imgA1C2_4.shape[0]): 
     for j in range(S1HSV_imgA1C2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1204append(S1HSV_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_104.append(S1HSV_imgA1C2_4[i][j])

# %%
S1A1_1304= list()
S1C3_104 = list()
for i in range(S1HSV_imgA1C3_4.shape[0]): 
     for j in range(S1HSV_imgA1C3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1304.append(S1HSV_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_104.append(S1HSV_imgA1C3_4[i][j])

# %%
S1A1_1404= list()
S1C4_104 = list()
for i in range(S1HSV_imgA1C4_4.shape[0]): 
     for j in range(S1HSV_imgA1C4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1404.append(S1HSV_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_104.append(S1HSV_imgA1C4_4[i][j])

# %%
S1A1_1504= list()
S1D2_104 = list()
for i in range(S1HSV_imgA1D2_4.shape[0]): 
     for j in range(S1HSV_imgA1D2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1504.append(S1HSV_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_104.append(S1HSV_imgA1D2_4[i][j])

# %%
S1A1_1604= list()
S1D3_104 = list()
for i in range(S1HSV_imgA1D3_4.shape[0]): 
     for j in range(S1HSV_imgA1D3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1604append(S1HSV_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_104.append(S1HSV_imgA1D3_4[i][j])

# %%
S1A1_1704= list()
S1D4_104 = list()
for i in range(S1HSV_imgA1D4_4.shape[0]): 
     for j in range(S1HSV_imgA1D4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1704.append(S1HSV_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_104.append(S1HSV_imgA1D4_4[i][j])

# %% [markdown]
# ###Img 5

# %%
S1A1_105= list()
S1A1_205 = list()
for i in range(S1HSV_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_105.append(S1HSV_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_205.append(S1HSV_imgA1A1_5[i][j])

# %%
S1A1_305= list()
S1A2_105 = list()
for i in range(S1HSV_imgA1A2_5.shape[0]): 
     for j in range(S1HSV_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_305.append(S1HSV_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_105.append(S1HSV_imgA1A2_5[i][j])

# %%
S1A1_405= list()
S1A3_105 = list()
for i in range(S1HSV_imgA1A3_5.shape[0]): 
     for j in range(S1HSV_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_405.append(S1HSV_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_105.append(S1HSV_imgA1A3_5[i][j])

# %%
S1A1_505= list()
S1A3_5105 = list()
for i in range(S1HSV_imgA1A3_55.shape[0]): 
     for j in range(S1HSV_imgA1A3_55.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_505.append(S1HSV_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5105.append(S1HSV_imgA1A3_55[i][j])

# %%
S1A1_605= list()
S1A4_105 = list()
for i in range(S1HSV_imgA1A4_5.shape[0]): 
     for j in range(S1HSV_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_605.append(S1HSV_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_105.append(S1HSV_imgA1A4_5[i][j])

# %%
S1A1_705= list()
S1B1_105 = list()
for i in range(S1HSV_imgA1B1_5.shape[0]): 
     for j in range(S1HSV_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_705.append(S1HSV_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_105.append(S1HSV_imgA1B1_5[i][j])

# %%
S1A1_805= list()
S1B2_105 = list()
for i in range(S1HSV_imgA1B2_5.shape[0]): 
     for j in range(S1HSV_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_805.append(S1HSV_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_105.append(S1HSV_imgA1B2_5[i][j])

# %%
S1A1_905= list()
S1B3_105 = list()
for i in range(S1HSV_imgA1B3_5.shape[0]): 
     for j in range(S1HSV_imgA1B3_.5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_905.append(S1HSV_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_105.append(S1HSV_imgA1B3_5[i][j])

# %%
S1A1_1005= list()
S1B4_105 = list()
for i in range(S1HSV_imgA1B4_5.shape[0]): 
     for j in range(S1HSV_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1005.append(S1HSV_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_105.append(S1HSV_imgA1B4_5[i][j])

# %%
S1A1_1105= list()
S1C1_205 = list()
for i in range(S1HSV_imgA1C1_5.shape[0]): 
     for j in range(S1HSV_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1105.append(S1HSV_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_205.append(S1HSV_imgA1C1_5[i][j])

# %%
S1A1_1205= list()
S1C2_105 = list()
for i in range(S1HSV_imgA1C2_5.shape[0]): 
     for j in range(S1HSV_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1205.append(S1HSV_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_105.append(S1HSV_imgA1C2_5[i][j])

# %%
S1A1_1305= list()
S1C3_105 = list()
for i in range(S1HSV_imgA1C3_5.shape[0]): 
     for j in range(S1HSV_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1305.append(S1HSV_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_105.append(S1HSV_imgA1C3_5[i][j])

# %%
S1A1_1405= list()
S1C4_105 = list()
for i in range(S1HSV_imgA1C4_5.shape[0]): 
     for j in range(S1HSV_imgA1C4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1405.append(S1HSV_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_105.append(S1HSV_imgA1C4_5[i][j])

# %%
S1A1_1505= list()
S1D2_105 = list()
for i in range(S1HSV_imgA1D2_5.shape[0]): 
     for j in range(S1HSV_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1505.append(S1HSV_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_105.append(S1HSV_imgA1D2_5[i][j])

# %%
S1A1_1605= list()
S1D3_105 = list()
for i in range(S1HSV_imgA1D3_5.shape[0]): 
     for j in range(S1HSV_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1605.append(S1HSV_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_105.append(S1HSV_imgA1D3_5[i][j])

# %%
S1A1_1705= list()
S1D4_105 = list()
for i in range(S1HSV_imgA1D4_5.shape[0]): 
     for j in range(S1HSV_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1705.append(S1HSV_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_105.append(S1HSV_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 6

# %%
S1A1_106= list()
S1A1_206 = list()
for i in range(S1HSV_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_.6shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_106.append(S1HSV_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_206.append(S1HSV_imgA1A1_6[i][j])

# %%
S1A1_306= list()
S1A2_106 = list()
for i in range(S1HSV_imgA1A2_6.shape[0]): 
     for j in range(S1HSV_imgA1A2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_306.append(S1HSV_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_106.append(S1HSV_imgA1A2_6[i][j])

# %%
S1A1_406= list()
S1A3_106 = list()
for i in range(S1HSV_imgA1A3_6.shape[0]): 
     for j in range(S1HSV_imgA1A3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_406.append(S1HSV_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_106.append(S1HSV_imgA1A3_6[i][j])

# %%
S1A1_506= list()
S1A3_5106 = list()
for i in range(S1HSV_imgA1A3_56.shape[0]): 
     for j in range(S1HSV_imgA1A3_56.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_506.append(S1HSV_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5106.append(S1HSV_imgA1A3_56[i][j])

# %%
S1A1_606= list()
S1A4_106= list()
for i in range(S1HSV_imgA1A4_6.shape[0]): 
     for j in range(S1HSV_imgA1A4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_606.append(S1HSV_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_106.append(S1HSV_imgA1A4_6[i][j])

# %%
S1A1_706= list()
S1B1_106 = list()
for i in range(S1HSV_imgA1B1_6.shape[0]): 
     for j in range(S1HSV_imgA1B1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_706.append(S1HSV_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_106.append(S1HSV_imgA1B1_6[i][j])

# %%
S1A1_806= list()
S1B2_106 = list()
for i in range(S1HSV_imgA1B2_6.shape[0]): 
     for j in range(S1HSV_imgA1B2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_806.append(S1HSV_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_106.append(S1HSV_imgA1B2_6[i][j])

# %%
S1A1_906= list()
S1B3_106 = list()
for i in range(S1HSV_imgA1B3_6.shape[0]): 
     for j in range(S1HSV_imgA1B3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_90.append(S1HSV_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_10.append(S1HSV_imgA1B3_6[i][j])

# %%
S1A1_1006= list()
S1B4_106 = list()
for i in range(S1HSV_imgA1B4_6.shape[0]): 
     for j in range(S1HSV_imgA1B4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1006.append(S1HSV_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_106.append(S1HSV_imgA1B4_6[i][j])

# %%
S1A1_1106= list()
S1C1_206 = list()
for i in range(S1HSV_imgA1C1_6.shape[0]): 
     for j in range(S1HSV_imgA1C1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1106.append(S1HSV_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_206.append(S1HSV_imgA1C1_6[i][j])

# %%
S1A1_1206= list()
S1C2_106 = list()
for i in range(S1HSV_imgA1C2_.6shape[0]): 
     for j in range(S1HSV_imgA1C2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1206.append(S1HSV_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_106.append(S1HSV_imgA1C2_6[i][j])

# %%
S1A1_1306= list()
S1C3_106 = list()
for i in range(S1HSV_imgA1C3_6.shape[0]): 
     for j in range(S1HSV_imgA1C3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1306.append(S1HSV_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_106.append(S1HSV_imgA1C3_6[i][j])

# %%
S1A1_140= list()
S1C4_10 = list()
for i in range(S1HSV_imgA1C4_.shape[0]): 
     for j in range(S1HSV_imgA1C4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_140.append(S1HSV_imgA1C4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_10.append(S1HSV_imgA1C4_[i][j])

# %%
S1A1_1506= list()
S1D2_106 = list()
for i in range(S1HSV_imgA1D2_6.shape[0]): 
     for j in range(S1HSV_imgA1D2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1506.append(S1HSV_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_106.append(S1HSV_imgA1D2_6[i][j])

# %%
S1A1_1606= list()
S1D3_106 = list()
for i in range(S1HSV_imgA1D3_6.shape[0]): 
     for j in range(S1HSV_imgA1D3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1606.append(S1HSV_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_106.append(S1HSV_imgA1D3_6[i][j])

# %%
S1A1_1706= list()
S1D4_106 = list()
for i in range(S1HSV_imgA1D4_6.shape[0]): 
     for j in range(S1HSV_imgA1D4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1706.append(S1HSV_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_106.append(S1HSV_imgA1D4_6[i][j])

# %% [markdown]
# ###Img 7

# %%
S1A1_107= list()
S1A1_2067 = list()
for i in range(S1HSV_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_107.append(S1HSV_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_207.append(S1HSV_imgA1A1_7[i][j])

# %%
S1A1_307= list()
S1A2_107 = list()
for i in range(S1HSV_imgA1A2_7.shape[0]): 
     for j in range(S1HSV_imgA1A2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_307.append(S1HSV_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_107.append(S1HSV_imgA1A2_7[i][j])

# %%
S1A1_407= list()
S1A3_107 = list()
for i in range(S1HSV_imgA1A3_7.shape[0]): 
     for j in range(S1HSV_imgA1A3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_407.append(S1HSV_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_107.append(S1HSV_imgA1A3_7[i][j])

# %%
S1A1_507= list()
S1A3_5107 = list()
for i in range(S1HSV_imgA1A3_57.shape[0]): 
     for j in range(S1HSV_imgA1A3_57.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_507.append(S1HSV_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5107.append(S1HSV_imgA1A3_57[i][j])

# %%
S1A1_607= list()
S1A4_107 = list()
for i in range(S1HSV_imgA1A4_7.shape[0]): 
     for j in range(S1HSV_imgA1A4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_607.append(S1HSV_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_107.append(S1HSV_imgA1A4_7[i][j])

# %%
S1A1_707= list()
S1B1_107 = list()
for i in range(S1HSV_imgA1B1_7.shape[0]): 
     for j in range(S1HSV_imgA1B1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_707.append(S1HSV_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_107.append(S1HSV_imgA1B1_7i][j])

# %%
S1A1_807= list()
S1B2_107 = list()
for i in range(S1HSV_imgA1B2_7.shape[0]): 
     for j in range(S1HSV_imgA1B2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_807.append(S1HSV_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_107.append(S1HSV_imgA1B2_7[i][j])

# %%
S1A1_907= list()
S1B3_107 = list()
for i in range(S1HSV_imgA1B3_7.shape[0]): 
     for j in range(S1HSV_imgA1B3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_907.append(S1HSV_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_107.append(S1HSV_imgA1B3_7[i][j])

# %%
S1A1_1007= list()
S1B4_107 = list()
for i in range(S1HSV_imgA1B4_7.shape[0]): 
     for j in range(S1HSV_imgA1B4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1007.append(S1HSV_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_107.append(S1HSV_imgA1B4_7[i][j])

# %%
S1A1_1107= list()
S1C1_207 = list()
for i in range(S1HSV_imgA1C1_7.shape[0]): 
     for j in range(S1HSV_imgA1C1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1107.append(S1HSV_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_207append(S1HSV_imgA1C1_7[i][j])

# %%
S1A1_1207= list()
S1C2_107 = list()
for i in range(S1HSV_imgA1C2_7.shape[0]): 
     for j in range(S1HSV_imgA1C2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1207.append(S1HSV_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_107.append(S1HSV_imgA1C2_7[i][j])

# %%
S1A1_1307= list()
S1C3_107 = list()
for i in range(S1HSV_imgA1C3_7.shape[0]): 
     for j in range(S1HSV_imgA1C3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1307.append(S1HSV_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_107.append(S1HSV_imgA1C3_[7i][j])

# %%
S1A1_1407= list()
S1C4_107 = list()
for i in range(S1HSV_imgA1C4_7.shape[0]): 
     for j in range(S1HSV_imgA1C4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1407.append(S1HSV_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_107.append(S1HSV_imgA1C4_7[i][j])

# %%
S1A1_1507= list()
S1D2_107 = list()
for i in range(S1HSV_imgA1D2_7.shape[0]): 
     for j in range(S1HSV_imgA1D2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1507.append(S1HSV_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_107.append(S1HSV_imgA1D2_7[i][j])

# %%
S1A1_1607= list()
S1D3_107 = list()
for i in range(S1HSV_imgA1D3_7.shape[0]): 
     for j in range(S1HSV_imgA1D3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1607.append(S1HSV_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_107.append(S1HSV_imgA1D3_7[i][j])

# %%
S1A1_1707= list()
S1D4_107 = list()
for i in range(S1HSV_imgA1D4_7.shape[0]): 
     for j in range(S1HSV_imgA1D4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1707.append(S1HSV_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_107.append(S1HSV_imgA1D4_7[i][j])

# %% [markdown]
# ###Img 8

# %%
S1A1_108= list()
S1A1_208 = list()
for i in range(S1HSV_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_108.append(S1HSV_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_208.append(S1HSV_imgA1A1_8[i][j])

# %%
S1A1_308= list()
S1A2_108 = list()
for i in range(S1HSV_imgA1A2_8shape[0]): 
     for j in range(S1HSV_imgA1A2_8shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_308.append(S1HSV_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_108.append(S1HSV_imgA1A2_8[i][j])

# %%
S1A1_408= list()
S1A3_108 = list()
for i in range(S1HSV_imgA1A3_8.shape[0]): 
     for j in range(S1HSV_imgA1A3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_408.append(S1HSV_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_108.append(S1HSV_imgA1A3_8[i][j])

# %%
S1A1_508= list()
S1A3_5108 = list()
for i in range(S1HSV_imgA1A3_58.shape[0]): 
     for j in range(S1HSV_imgA1A3_58.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_508.append(S1HSV_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5108.append(S1HSV_imgA1A3_58[i][j])

# %%
S1A1_608= list()
S1A4_108 = list()
for i in range(S1HSV_imgA1A4_8.shape[0]): 
     for j in range(S1HSV_imgA1A4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_608.append(S1HSV_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_108append(S1HSV_imgA1A4_8[i][j])

# %%
S1A1_708= list()
S1B1_108 = list()
for i in range(S1HSV_imgA1B1_8.shape[0]): 
     for j in range(S1HSV_imgA1B1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_708.append(S1HSV_imgA1B1_8i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_108.append(S1HSV_imgA1B1_8[i][j])

# %%
S1A1_808= list()
S1B2_108 = list()
for i in range(S1HSV_imgA1B2_8.shape[0]): 
     for j in range(S1HSV_imgA1B2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_808.append(S1HSV_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_108.append(S1HSV_imgA1B2_8[i][j])

# %%
S1A1_908= list()
S1B3_108 = list()
for i in range(S1HSV_imgA1B3_8.shape[0]): 
     for j in range(S1HSV_imgA1B3_.8shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_908.append(S1HSV_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_108.append(S1HSV_imgA1B3_8[i][j])

# %%
S1A1_1008= list()
S1B4_108 = list()
for i in range(S1HSV_imgA1B4_8.shape[0]): 
     for j in range(S1HSV_imgA1B4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_100.append(S1HSV_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_10.append(S1HSV_imgA1B4_8[i][j])

# %%
S1A1_1108= list()
S1C1_208 = list()
for i in range(S1HSV_imgA1C1_8.shape[0]): 
     for j in range(S1HSV_imgA1C1_.8shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1108.append(S1HSV_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_208.append(S1HSV_imgA1C1_8[i][j])

# %%
S1A1_1208= list()
S1C2_108 = list()
for i in range(S1HSV_imgA1C2_8.shape[0]): 
     for j in range(S1HSV_imgA1C2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1208.append(S1HSV_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_108.append(S1HSV_imgA1C2_8[i][j])

# %%
S1A1_1308= list()
S1C3_108 = list()
for i in range(S1HSV_imgA1C3_8.shape[0]): 
     for j in range(S1HSV_imgA1C3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1308.append(S1HSV_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_108.append(S1HSV_imgA1C3_8[i][j])

# %%
S1A1_1408= list()
S1C4_108 = list()
for i in range(S1HSV_imgA1C4_8.shape[0]): 
     for j in range(S1HSV_imgA1C4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1408.append(S1HSV_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_108append(S1HSV_imgA1C4_8[i][j])

# %%
S1A1_1508= list()
S1D2_108 = list()
for i in range(S1HSV_imgA1D2_8.shape[0]): 
     for j in range(S1HSV_imgA1D2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1508.append(S1HSV_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_108.append(S1HSV_imgA1D2_8[i][j])

# %%
S1A1_160= list()
S1D3_10 = list()
for i in range(S1HSV_imgA1D3_.shape[0]): 
     for j in range(S1HSV_imgA1D3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_160.append(S1HSV_imgA1D3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_10.append(S1HSV_imgA1D3_[i][j])

# %%
S1A1_1708= list()
S1D4_108 = list()
for i in range(S1HSV_imgA1D4_.8shape[0]): 
     for j in range(S1HSV_imgA1D4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1708.append(S1HSV_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_108.append(S1HSV_imgA1D4_8[i][j])

# %% [markdown]
# ###Img 9

# %%
S1A1_109= list()
S1A1_209 = list()
for i in range(S1HSV_imgA1A1_9shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_109.append(S1HSV_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_209.append(S1HSV_imgA1A1_9[i][j])

# %%
S1A1_309= list()
S1A2_109 = list()
for i in range(S1HSV_imgA1A2_.9shape[0]): 
     for j in range(S1HSV_imgA1A2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_309.append(S1HSV_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_109append(S1HSV_imgA1A2_[9i][j])

# %%
S1A1_409= list()
S1A3_109 = list()
for i in range(S1HSV_imgA1A3_9.shape[0]): 
     for j in range(S1HSV_imgA1A3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_409.append(S1HSV_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_109.append(S1HSV_imgA1A3_9[i][j])

# %%
S1A1_509= list()
S1A3_5109 = list()
for i in range(S1HSV_imgA1A3_59.shape[0]): 
     for j in range(S1HSV_imgA1A3_59.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_509.append(S1HSV_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5109.append(S1HSV_imgA1A3_59[i][j])

# %%
S1A1_609= list()
S1A4_109 = list()
for i in range(S1HSV_imgA1A4_9.shape[0]): 
     for j in range(S1HSV_imgA1A4_.9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_609.append(S1HSV_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_109.append(S1HSV_imgA1A4_9[i][j])

# %%
S1A1_709= list()
S1B1_109= list()
for i in range(S1HSV_imgA1B1_9.shape[0]): 
     for j in range(S1HSV_imgA1B1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_709.append(S1HSV_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_109.append(S1HSV_imgA1B19[i][j])

# %%
S1A1_809= list()
S1B2_109 = list()
for i in range(S1HSV_imgA1B2_9.shape[0]): 
     for j in range(S1HSV_imgA1B2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_809.append(S1HSV_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_109.append(S1HSV_imgA1B2_9[i][j])

# %%
S1A1_909= list()
S1B3_109 = list()
for i in range(S1HSV_imgA1B3_.shape[0]): 
     for j in range(S1HSV_imgA1B3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_90.append(S1HSV_imgA1B3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_10.append(S1HSV_imgA1B3_[i][j])

# %%
S1A1_1009= list()
S1B4_109 = list()
for i in range(S1HSV_imgA1B4_9.shape[0]): 
     for j in range(S1HSV_imgA1B4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1009.append(S1HSV_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_109.append(S1HSV_imgA1B4_9[i][j])

# %%
S1A1_1109= list()
S1C1_209 = list()
for i in range(S1HSV_imgA1C1_9.shape[0]): 
     for j in range(S1HSV_imgA1C1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1109.append(S1HSV_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_209.append(S1HSV_imgA1C1_9[i][j])

# %%
S1A1_1209= list()
S1C2_109 = list()
for i in range(S1HSV_imgA1C2_9.shape[0]): 
     for j in range(S1HSV_imgA1C2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1209.append(S1HSV_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_109.append(S1HSV_imgA1C2_9[i][j])

# %%
S1A1_1309= list()
S1C3_109 = list()
for i in range(S1HSV_imgA1C3_9.shape[0]): 
     for j in range(S1HSV_imgA1C3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1309.append(S1HSV_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_109.append(S1HSV_imgA1C3_9[i][j])

# %%
S1A1_1409= list()
S1C4_109 = list()
for i in range(S1HSV_imgA1C4_9.shape[0]): 
     for j in range(S1HSV_imgA1C4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1409.append(S1HSV_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_109.append(S1HSV_imgA1C4_9[i][j])

# %%
S1A1_1509= list()
S1D2_109 = list()
for i in range(S1HSV_imgA1D2_9.shape[0]): 
     for j in range(S1HSV_imgA1D2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1509.append(S1HSV_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_109.append(S1HSV_imgA1D2_9[i][j])

# %%
S1A1_1609= list()
S1D3_109 = list()
for i in range(S1HSV_imgA1D3_9.shape[0]): 
     for j in range(S1HSV_imgA1D3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1609.append(S1HSV_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_109.append(S1HSV_imgA1D3_9[i][j])

# %%
S1A1_1709= list()
S1D4_109 = list()
for i in range(S1HSV_imgA1D4_9.shape[0]): 
     for j in range(S1HSV_imgA1D4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1709.append(S1HSV_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_109.append(S1HSV_imgA1D4_9[i][j])

# %% [markdown]
# ###Img 10

# %%
S1A1_110= list()
S1A1_210 = list()
for i in range(S1HSV_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_110.append(S1HSV_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_2010.append(S1HSV_imgA1A1_10[i][j])

# %%
S1A1_310= list()
S1A2_110 = list()
for i in range(S1HSV_imgA1A2_10.shape[0]): 
     for j in range(S1HSV_imgA1A2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_310.append(S1HSV_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_110.append(S1HSV_imgA1A2_10[i][j])

# %%
S1A1_410= list()
S1A3_110 = list()
for i in range(S1HSV_imgA1A3_10.shape[0]): 
     for j in range(S1HSV_imgA1A3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_410.append(S1HSV_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_101.append(S1HSV_imgA1A3_10[i][j])

# %%
S1A1_510= list()
S1A3_510 = list()
for i in range(S1HSV_imgA1A3_510.shape[0]): 
     for j in range(S1HSV_imgA1A3_510.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_510.append(S1HSV_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_510.append(S1HSV_imgA1A3_510[i][j])

# %%
S1A1_610= list()
S1A4_110 = list()
for i in range(S1HSV_imgA1A4_10.shape[0]): 
     for j in range(S1HSV_imgA1A4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_610.append(S1HSV_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_110.append(S1HSV_imgA1A4_10[i][j])

# %%
S1A1_710= list()
S1B1_110 = list()
for i in range(S1HSV_imgA1B1_10.shape[0]): 
     for j in range(S1HSV_imgA1B1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_710.append(S1HSV_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_110.append(S1HSV_imgA1B1_10[i][j])

# %%
S1A1_810= list()
S1B2_110 = list()
for i in range(S1HSV_imgA1B2_10.shape[0]): 
     for j in range(S1HSV_imgA1B2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_810.append(S1HSV_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_110.append(S1HSV_imgA1B2_10[i][j])

# %%
S1A1_910= list()
S1B3_110 = list()
for i in range(S1HSV_imgA1B3_10.shape[0]): 
     for j in range(S1HSV_imgA1B3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_910.append(S1HSV_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_110.append(S1HSV_imgA1B3_10[i][j])

# %%
S1A1_1010= list()
S1B4_110 = list()
for i in range(S1HSV_imgA1B4_10.shape[0]): 
     for j in range(S1HSV_imgA1B4_.10shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1010.append(S1HSV_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_110.append(S1HSV_imgA1B4_10[i][j])

# %%
S1A1_1110= list()
S1C1_210 = list()
for i in range(S1HSV_imgA1C1_10.shape[0]): 
     for j in range(S1HSV_imgA1C1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1110.append(S1HSV_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_210.append(S1HSV_imgA1C1_10[i][j])

# %%
S1A1_1210= list()
S1C2_110 = list()
for i in range(S1HSV_imgA1C2_10.shape[0]): 
     for j in range(S1HSV_imgA1C2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1210.append(S1HSV_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_10.append(S1HSV_imgA1C2_10[i][j])

# %%
S1A1_1310= list()
S1C3_110 = list()
for i in range(S1HSV_imgA1C3_10shape[0]): 
     for j in range(S1HSV_imgA1C3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1310.append(S1HSV_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_110.append(S1HSV_imgA1C3_10[i][j])

# %%
S1A1_1410= list()
S1C4_110 = list()
for i in range(S1HSV_imgA1C4_10.shape[0]): 
     for j in range(S1HSV_imgA1C4_.10shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1410.append(S1HSV_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_110.append(S1HSV_imgA1C4_10[i][j])

# %%
S1A1_1510= list()
S1D2_110 = list()
for i in range(S1HSV_imgA1D2_10.shape[0]): 
     for j in range(S1HSV_imgA1D2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1510.append(S1HSV_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_110.append(S1HSV_imgA1D2_10[i][j])

# %%
S1A1_1610= list()
S1D3_110 = list()
for i in range(S1HSV_imgA1D3_10.shape[0]): 
     for j in range(S1HSV_imgA1D3_.10shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_160.append(S1HSV_imgA1D310_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_110.append(S1HSV_imgA1D3_10[i][j])

# %%
S1A1_1710= list()
S1D4_110 = list()
for i in range(S1HSV_imgA1D4_10.shape[0]): 
     for j in range(S1HSV_imgA1D4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1710.append(S1HSV_imgA1D4_10i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_110.append(S1HSV_imgA1D4_10[i][j])

# %% [markdown]
# ##Set2

# %% [markdown]
# ###RGB

# %%
S2A1_1= list()
S2A1_2 = list()
for i in range(S2RGB_imgA1A1_1.shape[0]): 
     for j in range(S2RGB_imgA1A1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1.append(S2RGB_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_2.append(S2RGB_imgA1A1_1[i][j])

# %%
S2A1_3= list()
S2A2_1 = list()
for i in range(S2RGB_imgA1A2_1.shape[0]): 
     for j in range(S2RGB_imgA1A2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_3.append(S2RGB_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_1.append(S2RGB_imgA1A2_1[i][j])

# %%
S2A1_4= list()
S2A3_1 = list()
for i in range(S2RGB_imgA1A3_1.shape[0]): 
     for j in range(S2RGB_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_4.append(S2RGB_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_1.append(S2RGB_imgA1A3_1[i][j])

# %%
S2A1_5= list()
S2A3_51 = list()
for i in range(S2RGB_imgA1A3_51.shape[0]): 
     for j in range(S2RGB_imgA1A3_51.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_5.append(S2RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_51.append(S2RGB_imgA1A3_51[i][j])

# %%
S2A1_6= list()
S2A4_1 = list()
for i in range(S2RGB_imgA1A4_1.shape[0]): 
     for j in range(S2RGB_imgA1A4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_6.append(S2RGB_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_1.append(S2RGB_imgA1A4_1[i][j])

# %%
S2A1_7= list()
S2B1_1 = list()
for i in range(S2RGB_imgA1B1_1.shape[0]): 
     for j in range(S2RGB_imgA1B1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_7.append(S2RGB_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_1.append(S2RGB_imgA1B1_1[i][j])

# %%
S2A1_8= list()
S2B2_1 = list()
for i in range(S2RGB_imgA1B2_1.shape[0]): 
     for j in range(S2RGB_imgA1B2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_8.append(S2RGB_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_1.append(S2RGB_imgA1B2_1[i][j])

# %%
S2A1_9= list()
S2B3_1 = list()
for i in range(S2RGB_imgA1B3_1.shape[0]): 
     for j in range(S2RGB_imgA1B3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_9.append(S2RGB_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_1.append(S2RGB_imgA1B3_1[i][j])

# %%
S2A1_10= list()
S2B4_1 = list()
for i in range(S2RGB_imgA1B4_1.shape[0]): 
     for j in range(S2RGB_imgA1B4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_10.append(S2RGB_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_1.append(S2RGB_imgA1B4_1[i][j])

# %%
S2A1_11= list()
S2C1_1 = list()
for i in range(S2RGB_imgA1C1_1.shape[0]): 
     for j in range(S2RGB_imgA1C1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_11.append(S2RGB_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_1.append(S2RGB_imgA1C1_1[i][j])

# %%
S2A1_12= list()
S2C2_1 = list()
for i in range(S2RGB_imgA1C2_1.shape[0]): 
     for j in range(S2RGB_imgA1C2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_12.append(S2RGB_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_1.append(S2RGB_imgA1C2_1[i][j])

# %%
S2A1_13= list()
S2C3_1 = list()
for i in range(S2RGB_imgA1C3_1.shape[0]): 
     for j in range(S2RGB_imgA1C3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_13.append(S2RGB_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_1.append(S2RGB_imgA1C3_1[i][j])

# %%
S2A1_14= list()
S2C4_1 = list()
for i in range(S2RGB_imgA1C4_1.shape[0]): 
     for j in range(S2RGB_imgA1C4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_14.append(S2RGB_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_1.append(S2RGB_imgA1C4_1[i][j])

# %%
S2A1_15= list()
S2D2_1 = list()
for i in range(S2RGB_imgA1C2_1.shape[0]): 
     for j in range(S2RGB_imgA1D2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_15.append(S2RGB_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_1.append(S2RGB_imgA1D2_1[i][j])

# %%
S2A1_16= list()
S2D3_1 = list()
for i in range(S2RGB_imgA1D3_1.shape[0]): 
     for j in range(S2RGB_imgA1D3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_16.append(S2RGB_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_1.append(S2RGB_imgA1D3_1[i][j])

# %%
S2A1_17= list()
S2D4_1 = list()
for i in range(S2RGB_imgA1D4_1.shape[0]): 
     for j in range(S2RGB_imgA1D4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_14.append(S2RGB_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_1.append(S2RGB_imgA1D4_1[i][j])

# %% [markdown]
# ###Img 2

# %%
S2A1_102= list()
S2A1_202= list()
for i in range(S2RGB_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2RGB_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2RGB_imgA1A1_2[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2RGB_imgA1A2_2.shape[0]): 
     for j in range(S2RGB_imgA1A2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2RGB_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_102.append(S2RGB_imgA1A2_2[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2RGB_imgA1A3_2.shape[0]): 
     for j in range(S2RGB_imgA1A3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2RGB_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2RGB_imgA1A3_2[i][j])

# %%
S2A1_502= list()
S2A3_5102 = list()
for i in range(S2RGB_imgA1A3_52.shape[0]): 
     for j in range(S2RGB_imgA1A3_52.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S21_502.append(S2RGB_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2RGB_imgA1A3_52[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2RGB_imgA1A4_2.shape[0]): 
     for j in range(S2RGB_imgA1A4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2RGB_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2RGB_imgA1A4_2[i][j])

# %%
S2A1_702= list()
S2B1_102 = list()
for i in range(S2RGB_imgA1B1_2.shape[0]): 
     for j in range(S2RGB_imgA1B1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2RGB_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2RGB_imgA1B1_2[i][j])

# %%
S2A1_80= list()
S2B2_10 = list()
for i in range(S2RGB_imgA1B2_.shape[0]): 
     for j in range(S2RGB_imgA1B2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_80.append(S2RGB_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_10.append(S2RGB_imgA1B2_[i][j])

# %%
SA21_902= list()
S2B3_102 = list()
for i in range(S2RGB_imgA1B3_2.shape[0]): 
     for j in range(S2RGB_imgA1B3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2RGB_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2RGB_imgA1B3_2[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SRGB_imgA1B4_2.shape[0]): 
     for j in range(SRGB_imgA1B4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SRGB_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SRGB_imgA1B4_2[i][j])

# %%
S2A1_1102= list()
S2C1_202 = list()
for i in range(S2RGB_imgA1C1_.2shape[0]): 
     for j in range(S2RGB_imgA1C1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2RGB_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_202.append(S2RGB_imgA1C1_2[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2RGB_imgA1C2_2.shape[0]): 
     for j in range(S2RGB_imgA1C2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2RGB_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(SR2GB_imgA1C2_2[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2RGB_imgA1C3_2.shape[0]): 
     for j in range(S2RGB_imgA1C3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2RGB_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2RGB_imgA1C3_2[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2RGB_imgA1C4_2.shape[0]): 
     for j in range(S2RGB_imgA1C4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2RGB_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2RGB_imgA1C4_2[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2RGB_imgA1D2_2.shape[0]): 
     for j in range(S2RGB_imgA1D2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2RGB_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2RGB_imgA1D2_2[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2RGB_imgA1D3_2.shape[0]): 
     for j in range(S2RGB_imgA1D3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2RGB_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2RGB_imgA1D3_2[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2RGB_imgA1D4_2.shape[0]): 
     for j in range(S2RGB_imgA1D4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1702.append(S2RGB_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2RGB_imgA1D4_2[i][j])

# %% [markdown]
# ###Img 3

# %%
S2A1_103= list()
S2A1_203= list()
for i in range(S2RGB_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_103.append(S2RGB_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_203.append(S2RGB_imgA1A1_3[i][j])

# %%
S2A1_303= list()
S2A2_103 = list()
for i in range(S2RGB_imgA1A2_3.shape[0]): 
     for j in range(S2RGB_imgA1A2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_303.append(S2RGB_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_103.append(S2RGB_imgA1A2_3[i][j])

# %%
S2A1_403= list()
S2A3_103 = list()
for i in range(S2RGB_imgA1A3_3.shape[0]): 
     for j in range(S2RGB_imgA1A3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_403.append(S2RGB_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_103.append(S2RGB_imgA1A3_3[i][j])

# %%
S2A1_503= list()
S2A3_5103= list()
for i in range(S2RGB_imgA1A3_53.shape[0]): 
     for j in range(S2RGB_imgA1A3_53.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_503.append(S2RGB_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5103.append(S2RGB_imgA1A3_53[i][j])

# %%
S2A1_603= list()
S2A4_103 = list()
for i in range(S2RGB_imgA1A4_.3shape[0]): 
     for j in range(S2RGB_imgA1A4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_603.append(S2RGB_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_103.append(S2RGB_imgA1A4_3[i][j])

# %%
S2A1_703= list()
S2B1_103 = list()
for i in range(S2RGB_imgA1B1_3.shape[0]): 
     for j in range(S2RGB_imgA1B1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_703.append(S2RGB_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_103.append(S2RGB_imgA1B1_3[i][j])

# %%
S2A1_803= list()
S2B2_103 = list()
for i in range(S2RGB_imgA1B2_3.shape[0]): 
     for j in range(S2RGB_imgA1B2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_803.append(S2RGB_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_103.append(S2RGB_imgA1B2_3[i][j])

# %%
S2A1_903= list()
S2B3_103 = list()
for i in range(S2RGB_imgA1B3_3.shape[0]): 
     for j in range(S2RGB_imgA1B3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_903.append(S2RGB_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_103.append(S2RGB_imgA1B3_3[i][j])

# %%
S2A1_100= list()
S2B4_10 = list()
for i in range(S2RGB_imgA1B4_.shape[0]): 
     for j in range(S2RGB_imgA1B4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_100.append(S2RGB_imgA1B4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_10.append(S2RGB_imgA1B4_[i][j])

# %%
S2A21_1103= list()
S2C1_203 = list()
for i in range(S2RGB_imgA1C1_3.shape[0]): 
     for j in range(S2RGB_imgA1C1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1103.append(S2RGB_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_203.append(S2RGB_imgA1C1_3[i][j])

# %%
S2A1_1203= list()
S2C2_103 = list()
for i in range(S2RGB_imgA1C2_3.shape[0]): 
     for j in range(S2RGB_imgA1C2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1203.append(S2RGB_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_103.append(S2RGB_imgA1C2_3[i][j])

# %%
S2A1_1303= list()
S2C3_103 = list()
for i in range(S2RGB_imgA1C3_3.shape[0]): 
     for j in range(S2RGB_imgA1C3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_130.append(S2RGB_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_10.append(S2RGB_imgA1C3_3[i][j])

# %%
S2A1_140= list()
S2C4_10 = list()
for i in range(S2RGB_imgA1C4_.shape[0]): 
     for j in range(S2RGB_imgA1C4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_140.append(S2RGB_imgA1C4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_10.append(S2RGB_imgA1C4_[i][j])

# %%
S2A1_150= list()
S2D2_10 = list()
for i in range(S2RGB_imgA1D2_.shape[0]): 
     for j in range(S2RGB_imgA1D2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_150.append(S2RGB_imgA1D2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_10.append(S2RGB_imgA1D2_[i][j])

# %%
S2A1_1603= list()
S2D3_103 = list()
for i in range(S1RGB_imgA1D3_3.shape[0]): 
     for j in range(S1RGB_imgA1D3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1603.append(SRGB_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_103.append(SRGB_imgA1D3_3[i][j])

# %%
S2A1_1703= list()
S2D4_103= list()
for i in range(S2RGB_imgA1D4_3.shape[0]): 
     for j in range(S2RGB_imgA1D4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1703.append(S2RGB_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_103.append(S2RGB_imgA1D4_3[i][j])

# %% [markdown]
# ###Img 4

# %%
S2A1_104= list()
S2A1_204= list()
for i in range(S2RGB_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_104.append(S2RGB_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_204.append(S2RGB_imgA1A1_4[i][j])

# %%
S2A1_304= list()
S2A2_104= list()
for i in range(S2RGB_imgA1A2_4.shape[0]): 
     for j in range(S2RGB_imgA1A2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_304.append(S2RGB_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_104.append(S2RGB_imgA1A2_4[i][j])

# %%
S2A1_404= list()
S2A3_104 = list()
for i in range(SR2GB_imgA1A3_4.shape[0]): 
     for j in range(S2RGB_imgA1A3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_404.append(S2RGB_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_104.append(S2RGB_imgA1A3_4[i][j])

# %%
S2A1_504= list()
S2A3_5104 = list()
for i in range(S2RGB_imgA1A3_54.shape[0]): 
     for j in range(S2RGB_imgA1A3_54.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_504.append(S2RGB_imgA1A3_514[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5104.append(S2RGB_imgA1A3_54[i][j])

# %%
S2A1_604= list()
S2A4_104 = list()
for i in range(S2RGB_imgA1A4_4.shape[0]): 
     for j in range(S2RGB_imgA1A4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_604.append(S2RGB_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_104.append(S2RGB_imgA1A4_4[i][j])

# %%
S2A1_704= list()
S2B1_104 = list()
for i in range(S2RGB_imgA1B1_4.shape[0]): 
     for j in range(S2RGB_imgA1B1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_704.append(S2RGB_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_104.append(S2RGB_imgA1B1_4[i][j])

# %%
S2A1_804= list()
S2B2_104 = list()
for i in range(S2RGB_imgA1B2_4.shape[0]): 
     for j in range(S2RGB_imgA1B2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_804.append(SRGB_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_104.append(SRGB_imgA1B2_4[i][j])

# %%
S2A1_90= list()
S2B3_10 = list()
for i in range(S2GB_imgA1B3_.shape[0]): 
     for j in range(S2RGB_imgA1B3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_90.append(S2RGB_imgA1B3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_10.append(S2RGB_imgA1B3_[i][j])

# %%
S2A1_1004= list()
S2B4_104 = list()
for i in range(S2RGB_imgA1B4_4.shape[0]): 
     for j in range(S2RGB_imgA1B4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1004.append(S2RGB_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_104.append(S2RGB_imgA1B4_4[i][j])

# %%
S2A1_1104= list()
S2C1_204 = list()
for i in range(S2RGB_imgA1C1_4.shape[0]): 
     for j in range(S2RGB_imgA1C1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1104.append(S2RGB_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_204.append(S2RGB_imgA1C1_4[i][j])

# %%
S2A1_1204= list()
S2C2_104= list()
for i in range(S2RGB_imgA1C2_4.shape[0]): 
     for j in range(S2RGB_imgA1C2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1204.append(S2RGB_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_104.append(S2RGB_imgA1C2_4[i][j])

# %%
S2A1_1304= list()
S2C3_104 = list()
for i in range(S2RGB_imgA1C3_4.shape[0]): 
     for j in range(S2RGB_imgA1C3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1304.append(S2RGB_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_104.append(S2RGB_imgA1C3_4[i][j])

# %%
S2A1_1404= list()
S2C4_104 = list()
for i in range(S2RGB_imgA1C4_4.shape[0]): 
     for j in range(S2RGB_imgA1C4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1404.append(S2RGB_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_104.append(S2RGB_imgA1C4_4[i][j])

# %%
S2A1_1504= list()
S2D2_104 = list()
for i in range(S2RGB_imgA1D2_4.shape[0]): 
     for j in range(S2RGB_imgA1D2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1504.append(S2RGB_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_104.append(S2RGB_imgA1D2_4[i][j])

# %%
S2A1_1604= list()
S2D3_104 = list()
for i in range(S2RGB_imgA1D3_4.shape[0]): 
     for j in range(S2RGB_imgA1D3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1604.append(S2RGB_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_104.append(S2RGB_imgA1D3_4[i][j])

# %%
S2A1_1704= list()
S2D4_104 = list()
for i in range(S2RGB_imgA1D4_4.shape[0]): 
     for j in range(SRGB_imgA1D4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1704.append(S2RGB_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_104.append(S2RGB_imgA1D4_4[i][j])

# %% [markdown]
# ###Img 5

# %%
S2A1_105= list()
S2A1_205= list()
for i in range(S2RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_105.append(S2RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_205.append(S2RGB_imgA1A1_5[i][j])

# %%
S2A1_305= list()
S2A2_105 = list()
for i in range(S2RGB_imgA1A2_5.shape[0]): 
     for j in range(S2RGB_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_305.append(S2RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_105.append(S2RGB_imgA1A2_5[i][j])

# %%
S2A1_405= list()
S2A3_105= list()
for i in range(S2RGB_imgA1A3_5.shape[0]): 
     for j in range(S2RGB_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_405.append(S2RGB_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_105.append(S2RGB_imgA1A3_5[i][j])

# %%
S21_505= list()
S2A3_5105 = list()
for i in range(SRGB_5imgA1A3_5.shape[0]): 
     for j in range(S2RGB_5imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_505.append(S2RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5105.append(S2RGB_imgA1A3_55[i][j])

# %%
S2A1_605= list()
S2A4_105 = list()
for i in range(S2RGB_imgA1A4_5.shape[0]): 
     for j in range(S2RGB_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_605.append(S2RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_105.append(S2RGB_imgA1A4_5[i][j])

# %%
SA1_705= list()
S2B1_105 = list()
for i in range(S2RGB_imgA1B1_5.shape[0]): 
     for j in range(S2RGB_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S21_705.append(SRGB_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_105.append(S2RGB_imgA1B1_5[i][j])

# %%
S2A1_805= list()
S2B2_105 = list()
for i in range(S2RGB_imgA1B2_5.shape[0]): 
     for j in range(S2RGB_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_805.append(S2RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_105.append(S2RGB_imgA1B2_5[i][j])

# %%
S2A1_905= list()
S2B3_105 = list()
for i in range(S2RGB_imgA1B3_5.shape[0]): 
     for j in range(S2RGB_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_905.append(S2RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_105.append(S2RGB_imgA1B3_5[i][j])

# %%
S2A21_1005= list()
S2B4_105 = list()
for i in range(S2RGB_imgA1B4_5.shape[0]): 
     for j in range(S2RGB_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1005.append(S2RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_105.append(S2RGB_imgA1B4_5[i][j])

# %%
S2A1_1105= list()
S2C1_205 = list()
for i in range(S2RGB_imgA1C1_5.shape[0]): 
     for j in range(S2RGB_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1105.append(S2RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_205.append(S2RGB_imgA1C1_5[i][j])

# %%
S2A1_1205= list()
S2C2_105 = list()
for i in range(S2RGB_imgA1C2_5.shape[0]): 
     for j in range(S2RGB_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1205.append(S2RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_105.append(S2RGB_imgA1C2_5[i][j])

# %%
S2A1_1305= list()
S2C3_105 = list()
for i in range(S2RGB_imgA1C3_5.shape[0]): 
     for j in range(S2RGB_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1305.append(S2RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_105.append(S2RGB_imgA1C3_5[i][j])

# %%
S2A1_1405= list()
S2C4_105= list()
for i in range(S2RGB_imgA1C4_.shape[0]): 
     for j in range(S2RGB_imgA1C4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1405.append(S2RGB_imgA1C4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_105.append(S2RGB_imgA1C4_[i][j])

# %%
S2A1_1505= list()
S2D2_105 = list()
for i in range(S2RGB_imgA1D2_5.shape[0]): 
     for j in range(S2RGB_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1505.append(S2RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_105.append(S2RGB_imgA1D2_5[i][j])

# %%
S2A1_1605= list()
S2D3_105 = list()
for i in range(S2RGB_imgA1D3_5.shape[0]): 
     for j in range(S2RGB_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S21_1605.append(S2RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_105.append(S2RGB_imgA1D3_5[i][j])

# %%
S2A1_1705= list()
S2D4_105 = list()
for i in range(S2RGB_imgA1D4_5.shape[0]): 
     for j in range(S2RGB_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1705.append(S2RGB_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_105.append(S2RGB_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 6

# %%
S2A1_105= list()
S2A1_205= list()
for i in range(S2RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_105.append(S2RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_205.append(S2RGB_imgA1A1_5[i][j])

# %%
S2A1_305= list()
S2A2_105 = list()
for i in range(S2RGB_imgA1A2_5.shape[0]): 
     for j in range(S2RGB_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_305.append(S2RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_105.append(S2RGB_imgA1A2_5[i][j])

# %%
S2A1_405= list()
S2A3_105 = list()
for i in range(S2RGB_imgA1A3_5.shape[0]): 
     for j in range(S2RGB_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_405.append(S2RGB_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_105.append(S2RGB_imgA1A3_5[i][j])

# %%
S2A1_505= list()
S2A3_5105 = list()
for i in range(S2RGB_imgA1A3_55.shape[0]): 
     for j in range(S2RGB_imgA1A3_55.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_505.append(S2RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5105.append(S2RGB_imgA1A3_55[i][j])

# %%
S2A1_605= list()
S2A4_105 = list()
for i in range(S2RGB_imgA1A4_5.shape[0]): 
     for j in range(S2RGB_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_605.append(S2RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_105.append(S2RGB_imgA1A4_5[i][j])

# %%
S2A1_705= list()
S2B1_105 = list()
for i in range(S2RGB_imgA1B1_5.shape[0]): 
     for j in range(S2RGB_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_705.append(S2RGB_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_105.append(S2RGB_imgA1B1_5[i][j])

# %%
S2A1_805= list()
S2B2_105 = list()
for i in range(S2RGB_imgA1B2_5.shape[0]): 
     for j in range(S2RGB_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_805.append(S2RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_105.append(S2RGB_imgA1B2_5[i][j])

# %%
SA1_905= list()
SB3_105 = list()
for i in range(SRGB_imgA1B3_5.shape[0]): 
     for j in range(SRGB_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_905.append(SRGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_105.append(SRGB_imgA1B3_5[i][j])

# %%
S2A1_1005= list()
S2B4_105 = list()
for i in range(S2RGB_imgA1B4_5.shape[0]): 
     for j in range(S2RGB_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1005.append(S2RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_105.append(S2RGB_imgA1B4_5[i][j])

# %%
S2A1_1105= list()
S2C1_205 = list()
for i in range(S2RGB_imgA1C1_5.shape[0]): 
     for j in range(S2RGB_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1105.append(S2RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_205.append(S2RGB_imgA1C1_5[i][j])

# %%
S2A1_1205= list()
S2C2_105 = list()
for i in range(S2RGB_imgA1C2_5.shape[0]): 
     for j in range(S2RGB_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1205.append(S2RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_105.append(S2RGB_imgA1C2_5[i][j])

# %%
S2A1_1305= list()
S2C3_105 = list()
for i in range(S2RGB_imgA1C3_5.shape[0]): 
     for j in range(S2RGB_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1305.append(S2RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_105.append(S2RGB_imgA1C3_5[i][j])

# %%
S2A1_1405= list()
S2C4_105 = list()
for i in range(S2RGB_imgA1C4_5.shape[0]): 
     for j in range(S2RGB_imgA1C4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1405.append(S2RGB_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_105.append(S2RGB_imgA1C4_5[i][j])

# %%
S2A1_1505= list()
S2D2_105 = list()
for i in range(S2RGB_imgA1D2_5.shape[0]): 
     for j in range(S2RGB_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1505.append(S2RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_105.append(S2RGB_imgA1D2_5[i][j])

# %%
S21_1605= list()
S2D3_105 = list()
for i in range(S2RGB_imgA1D3_5.shape[0]): 
     for j in range(S2RGB_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1605.append(S2RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_105.append(S2RGB_imgA1D3_5[i][j])

# %%
S2A1_1705= list()
S2D4_105 = list()
for i in range(S2RGB_imgA1D4_5.shape[0]): 
     for j in range(S2RGB_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1705.append(SRGB_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_105.append(S2RGB_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 7

# %%
S2A1_107= list()
S2A1_207= list()
for i in range(S2RGB_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_107.append(S2RGB_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_207.append(S2RGB_imgA1A1_7[i][j])

# %%
S2A1_30= list()
S2A2_10 = list()
for i in range(S2RGB_imgA1A2_.shape[0]): 
     for j in range(S2RGB_imgA1A2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_30.append(S2RGB_imgA1A2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_10.append(S2RGB_imgA1A2_[i][j])

# %%
S2A1_407= list()
S2A3_107 = list()
for i in range(S2RGB_imgA1A3_7.shape[0]): 
     for j in range(S2RGB_imgA1A3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_407.append(S2RGB_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_107.append(S2RGB_imgA1A3_7[i][j])

# %%
S2A1_507= list()
S2A3_5107 = list()
for i in range(S2RGB_imgA1A3_57.shape[0]): 
     for j in range(S2RGB_imgA1A3_57.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_507.append(S2RGB_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5107.append(S2RGB_imgA1A3_57[i][j])

# %%
S2A1_607= list()
S2A4_107 = list()
for i in range(S2RGB_imgA1A4_7.shape[0]): 
     for j in range(S2RGB_imgA1A4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_607.append(S2RGB_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_107.append(S2RGB_imgA1A4_7[i][j])

# %%
S2A1_707= list()
S2B1_107 = list()
for i in range(S2RGB_imgA1B1_7.shape[0]): 
     for j in range(S2RGB_imgA1B1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_707.append(S2RGB_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_107.append(S2RGB_imgA1B1_7[i][j])

# %%
S2A1_807= list()
S2B2_107 = list()
for i in range(S2RGB_imgA1B2_7.shape[0]): 
     for j in range(S2RGB_imgA1B2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_807.append(S2RGB_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_107.append(S2GB_imgA1B2_7[i][j])

# %%
S2A1_907= list()
S2B3_107 = list()
for i in range(S2RGB_imgA1B3_7.shape[0]): 
     for j in range(S2RGB_imgA1B3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_907.append(S2RGB_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_107.append(S2RGB_imgA1B3_7[i][j])

# %%
S2A1_1007= list()
S2B4_107 = list()
for i in range(S2RGB_imgA1B4_7.shape[0]): 
     for j in range(S2RGB_imgA1B4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1007.append(S2RGB_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_107.append(S2RGB_imgA1B4_7[i][j])

# %%
S2A1_1107= list()
S2C1_207 = list()
for i in range(S2RGB_imgA1C1_7.shape[0]): 
     for j in range(S2RGB_imgA1C1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1107.append(S2RGB_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_207.append(S2RGB_imgA1C1_7[i][j])

# %%
S2A1_1207= list()
S2C2_107 = list()
for i in range(S2RGB_imgA1C2_7.shape[0]): 
     for j in range(S2RGB_imgA1C2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1207.append(S2RGB_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_107.append(S2RGB_imgA1C2_7[i][j])

# %%
S2A1_1307= list()
S2C3_107 = list()
for i in range(S2RGB_imgA1C3_7.shape[0]): 
     for j in range(S2RGB_imgA1C3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1307.append(S2RGB_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_107.append(S2RGB_imgA1C3_7[i][j])

# %%
S2A1_1407= list()
S2C4_107 = list()
for i in range(S2RGB_imgA1C4_7.shape[0]): 
     for j in range(S2RGB_imgA1C4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1407.append(S2RGB_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_107.append(S2RGB_imgA1C4_7[i][j])

# %%
S21_1507= list()
S2D2_107 = list()
for i in range(S2RGB_imgA1D2_7.shape[0]): 
     for j in range(S2RGB_imgA1D2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1507.append(S2RGB_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_107.append(S2RGB_imgA1D2_7[i][j])

# %%
2A1_1607= list()
S2D3_107 = list()
for i in range(S2RGB_imgA1D3_7.shape[0]): 
     for j in range(S2RGB_imgA1D3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1607.append(S2RGB_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_107.append(S2RGB_imgA1D3_7[i][j])

# %%
S2A1_1707= list()
S2D4_107 = list()
for i in range(S2RGB_imgA1D4_7.shape[0]): 
     for j in range(S2RGB_imgA1D4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1707.append(S2RGB_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_107.append(S2RGB_imgA1D4_7[i][j])

# %% [markdown]
# ###Img 8

# %%
S2A1_108= list()
S2A1_208= list()
for i in range(S2RGB_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_108.append(SRGB_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_208.append(S2RGB_imgA1A1_8[i][j])

# %%
S2A1_308= list()
S2A2_108 = list()
for i in range(S2RGB_imgA1A2_8.shape[0]): 
     for j in range(S2RGB_imgA1A2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_308.append(S2RGB_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_108.append(S2RGB_imgA1A2_8[i][j])

# %%
S2A1_408= list()
S2A3_108 = list()
for i in range(S2RGB_imgA1A3_8.shape[0]): 
     for j in range(S2RGB_imgA1A3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_408.append(S2RGB_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_108.append(S2RGB_imgA1A3_8[i][j])

# %%
S2A1_508= list()
S2A3_5108 = list()
for i in range(S2RGB_imgA1A3_58.shape[0]): 
     for j in range(S2RGB_imgA1A3_58.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_508.append(S2RGB_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5108.append(S2RGB_imgA1A3_58[i][j])

# %%
S2A1_608= list()
S2A4_108 = list()
for i in range(S2RGB_imgA1A4_8.shape[0]): 
     for j in range(S2RGB_imgA1A4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_608.append(S2RGB_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_108.append(S2RGB_imgA1A4_8[i][j])

# %%
S2A1_708= list()
S2B1_108 = list()
for i in range(S2RGB_imgA1B1_8.shape[0]): 
     for j in range(S2RGB_imgA1B1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_708.append(S2RGB_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_108.append(S2RGB_imgA1B1_8[i][j])

# %%
S2A1_808= list()
S2B2_108 = list()
for i in range(S2RGB_imgA1B2_8.shape[0]): 
     for j in range(S2RGB_imgA1B2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_80.append(S2RGB_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_10.append(S2RGB_imgA1B2_8[i][j])

# %%
S2A1_90= list()
S2B3_10 = list()
for i in range(S2RGB_imgA1B3_.shape[0]): 
     for j in range(SR2GB_imgA1B3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_908.append(S2RGB_imgA1B3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_108.append(S2RGB_imgA1B3_[i][j])

# %%
S2A1_1008= list()
S2B4_108 = list()
for i in range(S2RGB_imgA1B4_8.shape[0]): 
     for j in range(S2RGB_imgA1B4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1008.append(S2RGB_8imgA1B4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_108.append(S2RGB_imgA1B4_8[i][j])

# %%
S2A1_1108= list()
S2C1_208 = list()
for i in range(S2RGB_imgA1C1_8.shape[0]): 
     for j in range(S2RGB_imgA1C1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1108.append(S2RGB_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_208.append(S2RGB_imgA1C1_8[i][j])

# %%
S2A1_1208= list()
S2C2_108 = list()
for i in range(S2RGB_imgA1C2_8.shape[0]): 
     for j in range(S2RGB_imgA1C2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1208.append(S2RGB_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_108.append(S2RGB_imgA1C2_8[i][j])

# %%
S2A1_1308= list()
S2C3_108 = list()
for i in range(S2RGB_imgA1C3_8.shape[0]): 
     for j in range(S2RGB_imgA1C3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1308.append(2SRGB_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_108.append(S2RGB_imgA1C3_8[i][j])

# %%
S2A1_1408= list()
S2C4_108 = list()
for i in range(S2RGB_imgA1C4_8.shape[0]): 
     for j in range(S2RGB_imgA1C4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1408.append(S2RGB_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_108.append(S2RGB_imgA1C4_8[i][j])

# %%
S2A1_1508= list()
S2D2_108 = list()
for i in range(S2RGB_imgA1D2_8.shape[0]): 
     for j in range(S2RGB_imgA1D2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1508.append(S2RGB_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_108.append(S2RGB_imgA1D2_8[i][j])

# %%
S2A1_1608= list()
S2D3_108 = list()
for i in range(S2RGB_imgA1D3_8.shape[0]): 
     for j in range(S2RGB_imgA1D3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1608.append(SR2GB_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_108.append(S2RGB_imgA1D3_8[i][j])

# %%
S2A1_1708= list()
S2D4_108 = list()
for i in range(S2RGB_imgA1D4_8.shape[0]): 
     for j in range(S2RGB_imgA1D4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1708.append(S2RGB_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_108.append(S2RGB_imgA1D4_8[i][j])

# %% [markdown]
# ###Img 9

# %%
S2A1_109= list()
S2A1_209= list()
for i in range(S2RGB_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_109.append(S2RGB_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_209.append(S2RGB_imgA1A1_9[i][j])

# %%
S2A1_309= list()
S2A2_109 = list()
for i in range(S2RGB_imgA1A2_9.shape[0]): 
     for j in range(S2RGB_imgA1A2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_309.append(S2RGB_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A2_109.append(S2RGB_imgA1A2_9[i][j])

# %%
S2A1_409= list()
S2A3_109 = list()
for i in range(S2RGB_imgA1A3_9.shape[0]): 
     for j in range(S2RGB_imgA1A3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_409.append(S2GB_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_109.append(S2RGB_imgA1A3_9[i][j])

# %%
S2A1_509= list()
S2A3_5109 = list()
for i in range(S2RGB_imgA1A3_59.shape[0]): 
     for j in range(S2RGB_imgA1A3_59.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_509.append(S2RGB_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5109.append(S2RGB_imgA1A3_59[i][j])

# %%
S2A1_609= list()
S2A4_109 = list()
for i in range(S2RGB_imgA1A4_9.shape[0]): 
     for j in range(S2RGB_imgA1A4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_609.append(S1GB_imgA1A4_9[i][j])
                if 17     70<i<1880 and 2015<j<2145 :
                    SA4_109.append(SRGB_imgA1A4_9[i][j])

# %%
S2A1_709= list() 
S2B1_109 = list()
for i in range(S2RGB_imgA1B1_9.shape[0]): 
     for j in range(S2RGB_imgA1B1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_709.append(SRGB_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_109.append(S2RGB_imgA1B1_9[i][j])

# %%
S2A1_809= list()
S2B2_109 = list()
for i in range(S2RGB_imgA1B2_9.shape[0]): 
     for j in range(S2RGB_imgA1B2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_809.append(S2RGB_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_109.append(S2RGB_imgA1B2_9[i][j])

# %%
S2A1_909= list()
S2B3_109 = list()
for i in range(S2RGB_imgA1B3_9.shape[0]): 
     for j in range(S2RGB_imgA1B3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_909.append(S2RGB_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_109.append(S2RGB_imgA1B3_9[i][j])

# %%
S2A1_1009= list()
S2B4_109 = list()
for i in range(SRGB_imgA1B4_9.shape[0]): 
     for j in range(S2RGB_imgA1B4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1009.append(S2RGB_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_109.append(S2RGB_imgA1B4_9[i][j])

# %%
S2A1_1109= list()
SC1_209 = list()
for i in range(S2RGB_imgA1C1_9.shape[0]): 
     for j in range(S2RGB_imgA1C1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1109.append(S2RGB_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_209.append(S2RGB_imgA1C1_9[i][j])

# %%
S2A1_1209= list()
S2C2_109 = list()
for i in range(S2RGB_imgA1C2_9.shape[0]): 
     for j in range(S2RGB_imgA1C2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1209.append(S2RGB_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_109.append(S2RGB_imgA1C2_9[i][j])

# %%
S2A1_1309= list()
S2C3_109 = list()
for i in range(S2RGB_imgA1C3_9.shape[0]): 
     for j in range(S2RGB_imgA1C3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1309.append(S2RGB_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_109.append(S2RGB_imgA1C3_9[i][j])

# %%
S2A1_1409= list()
S2C4_109 = list()
for i in range(S2RGB_imgA1C4_9.shape[0]): 
     for j in range(S2RGB_imgA1C4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1409.append(S2RGB_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_109.append(S2RGB_imgA1C4_9[i][j])

# %%
SA1_1509= list()
SD2_109 = list()
for i in range(SRGB_imgA1D2_9.shape[0]): 
     for j in range(SRGB_imgA1D2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1509.append(SRGB_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_109.append(SRGB_imgA1D2_9[i][j])

# %%
S2A1_1609= list()
S2D3_109 = list()
for i in range(S2RGB_imgA1D3_9.shape[0]): 
     for j in range(S2RGB_imgA1D3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1609.append(S2RGB_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_109.append(S2RGB_imgA1D3_9[i][j])

# %%
S2A1_1709= list()
S2D4_109 = list()
for i in range(S2RGB_imgA1D4_9.shape[0]): 
     for j in range(S2RGB_imgA1D4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1709.append(S2RGB_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_109.append(S2RGB_imgA1D4_9[i][j])

# %% [markdown]
# ###Img 10

# %%
S2A1_110= list()
S2A1_210= list()
for i in range(S2RGB_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_110.append(S2RGB_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_210.append(S2RGB_imgA1A1_10[i][j])

# %%
SA1_310= list()
SA2_110 = list()
for i in range(SRGB_imgA1A2_10.shape[0]): 
     for j in range(SRGB_imgA1A2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_310.append(SRGB_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA2_110.append(SGB_imgA1A2_10[i][j])

# %%
S2A1_410= list()
S2A3_110 = list()
for i in range(S2RGB_imgA1A3_10.shape[0]): 
     for j in range(S2RGB_imgA1A3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_410.append(S2RGB_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_110.append(S2RGB_imgA1A3_10[i][j])

# %%
S2A1_510= list()
S2A3_510 = list()
for i in range(S2RGB_imgA1A3_510.shape[0]): 
     for j in range(S2RGB_imgA1A3_510.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_510.append(S2RGB_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_510.append(S2RGB_imgA1A3_510[i][j])

# %%
S2A1_610= list()
S2A4_110 = list()
for i in range(S2RGB_imgA1A4_10.shape[0]): 
     for j in range(S2RGB_imgA1A4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_610.append(S2RGB_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_110.append(S2RGB_imgA1A4_10[i][j])

# %%
S2A1_710= list()
S2B1_110 = list()
for i in range(S2RGB_imgA1B1_10.shape[0]): 
     for j in range(S2RGB_imgA1B1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_710.append(S2RGB_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_110.append(S2RGB_imgA1B1_10[i][j])

# %%
S2A1_810= list()
S2B2_110 = list()
for i in range(S2RGB_imgA1B2_10.shape[0]): 
     for j in range(S2RGB_imgA1B2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_810.append(SRGB_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_110.append(S2RGB_imgA1B2_10[i][j])่

# %%
S2A1_910= list()
S2B3_110 = list()
for i in range(SRGB_imgA1B3_10.shape[0]): 
     for j in range(S2RGB_imgA1B3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_910.append(S1RGB_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_110.append(S1RGB_imgA1B3_10[i][j])

# %%
S2A1_1010= list()
S2B4_110 = list()
for i in range(S2RGB_imgA1B4_10.shape[0]): 
     for j in range(S1RGB_imgA1B4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1010.append(S2RGB_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_110.append(S2RGB_imgA1B4_10[i][j])

# %%
S1A1_1110= list()
S1C1_210 = list()
for i in range(S1RGB_imgA1C1_10.shape[0]): 
     for j in range(S1RGB_imgA1C1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1110.append(S1RGB_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_210.append(S1RGB_imgA1C1_10[i][j])

# %%
S2A1_1210= list()
S2C2_110 = list()
for i in range(S2RGB_imgA1C2_10.shape[0]): 
     for j in range(S2RGB_imgA1C2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1210.append(S2RGB_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_110.append(S2RGB_imgA1C2_10[i][j])

# %%
S2A1_1310= list()
S2C3_110 = list()
for i in range(S2RGB_imgA1C3_10.shape[0]): 
     for j in range(S2RGB_imgA1C3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1310.append(S2RGB_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_110.append(S2RGB_imgA1C3_10[i][j])

# %%
S2A1_1410= list()
S2C4_110 = list()
for i in range(S2RGB_imgA1C4_10.shape[0]): 
     for j in range(S2RGB_imgA1C4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1410.append(S2RGB_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_110.append(S2RGB_imgA1C4_10[i][j])

# %%
S2A1_1510= list()
S2D2_110 = list()
for i in range(S2RGB_imgA1D2_10.shape[0]): 
     for j in range(S2RGB_imgA1D2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1510.append(S2RGB_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_110.append(S2RGB_imgA1D210_[i][j])

# %%
S2A1_1610= list()
S2D3_110 = list()
for i in range(S2RGB_imgA1D3_10.shape[0]): 
     for j in range(S2RGB_imgA1D3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1610.append(S2RGB_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_110.append(S2RGB_imgA1D3_10[i][j])

# %%
S2A1_1710= list()
S2D4_110 = list()
for i in range(S2RGB_imgA1D4_10.shape[0]): 
     for j in range(S2RGB_imgA1D4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1710.append(S2RGB_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_110.append(S2RGB_imgA1D4_10[i][j])

# %% [markdown]
# ###HSV

# %%
S2A1_1= list()
S2A1_2 = list()
for i in range(S2HSV_imgA1A1_1.shape[0]): 
     for j in range(S2HSV_imgA1A1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1.append(S2HSV_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_2.append(S2HSV_imgA1A1_1[i][j])

# %%
S2A1_3= list()
S2A2_1 = list()
for i in range(S2HSV_imgA1A2_1.shape[0]): 
     for j in range(S2HSV_imgA1A2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_3.append(S2HSV_imgA1A2_1[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_1.append(S2HSV_imgA1A2_1[i][j])

# %%
S2A1_4= list()
S2A3_1 = list()
for i in range(S2HSV_imgA1A3_1.shape[0]): 
     for j in range(S2HSV_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_4.append(S2HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_1.append(S2HSV_imgA1A3_1[i][j])

# %%
S2A1_5= list()
S2A3_51 = list()
for i in range(S2HSV_imgA1A3_51.shape[0]): 
     for j in range(S2HSV_imgA1A3_51.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_5.append(S2HSV_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_51.append(S2HSV_imgA1A3_51[i][j])

# %%
S2A1_6= list()
S2A4_1 = list()
for i in range(S2HSV_imgA1A4_1.shape[0]): 
     for j in range(S2HSV_imgA1A4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_6.append(S2HSV_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_1.append(S2HSV_imgA1A4_1[i][j])

# %%
S2A1_7= list()
S2B1_1 = list()
for i in range(S2HSV_imgA1B1_1.shape[0]): 
     for j in range(S2HSV_imgA1B1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_7.append(S2HSV_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_1.append(S2HSV_imgA1B1_1[i][j])

# %%
S2A1_8= list()
S2B2_1 = list()
for i in range(S2HSV_imgA1B2_1.shape[0]): 
     for j in range(S2HSV_imgA1B2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_8.append(S2HSV_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_1.append(S2HSV_imgA1B2_1[i][j])

# %%
S2A1_9= list()
S2B3_1 = list()
for i in range(S2HSV_imgA1B3_1.shape[0]): 
     for j in range(S2HSV_imgA1B3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_9.append(S2HSV_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_1.append(S2HSV_imgA1B3_1[i][j])

# %%
S2A1_10= list()
S2B4_1 = list()
for i in range(S2HSV_imgA1B4_1.shape[0]): 
     for j in range(S2HSV_imgA1B4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_10.append(S2HSV_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_1.append(S2HSV_imgA1B4_1[i][j])

# %%
S2A1_11= list()
S2C1_1 = list()
for i in range(S2HSV_imgA1C1_1.shape[0]): 
     for j in range(S2HSV_imgA1C1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_11.append(S2HSV_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_1.append(S2HSV_imgA1C1_1[i][j])

# %%
S2A1_12= list()
S2C2_1 = list()
for i in range(S2HSV_imgA1C2_1.shape[0]): 
     for j in range(S2HSV_imgA1C2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_12.append(S2HSV_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_1.append(S2HSV_imgA1C2_1[i][j])

# %%
S2A1_13= list()
S2C3_1 = list()
for i in range(S2HSV_imgA1C3_1.shape[0]): 
     for j in range(S2HSV_imgA1C3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_13.append(S2HSV_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_1.append(S2HSV_imgA1C3_1[i][j])

# %%
S2A1_14= list()
S2C4_1 = list()
for i in range(S2HSV_imgA1C4_1.shape[0]): 
     for j in range(S2HSV_imgA1C4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_14.append(S2HSV_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_1.append(S2HSV_imgA1C4_1[i][j])

# %%
S2A1_15= list()
S2D2_1 = list()
for i in range(S2HSV_imgA1C2_1.shape[0]): 
     for j in range(S2HSV_imgA1D2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_15.append(S2HSV_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_1.append(S2HSV_imgA1D2_1[i][j])

# %%
S2A1_16= list()
S2D3_1 = list()
for i in range(S2HSV_imgA1D3_1.shape[0]): 
          for j in range(S2HSV_imgA1D3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_16.append(S2HSV_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_1.append(S2HSV_imgA1D3_1[i][j])

# %%
S2A1_17= list()
S2D4_1 = list()
for i in range(S2HSV_imgA1D4_1.shape[0]): 
     for j in range(S2HSV_imgA1D4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_14.append(S2HSV_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_1.append(S2HSV_imgA1D4_1[i][j])

# %% [markdown]
# ### Img 2

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_2.shape[0]): 
     for j in range(S2HSV_imgA1A1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_2[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_2.shape[0]): 
     for j in range(S2HSV_imgA1A2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_0[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_2[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_.2shape[0]): 
     for j in range(S2HSV_imgA1A3_.2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_[2i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_2[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
for i in range(S2HSV_imgA1A3_52.shape[0]): 
     for j in range(S2HSV_imgA1A3_52.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_52[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_.2shape[0]): 
     for j in range(S2HSV_imgA1A4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_2[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_.2shape[0]): 
     for j in range(S2HSV_imgA1B1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_2[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_2.shape[0]): 
     for j in range(S2HSV_imgA1B2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_[i][j])2

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_2.shape[0]): 
     for j in range(S2HSV_imgA1B3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_2[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_2.shape[0]): 
     for j in range(S2HSV_imgA1B4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_2[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_2.shape[0]): 
     for j in range(S2HSV_imgA1C1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_2[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_2.shape[0]): 
     for j in range(S2HSV_imgA1C2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_2[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_2.shape[0]): 
     for j in range(S2HSV_imgA1C3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_2[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_2.shape[0]): 
     for j in range(S2HSV_imgA1C4_2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_2[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_2.shape[0]): 
     for j in range(S2HSV_imgA1D2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_2[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_2.shape[0]): 
          for j in range(S2HSV_imgA1D3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_2[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_2.shape[0]): 
     for j in range(S2HSV_imgA1D4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_2[i][j])

# %% [markdown]
# ### Img 3

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_3.shape[0]): 
     for j in range(S2HSV_imgA1A1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_3i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_102.shape[0]): 
     for j in range(S2HSV_imgA1A2_102.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_102[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_102[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_3.shape[0]): 
     for j in range(S2HSV_imgA1A3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_3[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
for i in range(S2HSV_imgA1A3_53.shape[0]): 
     for j in range(S2HSV_imgA1A3_53.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_53[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_.shape[0]): 
     for j in range(S2HSV_imgA1A4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_3.shape[0]): 
     for j in range(S2HSV_imgA1B1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_3[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_3.shape[0]): 
     for j in range(S2HSV_imgA1B2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_3[i][j])

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_3.shape[0]): 
     for j in range(S2HSV_imgA1B3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_3[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_3.shape[0]): 
     for j in range(S2HSV_imgA1B4_3shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_3[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_3.shape[0]): 
     for j in range(S2HSV_imgA1C1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_3[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_3.shape[0]): 
     for j in range(S2HSV_imgA1C2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_3[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_3.shape[0]): 
     for j in range(S2HSV_imgA1C3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_3[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_3.shape[0]): 
     for j in range(S2HSV_imgA1C4_3shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_3[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_3.shape[0]): 
     for j in range(S2HSV_imgA1D2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_3[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_3.shape[0]): 
          for j in range(S2HSV_imgA1D3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_3[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_3.shape[0]): 
     for j in range(S2HSV_imgA1D4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D43_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_3[i][j])

# %% [markdown]
# ### Img 4

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_4.shape[0]): 
     for j in range(S2HSV_imgA1A1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_4[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_4.shape[0]): 
     for j in range(S2HSV_imgA1A2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_4[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_4[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_4.shape[0]): 
     for j in range(S2HSV_imgA1A3_.4shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_4[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
for i in range(S2HSV_imgA1A3_54.shape[0]): 
     for j in range(S2HSV_imgA1A3_54.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_54[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_4.shape[0]): 
     for j in range(S2HSV_imgA1A4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_4[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_4.shape[0]): 
     for j in range(S2HSV_imgA1B1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_4[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_4.shape[0]): 
     for j in range(S2HSV_imgA1B2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_4[i][j])

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_4.shape[0]): 
     for j in range(S2HSV_imgA1B3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_4[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_4.shape[0]): 
     for j in range(S2HSV_imgA1B4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_4[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_4.shape[0]): 
     for j in range(S2HSV_imgA1C1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_4[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_.shape[0]): 
     for j in range(S2HSV_imgA1C2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_4.shape[0]): 
     for j in range(S2HSV_imgA1C3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_4[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_4.shape[0]): 
     for j in range(S2HSV_imgA1C4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_4[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_4.shape[0]): 
     for j in range(S2HSV_imgA1D2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_4[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_4.shape[0]): 
          for j in range(S2HSV_imgA1D3_.4shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_4[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_4.shape[0]): 
     for j in range(S2HSV_imgA1D4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_4[i][j])

# %% [markdown]
# ### Img 5

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_5.shape[0]): 
     for j in range(S2HSV_imgA1A1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_5[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_5.shape[0]): 
     for j in range(S2HSV_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_5[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_5[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_5.shape[0]): 
     for j in range(S2HSV_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_5[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
for i in range(S2HSV_imgA1A3_55.shape[0]): 
     for j in range(S2HSV_imgA1A3_55.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_55[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_5.shape[0]): 
     for j in range(S2HSV_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_5[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_5.shape[0]): 
     for j in range(S2HSV_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_5[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_5.shape[0]): 
     for j in range(S2HSV_imgA1B2_.5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_5[i][j])

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_5.shape[0]): 
     for j in range(S2HSV_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_5[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_5.shape[0]): 
     for j in range(S2HSV_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_5[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_5.shape[0]): 
     for j in range(S2HSV_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_5.shape[0]): 
     for j in range(S2HSV_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_5[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_5.shape[0]): 
     for j in range(S2HSV_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_5[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_5.shape[0]): 
     for j in range(S2HSV_imgA1C4_5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_5[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_5.shape[0]): 
     for j in range(S2HSV_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_5i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_5.shape[0]): 
          for j in range(S2HSV_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_5[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_5.shape[0]): 
     for j in range(S2HSV_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_5[i][j])

# %% [markdown]
# ### Img 6

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_6.shape[0]): 
     for j in range(S2HSV_imgA1A1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_6[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_6.shape[0]): 
     for j in range(S2HSV_imgA1A2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_6[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_6[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_.shape[0]): 
     for j in range(S2HSV_imgA1A3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
for i in range(S2HSV_imgA1A3_6.shape[0]): 
     for j in range(S2HSV_imgA1A3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_6[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_6.shape[0]): 
     for j in range(S2HSV_imgA1A4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_6[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_6.shape[0]): 
     for j in range(S2HSV_imgA1B1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_6[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_6.shape[0]): 
     for j in range(S2HSV_imgA1B2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_6[i][j])

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_6.shape[0]): 
     for j in range(S2HSV_imgA1B3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_6[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_6.shape[0]): 
     for j in range(S2HSV_imgA1B4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_6[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_6.shape[0]): 
     for j in range(S2HSV_imgA1C1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_6[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_6.shape[0]): 
     for j in range(S2HSV_imgA1C2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_6[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_6.shape[0]): 
     for j in range(S2HSV_imgA1C3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_6[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_6.shape[0]): 
     for j in range(S2HSV_imgA1C4_6shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_6[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_6.shape[0]): 
     for j in range(S2HSV_imgA1D2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_6[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_6.shape[0]): 
          for j in range(S2HSV_imgA1D3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_6[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_6.shape[0]): 
     for j in range(S2HSV_imgA1D4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_6[i][j])

# %% [markdown]
# ### Img 7

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_7.shape[0]): 
     for j in range(S2HSV_imgA1A1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_7[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_7.shape[0]): 
     for j in range(S2HSV_imgA1A2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_7[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_7[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_7.shape[0]): 
     for j in range(S2HSV_imgA1A3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_7[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
for i in range(S2HSV_imgA1A3_57.shape[0]): 
     for j in range(S2HSV_imgA1A3_57.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_57[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_7.shape[0]): 
     for j in range(S2HSV_imgA1A4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_7[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_7.shape[0]): 
     for j in range(S2HSV_imgA1B1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_7[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_7.shape[0]): 
     for j in range(S2HSV_imgA1B2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_7[i][j])

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_7.shape[0]): 
     for j in range(S2HSV_imgA1B3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_7[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_7.shape[0]): 
     for j in range(S2HSV_imgA1B4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_7[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_7.shape[0]): 
     for j in range(S2HSV_imgA1C1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_7[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_7.shape[0]): 
     for j in range(S2HSV_imgA1C2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_7[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_7.shape[0]): 
     for j in range(S2HSV_imgA1C3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_7[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_7.shape[0]): 
     for j in range(S2HSV_imgA1C4_7shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_7[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_7.shape[0]): 
     for j in range(S2HSV_imgA1D2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_7[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_7.shape[0]): 
          for j in range(S2HSV_imgA1D3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_7[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_7.shape[0]): 
     for j in range(S2HSV_imgA1D4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_7[i][j])

# %% [markdown]
# ### Img 8

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_8.shape[0]): 
     for j in range(S2HSV_imgA1A1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_8[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_8.shape[0]): 
     for j in range(S2HSV_imgA1A2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_8[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_8[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_8.shape[0]): 
     for j in range(S2HSV_imgA1A3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_8[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
for i in range(S2HSV_imgA1A3_58.shape[0]): 
     for j in range(S2HSV_imgA1A3_58.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_58[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_8.shape[0]): 
     for j in range(S2HSV_imgA1A4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_8[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_8.shape[0]): 
     for j in range(S2HSV_imgA1B1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_8[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_8.shape[0]): 
     for j in range(S2HSV_imgA1B2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_8[i][j])

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_8.shape[0]): 
     for j in range(S2HSV_imgA1B3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_8[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_8.shape[0]): 
     for j in range(S2HSV_imgA1B4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_8[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_8.shape[0]): 
     for j in range(S2HSV_imgA1C1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_8[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_8.shape[0]): 
     for j in range(S2HSV_imgA1C2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_8[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_8.shape[0]): 
     for j in range(S2HSV_imgA1C3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_8[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_8.shape[0]): 
     for j in range(S2HSV_imgA1C4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_8[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_.shape[0]): 
     for j in range(S2HSV_imgA1D2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_8.shape[0]): 
          for j in range(S2HSV_imgA1D3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_8[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_8.shape[0]): 
     for j in range(S2HSV_imgA1D4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_8[i][j])

# %% [markdown]
# ### Img 9

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_9.shape[0]): 
     for j in range(S2HSV_imgA1A1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_9[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_9shape[0]): 
     for j in range(S2HSV_imgA1A2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_9[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_9[i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_9.shape[0]): 
     for j in range(S2HSV_imgA1A3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_9[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
for i in range(S2HSV_imgA1A3_59.shape[0]): 
     for j in range(S2HSV_imgA1A3_59.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_59[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_9.shape[0]): 
     for j in range(S2HSV_imgA1A4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_9[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_9.shape[0]): 
     for j in range(S2HSV_imgA1B1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_9[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_9.shape[0]): 
     for j in range(S2HSV_imgA1B2_.9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_9[i][j])

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_9.shape[0]): 
     for j in range(S2HSV_imgA1B3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_9[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_9.shape[0]): 
     for j in range(S2HSV_imgA1B4_.9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_9[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_9.shape[0]): 
     for j in range(S2HSV_imgA1C1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_9[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_9.shape[0]): 
     for j in range(S2HSV_imgA1C2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_9[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_9.shape[0]): 
     for j in range(S2HSV_imgA1C3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_9[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_9.shape[0]): 
     for j in range(S2HSV_imgA1C4_9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_9[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_9.shape[0]): 
     for j in range(S2HSV_imgA1D2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_9[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_9.shape[0]): 
          for j in range(S2HSV_imgA1D3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_9[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_9.shape[0]): 
     for j in range(S2HSV_imgA1D4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_9[i][j])

# %% [markdown]
# ### Img 10

# %%
S2A1_102= list()
S2A1_202 = list()
for i in range(S2HSV_imgA1A1_10.shape[0]): 
     for j in range(S2HSV_imgA1A1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_102.append(S2HSV_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A1_202.append(S2HSV_imgA1A1_10[i][j])

# %%
S2A1_302= list()
S2A2_102 = list()
for i in range(S2HSV_imgA1A2_10.shape[0]): 
     for j in range(S2HSV_imgA1A2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_302.append(S2HSV_imgA1A2_10[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S2A2_102.append(S2HSV_imgA1A2_10i][j])

# %%
S2A1_402= list()
S2A3_102 = list()
for i in range(S2HSV_imgA1A3_10.shape[0]): 
     for j in range(S2HSV_imgA1A3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_402.append(S2HSV_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_102.append(S2HSV_imgA1A3_10[i][j])

# %%
S2A1_502= list()
S2A3_5102= list()
     for j in range(S2HSV_imgA1A3_510.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_502.append(S2HSV_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A3_5102.append(S2HSV_imgA1A3_510[i][j])

# %%
S2A1_602= list()
S2A4_102 = list()
for i in range(S2HSV_imgA1A4_10.shape[0]): 
     for j in range(S2HSV_imgA1A4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_602.append(S2HSV_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2A4_102.append(S2HSV_imgA1A4_10[i][j])

# %%
S2A1_702= list()
S2B1_102= list()
for i in range(S2HSV_imgA1B1_10.shape[0]): 
     for j in range(S2HSV_imgA1B1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_10[i][j])

# %%
S2A1_802= list()
S2B2_102 = list()
for i in range(S2HSV_imgA1B2_10.shape[0]): 
     for j in range(S2HSV_imgA1B2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_802.append(S2HSV_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B2_102.append(S2HSV_imgA1B2_10[i][j])

# %%
S2A1_902= list()
S2B3_102= list()
for i in range(S2HSV_imgA1B3_10.shape[0]): 
     for j in range(S2HSV_imgA1B3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_902.append(S2HSV_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B3_102.append(S2HSV_imgA1B3_10[i][j])

# %%
S2A1_1002= list()
S2B4_102 = list()
for i in range(S2HSV_imgA1B4_10.shape[0]): 
     for j in range(S2HSV_imgA1B4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1002.append(S2HSV_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B4_102.append(S2HSV_imgA1B4_10[i][j])

# %%
S2A1_1102= list()
S2C1_102 = list()
for i in range(S2HSV_imgA1C1_10.shape[0]): 
     for j in range(S2HSV_imgA1C1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1102.append(S2HSV_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C1_102.append(S2HSV_imgA1C1_10[i][j])

# %%
S2A1_1202= list()
S2C2_102 = list()
for i in range(S2HSV_imgA1C2_10.shape[0]): 
     for j in range(S2HSV_imgA1C2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1202.append(S2HSV_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C2_102.append(S2HSV_imgA1C2_10[i][j])

# %%
S2A1_1302= list()
S2C3_102 = list()
for i in range(S2HSV_imgA1C3_10.shape[0]): 
     for j in range(S2HSV_imgA1C3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1302.append(S2HSV_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C3_102.append(S2HSV_imgA1C3_10[i][j])

# %%
S2A1_1402= list()
S2C4_102 = list()
for i in range(S2HSV_imgA1C4_10.shape[0]): 
     for j in range(S2HSV_imgA1C4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2C4_102.append(S2HSV_imgA1C4_10[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_10.shape[0]): 
     for j in range(S2HSV_imgA1D2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_10[i][j])

# %%
S2A1_1602= list()
S2D3_102 = list()
for i in range(S2HSV_imgA1D3_10.shape[0]): 
          for j in range(S2HSV_imgA1D3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1602.append(S2HSV_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D3_102.append(S2HSV_imgA1D3_10[i][j])

# %%
S2A1_1702= list()
S2D4_102 = list()
for i in range(S2HSV_imgA1D4_10.shape[0]): 
     for j in range(S2HSV_imgA1D4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1402.append(S2HSV_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D4_102.append(S2HSV_imgA1D4_10[i][j])

# %% [markdown]
# ##Set3

# %% [markdown]
# ###RGB

# %%
S3A1_1= list()
S3A1_2 = list()
for i in range(S3RGB_imgA1A1_1.shape[0]): 
     for j in range(S3RGB_imgA1A1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1.append(S3RGB_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_2.append(S3RGB_imgA1A1_1[i][j])

# %%
S3A1_3= list()
S3A2_1 = list()
for i in range(S3RGB_imgA1A2_1.shape[0]): 
     for j in range(S3RGB_imgA1A2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_3.append(S3RGB_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_1.append(S3RGB_imgA1A2_1[i][j])

# %%
S3A1_4= list()
S3A3_1 = list()
for i in range(S3RGB_imgA1A3_1.shape[0]): 
     for j in range(S3RGB_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_4.append(S3RGB_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_1.append(S3RGB_imgA1A3_1[i][j])

# %%
S3A1_5= list()
S3A3_51 = list()
for i in range(S3RGB_imgA1A3_51.shape[0]): 
     for j in range(S3RGB_imgA1A3_51.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_5.append(S3RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_51.append(S3RGB_imgA1A3_51[i][j])

# %%
S3A1_6= list()
S3A4_1 = list()
for i in range(S3RGB_imgA1A4_1.shape[0]): 
     for j in range(S3RGB_imgA1A4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_6.append(S3RGB_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_1.append(S3RGB_imgA1A4_1[i][j])

# %%
S3A1_7= list()
S3B1_1 = list()
for i in range(S3RGB_imgA1B1_1.shape[0]): 
     for j in range(S3RGB_imgA1B1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_7.append(S3RGB_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_1.append(S3RGB_imgA1B1_1[i][j])

# %%
S3A1_8= list()
S3B2_1 = list()
for i in range(S3RGB_imgA1B2_1.shape[0]): 
     for j in range(S3RGB_imgA1B2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_8.append(S3RGB_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_1.append(S3RGB_imgA1B2_1[i][j])

# %%
S3A1_9= list()
S3B3_1 = list()
for i in range(S3RGB_imgA1B3_1.shape[0]): 
     for j in range(S3RGB_imgA1B3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_9.append(S3RGB_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_1.append(S3RGB_imgA1B3_1[i][j])

# %%
S3A1_10= list()
S3B4_1 = list()
for i in range(S3RGB_imgA1B4_1.shape[0]): 
     for j in range(S3RGB_imgA1B4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_10.append(S3RGB_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_1.append(S3RGB_imgA1B4_1[i][j])

# %%
S3A1_11= list()
S3C1_2 = list()
for i in range(S3RGB_imgA1C1_1.shape[0]): 
     for j in range(S3RGB_imgA1C1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_11.append(S3RGB_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_2.append(S3RGB_imgA1C1_1[i][j])

# %%
S3A1_12= list()
S3C2_1 = list()
for i in range(S3RGB_imgA1C2_1.shape[0]): 
     for j in range(S3RGB_imgA1C2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_12.append(S3RGB_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_1.append(S3RGB_imgA1C2_1[i][j])

# %%
S3A1_13= list()
S3C3_1 = list()
for i in range(S3RGB_imgA1C3_1.shape[0]): 
     for j in range(S3RGB_imgA1C3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_13.append(S3RGB_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_1.append(S3RGB_imgA1C3_1[i][j])

# %%
S3A1_14= list()
S3C4_1 = list()
for i in range(S3RGB_imgA1C4_1.shape[0]): 
     for j in range(S3RGB_imgA1C4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_14.append(S3RGB_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_1.append(S3RGB_imgA1C4_1[i][j])

# %%
S3A1_15= list()
S3D2_1 = list()
for i in range(S3RGB_imgA1D2_1.shape[0]): 
     for j in range(S3RGB_imgA1D2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_15.append(S3RGB_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_1.append(S3RGB_imgA1D2_1[i][j])

# %%
S3A1_16= list()
S3D3_1 = list()
for i in range(S3RGB_imgA1D3_1.shape[0]): 
     for j in range(S3RGB_imgA1D3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_16.append(S3RGB_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_1.append(S3RGB_imgA1D3_1[i][j])

# %%
S3A1_17= list()
S3D4_1 = list()
for i in range(S3RGB_imgA1D4_1.shape[0]): 
     for j in range(S3RGB_imgA1D4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_17.append(S3RGB_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_1.append(S3RGB_imgA1D4_1[i][j])

# %% [markdown]
# ###Img 2

# %%
S3A1_102= list()
S3A1_202= list()
for i in range(S3RGB_imgA1A1_2.shape[0]): 
     for j in range(S3RGB_imgA1A1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_103.append(S3RGB_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_202.append(S3RGB_imgA1A1_2[i][j])

# %%
S3A1_302= list()
S3A2_102 = list()
for i in range(S3RGB_imgA1A2_2.shape[0]): 
     for j in range(S3RGB_imgA1A2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_302.append(S3RGB_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_102.append(S3RGB_imgA1A2_2[i][j])

# %%
S3A1_402= list()
S3A3_102 = list()
for i in range(S3RGB_imgA1A3_2.shape[0]): 
     for j in range(S3RGB_imgA1A3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_402.append(S3RGB_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_102.append(S3RGB_imgA1A3_2[i][j])

# %%
S3A1_502= list()
S3A3_502 = list()
for i in range(S3RGB_imgA1A3_52.shape[0]): 
     for j in range(S3RGB_imgA1A3_52.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_502.append(S3RGB_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_5102.append(S3RGB_imgA1A3_52[i][j])

# %%
S3A1_602= list()
S3A4_102 = list()
for i in range(S3RGB_imgA1A4_2.shape[0]): 
     for j in range(S3RGB_imgA1A4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_602.append(S3RGB_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_102.append(S3RGB_imgA1A4_2[i][j])

# %%
S3A1_702= list()
S3B1_102 = list()
for i in range(S3RGB_imgA1B1_2.shape[0]): 
     for j in range(S3RGB_imgA1B1_2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_702.append(S3RGB_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_102.append(S3RGB_imgA1B1_2[i][j])

# %%
S3A1_802= list()
S3B2_102 = list()
for i in range(S3RGB_imgA1B2_.shape[0]): 
     for j in range(S3RGB_imgA1B2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_802.append(S3RGB_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_102.append(S3RGB_imgA1B2_[i][j])

# %%
S3A1_902= list()
S3B3_102= list()
for i in range(S3RGB_imgA1B_2.shape[0]): 
     for j in range(S3RGB_imgA1B_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_902.append(S3RGB_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_102.append(S3RGB_imgA1B3_2[i][j])

# %%
S3A1_1002= list()
S3B4_102 = list()
for i in range(S3RGB_imgA1B4_2.shape[0]): 
     for j in range(S3RGB_imgA1B4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1002.append(S3RGB_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_102.append(S3RGB_imgA1B4_2[i][j])

# %%
S3A1_1102= list()
S3C1_202 = list()
for i in range(S3RGB_imgA1C1_2.shape[0]): 
     for j in range(S3RGB_imgA1C1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1102.append(S3RGB_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_202.append(S3RGB_imgA1C1_2[i][j])

# %%
S3A1_1202= list()
S3C2_102 = list()
for i in range(S3RGB_imgA1C2_2.shape[0]): 
     for j in range(S3RGB_imgA1C2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1202.append(S3RGB_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_102.append(S3RGB_imgA1C2_2[i][j])

# %%
S3A1_1302= list()
S3C3_102 = list()
for i in range(S3RGB_imgA1C3_2.shape[0]): 
     for j in range(S3RGB_imgA1C3_.2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1302.append(S3RGB_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_102.append(S3RGB_imgA1C3_2[i][j])

# %%
S3A1_1402= list()
S3C4_102 = list()
for i in range(S3RGB_imgA1C4_2.shape[0]): 
     for j in range(S3RGB_imgA1C4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1402.append(S3RGB_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_102.append(S3RGB_imgA1C4_2[i][j])

# %%
S3A1_1502= list()
S3D2_102 = list()
for i in range(S3RGB_imgA1D2_2.shape[0]): 
     for j in range(S3RGB_imgA1D2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1502.append(S3RGB_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_102.append(S3RGB_imgA1D2_2[i][j])

# %%
S3A1_1602= list()
S3D3_102 = list()
for i in range(S3RGB_imgA1D3_2.shape[0]): 
     for j in range(S3RGB_imgA1D3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1602.append(S3RGB_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_102.append(S3RGB_imgA1D3_2[i][j])

# %%
S3A1_1702= list()
S3D4_102= list()
for i in range(S3RGB_imgA1D4_2.shape[0]): 
     for j in range(S3RGB_imgA1D4_.2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1702.append(S3RGB_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_102.append(S3RGB_imgA1D4_2[i][j])

# %% [markdown]
# ###Img 3

# %%
S3A1_103= list()
S3A1_203= list()
for i in range(S3RGB_imgA1A1_3.shape[0]): 
     for j in range(S3RGB_imgA1A1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1.append(S3RGB_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_2.append(S3RGB_imgA1A1_3[i][j])

# %%
S3A1_303= list()
S3A2_103 = list()
for i in range(S3RGB_imgA1A2_3.shape[0]): 
     for j in range(S3RGB_imgA1A2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_303.append(S3RGB_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_103.append(S3RGB_imgA1A2_3[i][j])

# %%
S3A1_403= list()
S3A3_103 = list()
for i in range(S3RGB_imgA1A3_3.shape[0]): 
     for j in range(S3RGB_imgA1A3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_403.append(S3RGB_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_103.append(S3RGB_imgA1A3_3[i][j])

# %%
S3A1_503= list()  
S3A3_5103 = list()
for i in range(S3RGB_imgA1A3_53.shape[0]): 
     for j in range(S3RGB_imgA1A3_53.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_503.append(S3RGB_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_5103.append(S3RGB_imgA1A3_53[i][j])

# %%
S3A1_603= list()
S3A4_103 = list()
for i in range(S3RGB_imgA1A4_3.shape[0]): 
     for j in range(S3RGB_imgA1A4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_603.append(S3RGB_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_103.append(S3RGB_imgA1A4_3[i][j])

# %%
S3A1_703= list()
S3B1_103 = list()
for i in range(S3RGB_imgA1B1_3.shape[0]): 
     for j in range(S3RGB_imgA1B1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_703.append(S3RGB_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_103.append(S3RGB_imgA1B1_3[i][j])

# %%
S3A1_803= list()
S3B2_103 = list()
for i in range(S3RGB_imgA1B2_3.shape[0]): 
     for j in range(S3RGB_imgA1B2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_803.append(S3RGB_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_103.append(S3RGB_imgA1B2_3[i][j])

# %%
S3A1_903= list()
S3B3_103 = list()
for i in range(S3RGB_imgA1B3_3.shape[0]): 
     for j in range(S3RGB_imgA1B3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_903append(S3RGB_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_103.append(S3RGB_imgA1B3_3[i][j])

# %%
S3A1_1003= list()
S3B4_103 = list()
for i in range(S3RGB_imgA1B4_3.shape[0]): 
     for j in range(S3RGB_imgA1B4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1003.append(S3RGB_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_103.append(S3RGB_imgA1B4_3[i][j])

# %%
S3A1_1103= list()
S3C1_203 = list()
for i in range(S3RGB_imgA1C1_.shape[0]): 
     for j in range(S3RGB_imgA1C1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1103.append(S3RGB_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_203.append(S3RGB_imgA1C1_3[i][j])

# %%
S3A1_1203= list()
S3C2_103 = list()
for i in range(S3RGB_imgA1C2_3.shape[0]): 
     for j in range(S3RGB_imgA1C2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1203.append(S3RGB_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_103.append(S3RGB_imgA1C2_3[i][j])

# %%
S3A1_1303= list()
S3C3_103 = list()
for i in range(S3RGB_imgA1C3_3.shape[0]): 
     for j in range(S3RGB_imgA1C3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1303.append(S3RGB_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_103.append(S3RGB_imgA1C3_3[i][j])

# %%
S3A1_1403= list()
S3C4_103 = list()
for i in range(S3RGB_imgA1C4_3.shape[0]): 
     for j in range(S3RGB_imgA1C4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1403.append(S3RGB_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_103.append(S3RGB_imgA1C4_3[i][j])

# %%
S3A1_1503= list()
S3D2_103 = list()
for i in range(S3RGB_imgA1D2_3.shape[0]): 
     for j in range(S3RGB_imgA1D2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1503.append(S3RGB_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_103.append(S3RGB_imgA1D2_3[i][j])

# %%
S3A1_1603= list()
S3D3_103 = list()
for i in range(S3RGB_imgA1D3_3.shape[0]): 
     for j in range(S3RGB_imgA1D3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1603.append(S3RGB_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_103.append(S3RGB_imgA1D3_3[i][j])

# %%
S3A1_1703= list()
S3D4_103 = list()
for i in range(S3RGB_imgA1D4_3.shape[0]): 
     for j in range(S3RGB_imgA1D4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1703.append(S3RGB_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_103.append(S3RGB_imgA1D4_3[i][j])

# %% [markdown]
# ###Img 4

# %%
S3A1_104= list()
S3A1_204= list()
for i in range(S3RGB_imgA1A1_4.shape[0]): 
     for j in range(S3RGB_imgA1A1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_104.append(S3RGB_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_204.append(S3RGB_imgA1A1_4[i][j])

# %%
S3A1_304= list()
S3A2_104 = list()
for i in range(S3RGB_imgA1A2_4.shape[0]): 
     for j in range(S3RGB_imgA1A2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_304.append(S3RGB_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_104.append(S3RGB_imgA1A2_4[i][j])

# %%
S3A1_404= list()
S3A3_104 = list()
for i in range(S3RGB_imgA1A3_4.shape[0]): 
     for j in range(S3RGB_imgA1A3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_404.append(S3RGB_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_104.append(S3RGB_imgA1A3_4[i][j])

# %%
S3A1_504= list()
S3A3_5104 = list()
for i in range(S3RGB_imgA1A3_54.shape[0]): 
     for j in range(S3RGB_imgA1A3_54.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_504.append(S3RGB_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_5104.append(S3RGB_imgA1A3_54[i][j])

# %%
S3A1_604= list()
S3A4_104 = list()
for i in range(S3RGB_imgA1A4_4.shape[0]): 
     for j in range(S3RGB_imgA1A4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_604.append(S3RGB_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_104.append(S3RGB_imgA1A4_4[i][j])

# %%
S3A1_704= list()
S3B1_104 = list()
for i in range(S3RGB_imgA1B1_4.shape[0]): 
     for j in range(S3RGB_imgA1B1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_704.append(S3RGB_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_104.append(S3RGB_imgA1B1_4[i][j])

# %%
S3A1_804= list()
S3B2_104 = list()
for i in range(S3RGB_imgA1B2_.shape[0]): 
     for j in range(S3RGB_imgA1B2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_804.append(S3RGB_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_104.append(S3RGB_imgA1B2_[i][j])

# %%
S3A1_904= list()
S3B3_104 = list()
for i in range(S3RGB_imgA1B3_4.shape[0]): 
     for j in range(S3RGB_imgA1B3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_904.append(S3RGB_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_104.append(S3RGB_imgA1B3_4[i][j])

# %%
S3A1_1004= list()
S3B4_104 = list()
for i in range(S3RGB_imgA1B4_4.shape[0]): 
     for j in range(S3RGB_imgA1B4_.4shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1004.append(S3RGB_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_104.append(S3RGB_imgA1B4_4[i][j])

# %%
S3A1_1104= list()
S3C1_204 = list()
for i in range(S3RGB_imgA1C1_4.shape[0]): 
     for j in range(S3RGB_imgA1C1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1104.append(S3RGB_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_204.append(S3RGB_imgA1C1_4[i][j])

# %%
S3A1_1204= list()
S3C2_104 = list()
for i in range(S3RGB_imgA1C2_4.shape[0]): 
     for j in range(S3RGB_imgA1C2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1204.append(S3RGB_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_104.append(S3RGB_imgA1C2_4[i][j])

# %%
S3A1_1304= list()
S3C3_104 = list()
for i in range(S3RGB_imgA1C3_4.shape[0]): 
     for j in range(S3RGB_imgA1C3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1304.append(S3RGB_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_104.append(S3RGB_imgA1C3_4[i][j])

# %%
S3A1_1404= list()
S3C4_104 = list()
for i in range(S3RGB_imgA1C4_4.shape[0]): 
     for j in range(S3RGB_imgA1C4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1404.append(S3RGB_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_104.append(S3RGB_imgA1C4_4[i][j])

# %%
S3A1_1504= list()
S3D2_104 = list()
for i in range(S3RGB_imgA1D2_4.shape[0]): 
     for j in range(S3RGB_imgA1D2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1504.append(S3RGB_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_104.append(S3RGB_imgA1D2_4[i][j])

# %%
S3A1_1604= list()
S3D3_104 = list()
for i in range(S3RGB_imgA1D3_4.shape[0]): 
     for j in range(S3RGB_imgA1D3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1604.append(S3RGB_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_104.append(S3RGB_imgA1D3_4[i][j])

# %%
S3A1_1704= list()
S3D4_104 = list()
for i in range(S3RGB_imgA1D4_4.shape[0]): 
     for j in range(S3RGB_imgA1D4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1704.append(S3RGB_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_104.append(S3RGB_imgA1D4_4[i][j])

# %% [markdown]
# ###Img 5

# %%
S3A1_105= list()
S3A1_205= list()
for i in range(S3RGB_imgA1A1_5.shape[0]): 
     for j in range(S3RGB_imgA1A1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_105.append(S3RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_205.append(S3RGB_imgA1A1_5[i][j])

# %%
S3A1_305= list()
S3A2_105 = list()
for i in range(S3RGB_imgA1A2_5.shape[0]): 
     for j in range(S3RGB_imgA1A2_.5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_305.append(S3RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_105.append(S3RGB_imgA1A2_5[i][j])

# %%
S3A1_405= list()
S3A3_105 = list()
for i in range(S3RGB_imgA1A3_5.shape[0]): 
     for j in range(S3RGB_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_405.append(S3RGB_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_105.append(S3RGB_imgA1A3_5[i][j])

# %%
S3A1_505= list()
S3A3_5105 = list()
for i in range(S3RGB_imgA1A3_55.shape[0]): 
     for j in range(S3RGB_imgA1A3_55.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_505.append(S3RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_5105.append(S3RGB_imgA1A3_55[i][j])

# %%
S3A1_605= list()
S3A4_105 = list()
for i in range(S3RGB_imgA1A4_5.shape[0]): 
     for j in range(S3RGB_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_605.append(S3RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_105.append(S3RGB_imgA1A4_5[i][j])

# %%
S3A1_705= list()
S3B1_105 = list()
for i in range(S3RGB_imgA1B1_5.shape[0]): 
     for j in range(S3RGB_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_705.append(S3RGB_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_105.append(S3RGB_imgA1B1_5[i][j])

# %%
S3A1_805= list()
S3B2_105 = list()
for i in range(S3RGB_imgA1B2_5.shape[0]): 
     for j in range(S3RGB_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_805.append(S3RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_105.append(S3RGB_imgA1B2_5[i][j])

# %%
S3A1_905= list()
S3B3_105 = list()
for i in range(S3RGB_imgA1B3_5.shape[0]): 
     for j in range(S3RGB_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_905.append(S3RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_105.append(S3RGB_imgA1B3_5[i][j])

# %%
S3A1_1005= list()
S3B4_105 = list()
for i in range(S3RGB_imgA1B4_5.shape[0]): 
     for j in range(S3RGB_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1005.append(S3RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_105.append(S3RGB_imgA1B4_5[i][j])

# %%
S3A1_1105= list()
S3C1_205 = list()
for i in range(S3RGB_imgA1C1_5.shape[0]): 
     for j in range(S3RGB_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1105.append(S3RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_205.append(S3RGB_imgA1C1_5[i][j])

# %%
S3A1_1205= list()
S3C2_105 = list()
for i in range(S3RGB_imgA1C2_5.shape[0]): 
     for j in range(S3RGB_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1205.append(S3RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_105.append(S3RGB_imgA1C2_5[i][j])

# %%
S3A1_1305= list()
S3C3_105 = list()
for i in range(S3RGB_imgA1C3_5.shape[0]): 
     for j in range(S3RGB_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1305.append(S3RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_105.append(S3RGB_imgA1C3_5[i][j])

# %%
S3A1_1405= list()
S3C4_105 = list()
for i in range(S3RGB_imgA1C4_5.shape[0]): 
     for j in range(S3RGB_imgA1C4_.5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1405.append(S3RGB_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_105.append(S3RGB_imgA1C4_5[i][j])

# %%
S3A1_1505= list()
S3D2_105 = list()
for i in range(S3RGB_imgA1D2_5.shape[0]): 
     for j in range(S3RGB_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1505.append(S3RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_105.append(S3RGB_imgA1D2_5[i][j])

# %%
S3A1_1605= list()
S3D3_105 = list()
for i in range(S3RGB_imgA1D3_5.shape[0]): 
     for j in range(S3RGB_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1605.append(S3RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_105.append(S3RGB_imgA1D3_5[i][j])

# %%
S3A1_1705= list()
S3D4_105= list()
for i in range(S3RGB_imgA1D4_5.shape[0]): 
     for j in range(S3RGB_imgA1D4_.5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1705.append(S3RGB_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_105.append(S3RGB_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 6

# %%
S3A1_106= list()
S3A1_206= list()
for i in range(S3RGB_imgA1A1_6.shape[0]): 
     for j in range(S3RGB_imgA1A1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_106.append(S3RGB_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_206.append(S3RGB_imgA1A1_6[i][j])

# %%
S3A1_306= list()
S3A2_106 = list()
for i in range(S3RGB_imgA1A2_6.shape[0]): 
     for j in range(S3RGB_imgA1A2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_306.append(S3RGB_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_106.append(S3RGB_imgA1A2_6[i][j])

# %%
S3A1_406= list()
S3A3_106 = list()
for i in range(S3RGB_imgA1A3_.shape[0]): 
     for j in range(S3RGB_imgA1A3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_406.append(S3RGB_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_106.append(S3RGB_imgA1A3_6[i][j])

# %%
S3A1_506= list()
S3A3_5106 = list()
for i in range(S3RGB_imgA1A3_56.shape[0]): 
     for j in range(S3RGB_imgA1A3_56.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_506.append(S3RGB_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_5106.append(S3RGB_imgA1A3_56[i][j])

# %%
S3A1_606= list()
S3A4_106 = list()
for i in range(S3RGB_imgA1A4_.6shape[0]): 
     for j in range(S3RGB_imgA1A4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_606.append(S3RGB_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_106.append(S3RGB_imgA1A4_6[i][j])

# %%
S3A1_706= list()
S3B1_106 = list()
for i in range(S3RGB_imgA1B1_6.shape[0]): 
     for j in range(S3RGB_imgA1B1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_706append(S3RGB_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_106.append(S3RGB_imgA1B1_6[i][j])

# %%
S3A1_806= list()
S3B2_106 = list()
for i in range(S3RGB_imgA1B2_6.shape[0]): 
     for j in range(S3RGB_imgA1B2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_806.append(S3RGB_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_106.append(S3RGB_imgA1B2_6[i][j])

# %%
S3A1_906= list()
S3B3_106 = list()
for i in range(S3RGB_imgA1B3_6.shape[0]): 
     for j in range(S3RGB_imgA1B3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_906.append(S3RGB_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_106.append(S3RGB_imgA1B3_6[i][j])

# %%
S3A1_1006= list()
S3B4_106 = list()
for i in range(S3RGB_imgA1B4_6.shape[0]): 
     for j in range(S3RGB_imgA1B4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1006.append(S3RGB_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_106.append(S3RGB_imgA1B4_6[i][j])

# %%
S3A1_1106= list()
S3C1_206= list()
for i in range(S3RGB_imgA1C1_6.shape[0]): 
     for j in range(S3RGB_imgA1C1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1106.append(S3RGB_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_206.append(S3RGB_imgA1C1_6[i][j])

# %%
S3A1_1206= list()
S3C2_106= list()
for i in range(S3RGB_imgA1C2_6.shape[0]): 
     for j in range(S3RGB_imgA1C2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1206.append(S3RGB_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_106.append(S3RGB_imgA1C2_6[i][j])

# %%
S3A1_1306= list()
S3C3_106 = list()
for i in range(S3RGB_imgA1C3_6.shape[0]): 
     for j in range(S3RGB_imgA1C3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1306.append(S3RGB_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_106.append(S3RGB_imgA1C3_6[i][j])

# %%
S3A1_1406= list()
S3C4_106= list()
for i in range(S3RGB_imgA1C4_6.shape[0]): 
     for j in range(S3RGB_imgA1C4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1406.append(S3RGB_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_106.append(S3RGB_imgA1C4_6[i][j])

# %%
S3A1_1506= list()
S3D2_106 = list()
for i in range(S3RGB_imgA1D2_6.shape[0]): 
     for j in range(S3RGB_imgA1D2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1506.append(S3RGB_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_106.append(S3RGB_imgA1D2_6[i][j])

# %%
S3A1_1606= list()
S3D3_106 = list()
for i in range(S3RGB_imgA1D3_6.shape[0]): 
     for j in range(S3RGB_imgA1D3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1606.append(S3RGB_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_106.append(S3RGB_imgA1D3_6[i][j])

# %%
S3A1_1706= list()
S3D4_106 = list()
for i in range(S3RGB_imgA1D4_6.shape[0]): 
     for j in range(S3RGB_imgA1D4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1706.append(S3RGB_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_106.append(S3RGB_imgA1D4_6[i][j])

# %% [markdown]
# ###Img 7

# %%
S3A1_107= list()
S3A1_207= list()
for i in range(S3RGB_imgA1A1_7.shape[0]): 
     for j in range(S3RGB_imgA1A1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_107.append(S3RGB_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_207.append(S3RGB_imgA1A1_7[i][j])

# %%
S3A1_307= list()
S3A2_107 = list()
for i in range(S3RGB_imgA1A2_7.shape[0]): 
     for j in range(S3RGB_imgA1A2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_307.append(S3RGB_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_107.append(S3RGB_imgA1A2_7[i][j])

# %%
S3A1_407= list()
S3A3_107= list()
for i in range(S3RGB_imgA1A3_7.shape[0]): 
     for j in range(S3RGB_imgA1A3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_407.append(S3RGB_imgA1A3_87[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_107.append(S3RGB_imgA1A3_7[i][j])

# %%
S3A1_507= list()
S3A3_5107 = list()
for i in range(S3RGB_imgA1A3_57.shape[0]): 
     for j in range(S3RGB_imgA1A3_57.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_507.append(S3RGB_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_5107.append(S3RGB_imgA1A3_57[i][j])

# %%
S3A1_607= list()
S3A4_107 = list()
for i in range(S3RGB_imgA1A4_7.shape[0]): 
     for j in range(S3RGB_imgA1A4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_607.append(S3RGB_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_107.append(S3RGB_imgA1A4_7[i][j])

# %%
S3A1_707= list()
S3B1_107 = list()
for i in range(S3RGB_imgA1B1_7.shape[0]): 
     for j in range(S3RGB_imgA1B1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_707.append(S3RGB_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_107.append(S3RGB_imgA1B1_7[i][j])

# %%
S3A1_807= list()
S3B2_107 = list()
for i in range(S3RGB_imgA1B2_7.shape[0]): 
     for j in range(S3RGB_imgA1B2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_807.append(S3RGB_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_107.append(S3RGB_imgA1B2_7[i][j])

# %%
S3A1_907= list()
S3B3_107 = list()
for i in range(S3RGB_imgA1B3_7.shape[0]): 
     for j in range(S3RGB_imgA1B3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_907.append(S3RGB_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_107.append(S3RGB_imgA1B3_7[i][j])

# %%
S3A1_1007= list()
S3B4_107 = list()
for i in range(S3RGB_imgA1B4_7shape[0]): 
     for j in range(S3RGB_imgA1B4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1007.append(S3RGB_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_107.append(S3RGB_imgA1B4_7[i][j])

# %%
S3A1_1107= list()
S3C1_207 = list()
for i in range(S3RGB_imgA1C1_7.shape[0]): 
     for j in range(S3RGB_imgA1C1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1107.append(S3RGB_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_207.append(S3RGB_imgA1C1_7i][j])

# %%
S3A1_1207= list()
S3C2_107 = list()
for i in range(S3RGB_imgA1C2_7.shape[0]): 
     for j in range(S3RGB_imgA1C2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1207.append(S3RGB_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_107.append(S3RGB_imgA1C2_7[i][j])

# %%
S3A1_1307= list()
S3C3_107 = list()
for i in range(S3RGB_imgA1C3_7.shape[0]): 
     for j in range(S3RGB_imgA1C3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_13.append(S3RGB_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_1.append(S3RGB_imgA1C3_7[i][j])

# %%
S3A1_1407= list()
S3C4_107 = list()
for i in range(S3RGB_imgA1C4_7.shape[0]): 
     for j in range(S3RGB_imgA1C4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1407.append(S3RGB_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_107.append(S3RGB_imgA1C4_7[i][j])

# %%
S3A1_1507= list()
S3D2_107 = list()
for i in range(S3RGB_imgA1D2_7.shape[0]): 
     for j in range(S3RGB_imgA1D2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1507.append(S3RGB_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_107.append(S3RGB_imgA1D2_7i][j])

# %%
S3A1_1607= list()
S3D3_107 = list()
for i in range(S3RGB_imgA1D3_7.shape[0]): 
     for j in range(S3RGB_imgA1D3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1607.append(S3RGB_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_107.append(S3RGB_imgA1D3_7[i][j])

# %%
S3A1_1707= list()
S3D4_107 = list()
for i in range(S3RGB_imgA1D4_7.shape[0]): 
     for j in range(S3RGB_imgA1D4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1707.append(S3RGB_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_107.append(S3RGB_imgA1D4_7[i][j])

# %% [markdown]
# ###Img 8

# %%
S3A1_108= list()
S3A1_208= list()
for i in range(S3RGB_imgA1A1_8.shape[0]): 
     for j in range(S3RGB_imgA1A1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_108.append(S3RGB_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_208.append(S3RGB_imgA1A1_8[i][j])

# %%
S3A1_308= list()
S3A2_108 = list()
for i in range(S3RGB_imgA1A2_8.shape[0]): 
     for j in range(S3RGB_imgA1A2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_308.append(S3RGB_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_108.append(S3RGB_imgA1A2_8[i][j])

# %%
S3A1_408= list()
S3A3_108 = list()
for i in range(S3RGB_imgA1A3_8.shape[0]): 
     for j in range(S3RGB_imgA1A3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_408.append(S3RGB_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_108.append(S3RGB_imgA1A3_8[i][j])

# %%
S3A1_508= list()
S3A3_5108 = list()
for i in range(S3RGB_imgA1A3_58.shape[0]): 
     for j in range(S3RGB_imgA1A3_58.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_508.append(S3RGB_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_5108.append(S3RGB_imgA1A3_58[i][j])

# %%
S3A1_608= list()
S3A4_108 = list()
for i in range(S3RGB_imgA1A4_.shape[0]): 
     for j in range(S3RGB_imgA1A4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_608.append(S3RGB_imgA1A4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_108.append(S3RGB_imgA1A4_[i][j])

# %%
S3A1_708= list()
S3B1_108 = list()
for i in range(S3RGB_imgA1B1_8.shape[0]): 
     for j in range(S3RGB_imgA1B1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_708.append(S3RGB_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_108.append(S3RGB_imgA1B1_8[i][j])

# %%
S3A1_808= list()
S3B2_108 = list()
for i in range(S3RGB_imgA1B2_.shape[0]): 
     for j in range(S3RGB_imgA1B2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_808.append(S3RGB_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_108.append(S3RGB_imgA1B2_[i][j])

# %%
S3A1_908= list()
S3B3_108 = list()
for i in range(S3RGB_imgA1B3_8.shape[0]): 
     for j in range(S3RGB_imgA1B3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_908.append(S3RGB_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_108.append(S3RGB_imgA1B3_8[i][j])

# %%
S3A1_1008= list()
S3B4_108 = list()
for i in range(S3RGB_imgA1B4_8.shape[0]): 
     for j in range(S3RGB_imgA1B4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1008.append(S3RGB_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_108.append(S3RGB_imgA1B4_8[i][j])

# %%
S3A1_1108= list()
S3C1_208 = list()
for i in range(S3RGB_imgA1C1_8.shape[0]): 
     for j in range(S3RGB_imgA1C1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1108.append(S3RGB_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_208.append(S3RGB_imgA1C1_8[i][j])

# %%
S3A1_1208= list()
S3C2_108 = list()
for i in range(S3RGB_imgA1C2_8.shape[0]): 
     for j in range(S3RGB_imgA1C2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1208.append(S3RGB_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_108.append(S3RGB_imgA1C2_8[i][j])

# %%
S3A1_1308= list()
S3C3_108 = list()
for i in range(S3RGB_imgA1C3_8.shape[0]): 
     for j in range(S3RGB_imgA1C3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1308.append(S3RGB_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_108.append(S3RGB_imgA1C3_8[i][j])

# %%
S3A1_1408= list()
S3C4_108 = list()
for i in range(S3RGB_imgA1C4_8.shape[0]): 
     for j in range(S3RGB_imgA1C4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1408.append(S3RGB_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_108.append(S3RGB_imgA1C4_8[i][j])

# %%
S3A1_1508= list()
S3D2_108 = list()
for i in range(S3RGB_imgA1D2_8.shape[0]): 
     for j in range(S3RGB_imgA1D2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1508append(S3RGB_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_108.append(S3RGB_imgA1D2_8[i][j])

# %%
S3A1_1608= list()
S3D3_108 = list()
for i in range(S3RGB_imgA1D3_.shape[0]): 
     for j in range(S3RGB_imgA1D3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1608.append(S3RGB_imgA1D3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_108.append(S3RGB_imgA1D3_[i][j])

# %%
S3A1_1708= list()
S3D4_108 = list()
for i in range(S3RGB_imgA1D4_8.shape[0]): 
     for j in range(S3RGB_imgA1D4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_17.08append(S3RGB_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_108.append(S3RGB_imgA1D4_8[i][j])

# %% [markdown]
# ###Img 9

# %%
S3A1_109= list()
S3A1_209= list()
for i in range(S3RGB_imgA1A1_9.shape[0]): 
     for j in range(S3RGB_imgA1A1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_109.append(S3RGB_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_209.append(S3RGB_imgA1A1_9[i][j])

# %%
S3A1_309= list()
S3A2_109 = list()
for i in range(S3RGB_imgA1A2_9.shape[0]): 
     for j in range(S3RGB_imgA1A2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_309.append(S3RGB_imgA1A2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_109.append(S3RGB_imgA1A2_9[i][j])

# %%
S3A1_409= list()
S3A3_109 = list()
for i in range(S3RGB_imgA1A3_9.shape[0]): 
     for j in range(S3RGB_imgA1A3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_409.append(S3RGB_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_109.append(S3RGB_imgA1A3_9[i][j])

# %%
S3A1_509= list()
S3A3_5109 = list()
for i in range(S3RGB_imgA1A3_59.shape[0]): 
     for j in range(S3RGB_imgA1A3_59.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_509.append(S3RGB_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_5109.append(S3RGB_imgA1A3_59[i][j])

# %%
S3A1_609= list()
S3A4_109 = list()
for i in range(S3RGB_imgA1A4_9.shape[0]): 
     for j in range(S3RGB_imgA1A4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_609.append(S3RGB_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_109.append(S3RGB_imgA1A4_9[i][j])

# %%
S3A1_709= list()
S3B1_109 = list()
for i in range(S3RGB_imgA1B1_9.shape[0]): 
     for j in range(S3RGB_imgA1B1_.9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_709.append(S3RGB_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_109.append(S3RGB_imgA1B1_9[i][j])

# %%
S3A1_809= list()
S3B2_109 = list()
for i in range(S3RGB_imgA1B2_9.shape[0]): 
     for j in range(S3RGB_imgA1B2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_8.append(S3RGB_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_1.append(S3RGB_imgA1B2_9[i][j])

# %%
S3A1_9= list()
S3B3_1 = list()
for i in range(S3RGB_imgA1B3_9.shape[0]): 
     for j in range(S3RGB_imgA1B3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_909.append(S3RGB_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_109.append(S3RGB_imgA1B3_9[i][j])

# %%
S3A1_1009= list()
S3B4_109 = list()
for i in range(S3RGB_imgA1B4_9.shape[0]): 
     for j in range(S3RGB_imgA1B4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1009.append(S3RGB_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_109.append(S3RGB_imgA1B4_9[i][j])

# %%
S3A1_1109= list()
S3C1_209 = list()
for i in range(S3RGB_imgA1C1_9.shape[0]): 
     for j in range(S3RGB_imgA1C1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1109.append(S3RGB_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_209.append(S3RGB_imgA1C1_9[i][j])

# %%
S3A1_1209= list()
S3C2_109= list()
for i in range(S3RGB_imgA1C2_.shape[0]): 
     for j in range(S3RGB_imgA1C2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1209.append(S3RGB_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_109.append(S3RGB_imgA1C2_9[i][j])

# %%
S3A1_1309= list()
S3C3_109= list()
for i in range(S3RGB_imgA1C3_9.shape[0]): 
     for j in range(S3RGB_imgA1C3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1309.append(S3RGB_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_109.append(S3RGB_imgA1C3_9[i][j])

# %%
S3A1_1409= list()
S3C4_109 = list()
for i in range(S3RGB_imgA1C4_9.shape[0]): 
     for j in range(S3RGB_imgA1C4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1409.append(S3RGB_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_109.append(S3RGB_imgA1C4_9[i][j])

# %%
S3A1_1509= list()
S3D2_109 = list()
for i in range(S3RGB_imgA1D2_9.shape[0]): 
     for j in range(S3RGB_imgA1D2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1509.append(S3RGB_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_109.append(S3RGB_imgA1D2_9[i][j])

# %%
S3A1_1609= list()
S3D3_109 = list()
for i in range(S3RGB_imgA1D3_9.shape[0]): 
     for j in range(S3RGB_imgA1D3_.9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_16.append(S3RGB_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_1.append(S3RGB_imgA1D3_9[i][j])

# %%
S3A1_17= list()
S3D4_1 = list()
for i in range(S3RGB_imgA1D4_9.shape[0]): 
     for j in range(S3RGB_imgA1D4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1709.append(S3RGB_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_109.append(S3RGB_imgA1D4_9[i][j])

# %% [markdown]
# ###Img 10

# %%
S3A1_110= list()
S3A1_210= list()
for i in range(S3RGB_imgA1A1_10.shape[0]): 
     for j in range(S3RGB_imgA1A1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_110.append(S3RGB_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A1_210.append(S3RGB_imgA1A1_10[i][j])

# %%
S3A1_310= list()
S3A2_110 = list()
for i in range(S3RGB_imgA1A2_10.shape[0]): 
     for j in range(S3RGB_imgA1A2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_310.append(S3RGB_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A2_110.append(S3RGB_imgA1A2_10[i][j])

# %%
S3A1_410= list()
S3A3_110 = list()
for i in range(S3RGB_imgA1A3_.shape[0]): 
     for j in range(S3RGB_imgA1A3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_410.append(S3RGB_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_110.append(S3RGB_imgA1A3_10[i][j])

# %%
S3A1_510= list()
S3A3_510 = list()
for i in range(S3RGB_imgA1A3_510.shape[0]): 
     for j in range(S3RGB_imgA1A3_510.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_510.append(S3RGB_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A3_510.append(S3RGB_imgA1A3_510[i][j])

# %%
S3A1_610= list()
S3A4_110 = list()
for i in range(S3RGB_imgA1A4_.shape[0]): 
     for j in range(S3RGB_imgA1A4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_610.append(S3RGB_imgA1A4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3A4_110.append(S3RGB_imgA1A4_[i][j])

# %%
S3A1_710= list()
S3B1_110 = list()
for i in range(S3RGB_imgA1B1_10.shape[0]): 
     for j in range(S3RGB_imgA1B1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_710.append(S3RGB_imgA1B110_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B1_110.append(S3RGB_imgA1B1_10[i][j])

# %%
S3A1_810= list()
S3B2_110 = list()
for i in range(S3RGB_imgA1B2_10.shape[0]): 
     for j in range(S3RGB_imgA1B2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_810.append(S3RGB_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B2_110.append(S3RGB_imgA1B2_10[i][j])

# %%
S3A1_910= list()
S3B3_110 = list()
for i in range(S3RGB_imgA1B3_10.shape[0]): 
     for j in range(S3RGB_imgA1B3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_910.append(S3RGB_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B3_110.append(S3RGB_imgA1B3_10[i][j])

# %%
S3A1_1010= list()
S3B4_110 = list()
for i in range(S3RGB_imgA1B4_10.shape[0]): 
     for j in range(S3RGB_imgA1B4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1010.append(S3RGB_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3B4_110.append(S3RGB_imgA1B4_10[i][j])

# %%
S3A1_1110= list()
S3C1_210= list()
for i in range(S3RGB_imgA1C1_10.shape[0]): 
     for j in range(S3RGB_imgA1C1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_11.append(S3RGB_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C1_2.append(S3RGB_imgA1C1_10[i][j])

# %%
S3A1_1210= list()
S3C2_110 = list()
for i in range(S3RGB_imgA1C2_10.shape[0]): 
     for j in range(S3RGB_imgA1C2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_12.append(S3RGB_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C2_1.append(S3RGB_imgA1C2_10[i][j])

# %%
S3A1_1310= list()
S3C3_110 = list()
for i in range(S3RGB_imgA1C3_10.shape[0]): 
     for j in range(S3RGB_imgA1C3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_13.append(S3RGB_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C3_1.append(S3RGB_imgA1C3_10i][j])

# %%
S3A1_1410= list()
S3C4_110 = list()
for i in range(S3RGB_imgA1C4_10.shape[0]): 
     for j in range(S3RGB_imgA1C4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_14.append(S3RGB_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3C4_1.append(S3RGB_imgA1C4_10[i][j])

# %%
S3A1_1510= list()
S3D2_110 = list()
for i in range(S3RGB_imgA1D2_10.shape[0]): 
     for j in range(S3RGB_imgA1D2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1510.append(S3RGB_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D2_110.append(S3RGB_imgA1D2_10[i][j])

# %%
S3A1_1610= list()
S3D3_110= list()
for i in range(S3RGB_imgA1D3_10.shape[0]): 
     for j in range(S3RGB_imgA1D3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_1610.append(S3RGB_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D3_110.append(S3RGB_imgA1D3_10[i][j])

# %%
S3A1_1710 list()
S3D4_110 = list()
for i in range(S3RGB_imgA1D4_10.shape[0]): 
     for j in range(S3RGB_imgA1D4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S3A1_17.append(S3RGB_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S3D4_1.append(S3RGB_imgA1D4_10[i][j])

# %% [markdown]
# ###HSV

# %% [markdown]
# ###Img 2

# %%
S1A1_102= list()
S1A1_202 = list()
for i in range(S1HSV_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_102.append(S1HSV_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_202.append(S1HSV_imgA1A1_2[i][j])

# %%
S1A1_302= list()
S1A2_102= list()
for i in range(S1HSV_imgA1A2_2.shape[0]): 
     for j in range(S1HSV_imgA1A2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_302.append(S1HSV_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_102.append(S1HSV_imgA1A2_2[i][j])

# %%
S1A1_4= list()
S1A3_1 = list()
for i in range(S1HSV_imgA1A3_1.shape[0]): 
     for j in range(S1HSV_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_4.append(S1HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_1.append(S1HSV_imgA1A3_1[i][j])

# %%
S1A1_502= list()
S1A3_5102 = list()
for i in range(S1HSV_imgA1A3_52.shape[0]): 
     for j in range(S1HSV_imgA1A3_52.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_50.append(S1HSV_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_510.append(S1HSV_imgA1A3_52[i][j])

# %%
S1A1_602= list()
S1A4_102 = list()
for i in range(S1HSV_imgA1A4_2.shape[0]): 
     for j in range(S1HSV_imgA1A4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_602.append(S1HSV_2imgA1A4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_102.append(S1HSV_imgA1A4_2[i][j])

# %%
S1A1_702= list()
S1B1_102= list()
for i in range(S1HSV_imgA1B1_2.shape[0]): 
     for j in range(S1HSV_imgA1B1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_702.append(S1HSV_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_102.append(S1HSV_imgA1B1_2[i][j])

# %%
S1A1_802= list()
S1B2_102 = list()
for i in range(S1HSV_imgA1B2_2.shape[0]): 
     for j in range(S1HSV_imgA1B2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_802.append(S1HSV_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_102.append(S1HSV_imgA1B2_2[i][j])

# %%
S1A1_902= list()
S1B3_102 = list()
for i in range(S1HSV_imgA1B3_2.shape[0]): 
     for j in range(S1HSV_imgA1B3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_902.append(S1HSV_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_102.append(S1HSV_imgA1B3_2[i][j])

# %%
S1A1_1002= list()
S1B4_102= list()
for i in range(S1HSV_imgA1B4_2.shape[0]): 
     for j in range(S1HSV_imgA1B4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1002.append(S1HSV_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_102.append(S1HSV_imgA1B4_2[i][j])

# %%
S1A1_1102= list()
S1C1_202 = list()
for i in range(S1HSV_imgA1C1_2.shape[0]): 
     for j in range(S1HSV_imgA1C1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1102.append(S1HSV_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_202.append(S1HSV_imgA1C1_2[i][j])

# %%
S1A1_1202= list()
S1C2_102 = list()
for i in range(S1HSV_imgA1C2_2.shape[0]): 
     for j in range(S1HSV_imgA1C2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1202.append(S1HSV_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_102.append(S1HSV_imgA1C2_2[i][j])

# %%
S1A1_1302= list()
S1C3_102 = list()
for i in range(S1HSV_imgA1C3_2.shape[0]): 
     for j in range(S1HSV_imgA1C3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1302.append(S1HSV_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_102.append(S1HSV_imgA1C3_2[i][j])

# %%
S1A1_1402= list()
S1C4_102 = list()
for i in range(S1HSV_imgA1C4_2.shape[0]): 
     for j in range(S1HSV_imgA1C4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1402.append(S1HSV_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_102.append(S1HSV_imgA1C4_2[i][j])

# %%
S1A1_1502= list()
S1D2_102 = list()
for i in range(S1HSV_imgA1D2_2.shape[0]): 
     for j in range(S1HSV_imgA1D2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1502.append(S1HSV_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_102.append(S1HSV_imgA1D2_2[i][j])

# %%
S1A1_1602= list()
S1D3_102 = list()
for i in range(S1HSV_imgA1D3_2shape[0]): 
     for j in range(S1HSV_imgA1D3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1602.append(S1HSV_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_102.append(S1HSV_imgA1D3_2[i][j])

# %%
S1A1_1702= list()
S1D4_102 = list()
for i in range(S1HSV_imgA1D4_2.shape[0]): 
     for j in range(S1HSV_imgA1D4_2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1702.append(S1HSV_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_102.append(S1HSV_imgA1D4_2[i][j])

# %% [markdown]
# ###Img 3

# %%
S1A1_103= list()
S1A1_203 = list()
for i in range(S1HSV_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_103.append(S1HSV_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_203append(S1HSV_imgA1A1_3[i][j])

# %%
S1A1_303= list()
S1A2_103 = list()
for i in range(S1HSV_imgA1A2_3.shape[0]): 
     for j in range(S1HSV_imgA1A2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_303.append(S1HSV_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_103.append(S1HSV_imgA1A2_3[i][j])

# %%
S1A1_403= list()
S1A3_103 = list()
for i in range(S1HSV_imgA1A3_3.shape[0]): 
     for j in range(S1HSV_imgA1A3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_403.append(S1HSV_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_103.append(S1HSV_imgA1A3_3[i][j])

# %%
S1A1_503= list()
S1A3_5103 = list()
for i in range(S1HSV_imgA1A3_53.shape[0]): 
     for j in range(S1HSV_imgA1A3_53.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_503.append(S1HSV_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5103.append(S1HSV_imgA1A3_53[i][j])

# %%
S1A1_60= list()
S1A4_10 = list()
for i in range(S1HSV_imgA1A4_.shape[0]): 
     for j in range(S1HSV_imgA1A4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_60.append(S1HSV_imgA1A4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_10.append(S1HSV_imgA1A4_[i][j])

# %%
S1A1_703= list()
S1B1_103= list()
for i in range(S1HSV_imgA1B1_3.shape[0]): 
     for j in range(S1HSV_imgA1B1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_703.append(S1HSV_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_103.append(S1HSV_imgA1B1_3[i][j])

# %%
S1A1_803= list()
S1B2_103 = list()
for i in range(S1HSV_imgA1B2_3.shape[0]): 
     for j in range(S1HSV_imgA1B2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_803.append(S1HSV_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_103.append(S1HSV_imgA1B2_3[i][j])

# %%
S1A1_903= list()
S1B3_103 = list()
for i in range(S1HSV_imgA1B3_3.shape[0]): 
     for j in range(S1HSV_imgA1B3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_903.append(S1HSV_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_103.append(S1HSV_imgA1B3_3[i][j])

# %%
S1A1_1003= list()
S1B4_103 = list()
for i in range(S1HSV_imgA1B4_3.shape[0]): 
     for j in range(S1HSV_imgA1B4_.3shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1003.append(S1HSV_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_103.append(S1HSV_imgA1B4_3[i][j])

# %%
S1A1_1103= list()
S1C1_203 = list()
for i in range(S1HSV_imgA1C1_3.shape[0]): 
     for j in range(S1HSV_imgA1C1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1103.append(S1HSV_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_203.append(S1HSV_imgA1C1_3[i][j])

# %%
S1A1_1203= list()
S1C2_103 = list()
for i in range(S1HSV_imgA1C23_.shape[0]): 
     for j in range(S1HSV_imgA1C23_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1203.append(S1HSV_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_103.append(S1HSV_imgA1C2_3[i][j])

# %%
S1A1_1303= list()
S1C3_103 = list()
for i in range(S1HSV_imgA1C3_3.shape[0]): 
     for j in range(S1HSV_imgA1C3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1303.append(S1HSV_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_103.append(S1HSV_imgA1C3_3[i][j])

# %%
S1A1_1403= list()
S1C4_103= list()
for i in range(S1HSV_imgA1C4_3.shape[0]): 
     for j in range(S1HSV_imgA1C4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1403.append(S1HSV_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_103.append(S1HSV_imgA1C4_3[i][j])

# %%
S1A1_1503= list()
S1D2_103 = list()
for i in range(S1HSV_imgA1D2_3.shape[0]): 
     for j in range(S1HSV_imgA1D2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1503.append(S1HSV_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_103.append(S1HSV_imgA1D2_3[i][j])

# %%
S1A1_1603= list()
S1D3_103 = list()
for i in range(S1HSV_imgA1D3_3.shape[0]): 
     for j in range(S1HSV_imgA1D3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1603.append(S1HSV_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_103.append(S1HSV_imgA1D3_3[i][j])

# %%
S1A1_1703= list()
S1D4_103 = list()
for i in range(S1HSV_imgA1D4_3.shape[0]): 
     for j in range(S1HSV_imgA1D4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1703.append(S1HSV_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_103.append(S1HSV_imgA1D4_3[i][j])

# %% [markdown]
# ###Img 4

# %%
S1A1_104= list()
S1A1_204 = list()
for i in range(S1HSV_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_104.append(S1HSV_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_204.append(S1HSV_imgA1A1_4[i][j])

# %%
S1A1_304= list()
S1A2_104 = list()
for i in range(S1HSV_imgA1A2_4.shape[0]): 
     for j in range(S1HSV_imgA1A2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_304.append(S1HSV_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_104.append(S1HSV_imgA1A2_4[i][j])

# %%
S1A1_404= list()
S1A3_104 = list()
for i in range(S1HSV_imgA1A3_4.shape[0]): 
     for j in range(S1HSV_imgA1A3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_404.append(S1HSV_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_104.append(S1HSV_imgA1A3_4[i][j])

# %%
S1A1_504= list()
S1A3_5104 = list()
for i in range(S1HSV_imgA1A3_54.shape[0]): 
     for j in range(S1HSV_imgA1A3_54.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_504.append(S1HSV_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5104.append(S1HSV_imgA1A3_54[i][j])

# %%
S1A1_604= list()
S1A4_104 = list()
for i in range(S1HSV_imgA1A4_4.shape[0]): 
     for j in range(S1HSV_imgA1A4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_604.append(S1HSV_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_104.append(S1HSV_imgA1A4_4[i][j])

# %%
S1A1_704= list()
S1B1_104 = list()
for i in range(S1HSV_imgA1B1_4.shape[0]): 
     for j in range(S1HSV_imgA1B1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_704.append(S1HSV_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_104.append(S1HSV_imgA1B1_4[i][j])

# %%
S1A1_804= list()
S1B2_104 = list()
for i in range(S1HSV_imgA1B2_4.shape[0]): 
     for j in range(S1HSV_imgA1B2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_804.append(S1HSV_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_104.append(S1HSV_imgA1B2_4[i][j])

# %%
S1A1_904= list()
S1B3_104 = list()
for i in range(S1HSV_imgA1B3_4.shape[0]): 
     for j in range(S1HSV_imgA1B3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_904.append(S1HSV_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_104.append(S1HSV_imgA1B3_4[i][j])

# %%
S1A1_1004= list()
S1B4_104 = list()
for i in range(S1HSV_imgA1B4_4.shape[0]): 
     for j in range(S1HSV_imgA1B4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1004.append(S1HSV_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_104.append(S1HSV_imgA1B4_4[i][j])

# %%
S1A1_1104= list()
S1C1_204= list()
for i in range(S1HSV_imgA1C1_4.shape[0]): 
     for j in range(S1HSV_imgA1C1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1104.append(S1HSV_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_204.append(S1HSV_imgA1C1_4[i][j])

# %%
S1A1_1204= list()
S1C2_104 = list()
for i in range(S1HSV_imgA1C2_4.shape[0]): 
     for j in range(S1HSV_imgA1C2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1204append(S1HSV_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_104.append(S1HSV_imgA1C2_4[i][j])

# %%
S1A1_1304= list()
S1C3_104 = list()
for i in range(S1HSV_imgA1C3_4.shape[0]): 
     for j in range(S1HSV_imgA1C3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1304.append(S1HSV_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_104.append(S1HSV_imgA1C3_4[i][j])

# %%
S1A1_1404= list()
S1C4_104 = list()
for i in range(S1HSV_imgA1C4_4.shape[0]): 
     for j in range(S1HSV_imgA1C4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1404.append(S1HSV_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_104.append(S1HSV_imgA1C4_4[i][j])

# %%
S1A1_1504= list()
S1D2_104 = list()
for i in range(S1HSV_imgA1D2_4.shape[0]): 
     for j in range(S1HSV_imgA1D2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1504.append(S1HSV_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_104.append(S1HSV_imgA1D2_4[i][j])

# %%
S1A1_1604= list()
S1D3_104 = list()
for i in range(S1HSV_imgA1D3_4.shape[0]): 
     for j in range(S1HSV_imgA1D3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1604append(S1HSV_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_104.append(S1HSV_imgA1D3_4[i][j])

# %%
S1A1_1704= list()
S1D4_104 = list()
for i in range(S1HSV_imgA1D4_4.shape[0]): 
     for j in range(S1HSV_imgA1D4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1704.append(S1HSV_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_104.append(S1HSV_imgA1D4_4[i][j])

# %% [markdown]
# ###Img 5

# %%
S1A1_105= list()
S1A1_205 = list()
for i in range(S1HSV_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_105.append(S1HSV_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_205.append(S1HSV_imgA1A1_5[i][j])

# %%
S1A1_305= list()
S1A2_105 = list()
for i in range(S1HSV_imgA1A2_5.shape[0]): 
     for j in range(S1HSV_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_305.append(S1HSV_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_105.append(S1HSV_imgA1A2_5[i][j])

# %%
S1A1_405= list()
S1A3_105 = list()
for i in range(S1HSV_imgA1A3_5.shape[0]): 
     for j in range(S1HSV_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_405.append(S1HSV_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_105.append(S1HSV_imgA1A3_5[i][j])

# %%
S1A1_505= list()
S1A3_5105 = list()
for i in range(S1HSV_imgA1A3_55.shape[0]): 
     for j in range(S1HSV_imgA1A3_55.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_505.append(S1HSV_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5105.append(S1HSV_imgA1A3_55[i][j])

# %%
S1A1_605= list()
S1A4_105 = list()
for i in range(S1HSV_imgA1A4_5.shape[0]): 
     for j in range(S1HSV_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_605.append(S1HSV_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_105.append(S1HSV_imgA1A4_5[i][j])

# %%
S1A1_705= list()
S1B1_105 = list()
for i in range(S1HSV_imgA1B1_5.shape[0]): 
     for j in range(S1HSV_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_705.append(S1HSV_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_105.append(S1HSV_imgA1B1_5[i][j])

# %%
S1A1_805= list()
S1B2_105 = list()
for i in range(S1HSV_imgA1B2_5.shape[0]): 
     for j in range(S1HSV_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_805.append(S1HSV_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_105.append(S1HSV_imgA1B2_5[i][j])

# %%
S1A1_905= list()
S1B3_105 = list()
for i in range(S1HSV_imgA1B3_5.shape[0]): 
     for j in range(S1HSV_imgA1B3_.5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_905.append(S1HSV_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_105.append(S1HSV_imgA1B3_5[i][j])

# %%
S1A1_1005= list()
S1B4_105 = list()
for i in range(S1HSV_imgA1B4_5.shape[0]): 
     for j in range(S1HSV_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1005.append(S1HSV_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_105.append(S1HSV_imgA1B4_5[i][j])

# %%
S1A1_1105= list()
S1C1_205 = list()
for i in range(S1HSV_imgA1C1_5.shape[0]): 
     for j in range(S1HSV_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1105.append(S1HSV_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_205.append(S1HSV_imgA1C1_5[i][j])

# %%
S1A1_1205= list()
S1C2_105 = list()
for i in range(S1HSV_imgA1C2_5.shape[0]): 
     for j in range(S1HSV_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1205.append(S1HSV_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_105.append(S1HSV_imgA1C2_5[i][j])

# %%
S1A1_1305= list()
S1C3_105 = list()
for i in range(S1HSV_imgA1C3_5.shape[0]): 
     for j in range(S1HSV_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1305.append(S1HSV_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_105.append(S1HSV_imgA1C3_5[i][j])

# %%
S1A1_1405= list()
S1C4_105 = list()
for i in range(S1HSV_imgA1C4_5.shape[0]): 
     for j in range(S1HSV_imgA1C4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1405.append(S1HSV_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_105.append(S1HSV_imgA1C4_5[i][j])

# %%
S1A1_1505= list()
S1D2_105 = list()
for i in range(S1HSV_imgA1D2_5.shape[0]): 
     for j in range(S1HSV_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1505.append(S1HSV_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_105.append(S1HSV_imgA1D2_5[i][j])

# %%
S1A1_1605= list()
S1D3_105 = list()
for i in range(S1HSV_imgA1D3_5.shape[0]): 
     for j in range(S1HSV_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1605.append(S1HSV_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_105.append(S1HSV_imgA1D3_5[i][j])

# %%
S1A1_1705= list()
S1D4_105 = list()
for i in range(S1HSV_imgA1D4_5.shape[0]): 
     for j in range(S1HSV_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1705.append(S1HSV_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_105.append(S1HSV_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 6

# %%
S1A1_106= list()
S1A1_206 = list()
for i in range(S1HSV_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_.6shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_106.append(S1HSV_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_206.append(S1HSV_imgA1A1_6[i][j])

# %%
S1A1_306= list()
S1A2_106 = list()
for i in range(S1HSV_imgA1A2_6.shape[0]): 
     for j in range(S1HSV_imgA1A2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_306.append(S1HSV_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_106.append(S1HSV_imgA1A2_6[i][j])

# %%
S1A1_406= list()
S1A3_106 = list()
for i in range(S1HSV_imgA1A3_6.shape[0]): 
     for j in range(S1HSV_imgA1A3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_406.append(S1HSV_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_106.append(S1HSV_imgA1A3_6[i][j])

# %%
S1A1_506= list()
S1A3_5106 = list()
for i in range(S1HSV_imgA1A3_56.shape[0]): 
     for j in range(S1HSV_imgA1A3_56.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_506.append(S1HSV_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5106.append(S1HSV_imgA1A3_56[i][j])

# %%
S1A1_606= list()
S1A4_106= list()
for i in range(S1HSV_imgA1A4_6.shape[0]): 
     for j in range(S1HSV_imgA1A4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_606.append(S1HSV_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_106.append(S1HSV_imgA1A4_6[i][j])

# %%
S1A1_706= list()
S1B1_106 = list()
for i in range(S1HSV_imgA1B1_6.shape[0]): 
     for j in range(S1HSV_imgA1B1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_706.append(S1HSV_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_106.append(S1HSV_imgA1B1_6[i][j])

# %%
S1A1_806= list()
S1B2_106 = list()
for i in range(S1HSV_imgA1B2_6.shape[0]): 
     for j in range(S1HSV_imgA1B2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_806.append(S1HSV_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_106.append(S1HSV_imgA1B2_6[i][j])

# %%
S1A1_906= list()
S1B3_106 = list()
for i in range(S1HSV_imgA1B3_6.shape[0]): 
     for j in range(S1HSV_imgA1B3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_90.append(S1HSV_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_10.append(S1HSV_imgA1B3_6[i][j])

# %%
S1A1_1006= list()
S1B4_106 = list()
for i in range(S1HSV_imgA1B4_6.shape[0]): 
     for j in range(S1HSV_imgA1B4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1006.append(S1HSV_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_106.append(S1HSV_imgA1B4_6[i][j])

# %%
S1A1_1106= list()
S1C1_206 = list()
for i in range(S1HSV_imgA1C1_6.shape[0]): 
     for j in range(S1HSV_imgA1C1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1106.append(S1HSV_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_206.append(S1HSV_imgA1C1_6[i][j])

# %%
S1A1_1206= list()
S1C2_106 = list()
for i in range(S1HSV_imgA1C2_.6shape[0]): 
     for j in range(S1HSV_imgA1C2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1206.append(S1HSV_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_106.append(S1HSV_imgA1C2_6[i][j])

# %%
S1A1_1306= list()
S1C3_106 = list()
for i in range(S1HSV_imgA1C3_6.shape[0]): 
     for j in range(S1HSV_imgA1C3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1306.append(S1HSV_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_106.append(S1HSV_imgA1C3_6[i][j])

# %%
S1A1_140= list()
S1C4_10 = list()
for i in range(S1HSV_imgA1C4_.shape[0]): 
     for j in range(S1HSV_imgA1C4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_140.append(S1HSV_imgA1C4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_10.append(S1HSV_imgA1C4_[i][j])

# %%
S1A1_1506= list()
S1D2_106 = list()
for i in range(S1HSV_imgA1D2_6.shape[0]): 
     for j in range(S1HSV_imgA1D2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1506.append(S1HSV_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_106.append(S1HSV_imgA1D2_6[i][j])

# %%
S1A1_1606= list()
S1D3_106 = list()
for i in range(S1HSV_imgA1D3_6.shape[0]): 
     for j in range(S1HSV_imgA1D3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1606.append(S1HSV_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_106.append(S1HSV_imgA1D3_6[i][j])

# %%
S1A1_1706= list()
S1D4_106 = list()
for i in range(S1HSV_imgA1D4_6.shape[0]): 
     for j in range(S1HSV_imgA1D4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1706.append(S1HSV_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_106.append(S1HSV_imgA1D4_6[i][j])

# %% [markdown]
# ###Img 7

# %%
S1A1_107= list()
S1A1_2067 = list()
for i in range(S1HSV_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_107.append(S1HSV_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_207.append(S1HSV_imgA1A1_7[i][j])

# %%
S1A1_307= list()
S1A2_107 = list()
for i in range(S1HSV_imgA1A2_7.shape[0]): 
     for j in range(S1HSV_imgA1A2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_307.append(S1HSV_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_107.append(S1HSV_imgA1A2_7[i][j])

# %%
S1A1_407= list()
S1A3_107 = list()
for i in range(S1HSV_imgA1A3_7.shape[0]): 
     for j in range(S1HSV_imgA1A3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_407.append(S1HSV_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_107.append(S1HSV_imgA1A3_7[i][j])

# %%
S1A1_507= list()
S1A3_5107 = list()
for i in range(S1HSV_imgA1A3_57.shape[0]): 
     for j in range(S1HSV_imgA1A3_57.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_507.append(S1HSV_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5107.append(S1HSV_imgA1A3_57[i][j])

# %%
S1A1_607= list()
S1A4_107 = list()
for i in range(S1HSV_imgA1A4_7.shape[0]): 
     for j in range(S1HSV_imgA1A4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_607.append(S1HSV_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_107.append(S1HSV_imgA1A4_7[i][j])

# %%
S1A1_707= list()
S1B1_107 = list()
for i in range(S1HSV_imgA1B1_7.shape[0]): 
     for j in range(S1HSV_imgA1B1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_707.append(S1HSV_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_107.append(S1HSV_imgA1B1_7i][j])

# %%
S1A1_807= list()
S1B2_107 = list()
for i in range(S1HSV_imgA1B2_7.shape[0]): 
     for j in range(S1HSV_imgA1B2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_807.append(S1HSV_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_107.append(S1HSV_imgA1B2_7[i][j])

# %%
S1A1_907= list()
S1B3_107 = list()
for i in range(S1HSV_imgA1B3_7.shape[0]): 
     for j in range(S1HSV_imgA1B3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_907.append(S1HSV_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_107.append(S1HSV_imgA1B3_7[i][j])

# %%
S1A1_1007= list()
S1B4_107 = list()
for i in range(S1HSV_imgA1B4_7.shape[0]): 
     for j in range(S1HSV_imgA1B4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1007.append(S1HSV_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_107.append(S1HSV_imgA1B4_7[i][j])

# %%
S1A1_1107= list()
S1C1_207 = list()
for i in range(S1HSV_imgA1C1_7.shape[0]): 
     for j in range(S1HSV_imgA1C1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1107.append(S1HSV_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_207append(S1HSV_imgA1C1_7[i][j])

# %%
S1A1_1207= list()
S1C2_107 = list()
for i in range(S1HSV_imgA1C2_7.shape[0]): 
     for j in range(S1HSV_imgA1C2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1207.append(S1HSV_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_107.append(S1HSV_imgA1C2_7[i][j])

# %%
S1A1_1307= list()
S1C3_107 = list()
for i in range(S1HSV_imgA1C3_7.shape[0]): 
     for j in range(S1HSV_imgA1C3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1307.append(S1HSV_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_107.append(S1HSV_imgA1C3_[7i][j])

# %%
S1A1_1407= list()
S1C4_107 = list()
for i in range(S1HSV_imgA1C4_7.shape[0]): 
     for j in range(S1HSV_imgA1C4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1407.append(S1HSV_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_107.append(S1HSV_imgA1C4_7[i][j])

# %%
S1A1_1507= list()
S1D2_107 = list()
for i in range(S1HSV_imgA1D2_7.shape[0]): 
     for j in range(S1HSV_imgA1D2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1507.append(S1HSV_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_107.append(S1HSV_imgA1D2_7[i][j])

# %%
S1A1_1607= list()
S1D3_107 = list()
for i in range(S1HSV_imgA1D3_7.shape[0]): 
     for j in range(S1HSV_imgA1D3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1607.append(S1HSV_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_107.append(S1HSV_imgA1D3_7[i][j])

# %%
S1A1_1707= list()
S1D4_107 = list()
for i in range(S1HSV_imgA1D4_7.shape[0]): 
     for j in range(S1HSV_imgA1D4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1707.append(S1HSV_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_107.append(S1HSV_imgA1D4_7[i][j])

# %% [markdown]
# ###Img 8

# %%
S1A1_108= list()
S1A1_208 = list()
for i in range(S1HSV_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_108.append(S1HSV_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_208.append(S1HSV_imgA1A1_8[i][j])

# %%
S1A1_308= list()
S1A2_108 = list()
for i in range(S1HSV_imgA1A2_8shape[0]): 
     for j in range(S1HSV_imgA1A2_8shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_308.append(S1HSV_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_108.append(S1HSV_imgA1A2_8[i][j])

# %%
S1A1_408= list()
S1A3_108 = list()
for i in range(S1HSV_imgA1A3_8.shape[0]): 
     for j in range(S1HSV_imgA1A3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_408.append(S1HSV_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_108.append(S1HSV_imgA1A3_8[i][j])

# %%
S1A1_508= list()
S1A3_5108 = list()
for i in range(S1HSV_imgA1A3_58.shape[0]): 
     for j in range(S1HSV_imgA1A3_58.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_508.append(S1HSV_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5108.append(S1HSV_imgA1A3_58[i][j])

# %%
S1A1_608= list()
S1A4_108 = list()
for i in range(S1HSV_imgA1A4_8.shape[0]): 
     for j in range(S1HSV_imgA1A4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_608.append(S1HSV_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_108append(S1HSV_imgA1A4_8[i][j])

# %%
S1A1_708= list()
S1B1_108 = list()
for i in range(S1HSV_imgA1B1_8.shape[0]): 
     for j in range(S1HSV_imgA1B1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_708.append(S1HSV_imgA1B1_8i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_108.append(S1HSV_imgA1B1_8[i][j])

# %%
S1A1_808= list()
S1B2_108 = list()
for i in range(S1HSV_imgA1B2_8.shape[0]): 
     for j in range(S1HSV_imgA1B2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_808.append(S1HSV_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_108.append(S1HSV_imgA1B2_8[i][j])

# %%
S1A1_908= list()
S1B3_108 = list()
for i in range(S1HSV_imgA1B3_8.shape[0]): 
     for j in range(S1HSV_imgA1B3_.8shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_908.append(S1HSV_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_108.append(S1HSV_imgA1B3_8[i][j])

# %%
S1A1_1008= list()
S1B4_108 = list()
for i in range(S1HSV_imgA1B4_8.shape[0]): 
     for j in range(S1HSV_imgA1B4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_100.append(S1HSV_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_10.append(S1HSV_imgA1B4_8[i][j])

# %%
S1A1_1108= list()
S1C1_208 = list()
for i in range(S1HSV_imgA1C1_8.shape[0]): 
     for j in range(S1HSV_imgA1C1_.8shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1108.append(S1HSV_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_208.append(S1HSV_imgA1C1_8[i][j])

# %%
S1A1_1208= list()
S1C2_108 = list()
for i in range(S1HSV_imgA1C2_8.shape[0]): 
     for j in range(S1HSV_imgA1C2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1208.append(S1HSV_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_108.append(S1HSV_imgA1C2_8[i][j])

# %%
S1A1_1308= list()
S1C3_108 = list()
for i in range(S1HSV_imgA1C3_8.shape[0]): 
     for j in range(S1HSV_imgA1C3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1308.append(S1HSV_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_108.append(S1HSV_imgA1C3_8[i][j])

# %%
S1A1_1408= list()
S1C4_108 = list()
for i in range(S1HSV_imgA1C4_8.shape[0]): 
     for j in range(S1HSV_imgA1C4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1408.append(S1HSV_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_108append(S1HSV_imgA1C4_8[i][j])

# %%
S1A1_1508= list()
S1D2_108 = list()
for i in range(S1HSV_imgA1D2_8.shape[0]): 
     for j in range(S1HSV_imgA1D2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1508.append(S1HSV_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_108.append(S1HSV_imgA1D2_8[i][j])

# %%
S1A1_160= list()
S1D3_10 = list()
for i in range(S1HSV_imgA1D3_.shape[0]): 
     for j in range(S1HSV_imgA1D3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_160.append(S1HSV_imgA1D3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_10.append(S1HSV_imgA1D3_[i][j])

# %%
S1A1_1708= list()
S1D4_108 = list()
for i in range(S1HSV_imgA1D4_.8shape[0]): 
     for j in range(S1HSV_imgA1D4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1708.append(S1HSV_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_108.append(S1HSV_imgA1D4_8[i][j])

# %% [markdown]
# ###Img 9

# %%
S1A1_109= list()
S1A1_209 = list()
for i in range(S1HSV_imgA1A1_9shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_109.append(S1HSV_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_209.append(S1HSV_imgA1A1_9[i][j])

# %%
S1A1_309= list()
S1A2_109 = list()
for i in range(S1HSV_imgA1A2_.9shape[0]): 
     for j in range(S1HSV_imgA1A2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_309.append(S1HSV_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_109append(S1HSV_imgA1A2_[9i][j])

# %%
S1A1_409= list()
S1A3_109 = list()
for i in range(S1HSV_imgA1A3_9.shape[0]): 
     for j in range(S1HSV_imgA1A3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_409.append(S1HSV_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_109.append(S1HSV_imgA1A3_9[i][j])

# %%
S1A1_509= list()
S1A3_5109 = list()
for i in range(S1HSV_imgA1A3_59.shape[0]): 
     for j in range(S1HSV_imgA1A3_59.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_509.append(S1HSV_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_5109.append(S1HSV_imgA1A3_59[i][j])

# %%
S1A1_609= list()
S1A4_109 = list()
for i in range(S1HSV_imgA1A4_9.shape[0]): 
     for j in range(S1HSV_imgA1A4_.9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_609.append(S1HSV_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_109.append(S1HSV_imgA1A4_9[i][j])

# %%
S1A1_709= list()
S1B1_109= list()
for i in range(S1HSV_imgA1B1_9.shape[0]): 
     for j in range(S1HSV_imgA1B1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_709.append(S1HSV_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_109.append(S1HSV_imgA1B19[i][j])

# %%
S1A1_809= list()
S1B2_109 = list()
for i in range(S1HSV_imgA1B2_9.shape[0]): 
     for j in range(S1HSV_imgA1B2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_809.append(S1HSV_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_109.append(S1HSV_imgA1B2_9[i][j])

# %%
S1A1_909= list()
S1B3_109 = list()
for i in range(S1HSV_imgA1B3_.shape[0]): 
     for j in range(S1HSV_imgA1B3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_90.append(S1HSV_imgA1B3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_10.append(S1HSV_imgA1B3_[i][j])

# %%
S1A1_1009= list()
S1B4_109 = list()
for i in range(S1HSV_imgA1B4_9.shape[0]): 
     for j in range(S1HSV_imgA1B4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1009.append(S1HSV_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_109.append(S1HSV_imgA1B4_9[i][j])

# %%
S1A1_1109= list()
S1C1_209 = list()
for i in range(S1HSV_imgA1C1_9.shape[0]): 
     for j in range(S1HSV_imgA1C1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1109.append(S1HSV_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_209.append(S1HSV_imgA1C1_9[i][j])

# %%
S1A1_1209= list()
S1C2_109 = list()
for i in range(S1HSV_imgA1C2_9.shape[0]): 
     for j in range(S1HSV_imgA1C2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1209.append(S1HSV_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_109.append(S1HSV_imgA1C2_9[i][j])

# %%
S1A1_1309= list()
S1C3_109 = list()
for i in range(S1HSV_imgA1C3_9.shape[0]): 
     for j in range(S1HSV_imgA1C3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1309.append(S1HSV_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_109.append(S1HSV_imgA1C3_9[i][j])

# %%
S1A1_1409= list()
S1C4_109 = list()
for i in range(S1HSV_imgA1C4_9.shape[0]): 
     for j in range(S1HSV_imgA1C4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1409.append(S1HSV_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_109.append(S1HSV_imgA1C4_9[i][j])

# %%
S1A1_1509= list()
S1D2_109 = list()
for i in range(S1HSV_imgA1D2_9.shape[0]): 
     for j in range(S1HSV_imgA1D2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1509.append(S1HSV_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_109.append(S1HSV_imgA1D2_9[i][j])

# %%
S1A1_1609= list()
S1D3_109 = list()
for i in range(S1HSV_imgA1D3_9.shape[0]): 
     for j in range(S1HSV_imgA1D3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1609.append(S1HSV_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_109.append(S1HSV_imgA1D3_9[i][j])

# %%
S1A1_1709= list()
S1D4_109 = list()
for i in range(S1HSV_imgA1D4_9.shape[0]): 
     for j in range(S1HSV_imgA1D4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1709.append(S1HSV_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_109.append(S1HSV_imgA1D4_9[i][j])

# %% [markdown]
# ###Img 10

# %%
S1A1_110= list()
S1A1_210 = list()
for i in range(S1HSV_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_110.append(S1HSV_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A1_2010.append(S1HSV_imgA1A1_10[i][j])

# %%
S1A1_310= list()
S1A2_110 = list()
for i in range(S1HSV_imgA1A2_10.shape[0]): 
     for j in range(S1HSV_imgA1A2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_310.append(S1HSV_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A2_110.append(S1HSV_imgA1A2_10[i][j])

# %%
S1A1_410= list()
S1A3_110 = list()
for i in range(S1HSV_imgA1A3_10.shape[0]): 
     for j in range(S1HSV_imgA1A3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_410.append(S1HSV_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_101.append(S1HSV_imgA1A3_10[i][j])

# %%
S1A1_510= list()
S1A3_510 = list()
for i in range(S1HSV_imgA1A3_510.shape[0]): 
     for j in range(S1HSV_imgA1A3_510.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_510.append(S1HSV_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A3_510.append(S1HSV_imgA1A3_510[i][j])

# %%
S1A1_610= list()
S1A4_110 = list()
for i in range(S1HSV_imgA1A4_10.shape[0]): 
     for j in range(S1HSV_imgA1A4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_610.append(S1HSV_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1A4_110.append(S1HSV_imgA1A4_10[i][j])

# %%
S1A1_710= list()
S1B1_110 = list()
for i in range(S1HSV_imgA1B1_10.shape[0]): 
     for j in range(S1HSV_imgA1B1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_710.append(S1HSV_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B1_110.append(S1HSV_imgA1B1_10[i][j])

# %%
S1A1_810= list()
S1B2_110 = list()
for i in range(S1HSV_imgA1B2_10.shape[0]): 
     for j in range(S1HSV_imgA1B2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_810.append(S1HSV_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B2_110.append(S1HSV_imgA1B2_10[i][j])

# %%
S1A1_910= list()
S1B3_110 = list()
for i in range(S1HSV_imgA1B3_10.shape[0]): 
     for j in range(S1HSV_imgA1B3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_910.append(S1HSV_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B3_110.append(S1HSV_imgA1B3_10[i][j])

# %%
S1A1_1010= list()
S1B4_110 = list()
for i in range(S1HSV_imgA1B4_10.shape[0]): 
     for j in range(S1HSV_imgA1B4_.10shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1010.append(S1HSV_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1B4_110.append(S1HSV_imgA1B4_10[i][j])

# %%
S1A1_1110= list()
S1C1_210 = list()
for i in range(S1HSV_imgA1C1_10.shape[0]): 
     for j in range(S1HSV_imgA1C1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1110.append(S1HSV_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C1_210.append(S1HSV_imgA1C1_10[i][j])

# %%
S1A1_1210= list()
S1C2_110 = list()
for i in range(S1HSV_imgA1C2_10.shape[0]): 
     for j in range(S1HSV_imgA1C2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1210.append(S1HSV_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C2_10.append(S1HSV_imgA1C2_10[i][j])

# %%
S1A1_1310= list()
S1C3_110 = list()
for i in range(S1HSV_imgA1C3_10shape[0]): 
     for j in range(S1HSV_imgA1C3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1310.append(S1HSV_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C3_110.append(S1HSV_imgA1C3_10[i][j])

# %%
S1A1_1410= list()
S1C4_110 = list()
for i in range(S1HSV_imgA1C4_10.shape[0]): 
     for j in range(S1HSV_imgA1C4_.10shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1410.append(S1HSV_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1C4_110.append(S1HSV_imgA1C4_10[i][j])

# %%
S1A1_1510= list()
S1D2_110 = list()
for i in range(S1HSV_imgA1D2_10.shape[0]): 
     for j in range(S1HSV_imgA1D2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1510.append(S1HSV_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D2_110.append(S1HSV_imgA1D2_10[i][j])

# %%
S1A1_1610= list()
S1D3_110 = list()
for i in range(S1HSV_imgA1D3_10.shape[0]): 
     for j in range(S1HSV_imgA1D3_.10shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_160.append(S1HSV_imgA1D310_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D3_110.append(S1HSV_imgA1D3_10[i][j])

# %%
S1A1_1710= list()
S1D4_110 = list()
for i in range(S1HSV_imgA1D4_10.shape[0]): 
     for j in range(S1HSV_imgA1D4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S1A1_1710.append(S1HSV_imgA1D4_10i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S1D4_110.append(S1HSV_imgA1D4_10[i][j])

# %% [markdown]
# ##Set4

# %% [markdown]
# ###RGB

# %%
S4A1_1= list()
S4A1_2 = list()
for i in range(S4RGB_imgA1A1_1.shape[0]): 
     for j in range(S4RGB_imgA1A1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1.append(S4RGB_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_2.append(S4RGB_imgA1A1_1[i][j])

# %%
S4A1_3= list()
S4A2_1 = list()
for i in range(S4RGB_imgA1A2_1.shape[0]): 
     for j in range(S4RGB_imgA1A2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_3.append(S4RGB_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_1.append(S4RGB_imgA1A2_1[i][j])

# %%
S4A1_4= list()
S4A3_1 = list()
for i in range(S4RGB_imgA1A3_1.shape[0]): 
     for j in range(S4RGB_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_4.append(S4RGB_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_1.append(S4RGB_imgA1A3_1[i][j])

# %%
S4A1_5= list()
S4A3_51 = list()
for i in range(S4RGB_imgA1A3_51.shape[0]): 
     for j in range(S4RGB_imgA1A3_51.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_5.append(S4RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_51.append(S4RGB_imgA1A3_51[i][j])

# %%
S4A1_6= list()
S4A4_1 = list()
for i in range(S4RGB_imgA1A4_1.shape[0]): 
     for j in range(S4RGB_imgA1A4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_6.append(S4RGB_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_1.append(S4RGB_imgA1A4_1[i][j])

# %%
S4A1_7= list()
S4B1_1 = list()
for i in range(S4RGB_imgA1B1_1.shape[0]): 
     for j in range(S4RGB_imgA1B1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_7.append(S4RGB_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_1.append(S4RGB_imgA1B1_1[i][j])

# %%
S4A1_8= list()
S4B2_1 = list()
for i in range(S4RGB_imgA1B2_1.shape[0]): 
     for j in range(S4RGB_imgA1B2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_8.append(S4RGB_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_1.append(S4RGB_imgA1B2_1[i][j])

# %%
S4A1_9= list()
S4B3_1 = list()
for i in range(S4RGB_imgA1B3_1.shape[0]): 
     for j in range(S4RGB_imgA1B3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_9.append(S4RGB_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_1.append(S4RGB_imgA1B3_1[i][j])

# %%
S4A1_10= list()
S4B4_1 = list()
for i in range(S4RGB_imgA1B4_1.shape[0]): 
     for j in range(S4RGB_imgA1B4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_10.append(S4RGB_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_1.append(S4RGB_imgA1B4_1[i][j])

# %%
S4A1_11= list()
S4C1_1 = list()
for i in range(S4RGB_imgA1C1_1.shape[0]): 
     for j in range(S4RGB_imgA1C1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_11.append(S4RGB_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_1.append(S4RGB_imgA1C1_1[i][j])

# %%
S4A1_12= list()
S4C2_1 = list()
for i in range(S4RGB_imgA1C2_1.shape[0]): 
     for j in range(S4RGB_imgA1C2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_12.append(S4RGB_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_1.append(S4RGB_imgA1C2_1[i][j])

# %%
S4A1_13= list()
S4C3_1 = list()
for i in range(S4RGB_imgA1C3_1.shape[0]): 
     for j in range(S4RGB_imgA1C3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_13.append(S4RGB_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_1.append(S4RGB_imgA1C3_1[i][j])

# %%
S4A1_14= list()
S4C4_1 = list()
for i in range(S4RGB_imgA1C4_1.shape[0]): 
     for j in range(S4RGB_imgA1C4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_14.append(S4RGB_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_1.append(S4RGB_imgA1C4_1[i][j])

# %%
S4A1_15= list()
S4D2_1 = list()
for i in range(S4RGB_imgA1C2_1.shape[0]): 
     for j in range(S4RGB_imgA1D2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_15.append(S4RGB_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_1.append(S4RGB_imgA1D2_1[i][j])

# %%
S4A1_16= list()
S4D3_1 = list()
for i in range(S4RGB_imgA1D3_1.shape[0]): 
     for j in range(S4RGB_imgA1D3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_16.append(S4RGB_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_1.append(S4RGB_imgA1D3_1[i][j])

# %%
S4A1_17= list()
S4D4_1 = list()
for i in range(S4RGB_imgA1D4_1.shape[0]): 
     for j in range(S4RGB_imgA1D4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_17.append(S4RGB_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_1.append(S4RGB_imgA1D4_1[i][j])

# %% [markdown]
# ###Img 2

# %%
S4A1_102= list()
S4A1_202= list()
for i in range(S4RGB_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_102.append(S4RGB_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_202.append(S4RGB_imgA1A1_2[i][j])

# %%
S4A1_302= list()
S4A2_102 = list()
for i in range(S4RGB_imgA1A2_2.shape[0]): 
     for j in range(S4RGB_imgA1A2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_302.append(S4RGB_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_102.append(S4RGB_imgA1A2_2[i][j])

# %%
S4A1_402= list()
S4A3_102 = list()
for i in range(S4RGB_imgA1A3_2.shape[0]): 
     for j in range(S4RGB_imgA1A3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_402.append(S4RGB_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_102.append(S4RGB_imgA1A3_2[i][j])

# %%
S4A1_502= list()
S4A3_5102 = list()
for i in range(S4RGB_imgA1A3_52.shape[0]): 
     for j in range(S4RGB_imgA1A3_52.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(S4RGB_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_5102.append(S4RGB_imgA1A3_52[i][j])

# %%
S4A1_602= list()
S4A4_102 = list()
for i in range(S4RGB_imgA1A4_2.shape[0]): 
     for j in range(S4RGB_imgA1A4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_602.append(S4RGB_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_102.append(S4RGB_imgA1A4_2[i][j])

# %%
S4A1_702= list()
S4B1_102 = list()
for i in range(S4RGB_imgA1B1_2.shape[0]): 
     for j in range(S4RGB_imgA1B1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_702.append(S4RGB_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_102.append(S4RGB_imgA1B1_2[i][j])

# %%
S4A1_80= list()
S4B2_10 = list()
for i in range(S4RGB_imgA1B2_.shape[0]): 
     for j in range(S4RGB_imgA1B2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_80.append(S4RGB_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_10.append(S4RGB_imgA1B2_[i][j])

# %%
S4A1_902= list()
S4B3_102 = list()
for i in range(S4RGB_imgA1B3_2.shape[0]): 
     for j in range(S4RGB_imgA1B3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_902.append(S4RGB_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_102.append(S4RGB_imgA1B3_2[i][j])

# %%
S4A1_1002= list()
S4B4_102 = list()
for i in range(S4RGB_imgA1B4_2.shape[0]): 
     for j in range(S4RGB_imgA1B4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1002.append(S4RGB_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_102.append(S4RGB_imgA1B4_2[i][j])

# %%
S4A1_1102= list()
S4C1_202 = list()
for i in range(S4RGB_imgA1C1_.2shape[0]): 
     for j in range(S4RGB_imgA1C1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1102.append(S4RGB_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_202.append(S4RGB_imgA1C1_2[i][j])

# %%
S4A1_1202= list()
S4C2_102 = list()
for i in range(S4RGB_imgA1C2_2.shape[0]): 
     for j in range(S4RGB_imgA1C2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1202.append(S4RGB_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_102.append(S4RGB_imgA1C2_2[i][j])

# %%
S4A1_1302= list()
S4C3_102 = list()
for i in range(S4RGB_imgA1C3_2.shape[0]): 
     for j in range(S4RGB_imgA1C3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1302.append(S4RGB_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_102.append(S4RGB_imgA1C3_2[i][j])

# %%
S4A1_1402= list()
S4C4_102 = list()
for i in range(S4RGB_imgA1C4_2.shape[0]): 
     for j in range(S4RGB_imgA1C4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1402.append(S4RGB_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_102.append(S4RGB_imgA1C4_2[i][j])

# %%
SA41_1502= list()
S4D2_102 = list()
for i in range(S4RGB_imgA1D2_2.shape[0]): 
     for j in range(S4RGB_imgA1D2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1502.append(S4RGB_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_102.append(S4RGB_imgA1D2_2[i][j])

# %%
S4A1_1602= list()
S4D3_102 = list()
for i in range(S4RGB_imgA1D3_2.shape[0]): 
     for j in range(S4RGB_imgA1D3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1602.append(S4RGB_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_102.append(S4RGB_imgA1D3_2[i][j])

# %%
S4A1_1702= list()
S4D4_102 = list()
for i in range(S4RGB_imgA1D4_2.shape[0]): 
     for j in range(S4RGB_imgA1D4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1702.append(S4RGB_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_102.append(S4RGB_imgA1D4_2[i][j])

# %% [markdown]
# ###Img 3

# %%
S4A1_103= list()
S4A1_203= list()
for i in range(S4RGB_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_103.append(S4RGB_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_203.append(S4RGB_imgA1A1_3[i][j])

# %%
S4A1_303= list()
S4A2_103 = list()
for i in range(SRGB_imgA1A2_3.shape[0]): 
     for j in range(SRGB_imgA1A2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_303.append(S4RGB_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_103.append(S4RGB_imgA1A2_3[i][j])

# %%
S4A1_403= list()
S4A3_103 = list()
for i in range(S4RGB_imgA1A3_3.shape[0]): 
     for j in range(S4RGB_imgA1A3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_403.append(S4RGB_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S43_103.append(S4RGB_imgA1A3_3[i][j])

# %%
S4A1_503= list()
S4A3_5103= list()
for i in range(S4RGB_imgA1A3_53.shape[0]): 
     for j in range(S4RGB_imgA1A3_53.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_503.append(S4RGB_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_5103.append(S4RGB_imgA1A3_53[i][j])

# %%
S4A1_603= list()
S4A4_103 = list()
for i in range(SRGB_imgA1A4_.3shape[0]): 
     for j in range(SRGB_imgA1A4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_603.append(S4RGB_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_103.append(S4RGB_imgA1A4_3[i][j])

# %%
S4A1_703= list()
S4B1_103 = list()
for i in range(4RGB_imgA1B1_3.shape[0]): 
     for j in range(S4RGB_imgA1B1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_703.append(S4RGB_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_103.append(S4RGB_imgA1B1_3[i][j])

# %%
S4A1_803= list()
S4B2_103 = list()
for i in range(S4RGB_imgA1B2_3.shape[0]): 
     for j in range(S4RGB_imgA1B2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_803.append(S4RGB_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_103.append(S4RGB_imgA1B2_3[i][j])

# %%
S4A1_903= list()
S4B3_103 = list()
for i in range(S4RGB_imgA1B3_3.shape[0]): 
     for j in range(S4RGB_imgA1B3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_903.append(S4RGB_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_103.append(S4RGB_imgA1B3_3[i][j])

# %%
S4A1_100= list()
S4B4_10 = list()
for i in range(S4RGB_imgA1B4_.shape[0]): 
     for j in range(S4RGB_imgA1B4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_100.append(S4RGB_imgA1B4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_10.append(S4GB_imgA1B4_[i][j])

# %%
S4A1_1103= list()
S4C1_203 = list()
for i in range(S4RGB_imgA1C1_3.shape[0]): 
     for j in range(S4RGB_imgA1C1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1103.append(S4RGB_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_203.append(S4RGB_imgA1C1_3[i][j])

# %%
S4A1_1203= list()
S4C2_103 = list()
for i in range(S1RGB_imgA1C2_3.shape[0]): 
     for j in range(S1RGB_imgA1C2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1203.append(S4RGB_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_103.append(S4RGB_imgA1C2_3[i][j])

# %%
S4A1_1303= list()
S4C3_103 = list()
for i in range(S4RGB_imgA1C3_3.shape[0]): 
     for j in range(S4RGB_imgA1C3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_130.append(S4RGB_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_10.append(S4RGB_imgA1C3_3[i][j])

# %%
S4A1_140= list()
S4C4_10 = list()
for i in range(SRGB_imgA1C4_.shape[0]): 
     for j in range(SRGB_imgA1C4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_140.append(S4RGB_imgA1C4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_10.append(S4RGB_imgA1C4_[i][j])

# %%
S4A1_150= list()
S4D2_10 = list()
for i in range(S4RGB_imgA1D2_.shape[0]): 
     for j in range(S4RGB_imgA1D2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_150.append(S4RGB_imgA1D2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_10.append(S4RGB_imgA1D2_[i][j])

# %%
S4A1_1603= list()
S4D3_103 = list()
for i in range(S4RGB_imgA1D3_3.shape[0]): 
     for j in range(S4RGB_imgA1D3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1603.append(S4RGB_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_103.append(S4RGB_imgA1D3_3[i][j])

# %%
S4A1_1703= list()
S4D4_103= list()
for i in range(S4RGB_imgA1D4_3.shape[0]): 
     for j in range(S4RGB_imgA1D4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA41_1703.append(S4RGB_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_103.append(S4RGB_imgA1D4_3[i][j])

# %% [markdown]
# ###Img 4

# %%
S4A1_104= list()
S4A1_204= list()
for i in range(S4RGB_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_104.append(S4RGB_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_204.append(S4RGB_imgA1A1_4[i][j])

# %%
S4A1_304= list()
S4A2_104= list()
for i in range(S4RGB_imgA1A2_4.shape[0]): 
     for j in range(S4RGB_imgA1A2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_304.append(S4RGB_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_104.append(S4RGB_imgA1A2_4[i][j])

# %%
S4A1_404= list()
S4A3_104 = list()
for i in range(S4RGB_imgA1A3_4.shape[0]): 
     for j in range(S4RGB_imgA1A3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_404.append(S4RGB_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_104.append(S4RGB_imgA1A3_4[i][j])

# %%
S4A1_504= list()
S4A3_5104 = list()
for i in range(S4RGB_imgA1A3_54.shape[0]): 
     for j in range(S4RGB_imgA1A3_54.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_504.append(S4RGB_imgA1A3_514[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_5104.append(S4RGB_imgA1A3_54[i][j])

# %%
S4A1_604= list()
S4A4_104 = list()
for i in range(S4RGB_imgA1A4_4.shape[0]): 
     for j in range(S4RGB_imgA1A4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_604.append(S4RGB_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_104.append(S4RGB_imgA1A4_4[i][j])

# %%
S4A1_704= list()
S4B1_104 = list()
for i in range(S4RGB_imgA1B1_4.shape[0]): 
     for j in range(S4RGB_imgA1B1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_704.append(S4RGB_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_104.append(S4RGB_imgA1B1_4[i][j])

# %%
S4A1_804= list()
S4B2_104 = list()
for i in range(S4RGB_imgA1B2_4.shape[0]): 
     for j in range(S4RGB_imgA1B2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_804.append(S4RGB_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_104.append(S4RGB_imgA1B2_4[i][j])

# %%
S4A1_90= list()
S4B3_10 = list()
for i in range(SR4GB_imgA1B3_.shape[0]): 
     for j in range(S4RGB_imgA1B3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_90.append(SRGB_imgA1B3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_10.append(SRGB_imgA1B3_[i][j])

# %%
S4A1_1004= list()
S4B4_104 = list()
for i in range(S4RGB_imgA1B4_4.shape[0]): 
     for j in range(S4RGB_imgA1B4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1004.append(S4RGB_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_104.append(S4RGB_imgA1B4_4[i][j])

# %%
S4A1_1104= list()
S4C1_204 = list()
for i in range(S4RGB_imgA1C1_4.shape[0]): 
     for j in range(S4RGB_imgA1C1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1104.append(S4RGB_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_204.append(S4RGB_imgA1C1_4[i][j])

# %%
S4A1_1204= list()
S4C2_104= list()
for i in range(S4RGB_imgA1C2_4.shape[0]): 
     for j in range(S4RGB_imgA1C2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1204.append(S4RGB_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_104.append(S4RGB_imgA1C2_4[i][j])

# %%
S4A1_1304= list()
S4C3_104 = list()
for i in range(S4RGB_imgA1C3_4.shape[0]): 
     for j in range(S4RGB_imgA1C3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1304.append(S4RGB_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_104.append(S4RGB_imgA1C3_4[i][j])

# %%
S4A1_1404= list()
S4C4_104 = list()
for i in range(S4RGB_imgA1C4_4.shape[0]): 
     for j in range(S4RGB_imgA1C4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1404.append(S4RGB_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_104.append(S4RGB_imgA1C4_4[i][j])

# %%
S4A1_1504= list()
S4D2_104 = list()
for i in range(S4RGB_imgA1D2_4.shape[0]): 
     for j in range(S4RGB_imgA1D2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1504.append(S4RGB_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_104.append(S4RGB_imgA1D2_4[i][j])

# %%
S4A1_1604= list()
S4D3_104 = list()
for i in range(S4RGB_imgA1D3_4.shape[0]): 
     for j in range(S4RGB_imgA1D3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1604.append(S4RGB_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_104.append(S4RGB_imgA1D3_4[i][j])

# %%
S4A1_1704= list()
S4D4_104 = list()
for i in range(S4RGB_imgA1D4_4.shape[0]): 
     for j in range(S4RGB_imgA1D4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1704.append(S4RGB_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_104.append(S4RGB_imgA1D4_4[i][j])

# %% [markdown]
# ###Img 5

# %%
S4A1_105= list()
S4A1_205= list()
for i in range(S4RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_105.append(S4RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_205.append(S4RGB_imgA1A1_5[i][j])

# %%
S4A1_305= list()
S4A2_105 = list()
for i in range(S4RGB_imgA1A2_5.shape[0]): 
     for j in range(S4RGB_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_305.append(S4RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_105.append(S4RGB_imgA1A2_5[i][j])

# %%
S4A1_405= list()
S4A3_105= list()
for i in range(S4RGB_imgA1A3_5.shape[0]): 
     for j in range(S4RGB_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA41_405.append(S4RGB_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_105.append(45RGB_imgA1A3_5[i][j])

# %%
S4A1_505= list()
S4A3_5105 = list()
for i in range(S4RGB_5imgA1A3_5.shape[0]): 
     for j in range(S4RGB_5imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_505.append(S4RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_5105.append(S4RGB_imgA1A3_55[i][j])

# %%
S4A1_605= list()
S4A4_105 = list()
for i in range(S4RGB_imgA1A4_5.shape[0]): 
     for j in range(S4RGB_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_605.append(S4RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_105.append(S4RGB_imgA1A4_5[i][j])

# %%
S4A1_705= list()
S4B1_105 = list()
for i in range(S4RGB_imgA1B1_5.shape[0]): 
     for j in range(S4RGB_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_705.append(S4RGB_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_105.append(S4RGB_imgA1B1_5[i][j])

# %%
S4A1_805= list()
S4B2_105 = list()
for i in range(S4RGB_imgA1B2_5.shape[0]): 
     for j in range(S4RGB_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_805.append(S4RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_105.append(S4RGB_imgA1B2_5[i][j])

# %%
S4A1_905= list()
S4B3_105 = list()
for i in range(S4RGB_imgA1B3_5.shape[0]): 
     for j in range(S4RGB_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_905.append(S4RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_105.append(S4RGB_imgA1B3_5[i][j])

# %%
S4A1_1005= list()
S4B4_105 = list()
for i in range(S4RGB_imgA1B4_5.shape[0]): 
     for j in range(S4RGB_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1005.append(S4RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_105.append(S4RGB_imgA1B4_5[i][j])

# %%
S4A1_1105= list()
S4C1_205 = list()
for i in range(S4RGB_imgA1C1_5.shape[0]): 
     for j in range(S4RGB_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1105.append(S4RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_205.append(S4RGB_imgA1C1_5[i][j])

# %%
S4A1_1205= list()
S4C2_105 = list()
for i in range(S4RGB_imgA1C2_5.shape[0]): 
     for j in range(S4RGB_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1205.append(S4RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_105.append(S4RGB_imgA1C2_5[i][j])

# %%
S4A1_1305= list()
S4C3_105 = list()
for i in range(S4RGB_imgA1C3_5.shape[0]): 
     for j in range(S4RGB_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1305.append(S4RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_105.append(S4RGB_imgA1C3_5[i][j])

# %%
S4A1_1405= list()
S4C4_105= list()
for i in range(S4RGB_imgA1C4_.shape[0]): 
     for j in range(S4RGB_imgA1C4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1405.append(S4RGB_imgA1C4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_105.append(S4RGB_imgA1C4_[i][j])

# %%
S4A1_1505= list()
S4D2_105 = list()
for i in range(S4RGB_imgA1D2_5.shape[0]): 
     for j in range(S4RGB_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1505.append(S4RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_105.append(SR4GB_imgA1D2_5[i][j])

# %%
S4A1_1605= list()
S4D3_105 = list()
for i in range(S4RGB_imgA1D3_5.shape[0]): 
     for j in range(S4RGB_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1605.append(S4RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_105.append(S4RGB_imgA1D3_5[i][j])

# %%
S4A1_1705= list()
S4D4_105 = list()
for i in range(S4RGB_imgA1D4_5.shape[0]): 
     for j in range(S4RGB_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1705.append(S4RGB_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_105.append(S4RGB_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 6

# %%
S4A1_105= list()
S4A1_205= list()
for i in range(S4RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_105.append(S4RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_205.append(S4RGB_imgA1A1_5[i][j])

# %%
S4A1_305= list()
S4A2_105 = list()
for i in range(S4RGB_imgA1A2_5.shape[0]): 
     for j in range(S4RGB_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_305.append(S4RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_105.append(S4RGB_imgA1A2_5[i][j])

# %%
S4A1_405= list()
S4A3_105 = list()
for i in range(S4RGB_imgA1A3_5.shape[0]): 
     for j in range(S4RGB_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_405.append(S4RGB_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_105.append(S4RGB_imgA1A3_5[i][j])

# %%
S4A1_505= list()
S4A3_5105 = list()
for i in range(S4GB_imgA1A3_55.shape[0]): 
     for j in range(S4RGB_imgA1A3_55.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_505.append(S4RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_5105.append(S4RGB_imgA1A3_55[i][j])

# %%
S4A1_605= list()
S4A4_105 = list()
for i in range(S4RGB_imgA1A4_5.shape[0]): 
     for j in range(S4RGB_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA41_605.append(S4RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_105.append(S4RGB_imgA1A4_5[i][j])

# %%
S4A1_705= list()
S4B1_105 = list()
for i in range(S4RGB_imgA1B1_5.shape[0]): 
     for j in range(S4RGB_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_705.append(S4RGB_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_105.append(S4RGB_imgA1B1_5[i][j])

# %%
S4A1_805= list()
S4B2_105 = list()
for i in range(S4RGB_imgA1B2_5.shape[0]): 
     for j in range(SR4GB_imgA1B2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_805.append(S4RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_105.append(S4RGB_imgA1B2_5[i][j])

# %%
S4A1_905= list()
S4B3_105 = list()
for i in range(S4RGB_imgA1B3_5.shape[0]): 
     for j in range(4SRGB_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_905.append(S4RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_105.append(S4RGB_imgA1B3_5[i][j])

# %%
S4A1_1005= list()
S4B4_105 = list()
for i in range(S4RGB_imgA1B4_5.shape[0]): 
     for j in range(S4RGB_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1005.append(S4RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_105.append(S4RGB_imgA1B4_5[i][j])

# %%
S4A1_1105= list()
S4C1_205 = list()
for i in range(S4RGB_imgA1C1_5.shape[0]): 
     for j in range(S4RGB_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1105.append(S4RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_205.append(S4RGB_imgA1C1_5[i][j])

# %%
S4A1_1205= list()
S4C2_105 = list()
for i in range(S4RGB_imgA1C2_5.shape[0]): 
     for j in range(S4RGB_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1205.append(S4RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_105.append(S4RGB_imgA1C2_5[i][j])

# %%
S4A1_1305= list()
S4C3_105 = list()
for i in range(S4RGB_imgA1C3_5.shape[0]): 
     for j in range(S4RGB_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1305.append(S4RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_105.append(S4RGB_imgA1C3_5[i][j])

# %%
S4A1_1405= list()
S4C4_105 = list()
for i in range(S4RGB_imgA1C4_5.shape[0]): 
     for j in range(S4RGB_imgA1C4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1405.append(S4RGB_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_105.append(S4RGB_imgA1C4_5[i][j])

# %%
S4A1_1505= list()
S4D2_105 = list()
for i in range(S4RGB_imgA1D2_5.shape[0]): 
     for j in range(S4RGB_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1505.append(S4RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_105.append(S4RGB_imgA1D2_5[i][j])

# %%
S4A1_1605= list()
S4D3_105 = list()
for i in range(S4RGB_imgA1D3_5.shape[0]): 
     for j in range(S4RGB_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1605.append(S4RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_105.append(SR4GB_imgA1D3_5[i][j])

# %%
S4A1_1705= list()
S4D4_105 = list()
for i in range(S4RGB_imgA1D4_5.shape[0]): 
     for j in range(S4RGB_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1705.append(S4RGB_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_105.append(S4RGB_imgA1D4_5[i][j])

# %% [markdown]
# ###Img 7

# %%
S4A1_107= list()
S4A1_207= list()
for i in range(S4RGB_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_107.append(S4RGB_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_207.append(S4RGB_imgA1A1_7[i][j])

# %%
S4A1_30= list()
S4A2_10 = list()
for i in range(S4RGB_imgA1A2_.shape[0]): 
     for j in range(S4RGB_imgA1A2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_30.append(S4RGB_imgA1A2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_10.append(S4RGB_imgA1A2_[i][j])

# %%
S4A1_407= list()
S4A3_107 = list()
for i in range(S4RGB_imgA1A3_7.shape[0]): 
     for j in range(S4RGB_imgA1A3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_407.append(S4RGB_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_107.append(S4RGB_imgA1A3_7[i][j])

# %%
S41_507= list()
S4A3_5107 = list()
for i in range(S4RGB_imgA1A3_57.shape[0]): 
     for j in range(S4RGB_imgA1A3_57.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_507.append(S4RGB_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_5107.append(S4RGB_imgA1A3_57[i][j])

# %%
S4A1_607= list()
S4A4_107 = list()
for i in range(S4RGB_imgA1A4_7.shape[0]): 
     for j in range(S4RGB_imgA1A4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_607.append(S4RGB_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_107.append(S4RGB_imgA1A4_7[i][j])

# %%
S4A1_707= list()
S4B1_107 = list()
for i in range(S4RGB_imgA1B1_7.shape[0]): 
     for j in range(S4RGB_imgA1B1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_707.append(S4RGB_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_107.append(S4RGB_imgA1B1_7[i][j])

# %%
S4A1_807= list()
S4B2_107 = list()
for i in range(S4RGB_imgA1B2_7.shape[0]): 
     for j in range(S4RGB_imgA1B2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_807.append(S4RGB_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_107.append(S4RGB_imgA1B2_7[i][j])

# %%
S4A1_907= list()
S4B3_107 = list()
for i in range(S4RGB_imgA1B3_7.shape[0]): 
     for j in range(S4RGB_imgA1B3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_907.append(S4RGB_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_107.append(S4RGB_imgA1B3_7[i][j])

# %%
S4A1_1007= list()
S4B4_107 = list()
for i in range(S4RGB_imgA1B4_7.shape[0]): 
     for j in range(S4RGB_imgA1B4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1007.append(S4RGB_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_107.append(S4RGB_imgA1B4_7[i][j])

# %%
S41_1107= list()
S4C1_207 = list()
for i in range(S4RGB_imgA1C1_7.shape[0]): 
     for j in range(S4RGB_imgA1C1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1107.append(S4RGB_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_207.append(S4RGB_imgA1C1_7[i][j])

# %%
S4A1_1207= list()
S4C2_107 = list()
for i in range(S4RGB_imgA1C2_7.shape[0]): 
     for j in range(S4RGB_imgA1C2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1207.append(S4RGB_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_107.append(S4RGB_imgA1C2_7[i][j])

# %%
SA1_1307= list()
SC3_107 = list()
for i in range(SRGB_imgA1C3_7.shape[0]): 
     for j in range(SRGB_imgA1C3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1307.append(SRGB_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_107.append(SRGB_imgA1C3_7[i][j])

# %%
S4A1_1407= list()
S4C4_107 = list()
for i in range(S4RGB_imgA1C4_7.shape[0]): 
     for j in range(S4RGB_imgA1C4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1407.append(S4RGB_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_107.append(S4RGB_imgA1C4_7[i][j])

# %%
S4A1_1507= list()
S4D2_107 = list()
for i in range(S4RGB_imgA1D2_7.shape[0]): 
     for j in range(S4RGB_imgA1D2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1507.append(SRGB_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_107.append(SRGB_imgA1D2_7[i][j])

# %%
S4A1_1607= list()
S4D3_107 = list()
for i in range(S4RGB_imgA1D3_7.shape[0]): 
     for j in range(S4RGB_imgA1D3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1607.append(S4RGB_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_107.append(S4RGB_imgA1D3_7[i][j])

# %%
S4A1_1707= list()
S4D4_107 = list()
for i in range(S4RGB_imgA1D4_7.shape[0]): 
     for j in range(S4RGB_imgA1D4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1707.append(S4RGB_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_107.append(S4RGB_imgA1D4_7[i][j])

# %% [markdown]
# ###Img 8

# %%
S4A1_108= list()
S4A1_208= list()
for i in range(S4RGB_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_108.append(S4RGB_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_208.append(S4RGB_imgA1A1_8[i][j])

# %%
S4A1_308= list()
S4A2_108 = list()
for i in range(S4RGB_imgA1A2_8.shape[0]): 
     for j in range(S4RGB_imgA1A2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_308.append(S4RGB_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_108.append(S4RGB_imgA1A2_8[i][j])

# %%
S4A1_408= list()
S4A3_108 = list()
for i in range(S4RGB_imgA1A3_8.shape[0]): 
     for j in range(S4RGB_imgA1A3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_408.append(S4RGB_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    4A3_108.append(S4RGB_imgA1A3_8[i][j])

# %%
SA1_508= list()
SA3_5108 = list()
for i in range(SRGB_imgA1A3_58.shape[0]): 
     for j in range(SRGB_imgA1A3_58.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_508.append(SRGB_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5108.append(SRGB_imgA1A3_58[i][j])

# %%
S4A1_608= list()
S4A4_108 = list()
for i in range(S4RGB_imgA1A4_8.shape[0]): 
     for j in range(S4RGB_imgA1A4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_608.append(S4RGB_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_108.append(S4RGB_imgA1A4_8[i][j])

# %%
S4A1_708= list()
S4B1_108 = list()
for i in range(S4RGB_imgA1B1_8.shape[0]): 
     for j in range(S4RGB_imgA1B1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_708.append(S4RGB_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_108.append(S4RGB_imgA1B1_8[i][j])

# %%
S4A1_808= list()
S4B2_108 = list()
for i in range(S4RGB_imgA1B2_8.shape[0]): 
     for j in range(S4RGB_imgA1B2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_80.append(S4RGB_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_10.append(S4RGB_imgA1B2_8[i][j])

# %%
S4A1_90= list()
S4B3_10 = list()
for i in range(S4RGB_imgA1B3_.shape[0]): 
     for j in range(S4RGB_imgA1B3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_908.append(S4RGB_imgA1B3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_108.append(S4RGB_imgA1B3_[i][j])

# %%
S4A1_1008= list()
S4B4_108 = list()
for i in range(S4RGB_imgA1B4_8.shape[0]): 
     for j in range(S4RGB_imgA1B4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1008.append(S4RGB_8imgA1B4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_108.append(S4RGB_imgA1B4_8[i][j])

# %%
S4A1_1108= list()
S4C1_208 = list()
for i in range(S4RGB_imgA1C1_8.shape[0]): 
     for j in range(S4RGB_imgA1C1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1108.append(S4RGB_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_208.append(S4RGB_imgA1C1_8[i][j])

# %%
S4A1_1208= list()
S4C2_108 = list()
for i in range(S4RGB_imgA1C2_8.shape[0]): 
     for j in range(S4RGB_imgA1C2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1208.append(S4RGB_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_108.append(S4RGB_imgA1C2_8[i][j])

# %%
S4A1_1308= list()
S4C3_108 = list()
for i in range(S4RGB_imgA1C3_8.shape[0]): 
     for j in range(S4RGB_imgA1C3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1308.append(S4RGB_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_108.append(S4RGB_imgA1C3_8[i][j])

# %%
S4A1_1408= list()
S4C4_108 = list()
for i in range(S4RGB_imgA1C4_8.shape[0]): 
     for j in range(S4RGB_imgA1C4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1408.append(S4RGB_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_108.append(S4RGB_imgA1C4_8[i][j])

# %%
S4A1_1508= list()
S4D2_108 = list()
for i in range(S4RGB_imgA1D2_8.shape[0]): 
     for j in range(S4RGB_imgA1D2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1508.append(S4RGB_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_108.append(S4RGB_imgA1D2_8[i][j])

# %%
S4A1_1608= list()
S4D3_108 = list()
for i in range(S4RGB_imgA1D3_8.shape[0]): 
     for j in range(S4RGB_imgA1D3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1608.append(S4RGB_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_108.append(S4RGB_imgA1D3_8[i][j])

# %%
S4A1_1708= list()
S4D4_108 = list()
for i in range(S4RGB_imgA1D4_8.shape[0]): 
     for j in range(S4RGB_imgA1D4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1708.append(S4RGB_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_108.append(S4RGB_imgA1D4_8[i][j])

# %% [markdown]
# ###Img 9

# %%
S4A1_109= list()
S4A1_209= list()
for i in range(S4RGB_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_109.append(S4RGB_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_209.append(S4RGB_imgA1A1_9[i][j])

# %%
S4A1_309= list()
S4A2_109 = list()
for i in range(S4RGB_imgA1A2_9.shape[0]): 
     for j in range(S4RGB_imgA1A2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_309.append(S4RGB_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_109.append(S4RGB_imgA1A2_9[i][j])

# %%
S4A1_409= list()
S4A3_109 = list()
for i in range(S4RGB_imgA1A3_9.shape[0]): 
     for j in range(SRGB_imgA1A3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_409.append(S4RGB_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_109.append(S4RGB_imgA1A3_9[i][j])

# %%
S4A1_509= list()
S4A3_5109 = list()
for i in range(S4RGB_imgA1A3_59.shape[0]): 
     for j in range(S4RGB_imgA1A3_59.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_509.append(S4RGB_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_5109.append(S4RGB_imgA1A3_59[i][j])

# %%
S4A1_609= list()
S4A4_109 = list()
for i in range(S4RGB_imgA1A4_9.shape[0]): 
     for j in range(S4RGB_imgA1A4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_609.append(S4RGB_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_109.append(S4RGB_imgA1A4_9[i][j])

# %%
S4A1_709= list() 
S4B1_109 = list()
for i in range(S4RGB_imgA1B1_9.shape[0]): 
     for j in range(S4RGB_imgA1B1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_709.append(S4RGB_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_109.append(S4RGB_imgA1B1_9[i][j])

# %%
S4A1_809= list()
S4B2_109 = list()
for i in range(S4RGB_imgA1B2_9.shape[0]): 
     for j in range(S4RGB_imgA1B2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_809.append(S4RGB_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_109.append(SR4GB_imgA1B2_9[i][j])

# %%
S4A1_909= list()
S4B3_109 = list()
for i in range(S4RGB_imgA1B3_9.shape[0]): 
     for j in range(S4RGB_imgA1B3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_909.append(S4RGB_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_109.append(S4RGB_imgA1B3_9[i][j])

# %%
S4A1_1009= list()
S4B4_109 = list()
for i in range(S4RGB_imgA1B4_9.shape[0]): 
     for j in range(S4RGB_imgA1B4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1009.append(S4RGB_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_109.append(S4RGB_imgA1B4_9[i][j])

# %%
S4A1_1109= list()
S4C1_209 = list()
for i in range(S4RGB_imgA1C1_9.shape[0]): 
     for j in range(S4RGB_imgA1C1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1109.append(S4RGB_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_209.append(S4RGB_imgA1C1_9[i][j])

# %%
S4A1_1209= list()
S4C2_109 = list()
for i in range(S4RGB_imgA1C2_9.shape[0]): 
     for j in range(S4RGB_imgA1C2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1209.append(S4RGB_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S42_109.append(S4RGB_imgA1C2_9[i][j])

# %%
S4A1_1309= list()
S4C3_109 = list()
for i in range(S4RGB_imgA1C3_9.shape[0]): 
     for j in range(S4RGB_imgA1C3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1309.append(S4RGB_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_109.append(S4RGB_imgA1C3_9[i][j])

# %%
SA1_1409= list()
SC4_109 = list()
for i in range(S4RGB_imgA1C4_9.shape[0]): 
     for j in range(S4RGB_imgA1C4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1409.append(S4RGB_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_109.append(S4RGB_imgA1C4_9[i][j])

# %%
S4A1_1509= list()
S4D2_109 = list()
for i in range(S4RGB_imgA1D2_9.shape[0]): 
     for j in range(S4RGB_imgA1D2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1509.append(S4RGB_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_109.append(S4RGB_imgA1D2_9[i][j])

# %%
S4A1_1609= list()
S4D3_109 = list()
for i in range(S4RGB_imgA1D3_9.shape[0]): 
     for j in range(S4RGB_imgA1D3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1609.append(S4RGB_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_109.append(S4RGB_imgA1D3_9[i][j])

# %%
S4A1_1709= list()
S4D4_109 = list()
for i in range(S4RGB_imgA1D4_9.shape[0]): 
     for j in range(S4RGB_imgA1D4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1709.append(S4RGB_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_109.append(S4RGB_imgA1D4_9[i][j])

# %% [markdown]
# ###Img 10

# %%
S4A1_110= list()
S4A1_210= list()
for i in range(S4RGB_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_110.append(S4RGB_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_210.append(S4RGB_imgA1A1_10[i][j])

# %%
S4A1_310= list()
S4A2_110 = list()
for i in range(S4RGB_imgA1A2_10.shape[0]): 
     for j in range(S4RGB_imgA1A2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_310.append(S4RGB_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_110.append(S4RGB_imgA1A2_10[i][j])

# %%
S4A1_410= list()
S4A3_110 = list()
for i in range(S4RGB_imgA1A3_10.shape[0]): 
     for j in range(S4RGB_imgA1A3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_410.append(S4RGB_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_110.append(S4RGB_imgA1A3_10[i][j])

# %%
S4A1_510= list()
S4A3_510 = list()
for i in range(S4RGB_imgA1A3_510.shape[0]): 
     for j in range(S4RGB_imgA1A3_510.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_510.append(S4RGB_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_510.append(S4RGB_imgA1A3_510[i][j])

# %%
S4A1_610= list()
S4A4_110 = list()
for i in range(S4RGB_imgA1A4_10.shape[0]): 
     for j in range(S4RGB_imgA1A4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_610.append(S4RGB_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_110.append(S4RGB_imgA1A4_10[i][j])

# %%
S4A1_710= list()
S4B1_110 = list()
for i in range(S4RGB_imgA1B1_10.shape[0]): 
     for j in range(S4RGB_imgA1B1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_710.append(S4RGB_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_110.append(S4RGB_imgA1B1_10[i][j])

# %%
S41A1_810= list()
S4B2_110 = list()
for i in range(S4RGB_imgA1B2_10.shape[0]): 
     for j in range(S4RGB_imgA1B2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_810.append(S4RGB_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_110.append(S4RGB_imgA1B2_10[i][j])่

# %%
S4A1_910= list()
S4B3_110 = list()
for i in range(S4RGB_imgA1B3_10.shape[0]): 
     for j in range(S4RGB_imgA1B3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_910.append(S4RGB_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_110.append(S4RGB_imgA1B3_10[i][j])

# %%
S4A1_1010= list()
S4B4_110 = list()
for i in range(S4RGB_imgA1B4_10.shape[0]): 
     for j in range(S4RGB_imgA1B4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1010.append(S4RGB_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_110.append(S4RGB_imgA1B4_10[i][j])

# %%
S4A1_1110= list()
S4C1_210 = list()
for i in range(S4RGB_imgA1C1_10.shape[0]): 
     for j in range(S4RGB_imgA1C1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1110.append(S4RGB_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_210.append(S4RGB_imgA1C1_10[i][j])

# %%
S4A1_1210= list()
S4C2_110 = list()
for i in range(S4RGB_imgA1C2_10.shape[0]): 
     for j in range(S4RGB_imgA1C2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1210.append(S4RGB_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_110.append(S4RGB_imgA1C2_10[i][j])

# %%
S4A1_1310= list()
S4C3_110 = list()
for i in range(S4RGB_imgA1C3_10.shape[0]): 
     for j in range(S4RGB_imgA1C3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1310.append(S4RGB_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_110.append(S4RGB_imgA1C3_10[i][j])

# %%
S4A1_1410= list()
S4C4_110 = list()
for i in range(S4RGB_imgA1C4_10.shape[0]): 
     for j in range(S4RGB_imgA1C4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1410.append(S4RGB_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_110.append(S44RGB_imgA1C4_10[i][j])

# %%
S4A1_1510= list()
S4D2_110 = list()
for i in range(S4RGB_imgA1D2_10.shape[0]): 
     for j in range(S4RGB_imgA1D2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1510.append(S4RGB_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_110.append(S4RGB_imgA1D210_[i][j])

# %%
S4A1_1610= list()
S4D3_110 = list()
for i in range(S4RGB_imgA1D3_10.shape[0]): 
     for j in range(S4RGB_imgA1D3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1610.append(S4RGB_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_110.append(S4RGB_imgA1D3_10[i][j])

# %%
S4A1_1710= list()
S4D4_110 = list()
for i in range(S4RGB_imgA1D4_10.shape[0]): 
     for j in range(S4RGB_imgA1D4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1710.append(S4RGB_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_110.append(S4RGB_imgA1D4_10[i][j])

# %% [markdown]
# ###HSV

# %%
S4A1_1= list()
S4A1_2 = list()
for i in range(S4HSV_imgA1A1_1.shape[0]): 
     for j in range(S4HSV_imgA1A1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_1.append(S4HSV_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_2.append(S4HSV_imgA1A1_1[i][j])

# %%
S4A1_3= list()
S4A2_1 = list()
for i in range(S4HSV_imgA1A2_1.shape[0]): 
     for j in range(S4HSV_imgA1A2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_3.append(S4HSV_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A2_1.append(S4HSV_imgA1A2_1[i][j])

# %%
S4A1_4= list()
S4A3_1 = list()
for i in range(S4HSV_imgA1A3_1.shape[0]): 
     for j in range(S4HSV_imgA1A3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_4.append(S4HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_1.append(S4HSV_imgA1A3_1[i][j])

# %%
S4A1_5= list()
S4A3_51 = list()
for i in range(S4RGB_imgA1A3_51.shape[0]): 
     for j in range(S4RGB_imgA1A3_51.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_5.append(S4RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_51.append(S4RGB_imgA1A3_51[i][j])

# %%
S4A1_6= list()
S4A4_1 = list()
for i in range(S4HSV_imgA1A4_1.shape[0]): 
     for j in range(S4HSV_imgA1A4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_6.append(S4HSV_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A4_1.append(S4HSV_imgA1A4_1[i][j])

# %%
S4A1_7= list()
S4B1_1 = list()
for i in range(S4HSV_imgA1B1_1.shape[0]): 
     for j in range(S4HSV_imgA1B1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_7.append(S4HSV_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B1_1.append(S4HSV_imgA1B1_1[i][j])

# %%
S4A1_8= list()
S4B2_1 = list()
for i in range(S4HSV_imgA1B2_1.shape[0]): 
     for j in range(S4HSV_imgA1B2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_8.append(S4HSV_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B2_1.append(S4HSV_imgA1B2_1[i][j])

# %%
S4A1_9= list()
S4B3_1 = list()
for i in range(S4HSV_imgA1B3_1.shape[0]): 
     for j in range(S4HSV_imgA1B3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_9.append(S4HSV_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B3_1.append(S4HSV_imgA1B3_1[i][j])

# %%
S4A1_10= list()
S4B4_1 = list()
for i in range(S4HSV_imgA1B4_1.shape[0]): 
     for j in range(S4HSV_imgA1B4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_10.append(S4HSV_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4B4_1.append(S4HSV_imgA1B4_1[i][j])

# %%
S4A1_11= list()
S4C1_1 = list()
for i in range(S4HSV_imgA1C1_1.shape[0]): 
     for j in range(S4HSV_imgA1C1_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_11.append(S4HSV_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C1_1.append(S4HSV_imgA1C1_1[i][j])

# %%
S4A1_12= list()
S4C2_1 = list()
for i in range(S4HSV_imgA1C2_1.shape[0]): 
     for j in range(S4HSV_imgA1C2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_12.append(S4HSV_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C2_1.append(S4HSV_imgA1C2_1[i][j])

# %%
S4A1_13= list()
S4C3_1 = list()
for i in range(S4HSV_imgA1C3_1.shape[0]): 
     for j in range(S4HSV_imgA1C3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_13.append(S4HSV_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C3_1.append(S4HSV_imgA1C3_1[i][j])

# %%
S4A1_14= list()
S4C4_1 = list()
for i in range(S4HSV_imgA1C4_1.shape[0]): 
     for j in range(S4HSV_imgA1C4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_14.append(S4HSV_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4C4_1.append(S4HSV_imgA1C4_1[i][j])

# %%
S4A1_15= list()
S4D2_1 = list()
for i in range(S4HSV_imgA1C2_1.shape[0]): 
     for j in range(S4HSV_imgA1D2_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_15.append(S4HSV_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D2_1.append(S4HSV_imgA1D2_1[i][j])

# %%
S4A1_16= list()
S4D3_1 = list()
for i in range(S4HSV_imgA1D3_1.shape[0]): 
     for j in range(S4HSV_imgA1D3_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_16.append(S4HSV_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D3_1.append(S4HSV_imgA1D3_1[i][j])

# %%
S4A1_17= list()
S4D4_1 = list()
for i in range(S4HSV_imgA1D4_1.shape[0]): 
     for j in range(S4HSV_imgA1D4_1.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_17.append(S4HSV_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4D4_1.append(S4HSV_imgA1D4_1[i][j])

# %% [markdown]
# ### Img 2

# %%
S4A1_102= list()
S4A1_202 = list()
for i in range(S4HSV_imgA1A1_2.shape[0]): 
     for j in range(S4HSV_imgA1A1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_102.append(S4HSV_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A1_202.append(S4HSV_imgA1A1_2[i][j])

# %%
S4A1_302= list()
S4A2_102 = list()
for i in range(S4HSV_imgA1A2_2.shape[0]): 
     for j in range(S4HSV_imgA1A2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_302.append(S4HSV_imgA1A2_0[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   S4A2_102.append(S4HSV_imgA1A2_2[i][j])

# %%
S4A1_402= list()
S4A3_102 = list()
for i in range(S4HSV_imgA1A3_.2shape[0]): 
     for j in range(S4HSV_imgA1A3_.2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_402.append(S4HSV_imgA1A3_[2i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_102.append(S4HSV_imgA1A3_2[i][j])

# %%
S4A1_502= list()
S4A3_5102= list()
for i in range(S4HSV_imgA1A3_52.shape[0]): 
     for j in range(S4HSV_imgA1A3_52.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S4A1_502.append(S4HSV_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S4A3_5102.append(S4HSV_imgA1A3_52[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(SHSV_imgA1A4_.2shape[0]): 
     for j in range(SHSV_imgA1A4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_602.append(SHSV_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(2HSV_imgA1A4_2[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(SHSV_imgA1B1_.2shape[0]): 
     for j in range(SHSV_imgA1B1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_702.append(SHSV_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_102.append(SHSV_imgA1B1_2[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_2.shape[0]): 
     for j in range(SHSV_imgA1B2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(SHSV_imgA1B2_[i][j])2

# %%
SA1_902= list()
SB3_102= list()
for i in range(SHSV_imgA1B3_2.shape[0]): 
     for j in range(SHSV_imgA1B3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_2[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SHSV_imgA1B4_2.shape[0]): 
     for j in range(SHSV_imgA1B4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SHSV_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SHSV_imgA1B4_2[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(SHSV_imgA1C1_2.shape[0]): 
     for j in range(SHSV_imgA1C1_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(SHSV_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(SHSV_imgA1C1_2[i][j])

# %%
SA1_1202= list()
SC2_102 = list()
for i in range(SHSV_imgA1C2_2.shape[0]): 
     for j in range(SHSV_imgA1C2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1202.append(SHSV_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_2[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(SHSV_imgA1C3_2.shape[0]): 
     for j in range(SHSV_imgA1C3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(SHSV_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_102.append(SHSV_imgA1C3_2[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(SHSV_imgA1C4_2.shape[0]): 
     for j in range(SHSV_imgA1C4_2shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(S2HSV_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(S2HSV_imgA1C4_2[i][j])

# %%
SA1_1502= list()
SD2_102 = list()
for i in range(SHSV_imgA1C2_2.shape[0]): 
     for j in range(SHSV_imgA1D2_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1502.append(SHSV_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_102.append(SHSV_imgA1D2_2[i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(SHSV_imgA1D3_2.shape[0]): 
          for j in range(SHSV_imgA1D3_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_2[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_2.shape[0]): 
     for j in range(SHSV_imgA1D4_2.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_102.append(SHSV_imgA1D4_2[i][j])

# %% [markdown]
# ### Img 3

# %%
SA1_102= list()
SA1_202 = list()
for i in range(SHSV_imgA1A1_3.shape[0]): 
     for j in range(SHSV_imgA1A1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_102.append(SHSV_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA1_202.append(SHSV_imgA1A1_3i][j])

# %%
SA1_302= list()
SA2_102 = list()
for i in range(SHSV_imgA1A2_102.shape[0]): 
     for j in range(SHSV_imgA1A2_102.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_302.append(SHSV_imgA1A2_102[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   SA2_102.append(SHSV_imgA1A2_102[i][j])

# %%
SA1_402= list()
SA3_102 = list()
for i in range(SHSV_imgA1A3_3.shape[0]): 
     for j in range(SHSV_imgA1A3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_402.append(SHSV_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_102.append(SHSV_imgA1A3_3[i][j])

# %%
SA1_502= list()
SA3_5102= list()
for i in range(SHSV_imgA1A3_53.shape[0]): 
     for j in range(SHSV_imgA1A3_53.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(SHSV_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5102.append(SHSV_imgA1A3_53[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(SHSV_imgA1A4_.shape[0]): 
     for j in range(SHSV_imgA1A4_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    2A1_602.append(SHSV_imgA1A4_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(SHSV_imgA1A4_[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(SHSV_imgA1B1_3.shape[0]): 
     for j in range(SHSV_imgA1B1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_702.append(SHSV_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_102.append(SHSV_imgA1B1_3[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_3.shape[0]): 
     for j in range(SHSV_imgA1B2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(SHSV_imgA1B2_3[i][j])

# %%
SA1_902= list()
SB3_102= list()
for i in range(2HSV_imgA1B3_3.shape[0]): 
     for j in range(SHSV_imgA1B3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_3[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SHSV_imgA1B4_3.shape[0]): 
     for j in range(SHSV_imgA1B4_3shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SHSV_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SHSV_imgA1B4_3[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(SHSV_imgA1C1_3.shape[0]): 
     for j in range(SHSV_imgA1C1_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(SHSV_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(SHSV_imgA1C1_3[i][j])

# %%
SA1_1202= list()
SC2_102 = list()
for i in range(SHSV_imgA1C2_3.shape[0]): 
     for j in range(SHSV_imgA1C2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1202.append(SHSV_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_3[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(SHSV_imgA1C3_3.shape[0]): 
     for j in range(SHSV_imgA1C3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(2HSV_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_102.append(SHSV_imgA1C3_3[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(SHSV_imgA1C4_3.shape[0]): 
     for j in range(SHSV_imgA1C4_3shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(SHSV_imgA1C4_3[i][j])

# %%
SA1_1502= list()
SD2_102 = list()
for i in range(SHSV_imgA1C2_3.shape[0]): 
     for j in range(SHSV_imgA1D2_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1502.append(SHSV_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_102.append(SHSV_imgA1D2_3[i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(SHSV_imgA1D3_3.shape[0]): 
          for j in range(SHSV_imgA1D3_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_3[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_3.shape[0]): 
     for j in range(SHSV_imgA1D4_3.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1D43_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_102.append(SHSV_imgA1D4_3[i][j])

# %% [markdown]
# ### Img 4

# %%
SA1_102= list()
SA1_202 = list()
for i in range(SHSV_imgA1A1_4.shape[0]): 
     for j in range(SHSV_imgA1A1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_102.append(SHSV_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA1_202.append(SHSV_imgA1A1_4[i][j])

# %%
SA1_302= list()
SA2_102 = list()
for i in range(SHSV_imgA1A2_4.shape[0]): 
     for j in range(SHSV_imgA1A2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_302.append(SHSV_imgA1A2_4[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   SA2_102.append(SHSV_imgA1A2_4[i][j])

# %%
SA1_402= list()
SA3_102 = list()
for i in range(SHSV_imgA1A3_4.shape[0]): 
     for j in range(SHSV_imgA1A3_.4shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_402.append(SHSV_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_102.append(SHSV_imgA1A3_4[i][j])

# %%
SA1_502= list()
SA3_5102= list()
for i in range(SHSV_imgA1A3_54.shape[0]): 
     for j in range(SHSV_imgA1A3_54.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(SHSV_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5102.append(SHSV_imgA1A3_54[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(SHSV_imgA1A4_4.shape[0]): 
     for j in range(SHSV_imgA1A4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_602.append(SHSV_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(SHSV_imgA1A4_4[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(SHSV_imgA1B1_4.shape[0]): 
     for j in range(SHSV_imgA1B1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_702.append(SHSV_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_102.append(SHSV_imgA1B1_4[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_4.shape[0]): 
     for j in range(SHSV_imgA1B2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(2HSV_imgA1B2_4[i][j])

# %%
SA1_902= list()
SB3_102= list()
for i in range(SHSV_imgA1B3_4.shape[0]): 
     for j in range(SHSV_imgA1B3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_4[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SHSV_imgA1B4_4.shape[0]): 
     for j in range(SHSV_imgA1B4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SHSV_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SHSV_imgA1B4_4[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(SHSV_imgA1C1_4.shape[0]): 
     for j in range(SHSV_imgA1C1_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(SHSV_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(SHSV_imgA1C1_4[i][j])

# %%
SA1_1202= list()
SC2_102 = list()
for i in range(SHSV_imgA1C2_.shape[0]): 
     for j in range(SHSV_imgA1C2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1202.append(SHSV_imgA1C2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(SHSV_imgA1C3_4.shape[0]): 
     for j in range(SHSV_imgA1C3_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(SHSV_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S23_102.append(SHSV_imgA1C3_4[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(2HSV_imgA1C4_4.shape[0]): 
     for j in range(SHSV_imgA1C4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(SHSV_imgA1C4_4[i][j])

# %%
S2A1_1502= list()
S2D2_102 = list()
for i in range(S2HSV_imgA1C2_4.shape[0]): 
     for j in range(S2HSV_imgA1D2_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_1502.append(S2HSV_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2D2_102.append(S2HSV_imgA1D2_4[i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(S2HSV_imgA1D3_4.shape[0]): 
          for j in range(S2HSV_imgA1D3_.4shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_4[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_4.shape[0]): 
     for j in range(SHSV_imgA1D4_4.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S24_102.append(SHSV_imgA1D4_4[i][j])

# %% [markdown]
# ### Img 5

# %%
SA1_102= list()
SA1_202 = list()
for i in range(SHSV_imgA1A1_5.shape[0]): 
     for j in range(SHSV_imgA1A1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_102.append(SHSV_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA1_202.append(SHSV_imgA1A1_5[i][j])

# %%
SA1_302= list()
SA2_102 = list()
for i in range(SHSV_imgA1A2_5.shape[0]): 
     for j in range(SHSV_imgA1A2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_302.append(SHSV_imgA1A2_5[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   SA2_102.append(SHSV_imgA1A2_5[i][j])

# %%
SA1_402= list()
SA3_102 = list()
for i in range(SHSV_imgA1A3_5.shape[0]): 
     for j in range(SHSV_imgA1A3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_402.append(SHSV_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_102.append(SHSV_imgA1A3_5[i][j])

# %%
SA1_502= list()
SA3_5102= list()
for i in range(SHSV_imgA1A3_55.shape[0]): 
     for j in range(SHSV_imgA1A3_55.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(SHSV_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5102.append(SHSV_imgA1A3_55[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(SHSV_imgA1A4_5.shape[0]): 
     for j in range(SHSV_imgA1A4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_602.append(SHSV_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(SHSV_imgA1A4_5[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(SHSV_imgA1B1_5.shape[0]): 
     for j in range(SHSV_imgA1B1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_702.append(SHSV_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_102.append(SHSV_imgA1B1_5[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_5.shape[0]): 
     for j in range(SHSV_imgA1B2_.5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(SHSV_imgA1B2_5[i][j])

# %%
SA1_902= list()
SB3_102= list()
for i in range(SHSV_imgA1B3_5.shape[0]): 
     for j in range(2HSV_imgA1B3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_5[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SHSV_imgA1B4_5.shape[0]): 
     for j in range(SHSV_imgA1B4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SHSV_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SHSV_imgA1B4_5[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(SHSV_imgA1C1_5.shape[0]): 
     for j in range(SHSV_imgA1C1_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(SHSV_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(SHSV_imgA1C1_[i][j])

# %%
SA1_1202= list()
SC2_102 = list()
for i in range(SHSV_imgA1C2_5.shape[0]): 
     for j in range(S2HSV_imgA1C2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1202.append(S2HSV_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_5[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(2HSV_imgA1C3_5.shape[0]): 
     for j in range(SHSV_imgA1C3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(SHSV_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_102.append(SHSV_imgA1C3_5[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(SHSV_imgA1C4_5.shape[0]): 
     for j in range(SHSV_imgA1C4_5shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(SHSV_imgA1C4_5[i][j])

# %%
SA1_1502= list()
SD2_102 = list()
for i in range(SHSV_imgA1C2_5.shape[0]): 
     for j in range(SHSV_imgA1D2_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1502.append(SHSV_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_102.append(SHSV_imgA1D2_5i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(SHSV_imgA1D3_5.shape[0]): 
          for j in range(SHSV_imgA1D3_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_5[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_5.shape[0]): 
     for j in range(SHSV_imgA1D4_5.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_102.append(SHSV_imgA1D4_5[i][j])

# %% [markdown]
# ### Img 6

# %%
SA1_102= list()
SA1_202 = list()
for i in range(SHSV_imgA1A1_6.shape[0]): 
     for j in range(SHSV_imgA1A1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_102.append(SHSV_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA1_202.append(SHSV_imgA1A1_6[i][j])

# %%
SA1_302= list()
SA2_102 = list()
for i in range(SHSV_imgA1A2_6.shape[0]): 
     for j in range(SHSV_imgA1A2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_302.append(SHSV_imgA1A2_6[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   SA2_102.append(SHSV_imgA1A2_6[i][j])

# %%
SA1_402= list()
SA3_102 = list()
for i in range(SHSV_imgA1A3_.shape[0]): 
     for j in range(SHSV_imgA1A3_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_402.append(SHSV_imgA1A3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_102.append(SHSV_imgA1A3_[i][j])

# %%
SA1_502= list()
SA3_5102= list()
for i in range(SHSV_imgA1A3_6.shape[0]): 
     for j in range(SHSV_imgA1A3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(SHSV_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5102.append(SHSV_imgA1A3_6[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(SHSV_imgA1A4_6.shape[0]): 
     for j in range(SHSV_imgA1A4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_602.append(SHSV_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(SHSV_imgA1A4_6[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(SHSV_imgA1B1_6.shape[0]): 
     for j in range(SHSV_imgA1B1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_702.append(SHSV_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_102.append(SHSV_imgA1B1_6[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_6.shape[0]): 
     for j in range(SHSV_imgA1B2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(SHSV_imgA1B2_6[i][j])

# %%
SA1_902= list()
SB3_102= list()
for i in range(SHSV_imgA1B3_6.shape[0]): 
     for j in range(SHSV_imgA1B3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_6[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SHSV_imgA1B4_6.shape[0]): 
     for j in range(SHSV_imgA1B4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SHSV_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SHSV_imgA1B4_6[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(SHSV_imgA1C1_6.shape[0]): 
     for j in range(SHSV_imgA1C1_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(SHSV_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(SHSV_imgA1C1_6[i][j])

# %%
SA1_1202= list()
SC2_102 = list()
for i in range(SHSV_imgA1C2_6.shape[0]): 
     for j in range(SHSV_imgA1C2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1202.append(SHSV_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_6[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(SHSV_imgA1C3_6.shape[0]): 
     for j in range(SHSV_imgA1C3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(SHSV_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_102.append(SHSV_imgA1C3_6[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(SHSV_imgA1C4_6.shape[0]): 
     for j in range(SHSV_imgA1C4_6shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(2HSV_imgA1C4_6[i][j])

# %%
SA1_1502= list()
SD2_102 = list()
for i in range(SHSV_imgA1C2_6.shape[0]): 
     for j in range(SHSV_imgA1D2_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1502.append(SHSV_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_102.append(SHSV_imgA1D2_6[i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(SHSV_imgA1D3_6.shape[0]): 
          for j in range(SHSV_imgA1D3_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_6[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_6.shape[0]): 
     for j in range(SHSV_imgA1D4_6.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    2A1_1402.append(SHSV_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_102.append(SHSV_imgA1D4_6[i][j])

# %% [markdown]
# ### Img 7

# %%
SA1_102= list()
S2A1_202 = list()
for i in range(SHSV_imgA1A1_7.shape[0]): 
     for j in range(SHSV_imgA1A1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_102.append(SHSV_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA1_202.append(2HSV_imgA1A1_7[i][j])

# %%
SA1_302= list()
SA2_102 = list()
for i in range(SHSV_imgA1A2_7.shape[0]): 
     for j in range(SHSV_imgA1A2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_302.append(SHSV_imgA1A2_7[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   SA2_102.append(SHSV_imgA1A2_7[i][j])

# %%
SA1_402= list()
SA3_102 = list()
for i in range(SHSV_imgA1A3_7.shape[0]): 
     for j in range(SHSV_imgA1A3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_402.append(SHSV_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_102.append(SHSV_imgA1A3_7[i][j])

# %%
SA1_502= list()
SA3_5102= list()
for i in range(SHSV_imgA1A3_57.shape[0]): 
     for j in range(SHSV_imgA1A3_57.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(SHSV_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5102.append(SHSV_imgA1A3_57[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(2HSV_imgA1A4_7.shape[0]): 
     for j in range(SHSV_imgA1A4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_602.append(SHSV_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(SHSV_imgA1A4_7[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(SHSV_imgA1B1_7.shape[0]): 
     for j in range(SHSV_imgA1B1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_702.append(SHSV_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_102.append(SHSV_imgA1B1_7[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_7.shape[0]): 
     for j in range(SHSV_imgA1B2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(SHSV_imgA1B2_7[i][j])

# %%
SA1_902= list()
SB3_102= list()
for i in range(SHSV_imgA1B3_7.shape[0]): 
     for j in range(SHSV_imgA1B3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_7[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SHSV_imgA1B4_7.shape[0]): 
     for j in range(SHSV_imgA1B4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(S2HSV_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(S2HSV_imgA1B4_7[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(S2HSV_imgA1C1_7.shape[0]): 
     for j in range(S2HSV_imgA1C1_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(S2HSV_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(S2HSV_imgA1C1_7[i][j])

# %%
SA1_1202= list()
S2C2_102 = list()
for i in range(SHSV_imgA1C2_7.shape[0]): 
     for j in range(SHSV_imgA1C2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    2A1_1202.append(SHSV_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_7[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(SHSV_imgA1C3_7.shape[0]): 
     for j in range(SHSV_imgA1C3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(SHSV_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_102.append(SHSV_imgA1C3_7[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(SHSV_imgA1C4_7.shape[0]): 
     for j in range(SHSV_imgA1C4_7shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(SHSV_imgA1C4_7[i][j])

# %%
SA1_1502= list()
SD2_102 = list()
for i in range(SHSV_imgA1C2_7.shape[0]): 
     for j in range(SHSV_imgA1D2_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    2A1_1502.append(SHSV_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_102.append(SHSV_imgA1D2_7[i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(SHSV_imgA1D3_7.shape[0]): 
          for j in range(SHSV_imgA1D3_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_7[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_7.shape[0]): 
     for j in range(SHSV_imgA1D4_7.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_102.append(SHSV_imgA1D4_7[i][j])

# %% [markdown]
# ### Img 8

# %%
SA1_102= list()
SA1_202 = list()
for i in range(SHSV_imgA1A1_8.shape[0]): 
     for j in range(SHSV_imgA1A1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_102.append(SHSV_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA1_202.append(SHSV_imgA1A1_8[i][j])

# %%
SA1_302= list()
SA2_102 = list()
for i in range(SHSV_imgA1A2_8.shape[0]): 
     for j in range(SHSV_imgA1A2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_302.append(SHSV_imgA1A2_8[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   SA2_102.append(SHSV_imgA1A2_8[i][j])

# %%
SA1_402= list()
SA3_102 = list()
for i in range(SHSV_imgA1A3_8.shape[0]): 
     for j in range(SHSV_imgA1A3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_402.append(SHSV_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_102.append(SHSV_imgA1A3_8[i][j])

# %%
SA1_502= list()
SA3_5102= list()
for i in range(SHSV_imgA1A3_58.shape[0]): 
     for j in range(SHSV_imgA1A3_58.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(SHSV_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5102.append(SHSV_imgA1A3_58[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(SHSV_imgA1A4_8.shape[0]): 
     for j in range(SHSV_imgA1A4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_602.append(SHSV_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(SHSV_imgA1A4_8[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(S2HSV_imgA1B1_8.shape[0]): 
     for j in range(S2HSV_imgA1B1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    S2A1_702.append(S2HSV_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    S2B1_102.append(S2HSV_imgA1B1_8[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_8.shape[0]): 
     for j in range(SHSV_imgA1B2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(SHSV_imgA1B2_8[i][j])

# %%
SA1_902= list()
SB3_102= list()
for i in range(SHSV_imgA1B3_8.shape[0]): 
     for j in range(SHSV_imgA1B3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_8[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SHSV_imgA1B4_8.shape[0]): 
     for j in range(SHSV_imgA1B4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SHSV_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SHSV_imgA1B4_8[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(SHSV_imgA1C1_8.shape[0]): 
     for j in range(SHSV_imgA1C1_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(SHSV_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(SHSV_imgA1C1_8[i][j])

# %%
SA1_1202= list()
SC2_102 = list()
for i in range(SHSV_imgA1C2_8.shape[0]): 
     for j in range(SHSV_imgA1C2_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1202.append(SHSV_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_8[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(SHSV_imgA1C3_8.shape[0]): 
     for j in range(SHSV_imgA1C3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(SHSV_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_102.append(SHSV_imgA1C3_8[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(SHSV_imgA1C4_8.shape[0]): 
     for j in range(SHSV_imgA1C4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(SHSV_imgA1C4_8[i][j])

# %%
SA1_1502= list()
SD2_102 = list()
for i in range(SHSV_imgA1C2_.shape[0]): 
     for j in range(SHSV_imgA1D2_.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1502.append(SHSV_imgA1D2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_102.append(SHSV_imgA1D2_[i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(SHSV_imgA1D3_8.shape[0]): 
          for j in range(SHSV_imgA1D3_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_8[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_8.shape[0]): 
     for j in range(SHSV_imgA1D4_8.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_102.append(SHSV_imgA1D4_8[i][j])

# %% [markdown]
# ### Img 9

# %%
SA1_102= list()
SA1_202 = list()
for i in range(SHSV_imgA1A1_9.shape[0]): 
     for j in range(SHSV_imgA1A1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_102.append(SHSV_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA1_202.append(SHSV_imgA1A1_9[i][j])

# %%
SA1_302= list()
SA2_102 = list()
for i in range(SHSV_imgA1A2_9shape[0]): 
     for j in range(SHSV_imgA1A2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_302.append(SHSV_imgA1A2_9[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   SA2_102.append(SHSV_imgA1A2_9[i][j])

# %%
SA1_402= list()
SA3_102 = list()
for i in range(SHSV_imgA1A3_9.shape[0]): 
     for j in range(SHSV_imgA1A3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_402.append(SHSV_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_102.append(SHSV_imgA1A3_9[i][j])

# %%
SA1_502= list()
SA3_5102= list()
for i in range(SHSV_imgA1A3_59.shape[0]): 
     for j in range(SHSV_imgA1A3_59.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(SHSV_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5102.append(SHSV_imgA1A3_59[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(SHSV_imgA1A4_9.shape[0]): 
     for j in range(SHSV_imgA1A4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_602.append(SHSV_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(SHSV_imgA1A4_9[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(SHSV_imgA1B1_9.shape[0]): 
     for j in range(SHSV_imgA1B1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_702.append(SHSV_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_102.append(SHSV_imgA1B1_9[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_9.shape[0]): 
     for j in range(SHSV_imgA1B2_.9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(SHSV_imgA1B2_9[i][j])

# %%
SA1_902= list()
SB3_102= list()
for i in range(SHSV_imgA1B3_9.shape[0]): 
     for j in range(SHSV_imgA1B3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_9[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SHSV_imgA1B4_9.shape[0]): 
     for j in range(SHSV_imgA1B4_.9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SHSV_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SHSV_imgA1B4_9[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(SHSV_imgA1C1_9.shape[0]): 
     for j in range(SHSV_imgA1C1_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(SHSV_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(SHSV_imgA1C1_9[i][j])

# %%
SA1_1202= list()
SC2_102 = list()
for i in range(SHSV_imgA1C2_9.shape[0]): 
     for j in range(SHSV_imgA1C2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1202.append(SHSV_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_9[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(SHSV_imgA1C3_9.shape[0]): 
     for j in range(SHSV_imgA1C3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(SHSV_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_102.append(SHSV_imgA1C3_9[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(SHSV_imgA1C4_9.shape[0]): 
     for j in range(SHSV_imgA1C4_9shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(SHSV_imgA1C4_9[i][j])

# %%
SA1_1502= list()
SD2_102 = list()
for i in range(SHSV_imgA1C2_9.shape[0]): 
     for j in range(SHSV_imgA1D2_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1502.append(SSV_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_102.append(SHSV_imgA1D2_9[i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(SHSV_imgA1D3_9.shape[0]): 
          for j in range(SHSV_imgA1D3_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_9[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_9.shape[0]): 
     for j in range(SHSV_imgA1D4_9.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_102.append(SHSV_imgA1D4_9[i][j])

# %% [markdown]
# ### Img 10

# %%
SA1_102= list()
SA1_202 = list()
for i in range(SHSV_imgA1A1_10.shape[0]): 
     for j in range(SHSV_imgA1A1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_102.append(SHSV_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA1_202.append(SHSV_imgA1A1_10[i][j])

# %%
SA1_302= list()
SA2_102 = list()
for i in range(SHSV_imgA1A2_10.shape[0]): 
     for j in range(SHSV_imgA1A2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_302.append(SHSV_imgA1A2_10[i][j])
                if 1770<i<1880 and  2015<j<2145 :
                   SA2_102.append(SHSV_imgA1A2_10i][j])

# %%
SA1_402= list()
SA3_102 = list()
for i in range(SHSV_imgA1A3_10.shape[0]): 
     for j in range(SHSV_imgA1A3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_402.append(SHSV_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_102.append(SHSV_imgA1A3_10[i][j])

# %%
SA1_502= list()
SA3_5102= list()
     for j in range(SHSV_imgA1A3_510.shape[1]): 
          for j in range(SHSV_imgA1A3_510.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_502.append(SHSV_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA3_5102.append(SHSV_imgA1A3_510[i][j])

# %%
SA1_602= list()
SA4_102 = list()
for i in range(SHSV_imgA1A4_10.shape[0]): 
     for j in range(SHSV_imgA1A4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_602.append(SHSV_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SA4_102.append(SHSV_imgA1A4_10[i][j])

# %%
SA1_702= list()
SB1_102= list()
for i in range(SHSV_imgA1B1_10.shape[0]): 
     for j in range(SHSV_imgA1B1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_702.append(SHSV_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB1_102.append(SHSV_imgA1B1_10[i][j])

# %%
SA1_802= list()
SB2_102 = list()
for i in range(SHSV_imgA1B2_10.shape[0]): 
     for j in range(SHSV_imgA1B2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_802.append(SHSV_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB2_102.append(SHSV_imgA1B2_10[i][j])

# %%
SA1_902= list()
SB3_102= list()
for i in range(SHSV_imgA1B3_10.shape[0]): 
     for j in range(SHSV_imgA1B3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_902.append(SHSV_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB3_102.append(SHSV_imgA1B3_10[i][j])

# %%
SA1_1002= list()
SB4_102 = list()
for i in range(SSV_imgA1B4_10.shape[0]): 
     for j in range(SHSV_imgA1B4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1002.append(SHSV_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SB4_102.append(SHSV_imgA1B4_10[i][j])

# %%
SA1_1102= list()
SC1_102 = list()
for i in range(SHSV_imgA1C1_10.shape[0]): 
     for j in range(SHSV_imgA1C1_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1102.append(SHSV_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC1_102.append(SHSV_imgA1C1_10[i][j])

# %%
SA1_1202= list()
SC2_102 = list()
for i in range(SHSV_imgA1C2_10.shape[0]): 
     for j in range(SHSV_imgA1C2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1202.append(SHSV_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC2_102.append(SHSV_imgA1C2_10[i][j])

# %%
SA1_1302= list()
SC3_102 = list()
for i in range(SHSV_imgA1C3_10.shape[0]): 
     for j in range(SHSV_imgA1C3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1302.append(SHSV_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC3_102.append(SHSV_imgA1C3_10[i][j])

# %%
SA1_1402= list()
SC4_102 = list()
for i in range(SHSV_imgA1C4_10.shape[0]): 
     for j in range(SHSV_imgA1C4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SC4_102.append(SHSV_imgA1C4_10[i][j])

# %%
SA1_1502= list()
SD2_102 = list()
for i in range(SHSV_imgA1C2_10.shape[0]): 
     for j in range(SHSV_imgA1D2_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1502.append(2HSV_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD2_102.append(SHSV_imgA1D2_10[i][j])

# %%
SA1_1602= list()
SD3_102 = list()
for i in range(SHSV_imgA1D3_10.shape[0]): 
          for j in range(SHSV_imgA1D3_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1602.append(SHSV_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD3_102.append(SHSV_imgA1D3_10[i][j])

# %%
SA1_1702= list()
SD4_102 = list()
for i in range(SHSV_imgA1D4_10.shape[0]): 
     for j in range(SHSV_imgA1D4_10.shape[1]): 
                if 1770<i<1880 and 1700<j<1830 :
                    SA1_1402.append(SHSV_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                    SD4_102.append(SHSV_imgA1D4_10[i][j])

# %% [markdown]
# #6. หาค่า Mean

# %%
import numpy as np

# %% [markdown]
# ##Set1

# %% [markdown]
# ###RGB

# %%
S1meanrefA1_1 = list()
S1meanA1_2 = list()
for i in range(S1RGB_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1.append(S1RGB_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_2.append(S1RGB_imgA1A1_1[i][j])  
S1meanrefA1_1 = np.array(S1meanrefA1_1)
S1meanA1_2 = np.array(S1meanA1_2)

S1rgbrefA1_1 = list()
S1rgbA1_2 = list()
for i in range(3):
    S1rgbrefA1_1.append(S1meanrefA1_1[:,i].mean())
    S1rgbA1_2.append(S1meanA1_2[:,i].mean())
S1rgbrefA1_1,S1rgbA1_2

# %%
S1meanrefA1_3 = list()
S1meanA2_1 = list()
for i in range(S1RGB_imgA1A2_1.shape[0]): 
     for j in range(S1RGB_imgA1A2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_3.append(S1RGB_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_1.append(S1RGB_imgA1A2_1[i][j])  
S1meanrefA1_3 = np.array(S1meanrefA1_3)
S1meanA2_1 = np.array(S1meanA2_1)

S1rgbrefA1_3 = list()
S1rgbA2_1 = list()
for i in range(3):
    S1rgbrefA1_3.append(S1meanrefA1_3[:,i].mean())
    S1rgbA2_1.append(S1meanA2_1[:,i].mean())

# %%
S1meanrefA1_4 = list()
S1meanA3_1 = list()
for i in range(S1RGB_imgA1A3_1.shape[0]): 
     for j in range(S1RGB_imgA1A3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_4.append(S1RGB_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_1.append(S1RGB_imgA1A3_1[i][j])  
S1meanrefA1_4 = np.array(S1meanrefA1_4)
S1meanA3_1 = np.array(S1meanA3_1)

S1rgbrefA1_4 = list()
S1rgbA3_1 = list()
for i in range(3):
    S1rgbrefA1_4.append(S1meanrefA1_4[:,i].mean())
    S1rgbA3_1.append(S1meanA3_1[:,i].mean())

# %%
S1meanrefA1_5 = list()
S1meanA3_51 = list()
for i in range(S1RGB_imgA1A3_51.shape[0]): 
     for j in range(S1RGB_imgA1A3_51.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_5.append(S1RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_51.append(S1RGB_imgA1A3_51[i][j])  
S1meanrefA1_5 = np.array(S1meanrefA1_5)
S1meanA3_51 = np.array(S1meanA3_51)

S1rgbrefA1_5 = list()
S1rgbA3_51 = list()
for i in range(3):
    S1rgbrefA1_5.append(S1meanrefA1_5[:,i].mean())
    S1rgbA3_51.append(S1meanA3_51[:,i].mean())

# %%
S1meanrefA1_6 = list()
S1meanA4_1 = list()
for i in range(S1RGB_imgA1A4_1.shape[0]): 
     for j in range(S1RGB_imgA1A4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_6.append(S1RGB_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_1.append(S1RGB_imgA1A4_1[i][j])  
S1meanrefA1_6 = np.array(S1meanrefA1_6)
S1meanA4_1 = np.array(S1meanA4_1)

S1rgbrefA1_6 = list()
S1rgbA4_1 = list()
for i in range(3):
    S1rgbrefA1_6.append(S1meanrefA1_6[:,i].mean())
    S1rgbA4_1.append(S1meanA4_1[:,i].mean())

# %%
S1meanrefA1_7 = list()
S1meanB1_1 = list()
for i in range(S1RGB_imgA1B1_1.shape[0]): 
     for j in range(S1RGB_imgA1B1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_7.append(S1RGB_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_1.append(S1RGB_imgA1B1_1[i][j])  
S1meanrefA1_7 = np.array(S1meanrefA1_7)
S1meanB1_1 = np.array(S1meanB1_1)

S1rgbrefA1_7 = list()
S1rgbB1_1 = list()
for i in range(3):
    S1rgbrefA1_7.append(S1meanrefA1_7[:,i].mean())
    S1rgbB1_1.append(S1meanB1_1[:,i].mean())

# %%
S1meanrefA1_8 = list()
S1meanB2_1 = list()
for i in range(S1RGB_imgA1B2_1.shape[0]): 
     for j in range(S1RGB_imgA1B2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_8.append(S1RGB_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_1.append(S1RGB_imgA1B2_1[i][j])  
S1meanrefA1_8 = np.array(S1meanrefA1_8)
S1meanB2_1 = np.array(S1meanB2_1)

S1rgbrefA1_8 = list()
S1rgbB2_1 = list()
for i in range(3):
    S1rgbrefA1_8.append(S1meanrefA1_8[:,i].mean())
    S1rgbB2_1.append(S1meanB2_1[:,i].mean())

# %%
S1meanrefA1_9 = list()
S1meanB3_1 = list()
for i in range(S1RGB_imgA1B3_1.shape[0]): 
     for j in range(S1RGB_imgA1B3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_9.append(S1RGB_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_1.append(S1RGB_imgA1B3_1[i][j])  
S1meanrefA1_9 = np.array(S1meanrefA1_9)
S1meanB3_1 = np.array(S1meanB3_1)

S1rgbrefA1_9 = list()
S1rgbB3_1 = list()
for i in range(3):
    S1rgbrefA1_9.append(S1meanrefA1_9[:,i].mean())
    S1rgbB3_1.append(S1meanB3_1[:,i].mean())

# %%
S1meanrefA1_10 = list()
S1meanB4_1 = list()
for i in range(S1RGB_imgA1B4_1.shape[0]): 
     for j in range(S1RGB_imgA1B4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_10.append(S1RGB_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_1.append(S1RGB_imgA1B4_1[i][j])  
S1meanrefA1_10 = np.array(S1meanrefA1_10)
S1meanB4_1 = np.array(S1meanB4_1)

S1rgbrefA1_10 = list()
S1rgbB4_1 = list()
for i in range(3):
    S1rgbrefA1_10.append(S1meanrefA1_10[:,i].mean())
    S1rgbB4_1.append(S1meanB4_1[:,i].mean())

# %%
S1meanrefA1_11 = list()
S1meanC1_1 = list()
for i in range(S1RGB_imgA1C1_1.shape[0]): 
     for j in range(S1RGB_imgA1C1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_11.append(S1RGB_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_1.append(S1RGB_imgA1C1_1[i][j])  
S1meanrefA1_11 = np.array(S1meanrefA1_11)
S1meanC1_1 = np.array(S1meanC1_1)

S1rgbrefA1_11 = list()
S1rgbC1_1 = list()
for i in range(3):
    S1rgbrefA1_11.append(S1meanrefA1_11[:,i].mean())
    S1rgbC1_1.append(S1meanC1_1[:,i].mean())

# %%
S1meanrefA1_12 = list()
S1meanC2_1 = list()
for i in range(S1RGB_imgA1C2_1.shape[0]): 
     for j in range(S1RGB_imgA1C2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_12.append(S1RGB_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_1.append(S1RGB_imgA1C2_1[i][j])  
S1meanrefA1_12 = np.array(S1meanrefA1_12)
S1meanC2_1 = np.array(S1meanC2_1)

S1rgbrefA1_12 = list()
S1rgbC2_1 = list()
for i in range(3):
    S1rgbrefA1_12.append(S1meanrefA1_12[:,i].mean())
    S1rgbC2_1.append(S1meanC2_1[:,i].mean())

# %%
S1meanrefA1_13 = list()
S1meanC3_1 = list()
for i in range(S1RGB_imgA1C3_1.shape[0]): 
     for j in range(S1RGB_imgA1C3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_13.append(S1RGB_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_1.append(S1RGB_imgA1C3_1[i][j])  
S1meanrefA1_13 = np.array(S1meanrefA1_13)
S1meanC3_1 = np.array(S1meanC3_1)

S1rgbrefA1_13 = list()
S1rgbC3_1 = list()
for i in range(3):
    S1rgbrefA1_13.append(S1meanrefA1_13[:,i].mean())
    S1rgbC3_1.append(S1meanC3_1[:,i].mean())

# %%
S1meanrefA1_14 = list()
S1meanC4_1 = list()
for i in range(S1RGB_imgA1C4_1.shape[0]): 
     for j in range(S1RGB_imgA1C4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_14.append(S1RGB_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_1.append(S1RGB_imgA1C4_1[i][j])  
S1meanrefA1_14 = np.array(S1meanrefA1_14)
S1meanC4_1 = np.array(S1meanC4_1)

S1rgbrefA1_14 = list()
S1rgbC4_1 = list()
for i in range(3):
    S1rgbrefA1_14.append(S1meanrefA1_14[:,i].mean())
    S1rgbC4_1.append(S1meanC4_1[:,i].mean())

# %%
S1meanrefA1_15 = list()
S1meanD2_1 = list()
for i in range(S1RGB_imgA1D2_1.shape[0]): 
     for j in range(S1RGB_imgA1D2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_15.append(S1RGB_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_1.append(S1RGB_imgA1D2_1[i][j])  
S1meanrefA1_15 = np.array(S1meanrefA1_15)
S1meanD2_1 = np.array(S1meanD2_1)

S1rgbrefA1_15 = list()
S1rgbD2_1 = list()
for i in range(3):
    S1rgbrefA1_15.append(S1meanrefA1_15[:,i].mean())
    S1rgbD2_1.append(S1meanD2_1[:,i].mean())

# %%
S1meanrefA1_16 = list()
S1meanD3_1 = list()
for i in range(S1RGB_imgA1D3_1.shape[0]): 
     for j in range(S1RGB_imgA1D3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_16.append(S1RGB_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_1.append(S1RGB_imgA1D3_1[i][j])  
S1meanrefA1_16 = np.array(S1meanrefA1_16)
S1meanD3_1 = np.array(S1meanD3_1)

S1rgbrefA1_16 = list()
S1rgbD3_1 = list()
for i in range(3):
    S1rgbrefA1_16.append(S1meanrefA1_16[:,i].mean())
    S1rgbD3_1.append(S1meanD3_1[:,i].mean())

# %%
S1meanrefA1_17= list()
S1meanD4_1 = list()
for i in range(S1RGB_imgA1D4_1.shape[0]): 
     for j in range(S1RGB_imgA1D4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_17.append(S1RGB_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_1.append(S1RGB_imgA1D4_1[i][j])  
S1meanrefA1_17 = np.array(S1meanrefA1_14)
S1meanD4_1 = np.array(S1meanD4_1)

S1rgbrefA1_17 = list()
S1rgbD4_1 = list()
for i in range(3):
    S1rgbrefA1_17.append(S1meanrefA1_17[:,i].mean())
    S1rgbD4_1.append(S1meanD4_1[:,i].mean())

# %% [markdown]
# ###Img 2

# %%
S1meanrefA1_102 = list()
S1meanA1_202 = list()
for i in range(S1RGB_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_102.append(S1RGB_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_202.append(S1RGB_imgA1A1_2[i][j])  
S1meanrefA1_102 = np.array(S1meanrefA1_102)
S1meanA1_202 = np.array(S1meanA1_202)

S1rgbrefA1_102 = list()
S1rgbA1_202 = list()
for i in range(3):
    S1rgbrefA1_102.append(S1meanrefA1_102[:,i].mean())
    S1rgbA1_202.append(S1meanA1_202[:,i].mean())
S1rgbrefA1_102,S1rgbA1_202

# %%
S1meanrefA1_302 = list()
S1meanA2_102 = list()
for i in range(S1RGB_imgA1A2_2.shape[0]): 
     for j in range(S1RGB_imgA1A2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_302.append(S1RGB_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_102.append(S1RGB_imgA1A2_2[i][j])  
S1meanrefA1_302 = np.array(S1meanrefA1_302)
S1meanA2_102 = np.array(S1meanA2_102)

S1rgbrefA1_302 = list()
S1rgbA2_102 = list()
for i in range(3):
    S1rgbrefA1_302.append(S1meanrefA1_302[:,i].mean())
    S1rgbA2_102.append(S1meanA2_102[:,i].mean())

# %%
S1meanrefA1_402 = list()
S1meanA3_102 = list()
for i in range(S1RGB_imgA1A3_2.shape[0]): 
     for j in range(S1RGB_imgA1A3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_402.append(S1RGB_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_102.append(S1RGB_imgA1A3_2[i][j])  
S1meanrefA1_402 = np.array(S1meanrefA1_402)
S1meanA3_102 = np.array(S1meanA3_102)

S1rgbrefA1_402 = list()
S1rgbA3_102 = list()
for i in range(3):
    S1rgbrefA1_402.append(S1meanrefA1_402[:,i].mean())
    S1rgbA3_102.append(S1meanA3_102[:,i].mean())

# %%
S1meanrefA1_02 = list()
S1meanA3_5102 = list()
for i in range(S1RGB_imgA1A3_52.shape[0]): 
     for j in range(S1RGB_imgA1A3_52.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_502.append(S1RGB_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5102.append(S1RGB_imgA1A3_52[i][j])  
S1meanrefA1_502 = np.array(S1meanrefA1_502)
S1meanA3_5102 = np.array(S1meanA3_5102)

S1rgbrefA1_502 = list()
S1rgbA3_5102 = list()
for i in range(3):
    S1rgbrefA1_502.append(S1meanrefA1_502[:,i].mean())
    S1rgbA3_5102.append(S1meanA3_5102[:,i].mean())

# %%
S1meanrefA1_602 = list()
S1meanA4_102 = list()
for i in range(S1RGB_imgA1A4_2.shape[0]): 
     for j in range(S1RGB_imgA1A4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_602.append(S1RGB_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_102.append(S1RGB_imgA1A4_2[i][j])  
S1meanrefA1_602 = np.array(S1meanrefA1_602)
S1meanA4_102 = np.array(S1meanA4_102)

S1rgbrefA1_602 = list()
S1rgbA4_102 = list()
for i in range(3):
    S1rgbrefA1_602.append(S1meanrefA1_602[:,i].mean())
    S1rgbA4_102.append(S1meanA4_102[:,i].mean())

# %%
S1meanrefA1_702 = list()
S1meanB1_102 = list()
for i in range(S1RGB_imgA1B1_202.shape[0]): 
     for j in range(S1RGB_imgA1B1_202.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_702.append(S1RGB_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_102.append(S1RGB_imgA1B1_2[i][j])  
S1meanrefA1_702 = np.array(S1meanrefA1_702)
S1meanB1_102 = np.array(S1meanB1_102)

S1rgbrefA1_7 02= list()
S1rgbB1_102 = list()
for i in range(3):
    S1rgbrefA1_702.append(S1meanrefA1_702[:,i].mean())
    S1rgbB1_102.append(S1meanB1_102[:,i].mean())

# %%
S1meanrefA1_802 = list()
S1meanB2_102 = list()
for i in range(S1RGB_imgA1B2_2.shape[0]): 
     for j in range(S1RGB_imgA1B2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_802.append(S1RGB_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_102.append(S1RGB_imgA1B2_2[i][j])  
S1meanrefA1_802 = np.array(S1meanrefA1_802)
S1meanB2_102 = np.array(S1meanB2_102)

S1rgbrefA1_802 = list()
S1rgbB2_102 = list()
for i in range(3):
    S1rgbrefA1_802.append(S1meanrefA1_802[:,i].mean())
    S1rgbB2_102.append(S1meanB2_102[:,i].mean())

# %%
S1meanrefA1_902 = list()
S1meanB3_102 = list()
for i in range(S1RGB_imgA1B3_2.shape[0]): 
     for j in range(S1RGB_imgA1B3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_902.append(S1RGB_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_102.append(S1RGB_imgA1B3_2[i][j])  
S1meanrefA1_902 = np.array(S1meanrefA1_902)
S1meanB3_102 = np.array(S1meanB3_102)

S1rgbrefA1_902 = list()
S1rgbB3_102 = list()
for i in range(3):
    S1rgbrefA1_902.append(S1meanrefA1_902[:,i].mean())
    S1rgbB3_102.append(S1meanB3_102[:,i].mean())

# %%
S1meanrefA1_1002 = list()
S1meanB4_102 = list()
for i in range(S1RGB_imgA1B4_2.shape[0]): 
     for j in range(S1RGB_imgA1B4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1002.append(S1RGB_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_102.append(S1RGB_imgA1B4_2[i][j])  
S1meanrefA1_1002 = np.array(S1meanrefA1_1002)
S1meanB4_102 = np.array(S1meanB4_102)

S1rgbrefA1_1002 = list()
S1rgbB4_102 = list()
for i in range(3):
    S1rgbrefA1_1002.append(S1meanrefA1_1002[:,i].mean())
    S1rgbB4_102.append(S1meanB4_102[:,i].mean())

# %%
S1meanrefA1_1102 = list()
S1meanC1_102 = list()
for i in range(S1RGB_imgA1C1_2.shape[0]): 
     for j in range(S1RGB_imgA1C1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1102.append(S1RGB_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_102.append(S1RGB_imgA1C1_2[i][j])  
S1meanrefA1_1102 = np.array(S1meanrefA1_1102)
S1meanC1_102 = np.array(S1meanC1_102)

S1rgbrefA1_1102 = list()
S1rgbC1_102 = list()
for i in range(3):
    S1rgbrefA1_1102.append(S1meanrefA1_1102[:,i].mean())
    S1rgbC1_102.append(S1meanC1_102[:,i].mean())

# %%
S1meanrefA1_1202 = list()
S1meanC2_102 = list()
for i in range(S1RGB_imgA1C2_2.shape[0]): 
     for j in range(S1RGB_imgA1C2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1202.append(S1RGB_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_102.append(S1RGB_imgA1C2_2[i][j])  
S1meanrefA1_1202 = np.array(S1meanrefA1_1202)
S1meanC2_102 = np.array(S1meanC2_102)

S1rgbrefA1_1202 = list()
S1rgbC2_102 = list()
for i in range(3):
    S1rgbrefA1_1202.append(S1meanrefA1_1202[:,i].mean())
    S1rgbC2_102.append(S1meanC2_102[:,i].mean())

# %%
S1meanrefA1_1302 = list()
S1meanC3_102 = list()
for i in range(S1RGB_imgA1C3_2.shape[0]): 
     for j in range(S1RGB_imgA1C3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1302.append(S1RGB_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_102.append(S1RGB_imgA1C3_2[i][j])  
S1meanrefA1_1302 = np.array(S1meanrefA1_1302)
S1meanC3_102 = np.array(S1meanC3_102)

S1rgbrefA1_1302 = list()
S1rgbC3_102 = list()
for i in range(3):
    S1rgbrefA1_1302.append(S1meanrefA1_1302[:,i].mean())
    S1rgbC3_102.append(S1meanC3_102[:,i].mean())

# %%
S1meanrefA1_1402 = list()
S1meanC4_102 = list()
for i in range(S1RGB_imgA1C4_2.shape[0]): 
     for j in range(S1RGB_imgA1C4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1402.append(S1RGB_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_102.append(S1RGB_imgA1C4_2[i][j])  
S1meanrefA1_1402 = np.array(S1meanrefA1_1402)
S1meanC4_102 = np.array(S1meanC4_102)

S1rgbrefA1_1402 = list()
S1rgbC4_102 = list()
for i in range(3):
    S1rgbrefA1_1402.append(S1meanrefA1_1402[:,i].mean())
    S1rgbC4_102.append(S1meanC4_102[:,i].mean())

# %%
S1meanrefA1_1502 = list()
S1meanD2_102 = list()
for i in range(S1RGB_imgA1D2_2.shape[0]): 
     for j in range(S1RGB_imgA1D2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1502.append(S1RGB_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_102.append(S1RGB_imgA1D2_2[i][j])  
S1meanrefA1_1502 = np.array(S1meanrefA1_1502)
S1meanD2_102 = np.array(S1meanD2_102)

S1rgbrefA1_1502 = list()
S1rgbD2_102 = list()
for i in range(3):
    S1rgbrefA1_1502.append(S1meanrefA1_1502[:,i].mean())
    S1rgbD2_102.append(S1meanD2_102[:,i].mean())

# %%
S1meanrefA1_1602 = list()
S1meanD3_102 = list()
for i in range(S1RGB_imgA1D3_2.shape[0]): 
     for j in range(S1RGB_imgA1D3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1602.append(S1RGB_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_102.append(S1RGB_imgA1D3_2[i][j])  
S1meanrefA1_1602 = np.array(S1meanrefA1_1602)
S1meanD3_102 = np.array(S1meanD3_102

S1rgbrefA1_1602 = list()
S1rgbD3_102 = list()
for i in range(3):
    S1rgbrefA1_1602.append(S1meanrefA1_1602[:,i].mean())
    S1rgbD3_102.append(S1meanD3_102[:,i].mean())

# %%
S1meanrefA1_1702= list()
S1meanD4_102 = list()
for i in range(S1RGB_imgA1D4_2.shape[0]): 
     for j in range(S1RGB_imgA1D4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1702.append(S1RGB_imgA1D4_2i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_102.append(S1RGB_imgA1D4_2[i][j])  
S1meanrefA1_1702 = np.array(S1meanrefA1_1402)
S1meanD4_102 = np.array(S1meanD4_102)

S1rgbrefA1_1702 = list()
S1rgbD4_102 = list()
for i in range(3):
    S1rgbrefA1_1702.append(S1meanrefA1_1702[:,i].mean())
    S1rgbD4_102.append(S1meanD4_102[:,i].mean())

# %% [markdown]
# ###Img 3

# %%
S1meanrefA1_103 = list()
S1meanA1_203 = list()
for i in range(S1RGB_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1.append(S1RGB_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_2.append(S1RGB_imgA1A1_3[i][j])  
S1meanrefA1_103 = np.array(S1meanrefA1_103)
S1meanA1_203 = np.array(S1meanA1_203)

S1rgbrefA1_103 = list()
S1rgbA1_203 = list()
for i in range(3):
    S1rgbrefA1_103.append(S1meanrefA1_103[:,i].mean())
    S1rgbA1_203.append(S1meanA1_203[:,i].mean())
S1rgbrefA1_103,S1rgbA1_2 03

# %%
S1meanrefA1_303 = list()
S1meanA2_103 = list()
for i in range(S1RGB_imgA1A2_3.shape[0]): 
     for j in range(S1RGB_imgA1A2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_303.append(S1RGB_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_103.append(S1RGB_imgA1A2_3[i][j])  
S1meanrefA1_303 = np.array(S1meanrefA1_303)
S1meanA2_103 = np.array(S1meanA2_103)

S1rgbrefA1_303 = list()
S1rgbA2_103 = list()
for i in range(3):
    S1rgbrefA1_303.append(S1meanrefA1_303[:,i].mean())
    S1rgbA2_103.append(S1meanA2_103[:,i].mean())

# %%
S1meanrefA1_403 = list()
S1meanA3_103 = list()
for i in range(S1RGB_imgA1A3_3.shape[0]): 
     for j in range(S1RGB_imgA1A3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_403.append(S1RGB_imgA1A33_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_103.append(S1RGB_imgA1A3_3[i][j])  
S1meanrefA1_403= np.array(S1meanrefA1_403 )
S1meanA3_103 = np.array(S1meanA3_103 )

S1rgbrefA1_403  = list()
S1rgbA3_103  = list()
for i in range(3):
    S1rgbrefA1_403 .append(S1meanrefA1_403[:,i].mean())
    S1rgbA3_103 .append(S1meanA3_103 [:,i].mean())

# %%
S1meanrefA1_503  = list()
S1meanA3_5103  = list()
for i in range(S1RGB_imgA1A3_53.shape[0]): 
     for j in range(S1RGB_imgA1A3_53.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_503 .append(S1RGB_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5103 .append(S1RGB_imgA1A3_53[i][j])  
S1meanrefA1_503  = np.array(S1meanrefA1_503 )
S1meanA3_5103  = np.array(S1meanA3_5103 )

S1rgbrefA1_503  = list()
S1rgbA3_5103  = list()
for i in range(3):
    S1rgbrefA1_503 .append(S1meanrefA1_503 [:,i].mean())
    S1rgbA3_5103 .append(S1meanA3_5103 [:,i].mean())

# %%
S1meanrefA1_603  = list()
S1meanA4_103  = list()
for i in range(S1RGB_imgA1A4_3.shape[0]): 
     for j in range(S1RGB_imgA1A4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_603 .append(S1RGB_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_103 .append(S1RGB_imgA1A4_3[i][j])  
S1meanrefA1_603  = np.array(S1meanrefA1_603 )
S1meanA4_103  = np.array(S1meanA4_103 )

S1rgbrefA1_603  = list()
S1rgbA4_103  = list()
for i in range(3):
    S1rgbrefA1_603 .append(S1meanrefA1_603[:,i].mean())
    S1rgbA4_103 .append(S1meanA4_103 [:,i].mean())

# %%
S1meanrefA1_703  = list()
S1meanB1_103  = list()
for i in range(S1RGB_imgA1B1_3.shape[0]): 
     for j in range(S1RGB_imgA1B1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_703 .append(S1RGB_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_103 .append(S1RGB_imgA1B1_3[i][j])  
S1meanrefA1_703  = np.array(S1meanrefA1_73)
S1meanB1_103  = np.array(S1meanB1_103)

S1rgbrefA1_703  = list()
S1rgbB1_103  = list()
for i in range(3):
    S1rgbrefA1_703 .append(S1meanrefA1_703 [:,i].mean())
    S1rgbB1_103 .append(S1meanB1_103 [:,i].mean())

# %%
S1meanrefA1_803  = list()
S1meanB2_103  = list()
for i in range(S1RGB_imgA1B2_3.shape[0]): 
     for j in range(S1RGB_imgA1B2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_803 .append(S1RGB_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_103 .append(S1RGB_imgA1B2_3[i][j])  
S1meanrefA1_803  = np.array(S1meanrefA1_803 )
S1meanB2_103  = np.array(S1meanB2_103 )

S1rgbrefA1_803  = list()
S1rgbB2_103  = list()
for i in range(3):
    S1rgbrefA1_803 .append(S1meanrefA1_803 [:,i].mean())
    S1rgbB2_103 .append(S1meanB2_103 [:,i].mean())

# %%
S1meanrefA1_903  = list()
S1meanB3_103  = list()
for i in range(S1RGB_imgA1B3_3.shape[0]): 
     for j in range(S1RGB_imgA1B3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_903 .append(S1RGB_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_103 .append(S1RGB_imgA1B3_3[i][j])  
S1meanrefA1_903  = np.array(S1meanrefA1_903 )
S1meanB3_103  = np.array(S1meanB3_103 )

S1rgbrefA1_903  = list()
S1rgbB3_103  = list()
for i in range(3):
    S1rgbrefA1_903 .append(S1meanrefA1_903 [:,i].mean())
    S1rgbB3_103 .append(S1meanB3_103 [:,i].mean())

# %%
S1meanrefA1_1003  = list()
S1meanB4_103  = list()
for i in range(S1RGB_imgA1B4_3.shape[0]): 
     for j in range(S1RGB_imgA1B4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1003 .append(S1RGB_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_103 .append(S1RGB_imgA1B4_3[i][j])  
S1meanrefA1_1003  = np.array(S1meanrefA1_1003 )
S1meanB4_103  = np.array(S1meanB4_103 )

S1rgbrefA1_1003  = list()
S1rgbB4_103  = list()
for i in range(3):
    S1rgbrefA1_1003 .append(S1meanrefA1_1003[:,i].mean())
    S1rgbB4_103 .append(S1meanB4_103 [:,i].mean())

# %%
S1meanrefA1_1103  = list()
S1meanC1_103  = list()
for i in range(S1RGB_imgA1C1_3.shape[0]): 
     for j in range(S1RGB_imgA1C1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1103 .append(S1RGB_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_103 .append(S1RGB_imgA1C1_3[i][j])  
S1meanrefA1_1103  = np.array(S1meanrefA1_1103 )
S1meanC1_103  = np.array(S1meanC1_103 )

S1rgbrefA1_1103  = list()
S1rgbC1_103  = list()
for i in range(3):
    S1rgbrefA1_1103.append(S1meanrefA1_1103 [:,i].mean())
    S1rgbC1_103.append(S1meanC1_103 [:,i].mean())

# %%
S1meanrefA1_1203  = list()
S1meanC2_103 = list()
for i in range(S1RGB_imgA1C2_3.shape[0]): 
     for j in range(S1RGB_imgA1C2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1203.append(S1RGB_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_103.append(S1RGB_imgA1C2_3[i][j])  
S1meanrefA1_1203 = np.array(S1meanrefA1_1203)
S1meanC2_103 = np.array(S1meanC2_103)

S1rgbrefA1_1203 = list()
S1rgbC2_103 = list()
for i in range(3):
    S1rgbrefA1_1203.append(S1meanrefA1_1203[:,i].mean())
    S1rgbC2_103.append(S1meanC2_103[:,i].mean())

# %%
S1meanrefA1_1303 = list()
S1meanC3_103 = list()
for i in range(S1RGB_imgA1C3_3.shape[0]): 
     for j in range(S1RGB_imgA1C3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1303.append(S1RGB_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_103append(S1RGB_imgA1C3_3i][j])  
S1meanrefA1_1303 = np.array(S1meanrefA1_1303)
S1meanC3_103 = np.array(S1meanC3_103)

S1rgbrefA1_1303 = list()
S1rgbC3_103 = list()
for i in range(3):
    S1rgbrefA1_1303.append(S1meanrefA1_1303[:,i].mean())
    S1rgbC3_103.append(S1meanC3_103[:,i].mean())

# %%
S1meanrefA1_1403 = list()
S1meanC4_103 = list()
for i in range(S1RGB_imgA1C4_3.shape[0]): 
     for j in range(S1RGB_imgA1C4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1403.append(S1RGB_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_103.append(S1RGB_imgA1C4_3[i][j])  
S1meanrefA1_1403 = np.array(S1meanrefA1_1403)
S1meanC4_103 = np.array(S1meanC4_103)

S1rgbrefA1_1403 = list()
S1rgbC4_103 = list()
for i in range(3):
    S1rgbrefA1_1403.append(S1meanrefA1_1403[:,i].mean())
    S1rgbC4_103.append(S1meanC4_103[:,i].mean())

# %%
S1meanrefA1_1503 = list()
S1meanD2_103 = list()
for i in range(S1RGB_imgA1D2_3.shape[0]): 
     for j in range(S1RGB_imgA1D2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1503.append(S1RGB_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_103.append(S1RGB_imgA1D2_3[i][j])  
S1meanrefA1_1503 = np.array(S1meanrefA1_1503)
S1meanD2_103 = np.array(S1meanD2_103)

S1rgbrefA1_1503 = list()
S1rgbD2_103 = list()
for i in range(3):
    S1rgbrefA1_1503.append(S1meanrefA1_1503[:,i].mean())
    S1rgbD2_103.append(S1meanD2_103[:,i].mean())

# %%
S1meanrefA1_1603 = list()
S1meanD3_103 = list()
for i in range(S1RGB_imgA1D3_3.shape[0]): 
     for j in range(S1RGB_imgA1D3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1603.append(S1RGB_imgA1D33_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_103.append(S1RGB_imgA1D3_3[i][j])  
S1meanrefA1_1603 = np.array(S1meanrefA1_1603)
S1meanD3_103 = np.array(S1meanD3_103)

S1rgbrefA1_1603 = list()
S1rgbD3_103 = list()
for i in range(3):
    S1rgbrefA1_1603.append(S1meanrefA1_1603[:,i].mean())
    S1rgbD3_103.append(S1meanD3_103[:,i].mean())

# %%
S1meanrefA1_1703= list()
S1meanD4_103 = list()
for i in range(S1RGB_imgA1D4_3.shape[0]): 
     for j in range(S1RGB_imgA1D4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1703.append(S1RGB_imgA1D4_3i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_103.append(S1RGB_imgA1D4_3[i][j])  
S1meanrefA1_1703 = np.array(S1meanrefA1_1403)
S1meanD4_103 = np.array(S1meanD4_103)

S1rgbrefA1_1703 = list()
S1rgbD4_103 = list()
for i in range(3):
    S1rgbrefA1_1703.append(S1meanrefA1_1703[:,i].mean())
    S1rgbD4_103.append(S1meanD4_103[:,i].mean())

# %% [markdown]
# ###Img 4

# %%
S1meanrefA1_104 = list()
S1meanA1_204 = list()
for i in range(S1RGB_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_104.append(S1RGB_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_204.append(S1RGB_imgA1A1_4[i][j])  
S1meanrefA1_104 = np.array(S1meanrefA1_104)
S1meanA1_204 = np.array(S1meanA1_204)

S1rgbrefA1_104 = list()
S1rgbA1_204 = list()
for i in range(3):
    S1rgbrefA1_104.append(S1meanrefA1_104[:,i].mean())
    S1rgbA1_204.append(S1meanA1_204[:,i].mean())
S1rgbrefA1_104,S1rgbA1_204

# %%
S1meanrefA1_304 = list()
S1meanA2_104 = list()
for i in range(S1RGB_imgA1A2_4.shape[0]): 
     for j in range(S1RGB_imgA1A2_.44shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_304.append(S1RGB_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_104.append(S1RGB_imgA1A2_4[i][j])  
S1meanrefA1_304 = np.array(S1meanrefA1_304)
S1meanA2_104 = np.array(S1meanA2_104)

S1rgbrefA1_304 = list()
S1rgbA2_104 = list()
for i in range(3):
    S1rgbrefA1_304.append(S1meanrefA1_304[:,i].mean())
    S1rgbA2_104.append(S1meanA2_104[:,i].mean())

# %%
S1meanrefA1_404 = list()
S1meanA3_104 = list()
for i in range(S1RGB_imgA1A3_4.shape[0]): 
     for j in range(S1RGB_imgA1A3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_404.append(S1RGB_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_104.append(S1RGB_imgA1A3_4[i][j])  
S1meanrefA1_404 = np.array(S1meanrefA1_404)
S1meanA3_104 = np.array(S1meanA3_104)

S1rgbrefA1_404 = list()
S1rgbA3_104 = list()
for i in range(3):
    S1rgbrefA1_404.append(S1meanrefA1_404[:,i].mean())
    S1rgbA3_104.append(S1meanA3_104[:,i].mean())

# %%
S1meanrefA1_504 = list()
S1meanA3_5104 = list()
for i in range(S1RGB_imgA1A3_54.shape[0]): 
     for j in range(S1RGB_imgA1A3_54.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_504.append(S1RGB_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5104.append(S1RGB_imgA1A3_54[i][j])  
S1meanrefA1_504 = np.array(S1meanrefA1_5104)
S1meanA3_5104 = np.array(S1meanA3_5104)

S1rgbrefA1_504 = list()
S1rgbA3_5104 = list()
for i in range(3):
    S1rgbrefA1_504.append(S1meanrefA1_504[:,i].mean())
    S1rgbA3_5104.append(S1meanA3_5104[:,i].mean())

# %%
S1meanrefA1_604 = list()
S1meanA4_104 = list()
for i in range(S1RGB_imgA1A4_4.shape[0]): 
     for j in range(S1RGB_imgA1A4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_604.append(S1RGB_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_104.append(S1RGB_imgA1A4_4[i][j])  
S1meanrefA1_604 = np.array(S1meanrefA1_604)
S1meanA4_104 = np.array(S1meanA4_104)

S1rgbrefA1_604 = list()
S1rgbA4_104 = list()
for i in range(3):
    S1rgbrefA1_604.append(S1meanrefA1_604[:,i].mean())
    S1rgbA4_104.append(S1meanA4_104[:,i].mean())

# %%
S1meanrefA1_704 = list()
S1meanB1_104 = list()
for i in range(S1RGB_imgA1B1_4.shape[0]): 
     for j in range(S1RGB_imgA1B1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_704.append(S1RGB_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_104.append(S1RGB_imgA1B1_4[i][j])  
S1meanrefA1_704 = np.array(S1meanrefA1_704)
S1meanB1_104 = np.array(S1meanB1_104)

S1rgbrefA1_704 = list()
S1rgbB1_104 = list()
for i in range(3):
    S1rgbrefA1_704.append(S1meanrefA1_704[:,i].mean())
    S1rgbB1_104.append(S1meanB1_104[:,i].mean())

# %%
S1meanrefA1_804 = list()
S1meanB2_104 = list()
for i in range(S1RGB_imgA1B2_4.shape[0]): 
     for j in range(S1RGB_imgA1B2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_804.append(S1RGB_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_104.append(S1RGB_imgA1B2_4[i][j])  
S1meanrefA1_804 = np.array(S1meanrefA1_804)
S1meanB2_104 = np.array(S1meanB2_104)

S1rgbrefA1_804 = list()
S1rgbB2_104 = list()
for i in range(3):
    S1rgbrefA1_804.append(S1meanrefA1_804[:,i].mean())
    S1rgbB2_104.append(S1meanB2_104[:,i].mean())

# %%
S1meanrefA1_904 = list()
S1meanB3_104 = list()
for i in range(S1RGB_imgA1B3_4.shape[0]): 
     for j in range(S1RGB_imgA1B3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_904.append(S1RGB_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_104.append(S1RGB_imgA1B3_4[i][j])  
S1meanrefA1_904 = np.array(S1meanrefA1_904)
S1meanB3_104 = np.array(S1meanB3_104)

S1rgbrefA1_904 = list()
S1rgbB3_104 = list()
for i in range(3):
    S1rgbrefA1_904.append(S1meanrefA1_904[:,i].mean())
    S1rgbB3_104.append(S1meanB3_104[:,i].mean())

# %%
S1meanrefA1_1004 = list()
S1meanB4_104 = list()
for i in range(S1RGB_imgA1B4_4.shape[0]): 
     for j in range(S1RGB_imgA1B4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1004.append(S1RGB_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_104.append(S1RGB_imgA1B4_4[i][j])  
S1meanrefA1_1004 = np.array(S1meanrefA1_1004)
S1meanB4_104 = np.array(S1meanB4_104)

S1rgbrefA1_1004 = list()
S1rgbB4_104 = list()
for i in range(3):
    S1rgbrefA1_1004.append(S1meanrefA1_1004[:,i].mean())
    S1rgbB4_104.append(S1meanB4_104[:,i].mean())

# %%
S1meanrefA1_1104 = list()
S1meanC1_104 = list()
for i in range(S1RGB_imgA1C1_4.shape[0]): 
     for j in range(S1RGB_imgA1C1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1104.append(S1RGB_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_104.append(S1RGB_imgA1C1_4[i][j])  
S1meanrefA1_1104 = np.array(S1meanrefA1_1104)
S1meanC1_104 = np.array(S1meanC1_104)

S1rgbrefA1_1104 = list()
S1rgbC1_104 = list()
for i in range(3):
    S1rgbrefA1_1104.append(S1meanrefA1_1104[:,i].mean())
    S1rgbC1_104.append(S1meanC1_104[:,i].mean())

# %%
S1meanrefA1_1204 = list()
S1meanC2_104 = list()
for i in range(S1RGB_imgA1C2_4.shape[0]): 
     for j in range(S1RGB_imgA1C2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1204.append(S1RGB_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_104.append(S1RGB_imgA1C2_4[i][j])  
S1meanrefA1_1204 = np.array(S1meanrefA1_1204)
S1meanC2_104 = np.array(S1meanC2_104)

S1rgbrefA1_1204 = list()
S1rgbC2_104 = list()
for i in range(3):
    S1rgbrefA1_1204.append(S1meanrefA1_1204[:,i].mean())
    S1rgbC2_104.append(S1meanC2_104[:,i].mean())

# %%
S1meanrefA1_1304 = list()
S1meanC3_104 = list()
for i in range(S1RGB_imgA1C3_4.shape[0]): 
     for j in range(S1RGB_imgA1C3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1304.append(S1RGB_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_104.append(S1RGB_imgA1C3_4[i][j])  
S1meanrefA1_1304 = np.array(S1meanrefA1_1304)
S1meanC3_104 = np.array(S1meanC3_104)

S1rgbrefA1_1304 = list()
S1rgbC3_104 = list()
for i in range(3):
    S1rgbrefA1_1304.append(S1meanrefA1_1304[:,i].mean())
    S1rgbC3_104.append(S1meanC3_104[:,i].mean())

# %%
S1meanrefA1_1404 = list()
S1meanC4_104 = list()
for i in range(S1RGB_imgA1C4_4.shape[0]): 
     for j in range(S1RGB_imgA1C4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1404.append(S1RGB_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_104.append(S1RGB_imgA1C4_4[i][j])  
S1meanrefA1_1404 = np.array(S1meanrefA1_1404)
S1meanC4_104 = np.array(S1meanC4_104)

S1rgbrefA1_1404 = list()
S1rgbC4_104 = list()
for i in range(3):
    S1rgbrefA1_1404.append(S1meanrefA1_1404[:,i].mean())
    S1rgbC4_104.append(S1meanC4_104[:,i].mean())

# %%
S1meanrefA1_1504 = list()
S1meanD2_104 = list()
for i in range(S1RGB_imgA1D2_4.shape[0]): 
     for j in range(S1RGB_imgA1D2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1504.append(S1RGB_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_104.append(S1RGB_imgA1D2_4[i][j])  
S1meanrefA1_1504 = np.array(S1meanrefA1_1504)
S1meanD2_104 = np.array(S1meanD2_104)

S1rgbrefA1_1504 = list()
S1rgbD2_104 = list()
for i in range(3):
    S1rgbrefA1_1504.append(S1meanrefA1_1504[:,i].mean())
    S1rgbD2_104.append(S1meanD2_104[:,i].mean())

# %%
S1meanrefA1_1604 = list()
S1meanD3_104 = list()
for i in range(S1RGB_imgA1D3_4.shape[0]): 
     for j in range(S1RGB_imgA1D3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1604.append(S1RGB_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_104.append(S1RGB_imgA1D3_4[i][j])  
S1meanrefA1_1604 = np.array(S1meanrefA1_1604)
S1meanD3_104 = np.array(S1meanD3_104)

S1rgbrefA1_1604 = list()
S1rgbD3_104 = list()
for i in range(3):
    S1rgbrefA1_1604.append(S1meanrefA1_1604[:,i].mean())
    S1rgbD3_104.append(S1meanD3_104[:,i].mean())

# %%
S1meanrefA1_1704= list()
S1meanD4_104 = list()
for i in range(S1RGB_imgA1D4_4.shape[0]): 
     for j in range(S1RGB_imgA1D4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1704.append(S1RGB_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_104.append(S1RGB_imgA1D4_4[i][j])  
S1meanrefA1_1704 = np.array(S1meanrefA1_1404)
S1meanD4_104 = np.array(S1meanD4_104)

S1rgbrefA1_1704 = list()
S1rgbD4_104 = list()
for i in range(3):
    S1rgbrefA1_1704.append(S1meanrefA1_1704[:,i].mean())
    S1rgbD4_104.append(S1meanD4_104[:,i].mean())

# %% [markdown]
# ###Img 5

# %%
S1meanrefA1_105 = list()
S1meanA1_205 = list()
for i in range(S1RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_105.append(S1RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_205.append(S1RGB_imgA1A1_5[i][j])  
S1meanrefA1_105 = np.array(S1meanrefA1_105)
S1meanA1_205 = np.array(S1meanA1_205)

S1rgbrefA1_105 = list()
S1rgbA1_205 = list()
for i in range(3):
    S1rgbrefA1_105.append(S1meanrefA1_105[:,i].mean())
    S1rgbA1_205.append(S1meanA1_2[:,i].mean())
S1rgbrefA1_105,S1rgbA1_205

# %%
S1meanrefA1_305 = list()
S1meanA2_105 = list()
for i in range(S1RGB_imgA1A2_5.shape[0]): 
     for j in range(S1RGB_imgA1A2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_305.append(S1RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_105.append(S1RGB_imgA1A2_5[i][j])  
S1meanrefA1_305 = np.array(S1meanrefA1_305 )
S1meanA2_105 = np.array(S1meanA2_105 )

S1rgbrefA1_305 = list()
S1rgbA2_105  = list()
for i in range(3):
    S1rgbrefA1_305 .append(S1meanrefA1_305 [:,i].mean())
    S1rgbA2_105 .append(S1meanA2_105 [:,i].mean())

# %%
S1meanrefA1_405  = list()
S1meanA3_105  = list()
for i in range(S1RGB_imgA1A3_505 .shape[0]): 
     for j in range(S1RGB_imgA1A3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_405 .append(S1RGB_imgA1A3_505 [i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_105 .append(S1RGB_imgA1A3_505 [i][j])  
S1meanrefA1_4 05 = np.array(S1meanrefA1_405 )
S1meanA3_105  = np.array(S1meanA3_105 )

S1rgbrefA1_405  = list()
S1rgbA3_105  = list()
for i in range(3):
    S1rgbrefA1_405 .append(S1meanrefA1_405 [:,i].mean())
    S1rgbA3_105 .append(S1meanA3_105 [:,i].mean())

# %%
S1meanrefA1_505  = list()
S1meanA3_5105  = list()
for i in range(S1RGB_imgA1A3_55.shape[0]): 
     for j in range(S1RGB_imgA1A3_55.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_505 .append(S1RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5105 .append(S1RGB_imgA1A3_55[i][j])  
S1meanrefA1_505  = np.array(S1meanrefA1_5)
S1meanA3_5105  = np.array(S1meanA3_51)

S1rgbrefA1_505  = list()
S1rgbA3_5105  = list()
for i in range(3):
    S1rgbrefA1_505 .append(S1meanrefA1_505 [:,i].mean())
    S1rgbA3_5105 .append(S1meanA3_5105 [:,i].mean())

# %%
S1meanrefA1_605  = list()
S1meanA4_105  = list()
for i in range(S1RGB_imgA1A4_5.shape[0]): 
     for j in range(S1RGB_imgA1A4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_605 .append(S1RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_105 .append(S1RGB_imgA1A4_5[i][j])  
S1meanrefA1_605 = np.array(S1meanrefA1_6)
S1meanA4_105 = np.array(S1meanA4_1)

S1rgbrefA1_605 = list()
S1rgbA4_105 = list()
for i in range(3):
    S1rgbrefA1_605.append(S1meanrefA1_605[:,i].mean())
    S1rgbA4_105.append(S1meanA4_105[:,i].mean())

# %%
S1meanrefA1_705 = list()
S1meanB1_105 = list()
for i in range(S1RGB_imgA1B1_505.shape[0]): 
     for j in range(S1RGB_imgA1B1_505.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_705.append(S1RGB_imgA1B1_505[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_105.append(S1RGB_imgA1B1_505[i][j])  
S1meanrefA1_705 = np.array(S1meanrefA1_705)
S1meanB1_105 = np.array(S1meanB1_105)

S1rgbrefA1_705 = list()
S1rgbB1_105 = list()
for i in range(3):
    S1rgbrefA1_705.append(S1meanrefA1_705[:,i].mean())
    S1rgbB1_105.append(S1meanB1_105[:,i].mean())

# %%
S1meanrefA1_805 = list()
S1meanB2_105 = list()
for i in range(S1RGB_imgA1B2_5.shape[0]): 
     for j in range(S1RGB_imgA1B2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_805.append(S1RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_105.append(S1RGB_imgA1B2_5[i][j])  
S1meanrefA1_805 = np.array(S1meanrefA1_8)
S1meanB2_105 = np.array(S1meanB2_1)

S1rgbrefA1_805 = list()
S1rgbB2_105 = list()
for i in range(3):
    S1rgbrefA1_805.append(S1meanrefA1_805[:,i].mean())
    S1rgbB2_105.append(S1meanB2_105[:,i].mean())

# %%
S1meanrefA1_905 = list()
S1meanB3_105 = list()
for i in range(S1RGB_imgA1B3_5.shape[0]): 
     for j in range(S1RGB_imgA1B3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_905.append(S1RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_105.append(S1RGB_imgA1B3_5[i][j])  
S1meanrefA1_905 = np.array(S1meanrefA1_905)
S1meanB3_105 = np.array(S1meanB3_105)

S1rgbrefA1_905 = list()
S1rgbB3_105 = list()
for i in range(3):
    S1rgbrefA1_905.append(S1meanrefA1_905[:,i].mean())
    S1rgbB3_105.append(S1meanB3_105[:,i].mean())

# %%
S1meanrefA1_1005 = list()
S1meanB4_105 = list()
for i in range(S1RGB_imgA1B4_5.shape[0]): 
     for j in range(S1RGB_imgA1B4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1005.append(S1RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_105.append(S1RGB_imgA1B4_5[i][j])  
S1meanrefA1_1005 = np.array(S1meanrefA1_10)
S1meanB4_105 = np.array(S1meanB4_1)

S1rgbrefA1_1005 = list()
S1rgbB4_105 = list()
for i in range(3):
    S1rgbrefA1_1005.append(S1meanrefA1_1005[:,i].mean())
    S1rgbB4_105.append(S1meanB4_105[:,i].mean())

# %%
S1meanrefA1_1105 = list()
S1meanC1_105 = list()
for i in range(S1RGB_imgA1C1_5.shape[0]): 
     for j in range(S1RGB_imgA1C1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1105.append(S1RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_105.append(S1RGB_imgA1C1_5[i][j])  
S1meanrefA1_1105 = np.array(S1meanrefA1_1105)
S1meanC1_105 = np.array(S1meanC1_105)

S1rgbrefA1_1105 = list()
S1rgbC1_105 = list()
for i in range(3):
    S1rgbrefA1_1105.append(S1meanrefA1_1105[:,i].mean())
    S1rgbC1_105.append(S1meanC1_105[:,i].mean())

# %%
S1meanrefA1_1205 = list()
S1meanC2_105 = list()
for i in range(S1RGB_imgA1C2_5.shape[0]): 
     for j in range(S1RGB_imgA1C2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1205.append(S1RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_105.append(S1RGB_imgA1C2_5[i][j])  
S1meanrefA1_1205 = np.array(S1meanrefA1_1205)
S1meanC2_105 = np.array(S1meanC2_105)

S1rgbrefA1_1205 = list()
S1rgbC2_105 = list()
for i in range(3):
    S1rgbrefA1_1205.append(S1meanrefA1_1205[:,i].mean())
    S1rgbC2_105.append(S1meanC2_105[:,i].mean())

# %%
S1meanrefA1_1305 = list()
S1meanC3_105 = list()
for i in range(S1RGB_imgA1C3_5.shape[0]): 
     for j in range(S1RGB_imgA1C3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1305.append(S1RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_105.append(S1RGB_imgA1C3_5[i][j])  
S1meanrefA1_1305 = np.array(S1meanrefA1_13)
S1meanC3_105 = np.array(S1meanC3_1)

S1rgbrefA1_1305 = list()
S1rgbC3_105 = list()
for i in range(3):
    S1rgbrefA1_1305.append(S1meanrefA1_1305[:,i].mean())
    S1rgbC3_105.append(S1meanC3_105[:,i].mean())

# %%
S1meanrefA1_1405 = list()
S1meanC4_105 = list()
for i in range(S1RGB_imgA1C4_5.shape[0]): 
     for j in range(S1RGB_imgA1C4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1405.append(S1RGB_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_105.append(S1RGB_imgA1C4_5[i][j])  
S1meanrefA1_1405 = np.array(S1meanrefA1_1405)
S1meanC4_105 = np.array(S1meanC4_105)

S1rgbrefA1_1405 = list()
S1rgbC4_105 = list()
for i in range(3):
    S1rgbrefA1_1405.append(S1meanrefA1_1405[:,i].mean())
    S1rgbC4_105.append(S1meanC4_105[:,i].mean())

# %%
S1meanrefA1_1505 = list()
S1meanD2_105 = list()
for i in range(S1RGB_imgA1D2_5.shape[0]): 
     for j in range(S1RGB_imgA1D2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1505.append(S1RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_105.append(S1RGB_imgA1D2_5[i][j])  
S1meanrefA1_1505 = np.array(S1meanrefA1_15)
S1meanD2_105 = np.array(S1meanD2_1)

S1rgbrefA1_1505 = list()
S1rgbD2_105 = list()
for i in range(3):
    S1rgbrefA1_15อ.append(S1meanrefA1_1505[:,i].mean())
    S1rgbD2_105.append(S1meanD2_105[:,i].mean())

# %%
S1meanrefA1_1605 = list()
S1meanD3_105 = list()
for i in range(S1RGB_imgA1D3_505.shape[0]): 
     for j in range(S1RGB_imgA1D3_505.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1605.append(S1RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_105.append(S1RGB_imgA1D3_5 [i][j])  
S1meanrefA1_1605 = np.array(S1meanrefA1_1605)
S1meanD3_105 = np.array(S1meanD3_105)

S1rgbrefA1_1605 = list()
S1rgbD3_105 = list()
for i in range(3):
    S1rgbrefA1_1605.append(S1meanrefA1_1605[:,i].mean())
    S1rgbD3_105.append(S1meanD3_105[:,i].mean())

# %%
S1meanrefA1_1705= list()
S1meanD4_105 = list()
for i in range(S1RGB_imgA1D4_.shape[0]): 
     for j in range(S1RGB_imgA1D4_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1705.append(S1RGB_imgA1D4_1i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_105.append(S1RGB_imgA1D4_[i][j])  
S1meanrefA1_1705 = np.array(S1meanrefA1_1405)
S1meanD4_105 = np.array(S1meanD4_105)

S1rgbrefA1_1705 = list()
S1rgbD4_105 = list()
for i in range(3):
    S1rgbrefA1_1705.append(S1meanrefA1_1705[:,i].mean())
    S1rgbD4_105.append(S1meanD4_105[:,i].mean())

# %% [markdown]
# ###Img 6

# %%
S1meanrefA1_106 = list()
S1meanA1_206 = list()
for i in range(S1RGB_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_6.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_106.append(S1RGB_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_206.append(S1RGB_imgA1A1_6[i][j])  
S1meanrefA1_106 = np.array(S1meanrefA1_106)
S1meanA1_206 = np.array(S1meanA1_206)

S1rgbrefA1_106 = list()
S1rgbA1_206 = list()
for i in range(3):
    S1rgbrefA1_106.append(S1meanrefA1_106[:,i].mean())
    S1rgbA1_206.append(S1meanA1_206[:,i].mean())
S1rgbrefA1_106,S1rgbA1_206

# %%
S1meanrefA1_306 = list()
S1meanA2_106 = list()
for i in range(S1RGB_imgA1A2_6.shape[0]): 
     for j in range(S1RGB_imgA1A2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_306.append(S1RGB_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_106.append(S1RGB_imgA1A2_6[i][j])  
S1meanrefA1_306 = np.array(S1meanrefA1_306)
S1meanA2_106 = np.array(S1meanA2_106)

S1rgbrefA1_306 = list()
S1rgbA2_106 = list()
for i in range(3):
    S1rgbrefA1_306.append(S1meanrefA1_306[:,i].mean())
    S1rgbA2_106.append(S1meanA2_106[:,i].mean())

# %%
S1meanrefA1_406 = list()
S1meanA3_106 = list()
for i in range(S1RGB_imgA1A3_6.shape[0]): 
     for j in range(S1RGB_imgA1A3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_406.append(S1RGB_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_106.append(S1RGB_imgA1A3_6[i][j])  
S1meanrefA1_406 = np.array(S1meanrefA1_406)
S1meanA3_106 = np.array(S1meanA3_106)

S1rgbrefA1_406 = list()
S1rgbA3_106 = list()
for i in range(3):
    S1rgbrefA1_406.append(S1meanrefA1_406[:,i].mean())
    S1rgbA3_106.append(S1meanA3_106[:,i].mean())

# %%
S1meanrefA1_506 = list()
S1meanA3_5106 = list()
for i in range(S1RGB_imgA1A3_56.shape[0]): 
     for j in range(S1RGB_imgA1A3_56.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_506.append(S1RGB_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5106.append(S1RGB_imgA1A3_56[i][j])  
S1meanrefA1_506 = np.array(S1meanrefA1_506)
S1meanA3_5106 = np.array(S1meanA3_5106)

S1rgbrefA1_506 = list()
S1rgbA3_5106 = list()
for i in range(3):
    S1rgbrefA1_506.append(S1meanrefA1_506[:,i].mean())
    S1rgbA3_5106.append(S1meanA3_5106[:,i].mean())

# %%
S1meanrefA1_606 = list()
S1meanA4_106 = list()
for i in range(S1RGB_imgA1A4_6.shape[0]): 
     for j in range(S1RGB_imgA1A4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_606.append(S1RGB_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_106.append(S1RGB_imgA1A4_6[i][j])  
S1meanrefA1_606 = np.array(S1meanrefA1_606)
S1meanA4_106 = np.array(S1meanA4_106)

S1rgbrefA1_606 = list()
S1rgbA4_106 = list()
for i in range(3):
    S1rgbrefA1_606.append(S1meanrefA1_606[:,i].mean())
    S1rgbA4_106.append(S1meanA4_106[:,i].mean())

# %%
S1meanrefA1_706 = list()
S1meanB1_106 = list()
for i in range(S1RGB_imgA1B1_6.shape[0]): 
     for j in range(S1RGB_imgA1B1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_706.append(S1RGB_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_106.append(S1RGB_imgA1B1_6[i][j])  
S1meanrefA1_706 = np.array(S1meanrefA1_706)
S1meanB1_106 = np.array(S1meanB1_106)

S1rgbrefA1_706 = list()
S1rgbB1_106 = list()
for i in range(3):
    S1rgbrefA1_706.append(S1meanrefA1_706[:,i].mean())
    S1rgbB1_106.append(S1meanB1_106[:,i].mean())

# %%
S1meanrefA1_806 = list()
S1meanB2_106 = list()
for i in range(S1RGB_imgA1B2_6.shape[0]): 
     for j in range(S1RGB_imgA1B2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_806.append(S1RGB_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_106.append(S1RGB_imgA1B2_6[i][j])  
S1meanrefA1_806 = np.array(S1meanrefA1_806)
S1meanB2_106 = np.array(S1meanB2_106)

S1rgbrefA1_806 = list()
S1rgbB2_106 = list()
for i in range(3):
    S1rgbrefA1_806.append(S1meanrefA1_806[:,i].mean())
    S1rgbB2_106.append(S1meanB2_106[:,i].mean())

# %%
S1meanrefA1_906 = list()
S1meanB3_106 = list()
for i in range(S1RGB_imgA1B3_6.shape[0]): 
     for j in range(S1RGB_imgA1B3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_906.append(S1RGB_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_106.append(S1RGB_imgA1B3_6[i][j])  
S1meanrefA1_906 = np.array(S1meanrefA1_906)
S1meanB3_106 = np.array(S1meanB3_106)

S1rgbrefA1_906 = list()
S1rgbB3_106 = list()
for i in range(3):
    S1rgbrefA1_906.append(S1meanrefA1_906[:,i].mean())
    S1rgbB3_106.append(S1meanB3_106[:,i].mean())

# %%
S1meanrefA1_1006 = list()
S1meanB4_106 = list()
for i in range(S1RGB_imgA1B4_6.shape[0]): 
     for j in range(S1RGB_imgA1B4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1006.append(S1RGB_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_106.append(S1RGB_imgA1B4_6[i][j])  
S1meanrefA1_1006 = np.array(S1meanrefA1_1006)
S1meanB4_106 = np.array(S1meanB4_106)

S1rgbrefA1_1006 = list()
S1rgbB4_106 = list()
for i in range(3):
    S1rgbrefA1_1006.append(S1meanrefA1_1006[:,i].mean())
    S1rgbB4_106.append(S1meanB4_106[:,i].mean())

# %%
S1meanrefA1_1106 = list()
S1meanC1_106 = list()
for i in range(S1RGB_imgA1C1_6.shape[0]): 
     for j in range(S1RGB_imgA1C1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1106.append(S1RGB_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_106.append(S1RGB_imgA1C1_6[i][j])  
S1meanrefA1_1106 = np.array(S1meanrefA1_1106)
S1meanC1_106 = np.array(S1meanC1_106)

S1rgbrefA1_1106 = list()
S1rgbC1_106 = list()
for i in range(3):
    S1rgbrefA1_1106.append(S1meanrefA1_1106[:,i].mean())
    S1rgbC1_106.append(S1meanC1_106[:,i].mean())

# %%
S1meanrefA1_1206 = list()
S1meanC2_106 = list()
for i in range(S1RGB_imgA1C2_6.shape[0]): 
     for j in range(S1RGB_imgA1C2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1206.append(S1RGB_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_106.append(S1RGB_imgA1C2_6[i][j])  
S1meanrefA1_1206 = np.array(S1meanrefA1_1206)
S1meanC2_106 = np.array(S1meanC2_106)

S1rgbrefA1_1206 = list()
S1rgbC2_106 = list()
for i in range(3):
    S1rgbrefA1_1206.append(S1meanrefA1_1206[:,i].mean())
    S1rgbC2_106.append(S1meanC2_106[:,i].mean())

# %%
S1meanrefA1_1306 = list()
S1meanC3_106 = list()
for i in range(S1RGB_imgA1C3_6.shape[0]): 
     for j in range(S1RGB_imgA1C3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1306.append(S1RGB_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_106.append(S1RGB_imgA1C3_6[i][j])  
S1meanrefA1_1306 = np.array(S1meanrefA1_1306)
S1meanC3_106 = np.array(S1meanC3_106)

S1rgbrefA1_1306 = list()
S1rgbC3_106 = list()
for i in range(3):
    S1rgbrefA1_1306.append(S1meanrefA1_1306[:,i].mean())
    S1rgbC3_106.append(S1meanC3_106[:,i].mean())

# %%
S1meanrefA1_1406 = list()
S1meanC4_106 = list()
for i in range(S1RGB_imgA1C4_6.shape[0]): 
     for j in range(S1RGB_imgA1C4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1406.append(S1RGB_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_106.append(S1RGB_imgA1C4_6[i][j])  
S1meanrefA1_1406 = np.array(S1meanrefA1_1406)
S1meanC4_106 = np.array(S1meanC4_106)

S1rgbrefA1_1406 = list()
S1rgbC4_106 = list()
for i in range(3):
    S1rgbrefA1_1406.append(S1meanrefA1_1406[:,i].mean())
    S1rgbC4_106.append(S1meanC4_106[:,i].mean())

# %%
S1meanrefA1_1506 = list()
S1meanD2_106 = list()
for i in range(S1RGB_imgA1D2_6.shape[0]): 
     for j in range(S1RGB_imgA1D2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1506.append(S1RGB_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_106.append(S1RGB_imgA1D2_6[i][j])  
S1meanrefA1_1506 = np.array(S1meanrefA1_1506)
S1meanD2_106 = np.array(S1meanD2_106)

S1rgbrefA1_1506 = list()
S1rgbD2_1 = list()
for i in range(3):
    S1rgbrefA1_15.append(S1meanrefA1_15[:,i].mean())
    S1rgbD2_1.append(S1meanD2_1[:,i].mean())

# %%
S1meanrefA1_16 = list()
S1meanD3_1 = list()
for i in range(S1RGB_imgA1D3_6.shape[0]): 
     for j in range(S1RGB_imgA1D3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_16.append(S1RGB_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_1.append(S1RGB_imgA1D3_6[i][j])  
S1meanrefA1_16 = np.array(S1meanrefA1_1606)
S1meanD3_106 = np.array(S1meanD3_106)

S1rgbrefA1_1606 = list()
S1rgbD3_106 = list()
for i in range(3):
    S1rgbrefA1_1606.append(S1meanrefA1_1606[:,i].mean())
    S1rgbD3_106.append(S1meanD3_106[:,i].mean())

# %%
S1meanrefA1_1706= list()
S1meanD4_106 = list()
for i in range(S1RGB_imgA1D4_6.shape[0]): 
     for j in range(S1RGB_imgA1D4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1706.append(S1RGB_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_106.append(S1RGB_imgA1D4_6[i][j])  
S1meanrefA1_1706 = np.array(S1meanrefA1_1406)
S1meanD4_106 = np.array(S1meanD4_106)

S1rgbrefA1_1706 = list()
S1rgbD4_106 = list()
for i in range(3):
    S1rgbrefA1_1706.append(S1meanrefA1_1706[:,i].mean())
    S1rgbD4_106.append(S1meanD4_106[:,i].mean())

# %% [markdown]
# ###Img 7

# %%
S1meanrefA1_107 = list()
S1meanA1_207 = list()
for i in range(S1RGB_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_107.append(S1RGB_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_207.append(S1RGB_imgA1A1_7[i][j])  
S1meanrefA1_107 = np.array(S1meanrefA1_107)
S1meanA1_207 = np.array(S1meanA1_207)

S1rgbrefA1_107 = list()
S1rgbA1_207 = list()
for i in range(3):
    S1rgbrefA1_107.append(S1meanrefA1_107[:,i].mean())
    S1rgbA1_207.append(S1meanA1_207[:,i].mean())
S1rgbrefA1_107,S1rgbA1_207

# %%
S1meanrefA1_307 = list()
S1meanA2_107 = list()
for i in range(S1RGB_imgA1A2_7.shape[0]): 
     for j in range(S1RGB_imgA1A2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_307.append(S1RGB_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_107.append(S1RGB_imgA1A2_7[i][j])  
S1meanrefA1_307 = np.array(S1meanrefA1_307)
S1meanA2_107 = np.array(S1meanA2_107)

S1rgbrefA1_307 = list()
S1rgbA2_107 = list()
for i in range(3):
    S1rgbrefA1_307.append(S1meanrefA1_307[:,i].mean())
    S1rgbA2_107.append(S1meanA2_107[:,i].mean())

# %%
S1meanrefA1_407 = list()
S1meanA3_107 = list()
for i in range(S1RGB_imgA1A3_7.shape[0]): 
     for j in range(S1RGB_imgA1A3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_407.append(S1RGB_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_107.append(S1RGB_imgA1A3_7[i][j])  
S1meanrefA1_407 = np.array(S1meanrefA1_407)
S1meanA3_107 = np.array(S1meanA3_107)

S1rgbrefA1_407 = list()
S1rgbA3_107 = list()
for i in range(3):
    S1rgbrefA1_407.append(S1meanrefA1_407[:,i].mean())
    S1rgbA3_107.append(S1meanA3_107[:,i].mean())

# %%
S1meanrefA1_507 = list()
S1meanA3_5107 = list()
for i in range(S1RGB_imgA1A3_57.shape[0]): 
     for j in range(S1RGB_imgA1A3_57.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_507.append(S1RGB_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5107.append(S1RGB_imgA1A3_57[i][j])  
S1meanrefA1_507 = np.array(S1meanrefA1_507)
S1meanA3_5107 = np.array(S1meanA3_5107)

S1rgbrefA1_507 = list()
S1rgbA3_5107 = list()
for i in range(3):
    S1rgbrefA1_507.append(S1meanrefA1_507[:,i].mean())
    S1rgbA3_5107.append(S1meanA3_5107[:,i].mean())

# %%
S1meanrefA1_607 = list()
S1meanA4_107 = list()
for i in range(S1RGB_imgA1A4_7.shape[0]): 
     for j in range(S1RGB_imgA1A4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_607.append(S1RGB_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_107.append(S1RGB_imgA1A4_7[i][j])  
S1meanrefA1_607 = np.array(S1meanrefA1_607)
S1meanA4_107 = np.array(S1meanA4_107)

S1rgbrefA1_607 = list()
S1rgbA4_107 = list()
for i in range(3):
    S1rgbrefA1_607.append(S1meanrefA1_607[:,i].mean())
    S1rgbA4_107.append(S1meanA4_107[:,i].mean())

# %%
S1meanrefA1_707 = list()
S1meanB1_107 = list()
for i in range(S1RGB_imgA1B1_7.shape[0]): 
     for j in range(S1RGB_imgA1B1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_707.append(S1RGB_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_107.append(S1RGB_imgA1B1_7[i][j])  
S1meanrefA1_707 = np.array(S1meanrefA1_707)
S1meanB1_107 = np.array(S1meanB1_107)

S1rgbrefA1_707 = list()
S1rgbB1_107 = list()
for i in range(3):
    S1rgbrefA1_707.append(S1meanrefA1_707[:,i].mean())
    S1rgbB1_107.append(S1meanB1_107[:,i].mean())

# %%
S1meanrefA1_807 = list()
S1meanB2_107 = list()
for i in range(S1RGB_imgA1B2_7.shape[0]): 
     for j in range(S1RGB_imgA1B2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_807.append(S1RGB_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_107.append(S1RGB_imgA1B2_7[i][j])  
S1meanrefA1_807 = np.array(S1meanrefA1_807)
S1meanB2_107 = np.array(S1meanB2_107)

S1rgbrefA1_807 = list()
S1rgbB2_107 = list()
for i in range(3):
    S1rgbrefA1_807.append(S1meanrefA1_807[:,i].mean())
    S1rgbB2_107.append(S1meanB2_107[:,i].mean())

# %%
S1meanrefA1_907 = list()
S1meanB3_107 = list()
for i in range(S1RGB_imgA1B3_7.shape[0]): 
     for j in range(S1RGB_imgA1B3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_907.append(S1RGB_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_107.append(S1RGB_imgA1B3_7[i][j])  
S1meanrefA1_907 = np.array(S1meanrefA1_907)
S1meanB3_107 = np.array(S1meanB3_107)

S1rgbrefA1_907 = list()
S1rgbB3_107 = list()
for i in range(3):
    S1rgbrefA1_907.append(S1meanrefA1_907[:,i].mean())
    S1rgbB3_107.append(S1meanB3_107[:,i].mean())

# %%
S1meanrefA1_1007 = list()
S1meanB4_107 = list()
for i in range(S1RGB_imgA1B4_7.shape[0]): 
     for j in range(S1RGB_imgA1B4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1007.append(S1RGB_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_107.append(S1RGB_imgA1B4_7[i][j])  
S1meanrefA1_1007 = np.array(S1meanrefA1_1007)
S1meanB4_107 = np.array(S1meanB4_107)

S1rgbrefA1_1007 = list()
S1rgbB4_107 = list()
for i in range(3):
    S1rgbrefA1_1007.append(S1meanrefA1_1007[:,i].mean())
    S1rgbB4_107.append(S1meanB4_107[:,i].mean())

# %%
S1meanrefA1_1107 = list()
S1meanC1_107 = list()
for i in range(S1RGB_imgA1C1_7.shape[0]): 
     for j in range(S1RGB_imgA1C1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1107.append(S1RGB_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_107.append(S1RGB_imgA1C1_7[i][j])  
S1meanrefA1_1107 = np.array(S1meanrefA1_1107)
S1meanC1_107 = np.array(S1meanC1_107)

S1rgbrefA1_1107 = list()
S1rgbC1_107 = list()
for i in range(3):
    S1rgbrefA1_1107.append(S1meanrefA1_1107[:,i].mean())
    S1rgbC1_107.append(S1meanC1_107[:,i].mean())

# %%
S1meanrefA1_1207 = list()
S1meanC2_107 = list()
for i in range(S1RGB_imgA1C2_7.shape[0]): 
     for j in range(S1RGB_imgA1C2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1207.append(S1RGB_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_107.append(S1RGB_imgA1C2_7[i][j])  
S1meanrefA1_1207 = np.array(S1meanrefA1_1207)
S1meanC2_107 = np.array(S1meanC2_107)

S1rgbrefA1_1207 = list()
S1rgbC2_107 = list()
for i in range(3):
    S1rgbrefA1_1207.append(S1meanrefA1_1207[:,i].mean())
    S1rgbC2_107.append(S1meanC2_107[:,i].mean())

# %%
S1meanrefA1_1307 = list()
S1meanC3_107 = list()
for i in range(S1RGB_imgA1C3_7.shape[0]): 
     for j in range(S1RGB_imgA1C3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1307.append(S1RGB_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_107.append(S1RGB_imgA1C3_7[i][j])  
S1meanrefA1_1307 = np.array(S1meanrefA1_1307)
S1meanC3_107 = np.array(S1meanC3_107)

S1rgbrefA1_1307 = list()
S1rgbC3_107 = list()
for i in range(3):
    S1rgbrefA1_1307.append(S1meanrefA1_1307[:,i].mean())
    S1rgbC3_107.append(S1meanC3_107[:,i].mean())

# %%
S1meanrefA1_1407 = list()
S1meanC4_107 = list()
for i in range(S1RGB_imgA1C4_7.shape[0]): 
     for j in range(S1RGB_imgA1C4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1407.append(S1RGB_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_107.append(S1RGB_imgA1C4_7[i][j])  
S1meanrefA1_1407 = np.array(S1meanrefA1_1407)
S1meanC4_107 = np.array(S1meanC4_107)

S1rgbrefA1_1407 = list()
S1rgbC4_107 = list()
for i in range(3):
    S1rgbrefA1_1407.append(S1meanrefA1_1407[:,i].mean())
    S1rgbC4_107.append(S1meanC4_107[:,i].mean())

# %%
S1meanrefA1_1507 = list()
S1meanD2_107 = list()
for i in range(S1RGB_imgA1D2_7.shape[0]): 
     for j in range(S1RGB_imgA1D2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1507.append(S1RGB_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_107.append(S1RGB_imgA1D2_7[i][j])  
S1meanrefA1_1507 = np.array(S1meanrefA1_1507)
S1meanD2_107 = np.array(S1meanD2_107)

S1rgbrefA1_1507 = list()
S1rgbD2_107 = list()
for i in range(3):
    S1rgbrefA1_1507.append(S1meanrefA1_1507[:,i].mean())
    S1rgbD2_107.append(S1meanD2_107[:,i].mean())

# %%
S1meanrefA1_1607 = list()
S1meanD3_107 = list()
for i in range(S1RGB_imgA1D3_7.shape[0]): 
     for j in range(S1RGB_imgA1D3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1607.append(S1RGB_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_107.append(S1RGB_imgA1D3_7[i][j])  
S1meanrefA1_1607 = np.array(S1meanrefA1_1607)
S1meanD3_107 = np.array(S1meanD3_107)

S1rgbrefA1_1607 = list()
S1rgbD3_107 = list()
for i in range(3):
    S1rgbrefA1_1607.append(S1meanrefA1_1607[:,i].mean())
    S1rgbD3_107.append(S1meanD3_107[:,i].mean())

# %%
S1meanrefA1_1707= list()
S1meanD4_107 = list()
for i in range(S1RGB_imgA1D4_7.shape[0]): 
     for j in range(S1RGB_imgA1D4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1707.append(S1RGB_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_107.append(S1RGB_imgA1D4_7[i][j])  
S1meanrefA1_1707 = np.array(S1meanrefA1_1407)
S1meanD4_107 = np.array(S1meanD4_107)

S1rgbrefA1_1707 = list()
S1rgbD4_107 = list()
for i in range(3):
    S1rgbrefA1_1707.append(S1meanrefA1_1707[:,i].mean())
    S1rgbD4_107.append(S1meanD4_107[:,i].mean())

# %% [markdown]
# ###Img 8

# %%
S1meanrefA1_108 = list()
S1meanA1_208 = list()
for i in range(S1RGB_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_108.append(S1RGB_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_208.append(S1RGB_imgA1A1_8[i][j])  
S1meanrefA1_108 = np.array(S1meanrefA1_108)
S1meanA1_208 = np.array(S1meanA1_208)

S1rgbrefA1_108 = list()
S1rgbA1_208 = list()
for i in range(3):
    S1rgbrefA1_108.append(S1meanrefA1_108[:,i].mean())
    S1rgbA1_208.append(S1meanA1_208[:,i].mean())
S1rgbrefA1_108,S1rgbA1_208

# %%
S1meanrefA1_308 = list()
S1meanA2_108 = list()
for i in range(S1RGB_imgA1A2_8.shape[0]): 
     for j in range(S1RGB_imgA1A2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_308.append(S1RGB_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_108.append(S1RGB_imgA1A2_8[i][j])  
S1meanrefA1_308 = np.array(S1meanrefA1_308)
S1meanA2_108 = np.array(S1meanA2_108)

S1rgbrefA1_308 = list()
S1rgbA2_108 = list()
for i in range(3):
    S1rgbrefA1_308.append(S1meanrefA1_308[:,i].mean())
    S1rgbA2_108.append(S1meanA2_108[:,i].mean())

# %%
S1meanrefA1_408 = list()
S1meanA3_108 = list()
for i in range(S1RGB_imgA1A3_8.shape[0]): 
     for j in range(S1RGB_imgA1A3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_408.append(S1RGB_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_108.append(S1RGB_imgA1A3_8[i][j])  
S1meanrefA1_408 = np.array(S1meanrefA1_408)
S1meanA3_108 = np.array(S1meanA3_108)

S1rgbrefA1_408 = list()
S1rgbA3_108 = list()
for i in range(3):
    S1rgbrefA1_408.append(S1meanrefA1_408[:,i].mean())
    S1rgbA3_108.append(S1meanA3_108[:,i].mean())

# %%
S1meanrefA1_508 = list()
S1meanA3_5108 = list()
for i in range(S1RGB_imgA1A3_58.shape[0]): 
     for j in range(S1RGB_imgA1A3_58.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_508.append(S1RGB_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5108.append(S1RGB_imgA1A3_58[i][j])  
S1meanrefA1_508 = np.array(S1meanrefA1_508)
S1meanA3_5108 = np.array(S1meanA3_5108)

S1rgbrefA1_508 = list()
S1rgbA3_5108 = list()
for i in range(3):
    S1rgbrefA1_508.append(S1meanrefA1_508[:,i].mean())
    S1rgbA3_5108.append(S1meanA3_5108[:,i].mean())

# %%
S1meanrefA1_608 = list()
S1meanA4_108 = list()
for i in range(S1RGB_imgA1A4_8.shape[0]): 
     for j in range(S1RGB_imgA1A4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_608.append(S1RGB_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_108.append(S1RGB_imgA1A4_8[i][j])  
S1meanrefA1_608 = np.array(S1meanrefA1_608)
S1meanA4_108 = np.array(S1meanA4_108)

S1rgbrefA1_608 = list()
S1rgbA4_108 = list()
for i in range(3):
    S1rgbrefA1_608.append(S1meanrefA1_608[:,i].mean())
    S1rgbA4_108.append(S1meanA4_108[:,i].mean())

# %%
S1meanrefA1_708 = list()
S1meanB1_108 = list()
for i in range(S1RGB_imgA1B1_8.shape[0]): 
     for j in range(S1RGB_imgA1B1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_708.append(S1RGB_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_108.append(S1RGB_imgA1B1_8[i][j])  
S1meanrefA1_708 = np.array(S1meanrefA1_708)
S1meanB1_108 = np.array(S1meanB1_108)

S1rgbrefA1_708 = list()
S1rgbB1_108 = list()
for i in range(3):
    S1rgbrefA1_708.append(S1meanrefA1_708[:,i].mean())
    S1rgbB1_108.append(S1meanB1_108[:,i].mean())

# %%
S1meanrefA1_808 = list()
S1meanB2_108 = list()
for i in range(S1RGB_imgA1B2_8.shape[0]): 
     for j in range(S1RGB_imgA1B2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_808.append(S1RGB_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_108.append(S1RGB_imgA1B2_8[i][j])  
S1meanrefA1_808 = np.array(S1meanrefA1_808)
S1meanB2_108 = np.array(S1meanB2_108)

S1rgbrefA1_808 = list()
S1rgbB2_108 = list()
for i in range(3):
    S1rgbrefA1_808.append(S1meanrefA1_808[:,i].mean())
    S1rgbB2_108.append(S1meanB2_108[:,i].mean())

# %%
S1meanrefA1_908 = list()
S1meanB3_108 = list()
for i in range(S1RGB_imgA1B3_8.shape[0]): 
     for j in range(S1RGB_imgA1B3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_908.append(S1RGB_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_108.append(S1RGB_imgA1B3_8[i][j])  
S1meanrefA1_908 = np.array(S1meanrefA1_908)
S1meanB3_108 = np.array(S1meanB3_108)

S1rgbrefA1_908 = list()
S1rgbB3_108 = list()
for i in range(3):
    S1rgbrefA1_908.append(S1meanrefA1_908[:,i].mean())
    S1rgbB3_108.append(S1meanB3_108[:,i].mean())

# %%
S1meanrefA1_1008 = list()
S1meanB4_108 = list()
for i in range(S1RGB_imgA1B4_8.shape[0]): 
     for j in range(S1RGB_imgA1B4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1008.append(S1RGB_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_108.append(S1RGB_imgA1B4_8[i][j])  
S1meanrefA1_1008 = np.array(S1meanrefA1_1008)
S1meanB4_108 = np.array(S1meanB4_108)

S1rgbrefA1_1008 = list()
S1rgbB4_108 = list()
for i in range(3):
    S1rgbrefA1_1008.append(S1meanrefA1_1008[:,i].mean())
    S1rgbB4_108.append(S1meanB4_108[:,i].mean())

# %%
S1meanrefA1_1108 = list()
S1meanC1_108 = list()
for i in range(S1RGB_imgA1C1_8.shape[0]): 
     for j in range(S1RGB_imgA1C1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1108.append(S1RGB_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_108.append(S1RGB_imgA1C1_8[i][j])  
S1meanrefA1_1108 = np.array(S1meanrefA1_1108)
S1meanC1_108 = np.array(S1meanC1_108)

S1rgbrefA1_1108 = list()
S1rgbC1_108 = list()
for i in range(3):
    S1rgbrefA1_1108.append(S1meanrefA1_1108[:,i].mean())
    S1rgbC1_108.append(S1meanC1_108[:,i].mean())

# %%
S1meanrefA1_1208 = list()
S1meanC2_108 = list()
for i in range(S1RGB_imgA1C2_8.shape[0]): 
     for j in range(S1RGB_imgA1C2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1208.append(S1RGB_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_108.append(S1RGB_imgA1C2_8[i][j])  
S1meanrefA1_1208 = np.array(S1meanrefA1_1208)
S1meanC2_108 = np.array(S1meanC2_108)

S1rgbrefA1_1208 = list()
S1rgbC2_108 = list()
for i in range(3):
    S1rgbrefA1_1208.append(S1meanrefA1_1208[:,i].mean())
    S1rgbC2_108.append(S1meanC2_108[:,i].mean())

# %%
S1meanrefA1_1308 = list()
S1meanC3_108 = list()
for i in range(S1RGB_imgA1C3_8.shape[0]): 
     for j in range(S1RGB_imgA1C3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1308.append(S1RGB_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_108.append(S1RGB_imgA1C3_8[i][j])  
S1meanrefA1_1308 = np.array(S1meanrefA1_1308)
S1meanC3_108 = np.array(S1meanC3_108)

S1rgbrefA1_1308 = list()
S1rgbC3_108 = list()
for i in range(3):
    S1rgbrefA1_1308.append(S1meanrefA1_1308[:,i].mean())
    S1rgbC3_108.append(S1meanC3_108[:,i].mean())

# %%
S1meanrefA1_1408 = list()
S1meanC4_108 = list()
for i in range(S1RGB_imgA1C4_8.shape[0]): 
     for j in range(S1RGB_imgA1C4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1408.append(S1RGB_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_108.append(S1RGB_imgA1C4_8[i][j])  
S1meanrefA1_1408 = np.array(S1meanrefA1_1408)
S1meanC4_108 = np.array(S1meanC4_108)

S1rgbrefA1_1408 = list()
S1rgbC4_108 = list()
for i in range(3):
    S1rgbrefA1_1408.append(S1meanrefA1_1408[:,i].mean())
    S1rgbC4_108.append(S1meanC4_108[:,i].mean())

# %%
S1meanrefA1_1508 = list()
S1meanD2_108 = list()
for i in range(S1RGB_imgA1D2_8.shape[0]): 
     for j in range(S1RGB_imgA1D2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1508.append(S1RGB_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_108.append(S1RGB_imgA1D2_8[i][j])  
S1meanrefA1_1508 = np.array(S1meanrefA1_1508)
S1meanD2_108 = np.array(S1meanD2_108)

S1rgbrefA1_1508 = list()
S1rgbD2_108 = list()
for i in range(3):
    S1rgbrefA1_1508.append(S1meanrefA1_1508[:,i].mean())
    S1rgbD2_108.append(S1meanD2_108[:,i].mean())

# %%
S1meanrefA1_1608 = list()
S1meanD3_108 = list()
for i in range(S1RGB_imgA1D3_8.shape[0]): 
     for j in range(S1RGB_imgA1D3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1608.append(S1RGB_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_108.append(S1RGB_imgA1D3_8[i][j])  
S1meanrefA1_1608 = np.array(S1meanrefA1_1608)
S1meanD3_108 = np.array(S1meanD3_108)

S1rgbrefA1_1608 = list()
S1rgbD3_108 = list()
for i in range(3):
    S1rgbrefA1_1608.append(S1meanrefA1_1608[:,i].mean())
    S1rgbD3_108.append(S1meanD3_108[:,i].mean())

# %%
S1meanrefA1_1708= list()
S1meanD4_108 = list()
for i in range(S1RGB_imgA1D4_8.shape[0]): 
     for j in range(S1RGB_imgA1D4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1708.append(S1RGB_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_108.append(S1RGB_imgA1D4_8[i][j])  
S1meanrefA1_1708 = np.array(S1meanrefA1_1408)
S1meanD4_108 = np.array(S1meanD4_108)

S1rgbrefA1_1708 = list()
S1rgbD4_108 = list()
for i in range(3):
    S1rgbrefA1_1708.append(S1meanrefA1_1708[:,i].mean())
    S1rgbD4_108.append(S1meanD4_108[:,i].mean())

# %% [markdown]
# ###Img 9

# %%
S1meanrefA1_109 = list()
S1meanA1_209 = list()
for i in range(S1RGB_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_109.append(S1RGB_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_209.append(S1RGB_imgA1A1_9[i][j])  
S1meanrefA1_109 = np.array(S1meanrefA1_109)
S1meanA1_209 = np.array(S1meanA1_209)

S1rgbrefA1_109 = list()
S1rgbA1_209 = list()
for i in range(3):
    S1rgbrefA1_109.append(S1meanrefA1_109[:,i].mean())
    S1rgbA1_209.append(S1meanA1_209[:,i].mean())
S1rgbrefA1_109,S1rgbA1_209

# %%
S1meanrefA1_309 = list()
S1meanA2_109 = list()
for i in range(S1RGB_imgA1A2_9.shape[0]): 
     for j in range(S1RGB_imgA1A2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_309.append(S1RGB_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_109.append(S1RGB_imgA1A2_9[i][j])  
S1meanrefA1_309 = np.array(S1meanrefA1_309)
S1meanA2_109 = np.array(S1meanA2_109)

S1rgbrefA1_309 = list()
S1rgbA2_109 = list()
for i in range(3):
    S1rgbrefA1_309.append(S1meanrefA1_309[:,i].mean())
    S1rgbA2_109.append(S1meanA2_109[:,i].mean())

# %%
S1meanrefA1_409 = list()
S1meanA3_109 = list()
for i in range(S1RGB_imgA1A3_9.shape[0]): 
     for j in range(S1RGB_imgA1A3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_409.append(S1RGB_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_109.append(S1RGB_imgA1A3_9[i][j])  
S1meanrefA1_409 = np.array(S1meanrefA1_409)
S1meanA3_109 = np.array(S1meanA3_109)

S1rgbrefA1_409 = list()
S1rgbA3_109 = list()
for i in range(3):
    S1rgbrefA1_409.append(S1meanrefA1_409[:,i].mean())
    S1rgbA3_109.append(S1meanA3_109[:,i].mean())

# %%
S1meanrefA1_509 = list()
S1meanA3_5109 = list()
for i in range(S1RGB_imgA1A3_59.shape[0]): 
     for j in range(S1RGB_imgA1A3_59.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_509.append(S1RGB_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5109.append(S1RGB_imgA1A3_59[i][j])  
S1meanrefA1_509 = np.array(S1meanrefA1_509)
S1meanA3_5109 = np.array(S1meanA3_5109)

S1rgbrefA1_509 = list()
S1rgbA3_5109 = list()
for i in range(3):
    S1rgbrefA1_509.append(S1meanrefA1_509[:,i].mean())
    S1rgbA3_5109.append(S1meanA3_5109[:,i].mean())

# %%
S1meanrefA1_609 = list()
S1meanA4_109 = list()
for i in range(S1RGB_imgA1A4_9.shape[0]): 
     for j in range(S1RGB_imgA1A4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_609.append(S1RGB_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_109.append(S1RGB_imgA1A4_9[i][j])  
S1meanrefA1_609 = np.array(S1meanrefA1_609)
S1meanA4_109 = np.array(S1meanA4_109)

S1rgbrefA1_609 = list()
S1rgbA4_109 = list()
for i in range(3):
    S1rgbrefA1_609.append(S1meanrefA1_609[:,i].mean())
    S1rgbA4_109.append(S1meanA4_109[:,i].mean())

# %%
S1meanrefA1_709 = list()
S1meanB1_109 = list()
for i in range(S1RGB_imgA1B1_9.shape[0]): 
     for j in range(S1RGB_imgA1B1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_709.append(S1RGB_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_109.append(S1RGB_imgA1B1_9[i][j])  
S1meanrefA1_709 = np.array(S1meanrefA1_709)
S1meanB1_109 = np.array(S1meanB1_109)

S1rgbrefA1_709 = list()
S1rgbB1_109 = list()
for i in range(3):
    S1rgbrefA1_709.append(S1meanrefA1_709[:,i].mean())
    S1rgbB1_109.append(S1meanB1_109[:,i].mean())

# %%
S1meanrefA1_809 = list()
S1meanB2_109 = list()
for i in range(S1RGB_imgA1B2_9.shape[0]): 
     for j in range(S1RGB_imgA1B2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_809.append(S1RGB_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_109.append(S1RGB_imgA1B2_9[i][j])  
S1meanrefA1_809 = np.array(S1meanrefA1_809)
S1meanB2_109 = np.array(S1meanB2_109)

S1rgbrefA1_809 = list()
S1rgbB2_109 = list()
for i in range(3):
    S1rgbrefA1_809.append(S1meanrefA1_809[:,i].mean())
    S1rgbB2_109.append(S1meanB2_109[:,i].mean())

# %%
S1meanrefA1_909 = list()
S1meanB3_109 = list()
for i in range(S1RGB_imgA1B3_9.shape[0]): 
     for j in range(S1RGB_imgA1B3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_909.append(S1RGB_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_109.append(S1RGB_imgA1B3_9[i][j])  
S1meanrefA1_909 = np.array(S1meanrefA1_909)
S1meanB3_109 = np.array(S1meanB3_109)

S1rgbrefA1_909 = list()
S1rgbB3_109 = list()
for i in range(3):
    S1rgbrefA1_909.append(S1meanrefA1_909[:,i].mean())
    S1rgbB3_109.append(S1meanB3_109[:,i].mean())

# %%
S1meanrefA1_1009 = list()
S1meanB4_109 = list()
for i in range(S1RGB_imgA1B4_9.shape[0]): 
     for j in range(S1RGB_imgA1B4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1009.append(S1RGB_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_109.append(S1RGB_imgA1B4_9[i][j])  
S1meanrefA1_1009 = np.array(S1meanrefA1_1009)
S1meanB4_109 = np.array(S1meanB4_109)

S1rgbrefA1_1009 = list()
S1rgbB4_109 = list()
for i in range(3):
    S1rgbrefA1_1009.append(S1meanrefA1_1009[:,i].mean())
    S1rgbB4_109.append(S1meanB4_109[:,i].mean())

# %%
S1meanrefA1_1109 = list()
S1meanC1_109 = list()
for i in range(S1RGB_imgA1C1_9.shape[0]): 
     for j in range(S1RGB_imgA1C1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1109.append(S1RGB_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_109.append(S1RGB_imgA1C1_9[i][j])  
S1meanrefA1_1109 = np.array(S1meanrefA1_1109)
S1meanC1_109 = np.array(S1meanC1_109)

S1rgbrefA1_1109 = list()
S1rgbC1_109 = list()
for i in range(3):
    S1rgbrefA1_1109.append(S1meanrefA1_1109[:,i].mean())
    S1rgbC1_109.append(S1meanC1_109[:,i].mean())

# %%
S1meanrefA1_1209 = list()
S1meanC2_109 = list()
for i in range(S1RGB_imgA1C2_9.shape[0]): 
     for j in range(S1RGB_imgA1C2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1209.append(S1RGB_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_109.append(S1RGB_imgA1C2_9[i][j])  
S1meanrefA1_1209 = np.array(S1meanrefA1_1209)
S1meanC2_109 = np.array(S1meanC2_109)

S1rgbrefA1_1209 = list()
S1rgbC2_109 = list()
for i in range(3):
    S1rgbrefA1_1209.append(S1meanrefA1_1209[:,i].mean())
    S1rgbC2_109.append(S1meanC2_109[:,i].mean())

# %%
S1meanrefA1_13 = list()
S1meanC3_1 = list()
for i in range(S1RGB_imgA1C3_9.shape[0]): 
     for j in range(S1RGB_imgA1C3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_13.append(S1RGB_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_1.append(S1RGB_imgA1C3_9[i][j])  
S1meanrefA1_13 = np.array(S1meanrefA1_13)
S1meanC3_1 = np.array(S1meanC3_1)

S1rgbrefA1_13 = list()
S1rgbC3_1 = list()
for i in range(3):
    S1rgbrefA1_13.append(S1meanrefA1_13[:,i].mean())
    S1rgbC3_1.append(S1meanC3_1[:,i].mean())

# %%
S1meanrefA1_1409 = list()
S1meanC4_109 = list()
for i in range(S1RGB_imgA1C4_9.shape[0]): 
     for j in range(S1RGB_imgA1C4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1409.append(S1RGB_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_109.append(S1RGB_imgA1C4_9[i][j])  
S1meanrefA1_1409 = np.array(S1meanrefA1_1409)
S1meanC4_109 = np.array(S1meanC4_109)

S1rgbrefA1_1409 = list()
S1rgbC4_109 = list()
for i in range(3):
    S1rgbrefA1_1409.append(S1meanrefA1_1409[:,i].mean())
    S1rgbC4_109.append(S1meanC4_109[:,i].mean())

# %%
S1meanrefA1_1509 = list()
S1meanD2_109 = list()
for i in range(S1RGB_imgA1D2_9.shape[0]): 
     for j in range(S1RGB_imgA1D2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1509.append(S1RGB_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_109.append(S1RGB_imgA1D2_9[i][j])  
S1meanrefA1_1509 = np.array(S1meanrefA1_1509)
S1meanD2_109 = np.array(S1meanD2_109)

S1rgbrefA1_1509 = list()
S1rgbD2_109 = list()
for i in range(3):
    S1rgbrefA1_1509.append(S1meanrefA1_1509[:,i].mean())
    S1rgbD2_109.append(S1meanD2_109[:,i].mean())

# %%
S1meanrefA1_1609 = list()
S1meanD3_109 = list()
for i in range(S1RGB_imgA1D3_9.shape[0]): 
     for j in range(S1RGB_imgA1D3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1609.append(S1RGB_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_109.append(S1RGB_imgA1D3_9[i][j])  
S1meanrefA1_1609 = np.array(S1meanrefA1_1609)
S1meanD3_109 = np.array(S1meanD3_109)

S1rgbrefA1_1609 = list()
S1rgbD3_109 = list()
for i in range(3):
    S1rgbrefA1_1609.append(S1meanrefA1_1609[:,i].mean())
    S1rgbD3_109.append(S1meanD3_109[:,i].mean())

# %%
S1meanrefA1_1709= list()
S1meanD4_109 = list()
for i in range(S1RGB_imgA1D4_9.shape[0]): 
     for j in range(S1RGB_imgA1D4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1709.append(S1RGB_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_109.append(S1RGB_imgA1D4_9[i][j])  
S1meanrefA1_1709 = np.array(S1meanrefA1_1409)
S1meanD4_109 = np.array(S1meanD4_109)

S1rgbrefA1_1709 = list()
S1rgbD4_109 = list()
for i in range(3):
    S1rgbrefA1_1709.append(S1meanrefA1_1709[:,i].mean())
    S1rgbD4_109.append(S1meanD4_109[:,i].mean())

# %% [markdown]
# ###Img 10

# %%
S1meanrefA1_110 = list()
S1meanA1_210 = list()
for i in range(S1RGB_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_110.append(S1RGB_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_210.append(S1RGB_imgA1A1_10[i][j])  
S1meanrefA1_110 = np.array(S1meanrefA1_110)
S1meanA1_210 = np.array(S1meanA1_210)

S1rgbrefA1_110 = list()
S1rgbA1_210 = list()
for i in range(3):
    S1rgbrefA1_110.append(S1meanrefA1_110[:,i].mean())
    S1rgbA1_210.append(S1meanA1_210[:,i].mean())
S1rgbrefA1_110,S1rgbA1_210

# %%
S1meanrefA1_310 = list()
S1meanA2_110 = list()
for i in range(S1RGB_imgA1A2_10.shape[0]): 
     for j in range(S1RGB_imgA1A2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_310.append(S1RGB_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_110.append(S1RGB_imgA1A2_10[i][j])  
S1meanrefA1_310 = np.array(S1meanrefA1_310)
S1meanA2_110 = np.array(S1meanA2_110)

S1rgbrefA1_310 = list()
S1rgbA2_110 = list()
for i in range(3):
    S1rgbrefA1_310.append(S1meanrefA1_310[:,i].mean())
    S1rgbA2_110.append(S1meanA2_110[:,i].mean())

# %%
S1meanrefA1_410 = list()
S1meanA3_110 = list()
for i in range(S1RGB_imgA1A3_10.shape[0]): 
     for j in range(S1RGB_imgA1A3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_410.append(S1RGB_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_110.append(S1RGB_imgA1A3_10[i][j])  
S1meanrefA1_410 = np.array(S1meanrefA1_410)
S1meanA3_110 = np.array(S1meanA3_110)

S1rgbrefA1_410 = list()
S1rgbA3_110 = list()
for i in range(3):
    S1rgbrefA1_410.append(S1meanrefA1_410[:,i].mean())
    S1rgbA3_110.append(S1meanA3_110[:,i].mean())

# %%
S1meanrefA1_510 = list()
S1meanA3_5110 = list()
for i in range(S1RGB_imgA1A3_510.shape[0]): 
     for j in range(S1RGB_imgA1A3_510.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_510.append(S1RGB_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5110.append(S1RGB_imgA1A3_510[i][j])  
S1meanrefA1_510 = np.array(S1meanrefA1_510)
S1meanA3_5110 = np.array(S1meanA3_5110)

S1rgbrefA1_510 = list()
S1rgbA3_5110 = list()
for i in range(3):
    S1rgbrefA1_510.append(S1meanrefA1_51010[:,i].mean())
    S1rgbA3_5110.append(S1meanA3_511010[:,i].mean())

# %%
S1meanrefA1_610 = list()
S1meanA4_110 = list()
for i in range(S1RGB_imgA1A4_10.shape[0]): 
     for j in range(S1RGB_imgA1A4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_610.append(S1RGB_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_110.append(S1RGB_imgA1A4_10[i][j])  
S1meanrefA1_610 = np.array(S1meanrefA1_610)
S1meanA4_110 = np.array(S1meanA4_110)

S1rgbrefA1_610 = list()
S1rgbA4_110 = list()
for i in range(3):
    S1rgbrefA1_610.append(S1meanrefA1_610[:,i].mean())
    S1rgbA4_110.append(S1meanA4_110[:,i].mean())

# %%
S1meanrefA1_710 = list()
S1meanB1_110 = list()
for i in range(S1RGB_imgA1B1_10 .shape[0]): 
     for j in range(S1RGB_imgA1B1_10 .shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_710.append(S1RGB_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_110.append(S1RGB_imgA1B1_10 [i][j])  
S1meanrefA1_710 = np.array(S1meanrefA1_710)
S1meanB1_110 = np.array(S1meanB1_110)

S1rgbrefA1_710 = list()
S1rgbB1_110 = list()
for i in range(3):
    S1rgbrefA1_710.append(S1meanrefA1_710[:,i].mean())
    S1rgbB1_110.append(S1meanB1_110[:,i].mean())

# %%
S1meanrefA1_810 = list()
S1meanB2_110 = list()
for i in range(S1RGB_imgA1B2_10 .shape[0]): 
     for j in range(S1RGB_imgA1B2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_810.append(S1RGB_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_110.append(S1RGB_imgA1B2_10[i][j])  
S1meanrefA1_810 = np.array(S1meanrefA1_810)
S1meanB2_110 = np.array(S1meanB2_110)

S1rgbrefA1_810 = list()
S1rgbB2_110 = list()
for i in range(3):
    S1rgbrefA1_810.append(S1meanrefA1_810[:,i].mean())
    S1rgbB2_110.append(S1meanB2_110[:,i].mean())

# %%
S1meanrefA1_910 = list()
S1meanB3_110 = list()
for i in range(S1RGB_imgA1B3_10.shape[0]): 
     for j in range(S1RGB_imgA1B3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_910.append(S1RGB_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_110.append(S1RGB_imgA1B3_10[i][j])  
S1meanrefA1_910 = np.array(S1meanrefA1_910)
S1meanB3_110 = np.array(S1meanB3_110)

S1rgbrefA1_910 = list()
S1rgbB3_110 = list()
for i in range(3):
    S1rgbrefA1_910.append(S1meanrefA1_910[:,i].mean())
    S1rgbB3_110.append(S1meanB3_110[:,i].mean())

# %%
S1meanrefA1_1010 = list()
S1meanB4_110 = list()
for i in range(S1RGB_imgA1B4_10.shape[0]): 
     for j in range(S1RGB_imgA1B4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1010.append(S1RGB_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_110.append(S1RGB_imgA1B4_10[i][j])  
S1meanrefA1_1010 = np.array(S1meanrefA1_1010)
S1meanB4_110 = np.array(S1meanB4_110)

S1rgbrefA1_1010 = list()
S1rgbB4_110 = list()
for i in range(3):
    S1rgbrefA1_1010.append(S1meanrefA1_1010[:,i].mean())
    S1rgbB4_110.append(S1meanB4_110[:,i].mean())

# %%
S1meanrefA1_1110 = list()
S1meanC1_110 = list()
for i in range(S1RGB_imgA1C1_10.shape[0]): 
     for j in range(S1RGB_imgA1C1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1110.append(S1RGB_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_110.append(S1RGB_imgA1C1_10[i][j])  
S1meanrefA1_1110 = np.array(S1meanrefA1_1110)
S1meanC1_110 = np.array(S1meanC1_110)

S1rgbrefA1_1110 = list()
S1rgbC1_110 = list()
for i in range(3):
    S1rgbrefA1_1110.append(S1meanrefA1_1110[:,i].mean())
    S1rgbC1_110.append(S1meanC1_110[:,i].mean())

# %%
S1meanrefA1_1210 = list()
S1meanC2_110 = list()
for i in range(S1RGB_imgA1C2_10.shape[0]): 
     for j in range(S1RGB_imgA1C2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1210.append(S1RGB_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_110.append(S1RGB_imgA1C2_10[i][j])  
S1meanrefA1_1210 = np.array(S1meanrefA1_1210)
S1meanC2_110 = np.array(S1meanC2_110)

S1rgbrefA1_1210 = list()
S1rgbC2_110 = list()
for i in range(3):
    S1rgbrefA1_1210.append(S1meanrefA1_1210[:,i].mean())
    S1rgbC2_110.append(S1meanC2_110[:,i].mean())

# %%
S1meanrefA1_1310 = list()
S1meanC3_110 = list()
for i in range(S1RGB_imgA1C3_10.shape[0]): 
     for j in range(S1RGB_imgA1C3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1310.append(S1RGB_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_110.append(S1RGB_imgA1C3_10[i][j])  
S1meanrefA1_1310 = np.array(S1meanrefA1_1310)
S1meanC3_110 = np.array(S1meanC3_110)

S1rgbrefA1_1310 = list()
S1rgbC3_110 = list()
for i in range(3):
    S1rgbrefA1_1310.append(S1meanrefA1_1310[:,i].mean())
    S1rgbC3_110.append(S1meanC3_110[:,i].mean())

# %%
S1meanrefA1_1410 = list()
S1meanC4_110 = list()
for i in range(S1RGB_imgA1C4_10.shape[0]): 
     for j in range(S1RGB_imgA1C4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1410.append(S1RGB_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_110.append(S1RGB_imgA1C4_10[i][j])  
S1meanrefA1_1410 = np.array(S1meanrefA1_1410)
S1meanC4_110 = np.array(S1meanC4_110)

S1rgbrefA1_1410 = list()
S1rgbC4_110 = list()
for i in range(3):
    S1rgbrefA1_1410.append(S1meanrefA1_1410[:,i].mean())
    S1rgbC4_110.append(S1meanC4_110[:,i].mean())

# %%
S1meanrefA1_1510 = list()
S1meanD2_110 = list()
for i in range(S1RGB_imgA1D2_10.shape[0]): 
     for j in range(S1RGB_imgA1D2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1510.append(S1RGB_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_110.append(S1RGB_imgA1D2_10[i][j])  
S1meanrefA1_1510 = np.array(S1meanrefA1_1510)
S1meanD2_110 = np.array(S1meanD2_110)

S1rgbrefA1_1510 = list()
S1rgbD2_110 = list()
for i in range(3):
    S1rgbrefA1_1510.append(S1meanrefA1_1510[:,i].mean())
    S1rgbD2_110.append(S1meanD2_110[:,i].mean())

# %%
S1meanrefA1_1610 = list()
S1meanD3_110 = list()
for i in range(S1RGB_imgA1D3_10.shape[0]): 
     for j in range(S1RGB_imgA1D3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1610.append(S1RGB_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_110.append(S1RGB_imgA1D3_10[i][j])  
S1meanrefA1_1610 = np.array(S1meanrefA1_1610)
S1meanD3_110 = np.array(S1meanD3_110)

S1rgbrefA1_1610 = list()
S1rgbD3_110 = list()
for i in range(3):
    S1rgbrefA1_1610.append(S1meanrefA1_1610[:,i].mean())
    S1rgbD3_110.append(S1meanD3_110[:,i].mean())

# %%
S1meanrefA1_1710= list()
S1meanD4_110 = list()
for i in range(S1RGB_imgA1D4_10.shape[0]): 
     for j in range(S1RGB_imgA1D4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1710.append(S1RGB_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_110.append(S1RGB_imgA1D4_10[i][j])  
S1meanrefA1_1710 = np.array(S1meanrefA1_1410)
S1meanD4_110 = np.array(S1meanD4_110)

S1rgbrefA1_1710 = list()
S1rgbD4_110 = list()
for i in range(3):
    S1rgbrefA1_1710.append(S1meanrefA1_1710[:,i].mean())
    S1rgbD4_110.append(S1meanD4_110[:,i].mean())

# %% [markdown]
# ###HSV

# %%
S1meanrefA1_1 = list()
S1meanA1_2 = list()
for i in range(S1HSV_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1.append(S1HSV_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_2.append(S1HSV_imgA1A1_1[i][j])  
S1meanrefA1_1 = np.array(S1meanrefA1_1)
S1meanA1_2 = np.array(S1meanA1_2)

S1hsvrefA1_1 = list()
S1hsvA1_2 = list()
for i in range(3):
    S1hsvrefA1_1.append(S1meanrefA1_1[:,i].mean())
    S1hsvA1_2.append(S1meanA1_2[:,i].mean())
S1hsvrefA1_1,S1hsvA1_2

# %%
S1meanrefA1_3 = list()
S1meanA2_1 = list()
for i in range(S1HSV_imgA1A2_1.shape[0]): 
     for j in range(S1HSV_imgA1A2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_3.append(S1HSV_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_1.append(S1HSV_imgA1A2_1[i][j])  
S1meanrefA1_3 = np.array(S1meanrefA1_3)
S1meanA2_1 = np.array(S1meanA2_1)

S1hsvrefA1_3 = list()
S1hsvA2_1 = list()
for i in range(3):
    S1hsvrefA1_3.append(S1meanrefA1_3[:,i].mean())
    S1hsvA2_1.append(S1meanA2_1[:,i].mean())

# %%
S1meanrefA1_4 = list()
S1meanA3_1 = list()
for i in range(S1HSV_imgA1A3_1.shape[0]): 
     for j in range(S1HSV_imgA1A3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_4.append(S1HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_1.append(S1HSV_imgA1A3_1[i][j])  
S1meanrefA1_4 = np.array(S1meanrefA1_4)
S1meanA3_1 = np.array(S1meanA3_1)

S1hsvrefA1_4 = list()
S1hsvA3_1 = list()
for i in range(3):
    S1hsvrefA1_4.append(S1meanrefA1_4[:,i].mean())
    S1hsvA3_1.append(S1meanA3_1[:,i].mean())

# %%
S1meanrefA1_5 = list()
S1meanA3_51 = list()
for i in range(S1HSV_imgA1A3_51.shape[0]): 
     for j in range(S1HSV_imgA1A3_51.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_5.append(S1HSV_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_51.append(S1HSV_imgA1A3_51[i][j])  
S1meanrefA1_5 = np.array(S1meanrefA1_5)
S1meanA3_51 = np.array(S1meanA3_51)

S1hsvrefA1_5 = list()
S1hsvA3_51 = list()
for i in range(3):
    S1hsvrefA1_5.append(S1meanrefA1_5[:,i].mean())
    S1hsvA3_51.append(S1meanA3_51[:,i].mean())

# %%
S1meanrefA1_6 = list()
S1meanA4_1 = list()
for i in range(S1HSV_imgA1A4_1.shape[0]): 
     for j in range(S1HSV_imgA1A4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_6.append(S1HSV_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_1.append(S1HSV_imgA1A4_1[i][j])  
S1meanrefA1_6 = np.array(S1meanrefA1_6)
S1meanA4_1 = np.array(S1meanA4_1)

S1hsvrefA1_6 = list()
S1hsvA4_1 = list()
for i in range(3):
    S1hsvrefA1_6.append(S1meanrefA1_6[:,i].mean())
    S1hsvA4_1.append(S1meanA4_1[:,i].mean())

# %%
S1meanrefA1_7 = list()
S1meanB1_1 = list()
for i in range(S1HSV_imgA1B1_1.shape[0]): 
     for j in range(S1HSV_imgA1B1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_7.append(S1HSV_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_1.append(S1HSV_imgA1B1_1[i][j])  
S1meanrefA1_7 = np.array(S1meanrefA1_7)
S1meanB1_1 = np.array(S1meanB1_1)

S1hsvrefA1_7 = list()
S1hsvB1_1 = list()
for i in range(3):
    S1hsvrefA1_7.append(S1meanrefA1_7[:,i].mean())
    S1hsvB1_1.append(S1meanB1_1[:,i].mean())

# %%
S1meanrefA1_8 = list()
S1meanB2_1 = list()
for i in range(S1HSV_imgA1B2_1.shape[0]): 
     for j in range(S1HSV_imgA1B2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_8.append(S1HSV_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_1.append(S1HSV_imgA1B2_1[i][j])  
S1meanrefA1_8 = np.array(S1meanrefA1_8)
S1meanB2_1 = np.array(S1meanB2_1)

S1hsvrefA1_8 = list()
S1hsvB2_1 = list()
for i in range(3):
    S1hsvrefA1_8.append(S1meanrefA1_8[:,i].mean())
    S1hsvB2_1.append(S1meanB2_1[:,i].mean())

# %%
S1meanrefA1_9 = list()
S1meanB3_1 = list()
for i in range(S1HSV_imgA1B3_1.shape[0]): 
     for j in range(S1HSV_imgA1B3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_9.append(S1HSV_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_1.append(S1HSV_imgA1B3_1[i][j])  
S1meanrefA1_9 = np.array(S1meanrefA1_9)
S1meanB3_1 = np.array(S1meanB3_1)

S1hsvrefA1_9 = list()
S1hsvB3_1 = list()
for i in range(3):
    S1hsvrefA1_9.append(S1meanrefA1_9[:,i].mean())
    S1hsvB3_1.append(S1meanB3_1[:,i].mean())

# %%
S1meanrefA1_10 = list()
S1meanB4_1 = list()
for i in range(S1HSV_imgA1B4_1.shape[0]): 
     for j in range(S1HSV_imgA1B4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_10.append(S1HSV_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_1.append(S1HSV_imgA1B4_1[i][j])  
S1meanrefA1_10 = np.array(S1meanrefA1_10)
S1meanB4_1 = np.array(S1meanB4_1)

S1hsvrefA1_10 = list()
S1hsvB4_1 = list()
for i in range(3):
    S1hsvrefA1_10.append(S1meanrefA1_10[:,i].mean())
    S1hsvB4_1.append(S1meanB4_1[:,i].mean())

# %%
S1meanrefA1_11 = list()
S1meanC1_1 = list()
for i in range(S1HSV_imgA1C1_1.shape[0]): 
     for j in range(S1HSV_imgA1C1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_11.append(S1HSV_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_1.append(S1HSV_imgA1C1_1[i][j])  
S1meanrefA1_11 = np.array(S1meanrefA1_11)
S1meanC1_1 = np.array(S1meanC1_1)

S1hsvrefA1_11 = list()
S1hsvC1_1 = list()
for i in range(3):
    S1hsvrefA1_11.append(S1meanrefA1_11[:,i].mean())
    S1hsvC1_1.append(S1meanC1_1[:,i].mean())

# %%
S1meanrefA1_12 = list()
S1meanC2_1 = list()
for i in range(S1HSV_imgA1C2_1.shape[0]): 
     for j in range(S1HSV_imgA1C2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_12.append(S1HSV_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_1.append(S1HSV_imgA1C2_1[i][j])  
S1meanrefA1_12 = np.array(S1meanrefA1_12)
S1meanC2_1 = np.array(S1meanC2_1)

S1hsvrefA1_12 = list()
S1hsvC2_1 = list()
for i in range(3):
    S1hsvrefA1_12.append(S1meanrefA1_12[:,i].mean())
    S1hsvC2_1.append(S1meanC2_1[:,i].mean())

# %%
S1meanrefA1_13 = list()
S1meanC3_1 = list()
for i in range(S1HSV_imgA1C3_1.shape[0]): 
     for j in range(S1HSV_imgA1C3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_13.append(S1HSV_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_1.append(S1HSV_imgA1C3_1[i][j])  
S1meanrefA1_13 = np.array(S1meanrefA1_13)
S1meanC3_1 = np.array(S1meanC3_1)

S1hsvrefA1_13 = list()
S1hsvC3_1 = list()
for i in range(3):
    S1hsvrefA1_13.append(S1meanrefA1_13[:,i].mean())
    S1hsvC3_1.append(S1meanC3_1[:,i].mean())

# %%
S1meanrefA1_14 = list()
S1meanC4_1 = list()
for i in range(S1HSV_imgA1C4_1.shape[0]): 
     for j in range(S1HSV_imgA1C4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_14.append(S1HSV_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_1.append(S1HSV_imgA1C4_1[i][j])  
S1meanrefA1_14 = np.array(S1meanrefA1_14)
S1meanC4_1 = np.array(S1meanC4_1)

S1hsvrefA1_14 = list()
S1hsvC4_1 = list()
for i in range(3):
    S1hsvrefA1_14.append(S1meanrefA1_14[:,i].mean())
    S1hsvC4_1.append(S1meanC4_1[:,i].mean())

# %%
S1meanrefA1_15 = list()
S1meanD2_1 = list()
for i in range(S1HSV_imgA1D2_1.shape[0]): 
     for j in range(S1HSV_imgA1D2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_15.append(S1HSV_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_1.append(S1HSV_imgA1D2_1[i][j])  
S1meanrefA1_15 = np.array(S1meanrefA1_15)
S1meanD2_1 = np.array(S1meanD2_1)

S1hsvrefA1_15 = list()
S1hsvD2_1 = list()
for i in range(3):
    S1hsvrefA1_15.append(S1meanrefA1_15[:,i].mean())
    S1hsvD2_1.append(S1meanD2_1[:,i].mean())

# %%
S1meanrefA1_16 = list()
S1meanD3_1 = list()
for i in range(S1HSV_imgA1D3_1.shape[0]): 
     for j in range(S1HSV_imgA1D3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_16.append(S1HSV_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_1.append(S1HSV_imgA1D3_1[i][j])  
S1meanrefA1_16 = np.array(S1meanrefA1_16)
S1meanD3_1 = np.array(S1meanD3_1)

S1hsvrefA1_16 = list()
S1hsvD3_1 = list()
for i in range(3):
    S1hsvrefA1_16.append(S1meanrefA1_16[:,i].mean())
    S1hsvD3_1.append(S1meanD3_1[:,i].mean())

# %%
S1meanrefA1_17= list()
S1meanD4_1 = list()
for i in range(S1HSV_imgA1D4_1.shape[0]): 
     for j in range(S1HSV_imgA1D4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_17.append(S1HSV_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_1.append(S1HSV_imgA1D4_1[i][j])  
S1meanrefA1_17 = np.array(S1meanrefA1_14)
S1meanD4_1 = np.array(S1meanD4_1)

S1hsvrefA1_17 = list()
S1hsvD4_1 = list()
for i in range(3):
    S1hsvrefA1_17.append(S1meanrefA1_17[:,i].mean())
    S1hsvD4_1.append(S1meanD4_1[:,i].mean())

# %% [markdown]
# ###Img 2

# %%
S1meanrefA1_102 = list()
S1meanA1_202 = list()
for i in range(S1HSV_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_102.append(S1HSV_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_202.append(S1HSV_imgA1A1_2[i][j])  
S1meanrefA1_102= np.array(S1meanrefA1_102)
S1meanA1_202 = np.array(S1meanA1_202)

S1hsvrefA1_102 = list()
S1hsvA1_202 = list()
for i in range(3):
    S1hsvrefA1_102.append(S1meanrefA1_1[:,i].mean())
    S1hsvA1_202.append(S1meanA1_2[:,i].mean())
S1hsvrefA1_102,S1hsvA1_202

# %%
S1meanrefA1_302 = list()
S1meanA2_102 = list()
for i in range(S1HSV_imgA1A2_2.shape[0]): 
     for j in range(S1HSV_imgA1A2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_302.append(S1HSV_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_102.append(S1HSV_imgA1A2_2[i][j])  
S1meanrefA1_302 = np.array(S1meanrefA1_3)
S1meanA2_102 = np.array(S1meanA2_1)

S1hsvrefA1_302 = list()
S1hsvA2_102 = list()
for i in range(3):
    S1hsvrefA1_302.append(S1meanrefA1_302[:,i].mean())
    S1hsvA2_102.append(S1meanA2_102[:,i].mean())

# %%
S1meanrefA1_402 = list()
S1meanA3_102 = list()
for i in range(S1HSV_imgA1A3_2.shape[0]): 
     for j in range(S1HSV_imgA1A3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_402.append(S1HSV_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_102.append(S1HSV_imgA1A3_2[i][j])  
S1meanrefA1_402= np.array(S1meanrefA1_402)
S1meanA3_102 = np.array(S1meanA3_102)

S1hsvrefA1_402 = list()
S1hsvA3_102 = list()
for i in range(3):
    S1hsvrefA1_402.append(S1meanrefA1_402[:,i].mean())
    S1hsvA3_102.append(S1meanA3_102[:,i].mean())

# %%
S1meanrefA1_502 = list()
S1meanA3_5102 = list()
for i in range(S1HSV_imgA1A3_52.shape[0]): 
     for j in range(S1HSV_imgA1A3_52.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_502.append(S1HSV_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5102.append(S1HSV_imgA1A3_52[i][j])  
S1meanrefA1_502 = np.array(S1meanrefA1_502)
S1meanA3_5102 = np.array(S1meanA3_5102)

S1hsvrefA1_502 = list()
S1hsvA3_5102 = list()
for i in range(3):
    S1hsvrefA1_502.append(S1meanrefA1_502[:,i].mean())
    S1hsvA3_5102.append(S1meanA3_5102[:,i].mean())

# %%
S1meanrefA1_602 = list()
S1meanA4_102 = list()
for i in range(S1HSV_imgA1A4_2.shape[0]): 
     for j in range(S1HSV_imgA1A4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_602.append(S1HSV_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_102.append(S1HSV_imgA1A4_2[i][j])  
S1meanrefA1_602 = np.array(S1meanrefA1_602)
S1meanA4_102 = np.array(S1meanA4_102)

S1hsvrefA1_602 = list()
S1hsvA4_102 = list()
for i in range(3):
    S1hsvrefA1_602.append(S1meanrefA1_602[:,i].mean())
    S1hsvA4_102.append(S1meanA4_102[:,i].mean())

# %%
S1meanrefA1_702 = list()
S1meanB1_102 = list()
for i in range(S1HSV_imgA1B1_2.shape[0]): 
     for j in range(S1HSV_imgA1B1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_702.append(S1HSV_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_102.append(S1HSV_imgA1B1_2[i][j])  
S1meanrefA1_702 = np.array(S1meanrefA1_702)
S1meanB1_102 = np.array(S1meanB1_102)

S1hsvrefA1_702 = list()
S1hsvB1_102 = list()
for i in range(3):
    S1hsvrefA1_702.append(S1meanrefA1_702[:,i].mean())
    S1hsvB1_102.append(S1meanB1_102[:,i].mean())

# %%
S1meanrefA1_802 = list()
S1meanB2_102 = list()
for i in range(S1HSV_imgA1B2_2.shape[0]): 
     for j in range(S1HSV_imgA1B2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_802.append(S1HSV_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_102.append(S1HSV_imgA1B2_2[i][j])  
S1meanrefA1_802 = np.array(S1meanrefA1_802)
S1meanB2_102 = np.array(S1meanB2_102)

S1hsvrefA1_802 = list()
S1hsvB2_102 = list()
for i in range(3):
    S1hsvrefA1_802.append(S1meanrefA1_802[:,i].mean())
    S1hsvB2_102.append(S1meanB2_102[:,i].mean())

# %%
S1meanrefA1_902 = list()
S1meanB3_102 = list()
for i in range(S1HSV_imgA1B3_2.shape[0]): 
     for j in range(S1HSV_imgA1B3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_902.append(S1HSV_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_102.append(S1HSV_imgA1B3_2[i][j])  
S1meanrefA1_902 = np.array(S1meanrefA1_902)
S1meanB3_102 = np.array(S1meanB3_102)

S1hsvrefA1_902 = list()
S1hsvB3_102 = list()
for i in range(3):
    S1hsvrefA1_902.append(S1meanrefA1_902[:,i].mean())
    S1hsvB3_102.append(S1meanB3_102[:,i].mean())

# %%
S1meanrefA1_1002 = list()
S1meanB4_102 = list()
for i in range(S1HSV_imgA1B4_2.shape[0]): 
     for j in range(S1HSV_imgA1B4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1002.append(S1HSV_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_102.append(S1HSV_imgA1B4_2[i][j])  
S1meanrefA1_1002 = np.array(S1meanrefA1_1002)
S1meanB4_102 = np.array(S1meanB4_102)

S1hsvrefA1_1002 = list()
S1hsvB4_102 = list()
for i in range(3):
    S1hsvrefA1_10.append(S1meanrefA1_10[:,i].mean())
    S1hsvB4_1.append(S1meanB4_1[:,i].mean())

# %%
S1meanrefA1_1102 = list()
S1meanC1_102 = list()
for i in range(S1HSV_imgA1C1_2.shape[0]): 
     for j in range(S1HSV_imgA1C1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1102.append(S1HSV_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_102.append(S1HSV_imgA1C1_2[i][j])  
S1meanrefA1_1102 = np.array(S1meanrefA1_1102)
S1meanC1_102= np.array(S1meanC1_102)

S1hsvrefA1_1102 = list()
S1hsvC1_102 = list()
for i in range(3):
    S1hsvrefA1_1102.append(S1meanrefA1_1102[:,i].mean())
    S1hsvC1_102.append(S1meanC1_102[:,i].mean())

# %%
S1meanrefA1_1202 = list()
S1meanC2_102 = list()
for i in range(S1HSV_imgA1C2_2.shape[0]): 
     for j in range(S1HSV_imgA1C2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1202.append(S1HSV_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_102.append(S1HSV_imgA1C2_2[i][j])  
S1meanrefA1_1202 = np.array(S1meanrefA1_1202)
S1meanC2_102 = np.array(S1meanC2_102)

S1hsvrefA1_1202 = list()
S1hsvC2_102 = list()
for i in range(3):
    S1hsvrefA1_1202.append(S1meanrefA1_1202[:,i].mean())
    S1hsvC2_102.append(S1meanC2_102[:,i].mean())

# %%
S1meanrefA1_1302 = list()
S1meanC3_102 = list()
for i in range(S1HSV_imgA1C3_.shape[0]): 
     for j in range(S1HSV_imgA1C3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1302.append(S1HSV_imgA1C3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_102.append(S1HSV_imgA1C3_[i][j])  
S1meanrefA1_1302 = np.array(S1meanrefA1_1302)
S1meanC3_102 = np.array(S1meanC3_102)

S1hsvrefA1_1302 = list()
S1hsvC3_102 = list()
for i in range(3):
    S1hsvrefA1_1302.append(S1meanrefA1_1302[:,i].mean())
    S1hsvC3_102.append(S1meanC3_102[:,i].mean())

# %%
S1meanrefA1_1402 = list()
S1meanC4_102 = list()
for i in range(S1HSV_imgA1C4_2.shape[0]): 
     for j in range(S1HSV_imgA1C4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1402.append(S1HSV_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_102.append(S1HSV_imgA1C4_2[i][j])  
S1meanrefA1_1402 = np.array(S1meanrefA1_1402)
S1meanC4_102 = np.array(S1meanC4_102)

S1hsvrefA1_1402 = list()
S1hsvC4_102 = list()
for i in range(3):
    S1hsvrefA1_1402.append(S1meanrefA1_1402[:,i].mean())
    S1hsvC4_102.append(S1meanC4_102[:,i].mean())

# %%
S1meanrefA1_1502 = list()
S1meanD2_102 = list()
for i in range(S1HSV_imgA1D2_2.shape[0]): 
     for j in range(S1HSV_imgA1D2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1502.append(S1HSV_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_102.append(S1HSV_imgA1D2_2[i][j])  
S1meanrefA1_1502 = np.array(S1meanrefA1_1502)
S1meanD2_102 = np.array(S1meanD2_102)

S1hsvrefA1_1502 = list()
S1hsvD2_102 = list()
for i in range(3):
    S1hsvrefA1_1502.append(S1meanrefA1_1502[:,i].mean())
    S1hsvD2_102.append(S1meanD2_102[:,i].mean())

# %%
S1meanrefA1_1602 = list()
S1meanD3_102 = list()
for i in range(S1HSV_imgA1D3_2.shape[0]): 
     for j in range(S1HSV_imgA1D3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1602.append(S1HSV_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_102.append(S1HSV_imgA1D3_2[i][j])  
S1meanrefA1_1602 = np.array(S1meanrefA1_1602)
S1meanD3_102 = np.array(S1meanD3_102)

S1hsvrefA1_1602 = list()
S1hsvD3_102 = list()
for i in range(3):
    S1hsvrefA1_1602.append(S1meanrefA1_1602[:,i].mean())
    S1hsvD3_102.append(S1meanD3_102[:,i].mean())

# %%
S1meanrefA1_1702= list()
S1meanD4_102 = list()
for i in range(S1HSV_imgA1D4_2.shape[0]): 
     for j in range(S1HSV_imgA1D4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1702.append(S1HSV_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_102.append(S1HSV_imgA1D4_2[i][j])  
S1meanrefA1_1702 = np.array(S1meanrefA1_1702)
S1meanD4_102 = np.array(S1meanD4_102)

S1hsvrefA1_1702 = list()
S1hsvD4_102 = list()
for i in range(3):
    S1hsvrefA1_1702.append(S1meanrefA1_1702[:,i].mean())
    S1hsvD4_102.append(S1meanD4_102[:,i].mean())

# %% [markdown]
# ###Img 3

# %%
S1meanrefA1_103 = list()
S1meanA1_203 = list()
for i in range(S1HSV_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_103.append(S1HSV_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_203.append(S1HSV_imgA1A1_3[i][j])  
S1meanrefA1_103 = np.array(S1meanrefA1_103)
S1meanA1_203 = np.array(S1meanA1_203)

S1hsvrefA1_103 = list()
S1hsvA1_203 = list()
for i in range(3):
    S1hsvrefA1_103.append(S1meanrefA1_103[:,i].mean())
    S1hsvA1_203.append(S1meanA1_203[:,i].mean())
S1hsvrefA1_103,S1hsvA1_203

# %%
S1meanrefA1_303 = list()
S1meanA2_103 = list()
for i in range(S1HSV_imgA1A2_3.shape[0]): 
     for j in range(S1HSV_imgA1A2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_303.append(S1HSV_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_103.append(S1HSV_imgA1A2_3[i][j])  
S1meanrefA1_303 = np.array(S1meanrefA1_303)
S1meanA2_103 = np.array(S1meanA2_103)

S1hsvrefA1_303 = list()
S1hsvA2_103 = list()
for i in range(3):
    S1hsvrefA1_303.append(S1meanrefA1_303[:,i].mean())
    S1hsvA2_103.append(S1meanA2_103[:,i].mean())

# %%
S1meanrefA1_403 = list()
S1meanA3_103 = list()
for i in range(S1HSV_imgA1A3_3.shape[0]): 
     for j in range(S1HSV_imgA1A3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_403append(S1HSV_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_103.append(S1HSV_imgA1A3_3[i][j])  
S1meanrefA1_403 = np.array(S1meanrefA1_403)
S1meanA3_103 = np.array(S1meanA3_103)

S1hsvrefA1_403 = list()
S1hsvA3_103 = list()
for i in range(3):
    S1hsvrefA1_403.append(S1meanrefA1_403[:,i].mean())
    S1hsvA3_103.append(S1meanA3_103[:,i].mean())

# %%
S1meanrefA1_503 = list()
S1meanA3_5103 = list()
for i in range(S1HSV_imgA1A3_53.shape[0]): 
     for j in range(S1HSV_imgA1A3_53.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_503.append(S1HSV_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5103.append(S1HSV_imgA1A3_53[i][j])  
S1meanrefA1_503 = np.array(S1meanrefA1_503)
S1meanA3_5103 = np.array(S1meanA3_5103)

S1hsvrefA1_503 = list()
S1hsvA3_5103 = list()
for i in range(3):
    S1hsvrefA1_503.append(S1meanrefA1_503[:,i].mean())
    S1hsvA3_5103.append(S1meanA3_5103[:,i].mean())

# %%
S1meanrefA1_603 = list()
S1meanA4_103 = list()
for i in range(S1HSV_imgA1A4_303.shape[0]): 
     for j in range(S1HSV_imgA1A4_303.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_603.append(S1HSV_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_103.append(S1HSV_imgA1A4_3[i][j])  
S1meanrefA1_603 = np.array(S1meanrefA1_603)
S1meanA4_103 = np.array(S1meanA4_103)

S1hsvrefA1_603 = list()
S1hsvA4_103 = list()
for i in range(3):
    S1hsvrefA1_603.append(S1meanrefA1_603[:,i].mean())
    S1hsvA4_103.append(S1meanA4_103[:,i].mean())

# %%
S1meanrefA1_703 = list()
S1meanB1_103 = list()
for i in range(S1HSV_imgA1B1_3.shape[0]): 
     for j in range(S1HSV_imgA1B1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_703.append(S1HSV_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_103.append(S1HSV_imgA1B1_3[i][j])  
S1meanrefA1_703 = np.array(S1meanrefA1_703)
S1meanB1_103 = np.array(S1meanB1_103)

S1hsvrefA1_703 = list()
S1hsvB1_103 = list()
for i in range(3):
    S1hsvrefA1_703.append(S1meanrefA1_703[:,i].mean())
    S1hsvB1_103.append(S1meanB1_103[:,i].mean())

# %%
S1meanrefA1_803 = list()
S1meanB2_103 = list()
for i in range(S1HSV_imgA1B2_3.shape[0]): 
     for j in range(S1HSV_imgA1B2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_803.append(S1HSV_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_103.append(S1HSV_imgA1B2_3[i][j])  
S1meanrefA1_803 = np.array(S1meanrefA1_803)
S1meanB2_103 = np.array(S1meanB2_103

S1hsvrefA1_803 = list()
S1hsvB2_103 = list()
for i in range(3):
    S1hsvrefA1_8.append(S1meanrefA1_803[:,i].mean())
    S1hsvB2_1.append(S1meanB2_103[:,i].mean())

# %%
S1meanrefA1_903 = list()
S1meanB3_103 = list()
for i in range(S1HSV_imgA1B3_3.shape[0]): 
     for j in range(S1HSV_imgA1B3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_903.append(S1HSV_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_103.append(S1HSV_imgA1B3_3[i][j])  
S1meanrefA1_903 = np.array(S1meanrefA1_903)
S1meanB3_103 = np.array(S1meanB3_103)

S1hsvrefA1_903 = list()
S1hsvB3_103 = list()
for i in range(3):
    S1hsvrefA1_903.append(S1meanrefA1_9[:,i].mean())
    S1hsvB3_103.append(S1meanB3_1[:,i].mean())

# %%
S1meanrefA1_1003 = list()
S1meanB4_103 = list()
for i in range(S1HSV_imgA1B4_3.shape[0]): 
     for j in range(S1HSV_imgA1B4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1003.append(S1HSV_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_103.append(S1HSV_imgA1B4_3[i][j])  
S1meanrefA1_1003 = np.array(S1meanrefA1_1003)
S1meanB4_103 = np.array(S1meanB4_103)

S1hsvrefA1_1003 = list()
S1hsvB4_103 = list()
for i in range(3):
    S1hsvrefA1_1003.append(S1meanrefA1_1003[:,i].mean())
    S1hsvB4_103.append(S1meanB4_103[:,i].mean())

# %%
S1meanrefA1_1103 = list()
S1meanC1_103 = list()
for i in range(S1HSV_imgA1C1_3.shape[0]): 
     for j in range(S1HSV_imgA1C1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1103.append(S1HSV_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_103.append(S1HSV_imgA1C1_3[i][j])  
S1meanrefA1_1103 = np.array(S1meanrefA1_1103)
S1meanC1_103 = np.array(S1meanC1_103)

S1hsvrefA1_11 = list()
S1hsvC1_103 = list()
for i in range(3):
    S1hsvrefA1_1103.append(S1meanrefA1_1103[:,i].mean())
    S1hsvC1_103.append(S1meanC1_103[:,i].mean())

# %%
S1meanrefA1_1203 = list()
S1meanC2_103 = list()
for i in range(S1HSV_imgA1C2_3.shape[0]): 
     for j in range(S1HSV_imgA1C2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1203.append(S1HSV_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_103.append(S1HSV_imgA1C2_3[i][j])  
S1meanrefA1_1203 = np.array(S1meanrefA1_1203)
S1meanC2_103 = np.array(S1meanC2_103)

S1hsvrefA1_1203 = list()
S1hsvC2_103 = list()
for i in range(3):
    S1hsvrefA1_1203.append(S1meanrefA1_1203[:,i].mean())
    S1hsvC2_103.append(S1meanC2_103[:,i].mean())

# %%
S1meanrefA1_1303 = list()
S1meanC3_103 = list()
for i in range(S1HSV_imgA1C3_3.shape[0]): 
     for j in range(S1HSV_imgA1C3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1303.append(S1HSV_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_103.append(S1HSV_imgA1C3_3[i][j])  
S1meanrefA1_1303 = np.array(S1meanrefA1_130303)
S1meanC3_103 = np.array(S1meanC3_103)

S1hsvrefA1_1303 = list()
S1hsvC3_103 = list()
for i in range(3):
    S1hsvrefA1_1303.append(S1meanrefA1_1303[:,i].mean())
    S1hsvC3_103.append(S1meanC3_103[:,i].mean())

# %%
S1meanrefA1_1403 = list()
S1meanC4_103 = list()
for i in range(S1HSV_imgA1C4_3.shape[0]): 
     for j in range(S1HSV_imgA1C4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_14.append(S1HSV_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_103.append(S1HSV_imgA1C4_3[i][j])  
S1meanrefA1_1403 = np.array(S1meanrefA1_1403)
S1meanC4_103 = np.array(S1meanC4_103)

S1hsvrefA1_1403 = list()
S1hsvC4_103 = list()
for i in range(3):
    S1hsvrefA1_1403.append(S1meanrefA1_1403[:,i].mean())
    S1hsvC4_103.append(S1meanC4_103[:,i].mean())

# %%
S1meanrefA1_1503 = list()
S1meanD2_103 = list()
for i in range(S1HSV_imgA1D2_303.shape[0]): 
     for j in range(S1HSV_imgA1D2_303.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1503.append(S1HSV_imgA1D2_303[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_103.append(S1HSV_imgA1D2_303[i][j])  
S1meanrefA1_1503 = np.array(S1meanrefA1_1503)
S1meanD2_103 = np.array(S1meanD2_103)

S1hsvrefA1_1503 = list()
S1hsvD2_103 = list()
for i in range(3):
    S1hsvrefA1_1503.append(S1meanrefA1_1503[:,i].mean())
    S1hsvD2_103.append(S1meanD2_103[:,i].mean())

# %%
S1meanrefA1_1603 = list()
S1meanD3_103 = list()
for i in range(S1HSV_imgA1D3_3.shape[0]): 
     for j in range(S1HSV_imgA1D3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_16.append(S1HSV_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_1.append(S1HSV_imgA1D3_3[i][j])  
S1meanrefA1_1603 = np.array(S1meanrefA1_1603)
S1meanD3_103 = np.array(S1meanD3_103)

S1hsvrefA1_1603 = list()
S1hsvD3_103 = list()
for i in range(3):
    S1hsvrefA1_1603.append(S1meanrefA1_1603[:,i].mean())
    S1hsvD3_103.append(S1meanD3_103[:,i].mean())

# %%
S1meanrefA1_1703= list()
S1meanD4_103 = list()
for i in range(S1HSV_imgA1D4_3.shape[0]): 
     for j in range(S1HSV_imgA1D4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1703.append(S1HSV_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_103.append(S1HSV_imgA1D4_3[i][j])  
S1meanrefA1_1703 = np.array(S1meanrefA1_1403)
S1meanD4_103 = np.array(S1meanD4_103)

S1hsvrefA1_1703 = list()
S1hsvD4_103 = list()
for i in range(3):
    S1hsvrefA1_1703.append(S1meanrefA1_1703[:,i].mean())
    S1hsvD4_103.append(S1meanD4_103[:,i].mean())

# %% [markdown]
# ###Img 4

# %%
S1meanrefA1_104 = list()
S1meanA1_204 = list()
for i in range(S1HSV_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_104.append(S1HSV_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_204.append(S1HSV_imgA1A1_[i][j])  
S1meanrefA1_104 = np.array(S1meanrefA1_104)
S1meanA1_204 = np.array(S1meanA1_204)

S1hsvrefA1_104 = list()
S1hsvA1_204 = list()
for i in range(3):
    S1hsvrefA1_104.append(S1meanrefA1_104[:,i].mean())
    S1hsvA1_204.append(S1meanA1_204[:,i].mean())
S1hsvrefA1_104,S1hsvA1_204

# %%
S1meanrefA1_304 = list()
S1meanA2_104 = list()
for i in range(S1HSV_imgA1A2_4.shape[0]): 
     for j in range(S1HSV_imgA1A2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_304.append(S1HSV_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_104.append(S1HSV_imgA1A2_4[i][j])  
S1meanrefA1_304 = np.array(S1meanrefA1_304)
S1meanA2_104 = np.array(S1meanA2_104)

S1hsvrefA1_304 = list()
S1hsvA2_104 = list()
for i in range(3):
    S1hsvrefA1_304.append(S1meanrefA1_304[:,i].mean())
    S1hsvA2_104.append(S1meanA2_104[:,i].mean())

# %%
S1meanrefA1_404 = list()
S1meanA3_104 = list()
for i in range(S1HSV_imgA1A3_4.shape[0]): 
     for j in range(S1HSV_imgA1A3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_404.append(S1HSV_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_104.append(S1HSV_imgA1A3_4[i][j])  
S1meanrefA1_404 = np.array(S1meanrefA1_404)
S1meanA3_104 = np.array(S1meanA3_104)

S1hsvrefA1_404 = list()
S1hsvA3_104 = list()
for i in range(3):
    S1hsvrefA1_404.append(S1meanrefA1_404[:,i].mean())
    S1hsvA3_104.append(S1meanA3_104[:,i].mean())

# %%
S1meanrefA1_504 = list()
S1meanA3_5104 = list()
for i in range(S1HSV_imgA1A3_54.shape[0]): 
     for j in range(S1HSV_imgA1A3_54.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_504.append(S1HSV_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5104.append(S1HSV_imgA1A3_54[i][j])  
S1meanrefA1_504 = np.array(S1meanrefA1_504)
S1meanA3_5104 = np.array(S1meanA3_5104)

S1hsvrefA1_504 = list()
S1hsvA3_5104 = list()
for i in range(3):
    S1hsvrefA1_504.append(S1meanrefA1_504[:,i].mean())
    S1hsvA3_5104.append(S1meanA3_5104[:,i].mean())

# %%
S1meanrefA1_604 = list()
S1meanA4_104 = list()
for i in range(S1HSV_imgA1A4_4.shape[0]): 
     for j in range(S1HSV_imgA1A4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_604.append(S1HSV_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_104.append(S1HSV_imgA1A4_[i][j])  
S1meanrefA1_604 = np.array(S1meanrefA1_604)
S1meanA4_104 = np.array(S1meanA4_104)

S1hsvrefA1_604 = list()
S1hsvA4_104 = list()
for i in range(3):
    S1hsvrefA1_604.append(S1meanrefA1_604[:,i].mean())
    S1hsvA4_104.append(S1meanA4_104[:,i].mean())

# %%
S1meanrefA1_704 = list()
S1meanB1_104 = list()
for i in range(S1HSV_imgA1B1_4.shape[0]): 
     for j in range(S1HSV_imgA1B1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_7.append(S1HSV_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_1.append(S1HSV_imgA1B1_4[i][j])  
S1meanrefA1_704 = np.array(S1meanrefA1_704)
S1meanB1_104 = np.array(S1meanB1_104)

S1hsvrefA1_704 = list()
S1hsvB1_104 = list()
for i in range(3):
    S1hsvrefA1_704.append(S1meanrefA1_704[:,i].mean())
    S1hsvB1_104.append(S1meanB1_104[:,i].mean())

# %%
S1meanrefA1_804 = list()
S1meanB2_104 = list()
for i in range(S1HSV_imgA1B2_4.shape[0]): 
     for j in range(S1HSV_imgA1B2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_804.append(S1HSV_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_104.append(S1HSV_imgA1B2_4[i][j])  
S1meanrefA1_804 = np.array(S1meanrefA1_804)
S1meanB2_104 = np.array(S1meanB2_104)

S1hsvrefA1_804 = list()
S1hsvB2_104 = list()
for i in range(3):
    S1hsvrefA1_804.append(S1meanrefA1_804[:,i].mean())
    S1hsvB2_104.append(S1meanB2_104[:,i].mean())

# %%
S1meanrefA1_904 = list()
S1meanB3_104 = list()
for i in range(S1HSV_imgA1B3_404.shape[0]): 
     for j in range(S1HSV_imgA1B3_404.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_904.append(S1HSV_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_104.append(S1HSV_imgA1B3_4[i][j])  
S1meanrefA1_904 = np.array(S1meanrefA1_904)
S1meanB3_104 = np.array(S1meanB3_104)

S1hsvrefA1_904 = list()
S1hsvB3_104 = list()
for i in range(3):
    S1hsvrefA1_904.append(S1meanrefA1_904[:,i].mean())
    S1hsvB3_104.append(S1meanB3_104[:,i].mean())

# %%
S1meanrefA1_1004 = list()
S1meanB4_104 = list()
for i in range(S1HSV_imgA1B4_4.shape[0]): 
     for j in range(S1HSV_imgA1B4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1004.append(S1HSV_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_104.append(S1HSV_imgA1B4_4[i][j])  
S1meanrefA1_1004 = np.array(S1meanrefA1_1004)
S1meanB4_104 = np.array(S1meanB4_104)

S1hsvrefA1_1004 = list()
S1hsvB4_104= list()
for i in range(3):
    S1hsvrefA1_1004.append(S1meanrefA1_1004[:,i].mean())
    S1hsvB4_104.append(S1meanB4_104[:,i].mean())

# %%
S1meanrefA1_1104 = list()
S1meanC1_104 = list()
for i in range(S1HSV_imgA1C1_4.shape[0]): 
     for j in range(S1HSV_imgA1C1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1104.append(S1HSV_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_104.append(S1HSV_imgA1C1_4[i][j])  
S1meanrefA1_1104 = np.array(S1meanrefA1_1104)
S1meanC1_104 = np.array(S1meanC1_104)

S1hsvrefA1_1104 = list()
S1hsvC1_104 = list()
for i in range(3):
    S1hsvrefA1_1104.append(S1meanrefA1_1104[:,i].mean())
    S1hsvC1_104.append(S1meanC1_104[:,i].mean())

# %%
S1meanrefA1_1204 = list()
S1meanC2_104 = list()
for i in range(S1HSV_imgA1C2_4.shape[0]): 
     for j in range(S1HSV_imgA1C2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1204.append(S1HSV_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_104.append(S1HSV_imgA1C2_4[i][j])  
S1meanrefA1_1204 = np.array(S1meanrefA1_1204)
S1meanC2_1อ = np.array(S1meanC2_104)

S1hsvrefA1_1204 = list()
S1hsvC2_104 = list()
for i in range(3):
    S1hsvrefA1_1204.append(S1meanrefA1_1204[:,i].mean())
    S1hsvC2_104.append(S1meanC2_104[:,i].mean())

# %%
S1meanrefA1_1304 = list()
S1meanC3_104 = list()
for i in range(S1HSV_imgA1C3_4.shape[0]): 
     for j in range(S1HSV_imgA1C3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1304.append(S1HSV_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_104.append(S1HSV_imgA1C3_4[i][j])  
S1meanrefA1_1304 = np.array(S1meanrefA1_1304)
S1meanC3_104 = np.array(S1meanC3_104)

S1hsvrefA1_1304 = list()
S1hsvC3_104 = list()
for i in range(3):
    S1hsvrefA1_1304.append(S1meanrefA1_1304[:,i].mean())
    S1hsvC3_104.append(S1meanC3_104[:,i].mean())

# %%
S1meanrefA1_1404 = list()
S1meanC4_104 = list()
for i in range(S1HSV_imgA1C4_4.shape[0]): 
     for j in range(S1HSV_imgA1C4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1404.append(S1HSV_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_104.append(S1HSV_imgA1C4_4[i][j])  
S1meanrefA1_1404 = np.array(S1meanrefA1_14)
S1meanC4_104 = np.array(S1meanC4_1)

S1hsvrefA1_1404 = list()
S1hsvC4_104 = list()
for i in range(3):
    S1hsvrefA1_1404.append(S1meanrefA1_1404[:,i].mean())
    S1hsvC4_104.append(S1meanC4_104[:,i].mean())

# %%
S1meanrefA1_1504 = list()
S1meanD2_104 = list()
for i in range(S1HSV_imgA1D2_4.shape[0]): 
     for j in range(S1HSV_imgA1D2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1504.append(S1HSV_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_104.append(S1HSV_imgA1D2_4[i][j])  
S1meanrefA1_1504 = np.array(S1meanrefA1_1504)
S1meanD2_104 = np.array(S1meanD2_104)

S1hsvrefA1_1504 = list()
S1hsvD2_104 = list()
for i in range(3):
    S1hsvrefA1_1504.append(S1meanrefA1_1504[:,i].mean())
    S1hsvD2_104.append(S1meanD2_104[:,i].mean())

# %%
S1meanrefA1_1604 = list()
S1meanD3_104 = list()
for i in range(S1HSV_imgA1D3_4.shape[0]): 
     for j in range(S1HSV_imgA1D3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1604.append(S1HSV_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_104.append(S1HSV_imgA1D3_4[i][j])  
S1meanrefA1_1604 = np.array(S1meanrefA1_1604)
S1meanD3_104 = np.array(S1meanD3_104)

S1hsvrefA1_1604 = list()
S1hsvD3_104 = list()
for i in range(3):
    S1hsvrefA1_1604.append(S1meanrefA1_1604[:,i].mean())
    S1hsvD3_104.append(S1meanD3_104[:,i].mean())

# %%
S1meanrefA1_1704= list()
S1meanD4_104 = list()
for i in range(S1HSV_imgA1D4_4.shape[0]): 
     for j in range(S1HSV_imgA1D4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1704.append(S1HSV_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_104.append(S1HSV_imgA1D4_4[i][j])  
S1meanrefA1_1704 = np.array(S1meanrefA1_1404)
S1meanD4_104 = np.array(S1meanD4_104)

S1hsvrefA1_1704 = list()
S1hsvD4_104 = list()
for i in range(3):
    S1hsvrefA1_1704.append(S1meanrefA1_1704[:,i].mean())
    S1hsvD4_104.append(S1meanD4_104[:,i].mean())

# %% [markdown]
# ###Img 5

# %%
S1meanrefA1_105 = list()
S1meanA1_205 = list()
for i in range(S1HSV_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_105.append(S1HSV_imgA1A1_505[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_205.append(S1HSV_imgA1A1_505[i][j])  
S1meanrefA1_105 = np.array(S1meanrefA1_105)
S1meanA1_205 = np.array(S1meanA1_205)

S1hsvrefA1_105 = list()
S1hsvA1_205 = list()
for i in range(3):
    S1hsvrefA1_105.append(S1meanrefA1_105[:,i].mean())
    S1hsvA1_205.append(S1meanA1_205[:,i].mean())
S1hsvrefA1_105,S1hsvA1_205

# %%
S1meanrefA1_305 = list()
S1meanA2_105 = list()
for i in range(S1HSV_imgA1A2_5.shape[0]): 
     for j in range(S1HSV_imgA1A2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_305.append(S1HSV_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_105.append(S1HSV_imgA1A2_5[i][j])  
S1meanrefA1_305 = np.array(S1meanrefA1_305)
S1meanA2_105 = np.array(S1meanA2_105)

S1hsvrefA1_305 = list()
S1hsvA2_105 = list()
for i in range(3):
    S1hsvrefA1_305.append(S1meanrefA1_305[:,i].mean())
    S1hsvA2_105.append(S1meanA2_105[:,i].mean())

# %%
S1meanrefA1_405 = list()
S1meanA3_105 = list()
for i in range(S1HSV_imgA1A3_5.shape[0]): 
     for j in range(S1HSV_imgA1A3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_405.append(S1HSV_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_105.append(S1HSV_imgA1A3_5[i][j])  
S1meanrefA1_405 = np.array(S1meanrefA1_405)
S1meanA3_1อ = np.array(S1meanA3_105)

S1hsvrefA1_405 = list()
S1hsvA3_105= list()
for i in range(3):
    S1hsvrefA1_405.append(S1meanrefA1_405[:,i].mean())
    S1hsvA3_105.append(S1meanA3_105[:,i].mean())

# %%
S1meanrefA1_505 = list()
S1meanA3_5105 = list()
for i in range(S1HSV_imgA1A3_55.shape[0]): 
     for j in range(S1HSV_imgA1A3_55.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_505.append(S1HSV_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5105.append(S1HSV_imgA1A3_55[i][j])  
S1meanrefA1_505 = np.array(S1meanrefA1_505)
S1meanA3_5105 = np.array(S1meanA3_5105)

S1hsvrefA1_505= list()
S1hsvA3_5105 = list()
for i in range(3):
    S1hsvrefA1_505.append(S1meanrefA1_505[:,i].mean())
    S1hsvA3_5105.append(S1meanA3_5105[:,i].mean())

# %%
S1meanrefA1_605 = list()
S1meanA4_105= list()
for i in range(S1HSV_imgA1A4_5.shape[0]): 
     for j in range(S1HSV_imgA1A4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_605.append(S1HSV_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_105.append(S1HSV_imgA1A4_5[i][j])  
S1meanrefA1_605 = np.array(S1meanrefA1_605)
S1meanA4_105 = np.array(S1meanA4_105)

S1hsvrefA1_6อ = list()
S1hsvA4_105 = list()
for i in range(3):
    S1hsvrefA1_6อ.append(S1meanrefA1_605[:,i].mean())
    S1hsvA4_105.append(S1meanA4_105[:,i].mean())

# %%
S1meanrefA1_705 = list()
S1meanB1_105 = list()
for i in range(S1HSV_imgA1B1_5.shape[0]): 
     for j in range(S1HSV_imgA1B1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_705append(S1HSV_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_105.append(S1HSV_imgA1B1_5[i][j])  
S1meanrefA1_705 = np.array(S1meanrefA1_705)
S1meanB1_105 = np.array(S1meanB1_105)

S1hsvrefA1_705 = list()
S1hsvB1_105 = list()
for i in range(3):
    S1hsvrefA1_705.append(S1meanrefA1_7[:,i].mean())
    S1hsvB1_105.append(S1meanB1_1[:,i].mean())

# %%
S1meanrefA1_805 = list()
S1meanB2_105 = list()
for i in range(S1HSV_imgA1B2_5.shape[0]): 
     for j in range(S1HSV_imgA1B2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_8อ.append(S1HSV_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_105.append(S1HSV_imgA1B2_5[i][j])  
S1meanrefA1_805 = np.array(S1meanrefA1_8อ)
S1meanB2_105 = np.array(S1meanB2_105)

S1hsvrefA1_805 = list()
S1hsvB2_105 = list()
for i in range(3):
    S1hsvrefA1_805.append(S1meanrefA1_805[:,i].mean())
    S1hsvB2_105.append(S1meanB2_105[:,i].mean())

# %%
S1meanrefA1_905 = list()
S1meanB3_105= list()
for i in range(S1HSV_imgA1B3_5.shape[0]): 
     for j in range(S1HSV_imgA1B3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_905.append(S1HSV_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_105.append(S1HSV_imgA1B3_5[i][j])  
S1meanrefA1_905 = np.array(S1meanrefA1_905)
S1meanB3_105 = np.array(S1meanB3_105)

S1hsvrefA1_905 = list()
S1hsvB3_105 = list()
for i in range(3):
    S1hsvrefA1_905.append(S1meanrefA1_905[:,i].mean())
    S1hsvB3_105.append(S1meanB3_105[:,i].mean())

# %%
S1meanrefA1_1005 = list()
S1meanB4_105 = list()
for i in range(S1HSV_imgA1B4_5.shape[0]): 
     for j in range(S1HSV_imgA1B4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1005.append(S1HSV_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_105.append(S1HSV_imgA1B4_5[i][j])  
S1meanrefA1_1005 = np.array(S1meanrefA1_1005)
S1meanB4_105 = np.array(S1meanB4_105)

S1hsvrefA1_1005 = list()
S1hsvB4_105 = list()
for i in range(3):
    S1hsvrefA1_1005.append(S1meanrefA1_1005[:,i].mean())
    S1hsvB4_105.append(S1meanB4_105[:,i].mean())

# %%
S1meanrefA1_1105 = list()
S1meanC1_105 = list()
for i in range(S1HSV_imgA1C1_5.shape[0]): 
     for j in range(S1HSV_imgA1C1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1105.append(S1HSV_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_105.append(S1HSV_imgA1C1_5[i][j])  
S1meanrefA1_1105 = np.array(S1meanrefA1_1105)
S1meanC1_105 = np.array(S1meanC1_105)

S1hsvrefA1_1105 = list()
S1hsvC1_105= list()
for i in range(3):
    S1hsvrefA1_1105.append(S1meanrefA1_1105[:,i].mean())
    S1hsvC1_105.append(S1meanC1_105[:,i].mean())

# %%
S1meanrefA1_1205 = list()
S1meanC2_105 = list()
for i in range(S1HSV_imgA1C2_5.shape[0]): 
     for j in range(S1HSV_imgA1C2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1205.append(S1HSV_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_105append(S1HSV_imgA1C2_5[i][j])  
S1meanrefA1_1205 = np.array(S1meanrefA1_1205)
S1meanC2_105 = np.array(S1meanC2_105)

S1hsvrefA1_1205 = list()
S1hsvC2_105 = list()
for i in range(3):
    S1hsvrefA1_1205.append(S1meanrefA1_1205[:,i].mean())
    S1hsvC2_105.append(S1meanC2_105[:,i].mean())

# %%
S1meanrefA1_1305 = list()
S1meanC3_105 = list()
for i in range(S1HSV_imgA1C3_5.shape[0]): 
     for j in range(S1HSV_imgA1C3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1305 .append(S1HSV_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_105 .append(S1HSV_imgA1C3_5[i][j])  
S1meanrefA1_1305 = np.array(S1meanrefA1_1305)
S1meanC3_105 = np.array(S1meanC3_105)

S1hsvrefA1_1305 = list()
S1hsvC3_105 = list()
for i in range(3):
    S1hsvrefA1_1305.append(S1meanrefA1_1305[:,i].mean())
    S1hsvC3_105append(S1meanC3_105[:,i].mean())

# %%
S1meanrefA1_1405 = list()
S1meanC4_105 = list()
for i in range(S1HSV_imgA1C4_5.shape[0]): 
     for j in range(S1HSV_imgA1C4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1405.append(S1HSV_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_105.append(S1HSV_imgA1C4_5[i][j])  
S1meanrefA1_1405 = np.array(S1meanrefA1_1405)
S1meanC4_105 = np.array(S1meanC4_105)

S1hsvrefA1_1405 = list()
S1hsvC4_105 = list()
for i in range(3):
    S1hsvrefA1_1405.append(S1meanrefA1_1405[:,i].mean())
    S1hsvC4_105.append(S1meanC4_105[:,i].mean())

# %%
S1meanrefA1_1505  = list()
S1meanD2_105  = list()
for i in range(S1HSV_imgA1D2_5.shape[0]): 
     for j in range(S1HSV_imgA1D2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1505 .append(S1HSV_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_105 .append(S1HSV_imgA1D2_5[i][j])  
S1meanrefA1_1505 = np.array(S1meanrefA1_1505)
S1meanD2_105  = np.array(S1meanD2_105)

S1hsvrefA1_1505 = list()
S1hsvD2_105 = list()
for i in range(3):
    S1hsvrefA1_1505.append(S1meanrefA1_1505[:,i].mean())
    S1hsvD2_105.append(S1meanD2_105[:,i].mean())

# %%
S1meanrefA1_1605 = list()
S1meanD3_105 = list()
for i in range(S1HSV_imgA1D3_5.shape[0]): 
     for j in range(S1HSV_imgA1D3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1605.append(S1HSV_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_105.append(S1HSV_imgA1D3_5[i][j])  
S1meanrefA1_1605 = np.array(S1meanrefA1_1605)
S1meanD3_105 = np.array(S1meanD3_105)

S1hsvrefA1_1605 = list()
S1hsvD3_105 = list()
for i in range(3):
    S1hsvrefA1_1605.append(S1meanrefA1_1605[:,i].mean())
    S1hsvD3_105.append(S1meanD3_105[:,i].mean())

# %%
S1meanrefA1_1705= list()
S1meanD4_105 = list()
for i in range(S1HSV_imgA1D4_5.shape[0]): 
     for j in range(S1HSV_imgA1D4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1705.append(S1HSV_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_105.append(S1HSV_imgA1D4_5[i][j])  
S1meanrefA1_1705 = np.array(S1meanrefA1_1405)
S1meanD4_105 = np.array(S1meanD4_105)

S1hsvrefA1_1705 = list()
S1hsvD4_105 = list()
for i in range(3):
    S1hsvrefA1_1705.append(S1meanrefA1_1705[:,i].mean())
    S1hsvD4_105.append(S1meanD4_105[:,i].mean())

# %% [markdown]
# ###Img 6

# %%
S1meanrefA1_106 = list()
S1meanA1_206 = list()
for i in range(S1HSV_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_6.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_106.append(S1HSV_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_206.append(S1HSV_imgA1A1_6[i][j])  
S1meanrefA1_106 = np.array(S1meanrefA1_106)
S1meanA1_206 = np.array(S1meanA1_206)

S1hsvrefA1_106 = list()
S1hsvA1_206 = list()
for i in range(3):
    S1hsvrefA1_106.append(S1meanrefA1_106[:,i].mean())
    S1hsvA1_206.append(S1meanA1_206[:,i].mean())
S1hsvrefA1_106,S1hsvA1_206

# %%
S1meanrefA1_306 = list()
S1meanA2_106 = list()
for i in range(S1HSV_imgA1A2_6.shape[0]): 
     for j in range(S1HSV_imgA1A2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_306.append(S1HSV_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_106 .append(S1HSV_imgA1A2_6[i][j])  
S1meanrefA1_306  = np.array(S1meanrefA1_306 )
S1meanA2_106  = np.array(S1meanA2_106 )

S1hsvrefA1_306  = list()
S1hsvA2_106  = list()
for i in range(3):
    S1hsvrefA1_306 .append(S1meanrefA1_306 [:,i].mean())
    S1hsvA2_106 .append(S1meanA2_106 [:,i].mean())

# %%
S1meanrefA1_406  = list()
S1meanA3_106  = list()
for i in range(S1HSV_imgA1A3_6.shape[0]): 
     for j in range(S1HSV_imgA1A3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_406 .append(S1HSV_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_106 .append(S1HSV_imgA1A3_6[i][j])  
S1meanrefA1_406 = np.array(S1meanrefA1_406 )
S1meanA3_106  = np.array(S1meanA3_106 )

S1hsvrefA1_406  = list()
S1hsvA3_106  = list()
for i in range(3):
    S1hsvrefA1_406 .append(S1meanrefA1_4อ[:,i].mean())
    S1hsvA3_106 .append(S1meanA3_106 [:,i].mean())

# %%
S1meanrefA1_506  = list()
S1meanA3_5106  = list()
for i in range(S1HSV_imgA1A3_56.shape[0]): 
     for j in range(S1HSV_imgA1A3_56.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_506 .append(S1HSV_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5106 .append(S1HSV_imgA1A3_56[i][j])  
S1meanrefA1_506  = np.array(S1meanrefA1_506 )
S1meanA3_5106  = np.array(S1meanA3_5106 )

S1hsvrefA1_506  = list()
S1hsvA3_5106  = list()
for i in range(3):
    S1hsvrefA1_506 .append(S1meanrefA1_506 [:,i].mean())
    S1hsvA3_5106.append(S1meanA3_5106 [:,i].mean())

# %%
S1meanrefA1_606  = list()
S1meanA4_106  = list()
for i in range(S1HSV_imgA1A4_6.shape[0]): 
     for j in range(S1HSV_imgA1A4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_606 .append(S1HSV_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_106 .append(S1HSV_imgA1A4_6[i][j])  
S1meanrefA1_606  = np.array(S1meanrefA1_606 )
S1meanA4_106  = np.array(S1meanA4_106 )

S1hsvrefA1_606  = list()
S1hsvA4_106  = list()
for i in range(3):
    S1hsvrefA1_606 .append(S1meanrefA1_606 [:,i].mean())
    S1hsvA4_106 .append(S1meanA4_106 [:,i].mean())

# %%
S1meanrefA1_706  = list()
S1meanB1_106  = list()
for i in range(S1HSV_imgA1B1_6.shape[0]): 
     for j in range(S1HSV_imgA1B1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_706 .append(S1HSV_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_106 .append(S1HSV_imgA1B1_6[i][j])  
S1meanrefA1_706  = np.array(S1meanrefA1_706 )
S1meanB1_106  = np.array(S1meanB1_106 )

S1hsvrefA1_706  = list()
S1hsvB1_106  = list()
for i in range(3):
    S1hsvrefA1_706 .append(S1meanrefA1_706 [:,i].mean())
    S1hsvB1_106 .append(S1meanB1_106 [:,i].mean())

# %%
S1meanrefA1_806  = list()
S1meanB2_106  = list()
for i in range(S1HSV_imgA1B2_6.shape[0]): 
     for j in range(S1HSV_imgA1B2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_8อ.append(S1HSV_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_106 .append(S1HSV_imgA1B2_6[i][j])  
S1meanrefA1_806 = np.array(S1meanrefA1_806 )
S1meanB2_106  = np.array(S1meanB2_106 )

S1hsvrefA1_806  = list()
S1hsvB2_106  = list()
for i in range(3):
    S1hsvrefA1_806 .append(S1meanrefA1_806 [:,i].mean())
    S1hsvB2_106 .append(S1meanB2_106 [:,i].mean())

# %%
S1meanrefA1_906  = list()
S1meanB3_106  = list()
for i in range(S1HSV_imgA1B3_6.shape[0]): 
     for j in range(S1HSV_imgA1B3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_906 .append(S1HSV_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_106 .append(S1HSV_imgA1B3_6[i][j])  
S1meanrefA1_906  = np.array(S1meanrefA1_906)
S1meanB3_106  = np.array(S1meanB3_106)

S1hsvrefA1_906 = list()
S1hsvB3_106 = list()
for i in range(3):
    S1hsvrefA1_906.append(S1meanrefA1_906[:,i].mean())
    S1hsvB3_106.append(S1meanB3_106[:,i].mean())

# %%
S1meanrefA1_1006 = list()
S1meanB4_106 = list()
for i in range(S1HSV_imgA1B4_6.shape[0]): 
     for j in range(S1HSV_imgA1B4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1006.append(S1HSV_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_106.append(S1HSV_imgA1B4_6[i][j])  
S1meanrefA1_1006 = np.array(S1meanrefA1_1006)
S1meanB4_106 = np.array(S1meanB4_106)

S1hsvrefA1_1006 = list()
S1hsvB4_106 = list()
for i in range(3):
    S1hsvrefA1_1006.append(S1meanrefA1_1006[:,i].mean())
    S1hsvB4_106.append(S1meanB4_106[:,i].mean())

# %%
S1meanrefA1_1106 = list()
S1meanC1_106 = list()
for i in range(S1HSV_imgA1C1_6.shape[0]): 
     for j in range(S1HSV_imgA1C1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1106.append(S1HSV_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_106.append(S1HSV_imgA1C1_6[i][j])  
S1meanrefA1_1106 = np.array(S1meanrefA1_1106)
S1meanC1_106 = np.array(S1meanC1_106)

S1hsvrefA1_1106 = list()
S1hsvC1_106 = list()
for i in range(3):
    S1hsvrefA1_1106.append(S1meanrefA1_1106[:,i].mean())
    S1hsvC1_106.append(S1meanC1_106[:,i].mean())

# %%
S1meanrefA1_1206 = list()
S1meanC2_106 = list()
for i in range(S1HSV_imgA1C2_6.shape[0]): 
     for j in range(S1HSV_imgA1C2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1206.append(S1HSV_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_106.append(S1HSV_imgA1C2_6[i][j])  
S1meanrefA1_1206 = np.array(S1meanrefA1_1206)
S1meanC2_106 = np.array(S1meanC2_106)

S1hsvrefA1_1206 = list()
S1hsvC2_106 = list()
for i in range(3):
    S1hsvrefA1_1206.append(S1meanrefA1_12[:,i].mean())
    S1hsvC2_106.append(S1meanC2_1[:,i].mean())

# %%
S1meanrefA1_1306 = list()
S1meanC3_106 = list()
for i in range(S1HSV_imgA1C3_6.shape[0]): 
     for j in range(S1HSV_imgA1C3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1306.append(S1HSV_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_106.append(S1HSV_imgA1C3_6[i][j])  
S1meanrefA1_1306 = np.array(S1meanrefA1_1306)
S1meanC3_106 = np.array(S1meanC3_106

S1hsvrefA1_1306 = list()
S1hsvC3_106 = list()
for i in range(3):
    S1hsvrefA1_1306.append(S1meanrefA1_1306[:,i].mean())
    S1hsvC3_106.append(S1meanC3_106[:,i].mean())

# %%
S1meanrefA1_1406 = list()
S1meanC4_106 = list()
for i in range(S1HSV_imgA1C4_6.shape[0]): 
     for j in range(S1HSV_imgA1C4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1406.append(S1HSV_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_106.append(S1HSV_imgA1C4_6[i][j])  
S1meanrefA1_1406 = np.array(S1meanrefA1_1406)
S1meanC4_106 = np.array(S1meanC4_106)

S1hsvrefA1_1406 = list()
S1hsvC4_106 = list()
for i in range(3):
    S1hsvrefA1_1406.append(S1meanrefA1_1406[:,i].mean())
    S1hsvC4_106.append(S1meanC4_106[:,i].mean())

# %%
S1meanrefA1_1506 = list()
S1meanD2_106 = list()
for i in range(S1HSV_imgA1D2_6.shape[0]): 
     for j in range(S1HSV_imgA1D2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1506.append(S1HSV_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_106.append(S1HSV_imgA1D2_6[i][j])  
S1meanrefA1_1506 = np.array(S1meanrefA1_1506)
S1meanD2_106 = np.array(S1meanD2_106)

S1hsvrefA1_1506 = list()
S1hsvD2_106 = list()
for i in range(3):
    S1hsvrefA1_1506.append(S1meanrefA1_1506[:,i].mean())
    S1hsvD2_106.append(S1meanD2_106[:,i].mean())

# %%
S1meanrefA1_1606 = list()
S1meanD3_106 = list()
for i in range(S1HSV_imgA1D3_6.shape[0]): 
     for j in range(S1HSV_imgA1D3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1606.append(S1HSV_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_106.append(S1HSV_imgA1D3_6[i][j])  
S1meanrefA1_1606 = np.array(S1meanrefA1_1606)
S1meanD3_106 = np.array(S1meanD3_106)

S1hsvrefA1_1606 = list()
S1hsvD3_106 = list()
for i in range(3):
    S1hsvrefA1_1606.append(S1meanrefA1_1606[:,i].mean())
    S1hsvD3_1v.append(S1meanD3_106[:,i].mean())

# %%
S1meanrefA1_1706= list()
S1meanD4_106 = list()
for i in range(S1HSV_imgA1D4_6.shape[0]): 
     for j in range(S1HSV_imgA1D4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1706.append(S1HSV_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_106.append(S1HSV_imgA1D4_6[i][j])  
S1meanrefA1_1706 = np.array(S1meanrefA1_1406)
S1meanD4_106 = np.array(S1meanD4_106)

S1hsvrefA1_1706 = list()
S1hsvD4_10606 = list()
for i in range(3):
    S1hsvrefA1_1706.append(S1meanrefA1_1706[:,i].mean())
    S1hsvD4_106.append(S1meanD4_106[:,i].mean())

# %% [markdown]
# ###Img 7

# %%
S1meanrefA1_107 = list()
S1meanA1_207 = list()
for i in range(S1HSV_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_107.append(S1HSV_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_207.append(S1HSV_imgA1A1_7[i][j])  
S1meanrefA1_107 = np.array(S1meanrefA1_107)
S1meanA1_207 = np.array(S1meanA1_207)

S1hsvrefA1_107 = list()
S1hsvA1_207 = list()
for i in range(3):
    S1hsvrefA1_107.append(S1meanrefA1_107[:,i].mean())
    S1hsvA1_207.append(S1meanA1_207[:,i].mean())
S1hsvrefA1_107,S1hsvA1_207

# %%
S1meanrefA1_307 = list()
S1meanA2_107 = list()
for i in range(S1HSV_imgA1A2_7.shape[0]): 
     for j in range(S1HSV_imgA1A2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_307.append(S1HSV_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_107.append(S1HSV_imgA1A2_7[i][j])  
S1meanrefA1_307 = np.array(S1meanrefA1_307)
S1meanA2_107 = np.array(S1meanA2_1v)

S1hsvrefA1_307 = list()
S1hsvA2_107 = list()
for i in range(3):
    S1hsvrefA1_307.append(S1meanrefA1_307[:,i].mean())
    S1hsvA2_107.append(S1meanA2_107[:,i].mean())

# %%
S1meanrefA1_407 = list()
S1meanA3_107 = list()
for i in range(S1HSV_imgA1A3_7.shape[0]): 
     for j in range(S1HSV_imgA1A3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_407.append(S1HSV_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_107.append(S1HSV_imgA1A3_7[i][j])  
S1meanrefA1_407 = np.array(S1meanrefA1_407)
S1meanA3_107 = np.array(S1meanA3_107)

S1hsvrefA1_407 = list()
S1hsvA3_107 = list()
for i in range(3):
    S1hsvrefA1_407.append(S1meanrefA1_407[:,i].mean())
    S1hsvA3_107.append(S1meanA3_107[:,i].mean())

# %%
S1meanrefA1_507 = list()
S1meanA3_5107 = list()
for i in range(S1HSV_imgA1A3_5707.shape[0]): 
     for j in range(S1HSV_imgA1A3_57.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_507.append(S1HSV_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5107.append(S1HSV_imgA1A3_57[i][j])  
S1meanrefA1_5v = np.array(S1meanrefA1_5v)
S1meanA3_5107 = np.array(S1meanA3_5107)

S1hsvrefA1_507 = list()
S1hsvA3_5107 = list()
for i in range(3):
    S1hsvrefA1_507.append(S1meanrefA1_507[:,i].mean())
    S1hsvA3_5107.append(S1meanA3_5107[:,i].mean())

# %%
S1meanrefA1_607 = list()
S1meanA4_107 = list()
for i in range(S1HSV_imgA1A4_7.shape[0]): 
     for j in range(S1HSV_imgA1A4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_607.append(S1HSV_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_107.append(S1HSV_imgA1A4_7[i][j])  
S1meanrefA1_607 = np.array(S1meanrefA1_607)
S1meanA4_1v = np.array(S1meanA4_107)

S1hsvrefA1_607 = list()
S1hsvA4_107 = list()
for i in range(3):
    S1hsvrefA1_607.append(S1meanrefA1_607[:,i].mean())
    S1hsvA4_107.append(S1meanA4_107[:,i].mean())

# %%
S1meanrefA1_707 = list()
S1meanB1_107 = list()
for i in range(S1HSV_imgA1B1_7.shape[0]): 
     for j in range(S1HSV_imgA1B1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_707.append(S1HSV_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_107.append(S1HSV_imgA1B1_7[i][j])  
S1meanrefA1_707 = np.array(S1meanrefA1_7)
S1meanB1_107= np.array(S1meanB1_1)

S1hsvrefA1_707 = list()
S1hsvB1_107 = list()
for i in range(3):
    S1hsvrefA1_707.append(S1meanrefA1_707[:,i].mean())
    S1hsvB1_107.append(S1meanB1_107[:,i].mean())

# %%
S1meanrefA1_807 = list()
S1meanB2_107 = list()
for i in range(S1HSV_imgA1B2_7.shape[0]): 
     for j in range(S1HSV_imgA1B2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_807.append(S1HSV_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_107.append(S1HSV_imgA1B2_7[i][j])  
S1meanrefA1_807 = np.array(S1meanrefA1_807)
S1meanB2_107 = np.array(S1meanB2_107)

S1hsvrefA1_807 = list()
S1hsvB2_107 = list()
for i in range(3):
    S1hsvrefA1_807.append(S1meanrefA1_807[:,i].mean())
    S1hsvB2_107.append(S1meanB2_107[:,i].mean())

# %%
S1meanrefA1_907 = list()
S1meanB3_107 = list()
for i in range(S1HSV_imgA1B3_7.shape[0]): 
     for j in range(S1HSV_imgA1B3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_907.append(S1HSV_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_107.append(S1HSV_imgA1B3_7[i][j])  
S1meanrefA1_907= np.array(S1meanrefA1_907)
S1meanB3_107 = np.array(S1meanB3_107)

S1hsvrefA1_907 = list()
S1hsvB3_107 = list()
for i in range(3):
    S1hsvrefA1_907.append(S1meanrefA1_907[:,i].mean())
    S1hsvB3_107.append(S1meanB3_107[:,i].mean())

# %%
S1meanrefA1_1007 = list()
S1meanB4_107 = list()
for i in range(S1HSV_imgA1B4_7.shape[0]): 
     for j in range(S1HSV_imgA1B4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1007.append(S1HSV_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_107.append(S1HSV_imgA1B4_7[i][j])  
S1meanrefA1_1007= np.array(S1meanrefA1_1007)
S1meanB4_107 = np.array(S1meanB4_107)

S1hsvrefA1_1007 = list()
S1hsvB4_107 = list()
for i in range(3):
    S1hsvrefA1_1007.append(S1meanrefA1_1007[:,i].mean())
    S1hsvB4_107.append(S1meanB4_107[:,i].mean())

# %%
S1meanrefA1_1107 = list()
S1meanC1_1v = list()
for i in range(S1HSV_imgA1C1_7.shape[0]): 
     for j in range(S1HSV_imgA1C1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1107.append(S1HSV_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_107.append(S1HSV_imgA1C1_7[i][j])  
S1meanrefA1_1107= np.array(S1meanrefA1_1107)
S1meanC1_107 = np.array(S1meanC1_107)

S1hsvrefA1_1107 = list()
S1hsvC1_107 = list()
for i in range(3):
    S1hsvrefA1_1107.append(S1meanrefA1_1107[:,i].mean())
    S1hsvC1_107.append(S1meanC1_107[:,i].mean())

# %%
S1meanrefA1_1207 = list()
S1meanC2_107 = list()
for i in range(S1HSV_imgA1C2_7.shape[0]): 
     for j in range(S1HSV_imgA1C2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1207.append(S1HSV_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_107.append(S1HSV_imgA1C2_7[i][j])  
S1meanrefA1_1207 = np.array(S1meanrefA1_1207)
S1meanC2_107 = np.array(S1meanC2_107)

S1hsvrefA1_1207 = list()
S1hsvC2_107 = list()
for i in range(3):
    S1hsvrefA1_1207.append(S1meanrefA1_12v[:,i].mean())
    S1hsvC2_107.append(S1meanC2_107[:,i].mean())

# %%
S1meanrefA1_1307 = list()
S1meanC3_107 = list()
for i in range(S1HSV_imgA1C3_7.shape[0]): 
     for j in range(S1HSV_imgA1C3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1307.append(S1HSV_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_107.append(S1HSV_imgA1C3_7[i][j])  
S1meanrefA1_1307 = np.array(S1meanrefA1_1307)
S1meanC3_107 = np.array(S1meanC3_107)

S1hsvrefA1_1307 = list()
S1hsvC3_107 = list()
for i in range(3):
    S1hsvrefA1_1307.append(S1meanrefA1_1307[:,i].mean())
    S1hsvC3_107.append(S1meanC3_107[:,i].mean())

# %%
S1meanrefA1_1407 = list()
S1meanC4_107 = list()
for i in range(S1HSV_imgA1C4_7.shape[0]): 
     for j in range(S1HSV_imgA1C4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1407.append(S1HSV_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_107.append(S1HSV_imgA1C4_7[i][j])  
S1meanrefA1_1407 = np.array(S1meanrefA1_1407)
S1meanC4_107 = np.array(S1meanC4_107)

S1hsvrefA1_1407 = list()
S1hsvC4_107 = list()
for i in range(3):
    S1hsvrefA1_1407.append(S1meanrefA1_1407[:,i].mean())
    S1hsvC4_107.append(S1meanC4_107[:,i].mean())

# %%
S1meanrefA1_1507 = list()
S1meanD2_107 = list()
for i in range(S1HSV_imgA1D2_7.shape[0]): 
     for j in range(S1HSV_imgA1D2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1507.append(S1HSV_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_107.append(S1HSV_imgA1D2_7[i][j])  
S1meanrefA1_1507 = np.array(S1meanrefA1_1507)
S1meanD2_107 = np.array(S1meanD2_107)

S1hsvrefA1_1507= list()
S1hsvD2_107 = list()
for i in range(3):
    S1hsvrefA1_1507.append(S1meanrefA1_1507[:,i].mean())
    S1hsvD2_107.append(S1meanD2_107[:,i].mean())

# %%
S1meanrefA1_1607 = list()
S1meanD3_107 = list()
for i in range(S1HSV_imgA1D3_7.shape[0]): 
     for j in range(S1HSV_imgA1D3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1607.append(S1HSV_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_107.append(S1HSV_imgA1D3_7[i][j])  
S1meanrefA1_1607 = np.array(S1meanrefA1_1607)
S1meanD3_107 = np.array(S1meanD3_107)

S1hsvrefA1_1607 = list()
S1hsvD3_107 = list()
for i in range(3):
    S1hsvrefA1_1607.append(S1meanrefA1_1607[:,i].mean())
    S1hsvD3_107.append(S1meanD3_107[:,i].mean())

# %%
S1meanrefA1_1707= list()
S1meanD4_107 = list()
for i in range(S1HSV_imgA1D4_7.shape[0]): 
     for j in range(S1HSV_imgA1D4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1707.append(S1HSV_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_107.append(S1HSV_imgA1D4_7[i][j])  
S1meanrefA1_1707 = np.array(S1meanrefA1_1407)
S1meanD4_107 = np.array(S1meanD4_107,;)

S1hsvrefA1_1707 = list()
S1hsvD4_107 = list()
for i in range(3):
    S1hsvrefA1_1707.append(S1meanrefA1_1707[:,i].mean())
    S1hsvD4_107.append(S1meanD4_107[:,i].mean())

# %% [markdown]
# ###Img 8

# %%
S1meanrefA1_108 = list()
S1meanA1_208 = list()
for i in range(S1HSV_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_108.append(S1HSV_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_208.append(S1HSV_imgA1A1_8[i][j])  
S1meanrefA1_108 = np.array(S1meanrefA1_108)
S1meanA1_208 = np.array(S1meanA1_208)

S1hsvrefA1_108 = list()
S1hsvA1_208 = list()
for i in range(3):
    S1hsvrefA1_108.append(S1meanrefA1_108[:,i].mean())
    S1hsvA1_208.append(S1meanA1_208[:,i].mean())
S1hsvrefA1_108,S1hsvA1_208

# %%
S1meanrefA1_308 = list()
S1meanA2_108 = list()
for i in range(S1HSV_imgA1A2_8.shape[0]): 
     for j in range(S1HSV_imgA1A2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_308.append(S1HSV_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_108.append(S1HSV_imgA1A2_8[i][j])  
S1meanrefA1_308 = np.array(S1meanrefA1_308)
S1meanA2_108 = np.array(S1meanA2_108)

S1hsvrefA1_308 = list()
S1hsvA2_108 = list()
for i in range(3):
    S1hsvrefA1_308.append(S1meanrefA1_308[:,i].mean())
    S1hsvA2_108.append(S1meanA2_108[:,i].mean())

# %%
S1meanrefA1_408 = list()
S1meanA3_108 = list()
for i in range(S1HSV_imgA1A3_8.shape[0]): 
     for j in range(S1HSV_imgA1A3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_408.append(S1HSV_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_108.append(S1HSV_imgA1A3_8[i][j])  
S1meanrefA1_408 = np.array(S1meanrefA1_408)
S1meanA3_108 = np.array(S1meanA3_108)

S1hsvrefA1_408 = list()
S1hsvA3_108 = list()
for i in range(3):
    S1hsvrefA1_408.append(S1meanrefA1_408[:,i].mean())
    S1hsvA3_108.append(S1meanA3_108[:,i].mean())

# %%
S1meanrefA1_5v = list()
S1meanA3_5108 = list()
for i in range(S1HSV_imgA1A3_58.shape[0]): 
     for j in range(S1HSV_imgA1A3_58.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_508.append(S1HSV_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5108.append(S1HSV_imgA1A3_58[i][j])  
S1meanrefA1_508 = np.array(S1meanrefA1_508)
S1meanA3_5108 = np.array(S1meanA3_5108)

S1hsvrefA1_508 = list()
S1hsvA3_5108 = list()
for i in range(3):
    S1hsvrefA1_508.append(S1meanrefA1_508[:,i].mean())
    S1hsvA3_5108.append(S1meanA3_5108[:,i].mean())

# %%
S1meanrefA1_608 = list()
S1meanA4_108 = list()
for i in range(S1HSV_imgA1A4_8.shape[0]): 
     for j in range(S1HSV_imgA1A4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_608.append(S1HSV_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_108.append(S1HSV_imgA1A4_8[i][j])  
S1meanrefA1_608 = np.array(S1meanrefA1_608)
S1meanA4_108 = np.array(S1meanA4_108)

S1hsvrefA1_608 = list()
S1hsvA4_108= list()
for i in range(3):
    S1hsvrefA1_608.append(S1meanrefA1_608[:,i].mean())
    S1hsvA4_108.append(S1meanA4_108[:,i].mean())

# %%
S1meanrefA1_708 = list()
S1meanB1_108 = list()
for i in range(S1HSV_imgA1B1_8.shape[0]): 
     for j in range(S1HSV_imgA1B1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_708.append(S1HSV_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_108.append(S1HSV_imgA1B1_8[i][j])  
S1meanrefA1_708 = np.array(S1meanrefA1_708)
S1meanB1_108 = np.array(S1meanB1_108)

S1hsvrefA1_708 = list()
S1hsvB1_108 = list()
for i in range(3):
    S1hsvrefA1_708.append(S1meanrefA1_708[:,i].mean())
    S1hsvB1_108.append(S1meanB1_108[:,i].mean())

# %%
S1meanrefA1_808 = list()
S1meanB2_108 = list()
for i in range(S1HSV_imgA1B2_8.shape[0]): 
     for j in range(S1HSV_imgA1B2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_808.append(S1HSV_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_108.append(S1HSV_imgA1B2_8[i][j])  
S1meanrefA1_808 = np.array(S1meanrefA1_808)
S1meanB2_108 = np.array(S1meanB2_108)

S1hsvrefA1_808 = list()
S1hsvB2_108 = list()
for i in range(3):
    S1hsvrefA1_808.append(S1meanrefA1_808[:,i].mean())
    S1hsvB2_108.append(S1meanB2_108[:,i].mean())

# %%
S1meanrefA1_908 = list()
S1meanB3_108 = list()
for i in range(S1HSV_imgA1B3_8.shape[0]): 
     for j in range(S1HSV_imgA1B3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_908.append(S1HSV_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_108.append(S1HSV_imgA1B3_8[i][j])  
S1meanrefA1_908 = np.array(S1meanrefA1_908)
S1meanB3_108 = np.array(S1meanB3_108)

S1hsvrefA1_908 = list()
S1hsvB3_108 = list()
for i in range(3):
    S1hsvrefA1_908.append(S1meanrefA1_908[:,i].mean())
    S1hsvB3_108.append(S1meanB3_108[:,i].mean())

# %%
S1meanrefA1_1008 = list()
S1meanB4_108 = list()
for i in range(S1HSV_imgA1B4_8.shape[0]): 
     for j in range(S1HSV_imgA1B4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1008.append(S1HSV_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_108.append(S1HSV_imgA1B4_8[i][j])  
S1meanrefA1_1008 = np.array(S1meanrefA1_1008)
S1meanB4_108 = np.array(S1meanB4_108)

S1hsvrefA1_1008 = list()
S1hsvB4_108 = list()
for i in range(3):
    S1hsvrefA1_1008.append(S1meanrefA1_1008[:,i].mean())
    S1hsvB4_108.append(S1meanB4_108[:,i].mean())

# %%
S1meanrefA1_1108 = list()
S1meanC1_108 = list()
for i in range(S1HSV_imgA1C1_8.shape[0]): 
     for j in range(S1HSV_imgA1C1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1108.append(S1HSV_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_108.append(S1HSV_imgA1C1_8[i][j])  
S1meanrefA1_1108 = np.array(S1meanrefA1_1108)
S1meanC1_108 = np.array(S1meanC1_108)

S1hsvrefA1_1108 = list()
S1hsvC1_108 = list()
for i in range(3):
    S1hsvrefA1_1108.append(S1meanrefA1_1108[:,i].mean())
    S1hsvC1_108.append(S1meanC1_108[:,i].mean())

# %%
S1meanrefA1_1208 = list()
S1meanC2_108 = list()
for i in range(S1HSV_imgA1C2_808.shape[0]): 
     for j in range(S1HSV_imgA1C2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1208.append(S1HSV_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_108.append(S1HSV_imgA1C2_8[i][j])  
S1meanrefA1_12v = np.array(S1meanrefA1_1208)
S1meanC2_108 = np.array(S1meanC2_108)

S1hsvrefA1_12v = list()
S1hsvC2_108 = list()
for i in range(3):
    S1hsvrefA1_1208.append(S1meanrefA1_1208[:,i].mean())
    S1hsvC2_108.append(S1meanC2_108[:,i].mean())

# %%
S1meanrefA1_1308 = list()
S1meanC3_108 = list()
for i in range(S1HSV_imgA1C3_8.shape[0]): 
     for j in range(S1HSV_imgA1C3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1308.append(S1HSV_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_108.append(S1HSV_imgA1C3_8[i][j])  
S1meanrefA1_1308 = np.array(S1meanrefA1_1308)
S1meanC3_108 = np.array(S1meanC3_108)

S1hsvrefA1_1308 = list()
S1hsvC3_108 = list()
for i in range(3):
    S1hsvrefA1_1308.append(S1meanrefA1_1308[:,i].mean())
    S1hsvC3_108.append(S1meanC3_108[:,i].mean())

# %%
S1meanrefA1_1408 = list()
S1meanC4_108 = list()
for i in range(S1HSV_imgA1C4_8.shape[0]): 
     for j in range(S1HSV_imgA1C4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1408.append(S1HSV_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_108.append(S1HSV_imgA1C4_8[i][j])  
S1meanrefA1_1408 = np.array(S1meanrefA1_1408)
S1meanC4_108 = np.array(S1meanC4_108)

S1hsvrefA1_1408 = list()
S1hsvC4_108= list()
for i in range(3):
    S1hsvrefA1_1408.append(S1meanrefA1_1408[:,i].mean())
    S1hsvC4_108.append(S1meanC4_108[:,i].mean())

# %%
S1meanrefA1_1508 = list()
S1meanD2_108 = list()
for i in range(S1HSV_imgA1D2_8.shape[0]): 
     for j in range(S1HSV_imgA1D2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1508.append(S1HSV_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_108.append(S1HSV_imgA1D2_8[i][j])  
S1meanrefA1_1508 = np.array(S1meanrefA1_1508)
S1meanD2_108 = np.array(S1meanD2_108)

S1hsvrefA1_1508 = list()
S1hsvD2_108 = list()
for i in range(3):
    S1hsvrefA1_1508.append(S1meanrefA1_1508[:,i].mean())
    S1hsvD2_108.append(S1meanD2_108[:,i].mean())

# %%
S1meanrefA1_1608 = list()
S1meanD3_108 = list()
for i in range(S1HSV_imgA1D3_8.shape[0]): 
     for j in range(S1HSV_imgA1D3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1608.append(S1HSV_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_108.append(S1HSV_imgA1D3_8[i][j])  
S1meanrefA1_1608 = np.array(S1meanrefA1_1608)
S1meanD3_108 = np.array(S1meanD3_108)

S1hsvrefA1_1608 = list()
S1hsvD3_108 = list()
for i in range(3):
    S1hsvrefA1_1608.append(S1meanrefA1_1608[:,i].mean())
    S1hsvD3_108.append(S1meanD3_108[:,i].mean())

# %%
S1meanrefA1_1708= list()
S1meanD4_108 = list()
for i in range(S1HSV_imgA1D4_8.shape[0]): 
     for j in range(S1HSV_imgA1D4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1708.append(S1HSV_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_108.append(S1HSV_imgA1D4_8[i][j])  
S1meanrefA1_1708= np.array(S1meanrefA1_1408)
S1meanD4_108 = np.array(S1meanD4_108)

S1hsvrefA1_1708 = list()
S1hsvD4_108 = list()
for i in range(3):
    S1hsvrefA1_1708.append(S1meanrefA1_1708[:,i].mean())
    S1hsvD4_108.append(S1meanD4_108[:,i].mean())

# %% [markdown]
# ###Img 9

# %%
S1meanrefA1_109 = list()
S1meanA1_209 = list()
for i in range(S1HSV_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_109.append(S1HSV_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_209.append(S1HSV_imgA1A1_9[i][j])  
S1meanrefA1_109 = np.array(S1meanrefA1_109)
S1meanA1_209 = np.array(S1meanA1_209)

S1hsvrefA1_109 = list()
S1hsvA1_209 = list()
for i in range(3):
    S1hsvrefA1_109.append(S1meanrefA1_109[:,i].mean())
    S1hsvA1_209.append(S1meanA1_209[:,i].mean())
S1hsvrefA1_109,S1hsvA1_209

# %%
S1meanrefA1_309 = list()
S1meanA2_109 = list()
for i in range(S1HSV_imgA1A2_9.shape[0]): 
     for j in range(S1HSV_imgA1A2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_309.append(S1HSV_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_109.append(S1HSV_imgA1A2_9[i][j])  
S1meanrefA1_309 = np.array(S1meanrefA1_309)
S1meanA2_109 = np.array(S1meanA2_109)

S1hsvrefA1_309 = list()
S1hsvA2_109 = list()
for i in range(3):
    S1hsvrefA1_309.append(S1meanrefA1_309[:,i].mean())
    S1hsvA2_109.append(S1meanA2_109[:,i].mean())

# %%
S1meanrefA1_409 = list()
S1meanA3_109 = list()
for i in range(S1HSV_imgA1A3_9.shape[0]): 
     for j in range(S1HSV_imgA1A3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_409.append(S1HSV_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_109.append(S1HSV_imgA1A3_9[i][j])  
S1meanrefA1_409 = np.array(S1meanrefA1_409
S1meanA3_109 = np.array(S1meanA3_109)

S1hsvrefA1_409= list()
S1hsvA3_109 = list()
for i in range(3):
    S1hsvrefA1_409.append(S1meanrefA1_409[:,i].mean())
    S1hsvA3_109.append(S1meanA3_109[:,i].mean())

# %%
S1meanrefA1_509 = list()
S1meanA3_5109 = list()
for i in range(S1HSV_imgA1A3_59.shape[0]): 
     for j in range(S1HSV_imgA1A3_59.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_509.append(S1HSV_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5109.append(S1HSV_imgA1A3_59[i][j])  
S1meanrefA1_509 = np.array(S1meanrefA1_509)
S1meanA3_5109 = np.array(S1meanA3_5109)

S1hsvrefA1_509 = list()
S1hsvA3_5109 = list()
for i in range(3):
    S1hsvrefA1_509.append(S1meanrefA1_509[:,i].mean())
    S1hsvA3_5109.append(S1meanA3_5109[:,i].mean())

# %%
S1meanrefA1_609 = list()
S1meanA4_109 = list()
for i in range(S1HSV_imgA1A4_9.shape[0]): 
     for j in range(S1HSV_imgA1A4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_609.append(S1HSV_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_109.append(S1HSV_imgA1A4_9[i][j])  
S1meanrefA1_609 = np.array(S1meanrefA1_609)
S1meanA4_109 = np.array(S1meanA4_109)

S1hsvrefA1_609 = list()
S1hsvA4_109 = list()
for i in range(3):
    S1hsvrefA1_609.append(S1meanrefA1_609[:,i].mean())
    S1hsvA4_109.append(S1meanA4_109[:,i].mean())

# %%
S1meanrefA1_709 = list()
S1meanB1_109 = list()
for i in range(S1HSV_imgA1B1_9.shape[0]): 
     for j in range(S1HSV_imgA1B1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_709.append(S1HSV_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_109.append(S1HSV_imgA1B1_9[i][j])  
S1meanrefA1_709 = np.array(S1meanrefA1_709)
S1meanB1_109 = np.array(S1meanB1_109)

S1hsvrefA1_709 = list()
S1hsvB1_109 = list()
for i in range(3):
    S1hsvrefA1_709.append(S1meanrefA1_709[:,i].mean())
    S1hsvB1_109.append(S1meanB1_109[:,i].mean())

# %%
S1meanrefA1_809 = list()
S1meanB2_109= list()
for i in range(S1HSV_imgA1B2_9.shape[0]): 
     for j in range(S1HSV_imgA1B2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_809.append(S1HSV_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_109.append(S1HSV_imgA1B2_9[i][j])  
S1meanrefA1_809 = np.array(S1meanrefA1_809)
S1meanB2_109 = np.array(S1meanB2_109)

S1hsvrefA1_809 = list()
S1hsvB2_109 = list()
for i in range(3):
    S1hsvrefA1_809.append(S1meanrefA1_809[:,i].mean())
    S1hsvB2_109.append(S1meanB2_109[:,i].mean())

# %%
S1meanrefA1_909 = list()
S1meanB3_109 = list()
for i in range(S1HSV_imgA1B3_9.shape[0]): 
     for j in range(S1HSV_imgA1B3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_909.append(S1HSV_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_109.append(S1HSV_imgA1B3_9[i][j])  
S1meanrefA1_909 = np.array(S1meanrefA1_909)
S1meanB3_109 = np.array(S1meanB3_109)

S1hsvrefA1_909 = list()
S1hsvB3_109 = list()
for i in range(3):
    S1hsvrefA1_909.append(S1meanrefA1_909[:,i].mean())
    S1hsvB3_109.append(S1meanB3_109[:,i].mean())

# %%
S1meanrefA1_1009 = list()
S1meanB4_109 = list()
for i in range(S1HSV_imgA1B4_9.shape[0]): 
     for j in range(S1HSV_imgA1B4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1009.append(S1HSV_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_109.append(S1HSV_imgA1B4_9[i][j])  
S1meanrefA1_1009= np.array(S1meanrefA1_1009)
S1meanB4_109 = np.array(S1meanB4_109)

S1hsvrefA1_1009 = list()
S1hsvB4_109 = list()
for i in range(3):
    S1hsvrefA1_1009.append(S1meanrefA1_1009[:,i].mean())
    S1hsvB4_109.append(S1meanB4_109[:,i].mean())

# %%
S1meanrefA1_1109 = list()
S1meanC1_109 = list()
for i in range(S1HSV_imgA1C1_9.shape[0]): 
     for j in range(S1HSV_imgA1C1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1109.append(S1HSV_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_109.append(S1HSV_imgA1C1_9[i][j])  
S1meanrefA1_1109 = np.array(S1meanrefA1_1109)
S1meanC1_109 = np.array(S1meanC1_109)

S1hsvrefA1_1109 = list()
S1hsvC1_109 = list()
for i in range(3):
    S1hsvrefA1_1109.append(S1meanrefA1_1109[:,i].mean())
    S1hsvC1_109.append(S1meanC1_109[:,i].mean())

# %%
S1meanrefA1_1209 = list()
S1meanC2_109 = list()
for i in range(S1HSV_imgA1C2_909.shape[0]): 
     for j in range(S1HSV_imgA1C2_909.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1209.append(S1HSV_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_109.append(S1HSV_imgA1C2_9[i][j])  
S1meanrefA1_1209 = np.array(S1meanrefA1_1209)
S1meanC2_109 = np.array(S1meanC2_109)

S1hsvrefA1_1209 = list()
S1hsvC2_109= list()
for i in range(3):
    S1hsvrefA1_1209.append(S1meanrefA1_1209[:,i].mean())
    S1hsvC2_109.append(S1meanC2_109[:,i].mean())

# %%
S1meanrefA1_1309 = list()
S1meanC3_109 = list()
for i in range(S1HSV_imgA1C3_9.shape[0]): 
     for j in range(S1HSV_imgA1C3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1309.append(S1HSV_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_109.append(S1HSV_imgA1C3_9[i][j])  
S1meanrefA1_1309 = np.array(S1meanrefA1_1309)
S1meanC3_109 = np.array(S1meanC3_109)

S1hsvrefA1_1309 = list()
S1hsvC3_109 = list()
for i in range(3):
    S1hsvrefA1_1309.append(S1meanrefA1_1309[:,i].mean())
    S1hsvC3_109.append(S1meanC3_109[:,i].mean())

# %%
S1meanrefA1_1409 = list()
S1meanC4_109 = list()
for i in range(S1HSV_imgA1C4_9.shape[0]): 
     for j in range(S1HSV_imgA1C4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1409.append(S1HSV_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_109.append(S1HSV_imgA1C4_9[i][j])  
S1meanrefA1_1409 = np.array(S1meanrefA1_1409)
S1meanC4_109 = np.array(S1meanC4_109)

S1hsvrefA1_1409 = list()
S1hsvC4_109 = list()
for i in range(3):
    S1hsvrefA1_1409.append(S1meanrefA1_1409[:,i].mean())
    S1hsvC4_109.append(S1meanC4_109[:,i].mean())

# %%
S1meanrefA1_1509 = list()
S1meanD2_1v = list()
for i in range(S1HSV_imgA1D2_9.shape[0]): 
     for j in range(S1HSV_imgA1D2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1509.append(S1HSV_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_109.append(S1HSV_imgA1D2_9[i][j])  
S1meanrefA1_1509 = np.array(S1meanrefA1_1509)
S1meanD2_109 = np.array(S1meanD2_109)

S1hsvrefA1_1509 = list()
S1hsvD2_109 = list()
for i in range(3):
    S1hsvrefA1_1509.append(S1meanrefA1_1509[:,i].mean())
    S1hsvD2_109.append(S1meanD2_109[:,i].mean())

# %%
S1meanrefA1_1609 = list()
S1meanD3_109 = list()
for i in range(S1HSV_imgA1D3_9.shape[0]): 
     for j in range(S1HSV_imgA1D3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1609.append(S1HSV_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_109.append(S1HSV_imgA1D3_9[i][j])  
S1meanrefA1_1609 = np.array(S1meanrefA1_1609)
S1meanD3_109= np.array(S1meanD3_109)

S1hsvrefA1_1609 = list()
S1hsvD3_109 = list()
for i in range(3):
    S1hsvrefA1_1609.append(S1meanrefA1_1609[:,i].mean())
    S1hsvD3_109.append(S1meanD3_109[:,i].mean())

# %%
S1meanrefA1_1709= list()
S1meanD4_109 = list()
for i in range(S1HSV_imgA1D4_9.shape[0]): 
     for j in range(S1HSV_imgA1D4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1709.append(S1HSV_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_109.append(S1HSV_imgA1D4_9[i][j])  
S1meanrefA1_1709 = np.array(S1meanrefA1_1409)
S1meanD4_109 = np.array(S1meanD4_109)

S1hsvrefA1_17v = list()
S1hsvD4_109 = list()
for i in range(3):
    S1hsvrefA1_1709.append(S1meanrefA1_1709[:,i].mean())
    S1hsvD4_109.append(S1meanD4_109[:,i].mean())

# %% [markdown]
# ###Img 10

# %%
S1meanrefA1_110 = list()
S1meanA1_210 = list()
for i in range(S1HSV_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_110.append(S1HSV_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA1_210.append(S1HSV_imgA1A1_10[i][j])  
S1meanrefA1_110 = np.array(S1meanrefA1_110)
S1meanA1_210 = np.array(S1meanA1_210)

S1hsvrefA1_110 = list()
S1hsvA1_210 = list()
for i in range(3):
    S1hsvrefA1_110.append(S1meanrefA1_110[:,i].mean())
    S1hsvA1_210.append(S1meanA1_210[:,i].mean())
S1hsvrefA1_110,S1hsvA1_210

# %%
S1meanrefA1_310 = list()
S1meanA2_110 = list()
for i in range(S1HSV_imgA1A2_10.shape[0]): 
     for j in range(S1HSV_imgA1A2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_310.append(S1HSV_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA2_110.append(S1HSV_imgA1A2_10[i][j])  
S1meanrefA1_310 = np.array(S1meanrefA1_310)
S1meanA2_110 = np.array(S1meanA2_110)

S1hsvrefA1_310 = list()
S1hsvA2_110 = list()
for i in range(3):
    S1hsvrefA1_310.append(S1meanrefA1_310[:,i].mean())
    S1hsvA2_110.append(S1meanA2_110[:,i].mean())

# %%
S1meanrefA1_410 = list()
S1meanA3_110 = list()
for i in range(S1HSV_imgA1A3_10.shape[0]): 
     for j in range(S1HSV_imgA1A3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_410.append(S1HSV_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_110.append(S1HSV_imgA1A3_10[i][j])  
S1meanrefA1_410 = np.array(S1meanrefA1_410)
S1meanA3_110 = np.array(S1meanA3_110)

S1hsvrefA1_410 = list()
S1hsvA3_110 = list()
for i in range(3):
    S1hsvrefA1_410.append(S1meanrefA1_410[:,i].mean())
    S1hsvA3_110.append(S1meanA3_110[:,i].mean())

# %%
S1meanrefA1_510 = list()
S1meanA3_5110 = list()
for i in range(S1HSV_imgA1A3_510.shape[0]): 
     for j in range(S1HSV_imgA1A3_510.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_510.append(S1HSV_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA3_5110.append(S1HSV_imgA1A3_510[i][j])  
S1meanrefA1_510 = np.array(S1meanrefA1_5v)
S1meanA3_5110 = np.array(S1meanA3_5110)

S1hsvrefA1_510 = list()
S1hsvA3_5110 = list()
for i in range(3):
    S1hsvrefA1_510.append(S1meanrefA1_510[:,i].mean())
    S1hsvA3_5110.append(S1meanA3_5110[:,i].mean())

# %%
S1meanrefA1_610 = list()
S1meanA4_110 = list()
for i in range(S1HSV_imgA1A4_10.shape[0]): 
     for j in range(S1HSV_imgA1A4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_610.append(S1HSV_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanA4_110.append(S1HSV_imgA1A4_10[i][j])  
S1meanrefA1_610 = np.array(S1meanrefA1_610)
S1meanA4_110 = np.array(S1meanA4_110)

S1hsvrefA1_610 = list()
S1hsvA4_110 = list()
for i in range(3):
    S1hsvrefA1_610.append(S1meanrefA1_610[:,i].mean())
    S1hsvA4_110.append(S1meanA4_110[:,i].mean())

# %%
S1meanrefA1_710 = list()
S1meanB1_110 = list()
for i in range(S1HSV_imgA1B1_10.shape[0]): 
     for j in range(S1HSV_imgA1B1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_710.append(S1HSV_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB1_110.append(S1HSV_imgA1B1_10[i][j])  
S1meanrefA1_710 = np.array(S1meanrefA1_710)
S1meanB1_110 = np.array(S1meanB1_110)

S1hsvrefA1_710 = list()
S1hsvB1_110 = list()
for i in range(3):
    S1hsvrefA1_710.append(S1meanrefA1_710[:,i].mean())
    S1hsvB1_110.append(S1meanB1_110[:,i].mean())

# %%
S1meanrefA1_810 = list()
S1meanB2_1v = list()
for i in range(S1HSV_imgA1B2_1010.shape[0]): 
     for j in range(S1HSV_imgA1B2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_810.append(S1HSV_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_110.append(S1HSV_imgA1B2_10[i][j])  
S1meanrefA1_810 = np.array(S1meanrefA1_810)
S1meanB2_110 = np.array(S1meanB2_110)

S1hsvrefA1_810 = list()
S1hsvB2_110 = list()
for i in range(3):
    S1hsvrefA1_810.append(S1meanrefA1_810[:,i].mean())
    S1hsvB2_110.append(S1meanB2_110[:,i].mean())

# %%
S1meanrefA1_910 = list()
S1meanB3_110 = list()
for i in range(S1HSV_imgA1B3_10.shape[0]): 
     for j in range(S1HSV_imgA1B3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_910.append(S1HSV_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB3_110.append(S1HSV_imgA1B3_10[i][j])  
S1meanrefA1_910 = np.array(S1meanrefA1_910)
S1meanB3_110 = np.array(S1meanB3_110)

S1hsvrefA1_910 = list()
S1hsvB3_110 = list()
for i in range(3):
    S1hsvrefA1_910.append(S1meanrefA1_910[:,i].mean())
    S1hsvB3_110.append(S1meanB3_110[:,i].mean())

# %%
S1meanrefA1_1010 = list()
S1meanB4_110 = list()
for i in range(S1HSV_imgA1B4_10.shape[0]): 
     for j in range(S1HSV_imgA1B4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1010.append(S1HSV_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_110.append(S1HSV_imgA1B4_10[i][j])  
S1meanrefA1_1010 = np.array(S1meanrefA1_1010)
S1meanB4_110 = np.array(S1meanB4_110)

S1hsvrefA1_1010 = list()
S1hsvB4_110 = list()
for i in range(3):
    S1hsvrefA1_1010.append(S1meanrefA1_1010[:,i].mean())
    S1hsvB4_110.append(S1meanB4_110[:,i].mean())

# %%
S1meanrefA1_1110 = list()
S1meanC1_110 = list()
for i in range(S1HSV_imgA1C1_10.shape[0]): 
     for j in range(S1HSV_imgA1C1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1110.append(S1HSV_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC1_110.append(S1HSV_imgA1C1_10[i][j])  
S1meanrefA1_1110 = np.array(S1meanrefA1_1110)
S1meanC1_110 = np.array(S1meanC1_110)

S1hsvrefA1_1110 = list()
S1hsvC1_110 = list()
for i in range(3):
    S1hsvrefA1_1110.append(S1meanrefA1_1110[:,i].mean())
    S1hsvC1_110.append(S1meanC1_110[:,i].mean())

# %%
S1meanrefA1_1210 = list()
S1meanC2_110 = list()
for i in range(S1HSV_imgA1C2_10.shape[0]): 
     for j in range(S1HSV_imgA1C2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1210.append(S1HSV_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_110.append(S1HSV_imgA1C2_10[i][j])  
S1meanrefA1_1210 = np.array(S1meanrefA1_1210)
S1meanC2_110 = np.array(S1meanC2_110)

S1hsvrefA1_1210 = list()
S1hsvC2_1v = list()
for i in range(3):
    S1hsvrefA1_1210.append(S1meanrefA1_1210[:,i].mean())
    S1hsvC2_110.append(S1meanC2_110[:,i].mean())

# %%
S1meanrefA1_1310 = list()
S1meanC3_110 = list()
for i in range(S1HSV_imgA1C3_10.shape[0]): 
     for j in range(S1HSV_imgA1C3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1310.append(S1HSV_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC3_110.append(S1HSV_imgA1C3_10[i][j])  
S1meanrefA1_1310 = np.array(S1meanrefA1_1310)
S1meanC3_110 = np.array(S1meanC3_110)

S1hsvrefA1_1310 = list()
S1hsvC3_110 = list()
for i in range(3):
    S1hsvrefA1_1310.append(S1meanrefA1_1310[:,i].mean())
    S1hsvC3_110.append(S1meanC3_110[:,i].mean())

# %%
S1meanrefA1_1410 = list()
S1meanC4_110 = list()
for i in range(S1HSV_imgA1C4_10.shape[0]): 
     for j in range(S1HSV_imgA1C4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1410.append(S1HSV_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC4_110.append(S1HSV_imgA1C4_10[i][j])  
S1meanrefA1_1410 = np.array(S1meanrefA1_1410)
S1meanC4_110 = np.array(S1meanC4_110)

S1hsvrefA1_1410 = list()
S1hsvC4_110 = list()
for i in range(3):
    S1hsvrefA1_1410.append(S1meanrefA1_1410[:,i].mean())
    S1hsvC4_110.append(S1meanC4_110[:,i].mean())

# %%
S1meanrefA1_1510 = list()
S1meanD2_110 = list()
for i in range(S1HSV_imgA1D2_10.shape[0]): 
     for j in range(S1HSV_imgA1D2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1510.append(S1HSV_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD2_110.append(S1HSV_imgA1D2_10[i][j])  
S1meanrefA1_1510 = np.array(S1meanrefA1_1510)
S1meanD2_110 = np.array(S1meanD2_110)

S1hsvrefA1_1510 = list()
S1hsvD2_110 = list()
for i in range(3):
    S1hsvrefA1_15v.append(S1meanrefA1_1510[:,i].mean())
    S1hsvD2_110.append(S1meanD2_110[:,i].mean())

# %%
S1meanrefA1_1610 = list()
S1meanD3_110 = list()
for i in range(S1HSV_imgA1D3_10.shape[0]): 
     for j in range(S1HSV_imgA1D3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1610.append(S1HSV_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD3_110.append(S1HSV_imgA1D3_10[i][j])  
S1meanrefA1_1610 = np.array(S1meanrefA1_1610)
S1meanD3_110 = np.array(S1meanD3_110)

S1hsvrefA1_1610 = list()
S1hsvD3_110 = list()
for i in range(3):
    S1hsvrefA1_1610.append(S1meanrefA1_1610[:,i].mean())
    S1hsvD3_110.append(S1meanD3_110[:,i].mean())

# %%
S1meanrefA1_1710= list()
S1meanD4_110 = list()
for i in range(S1HSV_imgA1D4_10.shape[0]): 
     for j in range(S1HSV_imgA1D4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1710.append(S1HSV_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanD4_110.append(S1HSV_imgA1D4_10[i][j])  
S1meanrefA1_1710= np.array(S1meanrefA1_1410)
S1meanD4_110 = np.array(S1meanD4_110)

S1hsvrefA1_1710 = list()
S1hsvD4_110 = list()
for i in range(3):
    S1hsvrefA1_1710.append(S1meanrefA1_1710[:,i].mean())
    S1hsvD4_110.append(S1meanD4_110[:,i].mean())

# %% [markdown]
# ##Set2

# %% [markdown]
# ###RGB

# %%
S2meanrefA1_1 = list()
S2meanA1_2 = list()
for i in range(S2RGB_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1.append(S2RGB_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_2.append(S2RGB_imgA1A1_1[i][j])  
S2meanrefA1_1 = np.array(S2meanrefA1_1)
S2meanA1_2 = np.array(S2meanA1_2)

S2rgbrefA1_1 = list()
S2rgbA1_2 = list()
for i in range(3):
    S2rgbrefA1_1.append(S2meanrefA1_1[:,i].mean())
    S2rgbA1_2.append(S2meanA1_2[:,i].mean())

# %%
S2meanrefA1_3 = list()
S2meanA2_1 = list()
for i in range(S2RGB_imgA1A2_1.shape[0]): 
     for j in range(S2RGB_imgA1A2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_3.append(S2RGB_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_1.append(S2RGB_imgA1A2_1[i][j])  
S2meanrefA1_3 = np.array(S2meanrefA1_3)
S2meanA2_1 = np.array(S2meanA2_1)

S2rgbrefA1_3 = list()
S2rgbA2_1 = list()
for i in range(3):
    S2rgbrefA1_3.append(S2meanrefA1_3[:,i].mean())
    S2rgbA2_1.append(S2meanA2_1[:,i].mean())

# %%
S2meanrefA1_4 = list()
S2meanA3_1 = list()
for i in range(S2RGB_imgA1A3_1.shape[0]): 
     for j in range(S2RGB_imgA1A3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_4.append(S2RGB_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_1.append(S2RGB_imgA1A3_1[i][j])  
S2meanrefA1_4 = np.array(S2meanrefA1_4)
S2meanA3_1 = np.array(S2meanA3_1)

S2rgbrefA1_4 = list()
S2rgbA3_1 = list()
for i in range(3):
    S2rgbrefA1_4.append(S2meanrefA1_4[:,i].mean())
    S2rgbA3_1.append(S2meanA3_1[:,i].mean())

# %%
S2meanrefA1_5 = list()
S2meanA3_51 = list()
for i in range(S2RGB_imgA1A3_51.shape[0]): 
     for j in range(S2RGB_imgA1A3_51.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_5.append(S2RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_51.append(S2RGB_imgA1A3_51[i][j])  
S2meanrefA1_5 = np.array(S2meanrefA1_5)
S2meanA3_51 = np.array(S2meanA3_51)

S2rgbrefA1_5 = list()
S2rgbA3_51 = list()
for i in range(3):
    S2rgbrefA1_5.append(S2meanrefA1_5[:,i].mean())
    S2rgbA3_51.append(S2meanA3_51[:,i].mean())

# %%
S2meanrefA1_6 = list()
S2meanA4_1 = list()
for i in range(S2RGB_imgA1A4_1.shape[0]): 
     for j in range(S2RGB_imgA1A4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_6.append(S2RGB_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_1.append(S2RGB_imgA1A4_1[i][j])  
S2meanrefA1_6 = np.array(S2meanrefA1_6)
S2meanA4_1 = np.array(S2meanA4_1)

S2rgbrefA1_6 = list()
S2rgbA4_1 = list()
for i in range(3):
    S2rgbrefA1_6.append(S2meanrefA1_6[:,i].mean())
    S2rgbA4_1.append(S2meanA4_1[:,i].mean())

# %%
S2meanrefA1_7 = list()
S2meanB1_1 = list()
for i in range(S2RGB_imgA1B1_1.shape[0]): 
     for j in range(S2RGB_imgA1B1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_7.append(S2RGB_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_1.append(S2RGB_imgA1B1_1[i][j])  
S2meanrefA1_7 = np.array(S2meanrefA1_7)
S2meanB1_1 = np.array(S2meanB1_1)

S2rgbrefA1_7 = list()
S2rgbB1_1 = list()
for i in range(3):
    S2rgbrefA1_7.append(S2meanrefA1_7[:,i].mean())
    S2rgbB1_1.append(S2meanB1_1[:,i].mean())

# %%
S2meanrefA1_8 = list()
S2meanB2_1 = list()
for i in range(S2RGB_imgA1B2_1.shape[0]): 
     for j in range(S2RGB_imgA1B2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_8.append(S2RGB_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_1.append(S2RGB_imgA1B2_1[i][j])  
S2meanrefA1_8 = np.array(S2meanrefA1_8)
S2meanB2_1 = np.array(S2meanB2_1)

S2rgbrefA1_8 = list()
S2rgbB2_1 = list()
for i in range(3):
    S2rgbrefA1_8.append(S2meanrefA1_8[:,i].mean())
    S2rgbB2_1.append(S2meanB2_1[:,i].mean())

# %%
S2meanrefA1_9 = list()
S2meanB3_1 = list()
for i in range(S2RGB_imgA1B3_1.shape[0]): 
     for j in range(S2RGB_imgA1B3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_9.append(S2RGB_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_1.append(S2RGB_imgA1B3_1[i][j])  
S2meanrefA1_9 = np.array(S2meanrefA1_9)
S2meanB3_1 = np.array(S2meanB3_1)

S2rgbrefA1_9 = list()
S2rgbB3_1 = list()
for i in range(3):
    S2rgbrefA1_9.append(S2meanrefA1_9[:,i].mean())
    S2rgbB3_1.append(S2meanB3_1[:,i].mean())

# %%
S2meanrefA1_10 = list()
S2meanB4_1 = list()
for i in range(S2RGB_imgA1B4_1.shape[0]): 
     for j in range(S2RGB_imgA1B4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_10.append(S2RGB_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_1.append(S2RGB_imgA1B4_1[i][j])  
S2meanrefA1_10 = np.array(S2meanrefA1_10)
S2meanB4_1 = np.array(S2meanB4_1)

S2rgbrefA1_10 = list()
S2rgbB4_1 = list()
for i in range(3):
    S2rgbrefA1_10.append(S2meanrefA1_10[:,i].mean())
    S2rgbB4_1.append(S2meanB4_1[:,i].mean())

# %%
S2meanrefA1_11 = list()
S2meanC1_1 = list()
for i in range(S2RGB_imgA1C1_1.shape[0]): 
     for j in range(S2RGB_imgA1C1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_11.append(S2RGB_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_1.append(S2RGB_imgA1C1_1[i][j])  
S2meanrefA1_11 = np.array(S2meanrefA1_11)
S2meanC1_1 = np.array(S2meanC1_1)

S2rgbrefA1_11 = list()
S2rgbC1_1 = list()
for i in range(3):
    S2rgbrefA1_11.append(S2meanrefA1_11[:,i].mean())
    S2rgbC1_1.append(S2meanC1_1[:,i].mean())

# %%
S2meanrefA1_12 = list()
S2meanC2_1 = list()
for i in range(S2RGB_imgA1C2_1.shape[0]): 
     for j in range(S2RGB_imgA1C2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_12.append(S2RGB_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_1.append(S2RGB_imgA1C2_1[i][j])  
S2meanrefA1_12 = np.array(S2meanrefA1_12)
S2meanC2_1 = np.array(S2meanC2_1)

S2rgbrefA1_12 = list()
S2rgbC2_1 = list()
for i in range(3):
    S2rgbrefA1_12.append(S2meanrefA1_12[:,i].mean())
    S2rgbC2_1.append(S2meanC2_1[:,i].mean())

# %%
S2meanrefA1_13 = list()
S2meanC3_1 = list()
for i in range(S2RGB_imgA1C3_1.shape[0]): 
     for j in range(S2RGB_imgA1C3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_13.append(S2RGB_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_1.append(S2RGB_imgA1C3_1[i][j])  
S2meanrefA1_13 = np.array(S2meanrefA1_13)
S2meanC3_1 = np.array(S2meanC3_1)

S2rgbrefA1_13 = list()
S2rgbC3_1 = list()
for i in range(3):
    S2rgbrefA1_13.append(S2meanrefA1_13[:,i].mean())
    S2rgbC3_1.append(S2meanC3_1[:,i].mean())

# %%
S2meanrefA1_14 = list()
S2meanC4_1 = list()
for i in range(S2RGB_imgA1C4_1.shape[0]): 
     for j in range(S2RGB_imgA1C4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_14.append(S2RGB_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_1.append(S2RGB_imgA1C4_1[i][j])  
S2meanrefA1_14 = np.array(S2meanrefA1_14)
S2meanC4_1 = np.array(S2meanC4_1)

S2rgbrefA1_14 = list()
S2rgbC4_1 = list()
for i in range(3):
    S2rgbrefA1_14.append(S2meanrefA1_14[:,i].mean())
    S2rgbC4_1.append(S2meanC4_1[:,i].mean())

# %%
S2meanrefA1_15 = list()
S2meanD2_1 = list()
for i in range(S2RGB_imgA1D2_1.shape[0]): 
     for j in range(S2RGB_imgA1D2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_15.append(S2RGB_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_1.append(S2RGB_imgA1D2_1[i][j])  
S2meanrefA1_15 = np.array(S2meanrefA1_15)
S2meanD2_1 = np.array(S2meanD2_1)

S2rgbrefA1_15 = list()
S2rgbD2_1 = list()
for i in range(3):
    S2rgbrefA1_15.append(S2meanrefA1_15[:,i].mean())
    S2rgbD2_1.append(S2meanD2_1[:,i].mean())

# %%
S2meanrefA1_16 = list()
S2meanD3_1 = list()
for i in range(S2RGB_imgA1D3_1.shape[0]): 
     for j in range(S2RGB_imgA1D3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_16.append(S2RGB_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_1.append(S2RGB_imgA1D3_1[i][j])  
S2meanrefA1_16 = np.array(S2meanrefA1_16)
S2meanD3_1 = np.array(S2meanD3_1)

S2rgbrefA1_16 = list()
S2rgbD3_1 = list()
for i in range(3):
    S2rgbrefA1_16.append(S2meanrefA1_16[:,i].mean())
    S2rgbD3_1.append(S2meanD3_1[:,i].mean())

# %%
S2meanrefA1_17= list()
S2meanD4_1 = list()
for i in range(S2RGB_imgA1D4_1.shape[0]): 
     for j in range(S2RGB_imgA1D4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_17.append(S2RGB_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_1.append(S2RGB_imgA1D4_1[i][j])  
S2meanrefA1_17 = np.array(S2meanrefA1_14)
S2meanD4_1 = np.array(S2meanD4_1)

S2rgbrefA1_17 = list()
S2rgbD4_1 = list()
for i in range(3):
    S2rgbrefA1_17.append(S2meanrefA1_17[:,i].mean())
    S2rgbD4_1.append(S2meanD4_1[:,i].mean())

# %% [markdown]
# ###Img 2

# %%
S2meanrefA1_102 = list()
S2meanA1_202 = list()
for i in range(S2RGB_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_102.append(S2RGB_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_202.append(S2RGB_imgA1A1_2[i][j])  
S2meanrefA1_102 = np.array(S2meanrefA1_102)
S2meanA1_202 = np.array(S2meanA1_202)

S2rgbrefA1_102 = list()
S2rgbA1_202 = list()
for i in range(3):
    S2rgbrefA1_102.append(S2meanrefA1_102[:,i].mean())
    S2rgbA1_202.append(S2meanA1_202[:,i].mean())
S2rgbrefA1_102,S2rgbA1_202

# %%
S2meanrefA1_302 = list()
S2meanA2_102 = list()
for i in range(S2RGB_imgA1A2_2.shape[0]): 
     for j in range(S2RGB_imgA1A2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_302.append(S2RGB_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S2meanA2_102.append(S2RGB_imgA1A2_2[i][j])  
S2meanrefA1_302 = np.array(S2meanrefA1_302)
S2meanA2_102 = np.array(S2meanA2_102)

S2rgbrefA1_302 = list()
S2rgbA2_102 = list()
for i in range(3):
    S2rgbrefA1_302.append(S2meanrefA1_302[:,i].mean())
    S2rgbA2_102.append(S2meanA2_102[:,i].mean())

# %%
S2meanrefA1_402 = list()
S2meanA3_102 = list()
for i in range(S2RGB_imgA1A3_2.shape[0]): 
     for j in range(S2RGB_imgA1A3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_402.append(RGB_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_102.append(S2RGB_imgA1A3_2[i][j])  
S2meanrefA1_402 = np.array(S2meanrefA1_402)
S2meanA3_102 = np.array(S2meanA3_102)

S2rgbrefA1_402 = list()
S2rgbA3_102 = list()
for i in range(3):
    S2rgbrefA1_402.append(S2meanrefA1_402[:,i].mean())
    S2rgbA3_102.append(S2meanA3_102[:,i].mean())

# %%
S2meanrefA1_02 = list()
S2meanA3_5102 = list()
for i in range(S2RGB_imgA1A3_52.shape[0]): 
     for j in range(S2RGB_imgA1A3_52.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_502.append(S2RGB_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5102.append(S2RGB_imgA1A3_52[i][j])  
S2meanrefA1_502 = np.array(S2meanrefA1_502)
S2meanA3_5102 = np.array(S2meanA3_5102)

S2rgbrefA1_502 = list()
S2rgbA3_5102 = list()
for i in range(3):
    S2rgbrefA1_502.append(S2meanrefA1_502[:,i].mean())
    S2rgbA3_5102.append(S2meanA3_5102[:,i].mean())

# %%
S2meanrefA1_602 = list()
S2meanA4_102 = list()
for i in range(S2RGB_imgA1A4_2.shape[0]): 
     for j in range(S2RGB_imgA1A4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_602.append(S2RGB_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_102.append(S2RGB_imgA1A4_2[i][j])  
S2meanrefA1_602 = np.array(S2meanrefA1_602)
S2meanA4_102 = np.array(S2meanA4_102)

S2rgbrefA1_602 = list()
S2rgbA4_102 = list()
for i in range(3):
   S2rgbrefA1_602.append(S2meanrefA1_602[:,i].mean())
   S2rgbA4_102.append(S2meanA4_102[:,i].mean())

# %%
S2meanrefA1_702 = list()
S2meanB1_102 = list()
for i in range(S2RGB_imgA1B1_202.shape[0]): 
     for j in range(S2RGB_imgA1B1_202.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_702.append(S2RGB_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  meanB1_102.append(S2RGB_imgA1B1_2[i][j])  
S2meanrefA1_702 = np.array(S2meanrefA1_702)
S2meanB1_102 = np.array(S2meanB1_102)

S2rgbrefA1_7 02= list()
S2rgbB1_102 = list()
for i in range(3):
    S2rgbrefA1_702.append(S2meanrefA1_702[:,i].mean())
   S2rgbB1_102.append(S2meanB1_102[:,i].mean())

# %%
S2meanrefA1_802 = list()
S2meanB2_102 = list()
for i in range(RGB_imgA1B2_2.shape[0]): 
     for j in range(RGB_imgA1B2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_802.append(RGB_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S2meanB2_102.append(S2RGB_imgA1B2_2[i][j])  
S2meanrefA1_802 = np.array(S2meanrefA1_802)
S2meanB2_102 = np.array(S2meanB2_102)

S2gbrefA1_802 = list()
S2rgbB2_102 = list()
for i in range(3):
    S2rgbrefA1_802.append(S2meanrefA1_802[:,i].mean())
   S2rgbB2_102.append(S2meanB2_102[:,i].mean())

# %%
S2meanrefA1_902 = list()
S2meanB3_102 = list()
for i in range(S2RGB_imgA1B3_2.shape[0]): 
     for j in range(S2RGB_imgA1B3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S2meanrefA1_902.append(S2RGB_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_102.append(S2RGB_imgA1B3_2[i][j])  
S2meanrefA1_902 = np.array(S2meanrefA1_902)
S2meanB3_102 = np.array(S2meanB3_102)

S2rgbrefA1_902 = list()
S2rgbB3_102 = list()
for i in range(3):
    S2rgbrefA1_902.append(S2meanrefA1_902[:,i].mean())
    S2rgbB3_102.append(S2meanB3_102[:,i].mean())

# %%
meanrefA1_1002 = list()
meanB4_102 = list()
for i in range(RGB_imgA1B4_2.shape[0]): 
     for j in range(RGB_imgA1B4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  meanrefA1_1002.append(S1RGB_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  meanB4_102.append(RGB_imgA1B4_2[i][j])  
meanrefA1_1002 = np.array(meanrefA1_1002)
meanB4_102 = np.array(meanB4_102)

rgbrefA1_1002 = list()
rgbB4_102 = list()
for i in range(3):
    rgbrefA1_1002.append(meanrefA1_1002[:,i].mean())
    rgbB4_102.append(meanB4_102[:,i].mean())

# %%
S2meanrefA1_1102 = list()
S2meanC1_102 = list()
for i in range(S2RGB_imgA1C1_2.shape[0]): 
     for j in range(S2RGB_imgA1C1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1102.append(S2RGB_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_102.append(S2RGB_imgA1C1_2[i][j])  
S2meanrefA1_1102 = np.array(S2meanrefA1_1102)
S2meanC1_102 = np.array(S2meanC1_102)

S2rgbrefA1_1102 = list()
S2rgbC1_102 = list()
for i in range(3):
    S2rgbrefA1_1102.append(S2meanrefA1_1102[:,i].mean())
   S2rgbC1_102.append(S2meanC1_102[:,i].mean())

# %%
S2meanrefA1_1202 = list()
S2meanC2_102 = list()
for i in range(S2RGB_imgA1C2_2.shape[0]): 
     for j in range(S2RGB_imgA1C2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1202.append(S2RGB_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_102.append(S2RGB_imgA1C2_2[i][j])  
S2meanrefA1_1202 = np.array(S2meanrefA1_1202)
S2meanC2_102 = np.array(S2meanC2_102)

S2rgbrefA1_1202 = list()
S2rgbC2_102 = list()
for i in range(3):
    S2rgbrefA1_1202.append(S2meanrefA1_1202[:,i].mean())
    S2rgbC2_102.append(S2meanC2_102[:,i].mean())

# %%
S2meanrefA1_1302 = list()
S2meanC3_102 = list()
for i in range(S2RGB_imgA1C3_2.shape[0]): 
     for j in range(S2RGB_imgA1C3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1302.append(S2RGB_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                S2meanC3_102.append(S2RGB_imgA1C3_2[i][j])  
S2meanrefA1_1302 = np.array(S2meanrefA1_1302)
S2meanC3_102 = np.array(S2meanC3_102)

S2rgbrefA1_1302 = list()
S2rgbC3_102 = list()
for i in range(3):
    S2rgbrefA1_1302.append(S2meanrefA1_1302[:,i].mean())
    S2rgbC3_102.append(S2meanC3_102[:,i].mean())

# %%
S2meanrefA1_1402 = list()
S2meanC4_102 = list()
for i in range(S2RGB_imgA1C4_2.shape[0]): 
     for j in range(S2RGB_imgA1C4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1402.append(S2RGB_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_102.append(S2RGB_imgA1C4_2[i][j])  
S2meanrefA1_1402 = np.array(S2meanrefA1_1402)
S2meanC4_102 = np.array(S2meanC4_102)

S2rgbrefA1_1402 = list()
S2rgbC4_102 = list()
for i in range(3):
    S2rgbrefA1_1402.append(S2meanrefA1_1402[:,i].mean())
     S2rgbC4_102.append(S2meanC4_102[:,i].mean())

# %%
S2meanrefA1_1502 = list()
S2meanD2_102 = list()
for i in range(S2RGB_imgA1D2_2.shape[0]): 
     for j in range(RGB_imgA1D2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1502.append(RGB_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_102.append(RGB_imgA1D2_2[i][j])  
S2meanrefA1_1502 = np.array(S2meanrefA1_1502)
S2meanD2_102 = np.array(S2meanD2_102)

S2rgbrefA1_1502 = list()
S2rgbD2_102 = list()
for i in range(3):
    S2rgbrefA1_1502.append(S2meanrefA1_1502[:,i].mean())
    S2rgbD2_102.append(S2meanD2_102[:,i].mean())

# %%
S2meanrefA1_1602 = list()
S2meanD3_102 = list()
for i in range(S2RGB_imgA1D3_2.shape[0]): 
     for j in range(S2RGB_imgA1D3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1602.append(S2RGB_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S2meanD3_102.append(S2RGB_imgA1D3_2[i][j])  
S2meanrefA1_1602 = np.array(S2meanrefA1_1602)
S2meanD3_102 = np.array(S2meanD3_102

S2rgbrefA1_1602 = list()
S2rgbD3_102 = list()
for i in range(3):
    S2rgbrefA1_1602.append(S2meanrefA1_1602[:,i].mean())
    S2rgbD3_102.append(S2meanD3_102[:,i].mean())

# %%
S2meanrefA1_1702= list()
S2meanD4_102 = list()
for i in range(S2RGB_imgA1D4_2.shape[0]): 
     for j in range(S2RGB_imgA1D4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S2meanrefA1_1702.append(S2RGB_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_102.append(S2RGB_imgA1D4_2[i][j])  
S2meanrefA1_1702 = np.array(S2meanrefA1_1402)
S2meanD4_102 = np.array(S2meanD4_102)

S2rgbrefA1_1702 = list()
S2rgbD4_102 = list()
for i in range(3):
   S2rgbrefA1_1702.append(S2meanrefA1_1702[:,i].mean())
   S2gbD4_102.append(S2meanD4_102[:,i].mean())

# %% [markdown]
# ###Img 3

# %%
S2meanrefA1_103 = list()
S2meanA1_203 = list()
for i in range(S2RGB_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1.append(S2RGB_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_2.append(S2RGB_imgA1A1_3[i][j])  
S2meanrefA1_103 = np.array(S2meanrefA1_103)
S2meanA1_203 = np.array(S2meanA1_203)

S2rgbrefA1_103 = list()
S2rgbA1_203 = list()
for i in range(3):
    S2rgbrefA1_103.append(S2meanrefA1_103[:,i].mean())
    S2rgbA1_203.append(S2meanA1_203[:,i].mean())
S2rgbrefA1_103,S222rgbA1_2 03

# %%
S2meanrefA1_303 = list()
S2meanA2_103 = list()
for i in range(S2RGB_imgA1A2_3.shape[0]): 
     for j in range(S2RGB_imgA1A2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_303.append(S1RGB_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_103.append(S2RGB_imgA1A2_3[i][j])  
S2meanrefA1_303 = np.array(S2meanrefA1_303)
S2meanA2_103 = np.array(S2meanA2_103)

S2rgbrefA1_303 = list()
S2rgbA2_103 = list()
for i in range(3):
    S2rgbrefA1_303.append(S2meanrefA1_303[:,i].mean())
    S2rgbA2_103.append(S2meanA2_103[:,i].mean())

# %%
S2meanrefA1_403 = list()
S2meanA3_103 = list()
for i in range(S2RGB_imgA1A3_3.shape[0]): 
     for j in range(S2RGB_imgA1A3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_403.append(S2RGB_imgA1A33_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_103.append(S2RGB_imgA1A3_3[i][j])  
S2meanrefA1_403= np.array(S2meanrefA1_403 )
S2meanA3_103 = np.array(S2meanA3_103 )

S2gbrefA1_403  = list()
S2rgbA3_103  = list()
for i in range(3):
    S2rgbrefA1_403 .append(S2meanrefA1_403[:,i].mean())
    S2rgbA3_103 .append(S2meanA3_103 [:,i].mean())

# %%
S2meanrefA1_503  = list()
S2meanA3_5103  = list()
for i in range(S2RGB_imgA1A3_53.shape[0]): 
     for j in range(S2RGB_imgA1A3_53.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_503 .append(S2RGB_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5103 .append(S2RGB_imgA1A3_53[i][j])  
S2meanrefA1_503  = np.array(S2meanrefA1_503 )
S2meanA3_5103  = np.array(S2meanA3_5103 )

S2rgbrefA1_503  = list()
S2rgbA3_5103  = list()
for i in range(3):
    S2rgbrefA1_503 .append(S2meanrefA1_503 [:,i].mean())
    S2rgbA3_5103 .append(S2meanA3_5103 [:,i].mean())

# %%
S2meanrefA1_603  = list()
S2meanA4_103  = list()
for i in range(S2RGB_imgA1A4_3.shape[0]): 
     for j in range(S2RGB_imgA1A4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_603 .append(S2RGB_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_103 .append(S2RGB_imgA1A4_3[i][j])  
S2meanrefA1_603  = np.array(S2meanrefA1_603 )
S2meanA4_103  = np.array(S2meanA4_103 )

S2rgbrefA1_603  = list()
S2rgbA4_103  = list()
for i in range(3):
    S2rgbrefA1_603 .append(S2meanrefA1_603[:,i].mean())
    S2rgbA4_103 .append(S2meanA4_103 [:,i].mean())

# %%
S2meanrefA1_703  = list()
S2meanB1_103  = list()
for i in range(S2RGB_imgA1B1_3.shape[0]): 
     for j in range(S2RGB_imgA1B1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_703 .append(S2RGB_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_103 .append(S2RGB_imgA1B1_3[i][j])  
S2meanrefA1_703  = np.array(S2meanrefA1_73)
S2meanB1_103  = np.array(S2meanB1_103)

S2rgbrefA1_703  = list()
S2rgbB1_103  = list()
for i in range(3):
    S2rgbrefA1_703 .append(S2meanrefA1_703 [:,i].mean())
    S2rgbB1_103 .append(S2meanB1_103 [:,i].mean())

# %%
S2meanrefA1_803  = list()
S2meanB2_103  = list()
for i in range(S2RGB_imgA1B2_3.shape[0]): 
     for j in range(S2RGB_imgA1B2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_803 .append(S2RGB_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_103 .append(S2RGB_imgA1B2_3[i][j])  
S2meanrefA1_803  = np.array(S2meanrefA1_803 )
S2meanB2_103  = np.array(S2meanB2_103 )

S2rgbrefA1_803  = list()
S2rgbB2_103  = list()
for i in range(3):
    S2rgbrefA1_803 .append(S2meanrefA1_803 [:,i].mean())
    S2rgbB2_103 .append(S2meanB2_103 [:,i].mean())

# %%
S2meanrefA1_903  = list()
S2meanB3_103  = list()
for i in range(S2RGB_imgA1B3_3.shape[0]): 
     for j in range(S2RGB_imgA1B3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_903 .append(S2RGB_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_103 .append(S2RGB_imgA1B3_3[i][j])  
S2meanrefA1_903  = np.array(S2meanrefA1_903 )
S2meanB3_103  = np.array(S2meanB3_103 )

S2rgbrefA1_903  = list()
S2rgbB3_103  = list()
for i in range(3):
    S2rgbrefA1_903 .append(S2meanrefA1_903 [:,i].mean())
    S2rgbB3_103 .append(S2meanB3_103 [:,i].mean())

# %%
S2meanrefA1_1003  = list()
S2meanB4_103  = list()
for i in range(S2RGB_imgA1B4_3.shape[0]): 
     for j in range(S2RGB_imgA1B4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1003 .append(S2RGB_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_103 .append(S2RGB_imgA1B4_3[i][j])  
S2meanrefA1_1003  = np.array(S2meanrefA1_1003 )
S2meanB4_103  = np.array(S2meanB4_103 )

S2rgbrefA1_1003  = list()
S2gbB4_103  = list()
for i in range(3):
    S2rgbrefA1_1003 .append(S2meanrefA1_1003[:,i].mean())
    S2rgbB4_103 .append(S2meanB4_103 [:,i].mean())

# %%
S2meanrefA1_1103  = list()
S2meanC1_103  = list()
for i in range(S2RGB_imgA1C1_3.shape[0]): 
     for j in range(S2RGB_imgA1C1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1103 .append(S2RGB_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_103 .append(S2RGB_imgA1C1_3[i][j])  
S2meanrefA1_1103  = np.array(S2meanrefA1_1103 )
S2meanC1_103  = np.array(S2meanC1_103 )

S2rgbrefA1_1103  = list()
S2rgbC1_103  = list()
for i in range(3):
    S2rgbrefA1_1103.append(S2meanrefA1_1103 [:,i].mean())
    S2rgbC1_103.append(S2meanC1_103 [:,i].mean())

# %%
S2meanrefA1_1203  = list()
S2meanC2_103 = list()
for i in range(S2RGB_imgA1C2_3.shape[0]): 
     for j in range(S2RGB_imgA1C2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1203.append(S2RGB_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanC2_103.append(S2RGB_imgA1C2_3[i][j])  
S2meanrefA1_1203 = np.array(S2meanrefA1_1203)
S21meanC2_103 = np.array(S2meanC2_103)

S2gbrefA1_1203 = list()
S2rgbC2_103 = list()
for i in range(3):
    S2rgbrefA1_1203.append(S2meanrefA1_1203[:,i].mean())
    S2rgbC2_103.append(S2meanC2_103[:,i].mean())

# %%
S2meanrefA1_1303 = list()
S2meanC3_103 = list()
for i in range(S2RGB_imgA1C3_3.shape[0]): 
     for j in range(S2RGB_imgA1C3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1303.append(S2RGB_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_103append(S2RGB_imgA1C3_3i][j])  
S2meanrefA1_1303 = np.array(S2meanrefA1_1303)
S2meanC3_103 = np.array(S2meanC3_103)

S2rgbrefA1_1303 = list()
S2rgbC3_103 = list()
for i in range(3):
    S2rgbrefA1_1303.append(S2meanrefA1_1303[:,i].mean())
    S2rgbC3_103.append(S2meanC3_103[:,i].mean())

# %%
S2meanrefA1_1403 = list()
S2meanC4_103 = list()
for i in range(S2RGB_imgA1C4_3.shape[0]): 
     for j in range(S2RGB_imgA1C4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1403.append(S2RGB_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_103.append(S2RGB_imgA1C4_3[i][j])  
S2meanrefA1_1403 = np.array(S2meanrefA1_1403)
S2meanC4_103 = np.array(S2meanC4_103)

S2gbrefA1_1403 = list()
S2rgbC4_103 = list()
for i in range(3):
    S2rgbrefA1_1403.append(S2meanrefA1_1403[:,i].mean())
    S2rgbC4_103.append(S2meanC4_103[:,i].mean())

# %%
S2meanrefA1_1503 = list()
S2meanD2_103 = list()
for i in range(S2RGB_imgA1D2_3.shape[0]): 
     for j in range(S2RGB_imgA1D2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1503.append(S2RGB_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_103.append(S2RGB_imgA1D2_3[i][j])  
S2meanrefA1_1503 = np.array(S1meanrefA1_1503)
S2meanD2_103 = np.array(S2meanD2_103)

S2rgbrefA1_1503 = list()
S2gbD2_103 = list()
for i in range(3):
    S2rgbrefA1_1503.append(S2meanrefA1_1503[:,i].mean())
    S2rgbD2_103.append(S2meanD2_103[:,i].mean())

# %%
S2meanrefA1_1603 = list()
S2meanD3_103 = list()
for i in range(S2RGB_imgA1D3_3.shape[0]): 
     for j in range(S2RGB_imgA1D3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1603.append(S2RGB_imgA1D33_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_103.append(S2RGB_imgA1D3_3[i][j])  
S2meanrefA1_1603 = np.array(S2meanrefA1_1603)
S2meanD3_103 = np.array(S2meanD3_103)

S2gbrefA1_1603 = list()
S12gbD3_103 = list()
for i in range(3):
    S2rgbrefA1_1603.append(S2meanrefA1_1603[:,i].mean())
    S2rgbD3_103.append(S2meanD3_103[:,i].mean())

# %%
S2meanrefA1_1703= list()
S2meanD4_103 = list()
for i in range(S2RGB_imgA1D4_3.shape[0]): 
     for j in range(S2RGB_imgA1D4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1703.append(S2RGB_imgA1D4_3i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_103.append(S2RGB_imgA1D4_3[i][j])  
S2meanrefA1_1703 = np.array(S2meanrefA1_1403)
S2meanD4_103 = np.array(S2meanD4_103)

S2rgbrefA1_1703 = list()
S2rgbD4_103 = list()
for i in range(3):
    S2rgbrefA1_1703.append(S2meanrefA1_1703[:,i].mean())
    S2rgbD4_103.append(S2meanD4_103[:,i].mean())

# %% [markdown]
# ###Img 4

# %%
S2meanrefA1_104 = list()
S2meanA1_204 = list()
for i in range(S2RGB_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_104.append(S2RGB_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_204.append(S2RGB_imgA1A1_4[i][j])  
S2meanrefA1_104 = np.array(S2meanrefA1_104)
S2meanA1_204 = np.array(S2meanA1_204)

S2rgbrefA1_104 = list()
S2rgbA1_204 = list()
for i in range(3):
    S2rgbrefA1_104.append(S2meanrefA1_104[:,i].mean())
    S2rgbA1_204.append(S2meanA1_204[:,i].mean())
S2rgbrefA1_104,S2rgbA1_204

# %%
S2meanrefA1_304 = list()
S2meanA2_104 = list()
for i in range(S2RGB_imgA1A2_4.shape[0]): 
     for j in range(S2RGB_imgA1A2_.44shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_304.append(21RGB_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_104.append(S2RGB_imgA1A2_4[i][j])  
S2meanrefA1_304 = np.array(S2meanrefA1_304)
S2meanA2_104 = np.array(S2meanA2_104)

S2rgbrefA1_304 = list()
S2rgbA2_104 = list()
for i in range(3):
    S2rgbrefA1_304.append(S2meanrefA1_304[:,i].mean())
    S2rgbA2_104.append(S2meanA2_104[:,i].mean())

# %%
S2meanrefA1_404 = list()
S2meanA3_104 = list()
for i in range(S2RGB_imgA1A3_4.shape[0]): 
     for j in range(S2RGB_imgA1A3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_404.append(S2RGB_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_104.append(S2RGB_imgA1A3_4[i][j])  
S2meanrefA1_404 = np.array(S2meanrefA1_404)
S2meanA3_104 = np.array(S2meanA3_104)

S2rgbrefA1_404 = list()
S2rgbA3_104 = list()
for i in range(3):
    S2rgbrefA1_404.append(S2meanrefA1_404[:,i].mean())
    S2rgbA3_104.append(S2meanA3_104[:,i].mean())

# %%
S2meanrefA1_504 = list()
S2meanA3_5104 = list()
for i in range(S2RGB_imgA1A3_54.shape[0]): 
     for j in range(S2RGB_imgA1A3_54.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_504.append(S2RGB_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5104.append(S2RGB_imgA1A3_54[i][j])  
S2meanrefA1_504 = np.array(S2meanrefA1_5104)
S2meanA3_5104 = np.array(S2meanA3_5104)

S2rgbrefA1_504 = list()
S2rgbA3_5104 = list()
for i in range(3):
    S2rgbrefA1_504.append(S2meanrefA1_504[:,i].mean())
    S2rgbA3_5104.append(S2meanA3_5104[:,i].mean())

# %%
S2meanrefA1_604 = list()
S2meanA4_104 = list()
for i in range(S2RGB_imgA1A4_4.shape[0]): 
     for j in range(S2RGB_imgA1A4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_604.append(S2RGB_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_104.append(S2RGB_imgA1A4_4[i][j])  
S2meanrefA1_604 = np.array(S2meanrefA1_604)
S2meanA4_104 = np.array(S2meanA4_104)

S2rgbrefA1_604 = list()
S2rgbA4_104 = list()
for i in range(3):
    S2rgbrefA1_604.append(S2meanrefA1_604[:,i].mean())
    S2rgbA4_104.append(S2meanA4_104[:,i].mean())

# %%
S3meanrefA1_704 = list()
S2meanB1_104 = list()
for i in range(S2RGB_imgA1B1_4.shape[0]): 
     for j in range(S2RGB_imgA1B1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_704.append(S2RGB_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_104.append(S2RGB_imgA1B1_4[i][j])  
S2meanrefA1_704 = np.array(S2meanrefA1_704)
S2meanB1_104 = np.array(S2meanB1_104)

S2rgbrefA1_704 = list()
S2rgbB1_104 = list()
for i in range(3):
    S2rgbrefA1_704.append(S2meanrefA1_704[:,i].mean())
    S2rgbB1_104.append(S2meanB1_104[:,i].mean())

# %%
S2meanrefA1_804 = list()
S2meanB2_104 = list()
for i in range(S2RGB_imgA1B2_4.shape[0]): 
     for j in range(S2RGB_imgA1B2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_804.append(S2RGB_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_104.append(S2RGB_imgA1B2_4[i][j])  
S2meanrefA1_804 = np.array(S2meanrefA1_804)
S2meanB2_104 = np.array(S2meanB2_104)

S2rgbrefA1_804 = list()
S2rgbB2_104 = list()
for i in range(3):
    S2rgbrefA1_804.append(S2meanrefA1_804[:,i].mean())
    S2rgbB2_104.append(S2meanB2_104[:,i].mean())

# %%
S2meanrefA1_904 = list()
S2meanB3_104 = list()
for i in range(S2RGB_imgA1B3_4.shape[0]): 
     for j in range(S2RGB_imgA1B3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_904.append(S1RGB_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_104.append(S1RGB_imgA1B3_4[i][j])  
S2meanrefA1_904 = np.array(S1meanrefA1_904)
S2meanB3_104 = np.array(S1meanB3_104)

S2rgbrefA1_904 = list()
S2rgbB3_104 = list()
for i in range(3):
    S1rgbrefA1_904.append(S2meanrefA1_904[:,i].mean())
    S1rgbB3_104.append(S2meanB3_104[:,i].mean())

# %%
S2meanrefA1_1004 = list()
S2meanB4_104 = list()
for i in range(S2RGB_imgA1B4_4.shape[0]): 
     for j in range(S2RGB_imgA1B4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_1004.append(S2RGB_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB4_104.append(S2RGB_imgA1B4_4[i][j])  
S2meanrefA1_1004 = np.array(S1meanrefA1_1004)
S2meanB4_104 = np.array(S1meanB4_104)

S2rgbrefA1_1004 = list()
S2rgbB4_104 = list()
for i in range(3):
    S2rgbrefA1_1004.append(S2meanrefA1_1004[:,i].mean())
    S2rgbB4_104.append(S2meanB4_104[:,i].mean())

# %%
S2meanrefA1_1104 = list()
S2meanC1_104 = list()
for i in range(S2RGB_imgA1C1_4.shape[0]): 
     for j in range(S2RGB_imgA1C1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1104.append(S2RGB_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_104.append(S2RGB_imgA1C1_4[i][j])  
S2meanrefA1_1104 = np.array(S2meanrefA1_1104)
S2meanC1_104 = np.array(S2meanC1_104)

S2rgbrefA1_1104 = list()
S2rgbC1_104 = list()
for i in range(3):
    S2rgbrefA1_1104.append(S2meanrefA1_1104[:,i].mean())
    S2rgbC1_104.append(S2meanC1_104[:,i].mean())

# %%
S2meanrefA1_1204 = list()
S2meanC2_104 = list()
for i in range(S2RGB_imgA1C2_4.shape[0]): 
     for j in range(S2RGB_imgA1C2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1204.append(S2RGB_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_104.append(S2RGB_imgA1C2_4[i][j])  
S2meanrefA1_1204 = np.array(S2meanrefA1_1204)
S2meanC2_104 = np.array(S2meanC2_104)

S2rgbrefA1_1204 = list()
S2rgbC2_104 = list()
for i in range(3):
    S2rgbrefA1_1204.append(S2meanrefA1_1204[:,i].mean())
    S2rgbC2_104.append(S2meanC2_104[:,i].mean())

# %%
S2meanrefA1_1304 = list()
S2meanC3_104 = list()
for i in range(S2RGB_imgA1C3_4.shape[0]): 
     for j in range(S2RGB_imgA1C3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1304.append(S2RGB_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_104.append(S2RGB_imgA1C3_4[i][j])  
S2meanrefA1_1304 = np.array(S1meanrefA1_1304)
S2meanC3_104 = np.array(S1meanC3_104)

S2rgbrefA1_1304 = list()
S2rgbC3_104 = list()
for i in range(3):
    S2rgbrefA1_1304.append(S2meanrefA1_1304[:,i].mean())
    S2rgbC3_104.append(S2meanC3_104[:,i].mean())

# %%
S2meanrefA1_1404 = list()
S2meanC4_104 = list()
for i in range(S2RGB_imgA1C4_4.shape[0]): 
     for j in range(S2RGB_imgA1C4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1404.append(S2RGB_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_104.append(S2RGB_imgA1C4_4[i][j])  
S2meanrefA1_1404 = np.array(S2meanrefA1_1404)
S2meanC4_104 = np.array(S2meanC4_104)

S2rgbrefA1_1404 = list()
S2rgbC4_104 = list()
for i in range(3):
    S2rgbrefA1_1404.append(S2meanrefA1_1404[:,i].mean())
    S2rgbC4_104.append(S2meanC4_104[:,i].mean())

# %%
S2meanrefA1_1504 = list()
S2meanD2_104 = list()
for i in range(S2RGB_imgA1D2_4.shape[0]): 
     for j in range(S2RGB_imgA1D2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1504.append(S2RGB_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_104.append(S2RGB_imgA1D2_4[i][j])  
S2meanrefA1_1504 = np.array(S2meanrefA1_1504)
S2meanD2_104 = np.array(S2meanD2_104)

S2rgbrefA1_1504 = list()
S2rgbD2_104 = list()
for i in range(3):
    S2rgbrefA1_1504.append(S2meanrefA1_1504[:,i].mean())
    S2rgbD2_104.append(S2meanD2_104[:,i].mean())

# %%
S2meanrefA1_1604 = list()
S2meanD3_104 = list()
for i in range(S2RGB_imgA1D3_4.shape[0]): 
     for j in range(S2RGB_imgA1D3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1604.append(S2RGB_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_104.append(S2RGB_imgA1D3_4[i][j])  
S2meanrefA1_1604 = np.array(S2meanrefA1_1604)
S2meanD3_104 = np.array(S2meanD3_104)

S2rgbrefA1_1604 = list()
S2rgbD3_104 = list()
for i in range(3):
    S2rgbrefA1_1604.append(S2meanrefA1_1604[:,i].mean())
    S2rgbD3_104.append(S2meanD3_104[:,i].mean())

# %%
S2meanrefA1_1704= list()
S2meanD4_104 = list()
for i in range(S2RGB_imgA1D4_4.shape[0]): 
     for j in range(S2RGB_imgA1D4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1704.append(S2RGB_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_104.append(S2RGB_imgA1D4_4[i][j])  
S2meanrefA1_1704 = np.array(S2meanrefA1_1404)
S2meanD4_104 = np.array(S2meanD4_104)

S2rgbrefA1_1704 = list()
S2rgbD4_104 = list()
for i in range(3):
    S2rgbrefA1_1704.append(S2meanrefA1_1704[:,i].mean())
    S2rgbD4_104.append(S2meanD4_104[:,i].mean())

# %% [markdown]
# ###Img 5

# %%
S2meanrefA1_105 = list()
S2meanA1_205 = list()
for i in range(S2RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_105.append(S2RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_205.append(S2RGB_imgA1A1_5[i][j])  
S2meanrefA1_105 = np.array(S2meanrefA1_105)
S2meanA1_205 = np.array(S2meanA1_205)

S2rgbrefA1_105 = list()
S2rgbA1_205 = list()
for i in range(3):
    S2rgbrefA1_105.append(S2meanrefA1_105[:,i].mean())
    S2rgbA1_205.append(S2meanA1_2[:,i].mean())
S2rgbrefA1_105,S2rgbA1_205

# %%
S2meanrefA1_305 = list()
S2meanA2_105 = list()
for i in range(S2RGB_imgA1A2_5.shape[0]): 
     for j in range(S2RGB_imgA1A2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_305.append(S2RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_105.append(S2RGB_imgA1A2_5[i][j])  
S2meanrefA1_305 = np.array(S2meanrefA1_305 )
S2meanA2_105 = np.array(S2meanA2_105 )

S2rgbrefA1_305 = list()
S2rgbA2_105  = list()
for i in range(3):
    S2rgbrefA1_305 .append(S2meanrefA1_305 [:,i].mean())
    S2rgbA2_105 .append(S2meanA2_105 [:,i].mean())

# %%
S2meanrefA1_405  = list()
S2meanA3_105  = list()
for i in range(S2RGB_imgA1A3_505 .shape[0]): 
     for j in range(S2RGB_imgA1A3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_405 .append(S2RGB_imgA1A3_505 [i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_105 .append(S2RGB_imgA1A3_505 [i][j])  
S2meanrefA1_4 05 = np.array(S2meanrefA1_405 )
S2meanA3_105  = np.array(S2meanA3_105 )

S2rgbrefA1_405  = list()
S2rgbA3_105  = list()
for i in range(3):
    S2rgbrefA1_405 .append(S2meanrefA1_405 [:,i].mean())
    S2rgbA3_105 .append(S2meanA3_105 [:,i].mean())

# %%
S2meanrefA1_505  = list()
S2meanA3_5105  = list()
for i in range(S2RGB_imgA1A3_55.shape[0]): 
     for j in range(S2RGB_imgA1A3_55.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_505 .append(S2RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5105 .append(S2RGB_imgA1A3_55[i][j])  
S2meanrefA1_505  = np.array(S2meanrefA1_5)
S2meanA3_5105  = np.array(S2meanA3_51)

S2rgbrefA1_505  = list()
S2rgbA3_5105  = list()
for i in range(3):
    S2rgbrefA1_505 .append(S2meanrefA1_505 [:,i].mean())
    S2rgbA3_5105 .append(S2meanA3_5105 [:,i].mean())

# %%
S2meanrefA1_605  = list()
S2meanA4_105  = list()
for i in range(S2RGB_imgA1A4_5.shape[0]): 
     for j in range(S2RGB_imgA1A4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_605 .append(S2RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_105 .append(S2RGB_imgA1A4_5[i][j])  
S2meanrefA1_605 = np.array(S2meanrefA1_6)
S2meanA4_105 = np.array(S2meanA4_1)

S2rgbrefA1_605 = list()
S2rgbA4_105 = list()
for i in range(3):
    S2rgbrefA1_605.append(S2meanrefA1_605[:,i].mean())
    S2rgbA4_105.append(S2meanA4_105[:,i].mean())

# %%
S2meanrefA1_705 = list()
S2meanB1_105 = list()
for i in range(S2RGB_imgA1B1_505.shape[0]): 
     for j in range(S2RGB_imgA1B1_505.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_705.append(S2RGB_imgA1B1_505[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_105.append(S2RGB_imgA1B1_505[i][j])  
S2meanrefA1_705 = np.array(S2meanrefA1_705)
S2meanB1_105 = np.array(S2meanB1_105)

S2rgbrefA1_705 = list()
S2rgbB1_105 = list()
for i in range(3):
    S1rgbrefA1_705.append(S1meanrefA1_705[:,i].mean())
    S1rgbB1_105.append(S1meanB1_105[:,i].mean())

# %%
S2meanrefA1_805 = list()
S2meanB2_105 = list()
for i in range(S2RGB_imgA1B2_5.shape[0]): 
     for j in range(S2RGB_imgA1B2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_805.append(S2RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_105.append(S2RGB_imgA1B2_5[i][j])  
S2meanrefA1_805 = np.array(S2meanrefA1_8)
S2meanB2_105 = np.array(S2meanB2_1)

S2rgbrefA1_805 = list()
S2rgbB2_105 = list()
for i in range(3):
    S2rgbrefA1_805.append(S2meanrefA1_805[:,i].mean())
    S2rgbB2_105.append(S2meanB2_105[:,i].mean())

# %%
S2meanrefA1_905 = list()
S2meanB3_105 = list()
for i in range(S2RGB_imgA1B3_5.shape[0]): 
     for j in range(S2RGB_imgA1B3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_905.append(S2RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_105.append(S2RGB_imgA1B3_5[i][j])  
S2meanrefA1_905 = np.array(S2meanrefA1_905)
S2meanB3_105 = np.array(S2meanB3_105)

S2rgbrefA1_905 = list()
S2rgbB3_105 = list()
for i in range(3):
    S2rgbrefA1_905.append(S2meanrefA1_905[:,i].mean())
    S2rgbB3_105.append(S2meanB3_105[:,i].mean())

# %%
S2meanrefA1_1005 = list()
S2meanB4_105 = list()
for i in range(S2RGB_imgA1B4_5.shape[0]): 
     for j in range(S2RGB_imgA1B4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1005.append(S2RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_105.append(S2RGB_imgA1B4_5[i][j])  
S2meanrefA1_1005 = np.array(S2meanrefA1_10)
S2meanB4_105 = np.array(S2meanB4_1)

S2rgbrefA1_1005 = list()
S2rgbB4_105 = list()
for i in range(3):
    S2rgbrefA1_1005.append(S2meanrefA1_1005[:,i].mean())
    S2rgbB4_105.append(S2meanB4_105[:,i].mean())

# %%
S2meanrefA1_1105 = list()
S2meanC1_105 = list()
for i in range(S2RGB_imgA1C1_5.shape[0]): 
     for j in range(S2RGB_imgA1C1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1105.append(S2RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_105.append(S2RGB_imgA1C1_5[i][j])  
S2meanrefA1_1105 = np.array(S2meanrefA1_1105)
S2meanC1_105 = np.array(S2meanC1_105)

SrgbrefA1_1105 = list()
S2rgbC1_105 = list()
for i in range(3):
    S2rgbrefA1_1105.append(S2meanrefA1_1105[:,i].mean())
    S2rgbC1_105.append(S2meanC1_105[:,i].mean())

# %%
S2meanrefA1_1205 = list()
S2meanC2_105 = list()
for i in range(S2RGB_imgA1C2_5.shape[0]): 
     for j in range(S2RGB_imgA1C2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1205.append(S2RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_105.append(S2RGB_imgA1C2_5[i][j])  
S2meanrefA1_1205 = np.array(S2meanrefA1_1205)
S2meanC2_105 = np.array(S2meanC2_105)

S2rgbrefA1_1205 = list()
S2rgbC2_105 = list()
for i in range(3):
    S2rgbrefA1_1205.append(S2meanrefA1_1205[:,i].mean())
    S2rgbC2_105.append(S2meanC2_105[:,i].mean())

# %%
S2meanrefA1_1305 = list()
S2meanC3_105 = list()
for i in range(S2RGB_imgA1C3_5.shape[0]): 
     for j in range(S2RGB_imgA1C3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1305.append(S2RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_105.append(S2RGB_imgA1C3_5[i][j])  
S2meanrefA1_1305 = np.array(S2meanrefA1_13)
S2meanC3_105 = np.array(S2meanC3_1)

S2rgbrefA1_1305 = list()
S2rgbC3_105 = list()
for i in range(3):
    S2rgbrefA1_1305.append(S1meanrefA1_1305[:,i].mean())
    S2rgbC3_105.append(S1meanC3_105[:,i].mean())

# %%
S2meanrefA1_1405 = list()
S2meanC4_105 = list()
for i in range(S2RGB_imgA1C4_5.shape[0]): 
     for j in range(S2RGB_imgA1C4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1405.append(S2RGB_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_105.append(S2RGB_imgA1C4_5[i][j])  
S2meanrefA1_1405 = np.array(S2meanrefA1_1405)
S2meanC4_105 = np.array(S2meanC4_105)

S2rgbrefA1_1405 = list()
S2rgbC4_105 = list()
for i in range(3):
    S2rgbrefA1_1405.append(S2meanrefA1_1405[:,i].mean())
    S2rgbC4_105.append(S2meanC4_105[:,i].mean())

# %%
S2meanrefA1_1505 = list()
S2meanD2_105 = list()
for i in range(S3RGB_imgA1D2_5.shape[0]): 
     for j in range(S3RGB_imgA1D2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1505.append(S2RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_105.append(S2RGB_imgA1D2_5[i][j])  
S2meanrefA1_1505 = np.array(S2meanrefA1_15)
S2meanD2_105 = np.array(S2meanD2_1)

S2rgbrefA1_1505 = list()
S2rgbD2_105 = list()
for i in range(3):
    S2rgbrefA1_1505.append(S2meanrefA1_1505[:,i].mean())
    S2rgbD2_105.append(S2meanD2_105[:,i].mean())

# %%
S2meanrefA1_1605 = list()
S2meanD3_105 = list()
for i in range(S2RGB_imgA1D3_505.shape[0]): 
     for j in range(S2RGB_imgA1D3_505.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1605.append(S2RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_105.append(S2RGB_imgA1D3_5 [i][j])  
S2meanrefA1_1605 = np.array(S2meanrefA1_1605)
S2meanD3_105 = np.array(S2meanD3_105)

S2rgbrefA1_1605 = list()
S2rgbD3_105 = list()
for i in range(3):
    S2rgbrefA1_1605.append(S2meanrefA1_1605[:,i].mean())
    S2rgbD3_105.append(S2meanD3_105[:,i].mean())

# %%
S2meanrefA1_1705= list()
S2meanD4_105 = list()
for i in range(S2RGB_imgA1D4_.shape[0]): 
     for j in range(S2RGB_imgA1D4_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1705.append(S2RGB_imgA1D4_1i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_105.append(S2RGB_imgA1D4_[i][j])  
S2meanrefA1_1705 = np.array(S2meanrefA1_1405)
S2meanD4_105 = np.array(S2meanD4_105)

S2rgbrefA1_1705 = list()
S2rgbD4_105 = list()
for i in range(3):
    S2rgbrefA1_1705.append(S2meanrefA1_1705[:,i].mean())
    S2rgbD4_105.append(S2meanD4_105[:,i].mean())

# %% [markdown]
# ###Img 6

# %%
S2meanrefA1_106 = list()
S2meanA1_206 = list()
for i in range(S2RGB_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1RGB_imgA1A1_6.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_106.append(S2RGB_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_206.append(S2RGB_imgA1A1_6[i][j])  
S2meanrefA1_106 = np.array(S2meanrefA1_106)
S2meanA1_206 = np.array(S2meanA1_206)

S2rgbrefA1_106 = list()
S2rgbA1_206 = list()
for i in range(3):
    S2rgbrefA1_106.append(S2meanrefA1_106[:,i].mean())
    S2rgbA1_206.append(S2meanA1_206[:,i].mean())
S2rgbrefA1_106,S2rgbA1_206

# %%
S2meanrefA1_306 = list()
S2meanA2_106 = list()
for i in range(S2RGB_imgA1A2_6.shape[0]): 
     for j in range(S2RGB_imgA1A2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_306.append(S1RGB_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_106.append(S1RGB_imgA1A2_6[i][j])  
S2meanrefA1_306 = np.array(S2meanrefA1_306)
S2meanA2_106 = np.array(S2meanA2_106)

S2rgbrefA1_306 = list()
S2rgbA2_106 = list()
for i in range(3):
    S2rgbrefA1_306.append(S2meanrefA1_306[:,i].mean())
    S2rgbA2_106.append(S2meanA2_106[:,i].mean())

# %%
S2meanrefA1_406 = list()
S2meanA3_106 = list()
for i in range(S2RGB_imgA1A3_6.shape[0]): 
     for j in range(S2RGB_imgA1A3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_406.append(S2RGB_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_106.append(S2RGB_imgA1A3_6[i][j])  
S2meanrefA1_406 = np.array(S2meanrefA1_406)
S2meanA3_106 = np.array(S2meanA3_106)

S2rgbrefA1_406 = list()
S2rgbA3_106 = list()
for i in range(3):
    S2rgbrefA1_406.append(S2meanrefA1_406[:,i].mean())
    S2rgbA3_106.append(S2meanA3_106[:,i].mean())

# %%
S2meanrefA1_506 = list()
S2meanA3_5106 = list()
for i in range(S2RGB_imgA1A3_56.shape[0]): 
     for j in range(S2RGB_imgA1A3_56.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_506.append(S2RGB_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5106.append(S2RGB_imgA1A3_56[i][j])  
S2meanrefA1_506 = np.array(S2meanrefA1_506)
S2meanA3_5106 = np.array(S2meanA3_5106)

S2rgbrefA1_506 = list()
S2rgbA3_5106 = list()
for i in range(3):
    S2rgbrefA1_506.append(S2meanrefA1_506[:,i].mean())
    S2rgbA3_5106.append(S2meanA3_5106[:,i].mean())

# %%
S2meanrefA1_606 = list()
S2meanA4_106 = list()
for i in range(S2RGB_imgA1A4_6.shape[0]): 
     for j in range(S2RGB_imgA1A4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_606.append(S2RGB_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_106.append(S2RGB_imgA1A4_6[i][j])  
S2meanrefA1_606 = np.array(S2meanrefA1_606)
S2meanA4_106 = np.array(S2meanA4_106)

S2rgbrefA1_606 = list()
S2rgbA4_106 = list()
for i in range(3):
    S2rgbrefA1_606.append(S2meanrefA1_606[:,i].mean())
    S2rgbA4_106.append(S2meanA4_106[:,i].mean())

# %%
S2meanrefA1_706 = list()
S2meanB1_106 = list()
for i in range(S2RGB_imgA1B1_6.shape[0]): 
     for j in range(S2RGB_imgA1B1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_706.append(S2RGB_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_106.append(S2RGB_imgA1B1_6[i][j])  
S2meanrefA1_706 = np.array(S2meanrefA1_706)
S2meanB1_106 = np.array(S2meanB1_106)

S2rgbrefA1_706 = list()
S2rgbB1_106 = list()
for i in range(3):
    S2rgbrefA1_706.append(S2meanrefA1_706[:,i].mean())
    S2rgbB1_106.append(S2meanB1_106[:,i].mean())

# %%
S2meanrefA1_806 = list()
S2meanB2_106 = list()
for i in range(S2RGB_imgA1B2_6.shape[0]): 
     for j in range(S2RGB_imgA1B2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_806.append(S2RGB_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_106.append(S2RGB_imgA1B2_6[i][j])  
S2meanrefA1_806 = np.array(S2meanrefA1_806)
S2meanB2_106 = np.array(S2meanB2_106)

S2rgbrefA1_806 = list()
S2rgbB2_106 = list()
for i in range(3):
    S2rgbrefA1_806.append(S2meanrefA1_806[:,i].mean())
    S2rgbB2_106.append(S2meanB2_106[:,i].mean())

# %%
S2meanrefA1_906 = list()
S2meanB3_106 = list()
for i in range(S2RGB_imgA1B3_6.shape[0]): 
     for j in range(S2RGB_imgA1B3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_906.append(S2RGB_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_106.append(S2RGB_imgA1B3_6[i][j])  
S2meanrefA1_906 = np.array(S2meanrefA1_906)
S2meanB3_106 = np.array(S2meanB3_106)

S2rgbrefA1_906 = list()
S2rgbB3_106 = list()
for i in range(3):
    S2rgbrefA1_906.append(S2meanrefA1_906[:,i].mean())
    S2rgbB3_106.append(S2meanB3_106[:,i].mean())

# %%
S2meanrefA1_1006 = list()
S2meanB4_106 = list()
for i in range(S2RGB_imgA1B4_6.shape[0]): 
     for j in range(S2RGB_imgA1B4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1006.append(S2RGB_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_106.append(S2RGB_imgA1B4_6[i][j])  
S2meanrefA1_1006 = np.array(S2meanrefA1_1006)
S2meanB4_106 = np.array(S2meanB4_106)

S2rgbrefA1_1006 = list()
S2rgbB4_106 = list()
for i in range(3):
    S2rgbrefA1_1006.append(S2meanrefA1_1006[:,i].mean())
    S2rgbB4_106.append(S2meanB4_106[:,i].mean())

# %%
S2meanrefA1_1106 = list()
S2meanC1_106 = list()
for i in range(S2RGB_imgA1C1_6.shape[0]): 
     for j in range(S1RGB_imgA1C1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1106.append(S2RGB_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_106.append(S2RGB_imgA1C1_6[i][j])  
S2meanrefA1_1106 = np.array(S2meanrefA1_1106)
S2meanC1_106 = np.array(S2meanC1_106)

S2rgbrefA1_1106 = list()
S2rgbC1_106 = list()
for i in range(3):
    S2rgbrefA1_1106.append(S2meanrefA1_1106[:,i].mean())
    S2rgbC1_106.append(S2meanC1_106[:,i].mean())

# %%
S2meanrefA1_1206 = list()
S2meanC2_106 = list()
for i in range(S2RGB_imgA1C2_6.shape[0]): 
     for j in range(S2RGB_imgA1C2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1206.append(S2RGB_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_106.append(S2RGB_imgA1C2_6[i][j])  
S2meanrefA1_1206 = np.array(S2meanrefA1_1206)
S2meanC2_106 = np.array(S2meanC2_106)

S2rgbrefA1_1206 = list()
S2rgbC2_106 = list()
for i in range(3):
    S2rgbrefA1_1206.append(S2meanrefA1_1206[:,i].mean())
    S2rgbC2_106.append(S2meanC2_106[:,i].mean())

# %%
S2meanrefA1_1306 = list()
S2meanC3_106 = list()
for i in range(S2RGB_imgA1C3_6.shape[0]): 
     for j in range(S2RGB_imgA1C3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1306.append(S1RGB_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_106.append(S2RGB_imgA1C3_6[i][j])  
S2meanrefA1_1306 = np.array(S2meanrefA1_1306)
S2meanC3_106 = np.array(S2meanC3_106)

S2rgbrefA1_1306 = list()
S2rgbC3_106 = list()
for i in range(3):
    S2rgbrefA1_1306.append(S2meanrefA1_1306[:,i].mean())
    S2rgbC3_106.append(S2meanC3_106[:,i].mean())

# %%
S2meanrefA1_1406 = list()
S2meanC4_106 = list()
for i in range(S2RGB_imgA1C4_6.shape[0]): 
     for j in range(S2RGB_imgA1C4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1406.append(S2RGB_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_106.append(S2RGB_imgA1C4_6[i][j])  
S2meanrefA1_1406 = np.array(S2meanrefA1_1406)
S2meanC4_106 = np.array(S2meanC4_106)

S2rgbrefA1_1406 = list()
S2rgbC4_106 = list()
for i in range(3):
    S2rgbrefA1_1406.append(S1meanrefA1_1406[:,i].mean())
    S2rgbC4_106.append(S1meanC4_106[:,i].mean())

# %%
S2meanrefA1_1506 = list()
S2meanD2_106 = list()
for i in range(S1RGB_imgA1D2_6.shape[0]): 
     for j in range(S1RGB_imgA1D2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1506.append(S2RGB_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_106.append(S2RGB_imgA1D2_6[i][j])  
S2meanrefA1_1506 = np.array(S1meanrefA1_1506)
S2meanD2_106 = np.array(S1meanD2_106)

S2rgbrefA1_1506 = list()
S2rgbD2_1 = list()
for i in range(3):
    S2rgbrefA1_15.append(S2meanrefA1_15[:,i].mean())
    S2rgbD2_1.append(S2meanD2_1[:,i].mean())

# %%
S2meanrefA1_16 = list()
S2meanD3_1 = list()
for i in range(S2RGB_imgA1D3_6.shape[0]): 
     for j in range(S2RGB_imgA1D3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_16.append(S2RGB_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_1.append(S2RGB_imgA1D3_6[i][j])  
S2meanrefA1_16 = np.array(S2meanrefA1_1606)
S2meanD3_106 = np.array(S2meanD3_106)

S2rgbrefA1_1606 = list()
S2rgbD3_106 = list()
for i in range(3):
    S2rgbrefA1_1606.append(S2meanrefA1_1606[:,i].mean())
    S2rgbD3_106.append(S2meanD3_106[:,i].mean())

# %%
S2meanrefA1_1706= list()
S2meanD4_106 = list()
for i in range(S2RGB_imgA1D4_6.shape[0]): 
     for j in range(S2RGB_imgA1D4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1706.append(S2RGB_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_106.append(S2RGB_imgA1D4_6[i][j])  
S2meanrefA1_1706 = np.array(S2meanrefA1_1406)
S2meanD4_106 = np.array(S2meanD4_106)

S2rgbrefA1_1706 = list()
S2rgbD4_106 = list()
for i in range(3):
    S2rgbrefA1_1706.append(S2meanrefA1_1706[:,i].mean())
    S2rgbD4_106.append(S2meanD4_106[:,i].mean())

# %% [markdown]
# ###Img 7

# %%
S2meanrefA1_107 = list()
S2meanA1_207 = list()
for i in range(S2RGB_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_107.append(S2RGB_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_207.append(S2RGB_imgA1A1_7[i][j])  
S2meanrefA1_107 = np.array(S2meanrefA1_107)
S2meanA1_207 = np.array(S2meanA1_207)

S2rgbrefA1_107 = list()
S2rgbA1_207 = list()
for i in range(3):
    S2rgbrefA1_107.append(S2meanrefA1_107[:,i].mean())
    S2rgbA1_207.append(S2meanA1_207[:,i].mean())
S2rgbrefA1_107,S2rgbA1_207

# %%
S2meanrefA1_307 = list()
S2meanA2_107 = list()
for i in range(S2RGB_imgA1A2_7.shape[0]): 
     for j in range(S2RGB_imgA1A2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_307.append(S2RGB_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_107.append(S2RGB_imgA1A2_7[i][j])  
S2meanrefA1_307 = np.array(S2meanrefA1_307)
S2meanA2_107 = np.array(S2meanA2_107)

S2rgbrefA1_307 = list()
S2rgbA2_107 = list()
for i in range(3):
    S2rgbrefA1_307.append(S2meanrefA1_307[:,i].mean())
    S2rgbA2_107.append(S2meanA2_107[:,i].mean())

# %%
S2meanrefA1_407 = list()
S2meanA3_107 = list()
for i in range(S2RGB_imgA1A3_7.shape[0]): 
     for j in range(S2RGB_imgA1A3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_407.append(S2RGB_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_107.append(S2RGB_imgA1A3_7[i][j])  
S2meanrefA1_407 = np.array(S2meanrefA1_407)
S2meanA3_107 = np.array(S2meanA3_107)

S2rgbrefA1_407 = list()
S2rgbA3_107 = list()
for i in range(3):
    S2rgbrefA1_407.append(S2meanrefA1_407[:,i].mean())
    S2rgbA3_107.append(S2meanA3_107[:,i].mean())

# %%
S2meanrefA1_507 = list()
S2meanA3_5107 = list()
for i in range(S2RGB_imgA1A3_57.shape[0]): 
     for j in range(S2RGB_imgA1A3_57.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_507.append(S2RGB_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5107.append(S2RGB_imgA1A3_57[i][j])  
S2meanrefA1_507 = np.array(S2meanrefA1_507)
S2meanA3_5107 = np.array(S2meanA3_5107)

S2rgbrefA1_507 = list()
S2rgbA3_5107 = list()
for i in range(3):
    S2rgbrefA1_507.append(S2meanrefA1_507[:,i].mean())
    S2rgbA3_5107.append(S2meanA3_5107[:,i].mean())

# %%
S2meanrefA1_607 = list()
S2meanA4_107 = list()
for i in range(S2RGB_imgA1A4_7.shape[0]): 
     for j in range(S2RGB_imgA1A4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_607.append(S1RGB_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_107.append(S2RGB_imgA1A4_7[i][j])  
S2meanrefA1_607 = np.array(S2meanrefA1_607)
S2meanA4_107 = np.array(S2meanA4_107)

S2rgbrefA1_607 = list()
S2rgbA4_107 = list()
for i in range(3):
    S2rgbrefA1_607.append(S2meanrefA1_607[:,i].mean())
    S2rgbA4_107.append(S2meanA4_107[:,i].mean())

# %%
S2meanrefA1_707 = list()
S2meanB1_107 = list()
for i in range(S2RGB_imgA1B1_7.shape[0]): 
     for j in range(S2RGB_imgA1B1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_707.append(S2RGB_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_107.append(S2RGB_imgA1B1_7[i][j])  
S2meanrefA1_707 = np.array(S2meanrefA1_707)
S2meanB1_107 = np.array(S2meanB1_107)

S2rgbrefA1_707 = list()
S2rgbB1_107 = list()
for i in range(3):
    S2rgbrefA1_707.append(S2meanrefA1_707[:,i].mean())
    S2rgbB1_107.append(S2meanB1_107[:,i].mean())

# %%
S2meanrefA1_807 = list()
S2meanB2_107 = list()
for i in range(S2RGB_imgA1B2_7.shape[0]): 
     for j in range(S2RGB_imgA1B2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_807.append(S2RGB_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_107.append(S2RGB_imgA1B2_7[i][j])  
S2meanrefA1_807 = np.array(S2meanrefA1_807)
S2meanB2_107 = np.array(S2meanB2_107)

S2rgbrefA1_807 = list()
S2rgbB2_107 = list()
for i in range(3):
    S2rgbrefA1_807.append(S2meanrefA1_807[:,i].mean())
    S2rgbB2_107.append(S2meanB2_107[:,i].mean())

# %%
S2meanrefA1_907 = list()
S2meanB3_107 = list()
for i in range(S2RGB_imgA1B3_7.shape[0]): 
     for j in range(S2RGB_imgA1B3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_907.append(S2RGB_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_107.append(S2RGB_imgA1B3_7[i][j])  
S2meanrefA1_907 = np.array(S2meanrefA1_907)
S2meanB3_107 = np.array(S2meanB3_107)

S2rgbrefA1_907 = list()
S2rgbB3_107 = list()
for i in range(3):
    S2rgbrefA1_907.append(S2meanrefA1_907[:,i].mean())
    S2rgbB3_107.append(S2meanB3_107[:,i].mean())

# %%
S2meanrefA1_1007 = list()
S2meanB4_107 = list()
for i in range(S2RGB_imgA1B4_7.shape[0]): 
     for j in range(S2RGB_imgA1B4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1007.append(S2RGB_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_107.append(S2RGB_imgA1B4_7[i][j])  
S2meanrefA1_1007 = np.array(S2meanrefA1_1007)
S2meanB4_107 = np.array(S2meanB4_107)

S2rgbrefA1_1007 = list()
S2rgbB4_107 = list()
for i in range(3):
    S2rgbrefA1_1007.append(S2meanrefA1_1007[:,i].mean())
    S2rgbB4_107.append(S2meanB4_107[:,i].mean())

# %%
S2meanrefA1_1107 = list()
S2meanC1_107 = list()
for i in range(S2RGB_imgA1C1_7.shape[0]): 
     for j in range(S2RGB_imgA1C1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1107.append(S2RGB_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_107.append(S2RGB_imgA1C1_7[i][j])  
S2meanrefA1_1107 = np.array(S2meanrefA1_1107)
S2meanC1_107 = np.array(S2meanC1_107)

S2rgbrefA1_1107 = list()
S2rgbC1_107 = list()
for i in range(3):
    S2rgbrefA1_1107.append(S2meanrefA1_1107[:,i].mean())
    S2rgbC1_107.append(S2meanC1_107[:,i].mean())

# %%
S2meanrefA1_1207 = list()
S2meanC2_107 = list()
for i in range(S2RGB_imgA1C2_7.shape[0]): 
     for j in range(S2RGB_imgA1C2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1207.append(S2RGB_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_107.append(S2RGB_imgA1C2_7[i][j])  
S2meanrefA1_1207 = np.array(S2meanrefA1_1207)
S2meanC2_107 = np.array(S2meanC2_107)

S2rgbrefA1_1207 = list()
S2rgbC2_107 = list()
for i in range(3):
    S2rgbrefA1_1207.append(S2meanrefA1_1207[:,i].mean())
    S2rgbC2_107.append(S2meanC2_107[:,i].mean())

# %%
S2meanrefA1_1307 = list()
S2meanC3_107 = list()
for i in range(S2RGB_imgA1C3_7.shape[0]): 
     for j in range(S2RGB_imgA1C3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1307.append(S2RGB_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_107.append(S2RGB_imgA1C3_7[i][j])  
S2meanrefA1_1307 = np.array(S2meanrefA1_1307)
S2meanC3_107 = np.array(S2meanC3_107)

S2rgbrefA1_1307 = list()
S2rgbC3_107 = list()
for i in range(3):
    S2rgbrefA1_1307.append(S2meanrefA1_1307[:,i].mean())
    S2rgbC3_107.append(S2meanC3_107[:,i].mean())

# %%
S2meanrefA1_1407 = list()
S2meanC4_107 = list()
for i in range(S2RGB_imgA1C4_7.shape[0]): 
     for j in range(S2RGB_imgA1C4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  SmeanrefA1_1407.append(S2RGB_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_107.append(S2RGB_imgA1C4_7[i][j])  
S2meanrefA1_1407 = np.array(S2meanrefA1_1407)
S2meanC4_107 = np.array(S2meanC4_107)

S2rgbrefA1_1407 = list()
S2rgbC4_107 = list()
for i in range(3):
    S2rgbrefA1_1407.append(S2meanrefA1_1407[:,i].mean())
    S2rgbC4_107.append(S2meanC4_107[:,i].mean())

# %%
S2meanrefA1_1507 = list()
S2meanD2_107 = list()
for i in range(S2RGB_imgA1D2_7.shape[0]): 
     for j in range(S2RGB_imgA1D2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1507.append(S2RGB_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_107.append(S2RGB_imgA1D2_7[i][j])  
S2meanrefA1_1507 = np.array(S2meanrefA1_1507)
S2meanD2_107 = np.array(S2meanD2_107)

S2rgbrefA1_1507 = list()
S2rgbD2_107 = list()
for i in range(3):
    S2rgbrefA1_1507.append(S2meanrefA1_1507[:,i].mean())
    S2rgbD2_107.append(S2meanD2_107[:,i].mean())

# %%
S2meanrefA1_1607 = list()
S2meanD3_107 = list()
for i in range(S2RGB_imgA1D3_7.shape[0]): 
     for j in range(S2RGB_imgA1D3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1607.append(S2RGB_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_107.append(S2RGB_imgA1D3_7[i][j])  
S2meanrefA1_1607 = np.array(S2meanrefA1_1607)
S2meanD3_107 = np.array(S2meanD3_107)

S2rgbrefA1_1607 = list()
S2rgbD3_107 = list()
for i in range(3):
    S2rgbrefA1_1607.append(S2meanrefA1_1607[:,i].mean())
    S2rgbD3_107.append(S2meanD3_107[:,i].mean())

# %%
S2meanrefA1_1707= list()
S2meanD4_107 = list()
for i in range(S2RGB_imgA1D4_7.shape[0]): 
     for j in range(S2RGB_imgA1D4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1707.append(S2RGB_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_107.append(S2RGB_imgA1D4_7[i][j])  
S2meanrefA1_1707 = np.array(S2meanrefA1_1407)
S2meanD4_107 = np.array(S2meanD4_107)

S2rgbrefA1_1707 = list()
S2rgbD4_107 = list()
for i in range(3):
    S2rgbrefA1_1707.append(S2meanrefA1_1707[:,i].mean())
    S2rgbD4_107.append(S2meanD4_107[:,i].mean())

# %% [markdown]
# ###Img 8

# %%
S2meanrefA1_108 = list()
S2meanA1_208 = list()
for i in range(S2RGB_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_108.append(S2RGB_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_208.append(S2RGB_imgA1A1_8[i][j])  
S2meanrefA1_108 = np.array(S2meanrefA1_108)
S2meanA1_208 = np.array(S2meanA1_208)

S2rgbrefA1_108 = list()
S2rgbA1_208 = list()
for i in range(3):
    S2rgbrefA1_108.append(S2meanrefA1_108[:,i].mean())
    S2rgbA1_208.append(S2meanA1_208[:,i].mean())
S2rgbrefA1_108,S1rgbA1_208

# %%
S2meanrefA1_308 = list()
S2meanA2_108 = list()
for i in range(S2RGB_imgA1A2_8.shape[0]): 
     for j in range(S2RGB_imgA1A2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_308.append(S2RGB_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_108.append(S2RGB_imgA1A2_8[i][j])  
S2meanrefA1_308 = np.array(S2meanrefA1_308)
S2meanA2_108 = np.array(S2meanA2_108)

S2rgbrefA1_308 = list()
S2rgbA2_108 = list()
for i in range(3):
    S2rgbrefA1_308.append(S2meanrefA1_308[:,i].mean())
    S2rgbA2_108.append(S2meanA2_108[:,i].mean())

# %%
S2meanrefA1_408 = list()
S2meanA3_108 = list()
for i in range(S2RGB_imgA1A3_8.shape[0]): 
     for j in range(S2RGB_imgA1A3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_408.append(S2RGB_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_108.append(S2RGB_imgA1A3_8[i][j])  
S2meanrefA1_408 = np.array(S2meanrefA1_408)
S2meanA3_108 = np.array(S2meanA3_108)

S2rgbrefA1_408 = list()
S2rgbA3_108 = list()
for i in range(3):
    S2rgbrefA1_408.append(S2meanrefA1_408[:,i].mean())
    S2rgbA3_108.append(S2meanA3_108[:,i].mean())

# %%
S2meanrefA1_508 = list()
S2meanA3_5108 = list()
for i in range(S2RGB_imgA1A3_58.shape[0]): 
     for j in range(S2RGB_imgA1A3_58.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_508.append(S2RGB_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5108.append(S2RGB_imgA1A3_58[i][j])  
S2meanrefA1_508 = np.array(S2meanrefA1_508)
S2meanA3_5108 = np.array(S2meanA3_5108)

S2rgbrefA1_508 = list()
S2rgbA3_5108 = list()
for i in range(3):
    S2rgbrefA1_508.append(S2meanrefA1_508[:,i].mean())
    S2rgbA3_5108.append(S2meanA3_5108[:,i].mean())

# %%
S2meanrefA1_608 = list()
S2meanA4_108 = list()
for i in range(S2RGB_imgA1A4_8.shape[0]): 
     for j in range(S2RGB_imgA1A4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_608.append(S2RGB_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_108.append(S2RGB_imgA1A4_8[i][j])  
S2meanrefA1_608 = np.array(S2meanrefA1_608)
S2meanA4_108 = np.array(S2meanA4_108)

S2rgbrefA1_608 = list()
S2rgbA4_108 = list()
for i in range(3):
    S2rgbrefA1_608.append(S2meanrefA1_608[:,i].mean())
    S2rgbA4_108.append(S2meanA4_108[:,i].mean())

# %%
S2meanrefA1_708 = list()
S2meanB1_108 = list()
for i in range(S2RGB_imgA1B1_8.shape[0]): 
     for j in range(S2RGB_imgA1B1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_708.append(S2RGB_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_108.append(S2RGB_imgA1B1_8[i][j])  
S2meanrefA1_708 = np.array(S2meanrefA1_708)
S2meanB1_108 = np.array(S2meanB1_108)

S2rgbrefA1_708 = list()
S2rgbB1_108 = list()
for i in range(3):
    S2rgbrefA1_708.append(S2meanrefA1_708[:,i].mean())
    S2rgbB1_108.append(S2meanB1_108[:,i].mean())

# %%
S2meanrefA1_808 = list()
S2meanB2_108 = list()
for i in range(S2RGB_imgA1B2_8.shape[0]): 
     for j in range(S2RGB_imgA1B2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_808.append(S2RGB_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_108.append(S2RGB_imgA1B2_8[i][j])  
S2meanrefA1_808 = np.array(S2meanrefA1_808)
S2meanB2_108 = np.array(S2meanB2_108)

S2rgbrefA1_808 = list()
S2rgbB2_108 = list()
for i in range(3):
    S2rgbrefA1_808.append(S2meanrefA1_808[:,i].mean())
    S2rgbB2_108.append(S2meanB2_108[:,i].mean())

# %%
S2meanrefA1_908 = list()
S2meanB3_108 = list()
for i in range(S2RGB_imgA1B3_8.shape[0]): 
     for j in range(S2RGB_imgA1B3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_908.append(S2RGB_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_108.append(S2RGB_imgA1B3_8[i][j])  
S2meanrefA1_908 = np.array(S2meanrefA1_908)
S2meanB3_108 = np.array(S2meanB3_108)

S2rgbrefA1_908 = list()
S2rgbB3_108 = list()
for i in range(3):
    S2rgbrefA1_908.append(S2meanrefA1_908[:,i].mean())
    S2rgbB3_108.append(S2meanB3_108[:,i].mean())

# %%
S2meanrefA1_1008 = list()
S2meanB4_108 = list()
for i in range(S2RGB_imgA1B4_8.shape[0]): 
     for j in range(S2RGB_imgA1B4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1008.append(S2RGB_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_108.append(S2RGB_imgA1B4_8[i][j])  
S2meanrefA1_1008 = np.array(S2meanrefA1_1008)
S2meanB4_108 = np.array(S2meanB4_108)

S2rgbrefA1_1008 = list()
S2rgbB4_108 = list()
for i in range(3):
    S2rgbrefA1_1008.append(S2meanrefA1_1008[:,i].mean())
    S2rgbB4_108.append(S2meanB4_108[:,i].mean())

# %%
S2meanrefA1_1108 = list()
S2meanC1_108 = list()
for i in range(S2RGB_imgA1C1_8.shape[0]): 
     for j in range(S2RGB_imgA1C1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1108.append(S2RGB_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_108.append(S2RGB_imgA1C1_8[i][j])  
S2meanrefA1_1108 = np.array(S2meanrefA1_1108)
S2meanC1_108 = np.array(S2meanC1_108)

S2rgbrefA1_1108 = list()
S2rgbC1_108 = list()
for i in range(3):
    S2rgbrefA1_1108.append(S2meanrefA1_1108[:,i].mean())
    S2rgbC1_108.append(S2meanC1_108[:,i].mean())

# %%
S2meanrefA1_1208 = list()
S2meanC2_108 = list()
for i in range(S2RGB_imgA1C2_8.shape[0]): 
     for j in range(S2RGB_imgA1C2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1208.append(S2RGB_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_108.append(S2RGB_imgA1C2_8[i][j])  
S2meanrefA1_1208 = np.array(S2meanrefA1_1208)
S2meanC2_108 = np.array(S2meanC2_108)

S2rgbrefA1_1208 = list()
S2rgbC2_108 = list()
for i in range(3):
    S2rgbrefA1_1208.append(S2meanrefA1_1208[:,i].mean())
    S2rgbC2_108.append(S2meanC2_108[:,i].mean())

# %%
S2meanrefA1_1308 = list()
S2meanC3_108 = list()
for i in range(S2RGB_imgA1C3_8.shape[0]): 
     for j in range(S2RGB_imgA1C3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1308.append(S2RGB_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_108.append(S2RGB_imgA1C3_8[i][j])  
S2meanrefA1_1308 = np.array(S2meanrefA1_1308)
S2meanC3_108 = np.array(S2meanC3_108)

S2rgbrefA1_1308 = list()
S2rgbC3_108 = list()
for i in range(3):
    S2rgbrefA1_1308.append(S2meanrefA1_1308[:,i].mean())
    S2rgbC3_108.append(S2meanC3_108[:,i].mean())

# %%
S2meanrefA1_1408 = list()
S2meanC4_108 = list()
for i in range(S2RGB_imgA1C4_8.shape[0]): 
     for j in range(S2RGB_imgA1C4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1408.append(S2RGB_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_108.append(S2RGB_imgA1C4_8[i][j])  
S2meanrefA1_1408 = np.array(S2meanrefA1_1408)
S2meanC4_108 = np.array(S2meanC4_108)

S2rgbrefA1_1408 = list()
S2rgbC4_108 = list()
for i in range(3):
    S2rgbrefA1_1408.append(S2meanrefA1_1408[:,i].mean())
    S2rgbC4_108.append(S2meanC4_108[:,i].mean())

# %%
S2meanrefA1_1508 = list()
S2meanD2_108 = list()
for i in range(S2RGB_imgA1D2_8.shape[0]): 
     for j in range(S2RGB_imgA1D2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1508.append(S2RGB_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_108.append(S2RGB_imgA1D2_8[i][j])  
S2meanrefA1_1508 = np.array(S2meanrefA1_1508)
S2meanD2_108 = np.array(S2meanD2_108)

S2rgbrefA1_1508 = list()
S2rgbD2_108 = list()
for i in range(3):
    S2rgbrefA1_1508.append(S2meanrefA1_1508[:,i].mean())
    S2rgbD2_108.append(S2meanD2_108[:,i].mean())

# %%
S2meanrefA1_1608 = list()
S2meanD3_108 = list()
for i in range(S2RGB_imgA1D3_8.shape[0]): 
     for j in range(S2RGB_imgA1D3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1608.append(S2RGB_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_108.append(S2RGB_imgA1D3_8[i][j])  
S2meanrefA1_1608 = np.array(S2meanrefA1_1608)
S2meanD3_108 = np.array(S2meanD3_108)

S2rgbrefA1_1608 = list()
S2rgbD3_108 = list()
for i in range(3):
    S2rgbrefA1_1608.append(S2meanrefA1_1608[:,i].mean())
    S2rgbD3_108.append(S2meanD3_108[:,i].mean())

# %%
S2meanrefA1_1708= list()
S2meanD4_108 = list()
for i in range(S2RGB_imgA1D4_8.shape[0]): 
     for j in range(S2RGB_imgA1D4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1708.append(S2RGB_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_108.append(S2RGB_imgA1D4_8[i][j])  
S2meanrefA1_1708 = np.array(S2meanrefA1_1408)
S2meanD4_108 = np.array(S2meanD4_108)

S2rgbrefA1_1708 = list()
S2rgbD4_108 = list()
for i in range(3):
    S2rgbrefA1_1708.append(S2meanrefA1_1708[:,i].mean())
    S2rgbD4_108.append(S2meanD4_108[:,i].mean())

# %% [markdown]
# ###Img 9

# %%
S2meanrefA2_109 = list()
S1meanA2_209 = list()
for i in range(S2RGB_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_109.append(S2RGB_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_209.append(S2RGB_imgA1A1_9[i][j])  
S2meanrefA1_109 = np.array(S2meanrefA1_109)
S2meanA1_209 = np.array(S2meanA1_209)

S2rgbrefA1_109 = list()
S2rgbA1_209 = list()
for i in range(3):
    S2gbrefA1_109.append(S2meanrefA1_109[:,i].mean())
    S2rgbA1_209.append(S2meanA1_209[:,i].mean())
S2rgbrefA1_109,S2rgbA1_209

# %%
S2meanrefA1_309 = list()
S2meanA2_109 = list()
for i in range(S2RGB_imgA1A2_9.shape[0]): 
     for j in range(S2RGB_imgA1A2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_309.append(S2RGB_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_109.append(S2RGB_imgA1A2_9[i][j])  
S2meanrefA1_309 = np.array(S2meanrefA1_309)
S2meanA2_109 = np.array(S2meanA2_109)

S2rgbrefA1_309 = list()
S2rgbA2_109 = list()
for i in range(3):
    S2rgbrefA1_309.append(S2meanrefA1_309[:,i].mean())
    S2rgbA2_109.append(S2meanA2_109[:,i].mean())

# %%
S2meanrefA1_409 = list()
S2meanA3_109 = list()
for i in range(S2RGB_imgA1A3_9.shape[0]): 
     for j in range(S2RGB_imgA1A3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S1meanrefA1_409.append(S2RGB_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_109.append(S2RGB_imgA1A3_9[i][j])  
S2meanrefA1_409 = np.array(S2meanrefA1_409)
S2meanA3_109 = np.array(S2meanA3_109)

S2rgbrefA1_409 = list()
S2rgbA3_109 = list()
for i in range(3):
    S2rgbrefA1_409.append(S2meanrefA1_409[:,i].mean())
    S2rgbA3_109.append(S2meanA3_109[:,i].mean())

# %%
S2meanrefA1_509 = list()
S2meanA3_5109 = list()
for i in range(S2RGB_imgA1A3_59.shape[0]): 
     for j in range(S2RGB_imgA1A3_59.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_509.append(S2RGB_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5109.append(S2RGB_imgA1A3_59[i][j])  
S2meanrefA1_509 = np.array(S2meanrefA1_509)
S2meanA3_5109 = np.array(S2meanA3_5109)

S2rgbrefA1_509 = list()
S2rgbA3_5109 = list()
for i in range(3):
    S2rgbrefA1_509.append(S2meanrefA1_509[:,i].mean())
    S2rgbA3_5109.append(S2meanA3_5109[:,i].mean())

# %%
S2meanrefA1_609 = list()
S2meanA4_109 = list()
for i in range(S2RGB_imgA1A4_9.shape[0]): 
     for j in range(S2RGB_imgA1A4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_609.append(S2RGB_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_109.append(S2RGB_imgA1A4_9[i][j])  
S2meanrefA1_609 = np.array(S2meanrefA1_609)
S1meanA4_109 = np.array(S1meanA4_109)

S2rgbrefA1_609 = list()
S2rgbA4_109 = list()
for i in range(3):
    S2rgbrefA1_609.append(S2meanrefA1_609[:,i].mean())
    S2rgbA4_109.append(S2meanA4_109[:,i].mean())

# %%
S2meanrefA1_709 = list()
S2meanB1_109 = list()
for i in range(S2RGB_imgA1B1_9.shape[0]): 
     for j in range(S2RGB_imgA1B1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_709.append(S2RGB_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_109.append(S2RGB_imgA1B1_9[i][j])  
S2meanrefA1_709 = np.array(S2meanrefA1_709)
S2meanB1_109 = np.array(S2meanB1_109)

SrgbrefA1_709 = list()
S2rgbB1_109 = list()
for i in range(3):
    S2rgbrefA1_709.append(S2meanrefA1_709[:,i].mean())
    S2rgbB1_109.append(S2meanB1_109[:,i].mean())

# %%
S2meanrefA1_809 = list()
S2meanB2_109 = list()
for i in range(S2RGB_imgA2B2_9.shape[0]): 
     for j in range(S2RGB_imgA2B2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_809.append(S12RGB_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_109.append(S2RGB_imgA1B2_9[i][j])  
S2meanrefA1_809 = np.array(S2meanrefA1_809)
S2meanB2_109 = np.array(S2meanB2_109)

S2rgbrefA1_809 = list()
S2rgbB2_109 = list()
for i in range(3):
    S2rgbrefA1_809.append(S2meanrefA1_809[:,i].mean())
    S2rgbB2_109.append(S2meanB2_109[:,i].mean())

# %%
S2meanrefA1_909 = list()
S2meanB3_109 = list()
for i in range(S2RGB_imgA1B3_9.shape[0]): 
     for j in range(S2RGB_imgA1B3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_909.append(S1RGB_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_109.append(S1RGB_imgA1B3_9[i][j])  
S2meanrefA1_909 = np.array(S2meanrefA1_909)
S2meanB3_109 = np.array(S2meanB3_109)

S2rgbrefA1_909 = list()
S2rgbB3_109 = list()
for i in range(3):
    S2rgbrefA1_909.append(S2meanrefA1_909[:,i].mean())
    S2rgbB3_109.append(S2meanB3_109[:,i].mean())

# %%
S2meanrefA1_1009 = list()
S2meanB4_109 = list()
for i in range(S2RGB_imgA1B4_9.shape[0]): 
     for j in range(S2RGB_imgA1B4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1009.append(S2RGB_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_109.append(S2RGB_imgA1B4_9[i][j])  
S2meanrefA1_1009 = np.array(S2meanrefA1_1009)
S2meanB4_109 = np.array(S2meanB4_109)

S2rgbrefA1_1009 = list()
S2rgbB4_109 = list()
for i in range(3):
    S2rgbrefA1_1009.append(S2meanrefA1_1009[:,i].mean())
    S2rgbB4_109.append(S2meanB4_109[:,i].mean())

# %%
S2meanrefA1_1109 = list()
S2meanC1_109 = list()
for i in range(S2RGB_imgA1C1_9.shape[0]): 
     for j in range(S2RGB_imgA1C1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1109.append(S2RGB_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_109.append(S2RGB_imgA1C1_9[i][j])  
S2meanrefA1_1109 = np.array(S2meanrefA1_1109)
S2meanC1_109 = np.array(S2meanC1_109)

S2rgbrefA1_1109 = list()
S2rgbC1_109 = list()
for i in range(3):
    S2rgbrefA1_1109.append(S2meanrefA1_1109[:,i].mean())
    S2rgbC1_109.append(S2meanC1_109[:,i].mean())

# %%
S2meanrefA1_1209 = list()
S2meanC2_109 = list()
for i in range(S2RGB_imgA1C2_9.shape[0]): 
     for j in range(S2RGB_imgA1C2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1209.append(S2RGB_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_109.append(S2RGB_imgA1C2_9[i][j])  
S2meanrefA1_1209 = np.array(S2meanrefA1_1209)
S2meanC2_109 = np.array(S2meanC2_109)

S2rgbrefA1_1209 = list()
S2rgbC2_109 = list()
for i in range(3):
    S2rgbrefA1_1209.append(S2meanrefA1_1209[:,i].mean())
    S2rgbC2_109.append(S2meanC2_109[:,i].mean())

# %%
S2meanrefA1_13 = list()
S2meanC3_1 = list()
for i in range(S2RGB_imgA1C3_9.shape[0]): 
     for j in range(S2RGB_imgA1C3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_13.append(S2RGB_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_1.append(S2RGB_imgA1C3_9[i][j])  
S2meanrefA1_13 = np.array(S2meanrefA1_13)
S2meanC3_1 = np.array(S2meanC3_1)

S2rgbrefA1_13 = list()
S2rgbC3_1 = list()
for i in range(3):
    S2rgbrefA1_13.append(S2meanrefA1_13[:,i].mean())
    S2rgbC3_1.append(S2meanC3_1[:,i].mean())

# %%
S2meanrefA1_1409 = list()
S2meanC4_109 = list()
for i in range(S2RGB_imgA1C4_9.shape[0]): 
     for j in range(S2RGB_imgA1C4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1409.append(S2RGB_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_109.append(S2RGB_imgA1C4_9[i][j])  
S2meanrefA1_1409 = np.array(S2meanrefA1_1409)
S2meanC4_109 = np.array(S2meanC4_109)

S2rgbrefA1_1409 = list()
S2rgbC4_109 = list()
for i in range(3):
    S2rgbrefA1_1409.append(S2meanrefA1_1409[:,i].mean())
    SrgbC4_109.append(S2meanC4_109[:,i].mean())

# %%
S2meanrefA1_1509 = list()
S2meanD2_109 = list()
for i in range(S2RGB_imgA1D2_9.shape[0]): 
     for j in range(S2RGB_imgA1D2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1509.append(S2RGB_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_109.append(S2RGB_imgA1D2_9[i][j])  
S2meanrefA1_1509 = np.array(S1meanrefA1_1509)
S2meanD2_109 = np.array(S2meanD2_109)

S2rgbrefA1_1509 = list()
S2rgbD2_109 = list()
for i in range(3):
    S2rgbrefA1_1509.append(S2meanrefA1_1509[:,i].mean())
    S2rgbD2_109.append(S2meanD2_109[:,i].mean())

# %%
S2meanrefA1_1609 = list()
S2meanD3_109 = list()
for i in range(S2RGB_imgA1D3_9.shape[0]): 
     for j in range(S2RGB_imgA1D3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1609.append(S2RGB_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_109.append(S2RGB_imgA1D3_9[i][j])  
S2meanrefA1_1609 = np.array(S2meanrefA1_1609)
S2meanD3_109 = np.array(S2meanD3_109)

S2rgbrefA1_1609 = list()
S2rgbD3_109 = list()
for i in range(3):
    S2rgbrefA1_1609.append(S2meanrefA1_1609[:,i].mean())
    S2rgbD3_109.append(S2meanD3_109[:,i].mean())

# %%
S2meanrefA1_1709= list()
S2meanD4_109 = list()
for i in range(S2RGB_imgA1D4_9.shape[0]): 
     for j in range(S2RGB_imgA1D4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1709.append(S2RGB_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_109.append(S2RGB_imgA1D4_9[i][j])  
S2meanrefA1_1709 = np.array(S2meanrefA1_1409)
S2meanD4_109 = np.array(S2meanD4_109)

S2rgbrefA1_1709 = list()
S2rgbD4_109 = list()
for i in range(3):
    S2rgbrefA1_1709.append(S2meanrefA1_1709[:,i].mean())
    S2rgbD4_109.append(S2meanD4_109[:,i].mean())

# %% [markdown]
# ###Img 10

# %%
S2meanrefA1_110 = list()
S2meanA1_210 = list()
for i in range(S2RGB_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2RGB_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_110.append(S2RGB_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_210.append(S2RGB_imgA1A1_10[i][j])  
S2meanrefA1_110 = np.array(S2meanrefA1_110)
S2meanA1_210 = np.array(S2meanA1_210)

S2rgbrefA1_110 = list()
S2rgbA1_210 = list()
for i in range(3):
    S2rgbrefA1_110.append(S2meanrefA1_110[:,i].mean())
    S2rgbA1_210.append(S2meanA1_210[:,i].mean())
S2rgbrefA1_110,S2rgbA1_210

# %%
S2meanrefA1_310 = list()
S2meanA2_110 = list()
for i in range(S2RGB_imgA1A2_10.shape[0]): 
     for j in range(S2RGB_imgA1A2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_310.append(S2RGB_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_110.append(S2RGB_imgA1A2_10[i][j])  
S2meanrefA1_310 = np.array(S2meanrefA1_310)
S2meanA2_110 = np.array(S2meanA2_110)

S2rgbrefA1_310 = list()
S2rgbA2_110 = list()
for i in range(3):
    S2rgbrefA1_310.append(S2meanrefA1_310[:,i].mean())
    S2rgbA2_110.append(S2meanA2_110[:,i].mean())

# %%
S2meanrefA1_410 = list()
S2meanA3_110 = list()
for i in range(S2RGB_imgA1A3_10.shape[0]): 
     for j in range(S2RGB_imgA1A3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_410.append(S2RGB_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_110.append(S2RGB_imgA1A3_10[i][j])  
S2meanrefA1_410 = np.array(S2meanrefA1_410)
S2meanA3_110 = np.array(S2meanA3_110)

S2rgbrefA1_410 = list()
S2rgbA3_110 = list()
for i in range(3):
    S2rgbrefA1_410.append(S2meanrefA1_410[:,i].mean())
    S2rgbA3_110.append(S2meanA3_110[:,i].mean())

# %%
S2meanrefA1_510 = list()
S2meanA3_5110 = list()
for i in range(S2RGB_imgA1A3_510.shape[0]): 
     for j in range(S2RGB_imgA1A3_510.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_510.append(S2RGB_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5110.append(S2RGB_imgA1A3_510[i][j])  
S2meanrefA1_510 = np.array(S2meanrefA1_510)
S2meanA3_5110 = np.array(S2meanA3_5110)

S2rgbrefA1_510 = list()
S2rgbA3_5110 = list()
for i in range(3):
    S2rgbrefA1_510.append(S2meanrefA1_51010[:,i].mean())
    S2rgbA3_5110.append(S2meanA3_511010[:,i].mean())

# %%
S2meanrefA1_610 = list()
S2meanA4_110 = list()
for i in range(S2RGB_imgA1A4_10.shape[0]): 
     for j in range(S2RGB_imgA1A4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_610.append(S2RGB_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_110.append(S2RGB_imgA1A4_10[i][j])  
S2meanrefA1_610 = np.array(S2meanrefA1_610)
S2meanA4_110 = np.array(S2meanA4_110)

S2rgbrefA1_610 = list()
S2rgbA4_110 = list()
for i in range(3):
    S2rgbrefA1_610.append(S2meanrefA1_610[:,i].mean())
    S2rgbA4_110.append(S2meanA4_110[:,i].mean())

# %%
S2meanrefA1_710 = list()
S2meanB1_110 = list()
for i in range(S2RGB_imgA1B1_10 .shape[0]): 
     for j in range(S2RGB_imgA1B1_10 .shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_710.append(S2RGB_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_110.append(S2RGB_imgA1B1_10 [i][j])  
S2meanrefA1_710 = np.array(S2meanrefA1_710)
S2meanB1_110 = np.array(S2meanB1_110)

S2rgbrefA1_710 = list()
S2rgbB1_110 = list()
for i in range(3):
    S2rgbrefA1_710.append(S2meanrefA1_710[:,i].mean())
    S2rgbB1_110.append(S2meanB1_110[:,i].mean())

# %%
S2meanrefA1_810 = list()
S2meanB2_110 = list()
for i in range(S2RGB_imgA1B2_10 .shape[0]): 
     for j in range(S2RGB_imgA1B2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_810.append(S2RGB_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S1meanB2_110.append(S2RGB_imgA1B2_10[i][j])  
S2meanrefA1_810 = np.array(S2meanrefA1_810)
S2meanB2_110 = np.array(S2meanB2_110)

S2rgbrefA1_810 = list()
S2rgbB2_110 = list()
for i in range(3):
    S2rgbrefA1_810.append(S2meanrefA1_810[:,i].mean())
    S2rgbB2_110.append(S2meanB2_110[:,i].mean())

# %%
S2meanrefA1_910 = list()
S2meanB3_110 = list()
for i in range(S2RGB_imgA1B3_10.shape[0]): 
     for j in range(S2RGB_imgA1B3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_910.append(S2RGB_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_110.append(S2RGB_imgA1B3_10[i][j])  
S2meanrefA1_910 = np.array(S2meanrefA1_910)
S2meanB3_110 = np.array(S2meanB3_110)

S2rgbrefA1_910 = list()
S2rgbB3_110 = list()
for i in range(3):
    S2rgbrefA1_910.append(S2meanrefA1_910[:,i].mean())
    S2rgbB3_110.append(S2meanB3_110[:,i].mean())

# %%
S2meanrefA1_1010 = list()
S2meanB4_110 = list()
for i in range(S2RGB_imgA1B4_10.shape[0]): 
     for j in range(S2RGB_imgA1B4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1010.append(S2RGB_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_110.append(S2RGB_imgA1B4_10[i][j])  
S2meanrefA1_1010 = np.array(S2meanrefA1_1010)
S2meanB4_110 = np.array(S2meanB4_110)

S2rgbrefA1_1010 = list()
S2rgbB4_110 = list()
for i in range(3):
    S2rgbrefA1_1010.append(SmeanrefA1_1010[:,i].mean())
    S2rgbB4_110.append(S2meanB4_110[:,i].mean())

# %%
S2meanrefA1_1110 = list()
S2meanC1_110 = list()
for i in range(S2RGB_imgA1C1_10.shape[0]): 
     for j in range(S2RGB_imgA1C1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1110.append(S2RGB_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_110.append(S2RGB_imgA1C1_10[i][j])  
S2meanrefA1_1110 = np.array(S2meanrefA1_1110)
S2meanC1_110 = np.array(S2meanC1_110)

S2rgbrefA1_1110 = list()
S2rgbC1_110 = list()
for i in range(3):
    S2rgbrefA1_1110.append(S2meanrefA1_1110[:,i].mean())
    S2rgbC1_110.append(S2meanC1_110[:,i].mean())

# %%
S2meanrefA1_1210 = list()
S2meanC2_110 = list()
for i in range(S2RGB_imgA1C2_10.shape[0]): 
     for j in range(S2RGB_imgA1C2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1210.append(S2RGB_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_110.append(S2RGB_imgA1C2_10[i][j])  
S2meanrefA1_1210 = np.array(S2meanrefA1_1210)
S2meanC2_110 = np.array(S2meanC2_110)

S2rgbrefA1_1210 = list()
S2rgbC2_110 = list()
for i in range(3):
    S2rgbrefA1_1210.append(S2meanrefA1_1210[:,i].mean())
    S2rgbC2_110.append(S2meanC2_110[:,i].mean())

# %%
S2meanrefA1_1310 = list()
S2meanC3_110 = list()
for i in range(S2RGB_imgA1C3_10.shape[0]): 
     for j in range(S2RGB_imgA1C3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1310.append(S2RGB_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_110.append(S2RGB_imgA1C3_10[i][j])  
S2meanrefA1_1310 = np.array(S2meanrefA1_1310)
S2meanC3_110 = np.array(S2meanC3_110)

S2rgbrefA1_1310 = list()
S2rgbC3_110 = list()
for i in range(3):
    S2rgbrefA1_1310.append(S2meanrefA1_1310[:,i].mean())
    S2rgbC3_110.append(S2meanC3_110[:,i].mean())

# %%
S2meanrefA1_1410 = list()
S2meanC4_110 = list()
for i in range(S2RGB_imgA1C4_10.shape[0]): 
     for j in range(S2RGB_imgA1C4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1410.append(S2RGB_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_110.append(S2RGB_imgA1C4_10[i][j])  
S2meanrefA1_1410 = np.array(S2meanrefA1_1410)
S2meanC4_110 = np.array(S2meanC4_110)

S2rgbrefA1_1410 = list()
S2rgbC4_110 = list()
for i in range(3):
    S2rgbrefA1_1410.append(S2meanrefA1_1410[:,i].mean())
    S2rgbC4_110.append(S2meanC4_110[:,i].mean())

# %%
S2meanrefA1_1510 = list()
S2meanD2_110 = list()
for i in range(S2RGB_imgA1D2_10.shape[0]): 
     for j in range(S2RGB_imgA1D2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1510.append(S2RGB_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_110.append(S2RGB_imgA1D2_10[i][j])  
S2meanrefA1_1510 = np.array(S2meanrefA1_1510)
S2meanD2_110 = np.array(S2meanD2_110)

S2rgbrefA1_1510 = list()
S2rgbD2_110 = list()
for i in range(3):
    S2rgbrefA1_1510.append(S2meanrefA1_1510[:,i].mean())
    S2rgbD2_110.append(S2meanD2_110[:,i].mean())

# %%
S2meanrefA1_1610 = list()
S2meanD3_110 = list()
for i in range(S2RGB_imgA1D3_10.shape[0]): 
     for j in range(S2RGB_imgA1D3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1610.append(S2RGB_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_110.append(S2RGB_imgA1D3_10[i][j])  
S2meanrefA1_1610 = np.array(S2meanrefA1_1610)
S2meanD3_110 = np.array(S2meanD3_110)

S2rgbrefA1_1610 = list()
S2rgbD3_110 = list()
for i in range(3):
    S2rgbrefA1_1610.append(S2meanrefA1_1610[:,i].mean())
    S2rgbD3_110.append(S2meanD3_110[:,i].mean())

# %%
S2meanrefA1_1710= list()
S2meanD4_110 = list()
for i in range(S2RGB_imgA1D4_10.shape[0]): 
     for j in range(S2RGB_imgA1D4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1710.append(S2RGB_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_110.append(S2RGB_imgA1D4_10[i][j])  
S2meanrefA1_1710 = np.array(S2meanrefA1_1410)
S2meanD4_110 = np.array(S2meanD4_110)

S2rgbrefA1_1710 = list()
S2rgbD4_110 = list()
for i in range(3):
    S2rgbrefA1_1710.append(S2meanrefA1_1710[:,i].mean())
    S2rgbD4_110.append(S2meanD4_110[:,i].mean())

# %% [markdown]
# ###HSV

# %%
S2meanrefA1_1 = list()
S2meanA1_2 = list()
for i in range(S2HSV_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S2HSV_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1.append(S2HSV_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_2.append(S2HSV_imgA1A1_1[i][j])  
S2meanrefA1_1 = np.array(S2meanrefA1_1)
S2meanA1_2 = np.array(S2meanA1_2)

S2hsvrefA1_1 = list()
S2hsvA1_2 = list()
for i in range(3):
    S2hsvrefA1_1.append(S2meanrefA1_1[:,i].mean())
    S2hsvA1_2.append(S2meanA1_2[:,i].mean())

# %%
S2meanrefA1_3 = list()
S2meanA2_1 = list()
for i in range(S2HSV_imgA1A2_1.shape[0]): 
     for j in range(S2HSV_imgA1A2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_3.append(S2HSV_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_1.append(S2HSV_imgA1A2_1[i][j])  
S2meanrefA1_3 = np.array(S2meanrefA1_3)
S2meanA2_1 = np.array(S2meanA2_1)

S2hsvrefA1_3 = list()
S2hsvA2_1 = list()
for i in range(3):
    S2hsvrefA1_3.append(S2meanrefA1_3[:,i].mean())
    S2hsvA2_1.append(S2meanA2_1[:,i].mean())

# %%
S2meanrefA1_4 = list()
S2meanA3_1 = list()
for i in range(S2HSV_imgA1A3_1.shape[0]): 
     for j in range(S2HSV_imgA1A3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_4.append(S2HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_1.append(S2HSV_imgA1A3_1[i][j])  
S2meanrefA1_4 = np.array(S2meanrefA1_4)
S2meanA3_1 = np.array(S2meanA3_1)

S2hsvrefA1_4 = list()
S2hsvA3_1 = list()
for i in range(3):
    S2hsvrefA1_4.append(S2meanrefA1_4[:,i].mean())
    S2hsvA3_1.append(S2meanA3_1[:,i].mean())

# %%
S2meanrefA1_5 = list()
S2meanA3_51 = list()
for i in range(S2HSV_imgA1A3_51.shape[0]): 
     for j in range(S2HSV_imgA1A3_51.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_5.append(S2HSV_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_51.append(S2HSV_imgA1A3_51[i][j])  
S2meanrefA1_5 = np.array(S2meanrefA1_5)
S2meanA3_51 = np.array(S2meanA3_51)

S2hsvrefA1_5 = list()
S2hsvA3_51 = list()
for i in range(3):
    S2hsvrefA1_5.append(S2meanrefA1_5[:,i].mean())
    S2hsvA3_51.append(S2meanA3_51[:,i].mean())

# %%
S2meanrefA1_6 = list()
S2meanA4_1 = list()
for i in range(S2HSV_imgA1A4_1.shape[0]): 
     for j in range(S2HSV_imgA1A4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_6.append(S2HSV_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_1.append(S2HSV_imgA1A4_1[i][j])  
S2meanrefA1_6 = np.array(S2meanrefA1_6)
S2meanA4_1 = np.array(S2meanA4_1)

S2hsvrefA1_6 = list()
S2hsvA4_1 = list()
for i in range(3):
    S2hsvrefA1_6.append(S2meanrefA1_6[:,i].mean())
    S2hsvA4_1.append(S2meanA4_1[:,i].mean())

# %%
S2meanrefA1_7 = list()
S2meanB1_1 = list()
for i in range(S2HSV_imgA1B1_1.shape[0]): 
     for j in range(S2HSV_imgA1B1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_7.append(S2HSV_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_1.append(S2HSV_imgA1B1_1[i][j])  
S2meanrefA1_7 = np.array(S2meanrefA1_7)
S2meanB1_1 = np.array(S2meanB1_1)

S2hsvrefA1_7 = list()
S2hsvB1_1 = list()
for i in range(3):
    S2hsvrefA1_7.append(S2meanrefA1_7[:,i].mean())
    S2hsvB1_1.append(S2meanB1_1[:,i].mean())

# %%
S2meanrefA1_8 = list()
S2meanB2_1 = list()
for i in range(S2HSV_imgA1B2_1.shape[0]): 
     for j in range(S2HSV_imgA1B2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_8.append(S2HSV_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_1.append(S2HSV_imgA1B2_1[i][j])  
S2meanrefA1_8 = np.array(S2meanrefA1_8)
S2meanB2_1 = np.array(S2meanB2_1)

S2hsvrefA1_8 = list()
S2hsvB2_1 = list()
for i in range(3):
    S2hsvrefA1_8.append(S2meanrefA1_8[:,i].mean())
    S2hsvB2_1.append(S2meanB2_1[:,i].mean())

# %%
S2meanrefA1_9 = list()
S2meanB3_1 = list()
for i in range(S2HSV_imgA1B3_1.shape[0]): 
     for j in range(S2HSV_imgA1B3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_9.append(S2HSV_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_1.append(S2HSV_imgA1B3_1[i][j])  
S2meanrefA1_9 = np.array(S2meanrefA1_9)
S2meanB3_1 = np.array(S2meanB3_1)

S2hsvrefA1_9 = list()
S2hsvB3_1 = list()
for i in range(3):
    S2hsvrefA1_9.append(S2meanrefA1_9[:,i].mean())
    S2hsvB3_1.append(S2meanB3_1[:,i].mean())

# %%
S2meanrefA1_10 = list()
S2meanB4_1 = list()
for i in range(S2HSV_imgA1B4_1.shape[0]): 
     for j in range(S2HSV_imgA1B4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_10.append(S2HSV_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_1.append(S2HSV_imgA1B4_1[i][j])  
S2meanrefA1_10 = np.array(S2meanrefA1_10)
S2meanB4_1 = np.array(S2meanB4_1)

S2hsvrefA1_10 = list()
S2hsvB4_1 = list()
for i in range(3):
    S2hsvrefA1_10.append(S2meanrefA1_10[:,i].mean())
    S2hsvB4_1.append(S2meanB4_1[:,i].mean())

# %%
S2meanrefA1_11 = list()
S2meanC1_1 = list()
for i in range(S2HSV_imgA1C1_1.shape[0]): 
     for j in range(S2HSV_imgA1C1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_11.append(S2HSV_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                   S2meanC1_1.append(S2HSV_imgA1C1_1[i][j])  
S2meanrefA1_11 = np.array(S2meanrefA1_11)
S2meanC1_1 = np.array(S2meanC1_1)

S2hsvrefA1_11 = list()
S2hsvC1_1 = list()
for i in range(3):
    S2hsvrefA1_11.append(S2meanrefA1_11[:,i].mean())
    S2hsvC1_1.append(S2meanC1_1[:,i].mean())

# %%
S2meanrefA1_12 = list()
S2meanC2_1 = list()
for i in range(S2HSV_imgA1C2_1.shape[0]): 
     for j in range(S2HSV_imgA1C2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_12.append(S2HSV_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_1.append(S2HSV_imgA1C2_1[i][j])  
S2meanrefA1_12 = np.array(S2meanrefA1_12)
S2meanC2_1 = np.array(S2meanC2_1)

S2hsvrefA1_12 = list()
S2hsvC2_1 = list()
for i in range(3):
    S2hsvrefA1_12.append(S2meanrefA1_12[:,i].mean())
    S2hsvC2_1.append(S2meanC2_1[:,i].mean())

# %%
S2meanrefA1_13 = list()
S2meanC3_1 = list()
for i in range(S2HSV_imgA1C3_1.shape[0]): 
     for j in range(S2HSV_imgA1C3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_13.append(S2HSV_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_1.append(S2HSV_imgA1C3_1[i][j])  
S2meanrefA1_13 = np.array(S2meanrefA1_13)
S2meanC3_1 = np.array(S2meanC3_1)

S2hsvrefA1_13 = list()
S2hsvC3_1 = list()
for i in range(3):
    S2hsvrefA1_13.append(S2meanrefA1_13[:,i].mean())
    S2hsvC3_1.append(S2meanC3_1[:,i].mean())

# %%
S2meanrefA1_14 = list()
S2meanC4_1 = list()
for i in range(S2HSV_imgA1C4_1.shape[0]): 
     for j in range(S2HSV_imgA1C4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_14.append(S2HSV_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_1.append(S2HSV_imgA1C4_1[i][j])  
S2meanrefA1_14 = np.array(S2meanrefA1_14)
S2meanC4_1 = np.array(S2meanC4_1)

S2hsvrefA1_14 = list()
S2hsvC4_1 = list()
for i in range(3):
    S2hsvrefA1_14.append(S2meanrefA1_14[:,i].mean())
    S2hsvC4_1.append(S2meanC4_1[:,i].mean())

# %%
S2meanrefA1_15 = list()
S2meanD2_1 = list()
for i in range(S2HSV_imgA1D2_1.shape[0]): 
     for j in range(S2HSV_imgA1D2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_15.append(S2HSV_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_1.append(S2HSV_imgA1D2_1[i][j])  
S2meanrefA1_15 = np.array(S2meanrefA1_15)
S2meanD2_1 = np.array(S2meanD2_1)

S2hsvrefA1_15 = list()
S2hsvD2_1 = list()
for i in range(3):
    S2hsvrefA1_15.append(S2meanrefA1_15[:,i].mean())
    S2hsvD2_1.append(S2meanD2_1[:,i].mean())

# %%
S2meanrefA1_16 = list()
S2meanD3_1 = list()
for i in range(S2HSV_imgA1D3_1.shape[0]): 
     for j in range(S2HSV_imgA1D3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_16.append(S2HSV_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_1.append(S2HSV_imgA1D3_1[i][j])  
S2meanrefA1_16 = np.array(S2meanrefA1_16)
S2meanD3_1 = np.array(S2meanD3_1)

S2hsvrefA1_16 = list()
S2hsvD3_1 = list()
for i in range(3):
    S2hsvrefA1_16.append(S2meanrefA1_16[:,i].mean())
    S2hsvD3_1.append(S2meanD3_1[:,i].mean())

# %%
S2meanrefA1_17= list()
S2meanD4_1 = list()
for i in range(S2HSV_imgA1D4_1.shape[0]): 
     for j in range(S2HSV_imgA1D4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_17.append(S2HSV_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_1.append(S2HSV_imgA1D4_1[i][j])  
S2meanrefA1_17 = np.array(S2meanrefA1_14)
S2meanD4_1 = np.array(S2meanD4_1)

S2hsvrefA1_17 = list()
S2hsvD4_1 = list()
for i in range(3):
    S2hsvrefA1_17.append(S2meanrefA1_17[:,i].mean())
    S2hsvD4_1.append(S2meanD4_1[:,i].mean())

# %% [markdown]
# ###Img 2

# %%
S2meanrefA1_102 = list()
S2meanA1_202 = list()
for i in range(S1HSV_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_102.append(S1HSV_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_202.append(S1HSV_imgA1A1_2[i][j])  
S2meanrefA1_102= np.array(S2meanrefA1_102)
S2meanA1_202 = np.array(S2meanA1_202)

S2hsvrefA1_102 = list()
S2hsvA1_202 = list()
for i in range(3):
    S2hsvrefA1_102.append(S2meanrefA1_1[:,i].mean())
    S2hsvA1_202.append(S2meanA1_2[:,i].mean())
S2hsvrefA1_102,S2hsvA1_202

# %%
S2meanrefA1_302 = list()
S2meanA2_102 = list()
for i in range(S1HSV_imgA1A2_2.shape[0]): 
     for j in range(S1HSV_imgA1A2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_302.append(S1HSV_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_102.append(S1HSV_imgA1A2_2[i][j])  
S2meanrefA1_302 = np.array(S2meanrefA1_3)
S2meanA2_102 = np.array(S2meanA2_1)

S2hsvrefA1_302 = list()
S2hsvA2_102 = list()
for i in range(3):
    S2hsvrefA1_302.append(S2meanrefA1_302[:,i].mean())
    S2hsvA2_102.append(S2meanA2_102[:,i].mean())

# %%
S2meanrefA1_402 = list()
S2meanA3_102 = list()
for i in range(S1HSV_imgA1A3_2.shape[0]): 
     for j in range(S1HSV_imgA1A3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_402.append(S1HSV_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_102.append(S1HSV_imgA1A3_2[i][j])  
S2meanrefA1_402= np.array(S2meanrefA1_402)
S2meanA3_102 = np.array(S2meanA3_102)

S2hsvrefA1_402 = list()
S2hsvA3_102 = list()
for i in range(3):
    S2hsvrefA1_402.append(S2meanrefA1_402[:,i].mean())
    S2hsvA3_102.append(S2meanA3_102[:,i].mean())

# %%
S2meanrefA1_502 = list()
S2meanA3_5102 = list()
for i in range(S1HSV_imgA1A3_52.shape[0]): 
     for j in range(S1HSV_imgA1A3_52.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_502.append(S1HSV_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5102.append(S1HSV_imgA1A3_52[i][j])  
S2meanrefA1_502 = np.array(S2meanrefA1_502)
S2meanA3_5102 = np.array(S2meanA3_5102)

S2hsvrefA1_502 = list()
S2hsvA3_5102 = list()
for i in range(3):
    S2hsvrefA1_502.append(S2meanrefA1_502[:,i].mean())
    S2hsvA3_5102.append(S2meanA3_5102[:,i].mean())

# %%
S2meanrefA1_602 = list()
S2meanA4_102 = list()
for i in range(S1HSV_imgA1A4_2.shape[0]): 
     for j in range(S1HSV_imgA1A4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_602.append(S1HSV_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_102.append(S1HSV_imgA1A4_2[i][j])  
S2meanrefA1_602 = np.array(S2meanrefA1_602)
S2meanA4_102 = np.array(S2meanA4_102)

S2hsvrefA1_602 = list()
S2hsvA4_102 = list()
for i in range(3):
    S2hsvrefA1_602.append(S2meanrefA1_602[:,i].mean())
    S2hsvA4_102.append(S2meanA4_102[:,i].mean())

# %%
S2meanrefA1_702 = list()
S2meanB1_102 = list()
for i in range(S1HSV_imgA1B1_2.shape[0]): 
     for j in range(S1HSV_imgA1B1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_702.append(S1HSV_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_102.append(S1HSV_imgA1B1_2[i][j])  
S2meanrefA1_702 = np.array(S2meanrefA1_702)
S2meanB1_102 = np.array(S2meanB1_102)

S2hsvrefA1_702 = list()
S2hsvB1_102 = list()
for i in range(3):
    S2hsvrefA1_702.append(S2meanrefA1_702[:,i].mean())
    S2hsvB1_102.append(S2meanB1_102[:,i].mean())

# %%
S2meanrefA1_802 = list()
S2meanB2_102 = list()
for i in range(S1HSV_imgA1B2_2.shape[0]): 
     for j in range(S1HSV_imgA1B2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_802.append(S1HSV_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_102.append(S1HSV_imgA1B2_2[i][j])  
S2meanrefA1_802 = np.array(S2meanrefA1_802)
S2meanB2_102 = np.array(S2meanB2_102)

S2hsvrefA1_802 = list()
S2hsvB2_102 = list()
for i in range(3):
    S2hsvrefA1_802.append(S2meanrefA1_802[:,i].mean())
    S2hsvB2_102.append(S2meanB2_102[:,i].mean())

# %%
S2meanrefA1_902 = list()
S2meanB3_102 = list()
for i in range(S1HSV_imgA1B3_2.shape[0]): 
     for j in range(S1HSV_imgA1B3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_902.append(S1HSV_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_102.append(S1HSV_imgA1B3_2[i][j])  
S2meanrefA1_902 = np.array(S2meanrefA1_902)
S2meanB3_102 = np.array(S2meanB3_102)

S2hsvrefA1_902 = list()
S2hsvB3_102 = list()
for i in range(3):
    S2hsvrefA1_902.append(S2meanrefA1_902[:,i].mean())
    S2hsvB3_102.append(S2meanB3_102[:,i].mean())

# %%
S2meanrefA1_1002 = list()
S2meanB4_102 = list()
for i in range(S1HSV_imgA1B4_2.shape[0]): 
     for j in range(S1HSV_imgA1B4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1002.append(S1HSV_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_102.append(S1HSV_imgA1B4_2[i][j])  
S2meanrefA1_1002 = np.array(S2meanrefA1_1002)
S2meanB4_102 = np.array(S2meanB4_102)

S2hsvrefA1_1002 = list()
S2hsvB4_102 = list()
for i in range(3):
    S2hsvrefA1_10.append(S2meanrefA1_10[:,i].mean())
    S2hsvB4_1.append(S2meanB4_1[:,i].mean())

# %%
S2meanrefA1_1102 = list()
S2meanC1_102 = list()
for i in range(S1HSV_imgA1C1_2.shape[0]): 
     for j in range(S1HSV_imgA1C1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1102.append(S1HSV_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_102.append(S1HSV_imgA1C1_2[i][j])  
S2meanrefA1_1102 = np.array(S2meanrefA1_1102)
S2meanC1_102= np.array(S2meanC1_102)

S2hsvrefA1_1102 = list()
S2hsvC1_102 = list()
for i in range(3):
    S2hsvrefA1_1102.append(S2meanrefA1_1102[:,i].mean())
    S2hsvC1_102.append(S2meanC1_102[:,i].mean())

# %%
S2meanrefA1_1202 = list()
S2meanC2_102 = list()
for i in range(S1HSV_imgA1C2_2.shape[0]): 
     for j in range(S1HSV_imgA1C2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1202.append(S1HSV_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_102.append(S1HSV_imgA1C2_2[i][j])  
S2meanrefA1_1202 = np.array(S2meanrefA1_1202)
S2meanC2_102 = np.array(S2meanC2_102)

S2hsvrefA1_1202 = list()
S2hsvC2_102 = list()
for i in range(3):
    S2hsvrefA1_1202.append(S2meanrefA1_1202[:,i].mean())
    S2hsvC2_102.append(S2meanC2_102[:,i].mean())

# %%
S2meanrefA1_1302 = list()
S2meanC3_102 = list()
for i in range(S1HSV_imgA1C3_.shape[0]): 
     for j in range(S1HSV_imgA1C3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1302.append(S1HSV_imgA1C3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_102.append(S1HSV_imgA1C3_[i][j])  
S2meanrefA1_1302 = np.array(S2meanrefA1_1302)
S2meanC3_102 = np.array(S2meanC3_102)

S2hsvrefA1_1302 = list()
S2hsvC3_102 = list()
for i in range(3):
    S2hsvrefA1_1302.append(S2meanrefA1_1302[:,i].mean())
    S2hsvC3_102.append(S2meanC3_102[:,i].mean())

# %%
S2meanrefA1_1402 = list()
S2meanC4_102 = list()
for i in range(S1HSV_imgA1C4_2.shape[0]): 
     for j in range(S1HSV_imgA1C4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1402.append(S1HSV_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_102.append(S1HSV_imgA1C4_2[i][j])  
S2meanrefA1_1402 = np.array(S2meanrefA1_1402)
S2meanC4_102 = np.array(S2meanC4_102)

S2hsvrefA1_1402 = list()
S2hsvC4_102 = list()
for i in range(3):
    S2hsvrefA1_1402.append(S2meanrefA1_1402[:,i].mean())
    S2hsvC4_102.append(S2meanC4_102[:,i].mean())

# %%
S2meanrefA1_1502 = list()
S2meanD2_102 = list()
for i in range(S1HSV_imgA1D2_2.shape[0]): 
     for j in range(S1HSV_imgA1D2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1502.append(S1HSV_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_102.append(S1HSV_imgA1D2_2[i][j])  
S2meanrefA1_1502 = np.array(S2meanrefA1_1502)
S2meanD2_102 = np.array(S2meanD2_102)

S2hsvrefA1_1502 = list()
S2hsvD2_102 = list()
for i in range(3):
    S2hsvrefA1_1502.append(S2meanrefA1_1502[:,i].mean())
    S2hsvD2_102.append(S2meanD2_102[:,i].mean())

# %%
S2meanrefA1_1602 = list()
S2meanD3_102 = list()
for i in range(S1HSV_imgA1D3_2.shape[0]): 
     for j in range(S1HSV_imgA1D3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1602.append(S1HSV_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_102.append(S1HSV_imgA1D3_2[i][j])  
S2meanrefA1_1602 = np.array(S2meanrefA1_1602)
S2meanD3_102 = np.array(S2meanD3_102)

S2hsvrefA1_1602 = list()
S2hsvD3_102 = list()
for i in range(3):
    S2hsvrefA1_1602.append(S2meanrefA1_1602[:,i].mean())
    S2hsvD3_102.append(S2meanD3_102[:,i].mean())

# %%
S2meanrefA1_1702= list()
S2meanD4_102 = list()
for i in range(S1HSV_imgA1D4_2.shape[0]): 
     for j in range(S1HSV_imgA1D4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1702.append(S1HSV_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_102.append(S1HSV_imgA1D4_2[i][j])  
S2meanrefA1_1702 = np.array(S2meanrefA1_1702)
S2meanD4_102 = np.array(S2meanD4_102)

S2hsvrefA1_1702 = list()
S2hsvD4_102 = list()
for i in range(3):
    S2hsvrefA1_1702.append(S2meanrefA1_1702[:,i].mean())
    S2hsvD4_102.append(S2meanD4_102[:,i].mean())

# %% [markdown]
# ###Img 3

# %%
S2meanrefA1_103 = list()
S2meanA1_203 = list()
for i in range(S1HSV_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_103.append(S1HSV_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_203.append(S1HSV_imgA1A1_3[i][j])  
S2meanrefA1_103 = np.array(S2meanrefA1_103)
S2meanA1_203 = np.array(S2meanA1_203)

S2hsvrefA1_103 = list()
S2hsvA1_203 = list()
for i in range(3):
    S2hsvrefA1_103.append(S2meanrefA1_103[:,i].mean())
    S2hsvA1_203.append(S2meanA1_203[:,i].mean())
S2hsvrefA1_103,S2hsvA1_203

# %%
S2meanrefA1_303 = list()
S2meanA2_103 = list()
for i in range(S1HSV_imgA1A2_3.shape[0]): 
     for j in range(S1HSV_imgA1A2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_303.append(S1HSV_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_103.append(S1HSV_imgA1A2_3[i][j])  
S2meanrefA1_303 = np.array(S2meanrefA1_303)
S2meanA2_103 = np.array(S2meanA2_103)

S2hsvrefA1_303 = list()
S2hsvA2_103 = list()
for i in range(3):
    S2hsvrefA1_303.append(S2meanrefA1_303[:,i].mean())
    S2hsvA2_103.append(S2meanA2_103[:,i].mean())

# %%
S2meanrefA1_403 = list()
S2meanA3_103 = list()
for i in range(S1HSV_imgA1A3_3.shape[0]): 
     for j in range(S1HSV_imgA1A3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_403append(S1HSV_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_103.append(S1HSV_imgA1A3_3[i][j])  
S2meanrefA1_403 = np.array(S2meanrefA1_403)
S2meanA3_103 = np.array(S2meanA3_103)

S2hsvrefA1_403 = list()
S2hsvA3_103 = list()
for i in range(3):
    S2hsvrefA1_403.append(S2meanrefA1_403[:,i].mean())
    S2hsvA3_103.append(S2meanA3_103[:,i].mean())

# %%
S2meanrefA1_503 = list()
S2meanA3_5103 = list()
for i in range(S1HSV_imgA1A3_53.shape[0]): 
     for j in range(S1HSV_imgA1A3_53.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_503.append(S1HSV_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5103.append(S1HSV_imgA1A3_53[i][j])  
S2meanrefA1_503 = np.array(S2meanrefA1_503)
S2meanA3_5103 = np.array(S2meanA3_5103)

S2hsvrefA1_503 = list()
S2hsvA3_5103 = list()
for i in range(3):
    S2hsvrefA1_503.append(S2meanrefA1_503[:,i].mean())
    S2hsvA3_5103.append(S2meanA3_5103[:,i].mean())

# %%
S2meanrefA1_603 = list()
S2meanA4_103 = list()
for i in range(S1HSV_imgA1A4_303.shape[0]): 
     for j in range(S1HSV_imgA1A4_303.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_603.append(S1HSV_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_103.append(S1HSV_imgA1A4_3[i][j])  
S2meanrefA1_603 = np.array(S2meanrefA1_603)
S2meanA4_103 = np.array(S2meanA4_103)

S2hsvrefA1_603 = list()
S2hsvA4_103 = list()
for i in range(3):
    S2hsvrefA1_603.append(S2meanrefA1_603[:,i].mean())
    S2hsvA4_103.append(S2meanA4_103[:,i].mean())

# %%
S2meanrefA1_703 = list()
S2meanB1_103 = list()
for i in range(S1HSV_imgA1B1_3.shape[0]): 
     for j in range(S1HSV_imgA1B1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_703.append(S1HSV_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_103.append(S1HSV_imgA1B1_3[i][j])  
S2meanrefA1_703 = np.array(S2meanrefA1_703)
S2meanB1_103 = np.array(S2meanB1_103)

S2hsvrefA1_703 = list()
S2hsvB1_103 = list()
for i in range(3):
    S2hsvrefA1_703.append(S2meanrefA1_703[:,i].mean())
    S2hsvB1_103.append(S2meanB1_103[:,i].mean())

# %%
S2meanrefA1_803 = list()
S2meanB2_103 = list()
for i in range(S1HSV_imgA1B2_3.shape[0]): 
     for j in range(S1HSV_imgA1B2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_803.append(S1HSV_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_103.append(S1HSV_imgA1B2_3[i][j])  
S2meanrefA1_803 = np.array(S2meanrefA1_803)
S2meanB2_103 = np.array(S2meanB2_103

S2hsvrefA1_803 = list()
S2hsvB2_103 = list()
for i in range(3):
    S2hsvrefA1_8.append(S2meanrefA1_803[:,i].mean())
    S2hsvB2_1.append(S2meanB2_103[:,i].mean())

# %%
S2meanrefA1_903 = list()
S2meanB3_103 = list()
for i in range(S1HSV_imgA1B3_3.shape[0]): 
     for j in range(S1HSV_imgA1B3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_903.append(S1HSV_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_103.append(S1HSV_imgA1B3_3[i][j])  
S2meanrefA1_903 = np.array(S2meanrefA1_903)
S2meanB3_103 = np.array(S2meanB3_103)

S2hsvrefA1_903 = list()
S2hsvB3_103 = list()
for i in range(3):
    S2hsvrefA1_903.append(S2meanrefA1_9[:,i].mean())
    S2hsvB3_103.append(S2meanB3_1[:,i].mean())

# %%
S2meanrefA1_1003 = list()
S2meanB4_103 = list()
for i in range(S1HSV_imgA1B4_3.shape[0]): 
     for j in range(S1HSV_imgA1B4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1003.append(S1HSV_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_103.append(S1HSV_imgA1B4_3[i][j])  
S2meanrefA1_1003 = np.array(S2meanrefA1_1003)
S2meanB4_103 = np.array(S2meanB4_103)

S2hsvrefA1_1003 = list()
S2hsvB4_103 = list()
for i in range(3):
    S2hsvrefA1_1003.append(S2meanrefA1_1003[:,i].mean())
    S2hsvB4_103.append(S2meanB4_103[:,i].mean())

# %%
S2meanrefA1_1103 = list()
S2meanC1_103 = list()
for i in range(S1HSV_imgA1C1_3.shape[0]): 
     for j in range(S1HSV_imgA1C1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1103.append(S1HSV_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_103.append(S1HSV_imgA1C1_3[i][j])  
S2meanrefA1_1103 = np.array(S2meanrefA1_1103)
S2meanC1_103 = np.array(S2meanC1_103)

S2hsvrefA1_11 = list()
S2hsvC1_103 = list()
for i in range(3):
    S2hsvrefA1_1103.append(S2meanrefA1_1103[:,i].mean())
    S2hsvC1_103.append(S2meanC1_103[:,i].mean())

# %%
S2meanrefA1_1203 = list()
S2meanC2_103 = list()
for i in range(S1HSV_imgA1C2_3.shape[0]): 
     for j in range(S1HSV_imgA1C2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1203.append(S1HSV_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_103.append(S1HSV_imgA1C2_3[i][j])  
S2meanrefA1_1203 = np.array(S2meanrefA1_1203)
S2meanC2_103 = np.array(S2meanC2_103)

S2hsvrefA1_1203 = list()
S2hsvC2_103 = list()
for i in range(3):
    S2hsvrefA1_1203.append(S2meanrefA1_1203[:,i].mean())
    S2hsvC2_103.append(S2meanC2_103[:,i].mean())

# %%
S2meanrefA1_1303 = list()
S2meanC3_103 = list()
for i in range(S1HSV_imgA1C3_3.shape[0]): 
     for j in range(S1HSV_imgA1C3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1303.append(S1HSV_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_103.append(S1HSV_imgA1C3_3[i][j])  
S2meanrefA1_1303 = np.array(S2meanrefA1_130303)
S2meanC3_103 = np.array(S2meanC3_103)

S2hsvrefA1_1303 = list()
S2hsvC3_103 = list()
for i in range(3):
    S2hsvrefA1_1303.append(S2meanrefA1_1303[:,i].mean())
    S2hsvC3_103.append(S2meanC3_103[:,i].mean())

# %%
S2meanrefA1_1403 = list()
S2meanC4_103 = list()
for i in range(S1HSV_imgA1C4_3.shape[0]): 
     for j in range(S1HSV_imgA1C4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_14.append(S1HSV_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_103.append(S1HSV_imgA1C4_3[i][j])  
S2meanrefA1_1403 = np.array(S2meanrefA1_1403)
S2meanC4_103 = np.array(S2meanC4_103)

S2hsvrefA1_1403 = list()
S2hsvC4_103 = list()
for i in range(3):
    S2hsvrefA1_1403.append(S2meanrefA1_1403[:,i].mean())
    S2hsvC4_103.append(S2meanC4_103[:,i].mean())

# %%
S2meanrefA1_1503 = list()
S2meanD2_103 = list()
for i in range(S1HSV_imgA1D2_303.shape[0]): 
     for j in range(S1HSV_imgA1D2_303.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1503.append(S1HSV_imgA1D2_303[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_103.append(S1HSV_imgA1D2_303[i][j])  
S2meanrefA1_1503 = np.array(S2meanrefA1_1503)
S2meanD2_103 = np.array(S2meanD2_103)

S2hsvrefA1_1503 = list()
S2hsvD2_103 = list()
for i in range(3):
    S2hsvrefA1_1503.append(S2meanrefA1_1503[:,i].mean())
    S2hsvD2_103.append(S2meanD2_103[:,i].mean())

# %%
S2meanrefA1_1603 = list()
S2meanD3_103 = list()
for i in range(S1HSV_imgA1D3_3.shape[0]): 
     for j in range(S1HSV_imgA1D3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_16.append(S1HSV_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_1.append(S1HSV_imgA1D3_3[i][j])  
S2meanrefA1_1603 = np.array(S2meanrefA1_1603)
S2meanD3_103 = np.array(S2meanD3_103)

S2hsvrefA1_1603 = list()
S2hsvD3_103 = list()
for i in range(3):
    S2hsvrefA1_1603.append(S2meanrefA1_1603[:,i].mean())
    S2hsvD3_103.append(S2meanD3_103[:,i].mean())

# %%
S2meanrefA1_1703= list()
S2meanD4_103 = list()
for i in range(S1HSV_imgA1D4_3.shape[0]): 
     for j in range(S1HSV_imgA1D4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1703.append(S1HSV_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_103.append(S1HSV_imgA1D4_3[i][j])  
S2meanrefA1_1703 = np.array(S2meanrefA1_1403)
S2meanD4_103 = np.array(S2meanD4_103)

S2hsvrefA1_1703 = list()
S2hsvD4_103 = list()
for i in range(3):
    S2hsvrefA1_1703.append(S2meanrefA1_1703[:,i].mean())
    S2hsvD4_103.append(S2meanD4_103[:,i].mean())

# %% [markdown]
# ###Img 4

# %%
S2meanrefA1_104 = list()
S2meanA1_204 = list()
for i in range(S1HSV_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_104.append(S1HSV_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_204.append(S1HSV_imgA1A1_[i][j])  
S2meanrefA1_104 = np.array(S2meanrefA1_104)
S2meanA1_204 = np.array(S2meanA1_204)

S2hsvrefA1_104 = list()
S2hsvA1_204 = list()
for i in range(3):
    S2hsvrefA1_104.append(S2meanrefA1_104[:,i].mean())
    S2hsvA1_204.append(S2meanA1_204[:,i].mean())
S2hsvrefA1_104,S2hsvA1_204

# %%
S2meanrefA1_304 = list()
S2meanA2_104 = list()
for i in range(S1HSV_imgA1A2_4.shape[0]): 
     for j in range(S1HSV_imgA1A2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_304.append(S1HSV_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_104.append(S1HSV_imgA1A2_4[i][j])  
S2meanrefA1_304 = np.array(S2meanrefA1_304)
S2meanA2_104 = np.array(S2meanA2_104)

S2hsvrefA1_304 = list()
S2hsvA2_104 = list()
for i in range(3):
    S2hsvrefA1_304.append(S2meanrefA1_304[:,i].mean())
    S2hsvA2_104.append(S2meanA2_104[:,i].mean())

# %%
S2meanrefA1_404 = list()
S2meanA3_104 = list()
for i in range(S1HSV_imgA1A3_4.shape[0]): 
     for j in range(S1HSV_imgA1A3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_404.append(S1HSV_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_104.append(S1HSV_imgA1A3_4[i][j])  
S2meanrefA1_404 = np.array(S1meanrefA1_404)
S2meanA3_104 = np.array(S1meanA3_104)

S2hsvrefA1_404 = list()
S2hsvA3_104 = list()
for i in range(3):
    S2hsvrefA1_404.append(S2meanrefA1_404[:,i].mean())
    S2hsvA3_104.append(S2meanA3_104[:,i].mean())

# %%
S2meanrefA1_504 = list()
S2meanA3_5104 = list()
for i in range(S1HSV_imgA1A3_54.shape[0]): 
     for j in range(S1HSV_imgA1A3_54.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_504.append(S1HSV_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5104.append(S1HSV_imgA1A3_54[i][j])  
S2meanrefA1_504 = np.array(S2meanrefA1_504)
S2meanA3_5104 = np.array(S2meanA3_5104)

S2hsvrefA1_504 = list()
S2hsvA3_5104 = list()
for i in range(3):
    S2hsvrefA1_504.append(S2meanrefA1_504[:,i].mean())
    S2hsvA3_5104.append(S2meanA3_5104[:,i].mean())

# %%
S2meanrefA1_604 = list()
S2meanA4_104 = list()
for i in range(S1HSV_imgA1A4_4.shape[0]): 
     for j in range(S1HSV_imgA1A4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_604.append(S1HSV_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_104.append(S1HSV_imgA1A4_[i][j])  
S2meanrefA1_604 = np.array(S2meanrefA1_604)
S2meanA4_104 = np.array(S2meanA4_104)

S2hsvrefA1_604 = list()
S2hsvA4_104 = list()
for i in range(3):
    S2hsvrefA1_604.append(S2meanrefA1_604[:,i].mean())
    S2hsvA4_104.append(S2meanA4_104[:,i].mean())

# %%
S2meanrefA1_704 = list()
S2meanB1_104 = list()
for i in range(S1HSV_imgA1B1_4.shape[0]): 
     for j in range(S1HSV_imgA1B1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_7.append(S1HSV_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_1.append(S1HSV_imgA1B1_4[i][j])  
S2meanrefA1_704 = np.array(S2meanrefA1_704)
S2meanB1_104 = np.array(S2meanB1_104)

S2hsvrefA1_704 = list()
S2hsvB1_104 = list()
for i in range(3):
    S2hsvrefA1_704.append(S2meanrefA1_704[:,i].mean())
    S2hsvB1_104.append(S2meanB1_104[:,i].mean())

# %%
S2meanrefA1_804 = list()
S2meanB2_104 = list()
for i in range(S1HSV_imgA1B2_4.shape[0]): 
     for j in range(S1HSV_imgA1B2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_804.append(S1HSV_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_104.append(S1HSV_imgA1B2_4[i][j])  
S2meanrefA1_804 = np.array(S2meanrefA1_804)
S2meanB2_104 = np.array(S2meanB2_104)

S2hsvrefA1_804 = list()
S2hsvB2_104 = list()
for i in range(3):
    S2hsvrefA1_804.append(S2meanrefA1_804[:,i].mean())
    S2hsvB2_104.append(S2meanB2_104[:,i].mean())

# %%
S2meanrefA1_904 = list()
S2meanB3_104 = list()
for i in range(S1HSV_imgA1B3_404.shape[0]): 
     for j in range(S1HSV_imgA1B3_404.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_904.append(S1HSV_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_104.append(S1HSV_imgA1B3_4[i][j])  
S2meanrefA1_904 = np.array(S2meanrefA1_904)
S2meanB3_104 = np.array(S2meanB3_104)

S2hsvrefA1_904 = list()
S2hsvB3_104 = list()
for i in range(3):
    S2hsvrefA1_904.append(S2meanrefA1_904[:,i].mean())
    S2hsvB3_104.append(S2meanB3_104[:,i].mean())

# %%
S2meanrefA1_1004 = list()
S2meanB4_104 = list()
for i in range(S1HSV_imgA1B4_4.shape[0]): 
     for j in range(S1HSV_imgA1B4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1004.append(S1HSV_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_104.append(S1HSV_imgA1B4_4[i][j])  
S2meanrefA1_1004 = np.array(S2meanrefA1_1004)
S2meanB4_104 = np.array(S2meanB4_104)

S2hsvrefA1_1004 = list()
S2hsvB4_104= list()
for i in range(3):
    S2hsvrefA1_1004.append(S2meanrefA1_1004[:,i].mean())
    S2hsvB4_104.append(S2meanB4_104[:,i].mean())

# %%
S2meanrefA1_1104 = list()
S2meanC1_104 = list()
for i in range(S1HSV_imgA1C1_4.shape[0]): 
     for j in range(S1HSV_imgA1C1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1104.append(S1HSV_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_104.append(S1HSV_imgA1C1_4[i][j])  
S2meanrefA1_1104 = np.array(S2meanrefA1_1104)
S2meanC1_104 = np.array(S2meanC1_104)

S2hsvrefA1_1104 = list()
S2hsvC1_104 = list()
for i in range(3):
    S2hsvrefA1_1104.append(S2meanrefA1_1104[:,i].mean())
    S2hsvC1_104.append(S2meanC1_104[:,i].mean())

# %%
S2meanrefA1_1204 = list()
S2meanC2_104 = list()
for i in range(S1HSV_imgA1C2_4.shape[0]): 
     for j in range(S1HSV_imgA1C2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1204.append(S1HSV_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_104.append(S1HSV_imgA1C2_4[i][j])  
S2meanrefA1_1204 = np.array(S2meanrefA1_1204)
S2meanC2_104 = np.array(S2meanC2_104)

S2hsvrefA1_1204 = list()
S2hsvC2_104 = list()
for i in range(3):
    S2hsvrefA1_1204.append(S2meanrefA1_1204[:,i].mean())
    S2hsvC2_104.append(S2meanC2_104[:,i].mean())

# %%
S2meanrefA1_1304 = list()
S2meanC3_104 = list()
for i in range(S1HSV_imgA1C3_4.shape[0]): 
     for j in range(S1HSV_imgA1C3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1304.append(S1HSV_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_104.append(S1HSV_imgA1C3_4[i][j])  
S2meanrefA1_1304 = np.array(S2meanrefA1_1304)
S2meanC3_104 = np.array(S2meanC3_104)

S2hsvrefA1_1304 = list()
S2hsvC3_104 = list()
for i in range(3):
    S2hsvrefA1_1304.append(S2meanrefA1_1304[:,i].mean())
    S2hsvC3_104.append(S2meanC3_104[:,i].mean())

# %%
S2meanrefA1_1404 = list()
S2meanC4_104 = list()
for i in range(S1HSV_imgA1C4_4.shape[0]): 
     for j in range(S1HSV_imgA1C4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1404.append(S1HSV_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_104.append(S1HSV_imgA1C4_4[i][j])  
S2meanrefA1_1404 = np.array(S2meanrefA1_14)
S2meanC4_104 = np.array(S2meanC4_1)

S2hsvrefA1_1404 = list()
S2hsvC4_104 = list()
for i in range(3):
    S2hsvrefA1_1404.append(S2meanrefA1_1404[:,i].mean())
    S2hsvC4_104.append(S2meanC4_104[:,i].mean())

# %%
S2meanrefA1_1504 = list()
S2meanD2_104 = list()
for i in range(S1HSV_imgA1D2_4.shape[0]): 
     for j in range(S1HSV_imgA1D2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1504.append(S1HSV_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_104.append(S1HSV_imgA1D2_4[i][j])  
S2meanrefA1_1504 = np.array(S2meanrefA1_1504)
S2meanD2_104 = np.array(S2meanD2_104)

S2hsvrefA1_1504 = list()
S2hsvD2_104 = list()
for i in range(3):
    S2hsvrefA1_1504.append(S2meanrefA1_1504[:,i].mean())
    S2hsvD2_104.append(S2meanD2_104[:,i].mean())

# %%
S2meanrefA1_1604 = list()
S2meanD3_104 = list()
for i in range(S1HSV_imgA1D3_4.shape[0]): 
     for j in range(S1HSV_imgA1D3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1604.append(S1HSV_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_104.append(S1HSV_imgA1D3_4[i][j])  
S2meanrefA1_1604 = np.array(S2meanrefA1_1604)
S2meanD3_104 = np.array(S2meanD3_104)

S2hsvrefA1_1604 = list()
S2hsvD3_104 = list()
for i in range(3):
    S2hsvrefA1_1604.append(S2meanrefA1_1604[:,i].mean())
    S2hsvD3_104.append(S2meanD3_104[:,i].mean())

# %%
S2meanrefA1_1704= list()
S2meanD4_104 = list()
for i in range(S1HSV_imgA1D4_4.shape[0]): 
     for j in range(S1HSV_imgA1D4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1704.append(S1HSV_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_104.append(S1HSV_imgA1D4_4[i][j])  
S2meanrefA1_1704 = np.array(S2meanrefA1_1404)
S2meanD4_104 = np.array(S2meanD4_104)

S2hsvrefA1_1704 = list()
S2hsvD4_104 = list()
for i in range(3):
    S2hsvrefA1_1704.append(S2meanrefA1_1704[:,i].mean())
    S2hsvD4_104.append(S2meanD4_104[:,i].mean())

# %% [markdown]
# ###Img 5

# %%
S2meanrefA1_105 = list()
S2meanA1_205 = list()
for i in range(S1HSV_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_105.append(S1HSV_imgA1A1_505[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_205.append(S1HSV_imgA1A1_505[i][j])  
S2meanrefA1_105 = np.array(S2meanrefA1_105)
S2meanA1_205 = np.array(S2meanA1_205)

S2hsvrefA1_105 = list()
S2hsvA1_205 = list()
for i in range(3):
    S2hsvrefA1_105.append(S2meanrefA1_105[:,i].mean())
    S2hsvA1_205.append(S2meanA1_205[:,i].mean())
S2hsvrefA1_105,S2hsvA1_205

# %%
S2meanrefA1_305 = list()
S2meanA2_105 = list()
for i in range(S1HSV_imgA1A2_5.shape[0]): 
     for j in range(S1HSV_imgA1A2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_305.append(S1HSV_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_105.append(S1HSV_imgA1A2_5[i][j])  
S2meanrefA1_305 = np.array(S2meanrefA1_305)
S2meanA2_105 = np.array(S2meanA2_105)

S2hsvrefA1_305 = list()
S2hsvA2_105 = list()
for i in range(3):
    S2hsvrefA1_305.append(S2meanrefA1_305[:,i].mean())
    S2hsvA2_105.append(S2meanA2_105[:,i].mean())

# %%
S2meanrefA1_405 = list()
S2meanA3_105 = list()
for i in range(S1HSV_imgA1A3_5.shape[0]): 
     for j in range(S1HSV_imgA1A3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_405.append(S1HSV_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_105.append(S1HSV_imgA1A3_5[i][j])  
S2meanrefA1_405 = np.array(S1meanrefA1_405)
S2meanA3_1อ = np.array(S1meanA3_105)

S2hsvrefA1_405 = list()
S2hsvA3_105= list()
for i in range(3):
    S2hsvrefA1_405.append(S2meanrefA1_405[:,i].mean())
    S2hsvA3_105.append(S2meanA3_105[:,i].mean())

# %%
S2meanrefA1_505 = list()
S2meanA3_5105 = list()
for i in range(S1HSV_imgA1A3_55.shape[0]): 
     for j in range(S1HSV_imgA1A3_55.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_505.append(S1HSV_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5105.append(S1HSV_imgA1A3_55[i][j])  
S2meanrefA1_505 = np.array(S1meanrefA1_505)
S2meanA3_5105 = np.array(S1meanA3_5105)

S2hsvrefA1_505= list()
S2hsvA3_5105 = list()
for i in range(3):
    S2hsvrefA1_505.append(S2meanrefA1_505[:,i].mean())
    S2hsvA3_5105.append(S2meanA3_5105[:,i].mean())

# %%
S2meanrefA1_605 = list()
S2meanA4_105= list()
for i in range(S1HSV_imgA1A4_5.shape[0]): 
     for j in range(S1HSV_imgA1A4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_605.append(S1HSV_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_105.append(S1HSV_imgA1A4_5[i][j])  
S2meanrefA1_605 = np.array(S2meanrefA1_605)
S2meanA4_105 = np.array(S2meanA4_105)

S2hsvrefA1_605 = list()
S2hsvA4_105 = list()
for i in range(3):
    S2hsvrefA1_6อ.append(S2meanrefA1_605[:,i].mean())
    S2hsvA4_105.append(S2meanA4_105[:,i].mean())

# %%
S2meanrefA1_705 = list()
S2meanB1_105 = list()
for i in range(S1HSV_imgA1B1_5.shape[0]): 
     for j in range(S1HSV_imgA1B1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_705append(S1HSV_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_105.append(S1HSV_imgA1B1_5[i][j])  
S2meanrefA1_705 = np.array(S2meanrefA1_705)
S2meanB1_105 = np.array(S2meanB1_105)

S2hsvrefA1_705 = list()
S2hsvB1_105 = list()
for i in range(3):
    S2hsvrefA1_705.append(S2meanrefA1_7[:,i].mean())
    S2hsvB1_105.append(S2meanB1_1[:,i].mean())

# %%
S2meanrefA1_805 = list()
S2meanB2_105 = list()
for i in range(S1HSV_imgA1B2_5.shape[0]): 
     for j in range(S1HSV_imgA1B2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_8อ.append(S1HSV_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_105.append(S1HSV_imgA1B2_5[i][j])  
S2meanrefA1_805 = np.array(S2meanrefA1_8อ)
S2meanB2_105 = np.array(S2meanB2_105)

S2hsvrefA1_805 = list()
S2hsvB2_105 = list()
for i in range(3):
    S2hsvrefA1_805.append(S2meanrefA1_805[:,i].mean())
    S2hsvB2_105.append(S2meanB2_105[:,i].mean())

# %%
S2meanrefA1_905 = list()
S2meanB3_105= list()
for i in range(S1HSV_imgA1B3_5.shape[0]): 
     for j in range(S1HSV_imgA1B3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_905.append(S1HSV_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_105.append(S1HSV_imgA1B3_5[i][j])  
S2meanrefA1_905 = np.array(S2meanrefA1_905)
S2meanB3_105 = np.array(S2meanB3_105)

S2hsvrefA1_905 = list()
S2hsvB3_105 = list()
for i in range(3):
    S2hsvrefA1_905.append(S2meanrefA1_905[:,i].mean())
    S2hsvB3_105.append(S2meanB3_105[:,i].mean())

# %%
S2meanrefA1_1005 = list()
S2meanB4_105 = list()
for i in range(S1HSV_imgA1B4_5.shape[0]): 
     for j in range(S1HSV_imgA1B4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1005.append(S1HSV_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_105.append(S1HSV_imgA1B4_5[i][j])  
S2meanrefA1_1005 = np.array(S2meanrefA1_1005)
S2meanB4_105 = np.array(S2meanB4_105)

S2hsvrefA1_1005 = list()
S2hsvB4_105 = list()
for i in range(3):
    S2hsvrefA1_1005.append(S2meanrefA1_1005[:,i].mean())
    S2hsvB4_105.append(S2meanB4_105[:,i].mean())

# %%
S2meanrefA1_1105 = list()
S2meanC1_105 = list()
for i in range(S1HSV_imgA1C1_5.shape[0]): 
     for j in range(S1HSV_imgA1C1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1105.append(S1HSV_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_105.append(S1HSV_imgA1C1_5[i][j])  
S2meanrefA1_1105 = np.array(S2meanrefA1_1105)
S2meanC1_105 = np.array(S2meanC1_105)

S2hsvrefA1_1105 = list()
S2hsvC1_105= list()
for i in range(3):
    S2hsvrefA1_1105.append(S2meanrefA1_1105[:,i].mean())
    S2hsvC1_105.append(S2meanC1_105[:,i].mean())

# %%
S2meanrefA1_1205 = list()
S2meanC2_105 = list()
for i in range(S1HSV_imgA1C2_5.shape[0]): 
     for j in range(S1HSV_imgA1C2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1205.append(S1HSV_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_105append(S1HSV_imgA1C2_5[i][j])  
S2meanrefA1_1205 = np.array(S2meanrefA1_1205)
S2meanC2_105 = np.array(S2meanC2_105)

S2hsvrefA1_1205 = list()
S2hsvC2_105 = list()
for i in range(3):
    S2hsvrefA1_1205.append(S1meanrefA1_1205[:,i].mean())
    S2hsvC2_105.append(S1meanC2_105[:,i].mean())

# %%
S2meanrefA1_1305 = list()
S2meanC3_105 = list()
for i in range(S1HSV_imgA1C3_5.shape[0]): 
     for j in range(S1HSV_imgA1C3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1305 .append(S1HSV_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_105 .append(S1HSV_imgA1C3_5[i][j])  
S2meanrefA1_1305 = np.array(S2meanrefA1_1305)
S2meanC3_105 = np.array(S2meanC3_105)

S2hsvrefA1_1305 = list()
S2hsvC3_105 = list()
for i in range(3):
    S2hsvrefA1_1305.append(S2meanrefA1_1305[:,i].mean())
    S2hsvC3_105append(S2meanC3_105[:,i].mean())

# %%
S2meanrefA1_1405 = list()
S2meanC4_105 = list()
for i in range(S1HSV_imgA1C4_5.shape[0]): 
     for j in range(S1HSV_imgA1C4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1405.append(S1HSV_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_105.append(S1HSV_imgA1C4_5[i][j])  
S2meanrefA1_1405 = np.array(S2meanrefA1_1405)
S2meanC4_105 = np.array(S2meanC4_105)

S2hsvrefA1_1405 = list()
S2hsvC4_105 = list()
for i in range(3):
    S2hsvrefA1_1405.append(S2meanrefA1_1405[:,i].mean())
    S2hsvC4_105.append(S2meanC4_105[:,i].mean())

# %%
S2meanrefA1_1505  = list()
S2meanD2_105  = list()
for i in range(S1HSV_imgA1D2_5.shape[0]): 
     for j in range(S1HSV_imgA1D2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1505 .append(S1HSV_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_105 .append(S1HSV_imgA1D2_5[i][j])  
S2meanrefA1_1505 = np.array(S2meanrefA1_1505)
S2meanD2_105  = np.array(S2meanD2_105)

S2hsvrefA1_1505 = list()
S2hsvD2_105 = list()
for i in range(3):
    S2hsvrefA1_1505.append(S2meanrefA1_1505[:,i].mean())
    S2hsvD2_105.append(S2meanD2_105[:,i].mean())

# %%
S2meanrefA1_1605 = list()
S2meanD3_105 = list()
for i in range(S1HSV_imgA1D3_5.shape[0]): 
     for j in range(S1HSV_imgA1D3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1605.append(S1HSV_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_105.append(S1HSV_imgA1D3_5[i][j])  
S2meanrefA1_1605 = np.array(S2meanrefA1_1605)
S2meanD3_105 = np.array(S2meanD3_105)

S2hsvrefA1_1605 = list()
S2hsvD3_105 = list()
for i in range(3):
    S2hsvrefA1_1605.append(S2meanrefA1_1605[:,i].mean())
    S2hsvD3_105.append(S2meanD3_105[:,i].mean())

# %%
S2meanrefA1_1705= list()
S2meanD4_105 = list()
for i in range(S1HSV_imgA1D4_5.shape[0]): 
     for j in range(S1HSV_imgA1D4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1705.append(S1HSV_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_105.append(S1HSV_imgA1D4_5[i][j])  
S2meanrefA1_1705 = np.array(S2meanrefA1_1405)
S2meanD4_105 = np.array(S2meanD4_105)

S2hsvrefA1_1705 = list()
S2hsvD4_105 = list()
for i in range(3):
    S2hsvrefA1_1705.append(S2meanrefA1_1705[:,i].mean())
    S2hsvD4_105.append(S2meanD4_105[:,i].mean())

# %% [markdown]
# ###Img 6

# %%
S2meanrefA1_106 = list()
S2meanA1_206 = list()
for i in range(S1HSV_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_6.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_106.append(S1HSV_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_206.append(S1HSV_imgA1A1_6[i][j])  
S2meanrefA1_106 = np.array(S2meanrefA1_106)
S2meanA1_206 = np.array(S2meanA1_206)

S2hsvrefA1_106 = list()
S2hsvA1_206 = list()
for i in range(3):
    S2hsvrefA1_106.append(S2meanrefA1_106[:,i].mean())
    S2hsvA1_206.append(S2meanA1_206[:,i].mean())
S2hsvrefA1_106,S2hsvA1_206

# %%
S2meanrefA1_306 = list()
S2meanA2_106 = list()
for i in range(S1HSV_imgA1A2_6.shape[0]): 
     for j in range(S1HSV_imgA1A2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_306.append(S1HSV_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_106 .append(S1HSV_imgA1A2_6[i][j])  
S2meanrefA1_306  = np.array(S2meanrefA1_306 )
S2meanA2_106  = np.array(S2meanA2_106 )

S2hsvrefA1_306  = list()
S2hsvA2_106  = list()
for i in range(3):
    S2hsvrefA1_306 .append(S2meanrefA1_306 [:,i].mean())
    S2hsvA2_106 .append(S2meanA2_106 [:,i].mean())

# %%
S2meanrefA1_406  = list()
S2meanA3_106  = list()
for i in range(S1HSV_imgA1A3_6.shape[0]): 
     for j in range(S1HSV_imgA1A3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_406 .append(S1HSV_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_106 .append(S1HSV_imgA1A3_6[i][j])  
S2meanrefA1_406 = np.array(S2meanrefA1_406 )
S2meanA3_106  = np.array(S2meanA3_106 )

S2hsvrefA1_406  = list()
S2hsvA3_106  = list()
for i in range(3):
    S2hsvrefA1_406 .append(S2meanrefA1_4อ[:,i].mean())
    S2hsvA3_106 .append(S2meanA3_106 [:,i].mean())

# %%
S2meanrefA1_506  = list()
S2meanA3_5106  = list()
for i in range(S1HSV_imgA1A3_56.shape[0]): 
     for j in range(S1HSV_imgA1A3_56.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_506 .append(S1HSV_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5106 .append(S1HSV_imgA1A3_56[i][j])  
S2meanrefA1_506  = np.array(S1meanrefA1_506 )
S2meanA3_5106  = np.array(S1meanA3_5106 )

S2hsvrefA1_506  = list()
S2hsvA3_5106  = list()
for i in range(3):
    S2hsvrefA1_506 .append(S2meanrefA1_506 [:,i].mean())
    S2hsvA3_5106.append(S2meanA3_5106 [:,i].mean())

# %%
S2meanrefA1_606  = list()
S2meanA4_106  = list()
for i in range(S1HSV_imgA1A4_6.shape[0]): 
     for j in range(S1HSV_imgA1A4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_606 .append(S1HSV_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_106 .append(S1HSV_imgA1A4_6[i][j])  
S2meanrefA1_606  = np.array(S2meanrefA1_606 )
S2meanA4_106  = np.array(S2meanA4_106 )

S2hsvrefA1_606  = list()
S2hsvA4_106  = list()
for i in range(3):
    S2hsvrefA1_606 .append(S2meanrefA1_606 [:,i].mean())
    S2hsvA4_106 .append(S2meanA4_106 [:,i].mean())

# %%
S2meanrefA1_706  = list()
S2meanB1_106  = list()
for i in range(S1HSV_imgA1B1_6.shape[0]): 
     for j in range(S1HSV_imgA1B1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_706 .append(S1HSV_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_106 .append(S1HSV_imgA1B1_6[i][j])  
S2meanrefA1_706  = np.array(S1meanrefA1_706 )
S2meanB1_106  = np.array(S1meanB1_106 )

S2hsvrefA1_706  = list()
S2hsvB1_106  = list()
for i in range(3):
    S2hsvrefA1_706 .append(S2meanrefA1_706 [:,i].mean())
    S2hsvB1_106 .append(S2meanB1_106 [:,i].mean())

# %%
S2meanrefA1_806  = list()
S2meanB2_106  = list()
for i in range(S1HSV_imgA1B2_6.shape[0]): 
     for j in range(S1HSV_imgA1B2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_8อ.append(S1HSV_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_106 .append(S1HSV_imgA1B2_6[i][j])  
S2meanrefA1_806 = np.array(S1meanrefA1_806 )
S2meanB2_106  = np.array(S1meanB2_106 )

S2hsvrefA1_806  = list()
S2hsvB2_106  = list()
for i in range(3):
    S2hsvrefA1_806 .append(S2meanrefA1_806 [:,i].mean())
    S2hsvB2_106 .append(S2meanB2_106 [:,i].mean())

# %%
S2meanrefA1_906  = list()
S2meanB3_106  = list()
for i in range(S1HSV_imgA1B3_6.shape[0]): 
     for j in range(S1HSV_imgA1B3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_906 .append(S1HSV_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_106 .append(S1HSV_imgA1B3_6[i][j])  
S2meanrefA1_906  = np.array(S1meanrefA1_906)
S2meanB3_106  = np.array(S1meanB3_106)

S2hsvrefA1_906 = list()
S2hsvB3_106 = list()
for i in range(3):
    S2hsvrefA1_906.append(S1meanrefA1_906[:,i].mean())
    S2hsvB3_106.append(S1meanB3_106[:,i].mean())

# %%
S2meanrefA1_1006 = list()
S2meanB4_106 = list()
for i in range(S1HSV_imgA1B4_6.shape[0]): 
     for j in range(S1HSV_imgA1B4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1006.append(S1HSV_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_106.append(S1HSV_imgA1B4_6[i][j])  
S2meanrefA1_1006 = np.array(S1meanrefA1_1006)
S2meanB4_106 = np.array(S1meanB4_106)

S2hsvrefA1_1006 = list()
S2hsvB4_106 = list()
for i in range(3):
    S2hsvrefA1_1006.append(S2meanrefA1_1006[:,i].mean())
    S2hsvB4_106.append(S2meanB4_106[:,i].mean())

# %%
S2meanrefA1_1106 = list()
S2meanC1_106 = list()
for i in range(S1HSV_imgA1C1_6.shape[0]): 
     for j in range(S1HSV_imgA1C1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1106.append(S1HSV_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_106.append(S1HSV_imgA1C1_6[i][j])  
S2meanrefA1_1106 = np.array(S1meanrefA1_1106)
S2meanC1_106 = np.array(S1meanC1_106)

S2hsvrefA1_1106 = list()
S2hsvC1_106 = list()
for i in range(3):
    S2hsvrefA1_1106.append(S1meanrefA1_1106[:,i].mean())
    S2hsvC1_106.append(S1meanC1_106[:,i].mean())

# %%
S2meanrefA1_1206 = list()
S2meanC2_106 = list()
for i in range(S1HSV_imgA1C2_6.shape[0]): 
     for j in range(S1HSV_imgA1C2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1206.append(S1HSV_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_106.append(S1HSV_imgA1C2_6[i][j])  
S2meanrefA1_1206 = np.array(S1meanrefA1_1206)
S2meanC2_106 = np.array(S1meanC2_106)

S2hsvrefA1_1206 = list()
S2hsvC2_106 = list()
for i in range(3):
    S2hsvrefA1_1206.append(S2meanrefA1_12[:,i].mean())
    S2hsvC2_106.append(S2meanC2_1[:,i].mean())

# %%
S2meanrefA1_1306 = list()
S2meanC3_106 = list()
for i in range(S1HSV_imgA1C3_6.shape[0]): 
     for j in range(S1HSV_imgA1C3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1306.append(S1HSV_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_106.append(S1HSV_imgA1C3_6[i][j])  
S2meanrefA1_1306 = np.array(S1meanrefA1_1306)
S2meanC3_106 = np.array(S1meanC3_106

S2hsvrefA1_1306 = list()
S2hsvC3_106 = list()
for i in range(3):
    S2hsvrefA1_1306.append(S2meanrefA1_1306[:,i].mean())
    S2hsvC3_106.append(S2meanC3_106[:,i].mean())

# %%
S2meanrefA1_1406 = list()
S2meanC4_106 = list()
for i in range(S1HSV_imgA1C4_6.shape[0]): 
     for j in range(S1HSV_imgA1C4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1406.append(S1HSV_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_106.append(S1HSV_imgA1C4_6[i][j])  
S2meanrefA1_1406 = np.array(S1meanrefA1_1406)
S2meanC4_106 = np.array(S1meanC4_106)

S2hsvrefA1_1406 = list()
S2hsvC4_106 = list()
for i in range(3):
    S2hsvrefA1_1406.append(S2meanrefA1_1406[:,i].mean())
    S2hsvC4_106.append(S2meanC4_106[:,i].mean())

# %%
S2meanrefA1_1506 = list()
S2meanD2_106 = list()
for i in range(S1HSV_imgA1D2_6.shape[0]): 
     for j in range(S1HSV_imgA1D2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1506.append(S1HSV_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_106.append(S1HSV_imgA1D2_6[i][j])  
S2meanrefA1_1506 = np.array(S1meanrefA1_1506)
S2meanD2_106 = np.array(S1meanD2_106)

S2hsvrefA1_1506 = list()
S2hsvD2_106 = list()
for i in range(3):
    S2hsvrefA1_1506.append(S2meanrefA1_1506[:,i].mean())
    S2hsvD2_106.append(S2meanD2_106[:,i].mean())

# %%
S2meanrefA1_1606 = list()
S2meanD3_106 = list()
for i in range(S1HSV_imgA1D3_6.shape[0]): 
     for j in range(S1HSV_imgA1D3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1606.append(S1HSV_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_106.append(S1HSV_imgA1D3_6[i][j])  
S2meanrefA1_1606 = np.array(S1meanrefA1_1606)
S2meanD3_106 = np.array(S1meanD3_106)

S2hsvrefA1_1606 = list()
S2hsvD3_106 = list()
for i in range(3):
    S2hsvrefA1_1606.append(S2meanrefA1_1606[:,i].mean())
    S2hsvD3_1v.append(S2meanD3_106[:,i].mean())

# %%
S2meanrefA1_1706= list()
S2meanD4_106 = list()
for i in range(S1HSV_imgA1D4_6.shape[0]): 
     for j in range(S1HSV_imgA1D4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1706.append(S1HSV_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_106.append(S1HSV_imgA1D4_6[i][j])  
S2meanrefA1_1706 = np.array(S1meanrefA1_1406)
S2meanD4_106 = np.array(S1meanD4_106)

S2hsvrefA1_1706 = list()
S2hsvD4_10606 = list()
for i in range(3):
    S2hsvrefA1_1706.append(S2meanrefA1_1706[:,i].mean())
    S2hsvD4_106.append(S2meanD4_106[:,i].mean())

# %% [markdown]
# ###Img 7

# %%
S2meanrefA1_107 = list()
S2meanA1_207 = list()
for i in range(S1HSV_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_107.append(S1HSV_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_207.append(S1HSV_imgA1A1_7[i][j])  
S2meanrefA1_107 = np.array(S1meanrefA1_107)
S2meanA1_207 = np.array(SmeanA1_207)

S1hsvrefA1_107 = list()
S1hsvA1_207 = list()
for i in range(3):
    S2hsvrefA1_107.append(S2meanrefA1_107[:,i].mean())
    S2hsvA1_207.append(S2meanA1_207[:,i].mean())
S2hsvrefA1_107,S2hsvA1_207

# %%
S2meanrefA1_307 = list()
S2meanA2_107 = list()
for i in range(S1HSV_imgA1A2_7.shape[0]): 
     for j in range(S1HSV_imgA1A2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_307.append(S1HSV_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_107.append(S1HSV_imgA1A2_7[i][j])  
S2meanrefA1_307 = np.array(S2meanrefA1_307)
S2meanA2_107 = np.array(S2meanA2_1v)

S2hsvrefA1_307 = list()
S2hsvA2_107 = list()
for i in range(3):
    S2hsvrefA1_307.append(S2meanrefA1_307[:,i].mean())
    S2hsvA2_107.append(S2meanA2_107[:,i].mean())

# %%
S2meanrefA1_407 = list()
S2meanA3_107 = list()
for i in range(S1HSV_imgA1A3_7.shape[0]): 
     for j in range(S1HSV_imgA1A3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_407.append(S1HSV_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_107.append(S1HSV_imgA1A3_7[i][j])  
S2meanrefA1_407 = np.array(S2meanrefA1_407)
S2meanA3_107 = np.array(S2meanA3_107)

S2hsvrefA1_407 = list()
S2hsvA3_107 = list()
for i in range(3):
    S2hsvrefA1_407.append(S2meanrefA1_407[:,i].mean())
    S2hsvA3_107.append(S2meanA3_107[:,i].mean())

# %%
S2meanrefA1_507 = list()
S2meanA3_5107 = list()
for i in range(S1HSV_imgA1A3_5707.shape[0]): 
     for j in range(S1HSV_imgA1A3_57.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_507.append(S1HSV_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5107.append(S1HSV_imgA1A3_57[i][j])  
S2meanrefA1_5v = np.array(S2meanrefA1_5v)
S2meanA3_5107 = np.array(S2meanA3_5107)

S2hsvrefA1_507 = list()
S2hsvA3_5107 = list()
for i in range(3):
    S2hsvrefA1_507.append(S2meanrefA1_507[:,i].mean())
    S2hsvA3_5107.append(S2meanA3_5107[:,i].mean())

# %%
S2meanrefA1_607 = list()
S2meanA4_107 = list()
for i in range(S1HSV_imgA1A4_7.shape[0]): 
     for j in range(S1HSV_imgA1A4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_607.append(S1HSV_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_107.append(S1HSV_imgA1A4_7[i][j])  
S2meanrefA1_607 = np.array(S2meanrefA1_607)
S2meanA4_1v = np.array(S2meanA4_107)

S2hsvrefA1_607 = list()
S2hsvA4_107 = list()
for i in range(3):
    S2hsvrefA1_607.append(S2meanrefA1_607[:,i].mean())
    S2hsvA4_107.append(S2meanA4_107[:,i].mean())

# %%
S2meanrefA1_707 = list()
S2meanB1_107 = list()
for i in range(S1HSV_imgA1B1_7.shape[0]): 
     for j in range(S1HSV_imgA1B1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_707.append(S1HSV_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_107.append(S1HSV_imgA1B1_7[i][j])  
S2meanrefA1_707 = np.array(S2meanrefA1_7)
S2meanB1_107= np.array(S2meanB1_1)

S2hsvrefA1_707 = list()
S2hsvB1_107 = list()
for i in range(3):
    S2hsvrefA1_707.append(S2meanrefA1_707[:,i].mean())
    S2hsvB1_107.append(S2meanB1_107[:,i].mean())

# %%
S2meanrefA1_807 = list()
S2meanB2_107 = list()
for i in range(S1HSV_imgA1B2_7.shape[0]): 
     for j in range(S1HSV_imgA1B2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_807.append(S1HSV_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_107.append(S1HSV_imgA1B2_7[i][j])  
S2meanrefA1_807 = np.array(S2meanrefA1_807)
S2meanB2_107 = np.array(S2meanB2_107)

S2hsvrefA1_807 = list()
S2hsvB2_107 = list()
for i in range(3):
    S2hsvrefA1_807.append(S2meanrefA1_807[:,i].mean())
    S2hsvB2_107.append(S2meanB2_107[:,i].mean())

# %%
S2eanrefA1_907 = list()
S2meanB3_107 = list()
for i in range(S1HSV_imgA1B3_7.shape[0]): 
     for j in range(S1HSV_imgA1B3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_907.append(S1HSV_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_107.append(S1HSV_imgA1B3_7[i][j])  
S2meanrefA1_907= np.array(S2meanrefA1_907)
S2meanB3_107 = np.array(S2meanB3_107)

S2hsvrefA1_907 = list()
S2hsvB3_107 = list()
for i in range(3):
    S2hsvrefA1_907.append(S2meanrefA1_907[:,i].mean())
    S2hsvB3_107.append(S2meanB3_107[:,i].mean())

# %%
S2meanrefA1_1007 = list()
S2meanB4_107 = list()
for i in range(S1HSV_imgA1B4_7.shape[0]): 
     for j in range(S1HSV_imgA1B4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1007.append(S1HSV_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_107.append(S1HSV_imgA1B4_7[i][j])  
S2meanrefA1_1007= np.array(S1meanrefA1_1007)
S2meanB4_107 = np.array(S1meanB4_107)

S2hsvrefA1_1007 = list()
S2hsvB4_107 = list()
for i in range(3):
    S2hsvrefA1_1007.append(S2meanrefA1_1007[:,i].mean())
    S2hsvB4_107.append(S2meanB4_107[:,i].mean())

# %%
S2meanrefA1_1107 = list()
S2meanC1_1v = list()
for i in range(S1HSV_imgA1C1_7.shape[0]): 
     for j in range(S1HSV_imgA1C1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1107.append(S1HSV_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_107.append(S1HSV_imgA1C1_7[i][j])  
S2meanrefA1_1107= np.array(S2meanrefA1_1107)
S2meanC1_107 = np.array(S2meanC1_107)

S2hsvrefA1_1107 = list()
S2hsvC1_107 = list()
for i in range(3):
    S2hsvrefA1_1107.append(S2meanrefA1_1107[:,i].mean())
    S2hsvC1_107.append(S2meanC1_107[:,i].mean())

# %%
S2meanrefA1_1207 = list()
S2meanC2_107 = list()
for i in range(S1HSV_imgA1C2_7.shape[0]): 
     for j in range(S1HSV_imgA1C2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1207.append(S1HSV_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_107.append(S1HSV_imgA1C2_7[i][j])  
S2meanrefA1_1207 = np.array(S2meanrefA1_1207)
S2meanC2_107 = np.array(S2meanC2_107)

S2hsvrefA1_1207 = list()
S2hsvC2_107 = list()
for i in range(3):
    S2hsvrefA1_1207.append(S2meanrefA1_12v[:,i].mean())
    S2hsvC2_107.append(S2meanC2_107[:,i].mean())

# %%
S2meanrefA1_1307 = list()
S2meanC3_107 = list()
for i in range(S1HSV_imgA1C3_7.shape[0]): 
     for j in range(S1HSV_imgA1C3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1307.append(S1HSV_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_107.append(S1HSV_imgA1C3_7[i][j])  
S2meanrefA1_1307 = np.array(S1meanrefA1_1307)
S2meanC3_107 = np.array(S1meanC3_107)

S2hsvrefA1_1307 = list()
S2hsvC3_107 = list()
for i in range(3):
    S2hsvrefA1_1307.append(S2meanrefA1_1307[:,i].mean())
    S2hsvC3_107.append(S2meanC3_107[:,i].mean())

# %%
S2meanrefA1_1407 = list()
S2meanC4_107 = list()
for i in range(S1HSV_imgA1C4_7.shape[0]): 
     for j in range(S1HSV_imgA1C4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1407.append(S1HSV_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_107.append(S1HSV_imgA1C4_7[i][j])  
S2meanrefA1_1407 = np.array(S2meanrefA1_1407)
S2meanC4_107 = np.array(S2meanC4_107)

S2hsvrefA1_1407 = list()
S2hsvC4_107 = list()
for i in range(3):
    S2hsvrefA1_1407.append(S2meanrefA1_1407[:,i].mean())
    S2hsvC4_107.append(S2meanC4_107[:,i].mean())

# %%
S2meanrefA1_1507 = list()
S2meanD2_107 = list()
for i in range(S1HSV_imgA1D2_7.shape[0]): 
     for j in range(S1HSV_imgA1D2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1507.append(S1HSV_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_107.append(S1HSV_imgA1D2_7[i][j])  
S2meanrefA1_1507 = np.array(S2meanrefA1_1507)
S2meanD2_107 = np.array(S2meanD2_107)

S2hsvrefA1_1507= list()
S2hsvD2_107 = list()
for i in range(3):
    S2hsvrefA1_1507.append(S2meanrefA1_1507[:,i].mean())
    S2hsvD2_107.append(S2meanD2_107[:,i].mean())

# %%
S2meanrefA1_1607 = list()
S2meanD3_107 = list()
for i in range(S1HSV_imgA1D3_7.shape[0]): 
     for j in range(S1HSV_imgA1D3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1607.append(S1HSV_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_107.append(S1HSV_imgA1D3_7[i][j])  
S2meanrefA1_1607 = np.array(S2meanrefA1_1607)
S2meanD3_107 = np.array(S2meanD3_107)

S2hsvrefA1_1607 = list()
S2hsvD3_107 = list()
for i in range(3):
    S2hsvrefA1_1607.append(S2meanrefA1_1607[:,i].mean())
    S2hsvD3_107.append(S2meanD3_107[:,i].mean())

# %%
S2meanrefA1_1707= list()
S2meanD4_107 = list()
for i in range(S1HSV_imgA1D4_7.shape[0]): 
     for j in range(S1HSV_imgA1D4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1707.append(S1HSV_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_107.append(S1HSV_imgA1D4_7[i][j])  
S2meanrefA1_1707 = np.array(S2meanrefA1_1407)
S2meanD4_107 = np.array(S2meanD4_107,;)

S2hsvrefA1_1707 = list()
S2hsvD4_107 = list()
for i in range(3):
    S2hsvrefA1_1707.append(S2meanrefA1_1707[:,i].mean())
    S2hsvD4_107.append(S2meanD4_107[:,i].mean())

# %% [markdown]
# ###Img 8

# %%
S2meanrefA1_108 = list()
S2meanA1_208 = list()
for i in range(S1HSV_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_108.append(S1HSV_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_208.append(S1HSV_imgA1A1_8[i][j])  
S2meanrefA1_108 = np.array(S2meanrefA1_108)
S2meanA1_208 = np.array(S2meanA1_208)

S2hsvrefA1_108 = list()
S2hsvA1_208 = list()
for i in range(3):
    S2hsvrefA1_108.append(S2meanrefA1_108[:,i].mean())
    S2hsvA1_208.append(S2meanA1_208[:,i].mean())
S2hsvrefA1_108,S2hsvA1_208

# %%
S2meanrefA1_308 = list()
S2meanA2_108 = list()
for i in range(S1HSV_imgA1A2_8.shape[0]): 
     for j in range(S1HSV_imgA1A2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_308.append(S1HSV_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_108.append(S1HSV_imgA1A2_8[i][j])  
S2meanrefA1_308 = np.array(S2meanrefA1_308)
S2meanA2_108 = np.array(S2meanA2_108)

S2hsvrefA1_308 = list()
S2hsvA2_108 = list()
for i in range(3):
    S2hsvrefA1_308.append(S2meanrefA1_308[:,i].mean())
    S2hsvA2_108.append(S2meanA2_108[:,i].mean())

# %%
S2meanrefA1_408 = list()
S2meanA3_108 = list()
for i in range(S1HSV_imgA1A3_8.shape[0]): 
     for j in range(S1HSV_imgA1A3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_408.append(S1HSV_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_108.append(S1HSV_imgA1A3_8[i][j])  
S2meanrefA1_408 = np.array(S2meanrefA1_408)
S2meanA3_108 = np.array(S2meanA3_108)

S2hsvrefA1_408 = list()
S2hsvA3_108 = list()
for i in range(3):
    S2hsvrefA1_408.append(S2meanrefA1_408[:,i].mean())
    S2hsvA3_108.append(S2meanA3_108[:,i].mean())

# %%
S2meanrefA1_5v = list()
S2meanA3_5108 = list()
for i in range(S1HSV_imgA1A3_58.shape[0]): 
     for j in range(S1HSV_imgA1A3_58.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_508.append(S1HSV_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5108.append(S1HSV_imgA1A3_58[i][j])  
S2meanrefA1_508 = np.array(S2meanrefA1_508)
S2meanA3_5108 = np.array(S2meanA3_5108)

S2hsvrefA1_508 = list()
S2hsvA3_5108 = list()
for i in range(3):
    S2hsvrefA1_508.append(S2meanrefA1_508[:,i].mean())
    S2hsvA3_5108.append(S2meanA3_5108[:,i].mean())

# %%
S2meanrefA1_608 = list()
S2meanA4_108 = list()
for i in range(S1HSV_imgA1A4_8.shape[0]): 
     for j in range(S1HSV_imgA1A4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_608.append(S1HSV_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_108.append(S1HSV_imgA1A4_8[i][j])  
S2meanrefA1_608 = np.array(S2meanrefA1_608)
S2meanA4_108 = np.array(S2meanA4_108)

S2hsvrefA1_608 = list()
S2hsvA4_108= list()
for i in range(3):
    S2hsvrefA1_608.append(S2meanrefA1_608[:,i].mean())
    S2hsvA4_108.append(S2meanA4_108[:,i].mean())

# %%
S2meanrefA1_708 = list()
S2meanB1_108 = list()
for i in range(S1HSV_imgA1B1_8.shape[0]): 
     for j in range(S1HSV_imgA1B1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_708.append(S1HSV_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_108.append(S1HSV_imgA1B1_8[i][j])  
S2meanrefA1_708 = np.array(S2meanrefA1_708)
S2meanB1_108 = np.array(S2meanB1_108)

S2hsvrefA1_708 = list()
S2hsvB1_108 = list()
for i in range(3):
    S2hsvrefA1_708.append(S2meanrefA1_708[:,i].mean())
    S2hsvB1_108.append(S2meanB1_108[:,i].mean())

# %%
S2meanrefA1_808 = list()
S2meanB2_108 = list()
for i in range(S1HSV_imgA1B2_8.shape[0]): 
     for j in range(S1HSV_imgA1B2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_808.append(S1HSV_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_108.append(S1HSV_imgA1B2_8[i][j])  
S2meanrefA1_808 = np.array(S2meanrefA1_808)
S2meanB2_108 = np.array(S2meanB2_108)

S2hsvrefA1_808 = list()
S2hsvB2_108 = list()
for i in range(3):
    S2hsvrefA1_808.append(S2meanrefA1_808[:,i].mean())
    S2hsvB2_108.append(S2meanB2_108[:,i].mean())

# %%
S2meanrefA1_908 = list()
S2meanB3_108 = list()
for i in range(S1HSV_imgA1B3_8.shape[0]): 
     for j in range(S1HSV_imgA1B3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_908.append(S1HSV_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_108.append(S1HSV_imgA1B3_8[i][j])  
S2meanrefA1_908 = np.array(S2meanrefA1_908)
S2meanB3_108 = np.array(S2meanB3_108)

S2hsvrefA1_908 = list()
S2hsvB3_108 = list()
for i in range(3):
    S2hsvrefA1_908.append(S2meanrefA1_908[:,i].mean())
    S2hsvB3_108.append(S2meanB3_108[:,i].mean())

# %%
S2meanrefA1_1008 = list()
S2meanB4_108 = list()
for i in range(S1HSV_imgA1B4_8.shape[0]): 
     for j in range(S1HSV_imgA1B4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1008.append(S1HSV_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_108.append(S1HSV_imgA1B4_8[i][j])  
S2meanrefA1_1008 = np.array(S2meanrefA1_1008)
S2meanB4_108 = np.array(S2meanB4_108)

S2hsvrefA1_1008 = list()
S2hsvB4_108 = list()
for i in range(3):
    S2hsvrefA1_1008.append(S2meanrefA1_1008[:,i].mean())
    S2hsvB4_108.append(S2meanB4_108[:,i].mean())

# %%
S2meanrefA1_1108 = list()
S2meanC1_108 = list()
for i in range(S1HSV_imgA1C1_8.shape[0]): 
     for j in range(S1HSV_imgA1C1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1108.append(S1HSV_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_108.append(S1HSV_imgA1C1_8[i][j])  
S2meanrefA1_1108 = np.array(S2meanrefA1_1108)
S2meanC1_108 = np.array(S2meanC1_108)

S2hsvrefA1_1108 = list()
S2hsvC1_108 = list()
for i in range(3):
    S2hsvrefA1_1108.append(S2meanrefA1_1108[:,i].mean())
    S2hsvC1_108.append(S2meanC1_108[:,i].mean())

# %%
S2meanrefA1_1208 = list()
S2meanC2_108 = list()
for i in range(S1HSV_imgA1C2_808.shape[0]): 
     for j in range(S1HSV_imgA1C2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1208.append(S1HSV_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_108.append(S1HSV_imgA1C2_8[i][j])  
S2meanrefA1_12v = np.array(S2meanrefA1_1208)
S2meanC2_108 = np.array(S2meanC2_108)

S2hsvrefA1_12v = list()
S2hsvC2_108 = list()
for i in range(3):
    S2hsvrefA1_1208.append(S2meanrefA1_1208[:,i].mean())
    S2hsvC2_108.append(S2meanC2_108[:,i].mean())

# %%
S2meanrefA1_1308 = list()
S2meanC3_108 = list()
for i in range(S1HSV_imgA1C3_8.shape[0]): 
     for j in range(S1HSV_imgA1C3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1308.append(S1HSV_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_108.append(S1HSV_imgA1C3_8[i][j])  
S2meanrefA1_1308 = np.array(S2meanrefA1_1308)
S2meanC3_108 = np.array(S2meanC3_108)

S2hsvrefA1_1308 = list()
S2hsvC3_108 = list()
for i in range(3):
    S2hsvrefA1_1308.append(S2meanrefA1_1308[:,i].mean())
    S2hsvC3_108.append(S2meanC3_108[:,i].mean())

# %%
S2meanrefA1_1408 = list()
S2meanC4_108 = list()
for i in range(S1HSV_imgA1C4_8.shape[0]): 
     for j in range(S1HSV_imgA1C4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1408.append(S1HSV_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_108.append(S1HSV_imgA1C4_8[i][j])  
S2meanrefA1_1408 = np.array(S2meanrefA1_1408)
S2meanC4_108 = np.array(S2meanC4_108)

S2hsvrefA1_1408 = list()
S2hsvC4_108= list()
for i in range(3):
    S2hsvrefA1_1408.append(S2meanrefA1_1408[:,i].mean())
    S2hsvC4_108.append(S2meanC4_108[:,i].mean())

# %%
S2meanrefA1_1508 = list()
S2meanD2_108 = list()
for i in range(S1HSV_imgA1D2_8.shape[0]): 
     for j in range(S1HSV_imgA1D2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1508.append(S1HSV_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_108.append(S1HSV_imgA1D2_8[i][j])  
S2meanrefA1_1508 = np.array(S2meanrefA1_1508)
S2meanD2_108 = np.array(S2meanD2_108)

S2hsvrefA1_1508 = list()
S2hsvD2_108 = list()
for i in range(3):
    S2hsvrefA1_1508.append(S2meanrefA1_1508[:,i].mean())
    S2hsvD2_108.append(S2meanD2_108[:,i].mean())

# %%
S2meanrefA1_1608 = list()
S2meanD3_108 = list()
for i in range(S1HSV_imgA1D3_8.shape[0]): 
     for j in range(S1HSV_imgA1D3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1608.append(S1HSV_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_108.append(S1HSV_imgA1D3_8[i][j])  
S2meanrefA1_1608 = np.array(S2meanrefA1_1608)
S2meanD3_108 = np.array(S2meanD3_108)

S2hsvrefA1_1608 = list()
S2hsvD3_108 = list()
for i in range(3):
    S2hsvrefA1_1608.append(S2meanrefA1_1608[:,i].mean())
    S2hsvD3_108.append(S2meanD3_108[:,i].mean())

# %%
S2meanrefA1_1708= list()
S2meanD4_108 = list()
for i in range(S1HSV_imgA1D4_8.shape[0]): 
     for j in range(S1HSV_imgA1D4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1708.append(S1HSV_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_108.append(S1HSV_imgA1D4_8[i][j])  
S2meanrefA1_1708= np.array(S2meanrefA1_1408)
S2meanD4_108 = np.array(S2meanD4_108)

S2hsvrefA1_1708 = list()
S2hsvD4_108 = list()
for i in range(3):
    S2hsvrefA1_1708.append(S2meanrefA1_1708[:,i].mean())
    S2hsvD4_108.append(S2meanD4_108[:,i].mean())

# %% [markdown]
# ###Img 9

# %%
S2meanrefA1_109 = list()
S2meanA1_209 = list()
for i in range(S1HSV_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_109.append(S1HSV_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_209.append(S1HSV_imgA1A1_9[i][j])  
S2meanrefA1_109 = np.array(S2meanrefA1_109)
S2meanA1_209 = np.array(S2meanA1_209)

S2hsvrefA1_109 = list()
S2hsvA1_209 = list()
for i in range(3):
    S2hsvrefA1_109.append(S2meanrefA1_109[:,i].mean())
    S2hsvA1_209.append(S2meanA1_209[:,i].mean())
S2hsvrefA1_109,S2hsvA1_209

# %%
S2meanrefA1_309 = list()
S2meanA2_109 = list()
for i in range(S1HSV_imgA1A2_9.shape[0]): 
     for j in range(S1HSV_imgA1A2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_309.append(S1HSV_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_109.append(S1HSV_imgA1A2_9[i][j])  
S2meanrefA1_309 = np.array(S2meanrefA1_309)
S2meanA2_109 = np.array(S2meanA2_109)

S2hsvrefA1_309 = list()
S2hsvA2_109 = list()
for i in range(3):
    S2hsvrefA1_309.append(S2meanrefA1_309[:,i].mean())
    S2hsvA2_109.append(S2meanA2_109[:,i].mean())

# %%
S2meanrefA1_409 = list()
S2meanA3_109 = list()
for i in range(S1HSV_imgA1A3_9.shape[0]): 
     for j in range(S1HSV_imgA1A3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_409.append(S1HSV_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_109.append(S1HSV_imgA1A3_9[i][j])  
S2meanrefA1_409 = np.array(S2meanrefA1_409
S2meanA3_109 = np.array(S2meanA3_109)

S2hsvrefA1_409= list()
S2hsvA3_109 = list()
for i in range(3):
    S2hsvrefA1_409.append(S2meanrefA1_409[:,i].mean())
    S2hsvA3_109.append(S2meanA3_109[:,i].mean())

# %%
S2meanrefA1_509 = list()
S2meanA3_5109 = list()
for i in range(S1HSV_imgA1A3_59.shape[0]): 
     for j in range(S1HSV_imgA1A3_59.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_509.append(S1HSV_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5109.append(S1HSV_imgA1A3_59[i][j])  
S2meanrefA1_509 = np.array(S2meanrefA1_509)
S2meanA3_5109 = np.array(S2meanA3_5109)

S2hsvrefA1_509 = list()
S2hsvA3_5109 = list()
for i in range(3):
    S2hsvrefA1_509.append(S2meanrefA1_509[:,i].mean())
    S2hsvA3_5109.append(S2meanA3_5109[:,i].mean())

# %%
S2meanrefA1_609 = list()
S2meanA4_109 = list()
for i in range(S1HSV_imgA1A4_9.shape[0]): 
     for j in range(S1HSV_imgA1A4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_609.append(S1HSV_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_109.append(S1HSV_imgA1A4_9[i][j])  
S2meanrefA1_609 = np.array(S2meanrefA1_609)
S2meanA4_109 = np.array(S2meanA4_109)

S2hsvrefA1_609 = list()
S2hsvA4_109 = list()
for i in range(3):
    S2hsvrefA1_609.append(S2meanrefA1_609[:,i].mean())
    S2hsvA4_109.append(S2meanA4_109[:,i].mean())

# %%
S2meanrefA1_709 = list()
S2meanB1_109 = list()
for i in range(S1HSV_imgA1B1_9.shape[0]): 
     for j in range(S1HSV_imgA1B1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_709.append(S1HSV_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_109.append(S1HSV_imgA1B1_9[i][j])  
S2meanrefA1_709 = np.array(S2meanrefA1_709)
S2meanB1_109 = np.array(S2meanB1_109)

S2hsvrefA1_709 = list()
S2hsvB1_109 = list()
for i in range(3):
    S2hsvrefA1_709.append(S2meanrefA1_709[:,i].mean())
    S2hsvB1_109.append(S2meanB1_109[:,i].mean())

# %%
S2meanrefA1_809 = list()
S2meanB2_109= list()
for i in range(S1HSV_imgA1B2_9.shape[0]): 
     for j in range(S1HSV_imgA1B2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_809.append(S1HSV_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_109.append(S1HSV_imgA1B2_9[i][j])  
S2meanrefA1_809 = np.array(S2meanrefA1_809)
S2meanB2_109 = np.array(S2meanB2_109)

S2hsvrefA1_809 = list()
S2hsvB2_109 = list()
for i in range(3):
    S2hsvrefA1_809.append(S2meanrefA1_809[:,i].mean())
    S2hsvB2_109.append(S2meanB2_109[:,i].mean())

# %%
S2meanrefA1_909 = list()
S2meanB3_109 = list()
for i in range(S1HSV_imgA1B3_9.shape[0]): 
     for j in range(S1HSV_imgA1B3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_909.append(S1HSV_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_109.append(S1HSV_imgA1B3_9[i][j])  
S2meanrefA1_909 = np.array(S2meanrefA1_909)
S2meanB3_109 = np.array(S2meanB3_109)

S2hsvrefA1_909 = list()
S2hsvB3_109 = list()
for i in range(3):
    S2hsvrefA1_909.append(S2meanrefA1_909[:,i].mean())
    S2hsvB3_109.append(S2meanB3_109[:,i].mean())

# %%
S2meanrefA1_1009 = list()
S2meanB4_109 = list()
for i in range(S1HSV_imgA1B4_9.shape[0]): 
     for j in range(S1HSV_imgA1B4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1009.append(S1HSV_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_109.append(S1HSV_imgA1B4_9[i][j])  
S2meanrefA1_1009= np.array(S2meanrefA1_1009)
S2meanB4_109 = np.array(S2meanB4_109)

S2hsvrefA1_1009 = list()
S2hsvB4_109 = list()
for i in range(3):
    S2hsvrefA1_1009.append(S2meanrefA1_1009[:,i].mean())
    S2hsvB4_109.append(S2meanB4_109[:,i].mean())

# %%
S2meanrefA1_1109 = list()
S2meanC1_109 = list()
for i in range(S1HSV_imgA1C1_9.shape[0]): 
     for j in range(S1HSV_imgA1C1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1109.append(S1HSV_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_109.append(S1HSV_imgA1C1_9[i][j])  
S2meanrefA1_1109 = np.array(S2meanrefA1_1109)
S2meanC1_109 = np.array(S2meanC1_109)

S2hsvrefA1_1109 = list()
S2hsvC1_109 = list()
for i in range(3):
    S2hsvrefA1_1109.append(S2meanrefA1_1109[:,i].mean())
    S2hsvC1_109.append(S2meanC1_109[:,i].mean())

# %%
S2meanrefA1_1209 = list()
S2meanC2_109 = list()
for i in range(S1HSV_imgA1C2_909.shape[0]): 
     for j in range(S1HSV_imgA1C2_909.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1209.append(S1HSV_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_109.append(S1HSV_imgA1C2_9[i][j])  
S2meanrefA1_1209 = np.array(S2meanrefA1_1209)
S2meanC2_109 = np.array(S2meanC2_109)

S2hsvrefA1_1209 = list()
S2hsvC2_109= list()
for i in range(3):
    S2hsvrefA1_1209.append(S2meanrefA1_1209[:,i].mean())
    S2hsvC2_109.append(S2meanC2_109[:,i].mean())

# %%
S2meanrefA1_1309 = list()
S2meanC3_109 = list()
for i in range(S1HSV_imgA1C3_9.shape[0]): 
     for j in range(S1HSV_imgA1C3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1309.append(S1HSV_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_109.append(S1HSV_imgA1C3_9[i][j])  
S2meanrefA1_1309 = np.array(S2meanrefA1_1309)
S2meanC3_109 = np.array(S2meanC3_109)

S2hsvrefA1_1309 = list()
S2hsvC3_109 = list()
for i in range(3):
    S2hsvrefA1_1309.append(S2meanrefA1_1309[:,i].mean())
    S2hsvC3_109.append(S2meanC3_109[:,i].mean())

# %%
S2meanrefA1_1409 = list()
S2meanC4_109 = list()
for i in range(S1HSV_imgA1C4_9.shape[0]): 
     for j in range(S1HSV_imgA1C4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1409.append(S1HSV_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_109.append(S1HSV_imgA1C4_9[i][j])  
S2meanrefA1_1409 = np.array(S1meanrefA1_1409)
S2meanC4_109 = np.array(S1meanC4_109)

S2hsvrefA1_1409 = list()
S2hsvC4_109 = list()
for i in range(3):
    S2hsvrefA1_1409.append(S2meanrefA1_1409[:,i].mean())
    S2hsvC4_109.append(S2meanC4_109[:,i].mean())

# %%
S2meanrefA1_1509 = list()
S2meanD2_1v = list()
for i in range(S1HSV_imgA1D2_9.shape[0]): 
     for j in range(S1HSV_imgA1D2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1509.append(S1HSV_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_109.append(S1HSV_imgA1D2_9[i][j])  
S2meanrefA1_1509 = np.array(S2meanrefA1_1509)
S2meanD2_109 = np.array(S2meanD2_109)

S2hsvrefA1_1509 = list()
S2hsvD2_109 = list()
for i in range(3):
    S2hsvrefA1_1509.append(S2meanrefA1_1509[:,i].mean())
    S2hsvD2_109.append(S2meanD2_109[:,i].mean())

# %%
S2meanrefA1_1609 = list()
S2meanD3_109 = list()
for i in range(S1HSV_imgA1D3_9.shape[0]): 
     for j in range(S1HSV_imgA1D3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1609.append(S1HSV_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_109.append(S1HSV_imgA1D3_9[i][j])  
S2meanrefA1_1609 = np.array(S2meanrefA1_1609)
S2meanD3_109= np.array(S2meanD3_109)

S2hsvrefA1_1609 = list()
S2hsvD3_109 = list()
for i in range(3):
    S2hsvrefA1_1609.append(S2meanrefA1_1609[:,i].mean())
    S2hsvD3_109.append(S2meanD3_109[:,i].mean())

# %%
S2meanrefA1_1709= list()
S2meanD4_109 = list()
for i in range(S1HSV_imgA1D4_9.shape[0]): 
     for j in range(S1HSV_imgA1D4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1709.append(S1HSV_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_109.append(S1HSV_imgA1D4_9[i][j])  
S2meanrefA1_1709 = np.array(S1meanrefA1_1409)
S2meanD4_109 = np.array(S1meanD4_109)

S2hsvrefA1_17v = list()
S2hsvD4_109 = list()
for i in range(3):
    S2hsvrefA1_1709.append(S2meanrefA1_1709[:,i].mean())
    S2hsvD4_109.append(S2meanD4_109[:,i].mean())

# %% [markdown]
# ###Img 10

# %%
S2meanrefA1_110 = list()
S2meanA1_210 = list()
for i in range(S1HSV_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S1HSV_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_110.append(S1HSV_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA1_210.append(S1HSV_imgA1A1_10[i][j])  
S2meanrefA1_110 = np.array(S1meanrefA1_110)
S2meanA1_210 = np.array(S1meanA1_210)

S2hsvrefA1_110 = list()
S2hsvA1_210 = list()
for i in range(3):
    S2hsvrefA1_110.append(S1meanrefA1_110[:,i].mean())
    S2hsvA1_210.append(S1meanA1_210[:,i].mean())
S2hsvrefA1_110,S2hsvA1_210

# %%
S2meanrefA1_310 = list()
S2meanA2_110 = list()
for i in range(S1HSV_imgA1A2_10.shape[0]): 
     for j in range(S1HSV_imgA1A2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_310.append(S1HSV_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_110.append(S1HSV_imgA1A2_10[i][j])  
S2meanrefA1_310 = np.array(S2meanrefA1_310)
S2meanA2_110 = np.array(S2meanA2_110)

S2hsvrefA1_310 = list()
S2hsvA2_110 = list()
for i in range(3):
    S2hsvrefA1_310.append(S2meanrefA1_310[:,i].mean())
    S2hsvA2_110.append(S2meanA2_110[:,i].mean())

# %%
S2meanrefA1_410 = list()
S2meanA3_110 = list()
for i in range(S1HSV_imgA1A3_10.shape[0]): 
     for j in range(S1HSV_imgA1A3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_410.append(S1HSV_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_110.append(S1HSV_imgA1A3_10[i][j])  
S2meanrefA1_410 = np.array(S2meanrefA1_410)
S2meanA3_110 = np.array(S2meanA3_110)

S2hsvrefA1_410 = list()
S2hsvA3_110 = list()
for i in range(3):
    S2hsvrefA1_410.append(S2meanrefA1_410[:,i].mean())
    S2hsvA3_110.append(S2meanA3_110[:,i].mean())

# %%
S2meanrefA1_510 = list()
S2meanA3_5110 = list()
for i in range(S1HSV_imgA1A3_510.shape[0]): 
     for j in range(S1HSV_imgA1A3_510.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_510.append(S1HSV_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5110.append(S1HSV_imgA1A3_510[i][j])  
S2meanrefA1_510 = np.array(S2meanrefA1_5v)
S2meanA3_5110 = np.array(S2meanA3_5110)

S2hsvrefA1_510 = list()
S2hsvA3_5110 = list()
for i in range(3):
    S2hsvrefA1_510.append(S2meanrefA1_510[:,i].mean())
    S2hsvA3_5110.append(S2meanA3_5110[:,i].mean())

# %%
S2meanrefA1_610 = list()
S2meanA4_110 = list()
for i in range(S1HSV_imgA1A4_10.shape[0]): 
     for j in range(S1HSV_imgA1A4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_610.append(S1HSV_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA4_110.append(S1HSV_imgA1A4_10[i][j])  
S2meanrefA1_610 = np.array(S2meanrefA1_610)
S2meanA4_110 = np.array(S2meanA4_110)

S2hsvrefA1_610 = list()
S2hsvA4_110 = list()
for i in range(3):
    S2hsvrefA1_610.append(S2meanrefA1_610[:,i].mean())
    S2hsvA4_110.append(S2meanA4_110[:,i].mean())

# %%
S2meanrefA1_710 = list()
S2meanB1_110 = list()
for i in range(S1HSV_imgA1B1_10.shape[0]): 
     for j in range(S1HSV_imgA1B1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_710.append(S1HSV_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB1_110.append(S1HSV_imgA1B1_10[i][j])  
S2meanrefA1_710 = np.array(S2meanrefA1_710)
S2meanB1_110 = np.array(S2meanB1_110)

S2hsvrefA1_710 = list()
S2hsvB1_110 = list()
for i in range(3):
    S2hsvrefA1_710.append(S2meanrefA1_710[:,i].mean())
    S2hsvB1_110.append(S2meanB1_110[:,i].mean())

# %%
S2meanrefA1_810 = list()
S2meanB2_110 = list()
for i in range(S1HSV_imgA1B2_1010.shape[0]): 
     for j in range(S1HSV_imgA1B2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_810.append(S1HSV_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB2_110.append(S1HSV_imgA1B2_10[i][j])  
S2meanrefA1_810 = np.array(S2meanrefA1_810)
S2meanB2_110 = np.array(S2meanB2_110)

S2hsvrefA1_810 = list()
S2hsvB2_110 = list()
for i in range(3):
    S2hsvrefA1_810.append(S2meanrefA1_810[:,i].mean())
    S2hsvB2_110.append(S2meanB2_110[:,i].mean())

# %%
S2meanrefA1_910 = list()
S2meanB3_110 = list()
for i in range(S1HSV_imgA1B3_10.shape[0]): 
     for j in range(S1HSV_imgA1B3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_910.append(S1HSV_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB3_110.append(S1HSV_imgA1B3_10[i][j])  
S2meanrefA1_910 = np.array(S2meanrefA1_910)
S2meanB3_110 = np.array(S2meanB3_110)

S2hsvrefA1_910 = list()
S2hsvB3_110 = list()
for i in range(3):
    S2hsvrefA1_910.append(S2meanrefA1_910[:,i].mean())
    S2hsvB3_110.append(S2meanB3_110[:,i].mean())

# %%
S2meanrefA1_1010 = list()
S2meanB4_110 = list()
for i in range(S1HSV_imgA1B4_10.shape[0]): 
     for j in range(S1HSV_imgA1B4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1010.append(S1HSV_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanB4_110.append(S1HSV_imgA1B4_10[i][j])  
S2meanrefA1_1010 = np.array(S2meanrefA1_1010)
S2meanB4_110 = np.array(S2meanB4_110)

S2hsvrefA1_1010 = list()
S2hsvB4_110 = list()
for i in range(3):
    S2hsvrefA1_1010.append(S2meanrefA1_1010[:,i].mean())
    S2hsvB4_110.append(S2meanB4_110[:,i].mean())

# %%
S2meanrefA1_1110 = list()
S2meanC1_110 = list()
for i in range(S1HSV_imgA1C1_10.shape[0]): 
     for j in range(S1HSV_imgA1C1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1110.append(S1HSV_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC1_110.append(S1HSV_imgA1C1_10[i][j])  
S2meanrefA1_1110 = np.array(S2meanrefA1_1110)
S2meanC1_110 = np.array(S2meanC1_110)

S2hsvrefA1_1110 = list()
S2hsvC1_110 = list()
for i in range(3):
    S2hsvrefA1_1110.append(S1meanrefA1_1110[:,i].mean())
    S2hsvC1_110.append(S1meanC1_110[:,i].mean())

# %%
S2meanrefA1_1210 = list()
S2meanC2_110 = list()
for i in range(S1HSV_imgA1C2_10.shape[0]): 
     for j in range(S1HSV_imgA1C2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1210.append(S1HSV_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC2_110.append(S1HSV_imgA1C2_10[i][j])  
S2meanrefA1_1210 = np.array(S2meanrefA1_1210)
S2meanC2_110 = np.array(S2meanC2_110)

S2hsvrefA1_1210 = list()
S2hsvC2_1v = list()
for i in range(3):
    S2hsvrefA1_1210.append(S2meanrefA1_1210[:,i].mean())
    S2hsvC2_110.append(S2meanC2_110[:,i].mean())

# %%
S2meanrefA1_1310 = list()
S2meanC3_110 = list()
for i in range(S1HSV_imgA1C3_10.shape[0]): 
     for j in range(S1HSV_imgA1C3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1310.append(S1HSV_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_110.append(S1HSV_imgA1C3_10[i][j])  
S2meanrefA1_1310 = np.array(S2meanrefA1_1310)
S2meanC3_110 = np.array(S2meanC3_110)

S2hsvrefA1_1310 = list()
S2hsvC3_110 = list()
for i in range(3):
    S2hsvrefA1_1310.append(S2meanrefA1_1310[:,i].mean())
    S2hsvC3_110.append(S2meanC3_110[:,i].mean())

# %%
S2meanrefA1_1410 = list()
S2meanC4_110 = list()
for i in range(S1HSV_imgA1C4_10.shape[0]): 
     for j in range(S1HSV_imgA1C4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1410.append(S1HSV_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC4_110.append(S1HSV_imgA1C4_10[i][j])  
S2meanrefA1_1410 = np.array(S2meanrefA1_1410)
S2meanC4_110 = np.array(S2meanC4_110)

S2hsvrefA1_1410 = list()
S2hsvC4_110 = list()
for i in range(3):
    S2hsvrefA1_1410.append(S2meanrefA1_1410[:,i].mean())
    S2hsvC4_110.append(S2meanC4_110[:,i].mean())

# %%
S2meanrefA1_1510 = list()
S2meanD2_110 = list()
for i in range(S1HSV_imgA1D2_10.shape[0]): 
     for j in range(S1HSV_imgA1D2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1510.append(S1HSV_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD2_110.append(S1HSV_imgA1D2_10[i][j])  
S2meanrefA1_1510 = np.array(S2meanrefA1_1510)
S2meanD2_110 = np.array(S2meanD2_110)

S2hsvrefA1_1510 = list()
S2hsvD2_110 = list()
for i in range(3):
    S2hsvrefA1_15v.append(S2meanrefA1_1510[:,i].mean())
    S2hsvD2_110.append(S2meanD2_110[:,i].mean())

# %%
S2meanrefA1_1610 = list()
S2meanD3_110 = list()
for i in range(S1HSV_imgA1D3_10.shape[0]): 
     for j in range(S1HSV_imgA1D3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1610.append(S1HSV_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_110.append(S1HSV_imgA1D3_10[i][j])  
S2meanrefA1_1610 = np.array(S2meanrefA1_1610)
S2meanD3_110 = np.array(S2meanD3_110)

S2hsvrefA1_1610 = list()
S2hsvD3_110 = list()
for i in range(3):
    S2hsvrefA1_1610.append(S2meanrefA1_1610[:,i].mean())
    S2hsvD3_110.append(S2meanD3_110[:,i].mean())

# %%
S2meanrefA1_1710= list()
S2meanD4_110 = list()
for i in range(S1HSV_imgA1D4_10.shape[0]): 
     for j in range(S1HSV_imgA1D4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_1710.append(S1HSV_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD4_110.append(S1HSV_imgA1D4_10[i][j])  
S2meanrefA1_1710= np.array(S2meanrefA1_1410)
S1meanD4_110 = np.array(S2meanD4_110)

S2hsvrefA1_1710 = list()
S2hsvD4_110 = list()
for i in range(3):
    S2hsvrefA1_1710.append(S2meanrefA1_1710[:,i].mean())
    S2hsvD4_110.append(S2meanD4_110[:,i].mean())

# %% [markdown]
# ##Set3

# %% [markdown]
# ###RGB

# %%
S3meanrefA1_1 = list()
S3meanA1_2 = list()
for i in range(S3RGB_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1.append(S3RGB_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_2.append(S3RGB_imgA1A1_1[i][j])  
S3meanrefA1_1 = np.array(S3meanrefA1_1)
S3meanA1_2 = np.array(S3meanA1_2)

S3rgbrefA1_1 = list()
S3rgbA1_2 = list()
for i in range(3):
    S3rgbrefA1_1.append(S3meanrefA1_1[:,i].mean())
    S3rgbA1_2.append(S3meanA1_2[:,i].mean())

# %%
S3meanrefA1_3 = list()
S3meanA2_1 = list()
for i in range(S3RGB_imgA1A2_1.shape[0]): 
     for j in range(S3RGB_imgA1A2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_3.append(S3RGB_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_1.append(S3RGB_imgA1A2_1[i][j])  
S3meanrefA1_3 = np.array(S3meanrefA1_3)
S3meanA2_1 = np.array(S3meanA2_1)

S3rgbrefA1_3 = list()
S3rgbA2_1 = list()
for i in range(3):
    S3rgbrefA1_3.append(S3meanrefA1_3[:,i].mean())
    S3rgbA2_1.append(S3meanA2_1[:,i].mean())

# %%
S3meanrefA1_4 = list()
S3meanA3_1 = list()
for i in range(S3RGB_imgA1A3_1.shape[0]): 
     for j in range(S3RGB_imgA1A3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_4.append(S3RGB_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_1.append(S3RGB_imgA1A3_1[i][j])  
S3meanrefA1_4 = np.array(S3meanrefA1_4)
S3meanA3_1 = np.array(S3meanA3_1)

S3rgbrefA1_4 = list()
S3rgbA3_1 = list()
for i in range(3):
    S3rgbrefA1_4.append(S3meanrefA1_4[:,i].mean())
    S3rgbA3_1.append(S3meanA3_1[:,i].mean())

# %%
S3meanrefA1_5 = list()
S3meanA3_51 = list()
for i in range(S3RGB_imgA1A3_51.shape[0]): 
     for j in range(S3RGB_imgA1A3_51.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_5.append(S3RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_51.append(S3RGB_imgA1A3_51[i][j])  
S3meanrefA1_5 = np.array(S3meanrefA1_5)
S3meanA3_51 = np.array(S3meanA3_51)

S3rgbrefA1_5 = list()
S3rgbA3_51 = list()
for i in range(3):
    S3rgbrefA1_5.append(S3meanrefA1_5[:,i].mean())
    S3rgbA3_51.append(S3meanA3_51[:,i].mean())

# %%
S3meanrefA1_6 = list()
S3meanA4_1 = list()
for i in range(S3RGB_imgA1A4_1.shape[0]): 
     for j in range(S3RGB_imgA1A4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_6.append(S3RGB_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_1.append(S3RGB_imgA1A4_1[i][j])  
S3meanrefA1_6 = np.array(S3meanrefA1_6)
S3meanA4_1 = np.array(S3meanA4_1)

S3rgbrefA1_6 = list()
S3rgbA4_1 = list()
for i in range(3):
    S3rgbrefA1_6.append(S3meanrefA1_6[:,i].mean())
    S3rgbA4_1.append(S3meanA4_1[:,i].mean())

# %%
S3meanrefA1_7 = list()
S3meanB1_1 = list()
for i in range(S3RGB_imgA1B1_1.shape[0]): 
     for j in range(S3RGB_imgA1B1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_7.append(S3RGB_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_1.append(S3RGB_imgA1B1_1[i][j])  
S3meanrefA1_7 = np.array(S3meanrefA1_7)
S3meanB1_1 = np.array(S3meanB1_1)

S3rgbrefA1_7 = list()
S3rgbB1_1 = list()
for i in range(3):
    S3rgbrefA1_7.append(S3meanrefA1_7[:,i].mean())
    S3rgbB1_1.append(S3meanB1_1[:,i].mean())

# %%
S3meanrefA1_8 = list()
S3meanB2_1 = list()
for i in range(S3RGB_imgA1B2_1.shape[0]): 
     for j in range(S3RGB_imgA1B2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_8.append(S3RGB_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_1.append(S3RGB_imgA1B2_1[i][j])  
S3meanrefA1_8 = np.array(S3meanrefA1_8)
S3meanB2_1 = np.array(S3meanB2_1)

S3rgbrefA1_8 = list()
S3rgbB2_1 = list()
for i in range(3):
    S3rgbrefA1_8.append(S3meanrefA1_8[:,i].mean())
    S3rgbB2_1.append(S3meanB2_1[:,i].mean())

# %%
S3meanrefA1_9 = list()
S3meanB3_1 = list()
for i in range(S3RGB_imgA1B3_1.shape[0]): 
     for j in range(S3RGB_imgA1B3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_9.append(S3RGB_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_1.append(S3RGB_imgA1B3_1[i][j])  
S3meanrefA1_9 = np.array(S3meanrefA1_9)
S3meanB3_1 = np.array(S3meanB3_1)

S3rgbrefA1_9 = list()
S3rgbB3_1 = list()
for i in range(3):
    S3rgbrefA1_9.append(S3meanrefA1_9[:,i].mean())
    S3rgbB3_1.append(S3meanB3_1[:,i].mean())

# %%
S3meanrefA1_10 = list()
S3meanB4_1 = list()
for i in range(S3RGB_imgA1B4_1.shape[0]): 
     for j in range(S3RGB_imgA1B4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_10.append(S3RGB_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_1.append(S3RGB_imgA1B4_1[i][j])  
S3meanrefA1_10 = np.array(S3meanrefA1_10)
S3meanB4_1 = np.array(S3meanB4_1)

S3rgbrefA1_10 = list()
S3rgbB4_1 = list()
for i in range(3):
    S3rgbrefA1_10.append(S3meanrefA1_10[:,i].mean())
    S3rgbB4_1.append(S3meanB4_1[:,i].mean())

# %%
S3meanrefA1_11 = list()
S3meanC1_1 = list()
for i in range(S3RGB_imgA1C1_1.shape[0]): 
     for j in range(S3RGB_imgA1C1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_11.append(S3RGB_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_1.append(S3RGB_imgA1C1_1[i][j])  
S3meanrefA1_11 = np.array(S3meanrefA1_11)
S3meanC1_1 = np.array(S3meanC1_1)

S3rgbrefA1_11 = list()
S3rgbC1_1 = list()
for i in range(3):
    S3rgbrefA1_11.append(S3meanrefA1_11[:,i].mean())
    S3rgbC1_1.append(S3meanC1_1[:,i].mean())

# %%
S3meanrefA1_12 = list()
S3meanC2_1 = list()
for i in range(S3RGB_imgA1C2_1.shape[0]): 
     for j in range(S3RGB_imgA1C2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_12.append(S3RGB_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_1.append(S3RGB_imgA1C2_1[i][j])  
S3meanrefA1_12 = np.array(S3meanrefA1_12)
S3meanC2_1 = np.array(S3meanC2_1)

S3rgbrefA1_12 = list()
S3rgbC2_1 = list()
for i in range(3):
    S3rgbrefA1_12.append(S3meanrefA1_12[:,i].mean())
    S3rgbC2_1.append(S3meanC2_1[:,i].mean())

# %%
S3meanrefA1_13 = list()
S3meanC3_1 = list()
for i in range(S3RGB_imgA1C3_1.shape[0]): 
     for j in range(S3RGB_imgA1C3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_13.append(S3RGB_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_1.append(S3RGB_imgA1C3_1[i][j])  
S3meanrefA1_13 = np.array(S3meanrefA1_13)
S3meanC3_1 = np.array(S3meanC3_1)

S3rgbrefA1_13 = list()
S3rgbC3_1 = list()
for i in range(3):
    S3rgbrefA1_13.append(S3meanrefA1_13[:,i].mean())
    S3rgbC3_1.append(S3meanC3_1[:,i].mean())

# %%
S3meanrefA1_14 = list()
S3meanC4_1 = list()
for i in range(S3RGB_imgA1C4_1.shape[0]): 
     for j in range(S3RGB_imgA1C4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_14.append(S3RGB_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_1.append(S3RGB_imgA1C4_1[i][j])  
S3meanrefA1_14 = np.array(S3meanrefA1_14)
S3meanC4_1 = np.array(S3meanC4_1)

S3rgbrefA1_14 = list()
S3rgbC4_1 = list()
for i in range(3):
    S3rgbrefA1_14.append(S3meanrefA1_14[:,i].mean())
    S3rgbC4_1.append(S3meanC4_1[:,i].mean())

# %%
S3meanrefA1_15 = list()
S3meanD2_1 = list()
for i in range(S3RGB_imgA1D2_1.shape[0]): 
     for j in range(S3RGB_imgA1D2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_15.append(S3RGB_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_1.append(S3RGB_imgA1D2_1[i][j])  
S3meanrefA1_15 = np.array(S3meanrefA1_15)
S3meanD2_1 = np.array(S3meanD2_1)

S3rgbrefA1_15 = list()
S3rgbD2_1 = list()
for i in range(3):
    S3rgbrefA1_15.append(S3meanrefA1_15[:,i].mean())
    S3rgbD2_1.append(S3meanD2_1[:,i].mean())

# %%
S3meanrefA1_16 = list()
S3meanD3_1 = list()
for i in range(S3RGB_imgA1D3_1.shape[0]): 
     for j in range(S3RGB_imgA1D3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_16.append(S3RGB_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_1.append(S3RGB_imgA1D3_1[i][j])  
S3meanrefA1_16 = np.array(S3meanrefA1_16)
S3meanD3_1 = np.array(S3meanD3_1)

S3rgbrefA1_16 = list()
S3rgbD3_1 = list()
for i in range(3):
    S3rgbrefA1_16.append(S3meanrefA1_16[:,i].mean())
    S3rgbD3_1.append(S3meanD3_1[:,i].mean())

# %%
S3meanrefA1_17= list()
S3meanD4_1 = list()
for i in range(S3RGB_imgA1D4_1.shape[0]): 
     for j in range(S3RGB_imgA1D4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_17.append(S3RGB_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_1.append(S3RGB_imgA1D4_1[i][j])  
S3meanrefA1_17 = np.array(S3meanrefA1_14)
S3meanD4_1 = np.array(S3meanD4_1)

S3rgbrefA1_17 = list()
S3rgbD4_1 = list()
for i in range(3):
    S3rgbrefA1_17.append(S3meanrefA1_17[:,i].mean())
    S3rgbD4_1.append(S3meanD4_1[:,i].mean())

# %% [markdown]
# ###Img 2

# %%
S3meanrefA1_102 = list()
S3meanA1_202 = list()
for i in range(S3RGB_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_102.append(S3RGB_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_202.append(S3RGB_imgA1A1_2[i][j])  
S3meanrefA1_102 = np.array(S3meanrefA1_102)
S3meanA1_202 = np.array(S3meanA1_202)

S3rgbrefA1_102 = list()
S3rgbA1_202 = list()
for i in range(3):
    S3rgbrefA1_102.append(S3meanrefA1_102[:,i].mean())
    S3rgbA1_202.append(S3meanA1_202[:,i].mean())
S3rgbrefA1_102,S2rgbA1_202

# %%
S3meanrefA1_302 = list()
S3meanA2_102 = list()
for i in range(S3RGB_imgA1A2_2.shape[0]): 
     for j in range(S3RGB_imgA1A2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_302.append(S3RGB_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanA2_102.append(S3RGB_imgA1A2_2[i][j])  
S3meanrefA1_302 = np.array(S3meanrefA1_302)
S3meanA2_102 = np.array(S3meanA2_102)

S3rgbrefA1_302 = list()
S3rgbA2_102 = list()
for i in range(3):
    S3rgbrefA1_302.append(S3meanrefA1_302[:,i].mean())
    S3rgbA2_102.append(S3meanA2_102[:,i].mean())

# %%
S3meanrefA1_402 = list()
S3meanA3_102 = list()
for i in range(S3RGB_imgA1A3_2.shape[0]): 
     for j in range(S3RGB_imgA1A3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_402.append(S3RGB_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_102.append(S3RGB_imgA1A3_2[i][j])  
S3meanrefA1_402 = np.array(S3meanrefA1_402)
S3meanA3_102 = np.array(S3meanA3_102)

S3rgbrefA1_402 = list()
S3rgbA3_102 = list()
for i in range(3):
    S3rgbrefA1_402.append(S3meanrefA1_402[:,i].mean())
    S3rgbA3_102.append(S3meanA3_102[:,i].mean())

# %%
S3meanrefA1_02 = list()
S3meanA3_5102 = list()
for i in range(S3RGB_imgA1A3_52.shape[0]): 
     for j in range(S3RGB_imgA1A3_52.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_502.append(S3RGB_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5102.append(S3RGB_imgA1A3_52[i][j])  
S3meanrefA1_502 = np.array(S3meanrefA1_502)
S3meanA3_5102 = np.array(S3meanA3_5102)

S3gbrefA1_502 = list()
S3gbA3_5102 = list()
for i in range(3):
    S3rgbrefA1_502.append(S3meanrefA1_502[:,i].mean())
    S3rgbA3_5102.append(S3meanA3_5102[:,i].mean())

# %%
S3meanrefA1_602 = list()
S3meanA4_102 = list()
for i in range(S3RGB_imgA1A4_2.shape[0]): 
     for j in range(S3RGB_imgA1A4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3rmeanrefA1_602.append(S3RGB_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_102.append(S3RGB_imgA1A4_2[i][j])  
S3meanrefA1_602 = np.array(S3meanrefA1_602)
S3meanA4_102 = np.array(S3meanA4_102)

S3rgbrefA1_602 = list()
S3rgbA4_102 = list()
for i in range(3):
   S3rgbrefA1_602.append(S3meanrefA1_602[:,i].mean())
   S3rgbA4_102.append(S3meanA4_102[:,i].mean())

# %%
S3meanrefA1_702 = list()
S3meanB1_102 = list()
for i in range(S3RGB_imgA1B1_202.shape[0]): 
     for j in range(S3RGB_imgA1B1_202.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_702.append(S3RGB_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_102.append(S3RGB_imgA1B1_2[i][j])  
S3meanrefA1_702 = np.array(S3meanrefA1_702)
S3meanB1_102 = np.array(S3meanB1_102)

S3rgbrefA1_7 02= list()
S3rgbB1_102 = list()
for i in range(3):
   S3rgbrefA1_702.append(S3meanrefA1_702[:,i].mean())
   S3rgbB1_102.append(S3meanB1_102[:,i].mean())

# %%
S3meanrefA1_802 = list()
S3meanB2_102 = list()
for i in range(S3RGB_imgA1B2_2.shape[0]): 
     for j in range(S3RGB_imgA1B2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_802.append(S3RGB_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanB2_102.append(S3RGB_imgA1B2_2[i][j])  
S3meanrefA1_802 = np.array(S3meanrefA1_802)
S3meanB2_102 = np.array(S3meanB2_102)

S3gbrefA1_802 = list()
S3rgbB2_102 = list()
for i in range(3):
    S3rgbrefA1_802.append(S3meanrefA1_802[:,i].mean())
   S3rgbB2_102.append(S3meanB2_102[:,i].mean())

# %%
S3meanrefA1_902 = list()
S3meanB3_102 = list()
for i in range(S3RGB_imgA1B3_2.shape[0]): 
     for j in range(S3RGB_imgA1B3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_902.append(S3RGB_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanB3_102.append(S3RGB_imgA1B3_2[i][j])  
S3meanrefA1_902 = np.array(S3meanrefA1_902)
S3meanB3_102 = np.array(S3meanB3_102)

S3rgbrefA1_902 = list()
S3rgbB3_102 = list()
for i in range(3):
    S3rgbrefA1_902.append(S3meanrefA1_902[:,i].mean())
   S3rgbB3_102.append(S3meanB3_102[:,i].mean())

# %%
S3meanrefA1_1002 = list()
S3meanB4_102 = list()
for i in range(S3RGB_imgA1B4_2.shape[0]): 
     for j in range(S3RGB_imgA1B4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1002.append(S3RGB_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_102.append(S3RGB_imgA1B4_2[i][j])  
S3meanrefA1_1002 = np.array(S3meanrefA1_1002)
S3meanB4_102 = np.array(S3meanB4_102)

S3rgbrefA1_1002 = list()
S3rgbB4_102 = list()
for i in range(3):
    S3rgbrefA1_1002.append(S3meanrefA1_1002[:,i].mean())
    S3rgbB4_102.append(S3meanB4_102[:,i].mean())

# %%
S3meanrefA1_1102 = list()
S3meanC1_102 = list()
for i in range(S3RGB_imgA1C1_2.shape[0]): 
     for j in range(S3RGB_imgA1C1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1102.append(S3RGB_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  SS3meanC1_102.append(S3RGB_imgA1C1_2[i][j])  
S3meanrefA1_1102 = np.array(S3meanrefA1_1102)
S3meanC1_102 = np.array(S3meanC1_102)

S3rgbrefA1_1102 = list()
S3rgbC1_102 = list()
for i in range(3):
   S3rgbrefA1_1102.append(S3meanrefA1_1102[:,i].mean())
   S3rgbC1_102.append(S3meanC1_102[:,i].mean())

# %%
S3meanrefA1_1202 = list()
S3meanC2_102 = list()
for i in range(S3RGB_imgA1C2_2.shape[0]): 
     for j in range(S3RGB_imgA1C2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1202.append(S2RGB_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_102.append(S2RGB_imgA1C2_2[i][j])  
S3meanrefA1_1202 = np.array(S3meanrefA1_1202)
S3meanC2_102 = np.array(S3meanC2_102)

S3rgbrefA1_1202 = list()
S3rgbC2_102 = list()
for i in range(3):
    S3rgbrefA1_1202.append(S3meanrefA1_1202[:,i].mean())
    S3rgbC2_102.append(S3meanC2_102[:,i].mean())

# %%
S3meanrefA1_1302 = list()
S3meanC3_102 = list()
for i in range(S3RGB_imgA1C3_2.shape[0]): 
     for j in range(S3RGB_imgA1C3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1302.append(S3RGB_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanC3_102.append(S3RGB_imgA1C3_2[i][j])  
S3meanrefA1_1302 = np.array(S3meanrefA1_1302)
S3meanC3_102 = np.array(S3meanC3_102)

S3rgbrefA1_1302 = list()
S3rgbC3_102 = list()
for i in range(3):
    S3rgbrefA1_1302.append(S3meanrefA1_1302[:,i].mean())
    S3rgbC3_102.append(S3meanC3_102[:,i].mean())

# %%
S3meanrefA1_1402 = list()
S3meanC4_102 = list()
for i in range(S3RGB_imgA1C4_2.shape[0]): 
     for j in range(S3RGB_imgA1C4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1402.append(S3RGB_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_102.append(S3RGB_imgA1C4_2[i][j])  
S3meanrefA1_1402 = np.arrayS3meanrefA1_1402)
S3meanC4_102 = np.array(S3meanC4_102)

S3rgbrefA1_1402 = list()
S3rgbC4_102 = list()
for i in range(3):
    S3rgbrefA1_1402.append(S3meanrefA1_1402[:,i].mean())
     S3rgbC4_102.append(S3meanC4_102[:,i].mean())

# %%
S3meanrefA1_1502 = list()
S3meanD2_102 = list()
for i in range(S3RGB_imgA1D2_2.shape[0]): 
     for j in range(S3RGB_imgA1D2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1502.append(RGB_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_102.append(RGB_imgA1D2_2[i][j])  
S3meanrefA1_1502 = np.array(S3meanrefA1_1502)
S3meanD2_102 = np.array(S3meanD2_102)

S3rgbrefA1_1502 = list()
S3rgbD2_102 = list()
for i in range(3):
    S3rgbrefA1_1502.append(S3meanrefA1_1502[:,i].mean())
    S3rgbD2_102.append(S3meanD2_102[:,i].mean())

# %%
S3meanrefA1_1602 = list()
S3meanD3_102 = list()
for i in range(S3RGB_imgA1D3_2.shape[0]): 
     for j in range(S3RGB_imgA1D3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1602.append(S3RGB_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanD3_102.append(S3RGB_imgA1D3_2[i][j])  
S3meanrefA1_1602 = np.array(S3meanrefA1_1602)
S3meanD3_102 = np.array(S3meanD3_102

S3rgbrefA1_1602 = list()
S3rgbD3_102 = list()
for i in range(3):
    S3rgbrefA1_1602.append(S3meanrefA1_1602[:,i].mean())
    S3rgbD3_102.append(S3meanD3_102[:,i].mean())

# %%
S3meanrefA1_1702= list()
S3meanD4_102 = list()
for i in range(S3RGB_imgA1D4_2.shape[0]): 
     for j in range(S3RGB_imgA1D4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_1702.append(S2RGB_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanD4_102.append(S2RGB_imgA1D4_2[i][j])  
S3meanrefA1_1702 = np.array(S2meanrefA1_1402)
S3meanD4_102 = np.array(S2meanD4_102)

S3rgbrefA1_1702 = list()
S3rgbD4_102 = list()
for i in range(3):
   S3rgbrefA1_1702.append(S3meanrefA1_1702[:,i].mean())
   S3rgbD4_102.append(S3meanD4_102[:,i].mean())

# %% [markdown]
# ###Img 3

# %%
S3meanrefA1_103 = list()
S3meanA1_203 = list()
for i in range(S3RGB_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1.append(S3RGB_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_2.append(S3RGB_imgA1A1_3[i][j])  
S3meanrefA1_103 = np.array(S3meanrefA1_103)
S3meanA1_203 = np.array(S3meanA1_203)

S3rgbrefA1_103 = list()
S3rgbA1_203 = list()
for i in range(3):
    S3rgbrefA1_103.append(S3meanrefA1_103[:,i].mean())
    rgbA1_203.append(S3meanA1_203[:,i].mean())
S3rgbrefA1_103,S3rgbA1_2 03

# %%
S3meanrefA1_303 = list()
S3meanA2_103 = list()
for i in range(S3RGB_imgA1A2_3.shape[0]): 
     for j in range(S3RGB_imgA1A2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_303.append(S3RGB_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_103.append(S3RGB_imgA1A2_3[i][j])  
S3meanrefA1_303 = np.array(S3meanrefA1_303)
S3meanA2_103 = np.array(S3meanA2_103)

S3rgbrefA1_303 = list()
S3rgbA2_103 = list()
for i in range(3):
    S3rgbrefA1_303.append(S3meanrefA1_303[:,i].mean())
    S3rgbA2_103.append(S3meanA2_103[:,i].mean())

# %%
S3meanrefA1_403 = list()
S3meanA3_103 = list()
for i in range(S3RGB_imgA1A3_3.shape[0]): 
     for j in range(S3RGB_imgA1A3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_403.append(S3RGB_imgA1A33_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_103.append(S3RGB_imgA1A3_3[i][j])  
S3meanrefA1_403= np.array(S3meanrefA1_403 )
S3meanA3_103 = np.array(S3meanA3_103 )

S3gbrefA1_403  = list()
S3rgbA3_103  = list()
for i in range(3):
    S3rgbrefA1_403 .append(S3meanrefA1_403[:,i].mean())
    S3rgbA3_103 .append(S3meanA3_103 [:,i].mean())

# %%
S3meanrefA1_503  = list()
S3meanA3_5103  = list()
for i in range(S3RGB_imgA1A3_53.shape[0]): 
     for j in range(S3RGB_imgA1A3_53.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_503 .append(S3RGB_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5103 .append(S3RGB_imgA1A3_53[i][j])  
S3meanrefA1_503  = np.array(S3meanrefA1_503 )
S3meanA3_5103  = np.array(S3meanA3_5103 )

S3rgbrefA1_503  = list()
S3rgbA3_5103  = list()
for i in range(3):
    S3rgbrefA1_503 .append(S3meanrefA1_503 [:,i].mean())
    S3rgbA3_5103 .append(S3meanA3_5103 [:,i].mean())

# %%
S3meanrefA1_603  = list()
S3meanA4_103  = list()
for i in range(S3RGB_imgA1A4_3.shape[0]): 
     for j in range(S3RGB_imgA1A4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_603 .append(S3RGB_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_103 .append(S3RGB_imgA1A4_3[i][j])  
S3meanrefA1_603  = np.array(S3meanrefA1_603 )
S3meanA4_103  = np.array(S3meanA4_103 )

S3rgbrefA1_603  = list()
S3rgbA4_103  = list()
for i in range(3):
    S3rgbrefA1_603 .append(S3meanrefA1_603[:,i].mean())
    S3rgbA4_103 .append(S3meanA4_103 [:,i].mean())

# %%
S3meanrefA1_703  = list()
S3meanB1_103  = list()
for i in range(S3RGB_imgA1B1_3.shape[0]): 
     for j in range(S3RGB_imgA1B1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_703 .append(S3RGB_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_103 .append(S3RGB_imgA1B1_3[i][j])  
S3meanrefA1_703  = np.array(S3meanrefA1_73)
S3meanB1_103  = np.array(S3meanB1_103)

S3rgbrefA1_703  = list()
S3rgbB1_103  = list()
for i in range(3):
    S3rgbrefA1_703 .append(S3meanrefA1_703 [:,i].mean())
    S3rgbB1_103 .append(S3meanB1_103 [:,i].mean())

# %%
S3meanrefA1_803  = list()
S3meanB2_103  = list()
for i in range(S3RGB_imgA1B2_3.shape[0]): 
     for j in range(S3RGB_imgA1B2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_803 .append(S3RGB_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_103 .append(S3RGB_imgA1B2_3[i][j])  
S3meanrefA1_803  = np.array(S3meanrefA1_803 )
S3meanB2_103  = np.array(S3meanB2_103 )

S3rgbrefA1_803  = list()
S3rgbB2_103  = list()
for i in range(3):
    S3rgbrefA1_803 .append(S3meanrefA1_803 [:,i].mean())
    S3rgbB2_103 .append(S3meanB2_103 [:,i].mean())

# %%
S3meanrefA1_903  = list()
S3meanB3_103  = list()
for i in range(S3RGB_imgA1B3_3.shape[0]): 
     for j in range(S3RGB_imgA1B3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_903 .append(S3RGB_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_103 .append(S3RGB_imgA1B3_3[i][j])  
S3meanrefA1_903  = np.array(S3meanrefA1_903 )
S3meanB3_103  = np.array(S3meanB3_103 )

S3rgbrefA1_903  = list()
S3rgbB3_103  = list()
for i in range(3):
    S3rgbrefA1_903 .append(S3meanrefA1_903 [:,i].mean())
    S3rgbB3_103 .append(S3meanB3_103 [:,i].mean())

# %%
S3meanrefA1_1003  = list()
S3meanB4_103  = list()
for i in range(S3RGB_imgA1B4_3.shape[0]): 
     for j in range(S3RGB_imgA1B4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1003 .append(S3RGB_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_103 .append(S3RGB_imgA1B4_3[i][j])  
S3meanrefA1_1003  = np.array(S3meanrefA1_1003 )
S3meanB4_103  = np.array(S3meanB4_103 )

S3rgbrefA1_1003  = list()
S3gbB4_103  = list()
for i in range(3):
    S3rgbrefA1_1003 .append(S3meanrefA1_1003[:,i].mean())
    S3rgbB4_103 .append(S3meanB4_103 [:,i].mean())

# %%
S3meanrefA1_1103  = list()
S3meanC1_103  = list()
for i in range(S3RGB_imgA1C1_3.shape[0]): 
     for j in range(S3RGB_imgA1C1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1103 .append(S3RGB_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_103 .append(S3RGB_imgA1C1_3[i][j])  
S3meanrefA1_1103  = np.array(S3meanrefA1_1103 )
S3meanC1_103  = np.array(S3meanC1_103 )

S3rgbrefA1_1103  = list()
S3rgbC1_103  = list()
for i in range(3):
    S3rgbrefA1_1103.append(S3meanrefA1_1103 [:,i].mean())
    S3rgbC1_103.append(S3meanC1_103 [:,i].mean())

# %%
S3meanrefA1_1203  = list()
S3meanC2_103 = list()
for i in range(S3RGB_imgA1C2_3.shape[0]): 
     for j in range(S3RGB_imgA1C2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1203.append(S3RGB_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_103.append(S3RGB_imgA1C2_3[i][j])  
S3meanrefA1_1203 = np.array(S3meanrefA1_1203)
S3meanC2_103 = np.array(S3meanC2_103)

S3gbrefA1_1203 = list()
S3rgbC2_103 = list()
for i in range(3):
    S3rgbrefA1_1203.append(S3meanrefA1_1203[:,i].mean())
    S3rgbC2_103.append(S3meanC2_103[:,i].mean())

# %%
S3meanrefA1_1303 = list()
S3meanC3_103 = list()
for i in range(S3RGB_imgA1C3_3.shape[0]): 
     for j in range(S3RGB_imgA1C3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1303.append(S3RGB_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_103append(S3RGB_imgA1C3_3i][j])  
S3meanrefA1_1303 = np.array(S3meanrefA1_1303)
S3meanC3_103 = np.array(S3meanC3_103)

S3rgbrefA1_1303 = list()
S3rgbC3_103 = list()
for i in range(3):
    S3rgbrefA1_1303.append(S3meanrefA1_1303[:,i].mean())
    S3rgbC3_103.append(S3meanC3_103[:,i].mean())

# %%
S3meanrefA1_1403 = list()
S3meanC4_103 = list()
for i in range(S3RGB_imgA1C4_3.shape[0]): 
     for j in range(S3RGB_imgA1C4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_1403.append(S3RGB_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_103.append(S3RGB_imgA1C4_3[i][j])  
S3meanrefA1_1403 = np.array(S3meanrefA1_1403)
S3meanC4_103 = np.array(S3meanC4_103)

S3gbrefA1_1403 = list()
S3rgbC4_103 = list()
for i in range(3):
    S3rgbrefA1_1403.append(S3meanrefA1_1403[:,i].mean())
    S3rgbC4_103.append(S3meanC4_103[:,i].mean())

# %%
S3meanrefA1_1503 = list()
S3meanD2_103 = list()
for i in range(S3RGB_imgA1D2_3.shape[0]): 
     for j in range(S3RGB_imgA1D2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1503.append(S2RGB_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_103.append(S3RGB_imgA1D2_3[i][j])  
S3meanrefA1_1503 = np.array(S3meanrefA1_1503)
S3meanD2_103 = np.array(S3meanD2_103)

S3rgbrefA1_1503 = list()
S3gbD2_103 = list()
for i in range(3):
    S3rgbrefA1_1503.append(S3meanrefA1_1503[:,i].mean())
    S3rgbD2_103.append(S3meanD2_103[:,i].mean())

# %%
S3meanrefA1_1603 = list()
S3meanD3_103 = list()
for i in range(S3RGB_imgA1D3_3.shape[0]): 
     for j in range(S3RGB_imgA1D3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1603.append(S3RGB_imgA1D33_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_103.append(S3RGB_imgA1D3_3[i][j])  
S3meanrefA1_1603 = np.array(S3meanrefA1_1603)
S3meanD3_103 = np.array(S3meanD3_103)

S3gbrefA1_1603 = list()
S3gbD3_103 = list()
for i in range(3):
    S3rgbrefA1_1603.append(S3meanrefA1_1603[:,i].mean())
    S3rgbD3_103.append(S3meanD3_103[:,i].mean())

# %%
S3meanrefA1_1703= list()
S3meanD4_103 = list()
for i in range(S3RGB_imgA1D4_3.shape[0]): 
     for j in range(S3RGB_imgA1D4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1703.append(S3RGB_imgA1D4_3i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_103.append(S3RGB_imgA1D4_3[i][j])  
S3meanrefA1_1703 = np.array(S3meanrefA1_1403)
S3meanD4_103 = np.array(S3meanD4_103)

S3rgbrefA1_1703 = list()
S3rgbD4_103 = list()
for i in range(3):
    S3rgbrefA1_1703.append(S3meanrefA1_1703[:,i].mean())
    S3rgbD4_103.append(S3meanD4_103[:,i].mean())

# %% [markdown]
# ###Img 4

# %%
S3meanrefA1_104 = list()
S3meanA1_204 = list()
for i in range(S3RGB_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_104.append(S3RGB_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_204.append(S3RGB_imgA1A1_4[i][j])  
S3meanrefA1_104 = np.array(S3meanrefA1_104)
S3meanA1_204 = np.array(S3meanA1_204)

S3rgbrefA1_104 = list()
S3rgbA1_204 = list()
for i in range(3):
    S3rgbrefA1_104.append(S3meanrefA1_104[:,i].mean())
    S3rgbA1_204.append(S3meanA1_204[:,i].mean())
S3rgbrefA1_104,S2rgbA1_204

# %%
S3meanrefA1_304 = list()
S3meanA2_104 = list()
for i in range(S3RGB_imgA1A2_4.shape[0]): 
     for j in range(S3RGB_imgA1A2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_304.append(S3RGB_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_104.append(S3RGB_imgA1A2_4[i][j])  
S3meanrefA1_304 = np.array(S3meanrefA1_304)
S3meanA2_104 = np.array(S3meanA2_104)

S3rgbrefA1_304 = list()
S3rgbA2_104 = list()
for i in range(3):
    S3rgbrefA1_304.append(S3meanrefA1_304[:,i].mean())
    S3rgbA2_104.append(S3meanA2_104[:,i].mean())

# %%
S3meanrefA1_404 = list()
S3meanA3_104 = list()
for i in range(S3RGB_imgA1A3_4.shape[0]): 
     for j in range(S3RGB_imgA1A3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_404.append(S3RGB_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_104.append(S3RGB_imgA1A3_4[i][j])  
S3meanrefA1_404 = np.array(S3meanrefA1_404)
S3meanA3_104 = np.array(S3meanA3_104)

S3rgbrefA1_404 = list()
S3rgbA3_104 = list()
for i in range(3):
    S3rgbrefA1_404.append(S3meanrefA1_404[:,i].mean())
    S3rgbA3_104.append(S3meanA3_104[:,i].mean())

# %%
S3meanrefA1_504 = list()
S3meanA3_5104 = list()
for i in range(S3RGB_imgA1A3_54.shape[0]): 
     for j in range(S3RGB_imgA1A3_54.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_504.append(S3RGB_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5104.append(S3RGB_imgA1A3_54[i][j])  
S3meanrefA1_504 = np.array(S3meanrefA1_5104)
S3meanA3_5104 = np.array(S3meanA3_5104)

S3rgbrefA1_504 = list()
S3rgbA3_5104 = list()
for i in range(3):
    S3rgbrefA1_504.append(S3meanrefA1_504[:,i].mean())
    S3rgbA3_5104.append(S3meanA3_5104[:,i].mean())

# %%
S3meanrefA1_604 = list()
S3meanA4_104 = list()
for i in range(S3RGB_imgA1A4_4.shape[0]): 
     for j in range(S3RGB_imgA1A4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_604.append(S3RGB_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_104.append(S3RGB_imgA1A4_4[i][j])  
S3meanrefA1_604 = np.array(S3meanrefA1_604)
S3meanA4_104 = np.array(S3meanA4_104)

S3rgbrefA1_604 = list()
S3rgbA4_104 = list()
for i in range(3):
    S3rgbrefA1_604.append(S3meanrefA1_604[:,i].mean())
    S3rgbA4_104.append(S3meanA4_104[:,i].mean())

# %%
S3meanrefA1_704 = list()
S3meanB1_104 = list()
for i in range(S3RGB_imgA1B1_4.shape[0]): 
     for j in range(S3RGB_imgA1B1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_704.append(S3RGB_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_104.append(S3RGB_imgA1B1_4[i][j])  
S3meanrefA1_704 = np.array(S3meanrefA1_704)
S3meanB1_104 = np.array(S3meanB1_104)

S3rgbrefA1_704 = list()
S3rgbB1_104 = list()
for i in range(3):
    S3rgbrefA1_704.append(S3meanrefA1_704[:,i].mean())
    S3rgbB1_104.append(S3meanB1_104[:,i].mean())

# %%
S3meanrefA1_804 = list()
S3meanB2_104 = list()
for i in range(S3RGB_imgA1B2_4.shape[0]): 
     for j in range(S3RGB_imgA1B2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_804.append(S3RGB_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_104.append(S3RGB_imgA1B2_4[i][j])  
S3meanrefA1_804 = np.array(S3meanrefA1_804)
S3meanB2_104 = np.array(S3meanB2_104)

S3rgbrefA1_804 = list()
S3rgbB2_104 = list()
for i in range(3):
    S3rgbrefA1_804.append(S3meanrefA1_804[:,i].mean())
    S3rgbB2_104.append(S3meanB2_104[:,i].mean())

# %%
S3meanrefA1_904 = list()
S3meanB3_104 = list()
for i in range(S3RGB_imgA1B3_4.shape[0]): 
     for j in range(S3RGB_imgA1B3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_904.append(S1RGB_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_104.append(S3RGB_imgA1B3_4[i][j])  
S3meanrefA1_904 = np.array(S3meanrefA1_904)
S3meanB3_104 = np.array(S3meanB3_104)

S3rgbrefA1_904 = list()
S3rgbB3_104 = list()
for i in range(3):
    S3rgbrefA1_904.append(S3meanrefA1_904[:,i].mean())
    S3rgbB3_104.append(S3meanB3_104[:,i].mean())

# %%
S3meanrefA1_1004 = list()
S3meanB4_104 = list()
for i in range(S3RGB_imgA1B4_4.shape[0]): 
     for j in range(S3RGB_imgA1B4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1004.append(S3RGB_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_104.append(S3RGB_imgA1B4_4[i][j])  
S3meanrefA1_1004 = np.array(S3meanrefA1_1004)
S3meanB4_104 = np.array(S3meanB4_104)

S3rgbrefA1_1004 = list()
S3rgbB4_104 = list()
for i in range(3):
    S3rgbrefA1_1004.append(S3meanrefA1_1004[:,i].mean())
    S3rgbB4_104.append(S3meanB4_104[:,i].mean())

# %%
S3meanrefA1_1104 = list()
S3meanC1_104 = list()
for i in range(S3RGB_imgA1C1_4.shape[0]): 
     for j in range(S3RGB_imgA1C1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1104.append(S3RGB_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_104.append(S3RGB_imgA1C1_4[i][j])  
S3meanrefA1_1104 = np.array(S3meanrefA1_1104)
S3meanC1_104 = np.array(S3meanC1_104)

S3rgbrefA1_1104 = list()
S3rgbC1_104 = list()
for i in range(3):
    S3rgbrefA1_1104.append(S3meanrefA1_1104[:,i].mean())
    S3rgbC1_104.append(S3meanC1_104[:,i].mean())

# %%
S3meanrefA1_1204 = list()
S3meanC2_104 = list()
for i in range(S3RGB_imgA1C2_4.shape[0]): 
     for j in range(S3RGB_imgA1C2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1204.append(S3RGB_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_104.append(S3RGB_imgA1C2_4[i][j])  
S3meanrefA1_1204 = np.array(S3meanrefA1_1204)
S3meanC2_104 = np.array(S3meanC2_104)

S3rgbrefA1_1204 = list()
S3rgbC2_104 = list()
for i in range(3):
    S3rgbrefA1_1204.append(S3meanrefA1_1204[:,i].mean())
    S3rgbC2_104.append(S3meanC2_104[:,i].mean())

# %%
S3meanrefA1_1304 = list()
S3meanC3_104 = list()
for i in range(S3RGB_imgA1C3_4.shape[0]): 
     for j in range(S3RGB_imgA1C3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1304.append(S2RGB_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_104.append(S3RGB_imgA1C3_4[i][j])  
S3meanrefA1_1304 = np.array(S3meanrefA1_1304)
S3meanC3_104 = np.array(S3meanC3_104)

S3rgbrefA1_1304 = list()
S3rgbC3_104 = list()
for i in range(3):
    S3rgbrefA1_1304.append(S3meanrefA1_1304[:,i].mean())
    S3rgbC3_104.append(S3meanC3_104[:,i].mean())

# %%
S3meanrefA1_1404 = list()
S3meanC4_104 = list()
for i in range(S3RGB_imgA1C4_4.shape[0]): 
     for j in range(S3RGB_imgA1C4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1404.append(S2RGB_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_104.append(S2RGB_imgA1C4_4[i][j])  
S3meanrefA1_1404 = np.array(S2meanrefA1_1404)
S3meanC4_104 = np.array(S2meanC4_104)

S3rgbrefA1_1404 = list()
S3rgbC4_104 = list()
for i in range(3):
    S3rgbrefA1_1404.append(S3meanrefA1_1404[:,i].mean())
    S3rgbC4_104.append(S3meanC4_104[:,i].mean())

# %%
S3meanrefA1_1504 = list()
S3meanD2_104 = list()
for i in range(S3RGB_imgA1D2_4.shape[0]): 
     for j in range(S3RGB_imgA1D2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1504.append(S3RGB_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_104.append(S3RGB_imgA1D2_4[i][j])  
S3meanrefA1_1504 = np.array(S3meanrefA1_1504)
S3meanD2_104 = np.array(S3meanD2_104)

S3rgbrefA1_1504 = list()
S3rgbD2_104 = list()
for i in range(3):
    S3rgbrefA1_1504.append(S3meanrefA1_1504[:,i].mean())
    S3rgbD2_104.append(S3meanD2_104[:,i].mean())

# %%
S3meanrefA1_1604 = list()
S3meanD3_104 = list()
for i in range(S3RGB_imgA1D3_4.shape[0]): 
     for j in range(S3RGB_imgA1D3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1604.append(S3RGB_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_104.append(S3RGB_imgA1D3_4[i][j])  
S3meanrefA1_1604 = np.array(S3meanrefA1_1604)
S3meanD3_104 = np.array(S3meanD3_104)

S3rgbrefA1_1604 = list()
S3rgbD3_104 = list()
for i in range(3):
    S3rgbrefA1_1604.append(S3meanrefA1_1604[:,i].mean())
    S3rgbD3_104.append(S3meanD3_104[:,i].mean())

# %%
S3meanrefA1_1704= list()
S3meanD4_104 = list()
for i in range(S3RGB_imgA1D4_4.shape[0]): 
     for j in range(S3RGB_imgA1D4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1704.append(S3RGB_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_104.append(S3RGB_imgA1D4_4[i][j])  
S3meanrefA1_1704 = np.array(S3meanrefA1_1404)
S3meanD4_104 = np.array(S3meanD4_104)

S3rgbrefA1_1704 = list()
S3rgbD4_104 = list()
for i in range(3):
    S3rgbrefA1_1704.append(S3meanrefA1_1704[:,i].mean())
    S3rgbD4_104.append(S3meanD4_104[:,i].mean())

# %% [markdown]
# ###Img 5

# %%
S3meanrefA1_105 = list()
S3meanA1_205 = list()
for i in range(S3RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_105.append(S3RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_205.append(S3RGB_imgA1A1_5[i][j])  
S3meanrefA1_105 = np.array(S3meanrefA1_105)
S3meanA1_205 = np.array(S3meanA1_205)

S3rgbrefA1_105 = list()
S3rgbA1_205 = list()
for i in range(3):
    S3rgbrefA1_105.append(S3meanrefA1_105[:,i].mean())
    S3rgbA1_205.append(S3meanA1_2[:,i].mean())
S3rgbrefA1_105,S3rgbA1_205

# %%
S3meanrefA1_305 = list()
S3meanA2_105 = list()
for i in range(S3RGB_imgA1A2_5.shape[0]): 
     for j in range(S3RGB_imgA1A2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_305.append(S3RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_105.append(S3RGB_imgA1A2_5[i][j])  
S3meanrefA1_305 = np.array(S3meanrefA1_305 )
S3meanA2_105 = np.array(S3meanA2_105 )

S3rgbrefA1_305 = list()
S3rgbA2_105  = list()
for i in range(3):
    S3rgbrefA1_305 .append(S3meanrefA1_305 [:,i].mean())
    S3rgbA2_105 .append(S3meanA2_105 [:,i].mean())

# %%
S3meanrefA1_405  = list()
S3meanA3_105  = list()
for i in range(S3RGB_imgA1A3_505 .shape[0]): 
     for j in range(S3RGB_imgA1A3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_405 .append(S3RGB_imgA1A3_505 [i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_105 .append(S3RGB_imgA1A3_505 [i][j])  
S3meanrefA1_4 05 = np.array(S3meanrefA1_405 )
S3meanA3_105  = np.array(S3meanA3_105 )

S3rgbrefA1_405  = list()
S3rgbA3_105  = list()
for i in range(3):
    S3rgbrefA1_405 .append(S3meanrefA1_405 [:,i].mean())
    S3rgbA3_105 .append(S3meanA3_105 [:,i].mean())

# %%
S3meanrefA1_505  = list()
S3meanA3_5105  = list()
for i in range(S3RGB_imgA1A3_55.shape[0]): 
     for j in range(S3RGB_imgA1A3_55.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_505 .append(S3RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5105 .append(S3RGB_imgA1A3_55[i][j])  
S3meanrefA1_505  = np.array(S3meanrefA1_5)
S3meanA3_5105  = np.array(S3meanA3_51)

S3rgbrefA1_505  = list()
S3rgbA3_5105  = list()
for i in range(3):
    S3rgbrefA1_505 .append(S3meanrefA1_505 [:,i].mean())
    S3rgbA3_5105 .append(S3meanA3_5105 [:,i].mean())

# %%
S3meanrefA1_605  = list()
S3meanA4_105  = list()
for i in range(S3RGB_imgA1A4_5.shape[0]): 
     for j in range(S3RGB_imgA1A4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_605 .append(S3RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_105 .append(S3RGB_imgA1A4_5[i][j])  
S3meanrefA1_605 = np.array(S3meanrefA1_6)
S3meanA4_105 = np.array(S3meanA4_1)

S3rgbrefA1_605 = list()
S3rgbA4_105 = list()
for i in range(3):
    S3rgbrefA1_605.append(S3meanrefA1_605[:,i].mean())
    S3rgbA4_105.append(S3meanA4_105[:,i].mean())

# %%
S3meanrefA1_705 = list()
S3meanB1_105 = list()
for i in range(S3RGB_imgA1B1_505.shape[0]): 
     for j in range(S3RGB_imgA1B1_505.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_705.append(S3RGB_imgA1B1_505[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_105.append(S3RGB_imgA1B1_505[i][j])  
S3meanrefA1_705 = np.array(S3meanrefA1_705)
S3meanB1_105 = np.array(S3meanB1_105)

S3rgbrefA1_705 = list()
S3rgbB1_105 = list()
for i in range(3):
    S3rgbrefA1_705.append(S3meanrefA1_705[:,i].mean())
    S3rgbB1_105.append(S3meanB1_105[:,i].mean())

# %%
S3meanrefA1_805 = list()
S3meanB2_105 = list()
for i in range(S3RGB_imgA1B2_5.shape[0]): 
     for j in range(S3RGB_imgA1B2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_805.append(S3RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_105.append(S3RGB_imgA1B2_5[i][j])  
S3meanrefA1_805 = np.array(S3meanrefA1_8)
S3meanB2_105 = np.array(S3meanB2_1)

S3rgbrefA1_805 = list()
S3rgbB2_105 = list()
for i in range(3):
    S3rgbrefA1_805.append(S3meanrefA1_805[:,i].mean())
    S3rgbB2_105.append(S3meanB2_105[:,i].mean())

# %%
S3meanrefA1_905 = list()
S3meanB3_105 = list()
for i in range(S3RGB_imgA1B3_5.shape[0]): 
     for j in range(S3RGB_imgA1B3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_905.append(S3RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_105.append(S3RGB_imgA1B3_5[i][j])  
S3meanrefA1_905 = np.array(S3meanrefA1_905)
S3meanB3_105 = np.array(S3meanB3_105)

S3rgbrefA1_905 = list()
S3rgbB3_105 = list()
for i in range(3):
    S2rgbrefA1_905.append(S2meanrefA1_905[:,i].mean())
    S2rgbB3_105.append(S2meanB3_105[:,i].mean())

# %%
S3meanrefA1_1005 = list()
S3meanB4_105 = list()
for i in range(S3RGB_imgA1B4_5.shape[0]): 
     for j in range(S3RGB_imgA1B4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1005.append(S3RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_105.append(S3RGB_imgA1B4_5[i][j])  
S3meanrefA1_1005 = np.array(S3meanrefA1_10)
S3meanB4_105 = np.array(S3meanB4_1)

S3rgbrefA1_1005 = list()
S3rgbB4_105 = list()
for i in range(3):
    S3rgbrefA1_1005.append(S3meanrefA1_1005[:,i].mean())
    S2rgbB4_105.append(S3meanB4_105[:,i].mean())

# %%
S3meanrefA1_1105 = list()
S3meanC1_105 = list()
for i in range(S3RGB_imgA1C1_5.shape[0]): 
     for j in range(S3RGB_imgA1C1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1105.append(S3RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_105.append(S3RGB_imgA1C1_5[i][j])  
S3meanrefA1_1105 = np.array(S3meanrefA1_1105)
S3meanC1_105 = np.array(S3meanC1_105)

S3rgbrefA1_1105 = list()
S3rgbC1_105 = list()
for i in range(3):
    S3rgbrefA1_1105.append(S3meanrefA1_1105[:,i].mean())
    S3rgbC1_105.append(S3meanC1_105[:,i].mean())

# %%
S3meanrefA1_1205 = list()
S3meanC2_105 = list()
for i in range(S3RGB_imgA1C2_5.shape[0]): 
     for j in range(S3RGB_imgA1C2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1205.append(S3RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_105.append(S3RGB_imgA1C2_5[i][j])  
S3meanrefA1_1205 = np.array(S3meanrefA1_1205)
S3meanC2_105 = np.array(S3meanC2_105)

S3rgbrefA1_1205 = list()
S3rgbC2_105 = list()
for i in range(3):
    S3rgbrefA1_1205.append(S3meanrefA1_1205[:,i].mean())
    S3rgbC2_105.append(S3meanC2_105[:,i].mean())

# %%
S3meanrefA1_1305 = list()
S3meanC3_105 = list()
for i in range(S3RGB_imgA1C3_5.shape[0]): 
     for j in range(S3RGB_imgA1C3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1305.append(S3RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_105.append(S3RGB_imgA1C3_5[i][j])  
S3meanrefA1_1305 = np.array(S3meanrefA1_13)
S3meanC3_105 = np.array(S3meanC3_1)

S3rgbrefA1_1305 = list()
S3rgbC3_105 = list()
for i in range(3):
    S3rgbrefA1_1305.append(S3meanrefA1_1305[:,i].mean())
    S3rgbC3_105.append(S3meanC3_105[:,i].mean())

# %%
S3meanrefA1_1405 = list()
S3meanC4_105 = list()
for i in range(S3RGB_imgA1C4_5.shape[0]): 
     for j in range(S3RGB_imgA1C4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1405.append(S3RGB_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_105.append(S3RGB_imgA1C4_5[i][j])  
S3meanrefA1_1405 = np.array(S3meanrefA1_1405)
S3meanC4_105 = np.array(S3meanC4_105)

S3rgbrefA1_1405 = list()
S3rgbC4_105 = list()
for i in range(3):
    S3rgbrefA1_1405.append(S3meanrefA1_1405[:,i].mean())
    S3rgbC4_105.append(S3meanC4_105[:,i].mean())

# %%
S3meanrefA1_1505 = list()
S3meanD2_105 = list()
for i in range(S3RGB_imgA1D2_5.shape[0]): 
     for j in range(S3RGB_imgA1D2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1505.append(S3RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_105.append(S3RGB_imgA1D2_5[i][j])  
S3meanrefA1_1505 = np.array(S3meanrefA1_15)
S3meanD2_105 = np.array(S3meanD2_1)

S3rgbrefA1_1505 = list()
S3rgbD2_105 = list()
for i in range(3):
    S3rgbrefA1_1505.append(S3meanrefA1_1505[:,i].mean())
    S3rgbD2_105.appendS3meanD2_105[:,i].mean())

# %%
S3meanrefA1_1605 = list()
S3meanD3_105 = list()
for i in range(S3RGB_imgA1D3_505.shape[0]): 
     for j in range(S3RGB_imgA1D3_505.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1605.append(S3RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_105.append(S3RGB_imgA1D3_5 [i][j])  
S3meanrefA1_1605 = np.array(S3meanrefA1_1605)
S3meanD3_105 = np.array(S3meanD3_105)

S3rgbrefA1_1605 = list()
S3rgbD3_105 = list()
for i in range(3):
    S3rgbrefA1_1605.append(S3meanrefA1_1605[:,i].mean())
    S3rgbD3_105.append(S3meanD3_105[:,i].mean())

# %%
S3meanrefA1_1705= list()
S3meanD4_105 = list()
for i in range(S3RGB_imgA1D4_.shape[0]): 
     for j in range(S3RGB_imgA1D4_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1705.append(S3RGB_imgA1D4_1i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_105.append(S3RGB_imgA1D4_[i][j])  
S3meanrefA1_1705 = np.array(S3meanrefA1_1405)
S3meanD4_105 = np.array(S3meanD4_105)

S3rgbrefA1_1705 = list()
S3rgbD4_105 = list()
for i in range(3):
    S3rgbrefA1_1705.append(S3meanrefA1_1705[:,i].mean())
    S3rgbD4_105.append(S3meanD4_105[:,i].mean())

# %% [markdown]
# ###Img 6

# %%
S3meanrefA1_106 = list()
S3meanA1_206 = list()
for i in range(S3RGB_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_6.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_106.append(S3RGB_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_206.append(S3RGB_imgA1A1_6[i][j])  
S3meanrefA1_106 = np.array(S3meanrefA1_106)
S3meanA1_206 = np.array(S3meanA1_206)

S3rgbrefA1_106 = list()
S3rgbA1_206 = list()
for i in range(3):
    S3rgbrefA1_106.append(S3meanrefA1_106[:,i].mean())
    S3rgbA1_206.append(S3meanA1_206[:,i].mean())
S3rgbrefA1_106,S2rgbA1_206

# %%
S3meanrefA1_306 = list()
S3meanA2_106 = list()
for i in range(S3RGB_imgA1A2_6.shape[0]): 
     for j in range(S3RGB_imgA1A2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_306.append(S3RGB_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_106.append(S3RGB_imgA1A2_6[i][j])  
S3meanrefA1_306 = np.array(S3meanrefA1_306)
S3meanA2_106 = np.array(S3meanA2_106)

S3rgbrefA1_306 = list()
S3rgbA2_106 = list()
for i in range(3):
    S3rgbrefA1_306.append(S3meanrefA1_306[:,i].mean())
    S3rgbA2_106.append(S3meanA2_106[:,i].mean())

# %%
S3meanrefA1_406 = list()
S3meanA3_106 = list()
for i in range(S3RGB_imgA1A3_6.shape[0]): 
     for j in range(S3RGB_imgA1A3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_406.append(S3RGB_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_106.append(S3RGB_imgA1A3_6[i][j])  
S3meanrefA1_406 = np.array(S3meanrefA1_406)
S3meanA3_106 = np.array(S3meanA3_106)

S3rgbrefA1_406 = list()
S3rgbA3_106 = list()
for i in range(3):
    S3rgbrefA1_406.append(S3meanrefA1_406[:,i].mean())
    S3rgbA3_106.append(S3meanA3_106[:,i].mean())

# %%
S2meanrefA1_506 = list()
S2meanA3_5106 = list()
for i in range(S2RGB_imgA1A3_56.shape[0]): 
     for j in range(S2RGB_imgA1A3_56.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S2meanrefA1_506.append(S2RGB_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA3_5106.append(S2RGB_imgA1A3_56[i][j])  
S2meanrefA1_506 = np.array(S2meanrefA1_506)
S2meanA3_5106 = np.array(S2meanA3_5106)

S2rgbrefA1_506 = list()
S2rgbA3_5106 = list()
for i in range(3):
    S2rgbrefA1_506.append(S2meanrefA1_506[:,i].mean())
    S2rgbA3_5106.append(S2meanA3_5106[:,i].mean())

# %%
S3meanrefA1_606 = list()
S3meanA4_106 = list()
for i in range(S3RGB_imgA1A4_6.shape[0]): 
     for j in range(S3RGB_imgA1A4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_606.append(S3RGB_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_106.append(S3RGB_imgA1A4_6[i][j])  
S3meanrefA1_606 = np.array(S3meanrefA1_606)
S3meanA4_106 = np.array(S3meanA4_106)

S3rgbrefA1_606 = list()
S3rgbA4_106 = list()
for i in range(3):
    S3rgbrefA1_606.append(S3meanrefA1_606[:,i].mean())
    S3rgbA4_106.append(S3meanA4_106[:,i].mean())

# %%
S3meanrefA1_706 = list()
S3meanB1_106 = list()
for i in range(S3RGB_imgA1B1_6.shape[0]): 
     for j in range(S3RGB_imgA1B1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_706.append(S3RGB_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_106.append(S3RGB_imgA1B1_6[i][j])  
S3meanrefA1_706 = np.array(S3meanrefA1_706)
S3meanB1_106 = np.array(S3meanB1_106)

S3rgbrefA1_706 = list()
S3rgbB1_106 = list()
for i in range(3):
    S3rgbrefA1_706.append(S3meanrefA1_706[:,i].mean())
    S3rgbB1_106.append(S3meanB1_106[:,i].mean())

# %%
S3meanrefA1_806 = list()
S3meanB2_106 = list()
for i in range(S3RGB_imgA1B2_6.shape[0]): 
     for j in range(S3RGB_imgA1B2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_806.append(S3RGB_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_106.append(S3RGB_imgA1B2_6[i][j])  
S3meanrefA1_806 = np.array(S3meanrefA1_806)
S3meanB2_106 = np.array(S3meanB2_106)

S3rgbrefA1_806 = list()
S3rgbB2_106 = list()
for i in range(3):
    S3rgbrefA1_806.append(S3meanrefA1_806[:,i].mean())
    S3rgbB2_106.append(S3meanB2_106[:,i].mean())

# %%
S3meanrefA1_906 = list()
S3meanB3_106 = list()
for i in range(S3RGB_imgA1B3_6.shape[0]): 
     for j in range(S3RGB_imgA1B3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_906.append(S3RGB_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_106.append(S3RGB_imgA1B3_6[i][j])  
S3meanrefA1_906 = np.array(S3meanrefA1_906)
S3meanB3_106 = np.array(S3meanB3_106)

S3rgbrefA1_906 = list()
S3rgbB3_106 = list()
for i in range(3):
    S3rgbrefA1_906.append(S3meanrefA1_906[:,i].mean())
    S3rgbB3_106.append(S3meanB3_106[:,i].mean())

# %%
S3meanrefA1_1006 = list()
S3meanB4_106 = list()
for i in range(S3RGB_imgA1B4_6.shape[0]): 
     for j in range(S3RGB_imgA1B4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1006.append(S3RGB_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_106.append(S3RGB_imgA1B4_6[i][j])  
S3meanrefA1_1006 = np.array(S3meanrefA1_1006)
S3meanB4_106 = np.array(S3meanB4_106)

S3rgbrefA1_1006 = list()
S3rgbB4_106 = list()
for i in range(3):
    S3rgbrefA1_1006.append(S3meanrefA1_1006[:,i].mean())
    S3rgbB4_106.append(S3meanB4_106[:,i].mean())

# %%
S3meanrefA1_1106 = list()
S3meanC1_106 = list()
for i in range(S3RGB_imgA1C1_6.shape[0]): 
     for j in range(S3RGB_imgA1C1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1106.append(S3RGB_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_106.append(S3RGB_imgA1C1_6[i][j])  
S3meanrefA1_1106 = np.array(S3meanrefA1_1106)
S3meanC1_106 = np.array(S3meanC1_106)

S3rgbrefA1_1106 = list()
S3rgbC1_106 = list()
for i in range(3):
    S3rgbrefA1_1106.append(S3meanrefA1_1106[:,i].mean())
    S3rgbC1_106.append(S3meanC1_106[:,i].mean())

# %%
S3meanrefA1_1206 = list()
S3meanC2_106 = list()
for i in range(S3RGB_imgA1C2_6.shape[0]): 
     for j in range(S3RGB_imgA1C2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_1206.append(S3RGB_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_106.append(S3RGB_imgA1C2_6[i][j])  
S3meanrefA1_1206 = np.array(S3meanrefA1_1206)
S3meanC2_106 = np.array(S3meanC2_106)

S3rgbrefA1_1206 = list()
S3rgbC2_106 = list()
for i in range(3):
    S3rgbrefA1_1206.append(S3meanrefA1_1206[:,i].mean())
    S3rgbC2_106.append(S3meanC2_106[:,i].mean())

# %%
S3meanrefA1_1306 = list()
S3meanC3_106 = list()
for i in range(S3RGB_imgA1C3_6.shape[0]): 
     for j in range(S3RGB_imgA1C3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1306.append(S3RGB_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_106.append(S3RGB_imgA1C3_6[i][j])  
S3meanrefA1_1306 = np.array(S3meanrefA1_1306)
S3meanC3_106 = np.array(S3meanC3_106)

S3rgbrefA1_1306 = list()
S3rgbC3_106 = list()
for i in range(3):
    S3rgbrefA1_1306.append(S3meanrefA1_1306[:,i].mean())
     S3rgbC3_106.append(S3meanC3_106[:,i].mean())

# %%
S3meanrefA1_1406 = list()
S3meanC4_106 = list()
for i in range(S3RGB_imgA1C4_6.shape[0]): 
     for j in range(S3RGB_imgA1C4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_1406.append(S3RGB_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_106.append(S3RGB_imgA1C4_6[i][j])  
S3meanrefA1_1406 = np.array(S3meanrefA1_1406)
S3meanC4_106 = np.array(S3meanC4_106)

S3rgbrefA1_1406 = list()
S3rgbC4_106 = list()
for i in range(3):
    S3rgbrefA1_1406.append(S3meanrefA1_1406[:,i].mean())
   S3rgbC4_106.append(S3meanC4_106[:,i].mean())

# %%
S3meanrefA1_1506 = list()
S3meanD2_106 = list()
for i in range(S3RGB_imgA1D2_6.shape[0]): 
     for j in range(S3RGB_imgA1D2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1506.append(S3RGB_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_106.append(S3RGB_imgA1D2_6[i][j])  
S3meanrefA1_1506 = np.array(S3meanrefA1_1506)
S3meanD2_106 = np.array(S3meanD2_106)

S3rgbrefA1_1506 = list()
S3rgbD2_1 = list()
for i in range(3):
    S3rgbrefA1_15.append(S3meanrefA1_15[:,i].mean())
    S3rgbD2_1.append(S3meanD2_1[:,i].mean())

# %%
S3meanrefA1_16 = list()
S3meanD3_1 = list()
for i in range(S3RGB_imgA1D3_6.shape[0]): 
     for j in range(S3RGB_imgA1D3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_16.append(S3RGB_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_1.append(S3RGB_imgA1D3_6[i][j])  
S3meanrefA1_16 = np.array(S3meanrefA1_1606)
S3meanD3_106 = np.array(S3meanD3_106)

S3rgbrefA1_1606 = list()
S3rgbD3_106 = list()
for i in range(3):
    S3rgbrefA1_1606.append(S3meanrefA1_1606[:,i].mean())
    S3rgbD3_106.append(S3meanD3_106[:,i].mean())

# %%
S3meanrefA1_1706= list()
S3meanD4_106 = list()
for i in range(S3RGB_imgA1D4_6.shape[0]): 
     for j in range(S3RGB_imgA1D4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1706.append(S3RGB_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_106.append(S3RGB_imgA1D4_6[i][j])  
S3meanrefA1_1706 = np.array(S3meanrefA1_1406)
S3meanD4_106 = np.array(S3meanD4_106)

S3gbrefA1_1706 = list()
S3rgbD4_106 = list()
for i in range(3):
    S3rgbrefA1_1706.append(S3meanrefA1_1706[:,i].mean())
    S3rgbD4_106.append(S3meanD4_106[:,i].mean())

# %% [markdown]
# ###Img 7

# %%
S3meanrefA1_107 = list()
S3meanA1_207 = list()
for i in range(S3RGB_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_107.append(S3RGB_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_207.append(S3RGB_imgA1A1_7[i][j])  
S3meanrefA1_107 = np.array(S3meanrefA1_107)
S3meanA1_207 = np.array(S3meanA1_207)

S3rgbrefA1_107 = list()
S3rgbA1_207 = list()
for i in range(3):
    S3rgbrefA1_107.append(S3meanrefA1_107[:,i].mean())
    S3rgbA1_207.append(S2meanA1_207[:,i].mean())
S3rgbrefA1_107,S3rgbA1_207

# %%
S3meanrefA1_307 = list()
S3meanA2_107 = list()
for i in range(S3RGB_imgA1A2_7.shape[0]): 
     for j in range(S3RGB_imgA1A2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_307.append(S3RGB_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_107.append(S3RGB_imgA1A2_7[i][j])  
S3meanrefA1_307 = np.array(อmeanrefA1_307)
S3meanA2_107 = np.array(S3meanA2_107)

S3rgbrefA1_307 = list()
S3rgbA2_107 = list()
for i in range(3):
    S3rgbrefA1_307.append(S3meanrefA1_307[:,i].mean())
    S3rgbA2_107.append(S3meanA2_107[:,i].mean())

# %%
S3meanrefA1_407 = list()
S3meanA3_107 = list()
for i in range(S3RGB_imgA1A3_7.shape[0]): 
     for j in range(S3RGB_imgA1A3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_407.append(S3RGB_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_107.append(S3RGB_imgA1A3_7[i][j])  
S3meanrefA1_407 = np.array(S3meanrefA1_407)
S3meanA3_107 = np.array(S3meanA3_107)

S3rgbrefA1_407 = list()
S3rgbA3_107 = list()
for i in range(3):
    S2rgbrefA1_407.append(S2meanrefA1_407[:,i].mean())
    S3rgbA3_107.append(S3meanA3_107[:,i].mean())

# %%
S3meanrefA1_507 = list()
S3meanA3_5107 = list()
for i in range(S3RGB_imgA1A3_57.shape[0]): 
     for j in range(S3RGB_imgA1A3_57.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_507.append(S3RGB_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5107.append(S3RGB_imgA1A3_57[i][j])  
S3meanrefA1_507 = np.array(S3meanrefA1_507)
S3meanA3_5107 = np.array(S3meanA3_5107)

S3rgbrefA1_507 = list()
S3rgbA3_5107 = list()
for i in range(3):
    S3rgbrefA1_507.append(S3meanrefA1_507[:,i].mean())
    S3rgbA3_5107.append(S3meanA3_5107[:,i].mean())

# %%
S3meanrefA1_607 = list()
S3meanA4_107 = list()
for i in range(S3RGB_imgA1A4_7.shape[0]): 
     for j in range(S3RGB_imgA1A4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_607.append(S3RGB_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_107.append(S3RGB_imgA1A4_7[i][j])  
S3meanrefA1_607 = np.array(S3meanrefA1_607)
S3meanA4_107 = np.array(S3meanA4_107)

S3rgbrefA1_607 = list()
S3rgbA4_107 = list()
for i in range(3):
   S3rgbrefA1_607.append(S3meanrefA1_607[:,i].mean())
    S3rgbA4_107.append(S3meanA4_107[:,i].mean())

# %%
S3meanrefA1_707 = list()
S3meanB1_107 = list()
for i in range(S3RGB_imgA1B1_7.shape[0]): 
     for j in range(S3RGB_imgA1B1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_707.append(S3RGB_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_107.append(S3RGB_imgA1B1_7[i][j])  
S3meanrefA1_707 = np.array(S3meanrefA1_707)
S3meanB1_107 = np.array(S3meanB1_107)

S3rgbrefA1_707 = list()
S3rgbB1_107 = list()
for i in range(3):
    S3rgbrefA1_707.append(S3meanrefA1_707[:,i].mean())
    S3rgbB1_107.append(S3meanB1_107[:,i].mean())

# %%
S3meanrefA1_807 = list()
S3meanB2_107 = list()
for i in range(S3RGB_imgA1B2_7.shape[0]): 
     for j in range(S3RGB_imgA1B2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_807.append(S2RGB_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_107.append(S3RGB_imgA1B2_7[i][j])  
S3meanrefA1_807 = np.array(S3meanrefA1_807)
S3meanB2_107 = np.array(S3meanB2_107)

S3rgbrefA1_807 = list()
S3rgbB2_107 = list()
for i in range(3):
    S3rgbrefA1_807.append(S2meanrefA1_807[:,i].mean())
    S3rgbB2_107.append(S2meanB2_107[:,i].mean())

# %%
S3meanrefA1_907 = list()
S3meanB3_107 = list()
for i in range(S3RGB_imgA1B3_7.shape[0]): 
     for j in range(S3RGB_imgA1B3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_907.append(S3RGB_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_107.append(S3RGB_imgA1B3_7[i][j])  
S3meanrefA1_907 = np.array(S3meanrefA1_907)
S3meanB3_107 = np.array(S3meanB3_107)

S3rgbrefA1_907 = list()
S3rgbB3_107 = list()
for i in range(3):
    S3rgbrefA1_907.appendS3meanrefA1_907[:,i].mean())
    S3rgbB3_107.append(S3meanB3_107[:,i].mean())

# %%
S3meanrefA1_1007 = list()
S3meanB4_107 = list()
for i in range(S3RGB_imgA1B4_7.shape[0]): 
     for j in range(S3RGB_imgA1B4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1007.append(S3RGB_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_107.append(S3RGB_imgA1B4_7[i][j])  
S3meanrefA1_1007 = np.array(S3meanrefA1_1007)
S3meanB4_107 = np.array(S3meanB4_107)

S3rgbrefA1_1007 = list()
S3rgbB4_107 = list()
for i in range(3):
    S3rgbrefA1_1007.append(S3meanrefA1_1007[:,i].mean())
    S3rgbB4_107.append(S3meanB4_107[:,i].mean())

# %%
S3meanrefA1_1107 = list()
S3meanC1_107 = list()
for i in range(S3RGB_imgA1C1_7.shape[0]): 
     for j in range(S3RGB_imgA1C1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1107.append(S3RGB_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_107.append(S3RGB_imgA1C1_7[i][j])  
S3meanrefA1_1107 = np.array(S3meanrefA1_1107)
S3meanC1_107 = np.array(S3meanC1_107)

S3rgbrefA1_1107 = list()
S32rgbC1_107 = list()
for i in range(3):
    S3rgbrefA1_1107.append(S3meanrefA1_1107[:,i].mean())
    S3rgbC1_107.append(S3meanC1_107[:,i].mean())

# %%
S3meanrefA1_1207 = list()
S3meanC2_107 = list()
for i in range(S3RGB_imgA1C2_7.shape[0]): 
     for j in range(S3RGB_imgA1C2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1207.append(S3RGB_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_107.append(S3RGB_imgA1C2_7[i][j])  
S3meanrefA1_1207 = np.array(S3meanrefA1_1207)
S3meanC2_107 = np.array(S3meanC2_107)

S3rgbrefA1_1207 = list()
S3rgbC2_107 = list()
for i in range(3):
    S3rgbrefA1_1207.append(S3meanrefA1_1207[:,i].mean())
    S3rgbC2_107.append(S3meanC2_107[:,i].mean())

# %%
S3meanrefA1_1307 = list()
S3meanC3_107 = list()
for i in range(S3RGB_imgA1C3_7.shape[0]): 
     for j in range(S3RGB_imgA1C3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1307.append(S3RGB_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_107.append(S3RGB_imgA1C3_7[i][j])  
S3meanrefA1_1307 = np.array(S3meanrefA1_1307)
S3meanC3_107 = np.array(S3meanC3_107)

S3rgbrefA1_1307 = list()
S3rgbC3_107 = list()
for i in range(3):
    S3rgbrefA1_1307.append(S3meanrefA1_1307[:,i].mean())
    S3rgbC3_107.append(S3meanC3_107[:,i].mean())

# %%
S3meanrefA1_1407 = list()
S3meanC4_107 = list()
for i in range(S3RGB_imgA1C4_7.shape[0]): 
     for j in range(S3RGB_imgA1C4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_1407.append(S3RGB_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_107.append(S3RGB_imgA1C4_7[i][j])  
S3meanrefA1_1407 = np.array(S3meanrefA1_1407)
S3meanC4_107 = np.array(S3meanC4_107)

S3rgbrefA1_1407 = list()
S3rgbC4_107 = list()
for i in range(3):
    S3rgbrefA1_1407.append(S2meanrefA1_1407[:,i].mean())
    S3rgbC4_107.append(S2meanC4_107[:,i].mean())

# %%
S3meanrefA1_1507 = list()
S3meanD2_107 = list()
for i in range(S3RGB_imgA1D2_7.shape[0]): 
     for j in range(S3RGB_imgA1D2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1507.append(S3RGB_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_107.append(S3RGB_imgA1D2_7[i][j])  
S3meanrefA1_1507 = np.array(S3meanrefA1_1507)
S3meanD2_107 = np.array(S3meanD2_107)

S3rgbrefA1_1507 = list()
S3rgbD2_107 = list()
for i in range(3):
    S3rgbrefA1_1507.append(S3meanrefA1_1507[:,i].mean())
    S3rgbD2_107.append(S3meanD2_107[:,i].mean())

# %%
S3meanrefA1_1607 = list()
S3meanD3_107 = list()
for i in range(S3RGB_imgA1D3_7.shape[0]): 
     for j in range(S3RGB_imgA1D3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1607.append(S3RGB_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_107.append(S3RGB_imgA1D3_7[i][j])  
S3meanrefA1_1607 = np.array(S3meanrefA1_1607)
S3meanD3_107 = np.array(S3meanD3_107)

S3rgbrefA1_1607 = list()
S3rgbD3_107 = list()
for i in range(3):
    S3rgbrefA1_1607.append(S3meanrefA1_1607[:,i].mean())
    S3rgbD3_107.append(S3meanD3_107[:,i].mean())

# %%
S3meanrefA1_1707= list()
S3meanD4_107 = list()
for i in range(S3RGB_imgA1D4_7.shape[0]): 
     for j in range(S3RGB_imgA1D4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1707.append(S3RGB_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_107.append(S3RGB_imgA1D4_7[i][j])  
S3meanrefA1_1707 = np.array(S3meanrefA1_1407)
S3meanD4_107 = np.array(S3meanD4_107)

S3rgbrefA1_1707 = list()
S3rgbD4_107 = list()
for i in range(3):
    S3rgbrefA1_1707.append(S3meanrefA1_1707[:,i].mean())
    S3rgbD4_107.append(S3meanD4_107[:,i].mean())

# %% [markdown]
# ###Img 8

# %%
S3meanrefA1_108 = list()
S3meanA1_208 = list()
for i in range(S3RGB_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_108.append(S2RGB_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_208.append(S3RGB_imgA1A1_8[i][j])  
S3meanrefA1_108 = np.array(S3meanrefA1_108)
S3meanA1_208 = np.array(S3meanA1_208)

S3rgbrefA1_108 = list()
S3rgbA1_208 = list()
for i in range(3):
    S3rgbrefA1_108.append(S3meanrefA1_108[:,i].mean())
    S3rgbA1_208.append(S3meanA1_208[:,i].mean())
S2rgbrefA1_108,S1rgbA1_208

# %%
S3meanrefA1_308 = list()
S3meanA2_108 = list()
for i in range(S3RGB_imgA1A2_8.shape[0]): 
     for j in range(S3RGB_imgA1A2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_308.append(S3RGB_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_108.append(S3RGB_imgA1A2_8[i][j])  
S3meanrefA1_308 = np.array(S3meanrefA1_308)
S3meanA2_108 = np.array(S3meanA2_108)

S3rgbrefA1_308 = list()
S3rgbA2_108 = list()
for i in range(3):
    S3rgbrefA1_308.append(S2meanrefA1_308[:,i].mean())
    S3rgbA2_108.append(S3meanA2_108[:,i].mean())

# %%
S3meanrefA1_408 = list()
S3meanA3_108 = list()
for i in range(S3RGB_imgA1A3_8.shape[0]): 
     for j in range(S3RGB_imgA1A3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_408.append(S2RGB_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_108.append(S3RGB_imgA1A3_8[i][j])  
S3meanrefA1_408 = np.array(S3meanrefA1_408)
S3meanA3_108 = np.array(S3meanA3_108)

S3rgbrefA1_408 = list()
S3rgbA3_108 = list()
for i in range(3):
    S3rgbrefA1_408.append(S3meanrefA1_408[:,i].mean())
    S3rgbA3_108.append(S3meanA3_108[:,i].mean())

# %%
S3meanrefA1_508 = list()
S3meanA3_5108 = list()
for i in range(S3RGB_imgA1A3_58.shape[0]): 
     for j in range(S3RGB_imgA1A3_58.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_508.append(S3RGB_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5108.append(S3RGB_imgA1A3_58[i][j])  
S3meanrefA1_508 = np.array(S3meanrefA1_508)
S3meanA3_5108 = np.array(S3meanA3_5108)

S3rgbrefA1_508 = list()
S3rgbA3_5108 = list()
for i in range(3):
    S3rgbrefA1_508.append(S3meanrefA1_508[:,i].mean())
    S3rgbA3_5108.append(S3meanA3_5108[:,i].mean())

# %%
S3meanrefA1_608 = list()
S3meanA4_108 = list()
for i in range(S3RGB_imgA1A4_8.shape[0]): 
     for j in range(S3RGB_imgA1A4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_608.append(S3RGB_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_108.append(S3RGB_imgA1A4_8[i][j])  
S3meanrefA1_608 = np.array(S3meanrefA1_608)
S3meanA4_108 = np.array(S3meanA4_108)

S3rgbrefA1_608 = list()
S3rgbA4_108 = list()
for i in range(3):
    S3rgbrefA1_608.append(S3meanrefA1_608[:,i].mean())
    S3rgbA4_108.append(S3meanA4_108[:,i].mean())

# %%
S3meanrefA1_708 = list()
S3meanB1_108 = list()
for i in range(S3RGB_imgA1B1_8.shape[0]): 
     for j in range(S3RGB_imgA1B1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_708.append(S3RGB_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_108.append(S3RGB_imgA1B1_8[i][j])  
S3meanrefA1_708 = np.array(S3meanrefA1_708)
S3meanB1_108 = np.array(S3meanB1_108)

S3rgbrefA1_708 = list()
S3rgbB1_108 = list()
for i in range(3):
    S3rgbrefA1_708.append(S3meanrefA1_708[:,i].mean())
    S3rgbB1_108.append(S3meanB1_108[:,i].mean())

# %%
S3meanrefA1_808 = list()
S3meanB2_108 = list()
for i in range(S3RGB_imgA1B2_8.shape[0]): 
     for j in range(S3RGB_imgA1B2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_808.append(S3RGB_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_108.append(S3RGB_imgA1B2_8[i][j])  
S3meanrefA1_808 = np.array(S3meanrefA1_808)
S3meanB2_108 = np.array(S3meanB2_108)

S3rgbrefA1_808 = list()
S3rgbB2_108 = list()
for i in range(3):
    S3rgbrefA1_808.append(S3meanrefA1_808[:,i].mean())
    S3rgbB2_108.append(S3meanB2_108[:,i].mean())

# %%
S3meanrefA1_908 = list()
S3meanB3_108 = list()
for i in range(S3RGB_imgA1B3_8.shape[0]): 
     for j in range(S3RGB_imgA1B3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_908.append(S3RGB_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_108.append(S3RGB_imgA1B3_8[i][j])  
S3meanrefA1_908 = np.array(S3meanrefA1_908)
S3meanB3_108 = np.array(S3meanB3_108)

S3rgbrefA1_908 = list()
S3rgbB3_108 = list()
for i in range(3):
    S3rgbrefA1_908.append(S2meanrefA1_908[:,i].mean())
    S3rgbB3_108.append(S2meanB3_108[:,i].mean())

# %%
S3meanrefA1_1008 = list()
S3meanB4_108 = list()
for i in range(S3RGB_imgA1B4_8.shape[0]): 
     for j in range(S3RGB_imgA1B4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1008.append(S2RGB_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_108.append(S3RGB_imgA1B4_8[i][j])  
S3meanrefA1_1008 = np.array(S3meanrefA1_1008)
S3meanB4_108 = np.array(S3meanB4_108)

S3rgbrefA1_1008 = list()
S3rgbB4_108 = list()
for i in range(3):
    S3rgbrefA1_1008.append(S3meanrefA1_1008[:,i].mean())
    S3rgbB4_108.append(S3meanB4_108[:,i].mean())

# %%
S3meanrefA1_1108 = list()
S3meanC1_108 = list()
for i in range(S3RGB_imgA1C1_8.shape[0]): 
     for j in range(S3RGB_imgA1C1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1108.append(S3RGB_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_108.append(S3RGB_imgA1C1_8[i][j])  
S3meanrefA1_1108 = np.array(S3meanrefA1_1108)
S3meanC1_108 = np.array(S2meanC1_108)

S3rgbrefA1_1108 = list()
S3rgbC1_108 = list()
for i in range(3):
    S3rgbrefA1_1108.append(S3meanrefA1_1108[:,i].mean())
    S3rgbC1_108.append(S3meanC1_108[:,i].mean())

# %%
S3meanrefA1_1208 = list()
S3meanC2_108 = list()
for i in range(S3RGB_imgA1C2_8.shape[0]): 
     for j in range(S3RGB_imgA1C2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1208.append(S3RGB_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_108.append(S3RGB_imgA1C2_8[i][j])  
S3meanrefA1_1208 = np.array(S3meanrefA1_1208)
S3meanC2_108 = np.array(S3meanC2_108)

S3rgbrefA1_1208 = list()
S3rgbC2_108 = list()
for i in range(3):
    S3rgbrefA1_1208.append(S3meanrefA1_1208[:,i].mean())
    S3rgbC2_108.append(S3meanC2_108[:,i].mean())

# %%
S3meanrefA1_1308 = list()
S3meanC3_108 = list()
for i in range(S3RGB_imgA1C3_8.shape[0]): 
     for j in range(S3RGB_imgA1C3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1308.append(S3RGB_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_108.append(S3RGB_imgA1C3_8[i][j])  
S3meanrefA1_1308 = np.array(S3meanrefA1_1308)
S3meanC3_108 = np.array(S3meanC3_108)

S3rgbrefA1_1308 = list()
S3rgbC3_108 = list()
for i in range(3):
    S3rgbrefA1_1308.append(S3meanrefA1_1308[:,i].mean())
    S3rgbC3_108.append(S3meanC3_108[:,i].mean())

# %%
S3meanrefA1_1408 = list()
S3meanC4_108 = list()
for i in range(S3RGB_imgA1C4_8.shape[0]): 
     for j in range(S3RGB_imgA1C4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1408.append(S3RGB_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_108.append(S3RGB_imgA1C4_8[i][j])  
S3meanrefA1_1408 = np.array(S3meanrefA1_1408)
S3meanC4_108 = np.array(S3meanC4_108)

S3rgbrefA1_1408 = list()
S3rgbC4_108 = list()
for i in range(3):
    S3rgbrefA1_1408.append(S3meanrefA1_1408[:,i].mean())
   S3rgbC4_108.append(S3meanC4_108[:,i].mean())

# %%
S3meanrefA1_1508 = list()
S3meanD2_108 = list()
for i in range(S3RGB_imgA1D2_8.shape[0]): 
     for j in range(S3RGB_imgA1D2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1508.append(S3RGB_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_108.append(S3RGB_imgA1D2_8[i][j])  
S3meanrefA1_1508 = np.array(S3meanrefA1_1508)
S3meanD2_108 = np.array(S3meanD2_108)

S3rgbrefA1_1508 = list()
S3rgbD2_108 = list()
for i in range(3):
    S3rgbrefA1_1508.append(S3meanrefA1_1508[:,i].mean())
    S3rgbD2_108.append(S3meanD2_108[:,i].mean())

# %%
S3meanrefA1_1608 = list()
S3meanD3_108 = list()
for i in range(S3RGB_imgA1D3_8.shape[0]): 
     for j in range(S3RGB_imgA1D3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1608.append(S3RGB_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanD3_108.append(S3RGB_imgA1D3_8[i][j])  
S3meanrefA1_1608 = np.array(S3meanrefA1_1608)
S3meanD3_108 = np.array(S3meanD3_108)

S3rgbrefA1_1608 = list()
S3rgbD3_108 = list()
for i in range(3):
    S3rgbrefA1_1608.append(S3meanrefA1_1608[:,i].mean())
    S3rgbD3_108.append(S3meanD3_108[:,i].mean())

# %%
S3meanrefA1_1708= list()
S3meanD4_108 = list()
for i in range(S3RGB_imgA1D4_8.shape[0]): 
     for j in range(S3RGB_imgA1D4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1708.append(S3RGB_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_108.append(S3RGB_imgA1D4_8[i][j])  
S3meanrefA1_1708 = np.array(S3meanrefA1_1408)
S3meanD4_108 = np.array(S3meanD4_108)

S3rgbrefA1_1708 = list()
S3rgbD4_108 = list()
for i in range(3):
    S3rgbrefA1_1708.append(S3meanrefA1_1708[:,i].mean())
    S3rgbD4_108.append(S3meanD4_108[:,i].mean())

# %% [markdown]
# ###Img 9

# %%
S3meanrefA2_109 = list()
S3meanA2_209 = list()
for i in range(S3RGB_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_109.append(S3RGB_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_209.append(S3RGB_imgA1A1_9[i][j])  
S3meanrefA1_109 = np.array(S3meanrefA1_109)
S3meanA1_209 = np.array(S3meanA1_209)

S3rgbrefA1_109 = list()
S3rgbA1_209 = list()
for i in range(3):
    S3gbrefA1_109.append(S3meanrefA1_109[:,i].mean())
    S3rgbA1_209.append(S3meanA1_209[:,i].mean())
S3rgbrefA1_109,S3rgbA1_209

# %%
S3meanrefA1_309 = list()
S3meanA2_109 = list()
for i in range(S3RGB_imgA1A2_9.shape[0]): 
     for j in range(S3RGB_imgA1A2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_309.append(S2RGB_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_109.append(S3RGB_imgA1A2_9[i][j])  
S3meanrefA1_309 = np.array(S3meanrefA1_309)
S3meanA2_109 = np.array(S3meanA2_109)

S3rgbrefA1_309 = list()
S3rgbA2_109 = list()
for i in range(3):
    S3rgbrefA1_309.append(S3meanrefA1_309[:,i].mean())
    S3rgbA2_109.append(S3meanA2_109[:,i].mean())

# %%
S3meanrefA1_409 = list()
S3meanA3_109 = list()
for i in range(S3RGB_imgA1A3_9.shape[0]): 
     for j in range(S3RGB_imgA1A3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_409.append(S3RGB_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_109.append(S3RGB_imgA1A3_9[i][j])  
S3meanrefA1_409 = np.array(S3meanrefA1_409)
S3meanA3_109 = np.array(S3meanA3_109)

S3rgbrefA1_409 = list()
S3rgbA3_109 = list()
for i in range(3):
    S3rgbrefA1_409.append(S3meanrefA1_409[:,i].mean())
    S3rgbA3_109.append(S3meanA3_109[:,i].mean())

# %%
S3meanrefA1_509 = list()
S3meanA3_5109 = list()
for i in range(S3RGB_imgA1A3_59.shape[0]): 
     for j in range(S3RGB_imgA1A3_59.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_509.append(S3RGB_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5109.append(S3RGB_imgA1A3_59[i][j])  
S3meanrefA1_509 = np.array(S3meanrefA1_509)
S3meanA3_5109 = np.array(S3meanA3_5109)

S3rgbrefA1_509 = list()
S3rgbA3_5109 = list()
for i in range(3):
    S3rgbrefA1_509.append(S3meanrefA1_509[:,i].mean())
    S3rgbA3_5109.append(S3meanA3_5109[:,i].mean())

# %%
S3meanrefA1_609 = list()
S3meanA4_109 = list()
for i in range(S3RGB_imgA1A4_9.shape[0]): 
     for j in range(S3RGB_imgA1A4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_609.append(S3RGB_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_109.append(S3RGB_imgA1A4_9[i][j])  
S3meanrefA1_609 = np.array(S3meanrefA1_609)
S3meanA4_109 = np.array(S3meanA4_109)

S3rgbrefA1_609 = list()
S3rgbA4_109 = list()
for i in range(3):
    S3rgbrefA1_609.append(S3meanrefA1_609[:,i].mean())
    S3rgbA4_109.append(S3meanA4_109[:,i].mean())

# %%
S3meanrefA1_709 = list()
S3meanB1_109 = list()
for i in range(S3RGB_imgA1B1_9.shape[0]): 
     for j in range(S3RGB_imgA1B1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_709.append(S3RGB_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_109.append(S3RGB_imgA1B1_9[i][j])  
S3meanrefA1_709 = np.array(S3meanrefA1_709)
S3meanB1_109 = np.array(S3meanB1_109)

S3rgbrefA1_709 = list()
S3rgbB1_109 = list()
for i in range(3):
    S3rgbrefA1_709.append(S3meanrefA1_709[:,i].mean())
    S3rgbB1_109.append(S3meanB1_109[:,i].mean())

# %%
S3meanrefA1_809 = list()
S3meanB2_109 = list()
for i in range(S3RGB_imgA2B2_9.shape[0]): 
     for j in range(S3RGB_imgA2B2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_809.append(S3RGB_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_109.append(S3RGB_imgA1B2_9[i][j])  
S3meanrefA1_809 = np.array(S3meanrefA1_809)
S3meanB2_109 = np.array(S3meanB2_109)

S3rgbrefA1_809 = list()
S3rgbB2_109 = list()
for i in range(3):
    S3rgbrefA1_809.append(S3meanrefA1_809[:,i].mean())
    S3rgbB2_109.append(S3meanB2_109[:,i].mean())

# %%
S3meanrefA1_909 = list()
S3meanB3_109 = list()
for i in range(S3RGB_imgA1B3_9.shape[0]): 
     for j in range(S3RGB_imgA1B3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_909.append(S3RGB_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_109.append(S3RGB_imgA1B3_9[i][j])  
S3meanrefA1_909 = np.array(S3meanrefA1_909)
S3meanB3_109 = np.array(S3meanB3_109)

S3rgbrefA1_909 = list()
S3rgbB3_109 = list()
for i in range(3):
    S3rgbrefA1_909.append(S3meanrefA1_909[:,i].mean())
    S3rgbB3_109.append(S3meanB3_109[:,i].mean())

# %%
S3meanrefA1_1009 = list()
S3meanB4_109 = list()
for i in range(S3RGB_imgA1B4_9.shape[0]): 
     for j in range(S3RGB_imgA1B4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1009.append(S3RGB_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_109.append(S3RGB_imgA1B4_9[i][j])  
S3meanrefA1_1009 = np.array(S3meanrefA1_1009)
S3meanB4_109 = np.array(S3meanB4_109)

S3rgbrefA1_1009 = list()
S3rgbB4_109 = list()
for i in range(3):
    S3rgbrefA1_1009.append(S3meanrefA1_1009[:,i].mean())
    S3rgbB4_109.append(S3meanB4_109[:,i].mean())

# %%
S3meanrefA1_1109 = list()
S3meanC1_109 = list()
for i in range(S3RGB_imgA1C1_9.shape[0]): 
     for j in range(S3RGB_imgA1C1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1109.append(S3RGB_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_109.append(S3RGB_imgA1C1_9[i][j])  
S3meanrefA1_1109 = np.array(S3meanrefA1_1109)
S3meanC1_109 = np.array(S3meanC1_109)

S3rgbrefA1_1109 = list()
S3rgbC1_109 = list()
for i in range(3):
   S3rgbrefA1_1109.append(S3meanrefA1_1109[:,i].mean())
    S3rgbC1_109.append(S3meanC1_109[:,i].mean())

# %%
S3meanrefA1_1209 = list()
S3meanC2_109 = list()
for i in range(S3RGB_imgA1C2_9.shape[0]): 
     for j in range(S3RGB_imgA1C2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1209.append(S3RGB_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_109.append(S3RGB_imgA1C2_9[i][j])  
S3meanrefA1_1209 = np.array(S3meanrefA1_1209)
S3meanC2_109 = np.array(S3meanC2_109)

S3rgbrefA1_1209 = list()
S3rgbC2_109 = list()
for i in range(3):
    S3rgbrefA1_1209.append(S3meanrefA1_1209[:,i].mean())
    S3rgbC2_109.append(S3meanC2_109[:,i].mean())

# %%
S3meanrefA1_13 = list()
S3meanC3_1 = list()
for i in range(S3RGB_imgA1C3_9.shape[0]): 
     for j in range(S3RGB_imgA1C3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_13.append(S2RGB_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanC3_1.append(S3RGB_imgA1C3_9[i][j])  
S3meanrefA1_13 = np.array(S3meanrefA1_13)
S3meanC3_1 = np.array(S3meanC3_1)

S3rgbrefA1_13 = list()
S3rgbC3_1 = list()
for i in range(3):
    S3rgbrefA1_13.append(S3meanrefA1_13[:,i].mean())
    S3rgbC3_1.append(S3meanC3_1[:,i].mean())

# %%
S3meanrefA1_1409 = list()
S3meanC4_109 = list()
for i in range(S3RGB_imgA1C4_9.shape[0]): 
     for j in range(S3RGB_imgA1C4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1409.append(S3RGB_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_109.append(S3RGB_imgA1C4_9[i][j])  
S3meanrefA1_1409 = np.array(S3meanrefA1_1409)
S3meanC4_109 = np.array(S3meanC4_109)

S3rgbrefA1_1409 = list()
S3rgbC4_109 = list()
for i in range(3):
     S3rgbrefA1_1409.append(S3meanrefA1_1409[:,i].mean())
     S3rgbC4_109.append(S3meanC4_109[:,i].mean())

# %%
S3meanrefA1_1509 = list()
S3meanD2_109 = list()
for i in range(S3RGB_imgA1D2_9.shape[0]): 
     for j in range(S3RGB_imgA1D2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1509.append(S2RGB_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_109.append(S2RGB_imgA1D2_9[i][j])  
S3meanrefA1_1509 = np.array(S1meanrefA1_1509)
S3meanD2_109 = np.array(S2meanD2_109)

S3rgbrefA1_1509 = list()
S3rgbD2_109 = list()
for i in range(3):
    S3rgbrefA1_1509.append(S3meanrefA1_1509[:,i].mean())
    S3rgbD2_109.append(S3meanD2_109[:,i].mean())

# %%
S3meanrefA1_1609 = list()
S3meanD3_109 = list()
for i in range(S3RGB_imgA1D3_9.shape[0]): 
     for j in range(S3RGB_imgA1D3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1609.append(S3RGB_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_109.append(S3RGB_imgA1D3_9[i][j])  
S3meanrefA1_1609 = np.array(S3meanrefA1_1609)
S3meanD3_109 = np.array(S3meanD3_109)

S3rgbrefA1_1609 = list()
S3rgbD3_109 = list()
for i in range(3):
    S3rgbrefA1_1609.append(S3meanrefA1_1609[:,i].mean())
    S3rgbD3_109.append(S3meanD3_109[:,i].mean())

# %%
S3meanrefA1_1709= list()
S3meanD4_109 = list()
for i in rangeS3RGB_imgA1D4_9.shape[0]): 
     for j in range(S3RGB_imgA1D4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1709.append(S3RGB_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_109.append(S3RGB_imgA1D4_9[i][j])  
S3meanrefA1_1709 = np.array(S3meanrefA1_1409)
S3meanD4_109 = np.array(S3meanD4_109)

S3rgbrefA1_1709 = list()
S3rgbD4_109 = list()
for i in range(3):
    S3rgbrefA1_1709.append(S3meanrefA1_1709[:,i].mean())
   S3rgbD4_109.append(S3meanD4_109[:,i].mean())

# %% [markdown]
# ###Img 10

# %%
S3meanrefA1_110 = list()
S3meanA1_210 = list()
for i in range(S3RGB_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3RGB_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_110.append(S3RGB_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_210.append(S3RGB_imgA1A1_10[i][j])  
S3meanrefA1_110 = np.array(S3meanrefA1_110)
S3meanA1_210 = np.array(S3meanA1_210)

S3rgbrefA1_110 = list()
S3rgbA1_210 = list()
for i in range(3):
    S3rgbrefA1_110.append(S2meanrefA1_110[:,i].mean())
    S3rgbA1_210.append(S2meanA1_210[:,i].mean())
S3rgbrefA1_110,S2rgbA1_210

# %%
S3meanrefA1_310 = list()
S3meanA2_110 = list()
for i in range(S3RGB_imgA1A2_10.shape[0]): 
     for j in range(S3RGB_imgA1A2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_310.append(S2RGB_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S2meanA2_110.append(S2RGB_imgA1A2_10[i][j])  
S3meanrefA1_310 = np.array(S3meanrefA1_310)
S3meanA2_110 = np.array(S3meanA2_110)

S3rgbrefA1_310 = list()
S3rgbA2_110 = list()
for i in range(3):
    S3rgbrefA1_310.append(S3meanrefA1_310[:,i].mean())
    S3rgbA2_110.append(S3meanA2_110[:,i].mean())

# %%
S3meanrefA1_410 = list()
S3meanA3_110 = list()
for i in range(S3RGB_imgA1A3_10.shape[0]): 
     for j in range(S3RGB_imgA1A3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_410.append(S3RGB_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_110.append(S3RGB_imgA1A3_10[i][j])  
S3meanrefA1_410 = np.array(S3meanrefA1_410)
S3meanA3_110 = np.array(S3meanA3_110)

S3rgbrefA1_410 = list()
S3rgbA3_110 = list()
for i in range(3):
    S3rgbrefA1_410.append(S3meanrefA1_410[:,i].mean())
    S3rgbA3_110.append(S3meanA3_110[:,i].mean())

# %%
S3meanrefA1_510 = list()
S3meanA3_5110 = list()
for i in range(S3RGB_imgA1A3_510.shape[0]): 
     for j in range(S3RGB_imgA1A3_510.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_510.append(S3RGB_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5110.append(S3RGB_imgA1A3_510[i][j])  
S3meanrefA1_510 = np.array(S3meanrefA1_510)
S3meanA3_5110 = np.array(S3meanA3_5110)

S3rgbrefA1_510 = list()
S3rgbA3_5110 = list()
for i in range(3):
    S3rgbrefA1_510.append(S3meanrefA1_51010[:,i].mean())
    S3rgbA3_5110.append(S3meanA3_511010[:,i].mean())

# %%
S3meanrefA1_610 = list()
S3meanA4_110 = list()
for i in range(S3RGB_imgA1A4_10.shape[0]): 
     for j in range(S3RGB_imgA1A4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_610.append(S2RGB_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_110.append(S2RGB_imgA1A4_10[i][j])  
S3meanrefA1_610 = np.array(S3meanrefA1_610)
S3meanA4_110 = np.array(S3meanA4_110)

S3rgbrefA1_610 = list()
S3rgbA4_110 = list()
for i in range(3):
    S3rgbrefA1_610.append(S3meanrefA1_610[:,i].mean())
    S3rgbA4_110.append(S3meanA4_110[:,i].mean())

# %%
S3meanrefA1_710 = list()
S3meanB1_110 = list()
for i in range(S3RGB_imgA1B1_10 .shape[0]): 
     for j in range(S3RGB_imgA1B1_10 .shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_710.append(S3RGB_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_110.append(S3RGB_imgA1B1_10 [i][j])  
S3meanrefA1_710 = np.array(S3meanrefA1_710)
S3meanB1_110 = np.array(S3meanB1_110)

S3rgbrefA1_710 = list()
S3rgbB1_110 = list()
for i in range(3):
    S3rgbrefA1_710.append(S3meanrefA1_710[:,i].mean())
    S3rgbB1_110.append(S3meanB1_110[:,i].mean())

# %%
S3meanrefA1_810 = list()
S3meanB2_110 = list()
for i in range(S3RGB_imgA1B2_10 .shape[0]): 
     for j in range(S3RGB_imgA1B2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_810.append(S2RGB_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_110.append(S2RGB_imgA1B2_10[i][j])  
S3meanrefA1_810 = np.array(S2meanrefA1_810)
S3meanB2_110 = np.array(S2meanB2_110)

S3rgbrefA1_810 = list()
S3rgbB2_110 = list()
for i in range(3):
    S3rgbrefA1_810.append(S3meanrefA1_810[:,i].mean())
    S3rgbB2_110.append(S3meanB2_110[:,i].mean())

# %%
S3meanrefA1_910 = list()
S3meanB3_110 = list()
for i in range(S3RGB_imgA1B3_10.shape[0]): 
     for j in range(S3RGB_imgA1B3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_910.append(S3RGB_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_110.append(S3RGB_imgA1B3_10[i][j])  
S3meanrefA1_910 = np.array(S3meanrefA1_910)
S3meanB3_110 = np.array(S3meanB3_110)

S3rgbrefA1_910 = list()
S3rgbB3_110 = list()
for i in range(3):
    S3rgbrefA1_910.append(S3meanrefA1_910[:,i].mean())
    S3rgbB3_110.append(S3meanB3_110[:,i].mean())

# %%
S3meanrefA1_1010 = list()
S3meanB4_110 = list()
for i in range(S3RGB_imgA1B4_10.shape[0]): 
     for j in range(S3RGB_imgA1B4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1010.append(S3RGB_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_110.append(S3RGB_imgA1B4_10[i][j])  
S3meanrefA1_1010 = np.array(S3meanrefA1_1010)
S3meanB4_110 = np.array(S3meanB4_110)

S3rgbrefA1_1010 = list()
S3rgbB4_110 = list()
for i in range(3):
    S3rgbrefA1_1010.append(S3meanrefA1_1010[:,i].mean())
    S3rgbB4_110.append(S3meanB4_110[:,i].mean())

# %%
S3meanrefA1_1110 = list()
S3meanC1_110 = list()
for i in range(S3RGB_imgA1C1_10.shape[0]): 
     for j in range(S3RGB_imgA1C1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1110.append(S3RGB_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_110.append(S3RGB_imgA1C1_10[i][j])  
S3meanrefA1_1110 = np.array(S3meanrefA1_1110)
S3meanC1_110 = np.array(S3meanC1_110)

S3rgbrefA1_1110 = list()
S3rgbC1_110 = list()
for i in range(3):
    S3rgbrefA1_1110.append(S3meanrefA1_1110[:,i].mean())
    S3rgbC1_110.append(S3meanC1_110[:,i].mean())

# %%
S3meanrefA1_1210 = list()
S3meanC2_110 = list()
for i in range(S3RGB_imgA1C2_10.shape[0]): 
     for j in range(S3RGB_imgA1C2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1210.append(S3RGB_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_110.append(S3RGB_imgA1C2_10[i][j])  
S3meanrefA1_1210 = np.array(S3meanrefA1_1210)
S3meanC2_110 = np.array(S3meanC2_110)

S3rgbrefA1_1210 = list()
S3rgbC2_110 = list()
for i in range(3):
    S3rgbrefA1_1210.append(S3meanrefA1_1210[:,i].mean())
    S3rgbC2_110.append(S3meanC2_110[:,i].mean())

# %%
S3meanrefA1_1310 = list()
S3meanC3_110 = list()
for i in range(S3RGB_imgA1C3_10.shape[0]): 
     for j in range(S3RGB_imgA1C3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1310.append(S3RGB_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_110.append(S3RGB_imgA1C3_10[i][j])  
S3meanrefA1_1310 = np.array(S3meanrefA1_1310)
S3meanC3_110 = np.array(S3meanC3_110)

S3rgbrefA1_1310 = list()
S3rgbC3_110 = list()
for i in range(3):
    S3rgbrefA1_1310.append(S3meanrefA1_1310[:,i].mean())
    S3rgbC3_110.append(S3meanC3_110[:,i].mean())

# %%
S3meanrefA1_1410 = list()
S3meanC4_110 = list()
for i in range(S3RGB_imgA1C4_10.shape[0]): 
     for j in range(S3RGB_imgA1C4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1410.append(S3RGB_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_110.append(S3RGB_imgA1C4_10[i][j])  
S3meanrefA1_1410 = np.array(S3meanrefA1_1410)
S3meanC4_110 = np.array(S3meanC4_110)

S3rgbrefA1_1410 = list()
S3rgbC4_110 = list()
for i in range(3):
    S3rgbrefA1_1410.append(S3meanrefA1_1410[:,i].mean())
     S3rgbC4_110.append(S3meanC4_110[:,i].mean())

# %%
S3meanrefA1_1510 = list()
S3meanD2_110 = list()
for i in range(S3RGB_imgA1D2_10.shape[0]): 
     for j in range(S3RGB_imgA1D2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1510.append(S3RGB_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_110.append(S3RGB_imgA1D2_10[i][j])  
S3meanrefA1_1510 = np.array(S3meanrefA1_1510)
S3meanD2_110 = np.array(S3meanD2_110)

S3rgbrefA1_1510 = list()
S3rgbD2_110 = list()
for i in range(3):
    S3rgbrefA1_1510.append(S3meanrefA1_1510[:,i].mean())
     S3rgbD2_110.append(S3meanD2_110[:,i].mean())

# %%
S3meanrefA1_1610 = list()
S3meanD3_110 = list()
for i in range(S3RGB_imgA1D3_10.shape[0]): 
     for j in range(S3RGB_imgA1D3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1610.append(S3RGB_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_110.append(S3RGB_imgA1D3_10[i][j])  
S3meanrefA1_1610 = np.array(S3meanrefA1_1610)
S3meanD3_110 = np.array(S3meanD3_110)

S3rgbrefA1_1610 = list()
S3rgbD3_110 = list()
for i in range(3):
    S3rgbrefA1_1610.append(S3meanrefA1_1610[:,i].mean())
    S3rgbD3_110.append(S3meanD3_110[:,i].mean())

# %%
S3meanrefA1_1710= list()
S3meanD4_110 = list()
for i in range(S3RGB_imgA1D4_10.shape[0]): 
     for j in range(S3RGB_imgA1D4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1710.append(S3RGB_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_110.append(S3RGB_imgA1D4_10[i][j])  
S3meanrefA1_1710 = np.array(S3meanrefA1_1410)
S3meanD4_110 = np.array(S3meanD4_110)

S3rgbrefA1_1710 = list()
S3rgbD4_110 = list()
for i in range(3):
    S3rgbrefA1_1710.append(S3meanrefA1_1710[:,i].mean())
    S3rgbD4_110.append(S3meanD4_110[:,i].mean())

# %% [markdown]
# ###HSV

# %%
S3meanrefA1_1 = list()
S3meanA1_2 = list()
for i in range(S3HSV_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1.append(S3HSV_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_2.append(S3HSV_imgA1A1_1[i][j])  
S3meanrefA1_1 = np.array(S3meanrefA1_1)
S3meanA1_2 = np.array(S3meanA1_2)

S3hsvrefA1_1 = list() 
S3hsvA1_2 = list()
for i in range(3):
    S3hsvrefA1_1.append(S3meanrefA1_1[:,i].mean())
    S3hsvA1_2.append(S3meanA1_2[:,i].mean())

# %%
S3meanrefA1_3 = list()
S3meanA2_1 = list()
for i in range(S3HSV_imgA1A2_1.shape[0]): 
     for j in range(S3HSV_imgA1A2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_3.append(S3HSV_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_1.append(S3HSV_imgA1A2_1[i][j])  
S3meanrefA1_3 = np.array(S3meanrefA1_3)
S3meanA2_1 = np.array(S3meanA2_1)

S3hsvrefA1_3 = list()
S3hsvA2_1 = list()
for i in range(3):
    S3hsvrefA1_3.append(S3meanrefA1_3[:,i].mean())
    S3hsvA2_1.append(S3meanA2_1[:,i].mean())

# %%
S3meanrefA1_4 = list()
S3meanA3_1 = list()
for i in range(S3HSV_imgA1A3_1.shape[0]): 
     for j in range(S3HSV_imgA1A3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_4.append(S3HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_1.append(S3HSV_imgA1A3_1[i][j])  
S3meanrefA1_4 = np.array(S3meanrefA1_4)
S3meanA3_1 = np.array(S3meanA3_1)

S3hsvrefA1_4 = list()
S3hsvA3_1 = list()
for i in range(3):
    S3hsvrefA1_4.append(S3meanrefA1_4[:,i].mean())
    S3hsvA3_1.append(S3meanA3_1[:,i].mean())

# %%
S3meanrefA1_5 = list()
S3meanA3_51 = list()
for i in range(S3HSV_imgA1A3_51.shape[0]): 
     for j in range(S3HSV_imgA1A3_51.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_5.append(S3HSV_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_51.append(S3HSV_imgA1A3_51[i][j])  
S3meanrefA1_5 = np.array(S3meanrefA1_5)
S3meanA3_51 = np.array(S3meanA3_51)

S3hsvrefA1_5 = list()
S3hsvA3_51 = list()
for i in range(3):
    S3hsvrefA1_5.append(S3meanrefA1_5[:,i].mean())
    S3hsvA3_51.append(S3meanA3_51[:,i].mean())

# %%
S3meanrefA1_6 = list()
S3meanA4_1 = list()
for i in range(S3HSV_imgA1A4_1.shape[0]): 
     for j in range(S3HSV_imgA1A4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_6.append(S3HSV_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_1.append(S3HSV_imgA1A4_1[i][j])  
S3meanrefA1_6 = np.array(S3meanrefA1_6)
S3meanA4_1 = np.array(S3meanA4_1)

S3hsvrefA1_6 = list()
S3hsvA4_1 = list()
for i in range(3):
    S3hsvrefA1_6.append(S3meanrefA1_6[:,i].mean())
    S3hsvA4_1.append(S3meanA4_1[:,i].mean())

# %%
S3meanrefA1_7 = list()
S3meanB1_1 = list()
for i in range(S3HSV_imgA1B1_1.shape[0]): 
     for j in range(S3HSV_imgA1B1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_7.append(S3HSV_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_1.append(S3HSV_imgA1B1_1[i][j])  
S3meanrefA1_7 = np.array(S3meanrefA1_7)
S3meanB1_1 = np.array(S3meanB1_1)

S3hsvrefA1_7 = list()
S3hsvB1_1 = list()
for i in range(3):
    S3hsvrefA1_7.append(S3meanrefA1_7[:,i].mean())
    S3hsvB1_1.append(S3meanB1_1[:,i].mean())

# %%
S3meanrefA1_8 = list()
S3meanB2_1 = list()
for i in range(S3HSV_imgA1B2_1.shape[0]): 
     for j in range(S3HSV_imgA1B2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_8.append(S3HSV_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_1.append(S3HSV_imgA1B2_1[i][j])  
S3meanrefA1_8 = np.array(S3meanrefA1_8)
S3meanB2_1 = np.array(S3meanB2_1)

S3hsvrefA1_8 = list()
S3hsvB2_1 = list()
for i in range(3):
    S3hsvrefA1_8.append(S3meanrefA1_8[:,i].mean())
    S3hsvB2_1.append(S3meanB2_1[:,i].mean())

# %%
S3meanrefA1_9 = list()
S3meanB3_1 = list()
for i in range(S3HSV_imgA1B3_1.shape[0]): 
     for j in range(S3HSV_imgA1B3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_9.append(S3HSV_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_1.append(S3HSV_imgA1B3_1[i][j])  
S3meanrefA1_9 = np.array(S3meanrefA1_9)
S3meanB3_1 = np.array(S3meanB3_1)

S3hsvrefA1_9 = list()
S3hsvB3_1 = list()
for i in range(3):
    S3hsvrefA1_9.append(S3meanrefA1_9[:,i].mean())
    S3hsvB3_1.append(S3meanB3_1[:,i].mean())

# %%
S3meanrefA1_10 = list()
S3meanB4_1 = list()
for i in range(S3HSV_imgA1B4_1.shape[0]): 
     for j in range(S3HSV_imgA1B4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_10.append(S3HSV_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_1.append(S3HSV_imgA1B4_1[i][j])  
S3meanrefA1_10 = np.array(S3meanrefA1_10)
S3meanB4_1 = np.array(S3meanB4_1)

S3hsvrefA1_10 = list()
S3hsvB4_1 = list()
for i in range(3):
    S3hsvrefA1_10.append(S3meanrefA1_10[:,i].mean())
    S3hsvB4_1.append(S3meanB4_1[:,i].mean())

# %%
S3meanrefA1_11 = list()
S3meanC1_1 = list()
for i in range(S3HSV_imgA1C1_1.shape[0]): 
     for j in range(S3HSV_imgA1C1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_11.append(S3HSV_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_1.append(S3HSV_imgA1C1_1[i][j])  
S3meanrefA1_11 = np.array(S3meanrefA1_11)
S3meanC1_1 = np.array(S3meanC1_1)

S3hsvrefA1_11 = list()
S3hsvC1_1 = list()
for i in range(3):
    S3hsvrefA1_11.append(S3meanrefA1_11[:,i].mean())
    S3hsvC1_1.append(S3meanC1_1[:,i].mean())

# %%
S3meanrefA1_12 = list()
S3meanC2_1 = list()
for i in range(S3HSV_imgA1C2_1.shape[0]): 
     for j in range(S3HSV_imgA1C2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_12.append(S3HSV_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_1.append(S3HSV_imgA1C2_1[i][j])  
S3meanrefA1_12 = np.array(S3meanrefA1_12)
S3meanC2_1 = np.array(S3meanC2_1)

S3hsvrefA1_12 = list()
S3hsvC2_1 = list()
for i in range(3):
    S3hsvrefA1_12.append(S3meanrefA1_12[:,i].mean())
    S3hsvC2_1.append(S3meanC2_1[:,i].mean())

# %%
S3meanrefA1_13 = list()
S3meanC3_1 = list()
for i in range(S3HSV_imgA1C3_1.shape[0]): 
     for j in range(S3HSV_imgA1C3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_13.append(S3HSV_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_1.append(S3HSV_imgA1C3_1[i][j])  
S3meanrefA1_13 = np.array(S3meanrefA1_13)
S3meanC3_1 = np.array(S3meanC3_1)

S3hsvrefA1_13 = list()
S3hsvC3_1 = list()
for i in range(3):
    S3hsvrefA1_13.append(S3meanrefA1_13[:,i].mean())
    S3hsvC3_1.append(S3meanC3_1[:,i].mean())

# %%
S3meanrefA1_14 = list()
S3meanC4_1 = list()
for i in range(S3HSV_imgA1C4_1.shape[0]): 
     for j in range(S3HSV_imgA1C4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_14.append(S3HSV_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_1.append(S3HSV_imgA1C4_1[i][j])  
S3meanrefA1_14 = np.array(S3meanrefA1_14)
S3meanC4_1 = np.array(S3meanC4_1)

S3hsvrefA1_14 = list()
S3hsvC4_1 = list()
for i in range(3):
    S3hsvrefA1_14.append(S3meanrefA1_14[:,i].mean())
    S3hsvC4_1.append(S3meanC4_1[:,i].mean())

# %%
S3meanrefA1_15 = list()
S3meanD2_1 = list()
for i in range(S3HSV_imgA1D2_1.shape[0]): 
     for j in range(S3HSV_imgA1D2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_15.append(S3HSV_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_1.append(S3HSV_imgA1D2_1[i][j])  
S3meanrefA1_15 = np.array(S3meanrefA1_15)
S3meanD2_1 = np.array(S3meanD2_1)

S3hsvrefA1_15 = list()
S3hsvD2_1 = list()
for i in range(3):
    S3hsvrefA1_15.append(S3meanrefA1_15[:,i].mean())
    S3hsvD2_1.append(S3meanD2_1[:,i].mean())

# %%
S3meanrefA1_16 = list()
S3meanD3_1 = list()
for i in range(S3HSV_imgA1D3_1.shape[0]): 
     for j in range(S3HSV_imgA1D3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_16.append(S3HSV_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_1.append(S3HSV_imgA1D3_1[i][j])  
S3meanrefA1_16 = np.array(S3meanrefA1_16)
S3meanD3_1 = np.array(S3meanD3_1)

S3hsvrefA1_16 = list()
S3hsvD3_1 = list()
for i in range(3):
    S3hsvrefA1_16.append(S3meanrefA1_16[:,i].mean())
    S3hsvD3_1.append(S3meanD3_1[:,i].mean())

# %%
S3meanrefA1_17= list()
S3meanD4_1 = list()
for i in range(S3HSV_imgA1D4_1.shape[0]): 
     for j in range(S3HSV_imgA1D4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_17.append(S3HSV_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_1.append(S3HSV_imgA1D4_1[i][j])  
S3meanrefA1_17 = np.array(S3meanrefA1_14)
S3meanD4_1 = np.array(S3meanD4_1)

S3hsvrefA1_17 = list()
S3hsvD4_1 = list()
for i in range(3):
    S3hsvrefA1_17.append(S3meanrefA1_17[:,i].mean())
    S3hsvD4_1.append(S3meanD4_1[:,i].mean())

# %% [markdown]
# ###Img 2

# %%
S3meanrefA1_102 = list()
S3meanA1_202 = list()
for i in range(S3HSV_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_102.append(S3HSV_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_202.append(S3HSV_imgA1A1_2[i][j])  
S3meanrefA1_102= np.array(S3meanrefA1_102)
S3meanA1_202 = np.array(S3meanA1_202)

S3hsvrefA1_102 = list()
S3hsvA1_202 = list()
for i in range(3):
    S3hsvrefA1_102.append(S3meanrefA1_1[:,i].mean())
    S3hsvA1_202.append(S3meanA1_2[:,i].mean())
S3hsvrefA1_102,S3hsvA1_202

# %%
S3meanrefA1_302 = list()
S3meanA2_102 = list()
for i in range(S3HSV_imgA1A2_2.shape[0]): 
     for j in range(S3HSV_imgA1A2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_302.append(S3HSV_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_102.append(S3HSV_imgA1A2_2[i][j])  
S3meanrefA1_302 = np.array(S3meanrefA1_3)
S3meanA2_102 = np.array(S3meanA2_1)

S3hsvrefA1_302 = list()
S3hsvA2_102 = list()
for i in range(3):
    S3hsvrefA1_302.append(S3meanrefA1_302[:,i].mean())
    S3hsvA2_102.append(S3meanA2_102[:,i].mean())

# %%
S3meanrefA1_402 = list()
S3meanA3_102 = list()
for i in range(S3HSV_imgA1A3_2.shape[0]): 
     for j in range(S3HSV_imgA1A3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_402.append(S3HSV_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_102.append(S3HSV_imgA1A3_2[i][j])  
S3meanrefA1_402= np.array(S3meanrefA1_402)
S3meanA3_102 = np.array(S3meanA3_102)

S3hsvrefA1_402 = list()
S3hsvA3_102 = list()
for i in range(3):
    S3hsvrefA1_402.append(S3meanrefA1_402[:,i].mean())
    S3hsvA3_102.append(S3meanA3_102[:,i].mean())

# %%
S3meanrefA1_502 = list()
S3meanA3_5102 = list()
for i in range(S3HSV_imgA1A3_52.shape[0]): 
     for j in range(S3HSV_imgA1A3_52.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_502.append(S3HSV_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5102.append(S3HSV_imgA1A3_52[i][j])  
S3meanrefA1_502 = np.array(S1meanrefA1_502)
S3meanA3_5102 = np.array(S3meanA3_5102)

S3hsvrefA1_502 = list()
S3hsvA3_5102 = list()
for i in range(3):
    S3hsvrefA1_502.append(S1meanrefA1_502[:,i].mean())
    S3 hsvA3_5102.append(S1meanA3_5102[:,i].mean())

# %%
S3meanrefA1_602 = list()
S3meanA4_102 = list()
for i in range( S3HSV_imgA1A4_2.shape[0]): 
     for j in range( S3HSV_imgA1A4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                   S3meanrefA1_602.append( S3HSV_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                   S3meanA4_102.append( S3HSV_imgA1A4_2[i][j])  
 S3meanrefA1_602 = np.array( S3meanrefA1_602)
 S3meanA4_102 = np.array( S3meanA4_102)

 S3hsvrefA1_602 = list()
 S3hsvA4_102 = list()
for i in range(3):
     S3hsvrefA1_602.append( S3meanrefA1_602[:,i].mean())
     S3hsvA4_102.append( S3meanA4_102[:,i].mean())

# %%
S3meanrefA1_702 = list()
S3meanB1_102 = list()
for i in range(S3HSV_imgA1B1_2.shape[0]): 
     for j in range(S3HSV_imgA1B1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_702.append(S3HSV_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_102.append(S3HSV_imgA1B1_2[i][j])  
S3meanrefA1_702 = np.array(S3meanrefA1_702)
S3meanB1_102 = np.array(S3meanB1_102)

S3hsvrefA1_702 = list()
S3hsvB1_102 = list()
for i in range(3):
    S3hsvrefA1_702.append(S3meanrefA1_702[:,i].mean())
    S3hsvB1_102.append(S3meanB1_102[:,i].mean())

# %%
S3meanrefA1_802 = list()
S3meanB2_102 = list()
for i in range(S3HSV_imgA1B2_2.shape[0]): 
     for j in range(S3HSV_imgA1B2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_802.append(S3HSV_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_102.append(S3HSV_imgA1B2_2[i][j])  
S3meanrefA1_802 = np.array(S1meanrefA1_802)
S3meanB2_102 = np.array(S3meanB2_102)

S3hsvrefA1_802 = list()
S3hsvB2_102 = list()
for i in range(3):
    S3hsvrefA1_802.append(S3meanrefA1_802[:,i].mean())
    S3hsvB2_102.append(S3meanB2_102[:,i].mean())

# %%
S3meanrefA1_902 = list()
S3meanB3_102 = list()
for i in range(S3HSV_imgA1B3_2.shape[0]): 
     for j in range(S3HSV_imgA1B3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_902.append(S3HSV_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_102.append(S3HSV_imgA1B3_2[i][j])  
S3meanrefA1_902 = np.array(S3meanrefA1_902)
S3meanB3_102 = np.array(S3meanB3_102)

S3hsvrefA1_902 = list()
S3hsvB3_102 = list()
for i in range(3):
    S3hsvrefA1_902.append(S3meanrefA1_902[:,i].mean())
    S3hsvB3_102.append(S3meanB3_102[:,i].mean())

# %%
S3meanrefA1_1002 = list()
S3meanB4_102 = list()
for i in range(S3HSV_imgA1B4_2.shape[0]): 
     for j in range(S3HSV_imgA1B4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1002.append(S3HSV_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_102.append(S3HSV_imgA1B4_2[i][j])  
S3meanrefA1_1002 = np.array(S3meanrefA1_1002)
S3meanB4_102 = np.array(S3meanB4_102)

S3hsvrefA1_1002 = list()
S3hsvB4_102 = list()
for i in range(3):
    S3hsvrefA1_10.append(S3meanrefA1_10[:,i].mean())
    S3hsvB4_1.append(S3meanB4_1[:,i].mean())

# %%
S3meanrefA1_1102 = list()
S3meanC1_102 = list()
for i in range(S3HSV_imgA1C1_2.shape[0]): 
     for j in range(S3HSV_imgA1C1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1102.append(S3HSV_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanC1_102.append(S3HSV_imgA1C1_2[i][j])  
S3meanrefA1_1102 = np.array(S3meanrefA1_1102)
S3meanC1_102= np.array(S3meanC1_102)

S3hsvrefA1_1102 = list()
S3hsvC1_102 = list()
for i in range(3):
    S3hsvrefA1_1102.append(S3meanrefA1_1102[:,i].mean())
    S3hsvC1_102.append(S3meanC1_102[:,i].mean())

# %%
S31meanrefA1_1202 = list()
S3meanC2_102 = list()
for i in range(S3HSV_imgA1C2_2.shape[0]): 
     for j in range(S3HSV_imgA1C2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1202.append(S3HSV_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_102.append(S3HSV_imgA1C2_2[i][j])  
S3meanrefA1_1202 = np.array(S3meanrefA1_1202)
S3meanC2_102 = np.array(S3meanC2_102)

S3hsvrefA1_1202 = list()
S3hsvC2_102 = list()
for i in range(3):
    S3hsvrefA1_1202.append(S3meanrefA1_1202[:,i].mean())
    S3hsvC2_102.append(S3meanC2_102[:,i].mean())

# %%
S3meanrefA1_1302 = list()
S3meanC3_102 = list()
for i in range(S3HSV_imgA1C3_.shape[0]): 
     for j in range(S3HSV_imgA1C3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1302.append(S3HSV_imgA1C3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_102.append(S3HSV_imgA1C3_[i][j])  
S3meanrefA1_1302 = np.array(S3meanrefA1_1302)
S3meanC3_102 = np.array(S3meanC3_102)

S3hsvrefA1_1302 = list()
S3hsvC3_102 = list()
for i in range(3):
    S3hsvrefA1_1302.append(S3meanrefA1_1302[:,i].mean())
    S3hsvC3_102.append(S3meanC3_102[:,i].mean())

# %%
S3meanrefA1_1402 = list()
S3meanC4_102 = list()
for i in range(S3HSV_imgA1C4_2.shape[0]): 
     for j in range(S3HSV_imgA1C4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1402.append(S3HSV_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_102.append(S3HSV_imgA1C4_2[i][j])  
S3meanrefA1_1402 = np.array(S3meanrefA1_1402)
S3meanC4_102 = np.array(S3meanC4_102)

S3hsvrefA1_1402 = list()
S3hsvC4_102 = list()
for i in range(3):
    S3hsvrefA1_1402.append(S3meanrefA1_1402[:,i].mean())
    S3hsvC4_102.append(S3meanC4_102[:,i].mean())

# %%
S3meanrefA1_1502 = list()
S3meanD2_102 = list()
for i in range(S3HSV_imgA1D2_2.shape[0]): 
     for j in range(S3HSV_imgA1D2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1502.append(S3HSV_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_102.append(S3HSV_imgA1D2_2[i][j])  
S3meanrefA1_1502 = np.array(S3meanrefA1_1502)
S3meanD2_102 = np.array(S3meanD2_102)

S3hsvrefA1_1502 = list()
S3hsvD2_102 = list()
for i in range(3):
    S3hsvrefA1_1502.append(S3meanrefA1_1502[:,i].mean())
    S3hsvD2_102.append(S3meanD2_102[:,i].mean())

# %%
S3meanrefA1_1602 = list()
S3meanD3_102 = list()
for i in range(S3HSV_imgA1D3_2.shape[0]): 
     for j in range(S3HSV_imgA1D3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1602.append(S3HSV_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_102.append(S3HSV_imgA1D3_2[i][j])  
S3meanrefA1_1602 = np.array(S3meanrefA1_1602)
S3meanD3_102 = np.array(S3meanD3_102)

S3hsvrefA1_1602 = list()
S3hsvD3_102 = list()
for i in range(3):
    S3hsvrefA1_1602.append(S3meanrefA1_1602[:,i].mean())
    S3hsvD3_102.append(S3meanD3_102[:,i].mean())

# %%
S3meanrefA1_1702= list()
S3meanD4_102 = list()
for i in range(S3HSV_imgA1D4_2.shape[0]): 
     for j in range(S3HSV_imgA1D4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1702.append(S3HSV_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_102.append(S3HSV_imgA1D4_2[i][j])  
S3meanrefA1_1702 = np.array(S3meanrefA1_1702)
S3meanD4_102 = np.array(S3meanD4_102)

S3hsvrefA1_1702 = list()
S3hsvD4_102 = list()
for i in range(3):
    S3hsvrefA1_1702.append(S1meanrefA1_1702[:,i].mean())
    S3hsvD4_102.append(S3meanD4_102[:,i].mean())

# %% [markdown]
# ###Img 3

# %%
S3meanrefA1_103 = list()
S3meanA1_203 = list()
for i in range(S3HSV_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_103.append(S3HSV_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanA1_203.append(S3HSV_imgA1A1_3[i][j])  
S3meanrefA1_103 = np.array(S3meanrefA1_103)
S3meanA1_203 = np.array(S3meanA1_203)

S3hsvrefA1_103 = list()
S3hsvA1_203 = list()
for i in range(3):
    S3hsvrefA1_103.append(S3meanrefA1_103[:,i].mean())
    S3hsvA1_203.append(S3meanA1_203[:,i].mean())
S3hsvrefA1_103,S1hsvA1_203

# %%
S3meanrefA1_303 = list()
S3meanA2_103 = list()
for i in rangeS3HSV_imgA1A2_3.shape[0]): 
     for j in range(S3HSV_imgA1A2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_303.append(S3HSV_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_103.append(S3HSV_imgA1A2_3[i][j])  
S3meanrefA1_303 = np.array(S3meanrefA1_303)
S3meanA2_103 = np.array(S3meanA2_103)

S3hsvrefA1_303 = list()
S3hsvA2_103 = list()
for i in range(3):
    S3hsvrefA1_303.append(S3meanrefA1_303[:,i].mean())
    S3hsvA2_103.append(S3meanA2_103[:,i].mean())

# %%
S3meanrefA1_403 = list()
S3meanA3_103 = list()
for i in range(S3HSV_imgA1A3_3.shape[0]): 
     for j in range(S3HSV_imgA1A3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_403append(S3HSV_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_103.append(S3HSV_imgA1A3_3[i][j])  
S3meanrefA1_403 = np.array(S3meanrefA1_403)
S3meanA3_103 = np.array(S3meanA3_103)

S3hsvrefA1_403 = list()
S3hsvA3_103 = list()
for i in range(3):
    S3hsvrefA1_403.append(S3meanrefA1_403[:,i].mean())
    S3hsvA3_103.append(S3meanA3_103[:,i].mean())

# %%
S3meanrefA1_503 = list()
S3meanA3_5103 = list()
for i in range(S3HSV_imgA1A3_53.shape[0]): 
     for j in range(S3HSV_imgA1A3_53.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_503.append(S3HSV_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5103.append(S3HSV_imgA1A3_53[i][j])  
S3meanrefA1_503 = np.array(S3meanrefA1_503)
S3meanA3_5103 = np.array(S3meanA3_5103)

S3hsvrefA1_503 = list()
S3hsvA3_5103 = list()
for i in range(3):
    S3hsvrefA1_503.append(S3meanrefA1_503[:,i].mean())
    S3hsvA3_5103.append(S3meanA3_5103[:,i].mean())

# %%
S3meanrefA1_603 = list()
S3meanA4_103 = list()
for i in range(S3HSV_imgA1A4_303.shape[0]): 
     for j in range(S3HSV_imgA1A4_303.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_603.append(S3HSV_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_103.append(S3HSV_imgA1A4_3[i][j])  
S3meanrefA1_603 = np.array(S3meanrefA1_603)
S3meanA4_103 = np.array(S3meanA4_103)

S1hsvrefA1_603 = list()
S1hsvA4_103 = list()
for i in range(3):
    S1hsvrefA1_603.append(S1meanrefA1_603[:,i].mean())
    S1hsvA4_103.append(S1meanA4_103[:,i].mean())

# %%
S3meanrefA1_703 = list()
S3meanB1_103 = list()
for i in range(S3HSV_imgA1B1_3.shape[0]): 
     for j in range(S3HSV_imgA1B1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_703.append(S3HSV_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_103.append(S3HSV_imgA1B1_3[i][j])  
S3meanrefA1_703 = np.array(S3meanrefA1_703)
S3meanB1_103 = np.array(S3meanB1_103)

S3hsvrefA1_703 = list()
S3hsvB1_103 = list()
for i in range(3):
    S3hsvrefA1_703.append(S3meanrefA1_703[:,i].mean())
    S3hsvB1_103.append(S3meanB1_103[:,i].mean())

# %%
S3meanrefA1_803 = list()
S3meanB2_103 = list()
for i in range(S3HSV_imgA1B2_3.shape[0]): 
     for j in range(S3HSV_imgA1B2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_803.append(S3HSV_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_103.append(S3HSV_imgA1B2_3[i][j])  
S3meanrefA1_803 = np.array(S3meanrefA1_803)
S3meanB2_103 = np.array(S3meanB2_103

S3hsvrefA1_803 = list()
S3hsvB2_103 = list()
for i in range(3):
    S3hsvrefA1_8.append(S3meanrefA1_803[:,i].mean())
    S3hsvB2_1.append(S3meanB2_103[:,i].mean())

# %%
S3meanrefA1_903 = list()
S3meanB3_103 = list()
for i in range(S3HSV_imgA1B3_3.shape[0]): 
     for j in range(S3HSV_imgA1B3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_903.append(S3HSV_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_103.append(S3HSV_imgA1B3_3[i][j])  
S3meanrefA1_903 = np.array(S3meanrefA1_903)
S3meanB3_103 = np.array(S3meanB3_103)

S3hsvrefA1_903 = list()
S3hsvB3_103 = list()
for i in range(3):
    S3hsvrefA1_903.append(S3meanrefA1_9[:,i].mean())
    S3hsvB3_103.append(S3meanB3_1[:,i].mean())

# %%
S3meanrefA1_1003 = list()
S3meanB4_103 = list()
for i in range(S3HSV_imgA1B4_3.shape[0]): 
     for j in range(S3HSV_imgA1B4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1003.append(S3HSV_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_103.append(S3HSV_imgA1B4_3[i][j])  
S3meanrefA1_1003 = np.array(S3meanrefA1_1003)
S3meanB4_103 = np.array(S3meanB4_103)

S3hsvrefA1_1003 = list()
S3hsvB4_103 = list()
for i in range(3):
    S3hsvrefA1_1003.append(S3meanrefA1_1003[:,i].mean())
    S3hsvB4_103.append(S3meanB4_103[:,i].mean())

# %%
S3meanrefA1_1103 = list()
S3meanC1_103 = list()
for i in range(S3HSV_imgA1C1_3.shape[0]): 
     for j in range(S3HSV_imgA1C1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1103.append(S3HSV_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_103.append(S3HSV_imgA1C1_3[i][j])  
S3meanrefA1_1103 = np.array(S3meanrefA1_1103)
S3meanC1_103 = np.array(S3meanC1_103)

S3hsvrefA1_11 = list()
S3hsvC1_103 = list()
for i in range(3):
    S3hsvrefA1_1103.append(S3meanrefA1_1103[:,i].mean())
    S3hsvC1_103.append(S3meanC1_103[:,i].mean())

# %%
S3meanrefA1_1203 = list()
S3meanC2_103 = list()
for i in range(S3HSV_imgA1C2_3.shape[0]): 
     for j in range(S3HSV_imgA1C2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1203.append(S3HSV_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_103.append(S3HSV_imgA1C2_3[i][j])  
S3meanrefA1_1203 = np.array(S3meanrefA1_1203)
S3meanC2_103 = np.array(S3meanC2_103)

S3hsvrefA1_1203 = list()
S3hsvC2_103 = list()
for i in range(3):
    S3hsvrefA1_1203.append(S3meanrefA1_1203[:,i].mean())
    S3hsvC2_103.append(S3meanC2_103[:,i].mean())

# %%
S3meanrefA1_1303 = list()
S3meanC3_103 = list()
for i in range(S3HSV_imgA1C3_3.shape[0]): 
     for j in range(S3HSV_imgA1C3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1303.append(S3HSV_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_103.append(S3HSV_imgA1C3_3[i][j])  
S3meanrefA1_1303 = np.array(S3meanrefA1_130303)
S3meanC3_103 = np.array(S3meanC3_103)

S3hsvrefA1_1303 = list()
S3hsvC3_103 = list()
for i in range(3):
    S3hsvrefA1_1303.append(S3meanrefA1_1303[:,i].mean())
    S3hsvC3_103.append(S3meanC3_103[:,i].mean())

# %%
S3meanrefA1_1403 = list()
S3meanC4_103 = list()
for i in range(S3HSV_imgA1C4_3.shape[0]): 
     for j in range(S3HSV_imgA1C4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_14.append(S3HSV_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_103.append(S3HSV_imgA1C4_3[i][j])  
S3meanrefA1_1403 = np.array(S3meanrefA1_1403)
S3meanC4_103 = np.array(S3meanC4_103)

S3hsvrefA1_1403 = list()
S3hsvC4_103 = list()
for i in range(3):
    S3hsvrefA1_1403.append(S3meanrefA1_1403[:,i].mean())
    S3hsvC4_103.append(S3meanC4_103[:,i].mean())

# %%
S3meanrefA1_1503 = list()
S3meanD2_103 = list()
for i in range(S3HSV_imgA1D2_303.shape[0]): 
     for j in range(S3HSV_imgA1D2_303.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1503.append(S3HSV_imgA1D2_303[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_103.append(S3HSV_imgA1D2_303[i][j])  
S3meanrefA1_1503 = np.array(S3meanrefA1_1503)
S3meanD2_103 = np.array(S3meanD2_103)

S3hsvrefA1_1503 = list()
S3hsvD2_103 = list()
for i in range(3):
    S3hsvrefA1_1503.append(S3meanrefA1_1503[:,i].mean())
    S3hsvD2_103.append(S3meanD2_103[:,i].mean())

# %%
S3meanrefA1_1603 = list()
S3meanD3_103 = list()
for i in range(S3HSV_imgA1D3_3.shape[0]): 
     for j in range(S3HSV_imgA1D3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_16.append(S3HSV_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_1.append(S3HSV_imgA1D3_3[i][j])  
S3meanrefA1_1603 = np.array(S3meanrefA1_1603)
S3meanD3_103 = np.array(S3meanD3_103)

S3hsvrefA1_1603 = list()
S3hsvD3_103 = list()
for i in range(3):
    S3hsvrefA1_1603.append(S3meanrefA1_1603[:,i].mean())
    S3hsvD3_103.append(S3meanD3_103[:,i].mean())

# %%
S3meanrefA1_1703= list()
S3meanD4_103 = list()
for i in range(S3HSV_imgA1D4_3.shape[0]): 
     for j in range(S3HSV_imgA1D4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1703.append(S3HSV_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_103.append(S3HSV_imgA1D4_3[i][j])  
S3meanrefA1_1703 = np.array(S3meanrefA1_1403)
S3meanD4_103 = np.array(S3meanD4_103)

S3hsvrefA1_1703 = list()
S3hsvD4_103 = list()
for i in range(3):
    S3hsvrefA1_1703.append(S3meanrefA1_1703[:,i].mean())
    S3hsvD4_103.append(S3meanD4_103[:,i].mean())

# %% [markdown]
# ###Img 4

# %%
S3meanrefA1_104 = list()
S3meanA1_204 = list()
for i in range(S3HSV_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_104.append(S3HSV_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_204.append(S3HSV_imgA1A1_[i][j])  
S3meanrefA1_104 = np.array(S3meanrefA1_104)
S3meanA1_204 = np.array(S3meanA1_204)

S3hsvrefA1_104 = list()
S3hsvA1_204 = list()
for i in range(3):
    S3hsvrefA1_104.append(S3meanrefA1_104[:,i].mean())
    S3hsvA1_204.append(S3meanA1_204[:,i].mean())
S3hsvrefA1_104,S1hsvA1_204

# %%
S3meanrefA1_304 = list()
S3meanA2_104 = list()
for i in range(S3HSV_imgA1A2_4.shape[0]): 
     for j in range(S3HSV_imgA1A2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_304.append(S3HSV_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_104.append(S3HSV_imgA1A2_4[i][j])  
S3meanrefA1_304 = np.array(S3meanrefA1_304)
S3meanA2_104 = np.array(S3meanA2_104)

S3hsvrefA1_304 = list()
S3hsvA2_104 = list()
for i in range(3):
    S3hsvrefA1_304.append(S3meanrefA1_304[:,i].mean())
    S3hsvA2_104.append(S3meanA2_104[:,i].mean())

# %%
S3meanrefA1_404 = list()
S3meanA3_104 = list()
for i in range(S3HSV_imgA1A3_4.shape[0]): 
     for j in range(S3HSV_imgA1A3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_404.append(S3HSV_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_104.append(S3HSV_imgA1A3_4[i][j])  
S3meanrefA1_404 = np.array(S3meanrefA1_404)
S3meanA3_104 = np.array(S3meanA3_104)

S3hsvrefA1_404 = list()
S3hsvA3_104 = list()
for i in range(3):
    S3hsvrefA1_404.append(S3meanrefA1_404[:,i].mean())
    S3hsvA3_104.append(S3meanA3_104[:,i].mean())

# %%
S3meanrefA1_504 = list()
S3meanA3_5104 = list()
for i in range(S3HSV_imgA1A3_54.shape[0]): 
     for j in range(S3HSV_imgA1A3_54.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_504.append(S3HSV_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5104.append(S3HSV_imgA1A3_54[i][j])  
S3meanrefA1_504 = np.array(S3meanrefA1_504)
S3meanA3_5104 = np.array(S3meanA3_5104)

S3hsvrefA1_504 = list()
S3hsvA3_5104 = list()
for i in range(3):
    S3hsvrefA1_504.append(S3meanrefA1_504[:,i].mean())
    S3hsvA3_5104.append(S3meanA3_5104[:,i].mean())

# %%
S3meanrefA1_604 = list()
S3meanA4_104 = list()
for i in range(S3HSV_imgA1A4_4.shape[0]): 
     for j in range(S3HSV_imgA1A4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_604.append(S3HSV_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_104.append(S3HSV_imgA1A4_[i][j])  
S3meanrefA1_604 = np.array(S3meanrefA1_604)
S3meanA4_104 = np.array(S3meanA4_104)

S3hsvrefA1_604 = list()
S3hsvA4_104 = list()
for i in range(3):
    S3hsvrefA1_604.append(S3meanrefA1_604[:,i].mean())
    S3hsvA4_104.append(S3meanA4_104[:,i].mean())

# %%
S3meanrefA1_704 = list()
S3meanB1_104 = list()
for i in range(S3HSV_imgA1B1_4.shape[0]): 
     for j in range(S3HSV_imgA1B1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_7.append(S3HSV_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_1.append(S3HSV_imgA1B1_4[i][j])  
S3meanrefA1_704 = np.array(S3meanrefA1_704)
S3meanB1_104 = np.array(S3meanB1_104)

S3hsvrefA1_704 = list()
S3hsvB1_104 = list()
for i in range(3):
    S3hsvrefA1_704.append(S3meanrefA1_704[:,i].mean())
    S3hsvB1_104.append(S3meanB1_104[:,i].mean())

# %%
S3meanrefA1_804 = list()
S3meanB2_104 = list()
for i in range(S3HSV_imgA1B2_4.shape[0]): 
     for j in range(S3HSV_imgA1B2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_804.append(S3HSV_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_104.append(S3HSV_imgA1B2_4[i][j])  
S3meanrefA1_804 = np.array(S3meanrefA1_804)
S3meanB2_104 = np.array(S3meanB2_104)

S3hsvrefA1_804 = list()
S3hsvB2_104 = list()
for i in range(3):
    S3hsvrefA1_804.append(S3meanrefA1_804[:,i].mean())
    S3hsvB2_104.append(S3meanB2_104[:,i].mean())

# %%
S3meanrefA1_904 = list()
S3meanB3_104 = list()
for i in range(S3HSV_imgA1B3_404.shape[0]): 
     for j in range(S3HSV_imgA1B3_404.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_904.append(S3HSV_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_104.append(S3HSV_imgA1B3_4[i][j])  
S3meanrefA1_904 = np.array(S3meanrefA1_904)
S3meanB3_104 = np.array(S3meanB3_104)

S3hsvrefA1_904 = list()
S3hsvB3_104 = list()
for i in range(3):
    S3hsvrefA1_904.append(S3meanrefA1_904[:,i].mean())
    S3hsvB3_104.append(S3meanB3_104[:,i].mean())

# %%
S3meanrefA1_1004 = list()
S3meanB4_104 = list()
for i in range(S3HSV_imgA1B4_4.shape[0]): 
     for j in range(S3HSV_imgA1B4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1004.append(S3HSV_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_104.append(S3HSV_imgA1B4_4[i][j])  
S3meanrefA1_1004 = np.array(S3meanrefA1_1004)
S3meanB4_104 = np.array(S3meanB4_104)

S3hsvrefA1_1004 = list()
S3hsvB4_104= list()
for i in range(3):
    S3hsvrefA1_1004.append(S3meanrefA1_1004[:,i].mean())
    S3hsvB4_104.append(S3meanB4_104[:,i].mean())

# %%
S3meanrefA1_1104 = list()
S3meanC1_104 = list()
for i in range(S3HSV_imgA1C1_4.shape[0]): 
     for j in range(S3HSV_imgA1C1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1104.append(S3HSV_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_104.append(S3HSV_imgA1C1_4[i][j])  
S3meanrefA1_1104 = np.array(S3meanrefA1_1104)
S3meanC1_104 = np.array(S3meanC1_104)

S3hsvrefA1_1104 = list()
S3hsvC1_104 = list()
for i in range(3):
    S3hsvrefA1_1104.append(S3meanrefA1_1104[:,i].mean())
    S3hsvC1_104.append(S3meanC1_104[:,i].mean())

# %%
S3meanrefA1_1204 = list()
S3meanC2_104 = list()
for i in range(S3HSV_imgA1C2_4.shape[0]): 
     for j in range(S3HSV_imgA1C2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1204.append(S3HSV_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_104.append(S3HSV_imgA1C2_4[i][j])  
S3meanrefA1_1204 = np.array(S3meanrefA1_1204)
S3meanC2_1อ = np.array(S3meanC2_104)

S3hsvrefA1_1204 = list()
S3hsvC2_104 = list()
for i in range(3):
    S3hsvrefA1_1204.append(S3meanrefA1_1204[:,i].mean())
    S3hsvC2_104.append(S3meanC2_104[:,i].mean())

# %%
S3meanrefA1_1304 = list()
S3meanC3_104 = list()
for i in range(S3HSV_imgA1C3_4.shape[0]): 
     for j in range(S3HSV_imgA1C3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1304.append(S3HSV_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_104.append(S3HSV_imgA1C3_4[i][j])  
S3meanrefA1_1304 = np.array(S3meanrefA1_1304)
S3meanC3_104 = np.array(S3meanC3_104)

S3hsvrefA1_1304 = list()
S3hsvC3_104 = list()
for i in range(3):
    S3hsvrefA1_1304.append(S3meanrefA1_1304[:,i].mean())
    S3hsvC3_104.append(S3meanC3_104[:,i].mean())

# %%
S3meanrefA1_1404 = list()
S3meanC4_104 = list()
for i in range(S3HSV_imgA1C4_4.shape[0]): 
     for j in range(S3HSV_imgA1C4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1404.append(S3HSV_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_104.append(S3HSV_imgA1C4_4[i][j])  
S3meanrefA1_1404 = np.array(S3meanrefA1_14)
S3meanC4_104 = np.array(S3meanC4_1)

S3hsvrefA1_1404 = list()
S3hsvC4_104 = list()
for i in range(3):
    S3hsvrefA1_1404.append(S3meanrefA1_1404[:,i].mean())
    S3hsvC4_104.append(S3meanC4_104[:,i].mean())

# %%
S3meanrefA1_1504 = list()
S3meanD2_104 = list()
for i in range(S3HSV_imgA1D2_4.shape[0]): 
     for j in range(S3HSV_imgA1D2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1504.append(S3HSV_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_104.append(S3HSV_imgA1D2_4[i][j])  
S3meanrefA1_1504 = np.array(S3meanrefA1_1504)
S3meanD2_104 = np.array(S3meanD2_104)

S3hsvrefA1_1504 = list()
S3hsvD2_104 = list()
for i in range(3):
    S3hsvrefA1_1504.append(S3meanrefA1_1504[:,i].mean())
    S3hsvD2_104.append(S3meanD2_104[:,i].mean())

# %%
S3meanrefA1_1604 = list()
S3meanD3_104 = list()
for i in range(S3HSV_imgA1D3_4.shape[0]): 
     for j in range(S3HSV_imgA1D3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1604.append(S3HSV_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_104.append(S3HSV_imgA1D3_4[i][j])  
S3meanrefA1_1604 = np.array(S3meanrefA1_1604)
S3meanD3_104 = np.array(S3meanD3_104)

S3hsvrefA1_1604 = list()
S3hsvD3_104 = list()
for i in range(3):
    S3hsvrefA1_1604.append(S3meanrefA1_1604[:,i].mean())
    S3hsvD3_104.append(S3meanD3_104[:,i].mean())

# %%
S3meanrefA1_1704= list()
S3meanD4_104 = list()
for i in range(S3HSV_imgA1D4_4.shape[0]): 
     for j in range(S3HSV_imgA1D4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1704.append(S3HSV_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_104.append(S3HSV_imgA1D4_4[i][j])  
S3meanrefA1_1704 = np.array(S3meanrefA1_1404)
S3meanD4_104 = np.array(S3meanD4_104)

S3hsvrefA1_1704 = list()
S3hsvD4_104 = list()
for i in range(3):
    S3hsvrefA1_1704.append(S3meanrefA1_1704[:,i].mean())
    S3hsvD4_104.append(S3meanD4_104[:,i].mean())

# %% [markdown]
# ###Img 5

# %%
S3meanrefA1_105 = list()
S3meanA1_205 = list()
for i in range(S3HSV_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_105.append(S3HSV_imgA1A1_505[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_205.append(S3HSV_imgA1A1_505[i][j])  
S3meanrefA1_105 = np.array(S3meanrefA1_105)
S3meanA1_205 = np.array(S3meanA1_205)

S3hsvrefA1_105 = list()
S3hsvA1_205 = list()
for i in range(3):
    S3hsvrefA1_105.append(S3meanrefA1_105[:,i].mean())
    S3hsvA1_205.append(S3meanA1_205[:,i].mean())
S3hsvrefA1_105,S3hsvA1_205

# %%
S3meanrefA1_305 = list()
S3meanA2_105 = list()
for i in range(S3HSV_imgA1A2_5.shape[0]): 
     for j in range(S3HSV_imgA1A2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_305.append(S3HSV_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_105.append(S3HSV_imgA1A2_5[i][j])  
S3meanrefA1_305 = np.array(S3meanrefA1_305)
S3meanA2_105 = np.array(S3meanA2_105)

S3hsvrefA1_305 = list()
S3hsvA2_105 = list()
for i in range(3):
    S3hsvrefA1_305.append(S3meanrefA1_305[:,i].mean())
    S3hsvA2_105.append(S3meanA2_105[:,i].mean())

# %%
S3meanrefA1_405 = list()
S3meanA3_105 = list()
for i in range(S3HSV_imgA1A3_5.shape[0]): 
     for j in range(S3HSV_imgA1A3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_405.append(S3HSV_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_105.append(S3HSV_imgA1A3_5[i][j])  
S3meanrefA1_405 = np.array(S3meanrefA1_405)
S3meanA3_1อ = np.array(S3meanA3_105)

S3hsvrefA1_405 = list()
S3hsvA3_105= list()
for i in range(3):
    S3hsvrefA1_405.append(S3meanrefA1_405[:,i].mean())
    S3hsvA3_105.append(S3meanA3_105[:,i].mean())

# %%
S3meanrefA1_505 = list()
S3eanA3_5105 = list()
for i in range(S3HSV_imgA1A3_55.shape[0]): 
     for j in range(S3HSV_imgA1A3_55.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_505.append(S3HSV_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5105.append(S3HSV_imgA1A3_55[i][j])  
S3meanrefA1_505 = np.array(S3meanrefA1_505)
S3meanA3_5105 = np.array(S3meanA3_5105)

S3hsvrefA1_505= list()
S3hsvA3_5105 = list()
for i in range(3):
    S3hsvrefA1_505.append(S3meanrefA1_505[:,i].mean())
    S3hsvA3_5105.append(S3meanA3_5105[:,i].mean())

# %%
S3meanrefA1_605 = list()
S3meanA4_105= list()
for i in range(S3HSV_imgA1A4_5.shape[0]): 
     for j in range(S3HSV_imgA1A4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_605.append(S3HSV_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_105.append(S3HSV_imgA1A4_5[i][j])  
S3meanrefA1_605 = np.array(S3meanrefA1_605)
S3meanA4_105 = np.array(S3meanA4_105)

S3hsvrefA1_605 = list()
S3hsvA4_105 = list()
for i in range(3):
    S3hsvrefA1_605.append(S3meanrefA1_605[:,i].mean())
    S3hsvA4_105.append(S3meanA4_105[:,i].mean())

# %%
S3meanrefA1_705 = list()
S3meanB1_105 = list()
for i in range(S3HSV_imgA1B1_5.shape[0]): 
     for j in range(S3HSV_imgA1B1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_705append(S3HSV_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_105.append(S3HSV_imgA1B1_5[i][j])  
S3meanrefA1_705 = np.array(S3meanrefA1_705)
S3meanB1_105 = np.array(S3meanB1_105)

S3hsvrefA1_705 = list()
S3hsvB1_105 = list()
for i in range(3):
    S3hsvrefA1_705.append(S3meanrefA1_7[:,i].mean())
    S3hsvB1_105.append(S3meanB1_1[:,i].mean())

# %%
S3meanrefA1_805 = list()
S3meanB2_105 = list()
for i in range(S3HSV_imgA1B2_5.shape[0]): 
     for j in range(S3HSV_imgA1B2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_8อ.append(S3HSV_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_105.append(S3HSV_imgA1B2_5[i][j])  
S3meanrefA1_805 = np.array(S3meanrefA1_805)
S3meanB2_105 = np.array(S3meanB2_105)

S3hsvrefA1_805 = list()
S3hsvB2_105 = list()
for i in range(3):
    S3hsvrefA1_805.append(S3meanrefA1_805[:,i].mean())
    S3hsvB2_105.append(S3meanB2_105[:,i].mean())

# %%
S3meanrefA1_905 = list()
S3meanB3_105= list()
for i in range(S3HSV_imgA1B3_5.shape[0]): 
     for j in range(S3HSV_imgA1B3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_905.append(S3HSV_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_105.append(S3HSV_imgA1B3_5[i][j])  
S3meanrefA1_905 = np.array(S3meanrefA1_905)
S3meanB3_105 = np.array(S3meanB3_105)

S3hsvrefA1_905 = list()
S3hsvB3_105 = list()
for i in range(3):
    S3hsvrefA1_905.append(S3meanrefA1_905[:,i].mean())
    S3hsvB3_105.append(S3meanB3_105[:,i].mean())

# %%
S3meanrefA1_1005 = list()
S3meanB4_105 = list()
for i in range(S3HSV_imgA1B4_5.shape[0]): 
     for j in range(S3HSV_imgA1B4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1005.append(S3HSV_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_105.append(S3HSV_imgA1B4_5[i][j])  
S3meanrefA1_1005 = np.array(S3meanrefA1_1005)
S3meanB4_105 = np.array(S3meanB4_105)

S3hsvrefA1_1005 = list()
S3hsvB4_105 = list()
for i in range(3):
    S3hsvrefA1_1005.append(S3meanrefA1_1005[:,i].mean())
    S3hsvB4_105.append(S3meanB4_105[:,i].mean())

# %%
S3meanrefA1_1105 = list()
S3meanC1_105 = list()
for i in range(S3HSV_imgA1C1_5.shape[0]): 
     for j in range(S3HSV_imgA1C1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1105.append(S3HSV_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_105.append(S3HSV_imgA1C1_5[i][j])  
S3meanrefA1_1105 = np.array(S3meanrefA1_1105)
S3meanC1_105 = np.array(S3meanC1_105)

S3hsvrefA1_1105 = list()
S3hsvC1_105= list()
for i in range(3):
    S3hsvrefA1_1105.append(S3meanrefA1_1105[:,i].mean())
    S3hsvC1_105.append(S3meanC1_105[:,i].mean())

# %%
S3meanrefA1_1205 = list()
S3meanC2_105 = list()
for i in range(S3HSV_imgA1C2_5.shape[0]): 
     for j in range(S3HSV_imgA1C2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1205.append(S3HSV_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_105append(S3HSV_imgA1C2_5[i][j])  
S3meanrefA1_1205 = np.array(S3meanrefA1_1205)
S3meanC2_105 = np.array(S3meanC2_105)

S3hsvrefA1_1205 = list()
S3hsvC2_105 = list()
for i in range(3):
    S3hsvrefA1_1205.append(S3meanrefA1_1205[:,i].mean())
    S3hsvC2_105.append(S3meanC2_105[:,i].mean())

# %%
S3meanrefA1_1305 = list()
S3meanC3_105 = list()
for i in range(S3HSV_imgA1C3_5.shape[0]): 
     for j in range(S3HSV_imgA1C3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1305 .append(S3HSV_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_105 .append(S3HSV_imgA1C3_5[i][j])  
S3meanrefA1_1305 = np.array(S3meanrefA1_1305)
S3meanC3_105 = np.array(S3meanC3_105)

S3hsvrefA1_1305 = list()
S3hsvC3_105 = list()
for i in range(3):
    S3hsvrefA1_1305.append(S3meanrefA1_1305[:,i].mean())
    S3hsvC3_105append(S3meanC3_105[:,i].mean())

# %%
S3meanrefA1_1405 = list()
S3meanC4_105 = list()
for i in range(S3HSV_imgA1C4_5.shape[0]): 
     for j in range(S3HSV_imgA1C4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1405.append(S3HSV_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_105.append(S3HSV_imgA1C4_5[i][j])  
S3meanrefA1_1405 = np.array(S3meanrefA1_1405)
S3meanC4_105 = np.array(S3meanC4_105)

S3hsvrefA1_1405 = list()
S3hsvC4_105 = list()
for i in range(3):
    S3hsvrefA1_1405.append(S3meanrefA1_1405[:,i].mean())
    S3hsvC4_105.append(S3meanC4_105[:,i].mean())

# %%
S3meanrefA1_1505  = list()
S3meanD2_105  = list()
for i in range(S3HSV_imgA1D2_5.shape[0]): 
     for j in range(S3HSV_imgA1D2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1505 .append(S3HSV_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_105 .append(S3HSV_imgA1D2_5[i][j])  
S3meanrefA1_1505 = np.array(S3meanrefA1_1505)
S3meanD2_105  = np.array(S3meanD2_105)

S3hsvrefA1_1505 = list()
S3hsvD2_105 = list()
for i in range(3):
    S3hsvrefA1_1505.append(S3meanrefA1_1505[:,i].mean())
    S3hsvD2_105.append(S3meanD2_105[:,i].mean())

# %%
S3meanrefA1_1605 = list()
S3meanD3_105 = list()
for i in range(S3HSV_imgA1D3_5.shape[0]): 
     for j in range(S3HSV_imgA1D3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1605.append(S3HSV_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_105.append(S3HSV_imgA1D3_5[i][j])  
S3meanrefA1_1605 = np.array(S3meanrefA1_1605)
S3meanD3_105 = np.array(S3meanD3_105)

S3hsvrefA1_1605 = list()
S3hsvD3_105 = list()
for i in range(3):
    S3hsvrefA1_1605.append(S3meanrefA1_1605[:,i].mean())
    S3hsvD3_105.append(S3meanD3_105[:,i].mean())

# %%
S3meanrefA1_1705= list()
S3meanD4_105 = list()
for i in range(S3HSV_imgA1D4_5.shape[0]): 
     for j in range(S3HSV_imgA1D4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1705.append(S3HSV_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_105.append(S3HSV_imgA1D4_5[i][j])  
S3meanrefA1_1705 = np.array(S3meanrefA1_1405)
S3meanD4_105 = np.array(S3meanD4_105)

S3hsvrefA1_1705 = list()
S3hsvD4_105 = list()
for i in range(3):
   S3 hsvrefA1_1705.append(S3meanrefA1_1705[:,i].mean())
    S3hsvD4_105.append(S3meanD4_105[:,i].mean())

# %% [markdown]
# ###Img 6

# %%
S3meanrefA1_106 = list()
S3meanA1_206 = list()
for i in range(S3HSV_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_6.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_106.append(S3HSV_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_206.append(S3HSV_imgA1A1_6[i][j])  
S3meanrefA1_106 = np.array(S3meanrefA1_106)
S3meanA1_206 = np.array(S3meanA1_206)

S3hsvrefA1_106 = list()
S3hsvA1_206 = list()
for i in range(3):
    S3hsvrefA1_106.append(S3meanrefA1_106[:,i].mean())
   S3hsvA1_206.append(S3meanA1_206[:,i].mean())
S3hsvrefA1_106,hsvA1_206

# %%
S3meanrefA1_306 = list()
S3meanA2_106 = list()
for i in range(S3HSV_imgA1A2_6.shape[0]): 
     for j in range(S3HSV_imgA1A2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_306.append(S3HSV_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_106.append(S3HSV_imgA1A2_6[i][j])  
S3meanrefA1_306 = np.array(S3meanrefA1_306 )
S3meanA2_106 = np.array(S3meanA2_106 )

S3hsvrefA1_306  = list()
S3hsvA2_106  = list()
for i in range(3):
    S3hsvrefA1_306.append(S3S1meanrefA1_306 [:,i].mean())
    S3hsvA2_106.append(S3S1meanA2_106 [:,i].mean())

# %%
S3meanrefA1_406  = list()
S3meanA3_106  = list()
for i in range(S3HSV_imgA1A3_6.shape[0]): 
     for j in range(S3HSV_imgA1A3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_406.append(S3HSV_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_106.append(S3HSV_imgA1A3_6[i][j])  
S3meanrefA1_406 = np.array(S3meanrefA1_406 )
S3meanA3_106  = np.array(S3meanA3_106 )

S3hsvrefA1_406  = list()
S3hsvA3_106  = list()
for i in range(3):
     S3hsvrefA1_406 .append(S3meanrefA1_4อ[:,i].mean())
     S3hsvA3_106 .append(S3meanA3_106 [:,i].mean())

# %%
S3meanrefA1_506  = list()
S3meanA3_5106  = list()
for i in range(S3HSV_imgA1A3_56.shape[0]): 
     for j in range(S3HSV_imgA1A3_56.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_506 .append(S3HSV_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5106 .append(S3HSV_imgA1A3_56[i][j])  
S3meanrefA1_506  = np.array(S3meanrefA1_506 )
S3meanA3_5106  = np.array(S3meanA3_5106 )

S3hsvrefA1_506  = list()
S3hsvA3_5106  = list()
for i in range(3):
    S3hsvrefA1_506 .append(S3meanrefA1_506 [:,i].mean())
    S3hsvA3_5106.append(S3meanA3_5106 [:,i].mean())

# %%
S3meanrefA1_606  = list()
S3meanA4_106  = list()
for i in range(S3HSV_imgA1A4_6.shape[0]): 
     for j in range(S3HSV_imgA1A4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_606 .append(S3HSV_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_106 .append(S3HSV_imgA1A4_6[i][j])  
S3meanrefA1_606  = np.array(S3meanrefA1_606 )
S3meanA4_106  = np.array(S3meanA4_106 )

S3hsvrefA1_606  = list()
S3hsvA4_106  = list()
for i in range(3):
    S3hsvrefA1_606 .append(S3meanrefA1_606 [:,i].mean())
    S3hsvA4_106 .append(S3meanA4_106 [:,i].mean())

# %%
S3meanrefA1_706  = list()
S3meanB1_106  = list()
for i in range(S3HSV_imgA1B1_6.shape[0]): 
     for j in range(S3HSV_imgA1B1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_706 .append(HSV_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_106 .append(HSV_imgA1B1_6[i][j])  
S3meanrefA1_706  = np.array(S3meanrefA1_706 )
S3meanB1_106  = np.array(S3meanB1_106 )

S3hsvrefA1_706  = list()
S3hsvB1_106  = list()
for i in range(3):
    S3hsvrefA1_706 .append(S3meanrefA1_706 [:,i].mean())
   S3hsvB1_106 .append(S3meanB1_106 [:,i].mean())

# %%
S3meanrefA1_806  = list()
S3meanB2_106  = list()
for i in range(S3HSV_imgA1B2_6.shape[0]): 
     for j in range(S3HSV_imgA1B2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_8อ.append(S3HSV_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_106 .append(S3HSV_imgA1B2_6[i][j])  
S3meanrefA1_806 = np.array(S3meanrefA1_806 )
S3meanB2_106  = np.array(S3meanB2_106 )

S3hsvrefA1_806  = list()
S3hsvB2_106  = list()
for i in range(3):
    S3hsvrefA1_806 .append(S3meanrefA1_806 [:,i].mean())
    S3hsvB2_106 .append(S3meanB2_106 [:,i].mean())

# %%
S3meanrefA1_906  = list()
S3meanB3_106  = list()
for i in range(S3HSV_imgA1B3_6.shape[0]): 
     for j in range(S3HSV_imgA1B3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_906 .append(S3HSV_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_106 .append(S3HSV_imgA1B3_6[i][j])  
S3meanrefA1_906  = np.array(S3meanrefA1_906)
S3meanB3_106  = np.array(S3meanB3_106)

S3hsvrefA1_906 = list()
S3hsvB3_106 = list()
for i in range(3):
    S3hsvrefA1_906.append(S3meanrefA1_906[:,i].mean())
    S3hsvB3_106.append(S3meanB3_106[:,i].mean())

# %%
meanrefA1_1006 = list()
meanB4_106 = list()
for i in range(HSV_imgA1B4_6.shape[0]): 
     for j in range(HSV_imgA1B4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                   meanrefA1_1006.append(HSV_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  meanB4_106.append(HSV_imgA1B4_6[i][j])  
meanrefA1_1006 = np.array(meanrefA1_1006)
meanB4_106 = np.array(meanB4_106)

hsvrefA1_1006 = list()
hsvB4_106 = list()
for i in range(3):
    hsvrefA1_1006.append(meanrefA1_1006[:,i].mean())
    hsvB4_106.append(meanB4_106[:,i].mean())

# %%
S3meanrefA1_1106 = list()
S3meanC1_106 = list()
for i in range(S3HSV_imgA1C1_6.shape[0]): 
     for j in range(S3HSV_imgA1C1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1106.append(S3HSV_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_106.append(S3HSV_imgA1C1_6[i][j])  
S3meanrefA1_1106 = np.array(S3meanrefA1_1106)
S3meanC1_106 = np.array(S3meanC1_106)

S3hsvrefA1_1106 = list()
S3hsvC1_106 = list()
for i in range(3):
    S3hsvrefA1_1106.append(S3meanrefA1_1106[:,i].mean())
    S3hsvC1_106.append(S3meanC1_106[:,i].mean())

# %%
S3meanrefA1_1206 = list()
S3meanC2_106 = list()
for i in range(S3HSV_imgA1C2_6.shape[0]): 
     for j in range(VHSV_imgA1C2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                   S3meanrefA1_1206.append(S3HSV_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  VmeanC2_106.append(S3HSV_imgA1C2_6[i][j])  
S3meanrefA1_1206 = np.array(S3meanrefA1_1206)
S3meanC2_106 = np.array(S3meanC2_106)

S3hsvrefA1_1206 = list()
S3hsvC2_106 = list()
for i in range(3):
    S3hsvrefA1_1206.append(S3meanrefA1_12[:,i].mean())
    S3hsvC2_106.append(S3meanC2_1[:,i].mean())

# %%
S3meanrefA1_1306 = list()
S3meanC3_106 = list()
for i in range(S3HSV_imgA1C3_6.shape[0]): 
     for j in range(S3HSV_imgA1C3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1306.append(S3HSV_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_106.append(vHSV_imgA1C3_6[i][j])  
S3meanrefA1_1306 = np.array(vmeanrefA1_1306)
S3meanC3_106 = np.array(S3meanC3_106

S3hsvrefA1_1306 = list()
S3S1hsvC3_106 = list()
for i in range(3):
    S3hsvrefA1_1306.append(S3meanrefA1_1306[:,i].mean())
    S3hsvC3_106.append(S3meanC3_106[:,i].mean())

# %%
S3meanrefA1_1406 = list()
S3meanC4_106 = list()
for i in range(S3HSV_imgA1C4_6.shape[0]): 
     for j in range(S3HSV_imgA1C4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1406.append(S3HSV_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_106.append(S3HSV_imgA1C4_6[i][j])  
S3meanrefA1_1406 = np.array(S3meanrefA1_1406)
S3meanC4_106 = np.array(S3meanC4_106)

S3hsvrefA1_1406 = list()
S3hsvC4_106 = list()
for i in range(3):
    S3hsvrefA1_1406.append(S3meanrefA1_1406[:,i].mean())
    S3hsvC4_106.append(S3meanC4_106[:,i].mean())

# %%
S3meanrefA1_1506 = list()
S3meanD2_106 = list()
for i in range(S3HSV_imgA1D2_6.shape[0]): 
     for j in range(S3HSV_imgA1D2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1506.append(S3HSV_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_106.append(S3HSV_imgA1D2_6[i][j])  
S3meanrefA1_1506 = np.array(S3meanrefA1_1506)
S3meanD2_106 = np.array(S3meanD2_106)

S3hsvrefA1_1506 = list()
S3hsvD2_106 = list()
for i in range(3):
    S3hsvrefA1_1506.append(S3meanrefA1_1506[:,i].mean())
    S3hsvD2_106.append(S3meanD2_106[:,i].mean())

# %%
S3meanrefA1_1606 = list()
S3meanD3_106 = list()
for i in range(S3HSV_imgA1D3_6.shape[0]): 
     for j in range(S3HSV_imgA1D3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1606.append(S3HSV_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_106.append(S3HSV_imgA1D3_6[i][j])  
S3meanrefA1_1606 = np.array(S3meanrefA1_1606)
S3meanD3_106 = np.array(S3meanD3_106)

S3hsvrefA1_1606 = list()
S3hsvD3_106 = list()
for i in range(3):
    S3hsvrefA1_1606.append(S3meanrefA1_1606[:,i].mean())
    S3hsvD3_1v.append(S3meanD3_106[:,i].mean())

# %%
S3meanrefA1_1706= list()
S3meanD4_106 = list()
for i in range(S3HSV_imgA1D4_6.shape[0]): 
     for j in range(S3HSV_imgA1D4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1706.append(S3HSV_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_106.append(S3HSV_imgA1D4_6[i][j])  
S3meanrefA1_1706 = np.array(S3meanrefA1_1406)
S3meanD4_106 = np.array(S3meanD4_106)

S3hsvrefA1_1706 = list()
S3hsvD4_10606 = list()
for i in range(3):
    S3hsvrefA1_1706.append(S3meanrefA1_1706[:,i].mean())
    S3hsvD4_106.append(S3meanD4_106[:,i].mean())

# %% [markdown]
# ###Img 7

# %%
S3meanrefA1_107 = list()
S3meanA1_207 = list()
for i in range(S3HSV_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_107.append(S3HSV_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_207.append(S3HSV_imgA1A1_7[i][j])  
S3meanrefA1_107 = np.array(S3meanrefA1_107)
S3meanA1_207 = np.array(S3meanA1_207)

S3hsvrefA1_107 = list()
S3hsvA1_207 = list()
for i in range(3):
    S3hsvrefA1_107.append(S3meanrefA1_107[:,i].mean())
    S3hsvA1_207.append(S3meanA1_207[:,i].mean())
S3hsvrefA1_107,hsvA1_207

# %%
S3meanrefA1_307 = list()
S3meanA2_107 = list()
for i in range(S3HSV_imgA1A2_7.shape[0]): 
     for j in range(S3HSV_imgA1A2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_307.append(S3HSV_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_107.append(S3HSV_imgA1A2_7[i][j])  
S3meanrefA1_307 = np.array(S3meanrefA1_307)
S3meanA2_107 = np.array(S3meanA2_1v)

S3hsvrefA1_307 = list()
S3hsvA2_107 = list()
for i in range(3):
    S3hsvrefA1_307.append(S3meanrefA1_307[:,i].mean())
    S3hsvA2_107.append(S3meanA2_107[:,i].mean())

# %%
S3meanrefA1_407 = list()
S3meanA3_107 = list()
for i in range(S3HSV_imgA1A3_7.shape[0]): 
     for j in range(S3HSV_imgA1A3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_407.append(S3HSV_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_107.append(S3HSV_imgA1A3_7[i][j])  
S3meanrefA1_407 = np.array(S3meanrefA1_407)
S3meanA3_107 = np.array(S3meanA3_107)

S3hsvrefA1_407 = list()
S3hsvA3_107 = list()
for i in range(3):
    S3hsvrefA1_407.append(S3meanrefA1_407[:,i].mean())
   S3hsvA3_107.append(S3meanA3_107[:,i].mean())

# %%
S3meanrefA1_507 = list()
S3meanA3_5107 = list()
for i in range(S3HSV_imgA1A3_5707.shape[0]): 
     for j in range(S3HSV_imgA1A3_57.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_507.append(S3HSV_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5107.append(S3HSV_imgA1A3_57[i][j])  
S3meanrefA1_5v = np.array(S3meanrefA1_5v)
S3meanA3_5107 = np.array(S3meanA3_5107)

S3hsvrefA1_507 = list()
S3hsvA3_5107 = list()
for i in range(3):
    S3hsvrefA1_507.append(S3meanrefA1_507[:,i].mean())
    S3hsvA3_5107.append(S3meanA3_5107[:,i].mean())

# %%
S3meanrefA1_607 = list()
S3meanA4_107 = list()
for i in range(S3HSV_imgA1A4_7.shape[0]): 
     for j in range(S3HSV_imgA1A4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_607.append(S3HSV_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_107.append(S3HSV_imgA1A4_7[i][j])  
S3meanrefA1_607 = np.array(S3meanrefA1_607)
S3meanA4_1v = np.array(S3meanA4_107)

S3hsvrefA1_607 = list()
S3hsvA4_107 = list()
for i in range(3):
    S3hsvrefA1_607.append(S3meanrefA1_607[:,i].mean())
    S3hsvA4_107.append(S3meanA4_107[:,i].mean())

# %%
S3meanrefA1_707 = list()
S3meanB1_107 = list()
for i in range(S3HSV_imgA1B1_7.shape[0]): 
     for j in range(S3HSV_imgA1B1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_707.append(S3HSV_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_107.append(S3HSV_imgA1B1_7[i][j])  
S3meanrefA1_707 = np.array(S3meanrefA1_7)
S3meanB1_107= np.array(S3meanB1_1)

S3hsvrefA1_707 = list()
S3hsvB1_107 = list()
for i in range(3):
    S3hsvrefA1_707.append(S3meanrefA1_707[:,i].mean())
    S3hsvB1_107.append(S3meanB1_107[:,i].mean())

# %%
S3meanrefA1_807 = list()
S3meanB2_107 = list()
for i in range(S3HSV_imgA1B2_7.shape[0]): 
     for j in range(S3HSV_imgA1B2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_807.append(S3HSV_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_107.append(S3HSV_imgA1B2_7[i][j])  
S3meanrefA1_807 = np.array(S3meanrefA1_807)
S3meanB2_107 = np.array(S3meanB2_107)

S3hsvrefA1_807 = list()
S3hsvB2_107 = list()
for i in range(3):
    S3hsvrefA1_807.append(S3meanrefA1_807[:,i].mean())
    S3hsvB2_107.append(S3meanB2_107[:,i].mean())

# %%
S3meanrefA1_907 = list()
S3meanB3_107 = list()
for i in range(S3HSV_imgA1B3_7.shape[0]): 
     for j in range(S3HSV_imgA1B3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_907.append(S3HSV_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_107.append(S3HSV_imgA1B3_7[i][j])  
S3meanrefA1_907= np.array(S3meanrefA1_907)
S3meanB3_107 = np.array(S3meanB3_107)

S3hsvrefA1_907 = list()
S3hsvB3_107 = list()
for i in range(3):
     S3hsvrefA1_907.append(S3meanrefA1_907[:,i].mean())
     S3hsvB3_107.append(S3meanB3_107[:,i].mean())

# %%
S3meanrefA1_1007 = list()
S3meanB4_107 = list()
for i in range(S3HSV_imgA1B4_7.shape[0]): 
     for j in range(S3HSV_imgA1B4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1007.append(S3HSV_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  meanB4_107.append(S3HSV_imgA1B4_7[i][j])  
S3meanrefA1_1007= np.array(S3meanrefA1_1007)
S3meanB4_107 = np.array(S3meanB4_107)

S3hsvrefA1_1007 = list()
S3hsvB4_107 = list()
for i in range(3):
    S3hsvrefA1_1007.append(S3meanrefA1_1007[:,i].mean())
    S3hsvB4_107.append(S3meanB4_107[:,i].mean())

# %%
S3meanrefA1_1107 = list()
S3meanC1_1v = list()
for i in range(S3HSV_imgA1C1_7.shape[0]): 
     for j in range(S3HSV_imgA1C1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1107.append(S3HSV_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_107.append(S3HSV_imgA1C1_7[i][j])  
S3meanrefA1_1107= np.array(S3meanrefA1_1107)
S3meanC1_107 = np.array(S3meanC1_107)

S3hsvrefA1_1107 = list()
hsvC1_107 = list()
for i in range(3):
    S3hsvrefA1_1107.append(S3meanrefA1_1107[:,i].mean())
    S3hsvC1_107.append(S3meanC1_107[:,i].mean())

# %%
S3meanrefA1_1207 = list()
S3meanC2_107 = list()
for i in range(S3HSV_imgA1C2_7.shape[0]): 
     for j in range(S3HSV_imgA1C2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1207.append(S3HSV_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_107.append(S3HSV_imgA1C2_7[i][j])  
S3meanrefA1_1207 = np.array(S3meanrefA1_1207)
S3meanC2_107 = np.array(S3meanC2_107)

S3hsvrefA1_1207 = list()
S3hsvC2_107 = list()
for i in range(3):
    S3hsvrefA1_1207.append(S3meanrefA1_12v[:,i].mean())
    S3hsvC2_107.append(S3meanC2_107[:,i].mean())

# %%
S3meanrefA1_1307 = list()
S3meanC3_107 = list()
for i in range(S3HSV_imgA1C3_7.shape[0]): 
     for j in range(S3HSV_imgA1C3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1307.append(S3HSV_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_107.append(S3HSV_imgA1C3_7[i][j])  
S3meanrefA1_1307 = np.array(S3meanrefA1_1307)
S3meanC3_107 = np.array(S3meanC3_107)

S3hsvrefA1_1307 = list()
S3hsvC3_107 = list()
for i in range(3):
    S3hsvrefA1_1307.append(S3meanrefA1_1307[:,i].mean())
    S3hsvC3_107.append(S3meanC3_107[:,i].mean())

# %%
S3meanrefA1_1407 = list()
S3meanC4_107 = list()
for i in range(S3HSV_imgA1C4_7.shape[0]): 
     for j in range(S3HSV_imgA1C4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1407.append(S3HSV_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_107.append(S3HSV_imgA1C4_7[i][j])  
S3meanrefA1_1407 = np.array(S3meanrefA1_1407)
S3meanC4_107 = np.array(S3meanC4_107)

S3hsvrefA1_1407 = list()
S3hsvC4_107 = list()
for i in range(3):
    S3hsvrefA1_1407.append(S3meanrefA1_1407[:,i].mean())
    S3hsvC4_107.append(S3meanC4_107[:,i].mean())

# %%
S3meanrefA1_1507 = list()
S3meanD2_107 = list()
for i in range(S3HSV_imgA1D2_7.shape[0]): 
     for j in range(S3HSV_imgA1D2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1507.append(S3HSV_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_107.append(S3HSV_imgA1D2_7[i][j])  
S3meanrefA1_1507 = np.array(S3meanrefA1_1507)
S3meanD2_107 = np.array(S3meanD2_107)

S3hsvrefA1_1507= list()
S3hsvD2_107 = list()
for i in range(3):
    S3hsvrefA1_1507.append(S3meanrefA1_1507[:,i].mean())
    S3hsvD2_107.append(vmeanD2_107[:,i].mean())

# %%
S3meanrefA1_1607 = list()
S3meanD3_107 = list()
for i in range(S3HSV_imgA1D3_7.shape[0]): 
     for j in range(S3HSV_imgA1D3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1607.append(S3HSV_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_107.append(S3HSV_imgA1D3_7[i][j])  
S3meanrefA1_1607 = np.array(S3meanrefA1_1607)
S3meanD3_107 = np.array(S3meanD3_107)

S3hsvrefA1_1607 = list()
S3hsvD3_107 = list()
for i in range(3):
    S3hsvrefA1_1607.append(S3meanrefA1_1607[:,i].mean())
    S3hsvD3_107.append(S3meanD3_107[:,i].mean())

# %%
S3meanrefA1_1707= list()
S3meanD4_107 = list()
for i in range(S3HSV_imgA1D4_7.shape[0]): 
     for j in range(S3HSV_imgA1D4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1707.append(S3HSV_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_107.append(S3HSV_imgA1D4_7[i][j])  
S3meanrefA1_1707 = np.array(S3meanrefA1_1407)
S3meanD4_107 = np.array(S3meanD4_107,;)

S3hsvrefA1_1707 = list()
S3hsvD4_107 = list()
for i in range(3):
    S3hsvrefA1_1707.append(S3meanrefA1_1707[:,i].mean())
    S3hsvD4_107.append(S3meanD4_107[:,i].mean())

# %% [markdown]
# ###Img 8

# %%
S3meanrefA1_108 = list()
S3meanA1_208 = list()
for i in range(S3HSV_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_108.append(S3HSV_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_208.append(S3HSV_imgA1A1_8[i][j])  
S3meanrefA1_108 = np.array(S3meanrefA1_108)
S3meanA1_208 = np.array(S3meanA1_208)

S3hsvrefA1_108 = list()
S3hsvA1_208 = list()
for i in range(3):
    S3hsvrefA1_108.append(S3meanrefA1_108[:,i].mean())
    S3hsvA1_208.append(S3meanA1_208[:,i].mean())
S3hsvrefA1_108,hsvA1_208

# %%
S3meanrefA1_308 = list()
S3meanA2_108 = list()
for i in range(S3HSV_imgA1A2_8.shape[0]): 
     for j in range(S3HSV_imgA1A2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_308.append(S3HSV_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_108.append(S3HSV_imgA1A2_8[i][j])  
S3meanrefA1_308 = np.array(S3meanrefA1_308)
S3meanA2_108 = np.array(S3meanA2_108)

S3hsvrefA1_308 = list()
S3hsvA2_108 = list()
for i in range(3):
    S3hsvrefA1_308.appendS3meanrefA1_308[:,i].mean())
    S3hsvA2_108.append(S3meanA2_108[:,i].mean())

# %%
S3meanrefA1_408 = list()
S3meanA3_108 = list()
for i in range(S3HSV_imgA1A3_8.shape[0]): 
     for j in range(S3HSV_imgA1A3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_408.append(S3HSV_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_108.append(S3HSV_imgA1A3_8[i][j])  
S3meanrefA1_408 = np.array(S3meanrefA1_408)
S3meanA3_108 = np.array(S3meanA3_108)

S3hsvrefA1_408 = list()
S3hsvA3_108 = list()
for i in range(3):
    S3hsvrefA1_408.append(S3meanrefA1_408[:,i].mean())
    S3hsvA3_108.append(S3meanA3_108[:,i].mean())

# %%
S3meanrefA1_508 = list()
S3meanA3_5108 = list()
for i in range(S3HSV_imgA1A3_58.shape[0]): 
     for j in range(S3HSV_imgA1A3_58.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_508.append(S3HSV_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5108.append(S3HSV_imgA1A3_58[i][j])  
S3meanrefA1_508 = np.array(S3meanrefA1_508)
S3meanA3_5108 = np.array(S3meanA3_5108)

S3hsvrefA1_508 = list()
S3hsvA3_5108 = list()
for i in range(3):
    S3hsvrefA1_508.append(S3meanrefA1_508[:,i].mean())
    S3hsvA3_5108.append(S3meanA3_5108[:,i].mean())

# %%
S3meanrefA1_608 = list()
S3meanA4_108 = list()
for i in range(S3HSV_imgA1A4_8.shape[0]): 
     for j in range(S3HSV_imgA1A4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_608.append(S3HSV_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_108.append(S3HSV_imgA1A4_8[i][j])  
S3meanrefA1_608 = np.array(S3meanrefA1_608)
S3meanA4_108 = np.array(S3meanA4_108)

S3hsvrefA1_608 = list()
S3hsvA4_108= list()
for i in range(3):
    S3hsvrefA1_608.append(S3meanrefA1_608[:,i].mean())
    S3hsvA4_108.append(S3meanA4_108[:,i].mean())

# %%
S3meanrefA1_708 = list()
S3meanB1_108 = list()
for i in range(S3HSV_imgA1B1_8.shape[0]): 
     for j in range(S3HSV_imgA1B1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_708.append(S3HSV_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanB1_108.append(S3HSV_imgA1B1_8[i][j])  
S3meanrefA1_708 = np.array(S3meanrefA1_708)
S3meanB1_108 = np.array(S3meanB1_108)

S3hsvrefA1_708 = list()
S3hsvB1_108 = list()
for i in range(3):
    S3hsvrefA1_708.append(S3meanrefA1_708[:,i].mean())
    S3hsvB1_108.append(S3meanB1_108[:,i].mean())

# %%
S3meanrefA1_808 = list()
S3meanB2_108 = list()
for i in range(S3HSV_imgA1B2_8.shape[0]): 
     for j in range(S3HSV_imgA1B2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_808.append(S3HSV_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_108.append(S3HSV_imgA1B2_8[i][j])  
S3meanrefA1_808 = np.array(S3meanrefA1_808)
S3meanB2_108 = np.array(S3meanB2_108)

S3hsvrefA1_808 = list()
S3hsvB2_108 = list()
for i in range(3):
    S3hsvrefA1_808.append(S3meanrefA1_808[:,i].mean())
    S3hsvB2_108.append(S3meanB2_108[:,i].mean())

# %%
S3meanrefA1_908 = list()
S3meanB3_108 = list()
for i in range(S3HSV_imgA1B3_8.shape[0]): 
     for j in range(S3HSV_imgA1B3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_908.append(S3HSV_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_108.append(S3HSV_imgA1B3_8[i][j])  
S3meanrefA1_908 = np.array(S3meanrefA1_908)
S3meanB3_108 = np.array(S3meanB3_108)

S3hsvrefA1_908 = list()
S3hsvB3_108 = list()
for i in range(3):
    S3hsvrefA1_908.append(S3meanrefA1_908[:,i].mean())
    S3hsvB3_108.append(S3meanB3_108[:,i].mean())

# %%
S3meanrefA1_1008 = list()
S3meanB4_108 = list()
for i in range(S3HSV_imgA1B4_8.shape[0]): 
     for j in range(S3HSV_imgA1B4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1008.append(S3HSV_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_108.append(S3HSV_imgA1B4_8[i][j])  
S3meanrefA1_1008 = np.array(S3meanrefA1_1008)
S3meanB4_108 = np.array(S3meanB4_108)

S3hsvrefA1_1008 = list()
S3hsvB4_108 = list()
for i in range(3):
    S3hsvrefA1_1008.append(S3meanrefA1_1008[:,i].mean())
    S3hsvB4_108.append(S3meanB4_108[:,i].mean())

# %%
S3meanrefA1_1108 = list()
S3meanC1_108 = list()
for i in range(S3HSV_imgA1C1_8.shape[0]): 
     for j in range(S3HSV_imgA1C1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1108.append(S3HSV_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_108.append(S3HSV_imgA1C1_8[i][j])  
S3meanrefA1_1108 = np.array(S3meanrefA1_1108)
S3meanC1_108 = np.array(S3meanC1_108)

S3hsvrefA1_1108 = list()
S3hsvC1_108 = list()
for i in range(3):
    S3hsvrefA1_1108.append(S3meanrefA1_1108[:,i].mean())
    S3hsvC1_108.append(S3meanC1_108[:,i].mean())

# %%
S3meanrefA1_1208 = list()
S3meanC2_108 = list()
for i in range(S3HSV_imgA1C2_808.shape[0]): 
     for j in range(S3HSV_imgA1C2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1208.append(S3HSV_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_108.append(S3HSV_imgA1C2_8[i][j])  
S3meanrefA1_12v = np.array(S3meanrefA1_1208)
S3meanC2_108 = np.array(S3meanC2_108)

S3hsvrefA1_12v = list()
S3hsvC2_108 = list()
for i in range(3):
    S3hsvrefA1_1208.append(S3meanrefA1_1208[:,i].mean())
    S3hsvC2_108.append(S3meanC2_108[:,i].mean())

# %%
S3meanrefA1_1308 = list()
S3meanC3_108 = list()
for i in range(S3HSV_imgA1C3_8.shape[0]): 
     for j in range(S3HSV_imgA1C3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1308.append(S3HSV_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_108.append(S3HSV_imgA1C3_8[i][j])  
S3meanrefA1_1308 = np.array(S3meanrefA1_1308)
S3meanC3_108 = np.array(S3meanC3_108)

S3hsvrefA1_1308 = list()
S3hsvC3_108 = list()
for i in range(3):
    S3hsvrefA1_1308.append(S3meanrefA1_1308[:,i].mean())
    S3hsvC3_108.append(S3meanC3_108[:,i].mean())

# %%
S3meanrefA1_1408 = list()
S3meanC4_108 = list()
for i in range(S3HSV_imgA1C4_8.shape[0]): 
     for j in range(S3HSV_imgA1C4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_1408.append(S3HSV_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_108.append(S3HSV_imgA1C4_8[i][j])  
S3meanrefA1_1408 = np.array(S3meanrefA1_1408)
S3meanC4_108 = np.array(S3meanC4_108)

S3hsvrefA1_1408 = list()
S3hsvC4_108= list()
for i in range(3):
    S3hsvrefA1_1408.append(S3meanrefA1_1408[:,i].mean())
    S3hsvC4_108.append(S3meanC4_108[:,i].mean())

# %%
S3meanrefA1_1508 = list()
S3meanD2_108 = list()
for i in range(S3HSV_imgA1D2_8.shape[0]): 
     for j in range(S3HSV_imgA1D2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  meanrefA1_1508.append(S3HSV_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_108.append(S3HSV_imgA1D2_8[i][j])  
S3meanrefA1_1508 = np.array(S3meanrefA1_1508)
S3meanD2_108 = np.array(S3meanD2_108)

S3hsvrefA1_1508 = list()
S3hsvD2_108 = list()
for i in range(3):
    S3hsvrefA1_1508.append(S3meanrefA1_1508[:,i].mean())
    S3hsvD2_108.append(S3meanD2_108[:,i].mean())

# %%
S3meanrefA1_1608 = list()
S3meanD3_108 = list()
for i in range(HS3SV_imgA1D3_8.shape[0]): 
     for j in range(S3HSV_imgA1D3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1608.append(S3HSV_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_108.append(S3HSV_imgA1D3_8[i][j])  
S3meanrefA1_1608 = np.array(S3meanrefA1_1608)
S3meanD3_108 = np.array(S3meanD3_108)

S3hsvrefA1_1608 = list()
S3hsvD3_108 = list()
for i in range(3):
    S3hsvrefA1_1608.append(S3meanrefA1_1608[:,i].mean())
    S3hsvD3_108.append(S3meanD3_108[:,i].mean())

# %%
S3meanrefA1_1708= list()
S3meanD4_108 = list()
for i in range(S3HSV_imgA1D4_8.shape[0]): 
     for j in range(S3HSV_imgA1D4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1708.append(S3HSV_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_108.append(S3HSV_imgA1D4_8[i][j])  
S3meanrefA1_1708= np.array(S3meanrefA1_1408)
S3meanD4_108 = np.array(S3meanD4_108)

S3hsvrefA1_1708 = list()
S3hsvD4_108 = list()
for i in range(3):
    S3hsvrefA1_1708.append(S3meanrefA1_1708[:,i].mean())
    S3hsvD4_108.append(S3meanD4_108[:,i].mean())

# %% [markdown]
# ###Img 9

# %%
S3meanrefA1_109 = list()
S3meanA1_209 = list()
for i in range(S3HSV_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_109.append(S3HSV_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_209.append(S3HSV_imgA1A1_9[i][j])  
S3meanrefA1_109 = np.array(S3meanrefA1_109)
S3meanA1_209 = np.array(S3meanA1_209)

S3hsvrefA1_109 = list()
S3hsvA1_209 = list()
for i in range(3):
    S3hsvrefA1_109.append(S3meanrefA1_109[:,i].mean())
    S3hsvA1_209.append(S3meanA1_209[:,i].mean())
S3hsvrefA1_109,S3hsvA1_209

# %%
S3meanrefA1_309 = list()
S3meanA2_109 = list()
for i in range(S3HSV_imgA1A2_9.shape[0]): 
     for j in range(S3HSV_imgA1A2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_309.append(S3HSV_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_109.append(S3HSV_imgA1A2_9[i][j])  
S3meanrefA1_309 = np.array(S3meanrefA1_309)
S3meanA2_109 = np.array(S3meanA2_109)

S3hsvrefA1_309 = list()
S3hsvA2_109 = list()
for i in range(3):
    S3hsvrefA1_309.append(S3meanrefA1_309[:,i].mean())
    S3hsvA2_109.append(S3meanA2_109[:,i].mean())

# %%
S3meanrefA1_409 = list()
S3meanA3_109 = list()
for i in range(S3HSV_imgA1A3_9.shape[0]): 
     for j in range(S3HSV_imgA1A3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_409.append(S3HSV_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_109.append(S3HSV_imgA1A3_9[i][j])  
S3meanrefA1_409 = np.array(S3meanrefA1_409
S3meanA3_109 = np.array(S3meanA3_109)

S3hsvrefA1_409= list()
S3hsvA3_109 = list()
for i in range(3):
    S3hsvrefA1_409.append(S3meanrefA1_409[:,i].mean())
    S3hsvA3_109.append(S3meanA3_109[:,i].mean())

# %%
S3meanrefA1_509 = list()
S3meanA3_5109 = list()
for i in range(S3HSV_imgA1A3_59.shape[0]): 
     for j in range(S3HSV_imgA1A3_59.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_509.append(S3HSV_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5109.append(S3HSV_imgA1A3_59[i][j])  
S3meanrefA1_509 = np.array(S3meanrefA1_509)
S3meanA3_5109 = np.array(S3meanA3_5109)

S3hsvrefA1_509 = list()
S3hsvA3_5109 = list()
for i in range(3):
    S3hsvrefA1_509.append(S3meanrefA1_509[:,i].mean())
    S3hsvA3_5109.append(S3meanA3_5109[:,i].mean())

# %%
S3meanrefA1_609 = list()
S3meanA4_109 = list()
for i in range(S3HSV_imgA1A4_9.shape[0]): 
     for j in range(S3HSV_imgA1A4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_609.append(S3HSV_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_109.append(S3HSV_imgA1A4_9[i][j])  
S3meanrefA1_609 = np.array(S3meanrefA1_609)
S3meanA4_109 = np.array(S3meanA4_109)

S3hsvrefA1_609 = list()
S3hsvA4_109 = list()
for i in range(3):
    S3hsvrefA1_609.append(S3meanrefA1_609[:,i].mean())
    S3hsvA4_109.append(S3meanA4_109[:,i].mean())

# %%
S3meanrefA1_709 = list()
S3meanB1_109 = list()
for i in range(S3HSV_imgA1B1_9.shape[0]): 
     for j in range(S3HSV_imgA1B1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_709.append(S3HSV_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_109.append(S3HSV_imgA1B1_9[i][j])  
S3meanrefA1_709 = np.array(S3meanrefA1_709)
S3meanB1_109 = np.array(S3meanB1_109)

S3hsvrefA1_709 = list()
S3hsvB1_109 = list()
for i in range(3):
    S3hsvrefA1_709.append(S3meanrefA1_709[:,i].mean())
   S3hsvB1_109.append(S3meanB1_109[:,i].mean())

# %%
S3meanrefA1_809 = list()
S3meanB2_109= list()
for i in range(S3HSV_imgA1B2_9.shape[0]): 
     for j in range(S3HSV_imgA1B2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_809.append(S3HSV_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_109.append(S3HSV_imgA1B2_9[i][j])  
S3meanrefA1_809 = np.array(S3meanrefA1_809)
S3meanB2_109 = np.array(S3meanB2_109)

S3hsvrefA1_809 = list()
S3hsvB2_109 = list()
for i in range(3):
    S3hsvrefA1_809.append(S3meanrefA1_809[:,i].mean())
    S3hsvB2_109.append(S3meanB2_109[:,i].mean())

# %%
S3meanrefA1_909 = list()
S3meanB3_109 = list()
for i in range(S3HSV_imgA1B3_9.shape[0]): 
     for j in range(S3HSV_imgA1B3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_909.append(S3HSV_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_109.append(S3HSV_imgA1B3_9[i][j])  
S3meanrefA1_909 = np.array(S3meanrefA1_909)
S3meanB3_109 = np.array(S3meanB3_109)

S3hsvrefA1_909 = list()
S3hsvB3_109 = list()
for i in range(3):
    S3hsvrefA1_909.append(S3meanrefA1_909[:,i].mean())
    S3hsvB3_109.append(S3meanB3_109[:,i].mean())

# %%
S3meanrefA1_1009 = list()
S3meanB4_109 = list()
for i in range(S3HSV_imgA1B4_9.shape[0]): 
     for j in range(S3HSV_imgA1B4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1009.append(S3HSV_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_109.append(S3HSV_imgA1B4_9[i][j])  
S3meanrefA1_1009= np.array(S3meanrefA1_1009)
S3meanB4_109 = np.array(S3meanB4_109)

S3hsvrefA1_1009 = list()
S3hsvB4_109 = list()
for i in range(3):
    S3hsvrefA1_1009.append(S3meanrefA1_1009[:,i].mean())
    S3hsvB4_109.append(S3meanB4_109[:,i].mean())

# %%
S3meanrefA1_1109 = list()
S3meanC1_109 = list()
for i in range(S3HSV_imgA1C1_9.shape[0]): 
     for j in range(S3HSV_imgA1C1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1109.append(S3HSV_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_109.append(S3HSV_imgA1C1_9[i][j])  
S3meanrefA1_1109 = np.array(S3meanrefA1_1109)
S3meanC1_109 = np.array(S3meanC1_109)

S3hsvrefA1_1109 = list()
S3hsvC1_109 = list()
for i in range(3):
    S3hsvrefA1_1109.append(S3meanrefA1_1109[:,i].mean())
    S3hsvC1_109.append(S3meanC1_109[:,i].mean())

# %%
S3meanrefA1_1209 = list()
S3meanC2_109 = list()
for i in range(S3HSV_imgA1C2_909.shape[0]): 
     for j in range(S3HSV_imgA1C2_909.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1209.append(S3HSV_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_109.append(S3HSV_imgA1C2_9[i][j])  
S3meanrefA1_1209 = np.array(S3meanrefA1_1209)
S3meanC2_109 = np.array(S3meanC2_109)

S3hsvrefA1_1209 = list()
S3hsvC2_109= list()
for i in range(3):
    S3hsvrefA1_1209.append(S3meanrefA1_1209[:,i].mean())
    S3hsvC2_109.append(S3meanC2_109[:,i].mean())

# %%
S3meanrefA1_1309 = list()
S3meanC3_109 = list()
for i in range(S3HSV_imgA1C3_9.shape[0]): 
     for j in range(S3HSV_imgA1C3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1309.append(S3HSV_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_109.append(S3HSV_imgA1C3_9[i][j])  
S3meanrefA1_1309 = np.array(S3meanrefA1_1309)
S3meanC3_109 = np.array(S3meanC3_109)

S3hsvrefA1_1309 = list()
S3hsvC3_109 = list()
for i in range(3):
    S3hsvrefA1_1309.append(S3meanrefA1_1309[:,i].mean())
    S3hsvC3_109.append(S3meanC3_109[:,i].mean())

# %%
S3meanrefA1_1409 = list()
S3meanC4_109 = list()
for i in range(S3HSV_imgA1C4_9.shape[0]): 
     for j in range(S3HSV_imgA1C4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_1409.append(S3HSV_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC4_109.append(S3HSV_imgA1C4_9[i][j])  
S3meanrefA1_1409 = np.array(S3meanrefA1_1409)
S3meanC4_109 = np.array(S3meanC4_109)

S3hsvrefA1_1409 = list()
S3hsvC4_109 = list()
for i in range(3):
    S3hsvrefA1_1409.append(S3meanrefA1_1409[:,i].mean())
    S3hsvC4_109.append(S3meanC4_109[:,i].mean())

# %%
S3meanrefA1_1509 = list()
S3meanD2_1v = list()
for i in range(S3HSV_imgA1D2_9.shape[0]): 
     for j in range(S3HSV_imgA1D2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1509.append(S3HSV_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_109.append(S3HSV_imgA1D2_9[i][j])  
S3meanrefA1_1509 = np.array(S3meanrefA1_1509)
S3meanD2_109 = np.array(S3meanD2_109)

S3hsvrefA1_1509 = list()
S3hsvD2_109 = list()
for i in range(3):
    S3hsvrefA1_1509.append(S3meanrefA1_1509[:,i].mean())
    S3hsvD2_109.append(S3meanD2_109[:,i].mean())

# %%
S3meanrefA1_1609 = list()
S3meanD3_109 = list()
for i in range(S3HSV_imgA1D3_9.shape[0]): 
     for j in range(S3HSV_imgA1D3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1609.append(S3HSV_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_109.append(S3HSV_imgA1D3_9[i][j])  
S3meanrefA1_1609 = np.array(S3meanrefA1_1609)
S3meanD3_109= np.array(S3meanD3_109)

S3hsvrefA1_1609 = list()
S3hsvD3_109 = list()
for i in range(3):
    S3hsvrefA1_1609.append(S3meanrefA1_1609[:,i].mean())
    S3hsvD3_109.append(S3meanD3_109[:,i].mean())

# %%
S3meanrefA1_1709= list()
S3meanD4_109 = list()
for i in range(S3HSV_imgA1D4_9.shape[0]): 
     for j in range(S3HSV_imgA1D4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1709.append(S3HSV_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_109.append(S3HSV_imgA1D4_9[i][j])  
S3meanrefA1_1709 = np.array(S3meanrefA1_1409)
S3meanD4_109 = np.array(S3meanD4_109)

S3hsvrefA1_17v = list()
S3hsvD4_109 = list()
for i in range(3):
    S3hsvrefA1_1709.append(S3meanrefA1_1709[:,i].mean())
    S3hsvD4_109.append(S3meanD4_109[:,i].mean())

# %% [markdown]
# ###Img 10

# %%
S3meanrefA1_110 = list()
S3meanA1_210 = list()
for i in range(S3HSV_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S3HSV_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_110.append(S3HSV_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA1_210.append(S3HSV_imgA1A1_10[i][j])  
S3meanrefA1_110 = np.array(S3meanrefA1_110)
S3meanA1_210 = np.array(S3meanA1_210)

S3hsvrefA1_110 = list()
S3hsvA1_210 = list()
for i in range(3):
    S3hsvrefA1_110.append(S3meanrefA1_110[:,i].mean())
    S3hsvA1_210.append(S3meanA1_210[:,i].mean())
S3hsvrefA1_110,S3hsvA1_210

# %%
S3meanrefA1_310 = list()
S3meanA2_110 = list()
for i in range(S3HSV_imgA1A2_10.shape[0]): 
     for j in range(S3HSV_imgA1A2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_310.append(S3HSV_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_110.append(S3HSV_imgA1A2_10[i][j])  
S3meanrefA1_310 = np.array(S3meanrefA1_310)
S3meanA2_110 = np.array(S3meanA2_110)

S3hsvrefA1_310 = list()
S3hsvA2_110 = list()
for i in range(3):
    S3hsvrefA1_310.append(S3meanrefA1_310[:,i].mean())
    S3hsvA2_110.append(S3meanA2_110[:,i].mean())

# %%
S3meanrefA1_410 = list()
S3meanA3_110 = list()
for i in range(S3HSV_imgA1A3_10.shape[0]): 
     for j in range(S3HSV_imgA1A3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_410.append(S3HSV_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_110.append(S3HSV_imgA1A3_10[i][j])  
S3meanrefA1_410 = np.array(S3meanrefA1_410)
S3meanA3_110 = np.array(S3meanA3_110)

S3hsvrefA1_410 = list()
S3hsvA3_110 = list()
for i in range(3):
    S3hsvrefA1_410.append(S3meanrefA1_410[:,i].mean())
    S3hsvA3_110.append(S3meanA3_110[:,i].mean())

# %%
S3meanrefA1_510 = list()
S3meanA3_5110 = list()
for i in range(S3HSV_imgA1A3_510.shape[0]): 
     for j in range(S3HSV_imgA1A3_510.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_510.append(S3HSV_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA3_5110.append(S3HSV_imgA1A3_510[i][j])  
S3meanrefA1_510 = np.array(S3meanrefA1_5v)
S3meanA3_5110 = np.array(S3meanA3_5110)

S3hsvrefA1_510 = list()
S3hsvA3_5110 = list()
for i in range(3):
    S3hsvrefA1_510.append(S3meanrefA1_510[:,i].mean())
    S3hsvA3_5110.append(S3meanA3_5110[:,i].mean())

# %%
S3meanrefA1_610 = list()
S3meanA4_110 = list()
for i in range(S3HSV_imgA1A4_10.shape[0]): 
     for j in range(S3HSV_imgA1A4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<S32131 :
                  S3meanrefA1_610.append(HSV_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA4_110.append(S3HSV_imgA1A4_10[i][j])  
S3meanrefA1_610 = np.array(S3meanrefA1_610)
vmeanA4_110 = np.array(S3meanA4_110)

S3hsvrefA1_610 = list()
S3hsvA4_110 = list()
for i in range(3):
    S3hsvrefA1_610.append(S3meanrefA1_610[:,i].mean())
    S3hsvA4_110.append(S3meanA4_110[:,i].mean())

# %%
S3meanrefA1_710 = list()
S3meanB1_110 = list()
for i in range(S3HSV_imgA1B1_10.shape[0]): 
     for j in range(S3HSV_imgA1B1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_710.append(S3HSV_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB1_110.append(S3HSV_imgA1B1_10[i][j])  
S3meanrefA1_710 = np.array(S3meanrefA1_710)
S3meanB1_110 = np.array(S3meanB1_110)

S3hsvrefA1_710 = list()
S3hsvB1_110 = list()
for i in range(3):
    S3hsvrefA1_710.append(S3meanrefA1_710[:,i].mean())
    S3hsvB1_110.append(S3meanB1_110[:,i].mean())

# %%
S3meanrefA1_810 = list()
S3meanB2_1v = list()
for i in range(S3HSV_imgA1B2_1010.shape[0]): 
     for j in range(S3HSV_imgA1B2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_810.append(S3HSV_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB2_110.append(S3HSV_imgA1B2_10[i][j])  
S3meanrefA1_810 = np.array(S3meanrefA1_810)
S3meanB2_110 = np.array(S3meanB2_110)

S3hsvrefA1_810 = list()
S3hsvB2_110 = list()
for i in range(3):
    S3hsvrefA1_810.append(S3meanrefA1_810[:,i].mean())
    S3hsvB2_110.append(S3meanB2_110[:,i].mean())

# %%
S3meanrefA1_910 = list()
S3meanB3_110 = list()
for i in range(S3HSV_imgA1B3_10.shape[0]): 
     for j in range(S3HSV_imgA1B3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S3meanrefA1_910.append(S3HSV_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB3_110.append(S3HSV_imgA1B3_10[i][j])  
S3meanrefA1_910 = np.array(S3meanrefA1_910)
S3meanB3_110 = np.array(S3meanB3_110)

S3hsvrefA1_910 = list()
S3hsvB3_110 = list()
for i in range(3):
    S3hsvrefA1_910.append(S3meanrefA1_910[:,i].mean())
    S3hsvB3_110.append(S3meanB3_110[:,i].mean())

# %%
S3meanrefA1_1010 = list()
S3meanB4_110 = list()
for i in range(S3HSV_imgA1B4_10.shape[0]): 
     for j in range(S3HSV_imgA1B4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1010.append(S3HSV_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanB4_110.append(S3HSV_imgA1B4_10[i][j])  
S3meanrefA1_1010 = np.array(S3meanrefA1_1010)
S3meanB4_110 = np.array(S3meanB4_110)

S3hsvrefA1_1010 = list()
S3hsvB4_110 = list()
for i in range(3):
    S3hsvrefA1_1010.append(S3meanrefA1_1010[:,i].mean())
    S3hsvB4_110.append(S3meanB4_110[:,i].mean())

# %%
S3meanrefA1_1110 = list()
S3meanC1_110 = list()
for i in range(S3HSV_imgA1C1_10.shape[0]): 
     for j in range(S3HSV_imgA1C1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1110.append(S3HSV_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC1_110.append(S3HSV_imgA1C1_10[i][j])  
S3meanrefA1_1110 = np.array(S3meanrefA1_1110)
S3meanC1_110 = np.array(S3meanC1_110)

S3hsvrefA1_1110 = list()
S3hsvC1_110 = list()
for i in range(3):
    S3hsvrefA1_1110.append(S3meanrefA1_1110[:,i].mean())
    S3hsvC1_110.append(S3meanC1_110[:,i].mean())

# %%
S3meanrefA1_1210 = list()
S3meanC2_110 = list()
for i in range(S3HSV_imgA1C2_10.shape[0]): 
     for j in range(S3HSV_imgA1C2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1210.append(S3HSV_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC2_110.append(S3HSV_imgA1C2_10[i][j])  
S3meanrefA1_1210 = np.array(S3meanrefA1_1210)
S3meanC2_110 = np.array(S3meanC2_110)

S3hsvrefA1_1210 = list()
S3hsvC2_1v = list()
for i in range(3):
    S3hsvrefA1_1210.append(S3meanrefA1_1210[:,i].mean())
    S3hsvC2_110.append(S3meanC2_110[:,i].mean())

# %%
S3meanrefA1_1310 = list()
S3meanC3_110 = list()
for i in range(S3HSV_imgA1C3_10.shape[0]): 
     for j in range(S3HSV_imgA1C3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1310.append(S3HSV_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanC3_110.append(S3HSV_imgA1C3_10[i][j])  
S3meanrefA1_1310 = np.array(S3meanrefA1_1310)
S3meanC3_110 = np.array(S3meanC3_110)

S3hsvrefA1_1310 = list()
S3hsvC3_110 = list()
for i in range(3):
    S3hsvrefA1_1310.append(S3meanrefA1_1310[:,i].mean())
    S3hsvC3_110.append(S3meanC3_110[:,i].mean())

# %%
S3meanrefA1_1410 = list()
S3meanC4_110 = list()
for i in range(S3HSV_imgA1C4_10.shape[0]): 
     for j in range(S3HSV_imgA1C4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1410.append(S3HSV_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  vmeanC4_110.append(S3HSV_imgA1C4_10[i][j])  
S3meanrefA1_1410 = np.array(S3meanrefA1_1410)
S3meanC4_110 = np.array(S3meanC4_110)

S3hsvrefA1_1410 = list()
S3hsvC4_110 = list()
for i in range(3):
    S3hsvrefA1_1410.append(S3meanrefA1_1410[:,i].mean())
    S3hsvC4_110.append(S3meanC4_110[:,i].mean())

# %%
S3meanrefA1_1510 = list()
S3meanD2_110 = list()
for i in range(S3HSV_imgA1D2_10.shape[0]): 
     for j in range(S3HSV_imgA1D2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1510.append(S3HSV_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD2_110.append(S3HSV_imgA1D2_10[i][j])  
S3meanrefA1_1510 = np.array(S3meanrefA1_1510)
S3meanD2_110 = np.array(S3meanD2_110)

S3hsvrefA1_1510 = list()
S3hsvD2_110 = list()
for i in range(3):
    S3hsvrefA1_15v.append(S3meanrefA1_1510[:,i].mean())
    S3hsvD2_110.append(S3meanD2_110[:,i].mean())

# %%
S3meanrefA1_1610 = list()
S3meanD3_110 = list()
for i in range(S3HSV_imgA1D3_10.shape[0]): 
     for j in range(S3HSV_imgA1D3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1610.append(S3HSV_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD3_110.append(S3HSV_imgA1D3_10[i][j])  
S3meanrefA1_1610 = np.array(S3meanrefA1_1610)
S3meanD3_110 = np.array(S3meanD3_110)

S3hsvrefA1_1610 = list()
S3hsvD3_110 = list()
for i in range(3):
    S3hsvrefA1_1610.append(S3meanrefA1_1610[:,i].mean())
    S3hsvD3_110.append(S3meanD3_110[:,i].mean())

# %%
S3meanrefA1_1710= list()
S3meanD4_110 = list()
for i in range(S3HSV_imgA1D4_10.shape[0]): 
     for j in range(S3HSV_imgA1D4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_1710.append(S3HSV_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanD4_110.append(S3HSV_imgA1D4_10[i][j])  
S3meanrefA1_1710= np.array(S3meanrefA1_1410)
S3meanD4_110 = np.array(S3meanD4_110)

S3hsvrefA1_1710 = list()
S3hsvD4_110 = list()
for i in range(3):
    S3hsvrefA1_1710.append(S3meanrefA1_1710[:,i].mean())
    S3hsvD4_110.append(S3meanD4_110[:,i].mean())

# %% [markdown]
# ##Set4

# %% [markdown]
# ###RGB

# %%
S4meanrefA1_1 = list()
S4meanA1_2 = list()
for i in range(S4RGB_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1.append(S4RGB_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_2.append(S4RGB_imgA1A1_1[i][j])  
S4meanrefA1_1 = np.array(S4meanrefA1_1)
S4meanA1_2 = np.array(S4meanA1_2)

S4rgbrefA1_1 = list()
S4rgbA1_2 = list()
for i in range(3):
    S4rgbrefA1_1.append(S4meanrefA1_1[:,i].mean())
    S4rgbA1_2.append(S4meanA1_2[:,i].mean())

# %%
S4meanrefA1_3 = list()
S4meanA2_1 = list()
for i in range(S4RGB_imgA1A2_1.shape[0]): 
     for j in range(S4RGB_imgA1A2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_3.append(S4RGB_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_1.append(S4RGB_imgA1A2_1[i][j])  
S4meanrefA1_3 = np.array(S4meanrefA1_3)
S4meanA2_1 = np.array(S4meanA2_1)

S4rgbrefA1_3 = list()
S4rgbA2_1 = list()
for i in range(3):
    S4rgbrefA1_3.append(S4meanrefA1_3[:,i].mean())
    S4rgbA2_1.append(S4meanA2_1[:,i].mean())

# %%
S4meanrefA1_4 = list()
S4meanA3_1 = list()
for i in range(S4RGB_imgA1A3_1.shape[0]): 
     for j in range(S4RGB_imgA1A3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_4.append(S4RGB_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_1.append(S4RGB_imgA1A3_1[i][j])  
S4meanrefA1_4 = np.array(S4meanrefA1_4)
S4meanA3_1 = np.array(S4meanA3_1)

S4rgbrefA1_4 = list()
S4rgbA3_1 = list()
for i in range(3):
    S4rgbrefA1_4.append(S4meanrefA1_4[:,i].mean())
    S4rgbA3_1.append(S4meanA3_1[:,i].mean())

# %%
S4meanrefA1_5 = list()
S4meanA3_51 = list()
for i in range(S4RGB_imgA1A3_51.shape[0]): 
     for j in range(S4RGB_imgA1A3_51.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_5.append(S4RGB_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_51.append(S4RGB_imgA1A3_51[i][j])  
S4meanrefA1_5 = np.array(S4meanrefA1_5)
S4meanA3_51 = np.array(S4meanA3_51)

S4rgbrefA1_5 = list()
S4rgbA3_51 = list()
for i in range(3):
    S4rgbrefA1_5.append(S4meanrefA1_5[:,i].mean())
    S4rgbA3_51.append(S4meanA3_51[:,i].mean())

# %%
S4meanrefA1_6 = list()
S4meanA4_1 = list()
for i in range(S4RGB_imgA1A4_1.shape[0]): 
     for j in range(S4RGB_imgA1A4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_6.append(S4RGB_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_1.append(S4RGB_imgA1A4_1[i][j])  
S4meanrefA1_6 = np.array(S4meanrefA1_6)
S4meanA4_1 = np.array(S4meanA4_1)

S4rgbrefA1_6 = list()
S4rgbA4_1 = list()
for i in range(3):
    S4rgbrefA1_6.append(S4meanrefA1_6[:,i].mean())
    S4rgbA4_1.append(S4meanA4_1[:,i].mean())

# %%
S4meanrefA1_7 = list()
S4meanB1_1 = list()
for i in range(S4RGB_imgA1B1_1.shape[0]): 
     for j in range(S4RGB_imgA1B1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_7.append(S4RGB_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_1.append(S4RGB_imgA1B1_1[i][j])  
S4meanrefA1_7 = np.array(S4meanrefA1_7)
S4meanB1_1 = np.array(S4meanB1_1)

S4rgbrefA1_7 = list()
S4rgbB1_1 = list()
for i in range(3):
    S4rgbrefA1_7.append(S4meanrefA1_7[:,i].mean())
    S4rgbB1_1.append(S4meanB1_1[:,i].mean())

# %%
S4meanrefA1_8 = list()
S4meanB2_1 = list()
for i in range(S4RGB_imgA1B2_1.shape[0]): 
     for j in range(S4RGB_imgA1B2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_8.append(S4RGB_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_1.append(S4RGB_imgA1B2_1[i][j])  
S4meanrefA1_8 = np.array(S4meanrefA1_8)
S4meanB2_1 = np.array(S4meanB2_1)

S4rgbrefA1_8 = list()
S4rgbB2_1 = list()
for i in range(3):
    S4rgbrefA1_8.append(S4meanrefA1_8[:,i].mean())
    S4rgbB2_1.append(S4meanB2_1[:,i].mean())

# %%
S4meanrefA1_9 = list()
S4meanB3_1 = list()
for i in range(S4RGB_imgA1B3_1.shape[0]): 
     for j in range(S4RGB_imgA1B3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_9.append(S4RGB_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_1.append(S4RGB_imgA1B3_1[i][j])  
S4meanrefA1_9 = np.array(S4meanrefA1_9)
S4meanB3_1 = np.array(S4meanB3_1)

S4rgbrefA1_9 = list()
S4rgbB3_1 = list()
for i in range(3):
    S4rgbrefA1_9.append(S4meanrefA1_9[:,i].mean())
    S4rgbB3_1.append(S4meanB3_1[:,i].mean())

# %%
S4meanrefA1_10 = list()
S4meanB4_1 = list()
for i in range(S4RGB_imgA1B4_1.shape[0]): 
     for j in range(S4RGB_imgA1B4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_10.append(S4RGB_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_1.append(S4RGB_imgA1B4_1[i][j])  
S4meanrefA1_10 = np.array(S4meanrefA1_10)
S4meanB4_1 = np.array(S4meanB4_1)

S4rgbrefA1_10 = list()
S4rgbB4_1 = list()
for i in range(3):
    S4rgbrefA1_10.append(S4meanrefA1_10[:,i].mean())
    S4rgbB4_1.append(S4meanB4_1[:,i].mean())

# %%
S4meanrefA1_11 = list()
S4meanC1_1 = list()
for i in range(S4RGB_imgA1C1_1.shape[0]): 
     for j in range(S4RGB_imgA1C1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_11.append(S4RGB_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_1.append(S4RGB_imgA1C1_1[i][j])  
S4meanrefA1_11 = np.array(S4meanrefA1_11)
S4meanC1_1 = np.array(S4meanC1_1)

S4rgbrefA1_11 = list()
S4rgbC1_1 = list()
for i in range(3):
    S4rgbrefA1_11.append(S4meanrefA1_11[:,i].mean())
    S4rgbC1_1.append(S4meanC1_1[:,i].mean())

# %%
S4meanrefA1_12 = list()
S4meanC2_1 = list()
for i in range(S4RGB_imgA1C2_1.shape[0]): 
     for j in range(S4RGB_imgA1C2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_12.append(S4RGB_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_1.append(S4RGB_imgA1C2_1[i][j])  
S4meanrefA1_12 = np.array(S4meanrefA1_12)
S4meanC2_1 = np.array(S4meanC2_1)

S4rgbrefA1_12 = list()
S4rgbC2_1 = list()
for i in range(3):
    S4rgbrefA1_12.append(S4meanrefA1_12[:,i].mean())
    S4rgbC2_1.append(S4meanC2_1[:,i].mean())

# %%
S4meanrefA1_13 = list()
S4meanC3_1 = list()
for i in range(S4RGB_imgA1C3_1.shape[0]): 
     for j in range(S4RGB_imgA1C3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_13.append(S4RGB_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_1.append(S4RGB_imgA1C3_1[i][j])  
S4meanrefA1_13 = np.array(S4meanrefA1_13)
S4meanC3_1 = np.array(S4meanC3_1)

S4rgbrefA1_13 = list()
S4rgbC3_1 = list()
for i in range(3):
    S4rgbrefA1_13.append(S4meanrefA1_13[:,i].mean())
    S4rgbC3_1.append(S4meanC3_1[:,i].mean())

# %%
S4meanrefA1_14 = list()
S4meanC4_1 = list()
for i in range(S4RGB_imgA1C4_1.shape[0]): 
     for j in range(S4RGB_imgA1C4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_14.append(S4RGB_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_1.append(S4RGB_imgA1C4_1[i][j])  
S4meanrefA1_14 = np.array(S4meanrefA1_14)
S4meanC4_1 = np.array(S4meanC4_1)

S4rgbrefA1_14 = list()
S4rgbC4_1 = list()
for i in range(3):
    S4rgbrefA1_14.append(S4meanrefA1_14[:,i].mean())
    S4rgbC4_1.append(S4meanC4_1[:,i].mean())

# %%
S4meanrefA1_15 = list()
S4meanD2_1 = list()
for i in range(S4RGB_imgA1D2_1.shape[0]): 
     for j in range(S4RGB_imgA1D2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_15.append(S4RGB_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_1.append(S4RGB_imgA1D2_1[i][j])  
S4meanrefA1_15 = np.array(S4meanrefA1_15)
S4meanD2_1 = np.array(S4meanD2_1)

S4rgbrefA1_15 = list()
S4rgbD2_1 = list()
for i in range(3):
    S4rgbrefA1_15.append(S4meanrefA1_15[:,i].mean())
    S4rgbD2_1.append(S4meanD2_1[:,i].mean())

# %%
S4meanrefA1_16 = list()
S4meanD3_1 = list()
for i in range(S4RGB_imgA1D3_1.shape[0]): 
     for j in range(S4RGB_imgA1D3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_16.append(S4RGB_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_1.append(S4RGB_imgA1D3_1[i][j])  
S4meanrefA1_16 = np.array(S4meanrefA1_16)
S4meanD3_1 = np.array(S4meanD3_1)

S4rgbrefA1_16 = list()
S4rgbD3_1 = list()
for i in range(3):
    S4rgbrefA1_16.append(S4meanrefA1_16[:,i].mean())
    S4rgbD3_1.append(S4meanD3_1[:,i].mean())

# %%
S4meanrefA1_17= list()
S4meanD4_1 = list()
for i in range(S4RGB_imgA1D4_1.shape[0]): 
     for j in range(S4RGB_imgA1D4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_17.append(S4RGB_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_1.append(S4RGB_imgA1D4_1[i][j])  
S4meanrefA1_17 = np.array(S4meanrefA1_14)
S4meanD4_1 = np.array(S4meanD4_1)

S4rgbrefA1_17 = list()
S4rgbD4_1 = list()
for i in range(3):
    S4rgbrefA1_17.append(S4meanrefA1_17[:,i].mean())
    S4rgbD4_1.append(S4meanD4_1[:,i].mean())

# %% [markdown]
# ###Img 2

# %%
S4meanrefA1_102 = list()
S4meanA1_202 = list()
for i in range(S4RGB_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_102.append(S4RGB_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_202.append(S4RGB_imgA1A1_2[i][j])  
S4meanrefA1_102 = np.array(S4meanrefA1_102)
S4meanA1_202 = np.array(S4meanA1_202)

S4rgbrefA1_102 = list()
S4rgbA1_202 = list()
for i in range(3):
    S4rgbrefA1_102.append(S4meanrefA1_102[:,i].mean())
    S4rgbA1_202.append(S4meanA1_202[:,i].mean())
S4rgbrefA1_102,S4rgbA1_202

# %%
S4meanrefA1_302 = list()
S4meanA2_102 = list()
for i in range(S4RGB_imgA1A2_2.shape[0]): 
     for j in range(S4RGB_imgA1A2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_302.append(S4RGB_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanA2_102.append(S4RGB_imgA1A2_2[i][j])  
S4meanrefA1_302 = np.array(S4meanrefA1_302)
S4meanA2_102 = np.array(S4meanA2_102)

S4rgbrefA1_302 = list()
S4rgbA2_102 = list()
for i in range(3):
    S4rgbrefA1_302.append(S4meanrefA1_302[:,i].mean())
    S4rgbA2_102.append(S4meanA2_102[:,i].mean())

# %%
S4meanrefA1_402 = list()
S4meanA3_102 = list()
for i in range(S4RGB_imgA1A3_2.shape[0]): 
     for j in range(S4RGB_imgA1A3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_402.append(S4RGB_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_102.append(S4RGB_imgA1A3_2[i][j])  
S4meanrefA1_402 = np.array(S4meanrefA1_402)
S4meanA3_102 = np.array(S4meanA3_102)

S4rgbrefA1_402 = list()
S4rgbA3_102 = list()
for i in range(3):
    S4rgbrefA1_402.append(S4meanrefA1_402[:,i].mean())
    S4rgbA3_102.append(S4meanA3_102[:,i].mean())

# %%
S4meanrefA1_02 = list()
S4meanA3_5102 = list()
for i in range(S4RGB_imgA1A3_52.shape[0]): 
     for j in range(S4RGB_imgA1A3_52.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_502.append(S4RGB_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4S3meanA3_5102.append(S4RGB_imgA1A3_52[i][j])  
S4meanrefA1_502 = np.array(S4meanrefA1_502)
S4meanA3_5102 = np.array(S4meanA3_5102)

S4gbrefA1_502 = list()
S4gbA3_5102 = list()
for i in range(3):
    S4rgbrefA1_502.append(S4meanrefA1_502[:,i].mean())
    S4rgbA3_5102.append(S4meanA3_5102[:,i].mean())

# %%
S4meanrefA1_602 = list()
S4meanA4_102 = list()
for i in range(S4RGB_imgA1A4_2.shape[0]): 
     for j in range(S3RGB_imgA1A4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4rmeanrefA1_602.append(S4RGB_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_102.append(อRGB_imgA1A4_2[i][j])  
S4meanrefA1_602 = np.array(S4meanrefA1_602)
S4meanA4_102 = np.array(S4meanA4_102)

S4rgbrefA1_602 = list()
S4rgbA4_102 = list()
for i in range(3):
   S4rgbrefA1_602.append(S4meanrefA1_602[:,i].mean())
   S4rgbA4_102.append(S4meanA4_102[:,i].mean())

# %%
S4meanrefA1_702 = list()
S4meanB1_102 = list()
for i in range(S4RGB_imgA1B1_202.shape[0]): 
     for j in range(S4RGB_imgA1B1_202.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_702.append(S4RGB_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_102.append(S4RGB_imgA1B1_2[i][j])  
S4meanrefA1_702 = np.array(S4meanrefA1_702)
S4meanB1_102 = np.array(S4meanB1_102)

S4rgbrefA1_7 02= list()
S4rgbB1_102 = list()
for i in range(3):
   S4rgbrefA1_702.append(S4meanrefA1_702[:,i].mean())
   S4rgbB1_102.append(S4meanB1_102[:,i].mean())

# %%
S4meanrefA1_802 = list()
S4meanB2_102 = list()
for i in range(S4RGB_imgA1B2_2.shape[0]): 
     for j in range(S4RGB_imgA1B2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_802.append(S4RGB_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanB2_102.append(S4RGB_imgA1B2_2[i][j])  
S4meanrefA1_802 = np.array(S4meanrefA1_802)
S4meanB2_102 = np.array(S4meanB2_102)

S4gbrefA1_802 = list()
S4rgbB2_102 = list()
for i in range(3):
    S4rgbrefA1_802.append(S4meanrefA1_802[:,i].mean())
    S4rgbB2_102.append(S4meanB2_102[:,i].mean())

# %%
S4meanrefA1_902 = list()
S4meanB3_102 = list()
for i in range(S4RGB_imgA1B3_2.shape[0]): 
     for j in range(S4RGB_imgA1B3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_902.append(S4RGB_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S3meanB3_102.append(S4RGB_imgA1B3_2[i][j])  
S4meanrefA1_902 = np.array(S4meanrefA1_902)
S4meanB3_102 = np.array(S4meanB3_102)

S4rgbrefA1_902 = list()
S4rgbB3_102 = list()
for i in range(3):
    S4rgbrefA1_902.append(S4meanrefA1_902[:,i].mean())
    S4rgbB3_102.append(S4meanB3_102[:,i].mean())

# %%
S4meanrefA1_1002 = list()
S4meanB4_102 = list()
for i in range(S4RGB_imgA1B4_2.shape[0]): 
     for j in range(S4RGB_imgA1B4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1002.append(S4RGB_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_102.append(S4RGB_imgA1B4_2[i][j])  
S4meanrefA1_1002 = np.array(S4meanrefA1_1002)
S4meanB4_102 = np.array(S4meanB4_102)

S4rgbrefA1_1002 = list()
S4rgbB4_102 = list()
for i in range(3):
    S4rgbrefA1_1002.append(S4meanrefA1_1002[:,i].mean())
    S4rgbB4_102.append(S4meanB4_102[:,i].mean())

# %%
S4meanrefA1_1102 = list()
S4meanC1_102 = list()
for i in range(S4RGB_imgA1C1_2.shape[0]): 
     for j in range(S4RGB_imgA1C1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1102.append(S4RGB_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_102.append(S4RGB_imgA1C1_2[i][j])  
S4meanrefA1_1102 = np.array(S4meanrefA1_1102)
S4meanC1_102 = np.array(S4meanC1_102)

S4rgbrefA1_1102 = list()
S4rgbC1_102 = list()
for i in range(3):
   S4rgbrefA1_1102.append(S4meanrefA1_1102[:,i].mean())
   S4rgbC1_102.append(S4meanC1_102[:,i].mean())

# %%
S4meanrefA1_1202 = list()
S4meanC2_102 = list()
for i in range(S4RGB_imgA1C2_2.shape[0]): 
     for j in range(S4RGB_imgA1C2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1202.append(S4RGB_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_102.append(S4RGB_imgA1C2_2[i][j])  
S4meanrefA1_1202 = np.array(S4meanrefA1_1202)
S4meanC2_102 = np.array(S4meanC2_102)

S4rgbrefA1_1202 = list()
S4rgbC2_102 = list()
for i in range(3):
    S4rgbrefA1_1202.append(S4meanrefA1_1202[:,i].mean())
    S4rgbC2_102.append(S4meanC2_102[:,i].mean())

# %%
S4meanrefA1_1302 = list()
S4meanC3_102 = list()
for i in range(S4RGB_imgA1C3_2.shape[0]): 
     for j in range(S4RGB_imgA1C3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1302.append(S4RGB_imgA1C3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanC3_102.append(S4RGB_imgA1C3_2[i][j])  
S4meanrefA1_1302 = np.array(S4meanrefA1_1302)
S4meanC3_102 = np.array(S4meanC3_102)

S4rgbrefA1_1302 = list()
S4rgbC3_102 = list()
for i in range(3):
    S4rgbrefA1_1302.append(S4meanrefA1_1302[:,i].mean())
    S4rgbC3_102.append(S4meanC3_102[:,i].mean())

# %%
S4meanrefA1_1402 = list()
S4meanC4_102 = list()
for i in range(S4RGB_imgA1C4_2.shape[0]): 
     for j in range(S4RGB_imgA1C4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1402.append(S4RGB_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_102.append(S4RGB_imgA1C4_2[i][j])  
S4meanrefA1_1402 = np.array(S4meanrefA1_1402)
S4meanC4_102 = np.array(S4meanC4_102)

S4rgbrefA1_1402 = list()
S4rgbC4_102 = list()
for i in range(3):
     S4rgbrefA1_1402.append(S4meanrefA1_1402[:,i].mean())
     S4rgbC4_102.append(S4meanC4_102[:,i].mean())

# %%
S4meanrefA1_1502 = list()
S4meanD2_102 = list()
for i in range(S4RGB_imgA1D2_2.shape[0]): 
     for j in range(S4RGB_imgA1D2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1502.append(S4RGB_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_102.append(S4RGB_imgA1D2_2[i][j])  
S4meanrefA1_1502 = np.array(S4meanrefA1_1502)
S4meanD2_102 = np.array(S4meanD2_102)

S4rgbrefA1_1502 = list()
S4rgbD2_102 = list()
for i in range(3):
    S4rgbrefA1_1502.append(S4meanrefA1_1502[:,i].mean())
    S4rgbD2_102.append(S4meanD2_102[:,i].mean())

# %%
S4meanrefA1_1602 = list()
S4meanD3_102 = list()
for i in range(S4RGB_imgA1D3_2.shape[0]): 
     for j in range(S4RGB_imgA1D3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1602.append(S4RGB_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanD3_102.append(S4RGB_imgA1D3_2[i][j])  
S4meanrefA1_1602 = np.array(S4meanrefA1_1602)
S4meanD3_102 = np.array(S4meanD3_102

S4rgbrefA1_1602 = list()
S4rgbD3_102 = list()
for i in range(3):
    S4rgbrefA1_1602.append(S4meanrefA1_1602[:,i].mean())
    S4rgbD3_102.append(S4meanD3_102[:,i].mean())

# %%
S4meanrefA1_1702= list()
S4meanD4_102 = list()
for i in range(S4RGB_imgA1D4_2.shape[0]): 
     for j in range(S4RGB_imgA1D4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_1702.append(S4RGB_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanD4_102.append(S4RGB_imgA1D4_2[i][j])  
S4meanrefA1_1702 = np.array(S4meanrefA1_1402)
S4meanD4_102 = np.array(S4meanD4_102)

S4rgbrefA1_1702 = list()
S4rgbD4_102 = list()
for i in range(3):
   S4rgbrefA1_1702.append(S4meanrefA1_1702[:,i].mean())
   S4rgbD4_102.append(S4meanD4_102[:,i].mean())

# %% [markdown]
# ###Img 3

# %%
S4meanrefA1_103 = list()
S4meanA1_203 = list()
for i in range(S4RGB_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1.append(S4RGB_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_2.append(S4RGB_imgA1A1_3[i][j])  
S4meanrefA1_103 = np.array(S4meanrefA1_103)
S4meanA1_203 = np.array(S4meanA1_203)

S4rgbrefA1_103 = list()
S4rgbA1_203 = list()
for i in range(3):
    S4rgbrefA1_103.append(S4meanrefA1_103[:,i].mean())
    S4rgbA1_203.append(S4meanA1_203[:,i].mean())
S4rgbrefA1_103,S3rgbA1_2 03

# %%
S4meanrefA1_303 = list()
S4meanA2_103 = list()
for i in range(S4RGB_imgA1A2_3.shape[0]): 
     for j in range(S4RGB_imgA1A2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_303.append(S4RGB_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_103.append(S4RGB_imgA1A2_3[i][j])  
S4meanrefA1_303 = np.array(S4meanrefA1_303)
S4meanA2_103 = np.array(S4meanA2_103)

S4rgbrefA1_303 = list()
S4rgbA2_103 = list()
for i in range(3):
    S4rgbrefA1_303.append(S4meanrefA1_303[:,i].mean())
    S4rgbA2_103.append(S4meanA2_103[:,i].mean())

# %%
S4meanrefA1_403 = list()
S4meanA3_103 = list()
for i in range(S4RGB_imgA1A3_3.shape[0]): 
     for j in range(S4RGB_imgA1A3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_403.append(S4RGB_imgA1A33_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_103.append(S4RGB_imgA1A3_3[i][j])  
S4meanrefA1_403= np.array(S4meanrefA1_403 )
S4meanA3_103 = np.array(S4meanA3_103 )

S4gbrefA1_403  = list()
S4rgbA3_103  = list()
for i in range(3):
    S4rgbrefA1_403 .append(S4meanrefA1_403[:,i].mean())
    S4rgbA3_103 .append(S4meanA3_103 [:,i].mean())

# %%
S4meanrefA1_503  = list()
S4meanA3_5103  = list()
for i in range(S4RGB_imgA1A3_53.shape[0]): 
     for j in range(S4RGB_imgA1A3_53.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_503 .append(S4RGB_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5103 .append(S4RGB_imgA1A3_53[i][j])  
S4meanrefA1_503  = np.array(S4meanrefA1_503 )
S4meanA3_5103  = np.array(S4meanA3_5103 )

S4rgbrefA1_503  = list()
S4rgbA3_5103  = list()
for i in range(3):
    S4rgbrefA1_503 .append(S4meanrefA1_503 [:,i].mean())
    S4rgbA3_5103 .append(S4meanA3_5103 [:,i].mean())

# %%
S4meanrefA1_603  = list()
S4meanA4_103  = list()
for i in range(S4RGB_imgA1A4_3.shape[0]): 
     for j in range(S4RGB_imgA1A4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_603 .append(S4RGB_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_103 .append(S4RGB_imgA1A4_3[i][j])  
S4meanrefA1_603  = np.array(S4meanrefA1_603 )
S4meanA4_103  = np.array(S4meanA4_103 )

S4rgbrefA1_603  = list()
S4rgbA4_103  = list()
for i in range(3):
    S4rgbrefA1_603 .append(S4meanrefA1_603[:,i].mean())
    S4rgbA4_103 .append(S4meanA4_103 [:,i].mean())

# %%
S4meanrefA1_703  = list()
S4meanB1_103  = list()
for i in range(S4RGB_imgA1B1_3.shape[0]): 
     for j in range(S4RGB_imgA1B1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_703.append(S4RGB_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_103.append(S4RGB_imgA1B1_3[i][j])  
S4meanrefA1_703  = np.array(S4meanrefA1_73)
S4meanB1_103  = np.array(S4meanB1_103)

S4rgbrefA1_703  = list()
S4rgbB1_103  = list()
for i in range(3):
    S4rgbrefA1_703 .append(S4meanrefA1_703 [:,i].mean())
    S4rgbB1_103 .append(S4meanB1_103 [:,i].mean())

# %%
S4meanrefA1_803  = list()
S4meanB2_103  = list()
for i in range(S4RGB_imgA1B2_3.shape[0]): 
     for j in range(S4RGB_imgA1B2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_803 .append(S4RGB_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_103 .append(S4RGB_imgA1B2_3[i][j])  
S4meanrefA1_803  = np.array(S4meanrefA1_803 )
S4meanB2_103  = np.array(S4meanB2_103 )

S4rgbrefA1_803  = list()
S4rgbB2_103  = list()
for i in range(3):
    S4rgbrefA1_803 .append(S4meanrefA1_803 [:,i].mean())
    S4rgbB2_103 .append(S4meanB2_103 [:,i].mean())

# %%
S4meanrefA1_903  = list()
S4meanB3_103  = list()
for i in range(S4RGB_imgA1B3_3.shape[0]): 
     for j in range(S4RGB_imgA1B3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_903 .append(S4RGB_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_103 .append(S4RGB_imgA1B3_3[i][j])  
S4meanrefA1_903  = np.array(S4meanrefA1_903 )
S4meanB3_103  = np.array(S4meanB3_103 )

S4rgbrefA1_903  = list()
S4rgbB3_103  = list()
for i in range(3):
    S4rgbrefA1_903 .append(S4meanrefA1_903 [:,i].mean())
    S4rgbB3_103 .append(S4meanB3_103 [:,i].mean())

# %%
S4meanrefA1_1003  = list()
S4meanB4_103  = list()
for i in range(S4RGB_imgA1B4_3.shape[0]): 
     for j in range(S4RGB_imgA1B4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1003 .append(S4RGB_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_103 .append(S4RGB_imgA1B4_3[i][j])  
S4meanrefA1_1003  = np.array(S4meanrefA1_1003 )
S4meanB4_103  = np.array(S4meanB4_103 )

S4rgbrefA1_1003  = list()
S4gbB4_103  = list()
for i in range(3):
    S4gbrefA1_1003 .append(S4meanrefA1_1003[:,i].mean())
    S4rgbB4_103 .append(S4meanB4_103 [:,i].mean())

# %%
S4meanrefA1_1103  = list()
S4meanC1_103  = list()
for i in range(S4RGB_imgA1C1_3.shape[0]): 
     for j in range(S4RGB_imgA1C1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1103 .append(S4RGB_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_103 .append(S4RGB_imgA1C1_3[i][j])  
S4meanrefA1_1103  = np.array(S4meanrefA1_1103 )
S4meanC1_103  = np.array(S4meanC1_103 )

S4rgbrefA1_1103  = list()
S4rgbC1_103  = list()
for i in range(3):
    S4rgbrefA1_1103.append(S4meanrefA1_1103 [:,i].mean())
    S4rgbC1_103.append(S4meanC1_103 [:,i].mean())

# %%
S4meanrefA1_1203  = list()
S4meanC2_103 = list()
for i in range(S4RGB_imgA1C2_3.shape[0]): 
     for j in range(S4RGB_imgA1C2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1203.append(S4RGB_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_103.append(S4RGB_imgA1C2_3[i][j])  
S4meanrefA1_1203 = np.array(S4meanrefA1_1203)
S4meanC2_103 = np.array(S4meanC2_103)

S4gbrefA1_1203 = list()
S4rgbC2_103 = list()
for i in range(3):
    S4rgbrefA1_1203.append(S4meanrefA1_1203[:,i].mean())
    S4rgbC2_103.append(S4meanC2_103[:,i].mean())

# %%
S4meanrefA1_1303 = list()
S4meanC3_103 = list()
for i in range(S4RGB_imgA1C3_3.shape[0]): 
     for j in range(S4RGB_imgA1C3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1303.append(S4RGB_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_103append(S4RGB_imgA1C3_3i][j])  
S4meanrefA1_1303 = np.array(S4meanrefA1_1303)
S4meanC3_103 = np.array(S4meanC3_103)

S4rgbrefA1_1303 = list()
S4rgbC3_103 = list()
for i in range(3):
    S4rgbrefA1_1303.append(S4meanrefA1_1303[:,i].mean())
    S4rgbC3_103.append(S4meanC3_103[:,i].mean())

# %%
S4meanrefA1_1403 = list()
S4meanC4_103 = list()
for i in range(S4RGB_imgA1C4_3.shape[0]): 
     for j in range(S4RGB_imgA1C4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_1403.append(S4RGB_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_103.append(S4RGB_imgA1C4_3[i][j])  
S4meanrefA1_1403 = np.array(S4meanrefA1_1403)
S4meanC4_103 = np.array(S4meanC4_103)

S4gbrefA1_1403 = list()
S4rgbC4_103 = list()
for i in range(3):
    S4rgbrefA1_1403.append(S4meanrefA1_1403[:,i].mean())
    S4rgbC4_103.append(S4meanC4_103[:,i].mean())

# %%
S4meanrefA1_1503 = list()
S4meanD2_103 = list()
for i in range(S4RGB_imgA1D2_3.shape[0]): 
     for j in range(S4RGB_imgA1D2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1503.append(S4RGB_imgA1D2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_103.append(S4RGB_imgA1D2_3[i][j])  
S4meanrefA1_1503 = np.array(S4meanrefA1_1503)
S4meanD2_103 = np.array(S4meanD2_103)

S4rgbrefA1_1503 = list()
S4gbD2_103 = list()
for i in range(3):
    S4rgbrefA1_1503.append(S4meanrefA1_1503[:,i].mean())
    S4rgbD2_103.append(S4meanD2_103[:,i].mean())

# %%
S4meanrefA1_1603 = list()
S4meanD3_103 = list()
for i in range(S4RGB_imgA1D3_3.shape[0]): 
     for j in range(S4RGB_imgA1D3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1603.append(S4RGB_imgA1D33_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_103.append(S4RGB_imgA1D3_3[i][j])  
S4meanrefA1_1603 = np.array(S4meanrefA1_1603)
S4meanD3_103 = np.array(S4meanD3_103)

S4gbrefA1_1603 = list()
S4gbD3_103 = list()
for i in range(3):
    S4rgbrefA1_1603.append(S4meanrefA1_1603[:,i].mean())
    S4rgbD3_103.append(S4meanD3_103[:,i].mean())

# %%
S4meanrefA1_1703= list()
S4meanD4_103 = list()
for i in range(S4RGB_imgA1D4_3.shape[0]): 
     for j in range(S4RGB_imgA1D4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1703.append(S4RGB_imgA1D4_3i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_103.append(S4RGB_imgA1D4_3[i][j])  
S4meanrefA1_1703 = np.array(S4meanrefA1_1403)
S4meanD4_103 = np.array(S4meanD4_103)

S4rgbrefA1_1703 = list()
S4rgbD4_103 = list()
for i in range(3):
    S4rgbrefA1_1703.append(S4meanrefA1_1703[:,i].mean())
    S4rgbD4_103.append(S4meanD4_103[:,i].mean())

# %% [markdown]
# ###Img 4

# %%
S4meanrefA1_104 = list()
S4meanA1_204 = list()
for i in range(S4RGB_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_104.append(S4RGB_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  อmeanA1_204.append(S4RGB_imgA1A1_4[i][j])  
S4meanrefA1_104 = np.array(S4meanrefA1_104)
S4meanA1_204 = np.array(S4meanA1_204)

S4rgbrefA1_104 = list()
S4rgbA1_204 = list()
for i in range(3):
    S4rgbrefA1_104.append(S4meanrefA1_104[:,i].mean())
    S4rgbA1_204.append(S4meanA1_204[:,i].mean())
S4rgbrefA1_104,S4rgbA1_204

# %%
S4meanrefA1_304 = list()
S4meanA2_104 = list()
for i in range(S4RGB_imgA1A2_4.shape[0]): 
     for j in range(S4RGB_imgA1A2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_304.append(S4RGB_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_104.append(S4RGB_imgA1A2_4[i][j])  
S4meanrefA1_304 = np.array(S4meanrefA1_304)
S4meanA2_104 = np.array(S4meanA2_104)

S4rgbrefA1_304 = list()
S4rgbA2_104 = list()
for i in range(3):
    S4rgbrefA1_304.append(S4meanrefA1_304[:,i].mean())
    S4rgbA2_104.append(S4meanA2_104[:,i].mean())

# %%
S4meanrefA1_404 = list()
S4meanA3_104 = list()
for i in range(S4RGB_imgA1A3_4.shape[0]): 
     for j in range(S4RGB_imgA1A3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_404.append(S4RGB_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_104.append(S4RGB_imgA1A3_4[i][j])  
S4meanrefA1_404 = np.array(S4meanrefA1_404)
S4meanA3_104 = np.array(S4meanA3_104)

S4rgbrefA1_404 = list()
S4rgbA3_104 = list()
for i in range(3):
    S4rgbrefA1_404.append(S4meanrefA1_404[:,i].mean())
    S4rgbA3_104.append(S4meanA3_104[:,i].mean())

# %%
S4meanrefA1_504 = list()
S4meanA3_5104 = list()
for i in range(S4RGB_imgA1A3_54.shape[0]): 
     for j in range(S4RGB_imgA1A3_54.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_504.append(S4RGB_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5104.append(S4RGB_imgA1A3_54[i][j])  
S4meanrefA1_504 = np.array(S4meanrefA1_5104)
S4meanA3_5104 = np.array(S4meanA3_5104)

S4rgbrefA1_504 = list()
S4rgbA3_5104 = list()
for i in range(3):
    S4rgbrefA1_504.append(S4meanrefA1_504[:,i].mean())
    S4rgbA3_5104.append(S4meanA3_5104[:,i].mean())

# %%
S4meanrefA1_604 = list()
S4meanA4_104 = list()
for i in range(S4RGB_imgA1A4_4.shape[0]): 
     for j in range(S4RGB_imgA1A4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_604.append(S4RGB_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  vmeanA4_104.append(S4RGB_imgA1A4_4[i][j])  
S4meanrefA1_604 = np.array(S4meanrefA1_604)
S4meanA4_104 = np.array(S4meanA4_104)

S4rgbrefA1_604 = list()
S4rgbA4_104 = list()
for i in range(3):
    S4rgbrefA1_604.append(S4meanrefA1_604[:,i].mean())
    S4rgbA4_104.append(S4meanA4_104[:,i].mean())

# %%
S4meanrefA1_704 = list()
S4meanB1_104 = list()
for i in range(S4RGB_imgA1B1_4.shape[0]): 
     for j in range(vRGB_imgA1B1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_704.append(S4RGB_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_104.append(S4RGB_imgA1B1_4[i][j])  
S4meanrefA1_704 = np.array(S4meanrefA1_704)
S4meanB1_104 = np.array(S4meanB1_104)

S4rgbrefA1_704 = list()
S4rgbB1_104 = list()
for i in range(3):
    S4rgbrefA1_704.append(S4meanrefA1_704[:,i].mean())
    S4rgbB1_104.append(S4meanB1_104[:,i].mean())

# %%
S4meanrefA1_804 = list()
S4meanB2_104 = list()
for i in range(S4RGB_imgA1B2_4.shape[0]): 
     for j in range(S4RGB_imgA1B2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_804.append(S4RGB_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_104.append(S4RGB_imgA1B2_4[i][j])  
S4meanrefA1_804 = np.array(S4meanrefA1_804)
S4meanB2_104 = np.array(S4meanB2_104)

S4rgbrefA1_804 = list()
S4rgbB2_104 = list()
for i in range(3):
    S4rgbrefA1_804.append(S4meanrefA1_804[:,i].mean())
    S4rgbB2_104.append(S4meanB2_104[:,i].mean())

# %%
S4meanrefA1_904 = list()
S4meanB3_104 = list()
for i in range(S4RGB_imgA1B3_4.shape[0]): 
     for j in range(S4RGB_imgA1B3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_904.append(S4RGB_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_104.append(S4RGB_imgA1B3_4[i][j])  
S4meanrefA1_904 = np.array(S4meanrefA1_904)
S4meanB3_104 = np.array(S4meanB3_104)

S4rgbrefA1_904 = list()
S4rgbB3_104 = list()
for i in range(3):
    S3rgbrefA1_904.append(S3meanrefA1_904[:,i].mean())
    S3rgbB3_104.append(S3meanB3_104[:,i].mean())

# %%
S4meanrefA1_1004 = list()
S4meanB4_104 = list()
for i in range(S4RGB_imgA1B4_4.shape[0]): 
     for j in range(S4RGB_imgA1B4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1004.append(S4RGB_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_104.append(S4RGB_imgA1B4_4[i][j])  
S4meanrefA1_1004 = np.array(S4meanrefA1_1004)
S4meanB4_104 = np.array(S4meanB4_104)

S4rgbrefA1_1004 = list()
S4rgbB4_104 = list()
for i in range(3):
    S4rgbrefA1_1004.append(S4meanrefA1_1004[:,i].mean())
    S4rgbB4_104.append(S4meanB4_104[:,i].mean())

# %%
S4meanrefA1_1104 = list()
S4meanC1_104 = list()
for i in range(S4RGB_imgA1C1_4.shape[0]): 
     for j in range(S4RGB_imgA1C1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1104.append(S4RGB_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_104.append(S4RGB_imgA1C1_4[i][j])  
S4meanrefA1_1104 = np.array(S4meanrefA1_1104)
S4meanC1_104 = np.array(S4meanC1_104)

S4rgbrefA1_1104 = list()
S4rgbC1_104 = list()
for i in range(3):
    S4rgbrefA1_1104.append(S4meanrefA1_1104[:,i].mean())
    S4rgbC1_104.append(S4meanC1_104[:,i].mean())

# %%
S4meanrefA1_1204 = list()
S4meanC2_104 = list()
for i in range(S4RGB_imgA1C2_4.shape[0]): 
     for j in range(S4RGB_imgA1C2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_1204.append(S4RGB_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_104.append(S4RGB_imgA1C2_4[i][j])  
S4meanrefA1_1204 = np.array(S4meanrefA1_1204)
S4meanC2_104 = np.array(S4meanC2_104)

S4rgbrefA1_1204 = list()
S4rgbC2_104 = list()
for i in range(3):
    S4rgbrefA1_1204.append(S4meanrefA1_1204[:,i].mean())
   S4rgbC2_104.append(S4meanC2_104[:,i].mean())

# %%
S4meanrefA1_1304 = list()
S4meanC3_104 = list()
for i in range(S4RGB_imgA1C3_4.shape[0]): 
     for j in range(S4RGB_imgA1C3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1304.append(S4RGB_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_104.append(S4RGB_imgA1C3_4[i][j])  
S4meanrefA1_1304 = np.array(S4meanrefA1_1304)
S4meanC3_104 = np.array(S4meanC3_104)

S4rgbrefA1_1304 = list()
S4rgbC3_104 = list()
for i in range(3):
    S4rgbrefA1_1304.append(S4meanrefA1_1304[:,i].mean())
    S4rgbC3_104.append(S4meanC3_104[:,i].mean())

# %%
S4meanrefA1_1404 = list()
S4meanC4_104 = list()
for i in range(S4RGB_imgA1C4_4.shape[0]): 
     for j in range(S4RGB_imgA1C4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1404.append(S4RGB_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_104.append(S4RGB_imgA1C4_4[i][j])  
S4meanrefA1_1404 = np.array(S4meanrefA1_1404)
S4meanC4_104 = np.array(S4meanC4_104)

S4rgbrefA1_1404 = list()
S4rgbC4_104 = list()
for i in range(3):
    S4rgbrefA1_1404.append(S4meanrefA1_1404[:,i].mean())
    S4rgbC4_104.append(S4meanC4_104[:,i].mean())

# %%
S4meanrefA1_1504 = list()
S4meanD2_104 = list()
for i in range(S4RGB_imgA1D2_4.shape[0]): 
     for j in range(S4RGB_imgA1D2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1504.append(S4RGB_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_104.append(S4RGB_imgA1D2_4[i][j])  
S4meanrefA1_1504 = np.array(S4meanrefA1_1504)
S4meanD2_104 = np.array(S4meanD2_104)

S4rgbrefA1_1504 = list()
S4rgbD2_104 = list()
for i in range(3):
    S4rgbrefA1_1504.append(S4meanrefA1_1504[:,i].mean())
    S4rgbD2_104.append(S4meanD2_104[:,i].mean())

# %%
S4meanrefA1_1604 = list()
S4meanD3_104 = list()
for i in range(S4RGB_imgA1D3_4.shape[0]): 
     for j in range(S4RGB_imgA1D3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1604.append(S4RGB_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_104.append(S4RGB_imgA1D3_4[i][j])  
S4meanrefA1_1604 = np.array(S4meanrefA1_1604)
S4meanD3_104 = np.array(S4meanD3_104)

S4rgbrefA1_1604 = list()
S4rgbD3_104 = list()
for i in range(3):
    S4rgbrefA1_1604.append(S4meanrefA1_1604[:,i].mean())
    S4rgbD3_104.append(S4meanD3_104[:,i].mean())

# %%
S4meanrefA1_1704= list()
S4meanD4_104 = list()
for i in range(S4RGB_imgA1D4_4.shape[0]): 
     for j in range(S4RGB_imgA1D4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1704.append(S4RGB_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_104.append(S4RGB_imgA1D4_4[i][j])  
S4meanrefA1_1704 = np.array(S4meanrefA1_1404)
S4meanD4_104 = np.array(S4meanD4_104)

S4rgbrefA1_1704 = list()
S4rgbD4_104 = list()
for i in range(3):
    S4rgbrefA1_1704.append(S4meanrefA1_1704[:,i].mean())
    S4rgbD4_104.append(S4meanD4_104[:,i].mean())

# %% [markdown]
# ###Img 5

# %%
S4meanrefA1_105 = list()
S4meanA1_205 = list()
for i in range(S4RGB_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(vRGB_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_105.append(S4RGB_imgA1A1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4S3meanA1_205.append(S4RGB_imgA1A1_5[i][j])  
S4meanrefA1_105 = np.array(S4meanrefA1_105)
S3meanA1_205 = np.array(S4meanA1_205)

S4rgbrefA1_105 = list()
S4rgbA1_205 = list()
for i in range(3):
    S4rgbrefA1_105.append(S4meanrefA1_105[:,i].mean())
    S4gbA1_205.append(S4meanA1_2[:,i].mean())
S4rgbrefA1_105,S4gbA1_205

# %%
S4meanrefA1_305 = list()
S4meanA2_105 = list()
for i in range(S4RGB_imgA1A2_5.shape[0]): 
     for j in range(S4RGB_imgA1A2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_305.append(S4RGB_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_105.append(S4RGB_imgA1A2_5[i][j])  
S4meanrefA1_305 = np.array(S4meanrefA1_305 )
S4meanA2_105 = np.array(S4meanA2_105 )

S4rgbrefA1_305 = list()
S4rgbA2_105  = list()
for i in range(3):
    S4rgbrefA1_305 .append(S4meanrefA1_305 [:,i].mean())
    S4rgbA2_105 .append(S4meanA2_105 [:,i].mean())

# %%
S4meanrefA1_405  = list()
S4meanA3_105  = list()
for i in range(S4RGB_imgA1A3_505 .shape[0]): 
     for j in range(S4RGB_imgA1A3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_405 .append(S4RGB_imgA1A3_505 [i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_105 .append(S4RGB_imgA1A3_505 [i][j])  
S4meanrefA1_4 05 = np.array(S4meanrefA1_405 )
S4meanA3_105  = np.array(S4meanA3_105 )

S4rgbrefA1_405  = list()
S4rgbA3_105  = list()
for i in range(3):
    S4rgbrefA1_405 .append(S4meanrefA1_405 [:,i].mean())
    S4rgbA3_105 .append(S4meanA3_105 [:,i].mean())

# %%
S4meanrefA1_505  = list()
S4meanA3_5105  = list()
for i in range(S4RGB_imgA1A3_55.shape[0]): 
     for j in range(S4RGB_imgA1A3_55.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_505 .append(S4RGB_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5105 .append(S4RGB_imgA1A3_55[i][j])  
S4meanrefA1_505  = np.array(S4meanrefA1_5)
S4meanA3_5105  = np.array(S4meanA3_51)

S4rgbrefA1_505  = list()
S4rgbA3_5105  = list()
for i in range(3):
    S4rgbrefA1_505 .append(S4meanrefA1_505 [:,i].mean())
    S4rgbA3_5105 .append(S4meanA3_5105 [:,i].mean())

# %%
S4meanrefA1_605  = list()
S4meanA4_105  = list()
for i in range(S4RGB_imgA1A4_5.shape[0]): 
     for j in range(vRGB_imgA1A4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_605 .append(S4RGB_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_105 .append(S4RGB_imgA1A4_5[i][j])  
S4meanrefA1_605 = np.array(S4meanrefA1_6)
S4meanA4_105 = np.array(S4meanA4_1)

S4rgbrefA1_605 = list()
S4rgbA4_105 = list()
for i in range(3):
    S4rgbrefA1_605.append(S4meanrefA1_605[:,i].mean())
    S4rgbA4_105.append(S4meanA4_105[:,i].mean())

# %%
S4meanrefA1_705 = list()
S4meanB1_105 = list()
for i in range(S4RGB_imgA1B1_505.shape[0]): 
     for j in range(S4RGB_imgA1B1_505.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_705.append(S4RGB_imgA1B1_505[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_105.append(S4RGB_imgA1B1_505[i][j])  
S4meanrefA1_705 = np.array(S4meanrefA1_705)
S4meanB1_105 = np.array(S4meanB1_105)

S4rgbrefA1_705 = list()
S4rgbB1_105 = list()
for i in range(3):
    S4rgbrefA1_705.append(S4meanrefA1_705[:,i].mean())
    S4rgbB1_105.append(S4meanB1_105[:,i].mean())

# %%
S4meanrefA1_805 = list()
S4meanB2_105 = list()
for i in range(S4RGB_imgA1B2_5.shape[0]): 
     for j in range(S4RGB_imgA1B2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_805.append(S4RGB_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_105.append(S4RGB_imgA1B2_5[i][j])  
S4meanrefA1_805 = np.array(S4meanrefA1_8)
S4meanB2_105 = np.array(S4meanB2_1)

S4rgbrefA1_805 = list()
S4rgbB2_105 = list()
for i in range(3):
    S4rgbrefA1_805.append(S4meanrefA1_805[:,i].mean())
    S4rgbB2_105.append(S4meanB2_105[:,i].mean())

# %%
S4meanrefA1_905 = list()
S4meanB3_105 = list()
for i in range(S4RGB_imgA1B3_5.shape[0]): 
     for j in range(S4RGB_imgA1B3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_905.append(S4RGB_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_105.append(S4RGB_imgA1B3_5[i][j])  
S4meanrefA1_905 = np.array(S4meanrefA1_905)
S4meanB3_105 = np.array(S4meanB3_105)

S4rgbrefA1_905 = list()
S4rgbB3_105 = list()
for i in range(3):
    S4rgbrefA1_905.append(S4meanrefA1_905[:,i].mean())
    S4rgbB3_105.append(S4meanB3_105[:,i].mean())

# %%
S4meanrefA1_1005 = list()
S4meanB4_105 = list()
for i in range(S4RGB_imgA1B4_5.shape[0]): 
     for j in range(S4RGB_imgA1B4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1005.append(S4RGB_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_105.append(S4RGB_imgA1B4_5[i][j])  
S4meanrefA1_1005 = np.array(S4meanrefA1_10)
S4meanB4_105 = np.array(S4meanB4_1)

S4rgbrefA1_1005 = list()
S4rgbB4_105 = list()
for i in range(3):
    S4rgbrefA1_1005.append(S4meanrefA1_1005[:,i].mean())
    S4rgbB4_105.append(S4meanB4_105[:,i].mean())

# %%
S4meanrefA1_1105 = list()
S4meanC1_105 = list()
for i in range(S4RGB_imgA1C1_5.shape[0]): 
     for j in range(S4RGB_imgA1C1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1105.append(S4RGB_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_105.append(S4RGB_imgA1C1_5[i][j])  
S4meanrefA1_1105 = np.array(S4meanrefA1_1105)
S4meanC1_105 = np.array(S4meanC1_105)

S4rgbrefA1_1105 = list()
S4rgbC1_105 = list()
for i in range(3):
    S4rgbrefA1_1105.append(S4meanrefA1_1105[:,i].mean())
    S4rgbC1_105.append(S4meanC1_105[:,i].mean())

# %%
S4meanrefA1_1205 = list()
S4meanC2_105 = list()
for i in range(S4RGB_imgA1C2_5.shape[0]): 
     for j in range(S4RGB_imgA1C2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1205.append(S4RGB_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_105.append(S4RGB_imgA1C2_5[i][j])  
S4meanrefA1_1205 = np.array(S4meanrefA1_1205)
S4meanC2_105 = np.array(S4meanC2_105)

S4rgbrefA1_1205 = list()
S4rgbC2_105 = list()
for i in range(3):
    S4rgbrefA1_1205.append(S4meanrefA1_1205[:,i].mean())
    S4rgbC2_105.append(S4meanC2_105[:,i].mean())

# %%
S4meanrefA1_1305 = list()
S4meanC3_105 = list()
for i in range(S4RGB_imgA1C3_5.shape[0]): 
     for j in range(S4RGB_imgA1C3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1305.append(S3RGB_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_105.append(S3RGB_imgA1C3_5[i][j])  
S4meanrefA1_1305 = np.array(S3meanrefA1_13)
S4meanC3_105 = np.array(S3meanC3_1)

S4rgbrefA1_1305 = list()
S4rgbC3_105 = list()
for i in range(3):
    S4rgbrefA1_1305.append(S4meanrefA1_1305[:,i].mean())
    S4rgbC3_105.append(S4meanC3_105[:,i].mean())

# %%
S4meanrefA1_1405 = list()
S4meanC4_105 = list()
for i in range(S4RGB_imgA1C4_5.shape[0]): 
     for j in range(S4RGB_imgA1C4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1405.append(S4RGB_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_105.append(S4RGB_imgA1C4_5[i][j])  
S4meanrefA1_1405 = np.array(S4meanrefA1_1405)
S4meanC4_105 = np.array(S4meanC4_105)

S4rgbrefA1_1405 = list()
S4rgbC4_105 = list()
for i in range(3):
    S4rgbrefA1_1405.append(S4meanrefA1_1405[:,i].mean())
    S4rgbC4_105.append(S4meanC4_105[:,i].mean())

# %%
S4meanrefA1_1505 = list()
S4meanD2_105 = list()
for i in range(S4RGB_imgA1D2_5.shape[0]): 
     for j in range(S4RGB_imgA1D2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1505.append(S4RGB_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_105.append(S4RGB_imgA1D2_5[i][j])  
S4meanrefA1_1505 = np.array(S4meanrefA1_15)
S4meanD2_105 = np.array(S4meanD2_1)

S4rgbrefA1_1505 = list()
S4rgbD2_105 = list()
for i in range(3):
    S4rgbrefA1_1505.append(S4meanrefA1_1505[:,i].mean())
    S4rgbD2_105.append(S4meanD2_105[:,i].mean())

# %%
S4meanrefA1_1605 = list()
S4meanD3_105 = list()
for i in range(S4RGB_imgA1D3_505.shape[0]): 
     for j in range(S4RGB_imgA1D3_505.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1605.append(S4RGB_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_105.append(S4RGB_imgA1D3_5 [i][j])  
S4meanrefA1_1605 = np.array(S4meanrefA1_1605)
S4meanD3_105 = np.array(S4meanD3_105)

S4rgbrefA1_1605 = list()
S4rgbD3_105 = list()
for i in range(3):
    S4rgbrefA1_1605.append(S4meanrefA1_1605[:,i].mean())
    S4rgbD3_105.append(S4meanD3_105[:,i].mean())

# %%
S4meanrefA1_1705= list()
S4meanD4_105 = list()
for i in range(S4RGB_imgA1D4_.shape[0]): 
     for j in range(S4RGB_imgA1D4_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1705.append(S4RGB_imgA1D4_1i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_105.append(S4RGB_imgA1D4_[i][j])  
S4meanrefA1_1705 = np.array(S4meanrefA1_1405)
S4meanD4_105 = np.array(S4meanD4_105)

S4rgbrefA1_1705 = list()
S4rgbD4_105 = list()
for i in range(3):
    S4rgbrefA1_1705.append(S4meanrefA1_1705[:,i].mean())
    S4rgbD4_105.append(S4meanD4_105[:,i].mean())

# %% [markdown]
# ###Img 6

# %%
S4meanrefA1_106 = list()
S4meanA1_206 = list()
for i in range(S4RGB_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_6.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_106.append(S4RGB_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_206.append(S4RGB_imgA1A1_6[i][j])  
S4meanrefA1_106 = np.array(S4meanrefA1_106)
S4meanA1_206 = np.array(S4meanA1_206)

S4rgbrefA1_106 = list()
S4rgbA1_206 = list()
for i in range(3):
    S4rgbrefA1_106.append(S4meanrefA1_106[:,i].mean())
    S4rgbA1_206.append(S4meanA1_206[:,i].mean())
S4rgbrefA1_106,S4rgbA1_206

# %%
S4meanrefA1_306 = list()
S4meanA2_106 = list()
for i in range(S4RGB_imgA1A2_6.shape[0]): 
     for j in range(S4RGB_imgA1A2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_306.append(S3RGB_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_106.append(S4RGB_imgA1A2_6[i][j])  
S4meanrefA1_306 = np.array(S4meanrefA1_306)
S4meanA2_106 = np.array(S4meanA2_106)

S4rgbrefA1_306 = list()
S4rgbA2_106 = list()
for i in range(3):
    S4rgbrefA1_306.append(S4meanrefA1_306[:,i].mean())
    S4rgbA2_106.append(S4meanA2_106[:,i].mean())

# %%
S4meanrefA1_406 = list()
S4meanA3_106 = list()
for i in range(S4RGB_imgA1A3_6.shape[0]): 
     for j in range(S4RGB_imgA1A3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_406.append(S4RGB_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_106.append(S4RGB_imgA1A3_6[i][j])  
S4meanrefA1_406 = np.array(S4meanrefA1_406)
S4meanA3_106 = np.array(S4meanA3_106)

S4rgbrefA1_406 = list()
S4rgbA3_106 = list()
for i in range(3):
    S4rgbrefA1_406.append(S4meanrefA1_406[:,i].mean())
    S4rgbA3_106.append(S4meanA3_106[:,i].mean())

# %%
S4meanrefA1_506 = list()
S4meanA3_5106 = list()
for i in range(S4RGB_imgA1A3_56.shape[0]): 
     for j in range(S4RGB_imgA1A3_56.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_506.append(S4RGB_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5106.append(S4RGB_imgA1A3_56[i][j])  
S4meanrefA1_506 = np.array(S4meanrefA1_506)
S4meanA3_5106 = np.array(S4meanA3_5106)

S4rgbrefA1_506 = list()
S4gbA3_5106 = list()
for i in range(3):
    S4rgbrefA1_506.append(vmeanrefA1_506[:,i].mean())
    S4rgbA3_5106.append(S4meanA3_5106[:,i].mean())

# %%
S4meanrefA1_606 = list()
S4meanA4_106 = list()
for i in range(S4RGB_imgA1A4_6.shape[0]): 
     for j in range(S4RGB_imgA1A4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_606.append(S4RGB_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_106.append(S4RGB_imgA1A4_6[i][j])  
S4meanrefA1_606 = np.array(S4meanrefA1_606)
S4meanA4_106 = np.array(S4meanA4_106)

S4rgbrefA1_606 = list()
S4rgbA4_106 = list()
for i in range(3):
    S4rgbrefA1_606.append(S4meanrefA1_606[:,i].mean())
    S4rgbA4_106.append(S4meanA4_106[:,i].mean())

# %%
S4meanrefA1_706 = list()
S4meanB1_106 = list()
for i in range(S4RGB_imgA1B1_6.shape[0]): 
     for j in range(S4RGB_imgA1B1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_706.append(S4RGB_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_106.append(S4RGB_imgA1B1_6[i][j])  
S4meanrefA1_706 = np.array(S4meanrefA1_706)
S4meanB1_106 = np.array(S4meanB1_106)

S4rgbrefA1_706 = list()
S4rgbB1_106 = list()
for i in range(3):
    S4rgbrefA1_706.append(S4meanrefA1_706[:,i].mean())
    S4rgbB1_106.append(S4meanB1_106[:,i].mean())

# %%
S4meanrefA1_806 = list()
S4meanB2_106 = list()
for i in range(S4RGB_imgA1B2_6.shape[0]): 
     for j in range(S4RGB_imgA1B2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_806.append(S4RGB_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_106.append(S4RGB_imgA1B2_6[i][j])  
S4meanrefA1_806 = np.array(S4meanrefA1_806)
S4meanB2_106 = np.array(S4meanB2_106)

S4rgbrefA1_806 = list()
S4rgbB2_106 = list()
for i in range(3):
    S4rgbrefA1_806.append(S4meanrefA1_806[:,i].mean())
    S4rgbB2_106.append(S4meanB2_106[:,i].mean())

# %%
S4meanrefA1_906 = list()
S4meanB3_106 = list()
for i in range(S4RGB_imgA1B3_6.shape[0]): 
     for j in range(vRGB_imgA1B3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_906.append(S4RGB_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_106.append(S4RGB_imgA1B3_6[i][j])  
S4meanrefA1_906 = np.array(S4meanrefA1_906)
S4meanB3_106 = np.array(S4meanB3_106)

S4rgbrefA1_906 = list()
S4gbB3_106 = list()
for i in range(3):
    S4rgbrefA1_906.append(S4meanrefA1_906[:,i].mean())
    S4rgbB3_106.append(S4meanB3_106[:,i].mean())

# %%
S4meanrefA1_1006 = list()
S4meanB4_106 = list()
for i in range(S4RGB_imgA1B4_6.shape[0]): 
     for j in range(S4RGB_imgA1B4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1006.append(S4RGB_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_106.append(S4RGB_imgA1B4_6[i][j])  
S4meanrefA1_1006 = np.array(S4meanrefA1_1006)
S4meanB4_106 = np.array(S4meanB4_106)

S4rgbrefA1_1006 = list()
S4rgbB4_106 = list()
for i in range(3):
    S4rgbrefA1_1006.append(S4meanrefA1_1006[:,i].mean())
    S4rgbB4_106.append(S4meanB4_106[:,i].mean())

# %%
S4meanrefA1_1106 = list()
S4meanC1_106 = list()
for i in range(S4RGB_imgA1C1_6.shape[0]): 
     for j in range(S4RGB_imgA1C1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1106.append(S4RGB_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_106.append(S4RGB_imgA1C1_6[i][j])  
S4meanrefA1_1106 = np.array(S4meanrefA1_1106)
S4meanC1_106 = np.array(S4meanC1_106)

S4rgbrefA1_1106 = list()
S4rgbC1_106 = list()
for i in range(3):
    S4rgbrefA1_1106.append(S4meanrefA1_1106[:,i].mean())
    S4rgbC1_106.append(S4meanC1_106[:,i].mean())

# %%
S4meanrefA1_1206 = list()
S4meanC2_106 = list()
for i in range(S4RGB_imgA1C2_6.shape[0]): 
     for j in range(S4RGB_imgA1C2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_1206.append(S4RGB_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_106.append(S4RGB_imgA1C2_6[i][j])  
S4meanrefA1_1206 = np.array(S4meanrefA1_1206)
S4meanC2_106 = np.array(S4meanC2_106)

S4rgbrefA1_1206 = list()
S4rgbC2_106 = list()
for i in range(3):
    S4rgbrefA1_1206.append(S43meanrefA1_1206[:,i].mean())
    S4rgbC2_106.append(S4meanC2_106[:,i].mean())

# %%
S4meanrefA1_1306 = list()
S4meanC3_106 = list()
for i in range(S4RGB_imgA1C3_6.shape[0]): 
     for j in range(S4RGB_imgA1C3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1306.append(S4RGB_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_106.append(S4RGB_imgA1C3_6[i][j])  
S4meanrefA1_1306 = np.array(S4meanrefA1_1306)
S4meanC3_106 = np.array(S4meanC3_106)

S4rgbrefA1_1306 = list()
S4rgbC3_106 = list()
for i in range(3):
     S4rgbrefA1_1306.append(S4meanrefA1_1306[:,i].mean())
     S4rgbC3_106.append(S4meanC3_106[:,i].mean())

# %%
S4meanrefA1_1406 = list()
S4meanC4_106 = list()
for i in range(S4RGB_imgA1C4_6.shape[0]): 
     for j in range(S4RGB_imgA1C4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1406.append(S4RGB_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_106.append(S4RGB_imgA1C4_6[i][j])  
S4meanrefA1_1406 = np.array(S4meanrefA1_1406)
S4meanC4_106 = np.array(S4meanC4_106)

S4rgbrefA1_1406 = list()
S4rgbC4_106 = list()
for i in range(3):
    S4rgbrefA1_1406.append(S4meanrefA1_1406[:,i].mean())
    S4rgbC4_106.append(S4meanC4_106[:,i].mean())

# %%
S4meanrefA1_1506 = list()
S4meanD2_106 = list()
for i in range(S4RGB_imgA1D2_6.shape[0]): 
     for j in range(S4RGB_imgA1D2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1506.append(S4RGB_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_106.append(S4RGB_imgA1D2_6[i][j])  
S4meanrefA1_1506 = np.array(S4meanrefA1_1506)
S4meanD2_106 = np.array(S4meanD2_106)

S4rgbrefA1_1506 = list()
S4rgbD2_1 = list()
for i in range(3):
    S4rgbrefA1_15.append(S4meanrefA1_15[:,i].mean())
    S4rgbD2_1.append(S4meanD2_1[:,i].mean())

# %%
S4meanrefA1_16 = list()
S4meanD3_1 = list()
for i in range(S4RGB_imgA1D3_6.shape[0]): 
     for j in range(S4RGB_imgA1D3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_16.append(S4RGB_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_1.append(S4RGB_imgA1D3_6[i][j])  
S4meanrefA1_16 = np.array(S4meanrefA1_1606)
S4meanD3_106 = np.array(S4meanD3_106)

S4rgbrefA1_1606 = list()
S4rgbD3_106 = list()
for i in range(3):
    S4rgbrefA1_1606.append(S4meanrefA1_1606[:,i].mean())
    S4rgbD3_106.append(S4meanD3_106[:,i].mean())

# %%
S4meanrefA1_1706= list()
S4meanD4_106 = list()
for i in range(S4RGB_imgA1D4_6.shape[0]): 
     for j in range(S4RGB_imgA1D4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1706.append(S4RGB_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3S4meanD4_106.append(S4RGB_imgA1D4_6[i][j])  
S4meanrefA1_1706 = np.array(S3meanrefA1_1406)
S4meanD4_106 = np.array(S4meanD4_106)

S4gbrefA1_1706 = list()
S4rgbD4_106 = list()
for i in range(3):
    S4rgbrefA1_1706.append(S4meanrefA1_1706[:,i].mean())
    S4rgbD4_106.append(S4meanD4_106[:,i].mean())

# %% [markdown]
# ###Img 7

# %%
S4meanrefA1_107 = list()
S4meanA1_207 = list()
for i in range(S4RGB_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_107.append(S4RGB_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_207.append(S4RGB_imgA1A1_7[i][j])  
S3meanrefA1_107 = np.array(S4meanrefA1_107)
S4meanA1_207 = np.array(S4meanA1_207)

S4rgbrefA1_107 = list()
S4rgbA1_207 = list()
for i in range(3):
    S4rgbrefA1_107.append(S4meanrefA1_107[:,i].mean())
    S4rgbA1_207.append(S4meanA1_207[:,i].mean())
S3rgbrefA1_107,S4rgbA1_207

# %%
S4meanrefA1_307 = list()
S4meanA2_107 = list()
for i in range(S4RGB_imgA1A2_7.shape[0]): 
     for j in range(S4RGB_imgA1A2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S3meanrefA1_307.append(S4RGB_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S3meanA2_107.append(S4RGB_imgA1A2_7[i][j])  
S4meanrefA1_307 = np.array(S4meanrefA1_307)
S4meanA2_107 = np.array(S4meanA2_107)

S4rgbrefA1_307 = list()
S4rgbA2_107 = list()
for i in range(3):
    S4rgbrefA1_307.append(S4meanrefA1_307[:,i].mean())
    S4rgbA2_107.append(S4meanA2_107[:,i].mean())

# %%
S4meanrefA1_407 = list()
S4meanA3_107 = list()
for i in range(S4RGB_imgA1A3_7.shape[0]): 
     for j in range(S4RGB_imgA1A3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_407.append(S4RGB_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_107.append(S4RGB_imgA1A3_7[i][j])  
S4meanrefA1_407 = np.array(S4meanrefA1_407)
S4meanA3_107 = np.array(S4meanA3_107)

S4rgbrefA1_407 = list()
S4rgbA3_107 = list()
for i in range(3):
    S4rgbrefA1_407.append(S4meanrefA1_407[:,i].mean())
    S4rgbA3_107.append(S3meanA3_107[:,i].mean())

# %%
S4meanrefA1_507 = list()
S4meanA3_5107 = list()
for i in range(S4RGB_imgA1A3_57.shape[0]): 
     for j in range(S4RGB_imgA1A3_57.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_507.append(S4S3RGB_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5107.append(S4RGB_imgA1A3_57[i][j])  
S4meanrefA1_507 = np.array(S4meanrefA1_507)
S4meanA3_5107 = np.array(S4meanA3_5107)

S4rgbrefA1_507 = list()
S4rgbA3_5107 = list()
for i in range(3):
    S4rgbrefA1_507.append(S4meanrefA1_507[:,i].mean())
    S4rgbA3_5107.append(S4meanA3_5107[:,i].mean())

# %%
S4meanrefA1_607 = list()
S4meanA4_107 = list()
for i in range(S4RGB_imgA1A4_7.shape[0]): 
     for j in range(S4RGB_imgA1A4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_607.append(S3RGB_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_107.append(S3RGB_imgA1A4_7[i][j])  
S4meanrefA1_607 = np.array(S3meanrefA1_607)
S4meanA4_107 = np.array(S3meanA4_107)

S4rgbrefA1_607 = list()
S4rgbA4_107 = list()
for i in range(3):
    S4rgbrefA1_607.append(S4meanrefA1_607[:,i].mean())
    S4rgbA4_107.append(S4meanA4_107[:,i].mean())

# %%
S4meanrefA1_707 = list()
S4meanB1_107 = list()
for i in range(S4RGB_imgA1B1_7.shape[0]): 
     for j in range(S4RGB_imgA1B1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_707.append(S4RGB_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_107.append(S4RGB_imgA1B1_7[i][j])  
S4meanrefA1_707 = np.array(S4meanrefA1_707)
S4meanB1_107 = np.array(S4meanB1_107)

S4rgbrefA1_707 = list()
S4gbB1_107 = list()
for i in range(3):
    S4rgbrefA1_707.append(S4meanrefA1_707[:,i].mean())
    S4rgbB1_107.append(S4meanB1_107[:,i].mean())

# %%
S4meanrefA1_807 = list()
S4meanB2_107 = list()
for i in range(S4RGB_imgA1B2_7.shape[0]): 
     for j in range(S4RGB_imgA1B2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_807.append(S4RGB_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanB2_107.append(S4RGB_imgA1B2_7[i][j])  
S4meanrefA1_807 = np.array(S4meanrefA1_807)
S4meanB2_107 = np.array(S4meanB2_107)

S4rgbrefA1_807 = list()
S4rgbB2_107 = list()
for i in range(3):
    S4rgbrefA1_807.append(S4meanrefA1_807[:,i].mean())
    S4rgbB2_107.append(S4meanB2_107[:,i].mean())

# %%
S4meanrefA1_907 = list()
อmeanB3_107 = list()
for i in range(S4RGB_imgA1B3_7.shape[0]): 
     for j in range(S4RGB_imgA1B3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_907.append(S4RGB_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_107.append(S4RGB_imgA1B3_7[i][j])  
S4meanrefA1_907 = np.array(S4meanrefA1_907)
S4meanB3_107 = np.array(S4meanB3_107)

S4rgbrefA1_907 = list()
S4rgbB3_107 = list()
for i in range(3):
    S4rgbrefA1_907.append(S4meanrefA1_907[:,i].mean())
    S4rgbB3_107.append(S4meanB3_107[:,i].mean())

# %%
S4meanrefA1_1007 = list()
S4meanB4_107 = list()
for i in range(S4RGB_imgA1B4_7.shape[0]): 
     for j in range(S4RGB_imgA1B4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1007.append(S4RGB_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_107.append(S4RGB_imgA1B4_7[i][j])  
S4meanrefA1_1007 = np.array(S4meanrefA1_1007)
S4meanB4_107 = np.array(S4meanB4_107)

S4rgbrefA1_1007 = list()
S4rgbB4_107 = list()
for i in range(3):
    S4rgbrefA1_1007.append(S4meanrefA1_1007[:,i].mean())
    S4rgbB4_107.append(S4meanB4_107[:,i].mean())

# %%
S4meanrefA1_1107 = list()
S4meanC1_107 = list()
for i in range(S4RGB_imgA1C1_7.shape[0]): 
     for j in range(S4RGB_imgA1C1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1107.append(S4RGB_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_107.append(S4RGB_imgA1C1_7[i][j])  
S4meanrefA1_1107 = np.array(S4meanrefA1_1107)
S4meanC1_107 = np.array(S4meanC1_107)

S4rgbrefA1_1107 = list()
S4rgbC1_107 = list()
for i in range(3):
    S4rgbrefA1_1107.append(S4meanrefA1_1107[:,i].mean())
    S4rgbC1_107.append(S4meanC1_107[:,i].mean())

# %%
S4meanrefA1_1207 = list()
S4meanC2_107 = list()
for i in range(S4RGB_imgA1C2_7.shape[0]): 
     for j in range(S4RGB_imgA1C2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1207.append(S4RGB_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_107.append(S4RGB_imgA1C2_7[i][j])  
S4meanrefA1_1207 = np.array(S4meanrefA1_1207)
S4meanC2_107 = np.array(S4meanC2_107)

S4rgbrefA1_1207 = list()
S4rgbC2_107 = list()
for i in range(3):
    S4rgbrefA1_1207.append(S4meanrefA1_1207[:,i].mean())
    S4rgbC2_107.append(S4meanC2_107[:,i].mean())

# %%
S4meanrefA1_1307 = list()
S4meanC3_107 = list()
for i in range(S4RGB_imgA1C3_7.shape[0]): 
     for j in range(S4RGB_imgA1C3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1307.append(S4RGB_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_107.append(S4RGB_imgA1C3_7[i][j])  
S4meanrefA1_1307 = np.array(S4meanrefA1_1307)
S4meanC3_107 = np.array(S4meanC3_107)

S4rgbrefA1_1307 = list()
S4rgbC3_107 = list()
for i in range(3):
    S4rgbrefA1_1307.append(S4meanrefA1_1307[:,i].mean())
    S4rgbC3_107.append(S4meanC3_107[:,i].mean())

# %%
S4meanrefA1_1407 = list()
S4meanC4_107 = list()
for i in range(S4RGB_imgA1C4_7.shape[0]): 
     for j in range(S4RGB_imgA1C4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_1407.append(S4RGB_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_107.append(S4RGB_imgA1C4_7[i][j])  
S4meanrefA1_1407 = np.array(S4meanrefA1_1407)
S4meanC4_107 = np.array(S4meanC4_107)

S4rgbrefA1_1407 = list()
S4rgbC4_107 = list()
for i in range(3):
    S4rgbrefA1_1407.append(S4meanrefA1_1407[:,i].mean())
    S4rgbC4_107.append(S4meanC4_107[:,i].mean())

# %%
S4meanrefA1_1507 = list()
S4meanD2_107 = list()
for i in range(S4RGB_imgA1D2_7.shape[0]): 
     for j in range(S4RGB_imgA1D2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1507.append(S4RGB_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_107.append(S4RGB_imgA1D2_7[i][j])  
S4meanrefA1_1507 = np.array(S4meanrefA1_1507)
S4meanD2_107 = np.array(S4meanD2_107)

S4rgbrefA1_1507 = list()
S4rgbD2_107 = list()
for i in range(3):
    S4rgbrefA1_1507.append(S4meanrefA1_1507[:,i].mean())
    S4rgbD2_107.append(S4meanD2_107[:,i].mean())

# %%
S4meanrefA1_1607 = list()
S4meanD3_107 = list()
for i in range(S4RGB_imgA1D3_7.shape[0]): 
     for j in range(S4RGB_imgA1D3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1607.append(S4RGB_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_107.append(S4RGB_imgA1D3_7[i][j])  
S4meanrefA1_1607 = np.array(S4meanrefA1_1607)
S4meanD3_107 = np.array(S4meanD3_107)

S4rgbrefA1_1607 = list()
S4rgbD3_107 = list()
for i in range(3):
    S4rgbrefA1_1607.append(S4meanrefA1_1607[:,i].mean())
    S4rgbD3_107.append(S4meanD3_107[:,i].mean())

# %%
S4meanrefA1_1707= list()
S4meanD4_107 = list()
for i in range(S4RGB_imgA1D4_7.shape[0]): 
     for j in range(S4RGB_imgA1D4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1707.append(S4RGB_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_107.append(S4RGB_imgA1D4_7[i][j])  
S4meanrefA1_1707 = np.array(S4meanrefA1_1407)
S4meanD4_107 = np.array(S4meanD4_107)

S4rgbrefA1_1707 = list()
S4rgbD4_107 = list()
for i in range(3):
    S4rgbrefA1_1707.append(S4meanrefA1_1707[:,i].mean())
    S4rgbD4_107.append(S4meanD4_107[:,i].mean())

# %% [markdown]
# ###Img 8

# %%
S4meanrefA1_108 = list()
S4meanA1_208 = list()
for i in range(S4RGB_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_108.append(S4RGB_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_208.append(S4RGB_imgA1A1_8[i][j])  
S4meanrefA1_108 = np.array(S4meanrefA1_108)
S4meanA1_208 = np.array(S4meanA1_208)

S4rgbrefA1_108 = list()
S4rgbA1_208 = list()
for i in range(3):
    S4rgbrefA1_108.append(S4meanrefA1_108[:,i].mean())
    S4rgbA1_208.append(S4meanA1_208[:,i].mean())
S4rgbrefA1_108,S4rgbA1_208

# %%
S4meanrefA1_308 = list()
S4meanA2_108 = list()
for i in range(S4RGB_imgA1A2_8.shape[0]): 
     for j in range(S4RGB_imgA1A2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_308.append(S4RGB_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_108.append(S4RGB_imgA1A2_8[i][j])  
S4meanrefA1_308 = np.array(S4meanrefA1_308)
S4meanA2_108 = np.array(S4meanA2_108)

S4rgbrefA1_308 = list()
S4rgbA2_108 = list()
for i in range(3):
    S4rgbrefA1_308.append(S4meanrefA1_308[:,i].mean())
    S4rgbA2_108.append(S4meanA2_108[:,i].mean())

# %%
S4meanrefA1_408 = list()
S4meanA3_108 = list()
for i in range(S4RGB_imgA1A3_8.shape[0]): 
     for j in range(S4RGB_imgA1A3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_408.append(S4RGB_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_108.append(S4RGB_imgA1A3_8[i][j])  
S4meanrefA1_408 = np.array(S4meanrefA1_408)
S4meanA3_108 = np.array(S4meanA3_108)

S4rgbrefA1_408 = list()
S4rgbA3_108 = list()
for i in range(3):
    S4rgbrefA1_408.append(S4meanrefA1_408[:,i].mean())
    S4rgbA3_108.append(S4meanA3_108[:,i].mean())

# %%
S4meanrefA1_508 = list()
S3meanA3_5108 = list()
for i in range(S4RGB_imgA1A3_58.shape[0]): 
     for j in range(S4RGB_imgA1A3_58.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_508.append(S4RGB_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5108.append(S4RGB_imgA1A3_58[i][j])  
S4meanrefA1_508 = np.array(S4meanrefA1_508)
S4meanA3_5108 = np.array(S4meanA3_5108)

S4rgbrefA1_508 = list()
S4rgbA3_5108 = list()
for i in range(3):
    S4rgbrefA1_508.append(S4meanrefA1_508[:,i].mean())
    S4rgbA3_5108.append(S4meanA3_5108[:,i].mean())

# %%
S4meanrefA1_608 = list()
S4meanA4_108 = list()
for i in range(S4RGB_imgA1A4_8.shape[0]): 
     for j in range(S4RGB_imgA1A4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_608.append(S4RGB_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_108.append(S4RGB_imgA1A4_8[i][j])  
S4meanrefA1_608 = np.array(S4meanrefA1_608)
S4meanA4_108 = np.array(S4meanA4_108)

S4rgbrefA1_608 = list()
S4rgbA4_108 = list()
for i in range(3):
    S4rgbrefA1_608.append(S4meanrefA1_608[:,i].mean())
    S4rgbA4_108.append(S4meanA4_108[:,i].mean())

# %%
S4meanrefA1_708 = list()
S4meanB1_108 = list()
for i in range(S4RGB_imgA1B1_8.shape[0]): 
     for j in range(S4RGB_imgA1B1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_708.append(S4RGB_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_108.append(S4RGB_imgA1B1_8[i][j])  
S4meanrefA1_708 = np.array(S4meanrefA1_708)
S4meanB1_108 = np.array(S4meanB1_108)

S4rgbrefA1_708 = list()
S4rgbB1_108 = list()
for i in range(3):
    S4rgbrefA1_708.append(S4meanrefA1_708[:,i].mean())
    S4rgbB1_108.append(S4meanB1_108[:,i].mean())

# %%
S4meanrefA1_808 = list()
S4meanB2_108 = list()
for i in range(S4RGB_imgA1B2_8.shape[0]): 
     for j in range(S4RGB_imgA1B2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_808.append(S4RGB_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_108.append(S4RGB_imgA1B2_8[i][j])  
S4meanrefA1_808 = np.array(S4meanrefA1_808)
S4meanB2_108 = np.array(S4meanB2_108)

S4rgbrefA1_808 = list()
S4rgbB2_108 = list()
for i in range(3):
    S4rgbrefA1_808.append(S4meanrefA1_808[:,i].mean())
    S4rgbB2_108.append(S4meanB2_108[:,i].mean())

# %%
S4meanrefA1_908 = list()
S4meanB3_108 = list()
for i in range(S4RGB_imgA1B3_8.shape[0]): 
     for j in range(S4RGB_imgA1B3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_908.append(S4RGB_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_108.append(S4RGB_imgA1B3_8[i][j])  
S4meanrefA1_908 = np.array(S4meanrefA1_908)
S4meanB3_108 = np.array(S4meanB3_108)

S4rgbrefA1_908 = list()
S4rgbB3_108 = list()
for i in range(3):
    S4rgbrefA1_908.append(S4meanrefA1_908[:,i].mean())
    S4rgbB3_108.append(S4meanB3_108[:,i].mean())

# %%
S4meanrefA1_1008 = list()
S4meanB4_108 = list()
for i in range(S4RGB_imgA1B4_8.shape[0]): 
     for j in range(S4RGB_imgA1B4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1008.append(S2RGB_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_108.append(S4RGB_imgA1B4_8[i][j])  
S4meanrefA1_1008 = np.array(S4meanrefA1_1008)
S4meanB4_108 = np.array(S4meanB4_108)

S4rgbrefA1_1008 = list()
S4rgbB4_108 = list()
for i in range(3):
    S4rgbrefA1_1008.append(S4meanrefA1_1008[:,i].mean())
    S4rgbB4_108.append(S4meanB4_108[:,i].mean())

# %%
S4meanrefA1_1108 = list()
S4meanC1_108 = list()
for i in range(S4RGB_imgA1C1_8.shape[0]): 
     for j in range(S4RGB_imgA1C1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1108.append(S4RGB_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanC1_108.append(S4RGB_imgA1C1_8[i][j])  
S4meanrefA1_1108 = np.array(S4meanrefA1_1108)
S4meanC1_108 = np.array(S4meanC1_108)

S4rgbrefA1_1108 = list()
S4rgbC1_108 = list()
for i in range(3):
    S4rgbrefA1_1108.append(S4meanrefA1_1108[:,i].mean())
    S4rgbC1_108.append(S4meanC1_108[:,i].mean())

# %%
S4meanrefA1_1208 = list()
S4meanC2_108 = list()
for i in range(S4RGB_imgA1C2_8.shape[0]): 
     for j in range(S4RGB_imgA1C2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1208.append(S4RGB_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  vmeanC2_108.append(S4RGB_imgA1C2_8[i][j])  
S4meanrefA1_1208 = np.array(S4meanrefA1_1208)
S4meanC2_108 = np.array(S4meanC2_108)

S4rgbrefA1_1208 = list()
S4rgbC2_108 = list()
for i in range(3):
    S4rgbrefA1_1208.append(S4meanrefA1_1208[:,i].mean())
    S4rgbC2_108.append(S4meanC2_108[:,i].mean())

# %%
S4meanrefA1_1308 = list()
S4meanC3_108 = list()
for i in range(S4RGB_imgA1C3_8.shape[0]): 
     for j in range(S4RGB_imgA1C3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1308.append(S4RGB_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_108.append(S4RGB_imgA1C3_8[i][j])  
S4meanrefA1_1308 = np.array(S4meanrefA1_1308)
S4meanC3_108 = np.array(S4meanC3_108)

S4rgbrefA1_1308 = list()
S4rgbC3_108 = list()
for i in range(3):
    S4rgbrefA1_1308.append(S4meanrefA1_1308[:,i].mean())
    S4rgbC3_108.append(S4meanC3_108[:,i].mean())

# %%
S4meanrefA1_1408 = list()
S4meanC4_108 = list()
for i in range(S4RGB_imgA1C4_8.shape[0]): 
     for j in range(S4RGB_imgA1C4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1408.append(S4RGB_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_108.append(S4RGB_imgA1C4_8[i][j])  
S4meanrefA1_1408 = np.array(S4meanrefA1_1408)
S4meanC4_108 = np.array(S4meanC4_108)

S4rgbrefA1_1408 = list()
S4rgbC4_108 = list()
for i in range(3):
    S4rgbrefA1_1408.append(S4meanrefA1_1408[:,i].mean())
    S4rgbC4_108.append(S4meanC4_108[:,i].mean())

# %%
S4meanrefA1_1508 = list()
S4meanD2_108 = list()
for i in range(S4RGB_imgA1D2_8.shape[0]): 
     for j in range(S4RGB_imgA1D2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1508.append(S4RGB_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_108.append(S4RGB_imgA1D2_8[i][j])  
S4meanrefA1_1508 = np.array(S4meanrefA1_1508)
S4meanD2_108 = np.array(S4meanD2_108)

S4rgbrefA1_1508 = list()
S4rgbD2_108 = list()
for i in range(3):
    S4rgbrefA1_1508.append(S4meanrefA1_1508[:,i].mean())
    S4rgbD2_108.append(S4meanD2_108[:,i].mean())

# %%
S4meanrefA1_1608 = list()
S4meanD3_108 = list()
for i in range(S4RGB_imgA1D3_8.shape[0]): 
     for j in range(S4RGB_imgA1D3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1608.append(S4RGB_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_108.append(S4RGB_imgA1D3_8[i][j])  
S4meanrefA1_1608 = np.array(S4meanrefA1_1608)
S4meanD3_108 = np.array(S4meanD3_108)

S4rgbrefA1_1608 = list()
S4rgbD3_108 = list()
for i in range(3):
    S4rgbrefA1_1608.append(S4meanrefA1_1608[:,i].mean())
    S4rgbD3_108.append(S4meanD3_108[:,i].mean())

# %%
S4meanrefA1_1708= list()
S4meanD4_108 = list()
for i in range(S4RGB_imgA1D4_8.shape[0]): 
     for j in range(S4RGB_imgA1D4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1708.append(S4RGB_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_108.append(S4RGB_imgA1D4_8[i][j])  
S4meanrefA1_1708 = np.array(S4meanrefA1_1408)
S4meanD4_108 = np.array(S4meanD4_108)

S4rgbrefA1_1708 = list()
S4rgbD4_108 = list()
for i in range(3):
    S4rgbrefA1_1708.append(S4meanrefA1_1708[:,i].mean())
    S4rgbD4_108.append(S4meanD4_108[:,i].mean())

# %% [markdown]
# ###Img 9

# %%
S4meanrefA2_109 = list()
S4meanA2_209 = list()
for i in range(S4RGB_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_109.append(S4RGB_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_209.append(S4RGB_imgA1A1_9[i][j])  
S4meanrefA1_109 = np.array(S4meanrefA1_109)
S4meanA1_209 = np.array(S4meanA1_209)

S4rgbrefA1_109 = list()
S4rgbA1_209 = list()
for i in range(3):
    S4gbrefA1_109.append(S4meanrefA1_109[:,i].mean())
    S4rgbA1_209.append(S4meanA1_209[:,i].mean())
S4rgbrefA1_109,S4rgbA1_209

# %%
S4meanrefA1_309 = list()
S4meanA2_109 = list()
for i in range(S4RGB_imgA1A2_9.shape[0]): 
     for j in range(S4RGB_imgA1A2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_309.append(S4RGB_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_109.append(S4RGB_imgA1A2_9[i][j])  
S4meanrefA1_309 = np.array(S4meanrefA1_309)
S4meanA2_109 = np.array(S4meanA2_109)

S4rgbrefA1_309 = list()
S4rgbA2_109 = list()
for i in range(3):
    S4rgbrefA1_309.append(S4meanrefA1_309[:,i].mean())
    S4rgbA2_109.append(S4meanA2_109[:,i].mean())

# %%
S4meanrefA1_409 = list()
S4meanA3_109 = list()
for i in range(S4RGB_imgA1A3_9.shape[0]): 
     for j in range(S4RGB_imgA1A3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_409.append(S4RGB_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_109.append(S4RGB_imgA1A3_9[i][j])  
S4meanrefA1_409 = np.array(S4meanrefA1_409)
S4meanA3_109 = np.array(S4meanA3_109)

S4rgbrefA1_409 = list()
S4rgbA3_109 = list()
for i in range(3):
    S4rgbrefA1_409.append(S4meanrefA1_409[:,i].mean())
    S4rgbA3_109.append(S4meanA3_109[:,i].mean())

# %%
S4meanrefA1_509 = list()
S4meanA3_5109 = list()
for i in range(S4RGB_imgA1A3_59.shape[0]): 
     for j in range(S4RGB_imgA1A3_59.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_509.append(S4RGB_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5109.append(S4RGB_imgA1A3_59[i][j])  
S4meanrefA1_509 = np.array(S4meanrefA1_509)
S4meanA3_5109 = np.array(S4meanA3_5109)

S4rgbrefA1_509 = list()
S4rgbA3_5109 = list()
for i in range(3):
    S4rgbrefA1_509.append(S4meanrefA1_509[:,i].mean())
    S4rgbA3_5109.append(S4meanA3_5109[:,i].mean())

# %%
S4meanrefA1_609 = list()
S4meanA4_109 = list()
for i in range(S4RGB_imgA1A4_9.shape[0]): 
     for j in range(S4RGB_imgA1A4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_609.append(S4RGB_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_109.append(S4RGB_imgA1A4_9[i][j])  
S4meanrefA1_609 = np.array(S4meanrefA1_609)
S4meanA4_109 = np.array(S4meanA4_109)

S4rgbrefA1_609 = list()
S4rgbA4_109 = list()
for i in range(3):
    S4rgbrefA1_609.append(S4meanrefA1_609[:,i].mean())
    S4rgbA4_109.append(S4meanA4_109[:,i].mean())

# %%
S4meanrefA1_709 = list()
S4meanB1_109 = list()
for i in range(S4RGB_imgA1B1_9.shape[0]): 
     for j in range(S4RGB_imgA1B1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_709.append(S4RGB_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_109.append(S4RGB_imgA1B1_9[i][j])  
S4meanrefA1_709 = np.array(S4meanrefA1_709)
S4meanB1_109 = np.array(S4meanB1_109)

S4rgbrefA1_709 = list()
S4rgbB1_109 = list()
for i in range(3):
    S4rgbrefA1_709.append(S4meanrefA1_709[:,i].mean())
    S4rgbB1_109.append(S4meanB1_109[:,i].mean())

# %%
S4meanrefA1_809 = list()
S4meanB2_109 = list()
for i in range(S4RGB_imgA2B2_9.shape[0]): 
     for j in range(S4RGB_imgA2B2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_809.append(S4RGB_imgA1B2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_109.append(S4RGB_imgA1B2_9[i][j])  
S4meanrefA1_809 = np.array(S4meanrefA1_809)
S4meanB2_109 = np.array(S4meanB2_109)

S4rgbrefA1_809 = list()
S4rgbB2_109 = list()
for i in range(3):
    S4rgbrefA1_809.append(S4meanrefA1_809[:,i].mean())
    S4rgbB2_109.append(S4meanB2_109[:,i].mean())

# %%
S4meanrefA1_909 = list()
S4meanB3_109 = list()
for i in range(S4RGB_imgA1B3_9.shape[0]): 
     for j in range(S4RGB_imgA1B3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_909.append(S4RGB_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_109.append(S4RGB_imgA1B3_9[i][j])  
S4meanrefA1_909 = np.array(S4meanrefA1_909)
S4meanB3_109 = np.array(S4meanB3_109)

S4rgbrefA1_909 = list()
S4rgbB3_109 = list()
for i in range(3):
    S4rgbrefA1_909.append(S4meanrefA1_909[:,i].mean())
    S4rgbB3_109.append(S4meanB3_109[:,i].mean())

# %%
S4meanrefA1_1009 = list()
S4meanB4_109 = list()
for i in range(S4RGB_imgA1B4_9.shape[0]): 
     for j in range(S4RGB_imgA1B4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_1009.append(S4RGB_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_109.append(S4RGB_imgA1B4_9[i][j])  
S4meanrefA1_1009 = np.array(S4meanrefA1_1009)
S4meanB4_109 = np.array(S4meanB4_109)

S4rgbrefA1_1009 = list()
S4rgbB4_109 = list()
for i in range(3):
    S4rgbrefA1_1009.append(S4meanrefA1_1009[:,i].mean())
    S4rgbB4_109.append(S4meanB4_109[:,i].mean())

# %%
S4meanrefA1_1109 = list()
S4meanC1_109 = list()
for i in range(S4RGB_imgA1C1_9.shape[0]): 
     for j in range(S4RGB_imgA1C1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1109.append(S4RGB_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_109.append(S4RGB_imgA1C1_9[i][j])  
S4meanrefA1_1109 = np.array(S4meanrefA1_1109)
S4meanC1_109 = np.array(S4meanC1_109)

S4rgbrefA1_1109 = list()
S4rgbC1_109 = list()
for i in range(3):
    S4rgbrefA1_1109.append(S4meanrefA1_1109[:,i].mean())
    S4rgbC1_109.append(S4meanC1_109[:,i].mean())

# %%
S4meanrefA1_1209 = list()
S4meanC2_109 = list()
for i in range(S4RGB_imgA1C2_9.shape[0]): 
     for j in range(S4RGB_imgA1C2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1209.append(S4RGB_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_109.append(S4RGB_imgA1C2_9[i][j])  
S4meanrefA1_1209 = np.array(S4meanrefA1_1209)
S4meanC2_109 = np.array(S4meanC2_109)

S4rgbrefA1_1209 = list()
S4rgbC2_109 = list()
for i in range(3):
    S4rgbrefA1_1209.append(S4meanrefA1_1209[:,i].mean())
    S4rgbC2_109.append(S4meanC2_109[:,i].mean())

# %%
S4meanrefA1_1309 = list()
S4meanC3_109 = list()
for i in range(S4RGB_imgA1C3_9.shape[0]): 
     for j in range(S4RGB_imgA1C3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1309.append(S4RGB_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_109.append(S4RGB_imgA1C3_9[i][j])  
S4meanrefA1_1309 = np.array(S4meanrefA1_1309)
S4meanC3_109 = np.array(S4meanC3_109)

S4rgbrefA1_1309 = list()
S4rgbC3_109 = list()
for i in range(3):
    S4rgbrefA1_1309.append(S4meanrefA1_1309[:,i].mean())
    S4rgbC3_109.append(S4meanC3_109[:,i].mean())

# %%
S4meanrefA1_1409 = list()
S4meanC4_109 = list()
for i in range(S4RGB_imgA1C4_9.shape[0]): 
     for j in range(S4RGB_imgA1C4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                   S4meanrefA1_1409.append(S4RGB_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_109.append(S4RGB_imgA1C4_9[i][j])  
S4meanrefA1_1409 = np.array(S4meanrefA1_1409)
S4meanC4_109 = np.array(S4meanC4_109)

S4rgbrefA1_1409 = list()
S4rgbC4_109 = list()
for i in range(3):
     S4rgbrefA1_1409.append(S4meanrefA1_1409[:,i].mean())
     S4rgbC4_109.append(S4meanC4_109[:,i].mean())

# %%
S4meanrefA1_1509 = list()
S4meanD2_109 = list()
for i in range(S4RGB_imgA1D2_9.shape[0]): 
     for j in range(S4RGB_imgA1D2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1509.append(S4RGB_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_109.append(S4RGB_imgA1D2_9[i][j])  
S4meanrefA1_1509 = np.array(S4meanrefA1_1509)
S4meanD2_109 = np.array(S4meanD2_109)

S4rgbrefA1_1509 = list()
S4rgbD2_109 = list()
for i in range(3):
    S4rgbrefA1_1509.append(S4meanrefA1_1509[:,i].mean())
    S4rgbD2_109.append(S4meanD2_109[:,i].mean())

# %%
S4meanrefA1_1609 = list()
S4meanD3_109 = list()
for i in range(S4RGB_imgA1D3_9.shape[0]): 
     for j in range(S4RGB_imgA1D3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1609.append(S4RGB_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_109.append(S4RGB_imgA1D3_9[i][j])  
S4meanrefA1_1609 = np.array(S4meanrefA1_1609)
S4meanD3_109 = np.array(S4meanD3_109)

S4rgbrefA1_1609 = list()
S4rgbD3_109 = list()
for i in range(3):
    S4rgbrefA1_1609.append(S4meanrefA1_1609[:,i].mean())
    S4rgbD3_109.append(S4meanD3_109[:,i].mean())

# %%
S4meanrefA1_1709= list()
S4meanD4_109 = list()
for i in range(S4RGB_imgA1D4_9.shape[0]): 
     for j in range(S4RGB_imgA1D4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1709.append(S4RGB_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_109.append(S4RGB_imgA1D4_9[i][j])  
S4meanrefA1_1709 = np.array(S4meanrefA1_1409)
S4meanD4_109 = np.array(S4meanD4_109)

S4rgbrefA1_1709 = list()
S4rgbD4_109 = list()
for i in range(3):
    S4rgbrefA1_1709.append(S4meanrefA1_1709[:,i].mean())
    S4rgbD4_109.append(S4meanD4_109[:,i].mean())

# %% [markdown]
# ###Img 10

# %%
S4meanrefA1_110 = list()
S4meanA1_210 = list()
for i in range(S4RGB_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4RGB_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_110.append(S4RGB_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_210.append(S4RGB_imgA1A1_10[i][j])  
S4meanrefA1_110 = np.array(S4meanrefA1_110)
S4meanA1_210 = np.array(S4meanA1_210)

S4rgbrefA1_110 = list()
S4rgbA1_210 = list()
for i in range(3):
    S4rgbrefA1_110.append(S4meanrefA1_110[:,i].mean())
    S4rgbA1_210.append(S4meanA1_210[:,i].mean())
S4rgbrefA1_110,S4rgbA1_210

# %%
S4meanrefA1_310 = list()
S4meanA2_110 = list()
for i in range(S4RGB_imgA1A2_10.shape[0]): 
     for j in range(S4RGB_imgA1A2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_310.append(S4RGB_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanA2_110.append(S4RGB_imgA1A2_10[i][j])  
S4meanrefA1_310 = np.array(S4meanrefA1_310)
S4meanA2_110 = np.array(S4meanA2_110)

S4rgbrefA1_310 = list()
S4rgbA2_110 = list()
for i in range(3):
    S4rgbrefA1_310.append(S4meanrefA1_310[:,i].mean())
    S4rgbA2_110.append(S4meanA2_110[:,i].mean())

# %%
S4meanrefA1_410 = list()
S4meanA3_110 = list()
for i in range(S4RGB_imgA1A3_10.shape[0]): 
     for j in range(S4RGB_imgA1A3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_410.append(S4RGB_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_110.append(S4RGB_imgA1A3_10[i][j])  
S4meanrefA1_410 = np.array(S4meanrefA1_410)
S4meanA3_110 = np.array(S4meanA3_110)

S4rgbrefA1_410 = list()
S4rgbA3_110 = list()
for i in range(3):
    S4rgbrefA1_410.append(S4meanrefA1_410[:,i].mean())
    S4rgbA3_110.append(S4meanA3_110[:,i].mean())

# %%
S4meanrefA1_510 = list()
S4meanA3_5110 = list()
for i in range(S4RGB_imgA1A3_510.shape[0]): 
     for j in range(S4RGB_imgA1A3_510.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_510.append(S4RGB_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5110.append(S4RGB_imgA1A3_510[i][j])  
S4meanrefA1_510 = np.array(S4meanrefA1_510)
S4meanA3_5110 = np.array(S4meanA3_5110)

S4rgbrefA1_510 = list()
S4rgbA3_5110 = list()
for i in range(3):
    S4rgbrefA1_510.append(S4meanrefA1_51010[:,i].mean())
    S4rgbA3_5110.append(S4meanA3_511010[:,i].mean())

# %%
S4meanrefA1_610 = list()
S4meanA4_110 = list()
for i in range(S4RGB_imgA1A4_10.shape[0]): 
     for j in range(S4RGB_imgA1A4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_610.append(S4RGB_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_110.append(S4RGB_imgA1A4_10[i][j])  
S4meanrefA1_610 = np.array(S4meanrefA1_610)
S4meanA4_110 = np.array(S4meanA4_110)

S4rgbrefA1_610 = list()
S4rgbA4_110 = list()
for i in range(3):
    S4rgbrefA1_610.append(S4meanrefA1_610[:,i].mean())
    S4rgbA4_110.append(S4meanA4_110[:,i].mean())

# %%
S4meanrefA1_710 = list()
S4meanB1_110 = list()
for i in range(S4RGB_imgA1B1_10 .shape[0]): 
     for j in range(S4RGB_imgA1B1_10 .shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_710.append(S4RGB_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_110.append(S4RGB_imgA1B1_10 [i][j])  
S4meanrefA1_710 = np.array(S4meanrefA1_710)
S4meanB1_110 = np.array(S4meanB1_110)

S4rgbrefA1_710 = list()
S4rgbB1_110 = list()
for i in range(3):
    S4rgbrefA1_710.append(S4meanrefA1_710[:,i].mean())
    S4rgbB1_110.append(S4meanB1_110[:,i].mean())

# %%
S4meanrefA1_810 = list()
S4meanB2_110 = list()
for i in range(S4RGB_imgA1B2_10 .shape[0]): 
     for j in range(S4RGB_imgA1B2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_810.append(S4RGB_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_110.append(S4RGB_imgA1B2_10[i][j])  
S4meanrefA1_810 = np.array(S4meanrefA1_810)
S4meanB2_110 = np.array(S4meanB2_110)

S4rgbrefA1_810 = list()
S4rgbB2_110 = list()
for i in range(3):
    S4rgbrefA1_810.append(S4meanrefA1_810[:,i].mean())
    S4rgbB2_110.append(S4meanB2_110[:,i].mean())

# %%
S4meanrefA1_910 = list()
S4meanB3_110 = list()
for i in range(S4RGB_imgA1B3_10.shape[0]): 
     for j in range(S4RGB_imgA1B3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_910.append(S4RGB_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_110.append(S4RGB_imgA1B3_10[i][j])  
S4meanrefA1_910 = np.array(S4meanrefA1_910)
S4meanB3_110 = np.array(S4meanB3_110)

S4rgbrefA1_910 = list()
S4rgbB3_110 = list()
for i in range(3):
    S4rgbrefA1_910.append(S4meanrefA1_910[:,i].mean())
    S4rgbB3_110.append(S4meanB3_110[:,i].mean())

# %%
S4meanrefA1_1010 = list()
S4meanB4_110 = list()
for i in range(S4RGB_imgA1B4_10.shape[0]): 
     for j in range(S4RGB_imgA1B4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1010.append(S4RGB_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_110.append(S4RGB_imgA1B4_10[i][j])  
S4meanrefA1_1010 = np.array(S4meanrefA1_1010)
S4meanB4_110 = np.array(S4meanB4_110)

S4rgbrefA1_1010 = list()
S4rgbB4_110 = list()
for i in range(3):
    S4rgbrefA1_1010.append(S4meanrefA1_1010[:,i].mean())
    S4rgbB4_110.append(S4meanB4_110[:,i].mean())

# %%
S4meanrefA1_1110 = list()
S4meanC1_110 = list()
for i in range(S4RGB_imgA1C1_10.shape[0]): 
     for j in range(S4RGB_imgA1C1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1110.append(S4RGB_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_110.append(S4RGB_imgA1C1_10[i][j])  
S4meanrefA1_1110 = np.array(S4meanrefA1_1110)
S4meanC1_110 = np.array(S4meanC1_110)

S4rgbrefA1_1110 = list()
S4rgbC1_110 = list()
for i in range(3):
    S4rgbrefA1_1110.append(S4meanrefA1_1110[:,i].mean())
    S4rgbC1_110.append(S4meanC1_110[:,i].mean())

# %%
S4meanrefA1_1210 = list()
S4meanC2_110 = list()
for i in range(S4RGB_imgA1C2_10.shape[0]): 
     for j in range(S4RGB_imgA1C2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1210.append(S4RGB_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_110.append(S4RGB_imgA1C2_10[i][j])  
S4meanrefA1_1210 = np.array(S4meanrefA1_1210)
S4meanC2_110 = np.array(S4meanC2_110)

S4rgbrefA1_1210 = list()
S4rgbC2_110 = list()
for i in range(3):
     S4rgbrefA1_1210.append(S4meanrefA1_1210[:,i].mean())
     S4rgbC2_110.append(S4meanC2_110[:,i].mean())

# %%
S4meanrefA1_1310 = list()
S4meanC3_110 = list()
for i in range(S4RGB_imgA1C3_10.shape[0]): 
     for j in range(S4RGB_imgA1C3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1310.append(S4RGB_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_110.append(S4RGB_imgA1C3_10[i][j])  
S4meanrefA1_1310 = np.array(S4meanrefA1_1310)
S4meanC3_110 = np.array(S4meanC3_110)

S4rgbrefA1_1310 = list()
S4rgbC3_110 = list()
for i in range(3):
    S4rgbrefA1_1310.append(S4meanrefA1_1310[:,i].mean())
    S4rgbC3_110.append(S4meanC3_110[:,i].mean())

# %%
S4meanrefA1_1410 = list()
S4meanC4_110 = list()
for i in range(S3RGB_imgA1C4_10.shape[0]): 
     for j in range(S3RGB_imgA1C4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1410.append(S4RGB_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_110.append(S4RGB_imgA1C4_10[i][j])  
S4meanrefA1_1410 = np.array(S4meanrefA1_1410)
S4meanC4_110 = np.array(S4meanC4_110)

S4rgbrefA1_1410 = list()
S4rgbC4_110 = list()
for i in range(3):
     S4rgbrefA1_1410.append(S4meanrefA1_1410[:,i].mean())
     S4rgbC4_110.append(S4meanC4_110[:,i].mean())

# %%
S4meanrefA1_1510 = list()
S4meanD2_110 = list()
for i in range(S4RGB_imgA1D2_10.shape[0]): 
     for j in range(S4RGB_imgA1D2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1510.append(S4RGB_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_110.append(S4RGB_imgA1D2_10[i][j])  
S4meanrefA1_1510 = np.array(S4meanrefA1_1510)
S4meanD2_110 = np.array(S4meanD2_110)

S4rgbrefA1_1510 = list()
S4rgbD2_110 = list()
for i in range(3):
     S4rgbrefA1_1510.append(S4meanrefA1_1510[:,i].mean())
     S4rgbD2_110.append(S4meanD2_110[:,i].mean())

# %%
S4meanrefA1_1610 = list()
S4meanD3_110 = list()
for i in range(S4RGB_imgA1D3_10.shape[0]): 
     for j in range(S4RGB_imgA1D3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1610.append(S4RGB_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanD3_110.append(S4RGB_imgA1D3_10[i][j])  
S4meanrefA1_1610 = np.array(S4meanrefA1_1610)
S4meanD3_110 = np.array(S4meanD3_110)

S4rgbrefA1_1610 = list()
S4rgbD3_110 = list()
for i in range(3):
    S4rgbrefA1_1610.append(S4meanrefA1_1610[:,i].mean())
    S4rgbD3_110.append(S4meanD3_110[:,i].mean())

# %%
S4meanrefA1_1710= list()
S4meanD4_110 = list()
for i in range(S4RGB_imgA1D4_10.shape[0]): 
     for j in range(S4RGB_imgA1D4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1710.append(S4RGB_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_110.append(S4RGB_imgA1D4_10[i][j])  
S4meanrefA1_1710 = np.array(S4meanrefA1_1410)
S4meanD4_110 = np.array(S4meanD4_110)

S4rgbrefA1_1710 = list()
S4rgbD4_110 = list()
for i in range(3):
    S4rgbrefA1_1710.append(S4meanrefA1_1710[:,i].mean())
    S4rgbD4_110.append(S4meanD4_110[:,i].mean())

# %% [markdown]
# ###HSV

# %%
S4meanrefA1_1 = list()
S4meanA1_2 = list()
for i in range(S4HSV_imgA1A1_1.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_1.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1.append(S4HSV_imgA1A1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_2.append(S4HSV_imgA1A1_1[i][j])  
S4meanrefA1_1 = np.array(S4meanrefA1_1)
S4meanA1_2 = np.array(S4meanA1_2)

S4hsvrefA1_1 = list() 
S4hsvA1_2 = list()
for i in range(3):
    S4hsvrefA1_1.append(S4meanrefA1_1[:,i].mean())
    S4hsvA1_2.append(S4meanA1_2[:,i].mean())

# %%
S4meanrefA1_3 = list()
S4meanA2_1 = list()
for i in range(S4HSV_imgA1A2_1.shape[0]): 
     for j in range(S4HSV_imgA1A2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_3.append(S4HSV_imgA1A2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_1.append(S4HSV_imgA1A2_1[i][j])  
S4meanrefA1_3 = np.array(S4meanrefA1_3)
S4meanA2_1 = np.array(S4meanA2_1)

S4hsvrefA1_3 = list()
S4hsvA2_1 = list()
for i in range(3):
    S4hsvrefA1_3.append(S4meanrefA1_3[:,i].mean())
    S4hsvA2_1.append(S4meanA2_1[:,i].mean())

# %%
S4meanrefA1_4 = list()
S4meanA3_1 = list()
for i in range(S4HSV_imgA1A3_1.shape[0]): 
     for j in range(S4HSV_imgA1A3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_4.append(S4HSV_imgA1A3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_1.append(S4HSV_imgA1A3_1[i][j])  
S4meanrefA1_4 = np.array(S4meanrefA1_4)
S4meanA3_1 = np.array(S4meanA3_1)

S4hsvrefA1_4 = list()
S4hsvA3_1 = list()
for i in range(3):
    S4hsvrefA1_4.append(S4meanrefA1_4[:,i].mean())
    S4hsvA3_1.append(S4meanA3_1[:,i].mean())

# %%
S4meanrefA1_5 = list()
S4meanA3_51 = list()
for i in range(S4HSV_imgA1A3_51.shape[0]): 
     for j in range(S4HSV_imgA1A3_51.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_5.append(S4HSV_imgA1A3_51[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_51.append(S4HSV_imgA1A3_51[i][j])  
S4meanrefA1_5 = np.array(S4meanrefA1_5)
S4meanA3_51 = np.array(S4meanA3_51)

S4hsvrefA1_5 = list()
S4hsvA3_51 = list()
for i in range(3):
    S4hsvrefA1_5.append(S4meanrefA1_5[:,i].mean())
    S4hsvA3_51.append(S4meanA3_51[:,i].mean())

# %%
S4meanrefA1_6 = list()
S4meanA4_1 = list()
for i in range(S4HSV_imgA1A4_1.shape[0]): 
     for j in range(S4HSV_imgA1A4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_6.append(S4HSV_imgA1A4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_1.append(S4HSV_imgA1A4_1[i][j])  
S4meanrefA1_6 = np.array(S4meanrefA1_6)
S4meanA4_1 = np.array(S4meanA4_1)

S4hsvrefA1_6 = list()
S4hsvA4_1 = list()
for i in range(3):
    S4hsvrefA1_6.append(S4meanrefA1_6[:,i].mean())
    S4hsvA4_1.append(S4meanA4_1[:,i].mean())

# %%
S4meanrefA1_7 = list()
S4meanB1_1 = list()
for i in range(S4HSV_imgA1B1_1.shape[0]): 
     for j in range(S4HSV_imgA1B1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_7.append(S4HSV_imgA1B1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_1.append(S4HSV_imgA1B1_1[i][j])  
S4meanrefA1_7 = np.array(S4meanrefA1_7)
S4meanB1_1 = np.array(S4meanB1_1)

S4hsvrefA1_7 = list()
S4hsvB1_1 = list()
for i in range(3):
    S4hsvrefA1_7.append(S4meanrefA1_7[:,i].mean())
    S4hsvB1_1.append(S4meanB1_1[:,i].mean())

# %%
S4meanrefA1_8 = list()
S4meanB2_1 = list()
for i in range(S4HSV_imgA1B2_1.shape[0]): 
     for j in range(S4HSV_imgA1B2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_8.append(S4HSV_imgA1B2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_1.append(S4HSV_imgA1B2_1[i][j])  
S4meanrefA1_8 = np.array(S4meanrefA1_8)
S4meanB2_1 = np.array(S4meanB2_1)

S4hsvrefA1_8 = list()
S4hsvB2_1 = list()
for i in range(3):
    S4hsvrefA1_8.append(S4meanrefA1_8[:,i].mean())
    S4hsvB2_1.append(S4meanB2_1[:,i].mean())

# %%
S4meanrefA1_9 = list()
S4meanB3_1 = list()
for i in range(S4HSV_imgA1B3_1.shape[0]): 
     for j in range(S4HSV_imgA1B3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_9.append(S4HSV_imgA1B3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_1.append(S4HSV_imgA1B3_1[i][j])  
S4meanrefA1_9 = np.array(S4meanrefA1_9)
S4meanB3_1 = np.array(S4meanB3_1)

S4hsvrefA1_9 = list()
S4hsvB3_1 = list()
for i in range(3):
    S4hsvrefA1_9.append(S4meanrefA1_9[:,i].mean())
    S4hsvB3_1.append(S4meanB3_1[:,i].mean())

# %%
S4meanrefA1_10 = list()
S4meanB4_1 = list()
for i in range(S4HSV_imgA1B4_1.shape[0]): 
     for j in range(S4HSV_imgA1B4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_10.append(S4HSV_imgA1B4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_1.append(S4HSV_imgA1B4_1[i][j])  
S4meanrefA1_10 = np.array(S4meanrefA1_10)
S4meanB4_1 = np.array(S4meanB4_1)

S4hsvrefA1_10 = list()
S4hsvB4_1 = list()
for i in range(3):
    S4hsvrefA1_10.append(S4meanrefA1_10[:,i].mean())
    S4hsvB4_1.append(S4meanB4_1[:,i].mean())

# %%
S4meanrefA1_11 = list()
S4meanC1_1 = list()
for i in range(S4HSV_imgA1C1_1.shape[0]): 
     for j in range(S4HSV_imgA1C1_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_11.append(S4HSV_imgA1C1_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_1.append(S4HSV_imgA1C1_1[i][j])  
S4meanrefA1_11 = np.array(S4meanrefA1_11)
S4meanC1_1 = np.array(S4meanC1_1)

S4hsvrefA1_11 = list()
S4hsvC1_1 = list()
for i in range(3):
    S4hsvrefA1_11.append(S4meanrefA1_11[:,i].mean())
    S4hsvC1_1.append(S4meanC1_1[:,i].mean())

# %%
S4meanrefA1_12 = list()
S4meanC2_1 = list()
for i in range(S4HSV_imgA1C2_1.shape[0]): 
     for j in range(S4HSV_imgA1C2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_12.append(S4HSV_imgA1C2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_1.append(S4HSV_imgA1C2_1[i][j])  
S4meanrefA1_12 = np.array(S4meanrefA1_12)
S4meanC2_1 = np.array(S4meanC2_1)

S4hsvrefA1_12 = list()
S4hsvC2_1 = list()
for i in range(3):
    S4hsvrefA1_12.append(S4meanrefA1_12[:,i].mean())
    S4hsvC2_1.append(S4meanC2_1[:,i].mean())

# %%
S4meanrefA1_13 = list()
S4meanC3_1 = list()
for i in range(S4HSV_imgA1C3_1.shape[0]): 
     for j in range(S4HSV_imgA1C3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_13.append(S4HSV_imgA1C3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_1.append(S4HSV_imgA1C3_1[i][j])  
S4meanrefA1_13 = np.array(S4meanrefA1_13)
S4meanC3_1 = np.array(S4meanC3_1)

S4hsvrefA1_13 = list()
S4hsvC3_1 = list()
for i in range(3):
    S4hsvrefA1_13.append(S4meanrefA1_13[:,i].mean())
    S4hsvC3_1.append(S4meanC3_1[:,i].mean())

# %%
S4meanrefA1_14 = list()
S4meanC4_1 = list()
for i in range(S4HSV_imgA1C4_1.shape[0]): 
     for j in range(S4HSV_imgA1C4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_14.append(S4HSV_imgA1C4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_1.append(S4HSV_imgA1C4_1[i][j])  
S4meanrefA1_14 = np.array(S4meanrefA1_14)
S4meanC4_1 = np.array(S4meanC4_1)

S4hsvrefA1_14 = list()
S4hsvC4_1 = list()
for i in range(3):
    S4hsvrefA1_14.append(S4meanrefA1_14[:,i].mean())
    S4hsvC4_1.append(S4meanC4_1[:,i].mean())

# %%
S4meanrefA1_15 = list()
S4meanD2_1 = list()
for i in range(S4HSV_imgA1D2_1.shape[0]): 
     for j in range(S4HSV_imgA1D2_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_15.append(S4HSV_imgA1D2_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_1.append(S4HSV_imgA1D2_1[i][j])  
S4meanrefA1_15 = np.array(S4meanrefA1_15)
S4meanD2_1 = np.array(S4meanD2_1)

S4hsvrefA1_15 = list()
S4hsvD2_1 = list()
for i in range(3):
    S4hsvrefA1_15.append(S4meanrefA1_15[:,i].mean())
    S4hsvD2_1.append(S4meanD2_1[:,i].mean())

# %%
S4meanrefA1_16 = list()
S4meanD3_1 = list()
for i in range(S4HSV_imgA1D3_1.shape[0]): 
     for j in range(S4HSV_imgA1D3_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_16.append(S4HSV_imgA1D3_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_1.append(S4HSV_imgA1D3_1[i][j])  
S4meanrefA1_16 = np.array(S4meanrefA1_16)
S4meanD3_1 = np.array(S4meanD3_1)

S4hsvrefA1_16 = list()
S4hsvD3_1 = list()
for i in range(3):
    S4hsvrefA1_16.append(S4meanrefA1_16[:,i].mean())
    S4hsvD3_1.append(S4meanD3_1[:,i].mean())

# %%
S4meanrefA1_17= list()
S4meanD4_1 = list()
for i in range(S4HSV_imgA1D4_1.shape[0]): 
     for j in range(S4HSV_imgA1D4_1.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_17.append(S4HSV_imgA1D4_1[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_1.append(S4HSV_imgA1D4_1[i][j])  
S4meanrefA1_17 = np.array(S4meanrefA1_14)
S4meanD4_1 = np.array(S4meanD4_1)

S4hsvrefA1_17 = list()
S4hsvD4_1 = list()
for i in range(3):
    S4hsvrefA1_17.append(S4meanrefA1_17[:,i].mean())
    S4hsvD4_1.append(S4meanD4_1[:,i].mean())

# %% [markdown]
# ###Img 2

# %%
S4meanrefA1_102 = list()
S4meanA1_202 = list()
for i in range(S4HSV_imgA1A1_2.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_2.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_102.append(S4HSV_imgA1A1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_202.append(S4HSV_imgA1A1_2[i][j])  
S4meanrefA1_102= np.array(S4meanrefA1_102)
S4meanA1_202 = np.array(S4meanA1_202)

S4hsvrefA1_102 = list()
S4hsvA1_202 = list()
for i in range(3):
    S4hsvrefA1_102.append(S4meanrefA1_1[:,i].mean())
    S4hsvA1_202.append(S4meanA1_2[:,i].mean())
S4hsvrefA1_102,S4hsvA1_202

# %%
S4meanrefA1_302 = list()
S4meanA2_102 = list()
for i in range(S4HSV_imgA1A2_2.shape[0]): 
     for j in range(S4HSV_imgA1A2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_302.append(S4HSV_imgA1A2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_102.append(S4HSV_imgA1A2_2[i][j])  
S4meanrefA1_302 = np.array(S4meanrefA1_3)
S4meanA2_102 = np.array(S4meanA2_1)

S4hsvrefA1_302 = list()
S4hsvA2_102 = list()
for i in range(3):
    S4hsvrefA1_302.append(S4meanrefA1_302[:,i].mean())
    S4hsvA2_102.append(S4meanA2_102[:,i].mean())

# %%
S4meanrefA1_402 = list()
S4meanA3_102 = list()
for i in range(S4HSV_imgA1A3_2.shape[0]): 
     for j in range(S4HSV_imgA1A3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_402.append(S4HSV_imgA1A3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_102.append(S4HSV_imgA1A3_2[i][j])  
S4meanrefA1_402= np.array(S4meanrefA1_402)
S4meanA3_102 = np.array(S4meanA3_102)

S4hsvrefA1_402 = list()
S4hsvA3_102 = list()
for i in range(3):
    S4hsvrefA1_402.append(S4meanrefA1_402[:,i].mean())
    S4hsvA3_102.append(S4meanA3_102[:,i].mean())

# %%
S4meanrefA1_502 = list()
S4meanA3_5102 = list()
for i in range(S4HSV_imgA1A3_52.shape[0]): 
     for j in range(S4HSV_imgA1A3_52.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_502.append(S4HSV_imgA1A3_52[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5102.append(S4HSV_imgA1A3_52[i][j])  
S4meanrefA1_502 = np.array(S4meanrefA1_502)
S4meanA3_5102 = np.array(S4meanA3_5102)

S4hsvrefA1_502 = list()
S4hsvA3_5102 = list()
for i in range(3):
    S4hsvrefA1_502.append(S4meanrefA1_502[:,i].mean())
    S4hsvA3_5102.append(S4meanA3_5102[:,i].mean())

# %%
S4meanrefA1_602 = list()
S4meanA4_102 = list()
for i in range(S4HSV_imgA1A4_2.shape[0]): 
     for j in range(S4HSV_imgA1A4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_602.append(S4HSV_imgA1A4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_102.append(S4HSV_imgA1A4_2[i][j])  
S4meanrefA1_602 = np.array(S4meanrefA1_602)
S4meanA4_102 = np.array(S4meanA4_102)

S4hsvrefA1_602 = list()
S4hsvA4_102 = list()
for i in range(3):
    S4hsvrefA1_602.append(S4meanrefA1_602[:,i].mean())
    S4hsvA4_102.append(S4meanA4_102[:,i].mean())

# %%
S4meanrefA1_702 = list()
S4meanB1_102 = list()
for i in range(S4HSV_imgA1B1_2.shape[0]): 
     for j in range(S4HSV_imgA1B1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_702.append(S4HSV_imgA1B1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_102.append(S4HSV_imgA1B1_2[i][j])  
S4meanrefA1_702 = np.array(S4meanrefA1_702)
S4meanB1_102 = np.array(S4meanB1_102)

S4hsvrefA1_702 = list()
S4hsvB1_102 = list()
for i in range(3):
    S4hsvrefA1_702.append(S4meanrefA1_702[:,i].mean())
    S4hsvB1_102.append(S4meanB1_102[:,i].mean())

# %%
S4meanrefA1_802 = list()
S4meanB2_102 = list()
for i in range(S4HSV_imgA1B2_2.shape[0]): 
     for j in range(S4HSV_imgA1B2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_802.append(S4HSV_imgA1B2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_102.append(S4HSV_imgA1B2_2[i][j])  
S4meanrefA1_802 = np.array(S4meanrefA1_802)
S4meanB2_102 = np.array(S4meanB2_102)

S4hsvrefA1_802 = list()
S4hsvB2_102 = list()
for i in range(3):
    S4hsvrefA1_802.append(S4meanrefA1_802[:,i].mean())
    S4hsvB2_102.append(S4meanB2_102[:,i].mean())

# %%
S4meanrefA1_902 = list()
S4meanB3_102 = list()
for i in range(S4HSV_imgA1B3_2.shape[0]): 
     for j in range(S4HSV_imgA1B3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_902.append(S4HSV_imgA1B3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_102.append(S4HSV_imgA1B3_2[i][j])  
S4meanrefA1_902 = np.array(S4meanrefA1_902)
S4meanB3_102 = np.array(S4meanB3_102)

S4hsvrefA1_902 = list()
S4hsvB3_102 = list()
for i in range(3):
    S4hsvrefA1_902.append(S4meanrefA1_902[:,i].mean())
    S4hsvB3_102.append(S4meanB3_102[:,i].mean())

# %%
S4meanrefA1_1002 = list()
S4meanB4_102 = list()
for i in range(S4HSV_imgA1B4_2.shape[0]): 
     for j in range(S4HSV_imgA1B4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1002.append(S4HSV_imgA1B4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_102.append(S4HSV_imgA1B4_2[i][j])  
S4meanrefA1_1002 = np.array(S4meanrefA1_1002)
S4meanB4_102 = np.array(S4meanB4_102)

S4hsvrefA1_1002 = list()
S4hsvB4_102 = list()
for i in range(3):
    S4hsvrefA1_10.append(S4meanrefA1_10[:,i].mean())
    S4hsvB4_1.append(S4meanB4_1[:,i].mean())

# %%
S4meanrefA1_1102 = list()
S4meanC1_102 = list()
for i in range(S4HSV_imgA1C1_2.shape[0]): 
     for j in range(S4HSV_imgA1C1_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1102.append(S4HSV_imgA1C1_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_102.append(S4HSV_imgA1C1_2[i][j])  
S4meanrefA1_1102 = np.array(S4meanrefA1_1102)
S4meanC1_102= np.array(S4meanC1_102)

S4hsvrefA1_1102 = list()
S4hsvC1_102 = list()
for i in range(3):
    S4hsvrefA1_1102.append(S4meanrefA1_1102[:,i].mean())
    S4hsvC1_102.append(S4meanC1_102[:,i].mean())

# %%
S4meanrefA1_1202 = list()
S4meanC2_102 = list()
for i in range(S4HSV_imgA1C2_2.shape[0]): 
     for j in range(S4HSV_imgA1C2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1202.append(S4HSV_imgA1C2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_102.append(S4HSV_imgA1C2_2[i][j])  
S4meanrefA1_1202 = np.array(S4meanrefA1_1202)
S4meanC2_102 = np.array(S4meanC2_102)

S4hsvrefA1_1202 = list()
S4hsvC2_102 = list()
for i in range(3):
    S4hsvrefA1_1202.append(S4meanrefA1_1202[:,i].mean())
    S4hsvC2_102.append(S4meanC2_102[:,i].mean())

# %%
S4meanrefA1_1302 = list()
S4meanC3_102 = list()
for i in range(S4HSV_imgA1C3_.shape[0]): 
     for j in range(S4HSV_imgA1C3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1302.append(S4HSV_imgA1C3_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_102.append(S4HSV_imgA1C3_[i][j])  
S4meanrefA1_1302 = np.array(S4meanrefA1_1302)
S4meanC3_102 = np.array(S4meanC3_102)

S4hsvrefA1_1302 = list()
S4hsvC3_102 = list()
for i in range(3):
    S4hsvrefA1_1302.append(S4meanrefA1_1302[:,i].mean())
    S4hsvC3_102.append(S4meanC3_102[:,i].mean())

# %%
S4meanrefA1_1402 = list()
S4meanC4_102 = list()
for i in range(S4HSV_imgA1C4_2.shape[0]): 
     for j in range(S4HSV_imgA1C4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1402.append(S4HSV_imgA1C4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_102.append(S4HSV_imgA1C4_2[i][j])  
S4meanrefA1_1402 = np.array(S4meanrefA1_1402)
S4meanC4_102 = np.array(S4meanC4_102)

S4hsvrefA1_1402 = list()
S4hsvC4_102 = list()
for i in range(3):
    S4hsvrefA1_1402.append(S4meanrefA1_1402[:,i].mean())
    S4hsvC4_102.append(S4meanC4_102[:,i].mean())

# %%
S4meanrefA1_1502 = list()
S4meanD2_102 = list()
for i in range(S4HSV_imgA1D2_2.shape[0]): 
     for j in range(S4HSV_imgA1D2_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1502.append(S4HSV_imgA1D2_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_102.append(S4HSV_imgA1D2_2[i][j])  
S4meanrefA1_1502 = np.array(S4meanrefA1_1502)
S4meanD2_102 = np.array(S4meanD2_102)

S4hsvrefA1_1502 = list()
S4hsvD2_102 = list()
for i in range(3):
    S4hsvrefA1_1502.append(S4meanrefA1_1502[:,i].mean())
    S4hsvD2_102.append(S4meanD2_102[:,i].mean())

# %%
S4meanrefA1_1602 = list()
S4meanD3_102 = list()
for i in range(S4HSV_imgA1D3_2.shape[0]): 
     for j in range(S4HSV_imgA1D3_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1602.append(S4HSV_imgA1D3_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_102.append(S4HSV_imgA1D3_2[i][j])  
S4meanrefA1_1602 = np.array(S4meanrefA1_1602)
S4meanD3_102 = np.array(S4meanD3_102)

S4hsvrefA1_1602 = list()
S4hsvD3_102 = list()
for i in range(3):
    S4hsvrefA1_1602.append(S4meanrefA1_1602[:,i].mean())
    S4hsvD3_102.append(S4meanD3_102[:,i].mean())

# %%
S4meanrefA1_1702= list()
S4meanD4_102 = list()
for i in range(S4HSV_imgA1D4_2.shape[0]): 
     for j in range(S4HSV_imgA1D4_2.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1702.append(S4HSV_imgA1D4_2[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_102.append(S4HSV_imgA1D4_2[i][j])  
S4meanrefA1_1702 = np.array(S4meanrefA1_1702)
S4meanD4_102 = np.array(S4meanD4_102)

S4hsvrefA1_1702 = list()
S4hsvD4_102 = list()
for i in range(3):
    S4hsvrefA1_1702.append(S4meanrefA1_1702[:,i].mean())
    S4hsvD4_102.append(S4meanD4_102[:,i].mean())

# %% [markdown]
# ###Img 3

# %%
S4meanrefA1_103 = list()
S4meanA1_203 = list()
for i in range(S4HSV_imgA1A1_3.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_3.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_103.append(S4HSV_imgA1A1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_203.append(S4HSV_imgA1A1_3[i][j])  
S4meanrefA1_103 = np.array(S4meanrefA1_103)
S4meanA1_203 = np.array(S4meanA1_203)

S4hsvrefA1_103 = list()
S4hsvA1_203 = list()
for i in range(3):
    S4hsvrefA1_103.append(S4meanrefA1_103[:,i].mean())
    S4hsvA1_203.append(S4meanA1_203[:,i].mean())
S4hsvrefA1_103,S4hsvA1_203

# %%
S4meanrefA1_303 = list()
S4meanA2_103 = list()
for i in range(S4HSV_imgA1A2_3.shape[0]): 
     for j in range(S4HSV_imgA1A2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_303.append(S4HSV_imgA1A2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_103.append(S4HSV_imgA1A2_3[i][j])  
S4meanrefA1_303 = np.array(S4meanrefA1_303)
S4meanA2_103 = np.array(S4meanA2_103)

S4hsvrefA1_303 = list()
S4hsvA2_103 = list()
for i in range(3):
    S4hsvrefA1_303.append(S4meanrefA1_303[:,i].mean())
    S4hsvA2_103.append(S4meanA2_103[:,i].mean())

# %%
S4meanrefA1_403 = list()
S4meanA3_103 = list()
for i in range(S4HSV_imgA1A3_3.shape[0]): 
     for j in range(S4HSV_imgA1A3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_403append(S4HSV_imgA1A3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_103.append(S4HSV_imgA1A3_3[i][j])  
S4meanrefA1_403 = np.array(S4meanrefA1_403)
S4meanA3_103 = np.array(S4meanA3_103)

S4hsvrefA1_403 = list()
S4hsvA3_103 = list()
for i in range(3):
    S4hsvrefA1_403.append(S4meanrefA1_403[:,i].mean())
    S4hsvA3_103.append(S4meanA3_103[:,i].mean())

# %%
S4meanrefA1_503 = list()
S4meanA3_5103 = list()
for i in range(S4HSV_imgA1A3_53.shape[0]): 
     for j in range(S4HSV_imgA1A3_53.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_503.append(S4HSV_imgA1A3_53[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5103.append(S4HSV_imgA1A3_53[i][j])  
S4meanrefA1_503 = np.array(S4meanrefA1_503)
S4meanA3_5103 = np.array(S4meanA3_5103)

S4hsvrefA1_503 = list()
S4hsvA3_5103 = list()
for i in range(3):
    S4hsvrefA1_503.append(S4meanrefA1_503[:,i].mean())
    S4hsvA3_5103.append(S4meanA3_5103[:,i].mean())

# %%
S4meanrefA1_603 = list()
S4meanA4_103 = list()
for i in range(S4HSV_imgA1A4_303.shape[0]): 
     for j in range(S4HSV_imgA1A4_303.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_603.append(S4HSV_imgA1A4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_103.append(S4HSV_imgA1A4_3[i][j])  
S4meanrefA1_603 = np.array(S4meanrefA1_603)
S4meanA4_103 = np.array(S4meanA4_103)

S4hsvrefA1_603 = list()
S4hsvA4_103 = list()
for i in range(3):
    S4hsvrefA1_603.append(S4meanrefA1_603[:,i].mean())
    S4hsvA4_103.append(S4meanA4_103[:,i].mean())

# %%
S4meanrefA1_703 = list()
S4meanB1_103 = list()
for i in range(S4HSV_imgA1B1_3.shape[0]): 
     for j in range(S4HSV_imgA1B1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_703.append(S4HSV_imgA1B1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_103.append(S4HSV_imgA1B1_3[i][j])  
S4meanrefA1_703 = np.array(S4meanrefA1_703)
S4meanB1_103 = np.array(S4meanB1_103)

S4hsvrefA1_703 = list()
S4hsvB1_103 = list()
for i in range(3):
    S4hsvrefA1_703.append(S4meanrefA1_703[:,i].mean())
    S4hsvB1_103.append(S4meanB1_103[:,i].mean())

# %%
S4meanrefA1_803 = list()
S4meanB2_103 = list()
for i in range(S4HSV_imgA1B2_3.shape[0]): 
     for j in range(S4HSV_imgA1B2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_803.append(S4HSV_imgA1B2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_103.append(S4HSV_imgA1B2_3[i][j])  
S4meanrefA1_803 = np.array(S4meanrefA1_803)
S4meanB2_103 = np.array(S4meanB2_103

S4hsvrefA1_803 = list()
S4hsvB2_103 = list()
for i in range(3):
    S4hsvrefA1_8.append(S4meanrefA1_803[:,i].mean())
    S4hsvB2_1.append(S4meanB2_103[:,i].mean())

# %%
S4meanrefA1_903 = list()
S4meanB3_103 = list()
for i in range(S4HSV_imgA1B3_3.shape[0]): 
     for j in range(S4HSV_imgA1B3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_903.append(S4HSV_imgA1B3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_103.append(S4HSV_imgA1B3_3[i][j])  
S4meanrefA1_903 = np.array(S4meanrefA1_903)
S4meanB3_103 = np.array(S4meanB3_103)

S4hsvrefA1_903 = list()
S4hsvB3_103 = list()
for i in range(3):
    S4hsvrefA1_903.append(S4meanrefA1_9[:,i].mean())
    S4hsvB3_103.append(S4meanB3_1[:,i].mean())

# %%
S4meanrefA1_1003 = list()
S4meanB4_103 = list()
for i in range(S4HSV_imgA1B4_3.shape[0]): 
     for j in range(S4HSV_imgA1B4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1003.append(S4HSV_imgA1B4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_103.append(S4HSV_imgA1B4_3[i][j])  
S4meanrefA1_1003 = np.array(S4meanrefA1_1003)
S4meanB4_103 = np.array(S4meanB4_103)

S4hsvrefA1_1003 = list()
S4hsvB4_103 = list()
for i in range(3):
    S4hsvrefA1_1003.append(S4meanrefA1_1003[:,i].mean())
    S4hsvB4_103.append(S4meanB4_103[:,i].mean())

# %%
S4meanrefA1_1103 = list()
S4meanC1_103 = list()
for i in range(S4HSV_imgA1C1_3.shape[0]): 
     for j in range(S4HSV_imgA1C1_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1103.append(S4HSV_imgA1C1_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_103.append(S4HSV_imgA1C1_3[i][j])  
S4meanrefA1_1103 = np.array(S4meanrefA1_1103)
S4meanC1_103 = np.array(S4meanC1_103)

S4hsvrefA1_11 = list()
S4hsvC1_103 = list()
for i in range(3):
    S4hsvrefA1_1103.append(S4meanrefA1_1103[:,i].mean())
    S4hsvC1_103.append(S4meanC1_103[:,i].mean())

# %%
S4meanrefA1_1203 = list()
S4meanC2_103 = list()
for i in range(S4HSV_imgA1C2_3.shape[0]): 
     for j in range(S4HSV_imgA1C2_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1203.append(S4HSV_imgA1C2_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_103.append(S4HSV_imgA1C2_3[i][j])  
S4meanrefA1_1203 = np.array(S4meanrefA1_1203)
S4meanC2_103 = np.array(S4meanC2_103)

S4hsvrefA1_1203 = list()
S4hsvC2_103 = list()
for i in range(3):
    S4hsvrefA1_1203.append(S4meanrefA1_1203[:,i].mean())
    S4hsvC2_103.append(S4meanC2_103[:,i].mean())

# %%
S4meanrefA1_1303 = list()
S4meanC3_103 = list()
for i in range(S4HSV_imgA1C3_3.shape[0]): 
     for j in range(S4HSV_imgA1C3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1303.append(S4HSV_imgA1C3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_103.append(S4HSV_imgA1C3_3[i][j])  
S4meanrefA1_1303 = np.array(S4meanrefA1_130303)
S4meanC3_103 = np.array(S4meanC3_103)

S4hsvrefA1_1303 = list()
S4hsvC3_103 = list()
for i in range(3):
    S4hsvrefA1_1303.append(S4meanrefA1_1303[:,i].mean())
    S4hsvC3_103.append(S4meanC3_103[:,i].mean())

# %%
S4meanrefA1_1403 = list()
S4meanC4_103 = list()
for i in range(S4HSV_imgA1C4_3.shape[0]): 
     for j in range(S4HSV_imgA1C4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_14.append(S4HSV_imgA1C4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_103.append(S4HSV_imgA1C4_3[i][j])  
S4meanrefA1_1403 = np.array(S4meanrefA1_1403)
S4meanC4_103 = np.array(S4meanC4_103)

S4hsvrefA1_1403 = list()
S4hsvC4_103 = list()
for i in range(3):
    S4hsvrefA1_1403.append(S4meanrefA1_1403[:,i].mean())
    S4hsvC4_103.append(S4meanC4_103[:,i].mean())

# %%
S4meanrefA1_1503 = list()
S4meanD2_103 = list()
for i in range(S4HSV_imgA1D2_303.shape[0]): 
     for j in range(S4HSV_imgA1D2_303.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1503.append(S4HSV_imgA1D2_303[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_103.append(S4HSV_imgA1D2_303[i][j])  
S4meanrefA1_1503 = np.array(S4meanrefA1_1503)
S41meanD2_103 = np.array(S4meanD2_103)

S4hsvrefA1_1503 = list()
S4hsvD2_103 = list()
for i in range(3):
    S4hsvrefA1_1503.append(S4meanrefA1_1503[:,i].mean())
    S4hsvD2_103.append(S4meanD2_103[:,i].mean())

# %%
S4meanrefA1_1603 = list()
S4meanD3_103 = list()
for i in range(S4HSV_imgA1D3_3.shape[0]): 
     for j in range(S4HSV_imgA1D3_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_16.append(S4HSV_imgA1D3_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_1.append(S4HSV_imgA1D3_3[i][j])  
S4meanrefA1_1603 = np.array(S4meanrefA1_1603)
S4meanD3_103 = np.array(S4meanD3_103)

S4hsvrefA1_1603 = list()
S4hsvD3_103 = list()
for i in range(3):
    S4hsvrefA1_1603.append(S4meanrefA1_1603[:,i].mean())
    S41svD3_103.append(S4meanD3_103[:,i].mean())

# %%
S4meanrefA1_1703= list()
S4meanD4_103 = list()
for i in range(S4HSV_imgA1D4_3.shape[0]): 
     for j in range(S4HSV_imgA1D4_3.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1703.append(S4HSV_imgA1D4_3[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_103.append(S4HSV_imgA1D4_3[i][j])  
S4meanrefA1_1703 = np.array(S4meanrefA1_1403)
S4meanD4_103 = np.array(S4meanD4_103)

S4hsvrefA1_1703 = list()
S4hsvD4_103 = list()
for i in range(3):
    S4hsvrefA1_1703.append(S4meanrefA1_1703[:,i].mean())
    S4hsvD4_103.append(S4meanD4_103[:,i].mean())

# %% [markdown]
# ###Img 4

# %%
S4meanrefA1_104 = list()
S4meanA1_204 = list()
for i in range(S4HSV_imgA1A1_4.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_4.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_104.append(S4HSV_imgA1A1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_204.append(S4HSV_imgA1A1_[i][j])  
S4meanrefA1_104 = np.array(S4meanrefA1_104)
S4meanA1_204 = np.array(S4meanA1_204)

S4hsvrefA1_104 = list()
S4hsvA1_204 = list()
for i in range(3):
    S4hsvrefA1_104.append(S4meanrefA1_104[:,i].mean())
    S4hsvA1_204.append(S4meanA1_204[:,i].mean())
S4hsvrefA1_104,S4hsvA1_204

# %%
S4meanrefA1_304 = list()
S4meanA2_104 = list()
for i in range(S4HSV_imgA1A2_4.shape[0]): 
     for j in range(S4HSV_imgA1A2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_304.append(S4HSV_imgA1A2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_104.append(S4HSV_imgA1A2_4[i][j])  
S4meanrefA1_304 = np.array(S4meanrefA1_304)
S4meanA2_104 = np.array(S4meanA2_104)

S4hsvrefA1_304 = list()
S4hsvA2_104 = list()
for i in range(3):
    S4hsvrefA1_304.append(S4meanrefA1_304[:,i].mean())
    S4hsvA2_104.append(S4meanA2_104[:,i].mean())

# %%
S4meanrefA1_404 = list()
S4meanA3_104 = list()
for i in range(S4HSV_imgA1A3_4.shape[0]): 
     for j in range(S4HSV_imgA1A3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_404.append(S4HSV_imgA1A3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_104.append(S4HSV_imgA1A3_4[i][j])  
S4meanrefA1_404 = np.array(S4meanrefA1_404)
S4meanA3_104 = np.array(S4meanA3_104)

S4hsvrefA1_404 = list()
S4hsvA3_104 = list()
for i in range(3):
    S4hsvrefA1_404.append(S4meanrefA1_404[:,i].mean())
    S4hsvA3_104.append(S4meanA3_104[:,i].mean())

# %%
S4meanrefA1_504 = list()
S4meanA3_5104 = list()
for i in range(S4HSV_imgA1A3_54.shape[0]): 
     for j in range(S4HSV_imgA1A3_54.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_504.append(S4HSV_imgA1A3_54[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5104.append(S4HSV_imgA1A3_54[i][j])  
S4meanrefA1_504 = np.array(S4meanrefA1_504)
S4meanA3_5104 = np.array(S4meanA3_5104)

S4hsvrefA1_504 = list()
S4hsvA3_5104 = list()
for i in range(3):
    S4hsvrefA1_504.append(S4meanrefA1_504[:,i].mean())
    S4hsvA3_5104.append(S4meanA3_5104[:,i].mean())

# %%
S4meanrefA1_604 = list()
S4meanA4_104 = list()
for i in range(S4HSV_imgA1A4_4.shape[0]): 
     for j in range(S4HSV_imgA1A4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_604.append(S4HSV_imgA1A4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_104.append(S4HSV_imgA1A4_[i][j])  
S4meanrefA1_604 = np.array(S4meanrefA1_604)
S4meanA4_104 = np.array(S4meanA4_104)

S4hsvrefA1_604 = list()
S4hsvA4_104 = list()
for i in range(3):
    S4hsvrefA1_604.append(S4meanrefA1_604[:,i].mean())
    S4hsvA4_104.append(S4meanA4_104[:,i].mean())

# %%
S4meanrefA1_704 = list()
S4meanB1_104 = list()
for i in range(S4HSV_imgA1B1_4.shape[0]): 
     for j in range(S4HSV_imgA1B1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_7.append(S4HSV_imgA1B1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_1.append(S4HSV_imgA1B1_4[i][j])  
S4meanrefA1_704 = np.array(S4meanrefA1_704)
S4meanB1_104 = np.array(S4meanB1_104)

S4hsvrefA1_704 = list()
S4hsvB1_104 = list()
for i in range(3):
    S4hsvrefA1_704.append(S4meanrefA1_704[:,i].mean())
    S4hsvB1_104.append(S4meanB1_104[:,i].mean())

# %%
S4meanrefA1_804 = list()
S4meanB2_104 = list()
for i in range(S4HSV_imgA1B2_4.shape[0]): 
     for j in range(S4HSV_imgA1B2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_804.append(S4HSV_imgA1B2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_104.append(S4HSV_imgA1B2_4[i][j])  
S4meanrefA1_804 = np.array(S4meanrefA1_804)
S4meanB2_104 = np.array(S4meanB2_104)

S4hsvrefA1_804 = list()
S4hsvB2_104 = list()
for i in range(3):
    S4hsvrefA1_804.append(S4meanrefA1_804[:,i].mean())
    S4hsvB2_104.append(S4meanB2_104[:,i].mean())

# %%
S4meanrefA1_904 = list()
S4meanB3_104 = list()
for i in range(S4HSV_imgA1B3_404.shape[0]): 
     for j in range(S4HSV_imgA1B3_404.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_904.append(S4HSV_imgA1B3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_104.append(S4HSV_imgA1B3_4[i][j])  
S4meanrefA1_904 = np.array(S4meanrefA1_904)
S4meanB3_104 = np.array(S4meanB3_104)

S4hsvrefA1_904 = list()
S4hsvB3_104 = list()
for i in range(3):
    S4hsvrefA1_904.append(S4meanrefA1_904[:,i].mean())
    S4hsvB3_104.append(S4meanB3_104[:,i].mean())

# %%
S4meanrefA1_1004 = list()
S4meanB4_104 = list()
for i in range(S4HSV_imgA1B4_4.shape[0]): 
     for j in range(S4HSV_imgA1B4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1004.append(S4HSV_imgA1B4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_104.append(S4HSV_imgA1B4_4[i][j])  
S4meanrefA1_1004 = np.array(S4meanrefA1_1004)
S4meanB4_104 = np.array(S4meanB4_104)

S4hsvrefA1_1004 = list()
S4hsvB4_104= list()
for i in range(3):
    S4hsvrefA1_1004.append(S4meanrefA1_1004[:,i].mean())
    S4hsvB4_104.append(S4meanB4_104[:,i].mean())

# %%
S4meanrefA1_1104 = list()
S4meanC1_104 = list()
for i in range(S4HSV_imgA1C1_4.shape[0]): 
     for j in range(S4HSV_imgA1C1_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1104.append(S4HSV_imgA1C1_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_104.append(S4HSV_imgA1C1_4[i][j])  
S4meanrefA1_1104 = np.array(S4meanrefA1_1104)
S4meanC1_104 = np.array(S4meanC1_104)

S4hsvrefA1_1104 = list()
S4hsvC1_104 = list()
for i in range(3):
    S4hsvrefA1_1104.append(S4meanrefA1_1104[:,i].mean())
    S4hsvC1_104.append(S4meanC1_104[:,i].mean())

# %%
S4meanrefA1_1204 = list()
S4meanC2_104 = list()
for i in range(S4HSV_imgA1C2_4.shape[0]): 
     for j in range(S4HSV_imgA1C2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1204.append(S4HSV_imgA1C2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_104.append(S4HSV_imgA1C2_4[i][j])  
S4meanrefA1_1204 = np.array(S4meanrefA1_1204)
S4meanC2_1อ = np.array(S4meanC2_104)

S4hsvrefA1_1204 = list()
S4hsvC2_104 = list()
for i in range(3):
    S4hsvrefA1_1204.append(S4meanrefA1_1204[:,i].mean())
    S4hsvC2_104.append(S4meanC2_104[:,i].mean())

# %%
S4meanrefA1_1304 = list()
S4meanC3_104 = list()
for i in range(S4HSV_imgA1C3_4.shape[0]): 
     for j in range(S4HSV_imgA1C3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1304.append(S4HSV_imgA1C3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_104.append(S4HSV_imgA1C3_4[i][j])  
S4meanrefA1_1304 = np.array(S4meanrefA1_1304)
S4meanC3_104 = np.array(S4meanC3_104)

S4hsvrefA1_1304 = list()
S4hsvC3_104 = list()
for i in range(3):
    S4hsvrefA1_1304.append(S4meanrefA1_1304[:,i].mean())
    S4hsvC3_104.append(S4meanC3_104[:,i].mean())

# %%
S4meanrefA1_1404 = list()
S4meanC4_104 = list()
for i in range(S4HSV_imgA1C4_4.shape[0]): 
     for j in range(S4HSV_imgA1C4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1404.append(S4HSV_imgA1C4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_104.append(S4HSV_imgA1C4_4[i][j])  
S4meanrefA1_1404 = np.array(S4meanrefA1_14)
S4meanC4_104 = np.array(S4meanC4_1)

S4hsvrefA1_1404 = list()
S4hsvC4_104 = list()
for i in range(3):
    S4hsvrefA1_1404.append(S4meanrefA1_1404[:,i].mean())
    S4hsvC4_104.append(S4meanC4_104[:,i].mean())

# %%
S4meanrefA1_1504 = list()
S4meanD2_104 = list()
for i in range(S4HSV_imgA1D2_4.shape[0]): 
     for j in range(S4HSV_imgA1D2_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1504.append(S4HSV_imgA1D2_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_104.append(S4HSV_imgA1D2_4[i][j])  
S4meanrefA1_1504 = np.array(S4meanrefA1_1504)
S4meanD2_104 = np.array(S4meanD2_104)

S4hsvrefA1_1504 = list()
S4hsvD2_104 = list()
for i in range(3):
    S4hsvrefA1_1504.append(S4meanrefA1_1504[:,i].mean())
    S4hsvD2_104.append(S4meanD2_104[:,i].mean())

# %%
S4meanrefA1_1604 = list()
S4meanD3_104 = list()
for i in range(S4HSV_imgA1D3_4.shape[0]): 
     for j in range(S4HSV_imgA1D3_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1604.append(S4HSV_imgA1D3_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_104.append(S4HSV_imgA1D3_4[i][j])  
S4meanrefA1_1604 = np.array(S4meanrefA1_1604)
S4meanD3_104 = np.array(S4meanD3_104)

S4hsvrefA1_1604 = list()
S4hsvD3_104 = list()
for i in range(3):
    S4hsvrefA1_1604.append(S4meanrefA1_1604[:,i].mean())
    S4hsvD3_104.append(S4meanD3_104[:,i].mean())

# %%
S4meanrefA1_1704= list()
S4meanD4_104 = list()
for i in range(S4HSV_imgA1D4_4.shape[0]): 
     for j in range(S4HSV_imgA1D4_4.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1704.append(S4HSV_imgA1D4_4[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_104.append(S4HSV_imgA1D4_4[i][j])  
S4meanrefA1_1704 = np.array(S4meanrefA1_1404)
S4meanD4_104 = np.array(S4meanD4_104)

S4hsvrefA1_1704 = list()
S4hsvD4_104 = list()
for i in range(3):
    S4hsvrefA1_1704.append(S4meanrefA1_1704[:,i].mean())
    S4hsvD4_104.append(S4meanD4_104[:,i].mean())

# %% [markdown]
# ###Img 5

# %%
S4meanrefA1_105 = list()
S4meanA1_205 = list()
for i in range(S4HSV_imgA1A1_5.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_5.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_105.append(S4HSV_imgA1A1_505[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_205.append(S4HSV_imgA1A1_505[i][j])  
S4meanrefA1_105 = np.array(S4meanrefA1_105)
S4meanA1_205 = np.array(S4meanA1_205)

S4hsvrefA1_105 = list()
S4hsvA1_205 = list()
for i in range(3):
    S4hsvrefA1_105.append(S4meanrefA1_105[:,i].mean())
    S4hsvA1_205.append(S4meanA1_205[:,i].mean())
S4hsvrefA1_105,S4hsvA1_205

# %%
S4meanrefA1_305 = list()
S4meanA2_105 = list()
for i in range(S4HSV_imgA1A2_5.shape[0]): 
     for j in range(S4HSV_imgA1A2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_305.append(S4HSV_imgA1A2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_105.append(S4HSV_imgA1A2_5[i][j])  
S4meanrefA1_305 = np.array(S4meanrefA1_305)
S4meanA2_105 = np.array(S4meanA2_105)

S4hsvrefA1_305 = list()
S4hsvA2_105 = list()
for i in range(3):
    S4hsvrefA1_305.append(S4meanrefA1_305[:,i].mean())
    S4hsvA2_105.append(S4meanA2_105[:,i].mean())

# %%
S4meanrefA1_405 = list()
S4meanA3_105 = list()
for i in range(S4HSV_imgA1A3_5.shape[0]): 
     for j in range(S4HSV_imgA1A3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_405.append(S4HSV_imgA1A3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_105.append(S4HSV_imgA1A3_5[i][j])  
S4meanrefA1_405 = np.array(S4meanrefA1_405)
S4meanA3_1อ = np.array(S4meanA3_105)

S4hsvrefA1_405 = list()
S4hsvA3_105= list()
for i in range(3):
    S4hsvrefA1_405.append(S4meanrefA1_405[:,i].mean())
    S4hsvA3_105.append(S4meanA3_105[:,i].mean())

# %%
S4meanrefA1_505 = list()
S4meanA3_5105 = list()
for i in range(S4HSV_imgA1A3_55.shape[0]): 
     for j in range(S4HSV_imgA1A3_55.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_505.append(S4HSV_imgA1A3_55[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5105.append(S4HSV_imgA1A3_55[i][j])  
S4meanrefA1_505 = np.array(S4meanrefA1_505)
S4meanA3_5105 = np.array(S4meanA3_5105)

S4hsvrefA1_505= list()
S4hsvA3_5105 = list()
for i in range(3):
    S4hsvrefA1_505.append(S4meanrefA1_505[:,i].mean())
    S4hsvA3_5105.append(S4meanA3_5105[:,i].mean())

# %%
S4meanrefA1_605 = list()
S4meanA4_105= list()
for i in range(S4HSV_imgA1A4_5.shape[0]): 
     for j in range(S4HSV_imgA1A4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_605.append(S4HSV_imgA1A4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_105.append(S4HSV_imgA1A4_5[i][j])  
S4meanrefA1_605 = np.array(S4meanrefA1_605)
S4meanA4_105 = np.array(S4meanA4_105)

S4hsvrefA1_605 = list()
S4hsvA4_105 = list()
for i in range(3):
    S4hsvrefA1_605.append(S4meanrefA1_605[:,i].mean())
    S4hsvA4_105.append(S4meanA4_105[:,i].mean())

# %%
S4meanrefA1_705 = list()
S4meanB1_105 = list()
for i in range(S4HSV_imgA1B1_5.shape[0]): 
     for j in range(S4HSV_imgA1B1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_705append(S4HSV_imgA1B1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_105.append(S4HSV_imgA1B1_5[i][j])  
S4meanrefA1_705 = np.array(S4meanrefA1_705)
S4meanB1_105 = np.array(S4meanB1_105)

S4hsvrefA1_705 = list()
S4hsvB1_105 = list()
for i in range(3):
    S4hsvrefA1_705.append(S4meanrefA1_7[:,i].mean())
    S4hsvB1_105.append(S4meanB1_1[:,i].mean())

# %%
S4meanrefA1_805 = list()
S4meanB2_105 = list()
for i in range(S4HSV_imgA1B2_5.shape[0]): 
     for j in range(S4HSV_imgA1B2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_8อ.append(S4HSV_imgA1B2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_105.append(S4HSV_imgA1B2_5[i][j])  
S4meanrefA1_805 = np.array(S4meanrefA1_8อ)
S4meanB2_105 = np.array(S4meanB2_105)

S4hsvrefA1_805 = list()
S4hsvB2_105 = list()
for i in range(3):
    S4hsvrefA1_805.append(S4meanrefA1_805[:,i].mean())
    S4hsvB2_105.append(S4meanB2_105[:,i].mean())

# %%
S4meanrefA1_905 = list()
S4meanB3_105= list()
for i in range(S4HSV_imgA1B3_5.shape[0]): 
     for j in range(S4HSV_imgA1B3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_905.append(S4HSV_imgA1B3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_105.append(S4HSV_imgA1B3_5[i][j])  
S4meanrefA1_905 = np.array(S4meanrefA1_905)
S4meanB3_105 = np.array(S4meanB3_105)

S4hsvrefA1_905 = list()
S4hsvB3_105 = list()
for i in range(3):
    S4hsvrefA1_905.append(S4meanrefA1_905[:,i].mean())
    S4hsvB3_105.append(S4meanB3_105[:,i].mean())

# %%
S4meanrefA1_1005 = list()
S4meanB4_105 = list()
for i in range(S4HSV_imgA1B4_5.shape[0]): 
     for j in range(S4HSV_imgA1B4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1005.append(S4HSV_imgA1B4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_105.append(S4HSV_imgA1B4_5[i][j])  
S4meanrefA1_1005 = np.array(S4meanrefA1_1005)
S4meanB4_105 = np.array(S4meanB4_105)

S4hsvrefA1_1005 = list()
S4hsvB4_105 = list()
for i in range(3):
    S4hsvrefA1_1005.append(S4meanrefA1_1005[:,i].mean())
    S4hsvB4_105.append(S4meanB4_105[:,i].mean())

# %%
S4meanrefA1_1105 = list()
S4meanC1_105 = list()
for i in range(S4HSV_imgA1C1_5.shape[0]): 
     for j in range(S4HSV_imgA1C1_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1105.append(S4HSV_imgA1C1_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_105.append(S4HSV_imgA1C1_5[i][j])  
S4meanrefA1_1105 = np.array(S4meanrefA1_1105)
S4meanC1_105 = np.array(S4meanC1_105)

S4hsvrefA1_1105 = list()
S4hsvC1_105= list()
for i in range(3):
    S4hsvrefA1_1105.append(S4meanrefA1_1105[:,i].mean())
    S4hsvC1_105.append(S4meanC1_105[:,i].mean())

# %%
S4meanrefA1_1205 = list()
S4meanC2_105 = list()
for i in range(S4HSV_imgA1C2_5.shape[0]): 
     for j in range(S4HSV_imgA1C2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1205.append(S4HSV_imgA1C2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_105append(S4HSV_imgA1C2_5[i][j])  
S4meanrefA1_1205 = np.array(S4meanrefA1_1205)
S4meanC2_105 = np.array(S4meanC2_105)

S4hsvrefA1_1205 = list()
S4hsvC2_105 = list()
for i in range(3):
    S4hsvrefA1_1205.append(S4meanrefA1_1205[:,i].mean())
    S4hsvC2_105.append(S4meanC2_105[:,i].mean())

# %%
S4meanrefA1_1305 = list()
S4meanC3_105 = list()
for i in range(S4HSV_imgA1C3_5.shape[0]): 
     for j in range(S4HSV_imgA1C3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1305 .append(S4HSV_imgA1C3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_105 .append(S4HSV_imgA1C3_5[i][j])  
S4meanrefA1_1305 = np.array(S4meanrefA1_1305)
S4meanC3_105 = np.array(S4meanC3_105)

S4hsvrefA1_1305 = list()
S4hsvC3_105 = list()
for i in range(3):
    S4hsvrefA1_1305.append(S4meanrefA1_1305[:,i].mean())
    S4hsvC3_105append(S4meanC3_105[:,i].mean())

# %%
S4meanrefA1_1405 = list()
S4meanC4_105 = list()
for i in range(S4HSV_imgA1C4_5.shape[0]): 
     for j in range(S4HSV_imgA1C4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1405.append(S4HSV_imgA1C4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_105.append(S4HSV_imgA1C4_5[i][j])  
S4meanrefA1_1405 = np.array(S4meanrefA1_1405)
S4meanC4_105 = np.array(S4meanC4_105)

S4hsvrefA1_1405 = list()
S4hsvC4_105 = list()
for i in range(3):
    S4hsvrefA1_1405.append(S4meanrefA1_1405[:,i].mean())
    S4hsvC4_105.append(S4meanC4_105[:,i].mean())

# %%
S4meanrefA1_1505  = list()
S4meanD2_105  = list()
for i in range(S4HSV_imgA1D2_5.shape[0]): 
     for j in range(S4HSV_imgA1D2_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1505 .append(S4HSV_imgA1D2_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_105 .append(S4HSV_imgA1D2_5[i][j])  
S4meanrefA1_1505 = np.array(S4meanrefA1_1505)
S4meanD2_105  = np.array(S4meanD2_105)

S4hsvrefA1_1505 = list()
S4hsvD2_105 = list()
for i in range(3):
    S4hsvrefA1_1505.append(S4meanrefA1_1505[:,i].mean())
    S4hsvD2_105.append(S4meanD2_105[:,i].mean())

# %%
S4meanrefA1_1605 = list()
S4meanD3_105 = list()
for i in range(S4HSV_imgA1D3_5.shape[0]): 
     for j in range(S4HSV_imgA1D3_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1605.append(S4HSV_imgA1D3_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_105.append(S4HSV_imgA1D3_5[i][j])  
S4meanrefA1_1605 = np.array(S4meanrefA1_1605)
S4meanD3_105 = np.array(S4meanD3_105)

S4hsvrefA1_1605 = list()
S4hsvD3_105 = list()
for i in range(3):
    S4hsvrefA1_1605.append(S4meanrefA1_1605[:,i].mean())
    S4hsvD3_105.append(S4meanD3_105[:,i].mean())

# %%
S4meanrefA1_1705= list()
S4meanD4_105 = list()
for i in range(S4HSV_imgA1D4_5.shape[0]): 
     for j in range(S4HSV_imgA1D4_5.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1705.append(S4HSV_imgA1D4_5[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_105.append(S4HSV_imgA1D4_5[i][j])  
S4meanrefA1_1705 = np.array(S4meanrefA1_1405)
S4meanD4_105 = np.array(S4meanD4_105)

S4hsvrefA1_1705 = list()
S4hsvD4_105 = list()
for i in range(3):
    S4hsvrefA1_1705.append(S4meanrefA1_1705[:,i].mean())
    S4hsvD4_105.append(S4meanD4_105[:,i].mean())

# %% [markdown]
# ###Img 6

# %%
S4meanrefA1_106 = list()
S4meanA1_206 = list()
for i in range(S4HSV_imgA1A1_6.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_6.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_106.append(S4HSV_imgA1A1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_206.append(S4HSV_imgA1A1_6[i][j])  
S4meanrefA1_106 = np.array(S4meanrefA1_106)
S4meanA1_206 = np.array(S4meanA1_206)

S4hsvrefA1_106 = list()
S4hsvA1_206 = list()
for i in range(3):
    S4hsvrefA1_106.append(S4meanrefA1_106[:,i].mean())
    S4hsvA1_206.append(S4meanA1_206[:,i].mean())
S4hsvrefA1_106,S4hsvA1_206

# %%
S4meanrefA1_306 = list()
S4meanA2_106 = list()
for i in range(S4HSV_imgA1A2_6.shape[0]): 
     for j in range(S4HSV_imgA1A2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_306.append(S4HSV_imgA1A2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_106 .append(S4HSV_imgA1A2_6[i][j])  
S4meanrefA1_306  = np.array(S4meanrefA1_306 )
S4meanA2_106  = np.array(S4meanA2_106 )

S4hsvrefA1_306  = list()
S4hsvA2_106  = list()
for i in range(3):
    S4hsvrefA1_306 .append(S4meanrefA1_306 [:,i].mean())
    S4hsvA2_106 .append(S4meanA2_106 [:,i].mean())

# %%
S4meanrefA1_406  = list()
S4meanA3_106  = list()
for i in range(S4HSV_imgA1A3_6.shape[0]): 
     for j in range(S4HSV_imgA1A3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_406 .append(S4HSV_imgA1A3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_106 .append(S4HSV_imgA1A3_6[i][j])  
S4meanrefA1_406 = np.array(S4meanrefA1_406 )
S4meanA3_106  = np.array(S4meanA3_106 )

S4hsvrefA1_406  = list()
S4hsvA3_106  = list()
for i in range(3):
    S4 hsvrefA1_406 .append(S4meanrefA1_4อ[:,i].mean())
    S4hsvA3_106 .append(S4meanA3_106 [:,i].mean())

# %%
S4meanrefA1_506  = list()
S4meanA3_5106  = list()
for i in range(S4HSV_imgA1A3_56.shape[0]): 
     for j in range(S4HSV_imgA1A3_56.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_506 .append(S4HSV_imgA1A3_56[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5106 .append(S4HSV_imgA1A3_56[i][j])  
S4meanrefA1_506  = np.array(S4meanrefA1_506 )
S4meanA3_5106  = np.array(S4meanA3_5106 )

S4hsvrefA1_506  = list()
S4hsvA3_5106  = list()
for i in range(3):
    S4hsvrefA1_506 .append(S4meanrefA1_506 [:,i].mean())
    S4hsvA3_5106.append(S4meanA3_5106 [:,i].mean())

# %%
S4meanrefA1_606  = list()
S4meanA4_106  = list()
for i in range(S4HSV_imgA1A4_6.shape[0]): 
     for j in range(S4HSV_imgA1A4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_606 .append(S4HSV_imgA1A4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_106 .append(S4HSV_imgA1A4_6[i][j])  
S4meanrefA1_606  = np.array(S4meanrefA1_606 )
S4meanA4_106  = np.array(S4meanA4_106 )

S4hsvrefA1_606  = list()
S4hsvA4_106  = list()
for i in range(3):
   S4hsvrefA1_606 .append(S4meanrefA1_606 [:,i].mean())
   S4hsvA4_106 .append(S4meanA4_106 [:,i].mean())

# %%
S4meanrefA1_706  = list()
S4meanB1_106  = list()
for i in range(S4HSV_imgA1B1_6.shape[0]): 
     for j in range(S4HSV_imgA1B1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_706 .append(S4HSV_imgA1B1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_106 .append(S4HSV_imgA1B1_6[i][j])  
S4meanrefA1_706  = np.array(S4meanrefA1_706 )
S4meanB1_106  = np.array(S4meanB1_106 )

S4hsvrefA1_706  = list()
S4hsvB1_106  = list()
for i in range(3):
    S4hsvrefA1_706 .append(S4meanrefA1_706 [:,i].mean())
    S4hsvB1_106 .append(S4meanB1_106 [:,i].mean())

# %%
S4meanrefA1_806  = list()
S4meanB2_106  = list()
for i in range(S4HSV_imgA1B2_6.shape[0]): 
     for j in range(S4HSV_imgA1B2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_8อ.append(S4HSV_imgA1B2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_106 .append(S4HSV_imgA1B2_6[i][j])  
S4meanrefA1_806 = np.array(S4meanrefA1_806 )
S4meanB2_106  = np.array(S4meanB2_106 )

S4hsvrefA1_806  = list()
S4hsvB2_106  = list()
for i in range(3):
    S4hsvrefA1_806 .append(S4meanrefA1_806 [:,i].mean())
    S4hsvB2_106 .append(S4meanB2_106 [:,i].mean())

# %%
S4meanrefA1_906  = list()
S4meanB3_106  = list()
for i in range(S4HSV_imgA1B3_6.shape[0]): 
     for j in range(S4HSV_imgA1B3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_906 .append(S4HSV_imgA1B3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_106 .append(S4HSV_imgA1B3_6[i][j])  
S4meanrefA1_906  = np.array(S4meanrefA1_906)
S4meanB3_106  = np.array(S4meanB3_106)

S4hsvrefA1_906 = list()
S4hsvB3_106 = list()
for i in range(3):
    S4hsvrefA1_906.append(S4meanrefA1_906[:,i].mean())
    S4hsvB3_106.append(S4meanB3_106[:,i].mean())

# %%
S4meanrefA1_1006 = list()
S4meanB4_106 = list()
for i in range(S4HSV_imgA1B4_6.shape[0]): 
     for j in range(S4HSV_imgA1B4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                   S4meanrefA1_1006.append(S4HSV_imgA1B4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_106.append(S4HSV_imgA1B4_6[i][j])  
S4meanrefA1_1006 = np.array(S4meanrefA1_1006)
S4meanB4_106 = np.array(S4meanB4_106)

S4hsvrefA1_1006 = list()
S4hsvB4_106 = list()
for i in range(3):
    S4hsvrefA1_1006.append(S4meanrefA1_1006[:,i].mean())
    S4hsvB4_106.append(S4meanB4_106[:,i].mean())

# %%
S4meanrefA1_1106 = list()
S4meanC1_106 = list()
for i in range(S4HSV_imgA1C1_6.shape[0]): 
     for j in range(S4HSV_imgA1C1_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1106.append(S4HSV_imgA1C1_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_106.append(S4HSV_imgA1C1_6[i][j])  
S4meanrefA1_1106 = np.array(S4meanrefA1_1106)
S4meanC1_106 = np.array(S4meanC1_106)

S4hsvrefA1_1106 = list()
S4hsvC1_106 = list()
for i in range(3):
    S4hsvrefA1_1106.append(S4meanrefA1_1106[:,i].mean())
    S4hsvC1_106.append(S4meanC1_106[:,i].mean())

# %%
S4meanrefA1_1206 = list()
S4meanC2_106 = list()
for i in range(S4HSV_imgA1C2_6.shape[0]): 
     for j in range(S4HSV_imgA1C2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                   S4meanrefA1_1206.append(S4HSV_imgA1C2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_106.append(S4HSV_imgA1C2_6[i][j])  
S4meanrefA1_1206 = np.array(S4meanrefA1_1206)
S4meanC2_106 = np.array(S4meanC2_106)

S4hsvrefA1_1206 = list()
S4hsvC2_106 = list()
for i in range(3):
    S4hsvrefA1_1206.append(S4meanrefA1_12[:,i].mean())
    S4hsvC2_106.append(S4meanC2_1[:,i].mean())

# %%
S4meanrefA1_1306 = list()
S4meanC3_106 = list()
for i in range(S4HSV_imgA1C3_6.shape[0]): 
     for j in range(S4HSV_imgA1C3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1306.append(S4HSV_imgA1C3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_106.append(S4HSV_imgA1C3_6[i][j])  
S4meanrefA1_1306 = np.array(S4meanrefA1_1306)
S4meanC3_106 = np.array(S4meanC3_106

S4hsvrefA1_1306 = list()
S4hsvC3_106 = list()
for i in range(3):
    S4hsvrefA1_1306.append(S4meanrefA1_1306[:,i].mean())
    S4hsvC3_106.append(S4meanC3_106[:,i].mean())

# %%
S4meanrefA1_1406 = list()
S4meanC4_106 = list()
for i in range(S4HSV_imgA1C4_6.shape[0]): 
     for j in range(S4HSV_imgA1C4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1406.append(S4HSV_imgA1C4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_106.append(S4HSV_imgA1C4_6[i][j])  
S4meanrefA1_1406 = np.array(S4meanrefA1_1406)
S4meanC4_106 = np.array(S4meanC4_106)

S4hsvrefA1_1406 = list()
S4hsvC4_106 = list()
for i in range(3):
    S4hsvrefA1_1406.append(S4meanrefA1_1406[:,i].mean())
    S4hsvC4_106.append(S4meanC4_106[:,i].mean())

# %%
S4meanrefA1_1506 = list()
S4meanD2_106 = list()
for i in range(S4HSV_imgA1D2_6.shape[0]): 
     for j in range(S4HSV_imgA1D2_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1506.append(S4HSV_imgA1D2_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_106.append(S4HSV_imgA1D2_6[i][j])  
S4meanrefA1_1506 = np.array(S4meanrefA1_1506)
S4meanD2_106 = np.array(S4meanD2_106)

S4hsvrefA1_1506 = list()
S4hsvD2_106 = list()
for i in range(3):
    S4hsvrefA1_1506.append(S4meanrefA1_1506[:,i].mean())
    S4hsvD2_106.append(S4meanD2_106[:,i].mean())

# %%
S4meanrefA1_1606 = list()
S4meanD3_106 = list()
for i in range(S4HSV_imgA1D3_6.shape[0]): 
     for j in range(S4HSV_imgA1D3_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1606.append(S4HSV_imgA1D3_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_106.append(S4HSV_imgA1D3_6[i][j])  
S4meanrefA1_1606 = np.array(S4meanrefA1_1606)
S4meanD3_106 = np.array(S4meanD3_106)

S4hsvrefA1_1606 = list()
S4hsvD3_106 = list()
for i in range(3):
    S4hsvrefA1_1606.append(S4meanrefA1_1606[:,i].mean())
    S4hsvD3_1v.append(S4meanD3_106[:,i].mean())

# %%
S4meanrefA1_1706= list()
S4meanD4_106 = list()
for i in range(S4HSV_imgA1D4_6.shape[0]): 
     for j in range(S4HSV_imgA1D4_6.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1706.append(S4HSV_imgA1D4_6[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_106.append(S4HSV_imgA1D4_6[i][j])  
S4meanrefA1_1706 = np.array(S4meanrefA1_1406)
S4meanD4_106 = np.array(S4meanD4_106)

S4hsvrefA1_1706 = list()
S4hsvD4_10606 = list()
for i in range(3):
    S4hsvrefA1_1706.append(S4meanrefA1_1706[:,i].mean())
    S4hsvD4_106.append(S4meanD4_106[:,i].mean())

# %% [markdown]
# ###Img 7

# %%
S4meanrefA1_107 = list()
S4meanA1_207 = list()
for i in range(S4HSV_imgA1A1_7.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_7.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_107.append(S4HSV_imgA1A1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_207.append(S4HSV_imgA1A1_7[i][j])  
S4meanrefA1_107 = np.array(S4meanrefA1_107)
S4meanA1_207 = np.array(S4meanA1_207)

S4hsvrefA1_107 = list()
S4hsvA1_207 = list()
for i in range(3):
    S4hsvrefA1_107.append(S4meanrefA1_107[:,i].mean())
    S4hsvA1_207.append(S4meanA1_207[:,i].mean())
S4hsvrefA1_107,S4hsvA1_207

# %%
S4meanrefA1_307 = list()
S4meanA2_107 = list()
for i in range(S4HSV_imgA1A2_7.shape[0]): 
     for j in range(S4HSV_imgA1A2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_307.append(S4HSV_imgA1A2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_107.append(S4HSV_imgA1A2_7[i][j])  
S4meanrefA1_307 = np.array(S4meanrefA1_307)
S4meanA2_107 = np.array(S4meanA2_1v)

S4hsvrefA1_307 = list()
S4hsvA2_107 = list()
for i in range(3):
    S4hsvrefA1_307.append(S4meanrefA1_307[:,i].mean())
    S4hsvA2_107.append(S4meanA2_107[:,i].mean())

# %%
S4meanrefA1_407 = list()
S4meanA3_107 = list()
for i in range(S4HSV_imgA1A3_7.shape[0]): 
     for j in range(S4HSV_imgA1A3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_407.append(S4HSV_imgA1A3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_107.append(S4HSV_imgA1A3_7[i][j])  
S4meanrefA1_407 = np.array(S4meanrefA1_407)
S4meanA3_107 = np.array(S4meanA3_107)

S4hsvrefA1_407 = list()
S4hsvA3_107 = list()
for i in range(3):
    S4hsvrefA1_407.append(S4meanrefA1_407[:,i].mean())
    S4hsvA3_107.append(S4meanA3_107[:,i].mean())

# %%
S4meanrefA1_507 = list()
S4meanA3_5107 = list()
for i in range(S4HSV_imgA1A3_5707.shape[0]): 
     for j in range(S4HSV_imgA1A3_57.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_507.append(S4HSV_imgA1A3_57[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5107.append(S4HSV_imgA1A3_57[i][j])  
S4meanrefA1_5v = np.array(S4meanrefA1_5v)
S4meanA3_5107 = np.array(S4meanA3_5107)

S4hsvrefA1_507 = list()
S4hsvA3_5107 = list()
for i in range(3):
    S4hsvrefA1_507.append(S4meanrefA1_507[:,i].mean())
    S4hsvA3_5107.append(S4meanA3_5107[:,i].mean())

# %%
S4meanrefA1_607 = list()
S4meanA4_107 = list()
for i in range(S4HSV_imgA1A4_7.shape[0]): 
     for j in range(S4HSV_imgA1A4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_607.append(S4HSV_imgA1A4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_107.append(S4HSV_imgA1A4_7[i][j])  
S4meanrefA1_607 = np.array(S4meanrefA1_607)
S4meanA4_1v = np.array(S4meanA4_107)

S4hsvrefA1_607 = list()
S4hsvA4_107 = list()
for i in range(3):
    S4hsvrefA1_607.append(S4meanrefA1_607[:,i].mean())
    S4hsvA4_107.append(S4meanA4_107[:,i].mean())

# %%
S4meanrefA1_707 = list()
S4meanB1_107 = list()
for i in range(S4HSV_imgA1B1_7.shape[0]): 
     for j in range(S4HSV_imgA1B1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_707.append(S4HSV_imgA1B1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_107.append(S4HSV_imgA1B1_7[i][j])  
S4meanrefA1_707 = np.array(S4meanrefA1_7)
S4meanB1_107= np.array(S4meanB1_1)

S4hsvrefA1_707 = list()
S4hsvB1_107 = list()
for i in range(3):
    S4hsvrefA1_707.append(S4meanrefA1_707[:,i].mean())
    S4hsvB1_107.append(S4meanB1_107[:,i].mean())

# %%
S4meanrefA1_807 = list()
S4meanB2_107 = list()
for i in range(S4HSV_imgA1B2_7.shape[0]): 
     for j in range(S4HSV_imgA1B2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_807.append(S4HSV_imgA1B2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_107.append(S4HSV_imgA1B2_7[i][j])  
S4meanrefA1_807 = np.array(S4meanrefA1_807)
S4meanB2_107 = np.array(S4meanB2_107)

S4hsvrefA1_807 = list()
S4hsvB2_107 = list()
for i in range(3):
    S4hsvrefA1_807.append(S4meanrefA1_807[:,i].mean())
    S4hsvB2_107.append(S4meanB2_107[:,i].mean())

# %%
S4meanrefA1_907 = list()
S4meanB3_107 = list()
for i in range(S4HSV_imgA1B3_7.shape[0]): 
     for j in range(S4HSV_imgA1B3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_907.append(S4HSV_imgA1B3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_107.append(S4HSV_imgA1B3_7[i][j])  
S4meanrefA1_907= np.array(S4meanrefA1_907)
S4meanB3_107 = np.array(S4meanB3_107)

S4hsvrefA1_907 = list()
S4hsvB3_107 = list()
for i in range(3):
     S4hsvrefA1_907.append(S4meanrefA1_907[:,i].mean())
     S4hsvB3_107.append(S4meanB3_107[:,i].mean())

# %%
S4meanrefA1_1007 = list()
S4meanB4_107 = list()
for i in range(S4HSV_imgA1B4_7.shape[0]): 
     for j in range(S4HSV_imgA1B4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1007.append(S4HSV_imgA1B4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_107.append(S4HSV_imgA1B4_7[i][j])  
S4meanrefA1_1007= np.array(S4meanrefA1_1007)
S4meanB4_107 = np.array(S4meanB4_107)

S4hsvrefA1_1007 = list()
S4hsvB4_107 = list()
for i in range(3):
    S4hsvrefA1_1007.append(S4meanrefA1_1007[:,i].mean())
    S4hsvB4_107.append(S4meanB4_107[:,i].mean())

# %%
S4meanrefA1_1107 = list()
S4meanC1_1v = list()
for i in range(S4HSV_imgA1C1_7.shape[0]): 
     for j in range(S4HSV_imgA1C1_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1107.append(S4HSV_imgA1C1_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_107.append(S4HSV_imgA1C1_7[i][j])  
S4meanrefA1_1107= np.array(S4meanrefA1_1107)
S4meanC1_107 = np.array(S4meanC1_107)

S4hsvrefA1_1107 = list()
S4hsvC1_107 = list()
for i in range(3):
    S4hsvrefA1_1107.append(S4meanrefA1_1107[:,i].mean())
    S4hsvC1_107.append(S4meanC1_107[:,i].mean())

# %%
S4meanrefA1_1207 = list()
S4meanC2_107 = list()
for i in range(S4HSV_imgA1C2_7.shape[0]): 
     for j in range(S4HSV_imgA1C2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1207.append(S4HSV_imgA1C2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_107.append(S4HSV_imgA1C2_7[i][j])  
S4meanrefA1_1207 = np.array(S4meanrefA1_1207)
S4meanC2_107 = np.array(S4meanC2_107)

S4hsvrefA1_1207 = list()
S4hsvC2_107 = list()
for i in range(3):
   S4hsvrefA1_1207.append(S4meanrefA1_12v[:,i].mean())
   S4hsvC2_107.append(S4meanC2_107[:,i].mean())

# %%
S4meanrefA1_1307 = list()
S4meanC3_107 = list()
for i in range(S4HSV_imgA1C3_7.shape[0]): 
     for j in range(S4HSV_imgA1C3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1307.append(S4HSV_imgA1C3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_107.append(S4HSV_imgA1C3_7[i][j])  
S4meanrefA1_1307 = np.array(S4meanrefA1_1307)
S4meanC3_107 = np.array(S4meanC3_107)

S4hsvrefA1_1307 = list()
S4hsvC3_107 = list()
for i in range(3):
    S4hsvrefA1_1307.append(S4meanrefA1_1307[:,i].mean())
    S4hsvC3_107.append(S4meanC3_107[:,i].mean())

# %%
S4meanrefA1_1407 = list()
S4meanC4_107 = list()
for i in range(S4HSV_imgA1C4_7.shape[0]): 
     for j in range(S4HSV_imgA1C4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1407.append(S4HSV_imgA1C4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_107.append(S4HSV_imgA1C4_7[i][j])  
S4meanrefA1_1407 = np.array(S4meanrefA1_1407)
S4meanC4_107 = np.array(S4meanC4_107)

S4hsvrefA1_1407 = list()
S4hsvC4_107 = list()
for i in range(3):
    S4hsvrefA1_1407.append(S4meanrefA1_1407[:,i].mean())
    S4hsvC4_107.append(S4meanC4_107[:,i].mean())

# %%
S4meanrefA1_1507 = list()
S4meanD2_107 = list()
for i in range(S4HSV_imgA1D2_7.shape[0]): 
     for j in range(S4HSV_imgA1D2_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1507.append(S4HSV_imgA1D2_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_107.append(S4HSV_imgA1D2_7[i][j])  
S4meanrefA1_1507 = np.array(S4meanrefA1_1507)
S4meanD2_107 = np.array(S4meanD2_107)

S4hsvrefA1_1507= list()
S4hsvD2_107 = list()
for i in range(3):
    S4hsvrefA1_1507.append(S4meanrefA1_1507[:,i].mean())
    S4hsvD2_107.append(S4meanD2_107[:,i].mean())

# %%
S4meanrefA1_1607 = list()
S4meanD3_107 = list()
for i in range(S4HSV_imgA1D3_7.shape[0]): 
     for j in range(S4HSV_imgA1D3_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1607.append(S4HSV_imgA1D3_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_107.append(S4HSV_imgA1D3_7[i][j])  
S4meanrefA1_1607 = np.array(S4meanrefA1_1607)
S4meanD3_107 = np.array(S4meanD3_107)

S4hsvrefA1_1607 = list()
S4hsvD3_107 = list()
for i in range(3):
    S4hsvrefA1_1607.append(S4meanrefA1_1607[:,i].mean())
    S4hsvD3_107.append(S4meanD3_107[:,i].mean())

# %%
S4meanrefA1_1707= list()
S4meanD4_107 = list()
for i in range(S4HSV_imgA1D4_7.shape[0]): 
     for j in range(S4HSV_imgA1D4_7.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1707.append(S4HSV_imgA1D4_7[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_107.append(S4HSV_imgA1D4_7[i][j])  
S4meanrefA1_1707 = np.array(S4meanrefA1_1407)
S4meanD4_107 = np.array(S4meanD4_107,;)

S4hsvrefA1_1707 = list()
S4hsvD4_107 = list()
for i in range(3):
    S4hsvrefA1_1707.append(S4meanrefA1_1707[:,i].mean())
    S4hsvD4_107.append(S4meanD4_107[:,i].mean())

# %% [markdown]
# ###Img 8

# %%
S4meanrefA1_108 = list()
S4meanA1_208 = list()
for i in range(S4HSV_imgA1A1_8.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_8.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_108.append(S4HSV_imgA1A1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_208.append(S4HSV_imgA1A1_8[i][j])  
S4meanrefA1_108 = np.array(S4meanrefA1_108)
S4meanA1_208 = np.array(S4meanA1_208)

S4hsvrefA1_108 = list()
S4hsvA1_208 = list()
for i in range(3):
    S4hsvrefA1_108.append(S4meanrefA1_108[:,i].mean())
    S4hsvA1_208.append(S4meanA1_208[:,i].mean())
S4hsvrefA1_108,S4hsvA1_208

# %%
S4meanrefA1_308 = list()
S4meanA2_108 = list()
for i in range(S4HSV_imgA1A2_8.shape[0]): 
     for j in range(S4HSV_imgA1A2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_308.append(S4HSV_imgA1A2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_108.append(S4HSV_imgA1A2_8[i][j])  
S4meanrefA1_308 = np.array(S4meanrefA1_308)
S4meanA2_108 = np.array(S4meanA2_108)

S4hsvrefA1_308 = list()
S4hsvA2_108 = list()
for i in range(3):
    S4hsvrefA1_308.append(S4meanrefA1_308[:,i].mean())
    S4hsvA2_108.append(S4meanA2_108[:,i].mean())

# %%
S4meanrefA1_408 = list()
S4meanA3_108 = list()
for i in range(S4HSV_imgA1A3_8.shape[0]): 
     for j in range(S4HSV_imgA1A3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_408.append(S4HSV_imgA1A3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_108.append(S4HSV_imgA1A3_8[i][j])  
S4meanrefA1_408 = np.array(S4meanrefA1_408)
S4meanA3_108 = np.array(S4meanA3_108)

S4hsvrefA1_408 = list()
S4hsvA3_108 = list()
for i in range(3):
    S4hsvrefA1_408.append(S4meanrefA1_408[:,i].mean())
    S4hsvA3_108.append(S4meanA3_108[:,i].mean())

# %%
S4meanrefA1_508 = list()
S4meanA3_5108 = list()
for i in range(S4HSV_imgA1A3_58.shape[0]): 
     for j in range(S4HSV_imgA1A3_58.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_508.append(S4HSV_imgA1A3_58[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5108.append(S4HSV_imgA1A3_58[i][j])  
S4meanrefA1_508 = np.array(S4meanrefA1_508)
S4meanA3_5108 = np.array(S4meanA3_5108)

S4hsvrefA1_508 = list()
S4hsvA3_5108 = list()
for i in range(3):
    S4hsvrefA1_508.append(S4meanrefA1_508[:,i].mean())
    S4hsvA3_5108.append(S4meanA3_5108[:,i].mean())

# %%
S4meanrefA1_608 = list()
S4meanA4_108 = list()
for i in range(S4HSV_imgA1A4_8.shape[0]): 
     for j in range(S4HSV_imgA1A4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_608.append(S4HSV_imgA1A4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_108.append(S4HSV_imgA1A4_8[i][j])  
S4meanrefA1_608 = np.array(S4meanrefA1_608)
S4meanA4_108 = np.array(S4meanA4_108)

S4hsvrefA1_608 = list()
S4hsvA4_108= list()
for i in range(3):
    S4hsvrefA1_608.append(S4meanrefA1_608[:,i].mean())
    S4hsvA4_108.append(S4meanA4_108[:,i].mean())

# %%
S4meanrefA1_708 = list()
S4meanB1_108 = list()
for i in range(S4HSV_imgA1B1_8.shape[0]): 
     for j in range(S4HSV_imgA1B1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_708.append(S4HSV_imgA1B1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_108.append(S4HSV_imgA1B1_8[i][j])  
S4meanrefA1_708 = np.array(S4meanrefA1_708)
S4meanB1_108 = np.array(S4meanB1_108)

S4hsvrefA1_708 = list()
S4hsvB1_108 = list()
for i in range(3):
    S4hsvrefA1_708.append(S4meanrefA1_708[:,i].mean())
    S4hsvB1_108.append(S4meanB1_108[:,i].mean())

# %%
S4meanrefA1_808 = list()
S4meanB2_108 = list()
for i in range(S4HSV_imgA1B2_8.shape[0]): 
     for j in range(S4HSV_imgA1B2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_808.append(S4HSV_imgA1B2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_108.append(S4HSV_imgA1B2_8[i][j])  
S4meanrefA1_808 = np.array(S4meanrefA1_808)
S4meanB2_108 = np.array(S4meanB2_108)

S4hsvrefA1_808 = list()
S4hsvB2_108 = list()
for i in range(3):
    S4hsvrefA1_808.append(S4meanrefA1_808[:,i].mean())
    S4hsvB2_108.append(S4meanB2_108[:,i].mean())

# %%
S4meanrefA1_908 = list()
S4meanB3_108 = list()
for i in range(S4HSV_imgA1B3_8.shape[0]): 
     for j in range(S4HSV_imgA1B3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_908.append(S4HSV_imgA1B3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_108.append(S4HSV_imgA1B3_8[i][j])  
S4meanrefA1_908 = np.array(S4meanrefA1_908)
S4meanB3_108 = np.array(S4meanB3_108)

S4hsvrefA1_908 = list()
S4hsvB3_108 = list()
for i in range(3):
    S4hsvrefA1_908.append(S4meanrefA1_908[:,i].mean())
    S4hsvB3_108.append(S4meanB3_108[:,i].mean())

# %%
S4meanrefA1_1008 = list()
S4meanB4_108 = list()
for i in range(S4HSV_imgA1B4_8.shape[0]): 
     for j in range(S4HSV_imgA1B4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1008.append(S4HSV_imgA1B4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_108.append(S4HSV_imgA1B4_8[i][j])  
S4meanrefA1_1008 = np.array(S4meanrefA1_1008)
S4meanB4_108 = np.array(S4meanB4_108)

S4hsvrefA1_1008 = list()
S4hsvB4_108 = list()
for i in range(3):
    S4hsvrefA1_1008.append(S4meanrefA1_1008[:,i].mean())
    S4hsvB4_108.append(S4meanB4_108[:,i].mean())

# %%
S4meanrefA1_1108 = list()
S4meanC1_108 = list()
for i in range(S4HSV_imgA1C1_8.shape[0]): 
     for j in range(S4HSV_imgA1C1_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1108.append(S4HSV_imgA1C1_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_108.append(S4HSV_imgA1C1_8[i][j])  
S4meanrefA1_1108 = np.array(S4meanrefA1_1108)
S4meanC1_108 = np.array(S4meanC1_108)

S4hsvrefA1_1108 = list()
S4hsvC1_108 = list()
for i in range(3):
    S4hsvrefA1_1108.append(S4meanrefA1_1108[:,i].mean())
    S4hsvC1_108.append(S4meanC1_108[:,i].mean())

# %%
S4meanrefA1_1208 = list()
S4meanC2_108 = list()
for i in range(S4HSV_imgA1C2_808.shape[0]): 
     for j in range(S4HSV_imgA1C2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1208.append(S4HSV_imgA1C2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_108.append(S4HSV_imgA1C2_8[i][j])  
S4meanrefA1_12v = np.array(S4meanrefA1_1208)
S4meanC2_108 = np.array(S4meanC2_108)

S4hsvrefA1_12v = list()
S4hsvC2_108 = list()
for i in range(3):
    S4hsvrefA1_1208.append(S4meanrefA1_1208[:,i].mean())
    S4hsvC2_108.append(S4meanC2_108[:,i].mean())

# %%
S4meanrefA1_1308 = list()
S4meanC3_108 = list()
for i in range(S4HSV_imgA1C3_8.shape[0]): 
     for j in range(S4HSV_imgA1C3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1308.append(S4HSV_imgA1C3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_108.append(S4HSV_imgA1C3_8[i][j])  
S4meanrefA1_1308 = np.array(S4meanrefA1_1308)
S4meanC3_108 = np.array(S4meanC3_108)

S4hsvrefA1_1308 = list()
S4hsvC3_108 = list()
for i in range(3):
    S4hsvrefA1_1308.append(S4meanrefA1_1308[:,i].mean())
    S4hsvC3_108.append(S4meanC3_108[:,i].mean())

# %%
S4meanrefA1_1408 = list()
S4meanC4_108 = list()
for i in range(S4HSV_imgA1C4_8.shape[0]): 
     for j in range(S4HSV_imgA1C4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_1408.append(S4HSV_imgA1C4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                 S4meanC4_108.append(S4HSV_imgA1C4_8[i][j])  
S4meanrefA1_1408 = np.array(S4meanrefA1_1408)
S4meanC4_108 = np.array(S4meanC4_108)

S4hsvrefA1_1408 = list()
S4hsvC4_108= list()
for i in range(3):
    S4hsvrefA1_1408.append(S4meanrefA1_1408[:,i].mean())
    S4hsvC4_108.append(S4meanC4_108[:,i].mean())

# %%
S4meanrefA1_1508 = list()
S4meanD2_108 = list()
for i in range(S4HSV_imgA1D2_8.shape[0]): 
     for j in range(S4HSV_imgA1D2_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1508.append(S4HSV_imgA1D2_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_108.append(S4HSV_imgA1D2_8[i][j])  
S4meanrefA1_1508 = np.array(S4meanrefA1_1508)
S4meanD2_108 = np.array(S4meanD2_108)

S4hsvrefA1_1508 = list()
S4hsvD2_108 = list()
for i in range(3):
    S4hsvrefA1_1508.append(S4meanrefA1_1508[:,i].mean())
    S4hsvD2_108.append(S4meanD2_108[:,i].mean())

# %%
S4meanrefA1_1608 = list()
S4meanD3_108 = list()
for i in range(S4HSV_imgA1D3_8.shape[0]): 
     for j in range(S4HSV_imgA1D3_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1608.append(S4HSV_imgA1D3_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_108.append(S4HSV_imgA1D3_8[i][j])  
S4meanrefA1_1608 = np.array(S4meanrefA1_1608)
S4meanD3_108 = np.array(S4meanD3_108)

S4hsvrefA1_1608 = list()
S4hsvD3_108 = list()
for i in range(3):
    S4hsvrefA1_1608.append(S4meanrefA1_1608[:,i].mean())
    S4hsvD3_108.append(S4meanD3_108[:,i].mean())

# %%
S4meanrefA1_1708= list()
S4meanD4_108 = list()
for i in range(S4HSV_imgA1D4_8.shape[0]): 
     for j in range(S4HSV_imgA1D4_8.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1708.append(S4HSV_imgA1D4_8[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_108.append(S4HSV_imgA1D4_8[i][j])  
S4meanrefA1_1708= np.array(S4meanrefA1_1408)
S4meanD4_108 = np.array(S4meanD4_108)

S4hsvrefA1_1708 = list()
S4hsvD4_108 = list()
for i in range(3):
    S4hsvrefA1_1708.append(S4meanrefA1_1708[:,i].mean())
    S4hsvD4_108.append(S4meanD4_108[:,i].mean())

# %% [markdown]
# ###Img 9

# %%
S4meanrefA1_109 = list()
S4meanA1_209 = list()
for i in range(S4HSV_imgA1A1_9.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_9.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_109.append(S4HSV_imgA1A1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_209.append(S4HSV_imgA1A1_9[i][j])  
S4meanrefA1_109 = np.array(S4meanrefA1_109)
S4meanA1_209 = np.array(S4meanA1_209)

S4hsvrefA1_109 = list()
S4hsvA1_209 = list()
for i in range(3):
    S4hsvrefA1_109.append(S4meanrefA1_109[:,i].mean())
    S4hsvA1_209.append(S4meanA1_209[:,i].mean())
S4hsvrefA1_109,S4hsvA1_209

# %%
S4meanrefA1_309 = list()
S4meanA2_109 = list()
for i in range(S4HSV_imgA1A2_9.shape[0]): 
     for j in range(S4HSV_imgA1A2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_309.append(S4HSV_imgA1A2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_109.append(S4HSV_imgA1A2_9[i][j])  
S4meanrefA1_309 = np.array(S4meanrefA1_309)
S4meanA2_109 = np.array(S4meanA2_109)

S4hsvrefA1_309 = list()
S4hsvA2_109 = list()
for i in range(3):
    S4hsvrefA1_309.append(S4meanrefA1_309[:,i].mean())
    S4hsvA2_109.append(S4meanA2_109[:,i].mean())

# %%
S4meanrefA1_409 = list()
S4meanA3_109 = list()
for i in range(S4HSV_imgA1A3_9.shape[0]): 
     for j in range(S4HSV_imgA1A3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_409.append(HSV_imgA1A3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_109.append(S4HSV_imgA1A3_9[i][j])  
S4meanrefA1_409 = np.array(S4meanrefA1_409
S4meanA3_109 = np.array(S4meanA3_109)

S4hsvrefA1_409= list()
S4hsvA3_109 = list()
for i in range(3):
    S4hsvrefA1_409.append(S4meanrefA1_409[:,i].mean())
    S4hsvA3_109.append(S4meanA3_109[:,i].mean())

# %%
S4meanrefA1_509 = list()
S4meanA3_5109 = list()
for i in range(S4HSV_imgA1A3_59.shape[0]): 
     for j in range(S4HSV_imgA1A3_59.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_509.append(S4HSV_imgA1A3_59[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5109.append(S4HSV_imgA1A3_59[i][j])  
S4meanrefA1_509 = np.array(S4meanrefA1_509)
S4meanA3_5109 = np.array(S4meanA3_5109)

S4hsvrefA1_509 = list()
S4hsvA3_5109 = list()
for i in range(3):
    S4hsvrefA1_509.append(S4meanrefA1_509[:,i].mean())
    S4hsvA3_5109.append(S4meanA3_5109[:,i].mean())

# %%
S4meanrefA1_609 = list()
S4meanA4_109 = list()
for i in range(S4HSV_imgA1A4_9.shape[0]): 
     for j in range(S4HSV_imgA1A4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_609.append(S4HSV_imgA1A4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_109.append(S4HSV_imgA1A4_9[i][j])  
S4meanrefA1_609 = np.array(S4meanrefA1_609)
S4meanA4_109 = np.array(S4meanA4_109)

S4hsvrefA1_609 = list()
S4hsvA4_109 = list()
for i in range(3):
    S4hsvrefA1_609.append(S4meanrefA1_609[:,i].mean())
    S4hsvA4_109.append(S4meanA4_109[:,i].mean())

# %%
S4meanrefA1_709 = list()
S4meanB1_109 = list()
for i in range(S4HSV_imgA1B1_9.shape[0]): 
     for j in range(S4HSV_imgA1B1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_709.append(S4HSV_imgA1B1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_109.append(S4HSV_imgA1B1_9[i][j])  
S4meanrefA1_709 = np.array(S4meanrefA1_709)
S4meanB1_109 = np.array(S4meanB1_109)

S4hsvrefA1_709 = list()
S4hsvB1_109 = list()
for i in range(3):
    S4hsvrefA1_709.append(S4meanrefA1_709[:,i].mean())
    S4hsvB1_109.append(S4meanB1_109[:,i].mean())

# %%
S4meanrefA1_809 = list()
S4meanB2_109= list()
for i in range(S4HSV_imgA1B2_9.shape[0]): 
     for j in range(S4HSV_imgA1B2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_809.append(S4HSV_imgA1B2_[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_109.append(S4HSV_imgA1B2_9[i][j])  
S4meanrefA1_809 = np.array(S4meanrefA1_809)
S4meanB2_109 = np.array(S4meanB2_109)

S4hsvrefA1_809 = list()
S4hsvB2_109 = list()
for i in range(3):
    S4hsvrefA1_809.append(S4meanrefA1_809[:,i].mean())
    S4hsvB2_109.append(S4meanB2_109[:,i].mean())

# %%
S4meanrefA1_909 = list()
S4meanB3_109 = list()
for i in range(S4HSV_imgA1B3_9.shape[0]): 
     for j in range(S4HSV_imgA1B3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_909.append(S4HSV_imgA1B3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_109.append(S4HSV_imgA1B3_9[i][j])  
S4meanrefA1_909 = np.array(S4meanrefA1_909)
S4meanB3_109 = np.array(S4meanB3_109)

S4hsvrefA1_909 = list()
S4hsvB3_109 = list()
for i in range(3):
    S4hsvrefA1_909.append(S4meanrefA1_909[:,i].mean())
    S4hsvB3_109.append(S4meanB3_109[:,i].mean())

# %%
S4meanrefA1_1009 = list()
S4meanB4_109 = list()
for i in range(S4HSV_imgA1B4_9.shape[0]): 
     for j in range(S4HSV_imgA1B4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1009.append(S4HSV_imgA1B4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_109.append(S4HSV_imgA1B4_9[i][j])  
S4meanrefA1_1009= np.array(S4meanrefA1_1009)
S4meanB4_109 = np.array(S4meanB4_109)

ShsvrefA1_1009 = list()
S4hsvB4_109 = list()
for i in range(3):
    S4hsvrefA1_1009.append(S4meanrefA1_1009[:,i].mean())
    S4hsvB4_109.append(S4meanB4_109[:,i].mean())

# %%
S4meanrefA1_1109 = list()
S4meanC1_109 = list()
for i in range(S4HSV_imgA1C1_9.shape[0]): 
     for j in range(S4HSV_imgA1C1_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1109.append(S4HSV_imgA1C1_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_109.append(S4HSV_imgA1C1_9[i][j])  
S4meanrefA1_1109 = np.array(S4meanrefA1_1109)
S4meanC1_109 = np.array(S4meanC1_109)

S4hsvrefA1_1109 = list()
S4hsvC1_109 = list()
for i in range(3):
    S4hsvrefA1_1109.append(S4meanrefA1_1109[:,i].mean())
    S4hsvC1_109.append(S4meanC1_109[:,i].mean())

# %%
S4meanrefA1_1209 = list()
S4meanC2_109 = list()
for i in range(S4HSV_imgA1C2_909.shape[0]): 
     for j in range(S4HSV_imgA1C2_909.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1209.append(S4HSV_imgA1C2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_109.append(S4HSV_imgA1C2_9[i][j])  
S4meanrefA1_1209 = np.array(S4meanrefA1_1209)
S4meanC2_109 = np.array(S4meanC2_109)

S4hsvrefA1_1209 = list()
S4hsvC2_109= list()
for i in range(3):
    S4hsvrefA1_1209.append(S4meanrefA1_1209[:,i].mean())
    S4hsvC2_109.append(S4meanC2_109[:,i].mean())

# %%
S4meanrefA1_1309 = list()
S4meanC3_109 = list()
for i in range(S4HSV_imgA1C3_9.shape[0]): 
     for j in range(S4HSV_imgA1C3_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1309.append(S4HSV_imgA1C3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_109.append(S4HSV_imgA1C3_9[i][j])  
S4meanrefA1_1309 = np.array(S4meanrefA1_1309)
S4meanC3_109 = np.array(S4meanC3_109)

S4hsvrefA1_1309 = list()
S4hsvC3_109 = list()
for i in range(3):
    S4hsvrefA1_1309.append(S4meanrefA1_1309[:,i].mean())
    S4hsvC3_109.append(S4meanC3_109[:,i].mean())

# %%
S4meanrefA1_1409 = list()
S4meanC4_109 = list()
for i in range(S4HSV_imgA1C4_9.shape[0]): 
     for j in range(S4HSV_imgA1C4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                 S4meanrefA1_1409.append(S4HSV_imgA1C4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_109.append(S4HSV_imgA1C4_9[i][j])  
S4meanrefA1_1409 = np.array(S4meanrefA1_1409)
S4meanC4_109 = np.array(S4meanC4_109)

S4hsvrefA1_1409 = list()
S4hsvC4_109 = list()
for i in range(3):
   S4hsvrefA1_1409.append(S4meanrefA1_1409[:,i].mean())
   S4hsvC4_109.append(S4meanC4_109[:,i].mean())

# %%
S4meanrefA1_1509 = list()
S4meanD2_1v = list()
for i in range(S4HSV_imgA1D2_9.shape[0]): 
     for j in range(S4HSV_imgA1D2_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1509.append(S4HSV_imgA1D2_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_109.append(S4HSV_imgA1D2_9[i][j])  
S4meanrefA1_1509 = np.array(S4meanrefA1_1509)
S4meanD2_109 = np.array(S4meanD2_109)

S4hsvrefA1_1509 = list()
S4hsvD2_109 = list()
for i in range(3):
    S4hsvrefA1_1509.append(S4meanrefA1_1509[:,i].mean())
    S4hsvD2_109.append(S4meanD2_109[:,i].mean())

# %%
S4meanrefA1_1609 = list()
S4meanD3_109 = list()
for i in range(S4HSV_imgA1D3_9.shape[0]): 
     for j in range(S4HSV_imgA1D3_.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1609.append(S4HSV_imgA1D3_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_109.append(S4HSV_imgA1D3_9[i][j])  
S4meanrefA1_1609 = np.array(S4meanrefA1_1609)
S4meanD3_109= np.array(S4meanD3_109)

S4hsvrefA1_1609 = list()
S4hsvD3_109 = list()
for i in range(3):
    S4hsvrefA1_1609.append(S4meanrefA1_1609[:,i].mean())
    S4hsvD3_109.append(S4meanD3_109[:,i].mean())

# %%
S4meanrefA1_1709= list()
S4meanD4_109 = list()
for i in range(S4HSV_imgA1D4_9.shape[0]): 
     for j in range(S4HSV_imgA1D4_9.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1709.append(S4HSV_imgA1D4_9[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_109.append(S4HSV_imgA1D4_9[i][j])  
S4meanrefA1_1709 = np.array(S4meanrefA1_1409)
S4meanD4_109 = np.array(S4meanD4_109)

S4hsvrefA1_17v = list()
S4hsvD4_109 = list()
for i in range(3):
    S4hsvrefA1_1709.append(S4meanrefA1_1709[:,i].mean())
    S4hsvD4_109.append(S4meanD4_109[:,i].mean())

# %% [markdown]
# ###Img 10

# %%
S4meanrefA1_110 = list()
S4meanA1_210 = list()
for i in range(S4HSV_imgA1A1_10.shape[0]): #ให้ i รันตาม row หรือ shape[0] คือแถว มีทั้งหมด 4032 แถว ของภาพที่ปรับขนาดมาแล้ว
     for j in range(S4HSV_imgA1A1_10.shape[1]): #ให้ j รันตาม colum มีทั้งหมด 3024 colum เช่น แถวที่ 1 เข้ามาให้รันครบ 3024colum
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_110.append(S4HSV_imgA1A1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA1_210.append(S4HSV_imgA1A1_10[i][j])  
S4meanrefA1_110 = np.array(S4meanrefA1_110)
S4meanA1_210 = np.array(S4meanA1_210)

S4hsvrefA1_110 = list()
S4hsvA1_210 = list()
for i in range(3):
    S4hsvrefA1_110.append(S4meanrefA1_110[:,i].mean())
    S4hsvA1_210.append(S4meanA1_210[:,i].mean())
S4hsvrefA1_110,S4hsvA1_210

# %%
S4meanrefA1_310 = list()
S4meanA2_110 = list()
for i in range(S4HSV_imgA1A2_10.shape[0]): 
     for j in range(S4HSV_imgA1A2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_310.append(S4HSV_imgA1A2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA2_110.append(S4HSV_imgA1A2_10[i][j])  
S4meanrefA1_310 = np.array(S4meanrefA1_310)
S4meanA2_110 = np.array(S4meanA2_110)

S4hsvrefA1_310 = list()
S4hsvA2_110 = list()
for i in range(3):
    S4hsvrefA1_310.append(S4meanrefA1_310[:,i].mean())
    S4hsvA2_110.append(S4meanA2_110[:,i].mean())

# %%
S4meanrefA1_410 = list()
S4meanA3_110 = list()
for i in range(S4HSV_imgA1A3_10.shape[0]): 
     for j in range(S4HSV_imgA1A3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_410.append(S4HSV_imgA1A3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_110.append(S4HSV_imgA1A3_10[i][j])  
S4meanrefA1_410 = np.array(S4meanrefA1_410)
S4meanA3_110 = np.array(S4meanA3_110)

S4hsvrefA1_410 = list()
S4hsvA3_110 = list()
for i in range(3):
    S4hsvrefA1_410.append(S4meanrefA1_410[:,i].mean())
    S4hsvA3_110.append(S4meanA3_110[:,i].mean())

# %%
S4meanrefA1_510 = list()
S4meanA3_5110 = list()
for i in range(S4HSV_imgA1A3_510.shape[0]): 
     for j in range(S4HSV_imgA1A3_510.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_510.append(S4HSV_imgA1A3_510[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA3_5110.append(S4HSV_imgA1A3_510[i][j])  
S4meanrefA1_510 = np.array(S4meanrefA1_5v)
S4meanA3_5110 = np.array(S4meanA3_5110)

S4hsvrefA1_510 = list()
S4hsvA3_5110 = list()
for i in range(3):
    S4hsvrefA1_510.append(S4meanrefA1_510[:,i].mean())
    S4hsvA3_5110.append(S4meanA3_5110[:,i].mean())

# %%
S4meanrefA1_610 = list()
S4meanA4_110 = list()
for i in range(S4HSV_imgA1A4_10.shape[0]): 
     for j in range(S4HSV_imgA1A4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_610.append(S4HSV_imgA1A4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanA4_110.append(S4HSV_imgA1A4_10[i][j])  
S4meanrefA1_610 = np.array(S4meanrefA1_610)
S4meanA4_110 = np.array(S4meanA4_110)

S4hsvrefA1_610 = list()
S4hsvA4_110 = list()
for i in range(3):
    S4hsvrefA1_610.append(S4meanrefA1_610[:,i].mean())
    S4hsvA4_110.append(S4meanA4_110[:,i].mean())

# %%
S4meanrefA1_710 = list()
S4meanB1_110 = list()
for i in range(S4HSV_imgA1B1_10.shape[0]): 
     for j in range(S4HSV_imgA1B1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_710.append(S4HSV_imgA1B1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB1_110.append(S4HSV_imgA1B1_10[i][j])  
S4meanrefA1_710 = np.array(S4meanrefA1_710)
S4meanB1_110 = np.array(S4meanB1_110)

S4hsvrefA1_710 = list()
S4hsvB1_110 = list()
for i in range(3):
    S4hsvrefA1_710.append(S4meanrefA1_710[:,i].mean())
    S4hsvB1_110.append(S4meanB1_110[:,i].mean())

# %%
S4meanrefA1_810 = list()
S4meanB2_1v = list()
for i in range(S4HSV_imgA1B2_1010.shape[0]): 
     for j in range(S4HSV_imgA1B2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_810.append(S4HSV_imgA1B2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB2_110.append(S4HSV_imgA1B2_10[i][j])  
S4meanrefA1_810 = np.array(S4meanrefA1_810)
S4meanB2_110 = np.array(S4meanB2_110)

S4hsvrefA1_810 = list()
S4hsvB2_110 = list()
for i in range(3):
    S4hsvrefA1_810.append(S4meanrefA1_810[:,i].mean())
    S4hsvB2_110.append(S4meanB2_110[:,i].mean())

# %%
S4meanrefA1_910 = list()
S4meanB3_110 = list()
for i in range(S4HSV_imgA1B3_10.shape[0]): 
     for j in range(S4HSV_imgA1B3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_910.append(S4HSV_imgA1B3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB3_110.append(S4HSV_imgA1B3_10[i][j])  
S4meanrefA1_910 = np.array(S4meanrefA1_910)
S4meanB3_110 = np.array(S4meanB3_110)

S4hsvrefA1_910 = list()
S4hsvB3_110 = list()
for i in range(3):
    S4hsvrefA1_910.append(S4meanrefA1_910[:,i].mean())
    S4hsvB3_110.append(S4meanB3_110[:,i].mean())

# %%
S4meanrefA1_1010 = list()
S4meanB4_110 = list()
for i in range(S4HSV_imgA1B4_10.shape[0]): 
     for j in range(S4HSV_imgA1B4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1010.append(S4HSV_imgA1B4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanB4_110.append(S4HSV_imgA1B4_10[i][j])  
S4meanrefA1_1010 = np.array(S4meanrefA1_1010)
S4meanB4_110 = np.array(S4meanB4_110)

S4hsvrefA1_1010 = list()
S4hsvB4_110 = list()
for i in range(3):
    S4hsvrefA1_1010.append(S4meanrefA1_1010[:,i].mean())
    S4hsvB4_110.append(S4meanB4_110[:,i].mean())

# %%
S4meanrefA1_1110 = list()
S4meanC1_110 = list()
for i in range(S4HSV_imgA1C1_10.shape[0]): 
     for j in range(S4HSV_imgA1C1_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1110.append(S4HSV_imgA1C1_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC1_110.append(S4HSV_imgA1C1_10[i][j])  
S4meanrefA1_1110 = np.array(S4meanrefA1_1110)
S4meanC1_110 = np.array(S4meanC1_110)

S4hsvrefA1_1110 = list()
S4hsvC1_110 = list()
for i in range(3):
    S4hsvrefA1_1110.append(S4meanrefA1_1110[:,i].mean())
    S4hsvC1_110.append(S4meanC1_110[:,i].mean())

# %%
S4meanrefA1_1210 = list()
S4meanC2_110 = list()
for i in range(S4HSV_imgA1C2_10.shape[0]): 
     for j in range(S4HSV_imgA1C2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1210.append(S4HSV_imgA1C2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC2_110.append(S4HSV_imgA1C2_10[i][j])  
S4meanrefA1_1210 = np.array(S4meanrefA1_1210)
S4meanC2_110 = np.array(S4meanC2_110)

S4hsvrefA1_1210 = list()
S4hsvC2_110 = list()
for i in range(3):
    S4hsvrefA1_1210.append(S4meanrefA1_1210[:,i].mean())
    S4hsvC2_110.append(S4meanC2_110[:,i].mean())

# %%
S4meanrefA1_1310 = list()
S4meanC3_110 = list()
for i in range(S4HSV_imgA1C3_10.shape[0]): 
     for j in range(S4HSV_imgA1C3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1310.append(S4HSV_imgA1C3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC3_110.append(S4HSV_imgA1C3_10[i][j])  
S4meanrefA1_1310 = np.array(S4meanrefA1_1310)
S4meanC3_110 = np.array(S4meanC3_110)

S4hsvrefA1_1310 = list()
S4hsvC3_110 = list()
for i in range(3):
    S4hsvrefA1_1310.append(S4meanrefA1_1310[:,i].mean())
    S4hsvC3_110.append(S4meanC3_110[:,i].mean())

# %%
S4meanrefA1_1410 = list()
S4meanC4_110 = list()
for i in range(S4HSV_imgA1C4_10.shape[0]): 
     for j in range(S4HSV_imgA1C4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1410.append(S4HSV_imgA1C4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanC4_110.append(S4HSV_imgA1C4_10[i][j])  
S4meanrefA1_1410 = np.array(S4meanrefA1_1410)
S4meanC4_110 = np.array(S4meanC4_110)

S4hsvrefA1_1410 = list()
S4hsvC4_110 = list()
for i in range(3):
    S4hsvrefA1_1410.append(S4meanrefA1_1410[:,i].mean())
    S4hsvC4_110.append(S4meanC4_110[:,i].mean())

# %%
S4meanrefA1_1510 = list()
S4meanD2_110 = list()
for i in range(S4HSV_imgA1D2_10.shape[0]): 
     for j in range(S4HSV_imgA1D2_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1510.append(S4HSV_imgA1D2_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD2_110.append(S4HSV_imgA1D2_10[i][j])  
S4meanrefA1_1510 = np.array(S4meanrefA1_1510)
S4meanD2_110 = np.array(S4meanD2_110)

S4hsvrefA1_1510 = list()
S4hsvD2_110 = list()
for i in range(3):
    S4hsvrefA1_15v.append(S4meanrefA1_1510[:,i].mean())
    S4hsvD2_110.append(S4meanD2_110[:,i].mean())

# %%
S4meanrefA1_1610 = list()
S4meanD3_110 = list()
for i in range(S4HSV_imgA1D3_10.shape[0]): 
     for j in range(S4HSV_imgA1D3_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1610.append(S4HSV_imgA1D3_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD3_110.append(S4HSV_imgA1D3_10[i][j])  
S4meanrefA1_1610 = np.array(S4meanrefA1_1610)
S4meanD3_110 = np.array(S4meanD3_110)

S4hsvrefA1_1610 = list()
S4hsvD3_110 = list()
for i in range(3):
    S4hsvrefA1_1610.append(S4meanrefA1_1610[:,i].mean())
    S4hsvD3_110.append(S4meanD3_110[:,i].mean())

# %%
S4meanrefA1_1710= list()
S4meanD4_110 = list()
for i in range(S4HSV_imgA1D4_10.shape[0]): 
     for j in range(S4HSV_imgA1D4_10.shape[1]): 
                if 1769<i<1881 and 2019<j<2131 :
                  S4meanrefA1_1710.append(S4HSV_imgA1D4_10[i][j])
                if 1770<i<1880 and 2015<j<2145 :
                  S4meanD4_110.append(S4HSV_imgA1D4_10[i][j])  
S4meanrefA1_1710= np.array(S4meanrefA1_1410)
S4meanD4_110 = np.array(S4meanD4_110)

S4hsvrefA1_1710 = list()
S4hsvD4_110 = list()
for i in range(3):
    S4hsvrefA1_1710.append(S4meanrefA1_1710[:,i].mean())
    S4hsvD4_110.append(S4meanD4_110[:,i].mean())

# %% [markdown]
# #7.สร้างตาราง

# %%
from tabulate import tabulate

# %%
table   = [['R-ref', 'G-ref', 'B-ref', 'R-Shad', 'G-Shad', 'B-Shad', 'H-ref', 'S-ref', 'V-ref', 'H-Shad', 'S-Shad', 'V-Shad', 'Shade-ref', 'Shade', 'Setting']]

# %%
df = pd.DataFrame({'R-ref': [S1rgbrefA1_1[0],S1rgbrefA1_3[0],S1rgbrefA1_4[0], S1rgbrefA1_5[0], S1rgbrefA1_6[0],S1rgbrefA1_7[0], S1rgbrefA1_8[0],S1rgbrefA1_9[0], S1rgbrefA1_10[0], S1rgbrefA1_11[0], S1rgbrefA1_12[0], S1rgbrefA1_13[0], S1rgbrefA1_14[0], S1rgbrefA1_15[0], S1rgbrefA1_16[0], S1rgbrefA1_17[0]],
  'G-ref': [S1rgbrefA1_1[1], S1rgbrefA1_3[1], S1rgbrefA1_4[1], S1rgbrefA1_5[1], S1rgbrefA1_6[1], S1rgbrefA1_7[1], S1rgbrefA1_8[1], S1rgbrefA1_9[1], S1rgbrefA1_10[1], S1rgbrefA1_11[1], S1rgbrefA1_12[1], S1rgbrefA1_13[1], S1rgbrefA1_14[1], S1rgbrefA1_15[1], S1rgbrefA1_16[1], S1rgbrefA1_17[1]],
  'B-ref': [S1rgbrefA1_1[2],S1rgbrefA1_3[2],S1rgbrefA1_4[2],S1rgbrefA1_5[2], S1rgbrefA1_6[2],S1rgbrefA1_7[2], S1rgbrefA1_8[2],S1rgbrefA1_9[2], S1rgbrefA1_10[2],S1rgbrefA1_11[2], S1rgbrefA1_12[2],S1rgbrefA1_13[2], S1rgbrefA1_14[2],S1rgbrefA1_15[2], S1rgbrefA1_16[2],S1rgbrefA1_17[2]],
  'R-Shad': [S1rgbA1_2[0],S1rgbA2_1[0],S1rgbA3_1[0],S1rgbA3_51[0],S1rgbA4_1[0],S1rgbB1_1[0],S1rgbB2_1[0],S1rgbB3_1[0],S1rgbB4_1[0],S1rgbC1_1[0],S1rgbC2_1[0],S1rgbC3_1[0],S1rgbC4_1[0],S1rgbD2_1[0],S1rgbD3_1[0],S1rgbD4_1[0]],
  'G-Shad': [S1rgbA1_2[1],S1rgbA2_1[1],S1rgbA3_1[1], S1rgbA3_51[1],S1rgbA4_1[1],S1rgbB1_1[1],S1rgbB2_1[1],S1rgbB3_1[1],S1rgbB4_1[1],S1rgbC1_1[1],S1rgbC2_1[1],S1rgbC3_1[1],S1rgbC4_1[1],S1rgbD2_1[1],S1rgbD3_1[1], S1rgbD4_1[1]],
  'B-Shad': [S1rgbA1_2[2],S1rgbA2_1[2],S1rgbA3_1[2],S1rgbA3_51[2],S1rgbA4_1[2],S1rgbB1_1[2],S1rgbB2_1[2],S1rgbB3_1[2],S1rgbB4_1[2],S1rgbC1_1[2],S1rgbC2_1[2],S1rgbC3_1[2],S1rgbC4_1[2],S1rgbD2_1[2],S1rgbD3_1[2], S1rgbD4_1[2]],
  'H-ref': [S1hsvrefA1_1[0],S1hsvrefA1_3[0],S1hsvrefA1_4[0],S1hsvrefA1_5[0], S1hsvrefA1_6[0],S1hsvrefA1_7[0], S1hsvrefA1_8[0],S1hsvrefA1_9[0], S1hsvrefA1_10[0],S1hsvrefA1_11[0], S1hsvrefA1_12[0],S1hsvrefA1_13[0], S1hsvrefA1_14[0],S1hsvrefA1_15[0], S1hsvrefA1_16[0],S1hsvrefA1_17[0]],
  'S-ref': [S1hsvrefA1_1[1],S1hsvrefA1_3[1],S1hsvrefA1_4[1],S1hsvrefA1_5[1], S1hsvrefA1_6[1],S1hsvrefA1_7[1], S1hsvrefA1_8[1],S1hsvrefA1_9[1], S1hsvrefA1_10[1],S1hsvrefA1_11[1], S1hsvrefA1_12[0],S1hsvrefA1_13[1], S1hsvrefA1_14[1],S1hsvrefA1_15[1], S1hsvrefA1_16[1],S1hsvrefA1_17[1]],
  'V-ref': [S1hsvrefA1_1[2],S1hsvrefA1_3[2],S1hsvrefA1_4[2],S1hsvrefA1_5[2], S1hsvrefA1_6[2],S1hsvrefA1_7[2], S1hsvrefA1_8[2],S1hsvrefA1_9[2], S1hsvrefA1_10[2],S1hsvrefA1_11[2], S1hsvrefA1_12[0],S1hsvrefA1_13[2], S1hsvrefA1_14[2],S1hsvrefA1_15[2], S1hsvrefA1_16[2],S1hsvrefA1_17[2]],
   'H-Shad': [S1hsvA1_2[0],S1hsvA2_1[0],S1hsvA3_1[0],S1hsvA3_51[0],S1hsvA4_1[0],S1hsvB1_1[0],S1hsvB2_1[0],S1hsvB3_1[0],S1hsvB4_1[0],S1hsvC1_1[0],S1hsvC2_1[0],S1hsvC3_1[0],S1hsvC4_1[0],S1hsvD2_1[0],S1hsvD3_1[0],S1hsvD4_1[0]],
   'S-Shad': [S1hsvA1_2[1],S1hsvA2_1[1],S1hsvA3_1[1],S1hsvA3_51[1],S1hsvA4_1[1],S1hsvB1_1[1],S1hsvB2_1[1],S1hsvB3_1[1],S1hsvB4_1[1],S1hsvC1_1[1],S1hsvC2_1[1],S1hsvC3_1[1],S1hsvC4_1[1],S1hsvD2_1[1],S1hsvD3_1[1],S1hsvD4_1[1]],
   'V-Shad': [S1hsvA1_2[2],S1hsvA2_1[2],S1hsvA3_1[2],S1hsvA3_51[2],S1hsvA4_1[2],S1hsvB1_1[2],S1hsvB2_1[2],S1hsvB3_1[2],S1hsvB4_1[2],S1hsvC1_1[2],S1hsvC2_1[2],S1hsvC3_1[2],S1hsvC4_1[2],S1hsvD2_1[2],S1hsvD3_1[2],S1hsvD4_1[2]],
   'Shade-ref': ['B2', 'B2', 'B2',  'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2', 'B2'],
   'Shade':      ['A1', 'A2', 'A3', 'A3_5', 'A4', 'B1', 'B2', 'B3', 'B4', 'C1', 'C2', 'C3', 'C4', 'D2', 'D3', 'D4'],
   'Setting':     ['Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1'],
   'Img' : [S1_doubleA1A1_1, S1_doubleA1A2_1, S1_doubleA1A3_1, S1_doubleA1A3_51, S1_doubleA1A4_1, S1_doubleA1B1_1, S1_doubleA1B2_1, S1_doubleA1B3_1, S1_doubleA1B4_1, S1_doubleA1C1_1 ,S1_doubleA1C2_1, S1_doubleA1C3_1, S1_doubleA1C4_1,S1_doubleA1D2_1, S1_doubleA1D3_1, S1_doubleA1D4_1]})

# %%
df = pd.DataFrame({'R-ref':[S1rgbrefA1_1[0],S1rgbrefA1_102[0],S1rgbrefA1_103[0],S1rgbrefA1_104[0],S1rgbrefA1_105[0],S1rgbrefA1_106[0],S1rgbrefA1_107[0],S1rgbrefA1_108[0],S1rgbrefA1_109[0],S1rgbrefA1_110[0],
S1rgbrefA1_3[0],S1rgbrefA1_302[0],S1rgbrefA1_303[0],S1rgbrefA1_304[0],S1rgbrefA1_305[0], S1rgbrefA1_306[0],S1rgbrefA1_307[0],S1rgbrefA1_308[0],S1rgbrefA1_309[0],S1rgbrefA1_3010[0],
S1rgbrefA1_4[0], S1rgbrefA1_402[0], S1rgbrefA1_403[0], S1rgbrefA1_404[0], S1rgbrefA1_405[0],S1rgbrefA1_406[0], S1rgbrefA1_407[0], S1rgbrefA1_408[0], S1rgbrefA1_409[0], S1rgbrefA1_410[0],
S1rgbrefA1_5[0], S1rgbrefA1_502[0], S1rgbrefA1_503[0], S1rgbrefA1_504[0], S1rgbrefA1_505[0],S1rgbrefA1_506[0], S1rgbrefA1_507[0], S1rgbrefA1_508[0], S1rgbrefA1_509[0], S1rgbrefA1_510[0],
S1rgbrefA1_6[0], S1rgbrefA1_602[0], S1rgbrefA1_603[0], S1rgbrefA1_604[0], S1rgbrefA1_605[0],S1rgbrefA1_606[0], S1rgbrefA1_607[0], S1rgbrefA1_608[0], S1rgbrefA1_609[0], S1rgbrefA1_610[0],
S1rgbrefA1_7[0], S1rgbrefA1_702[0], S1rgbrefA1_703[0], S1rgbrefA1_704[0],S1rgbrefA1_705[0], S1rgbrefA1_706[0], S1rgbrefA1_707[0], S1rgbrefA1_708[0], S1rgbrefA1_709[0], S1rgbrefA1_710[0],
S1rgbrefA1_8[0], S1rgbrefA1_802[0], S1rgbrefA1_803[0], S1rgbrefA1_804[0], S1rgbrefA1_805[0],S1rgbrefA1_806[0], S1rgbrefA1_807[0], S1rgbrefA1_808[0], S1rgbrefA1_809[0], S1rgbrefA1_810[0],
S1rgbrefA1_9[0], S1rgbrefA1_902[0], S1rgbrefA1_903[0], S1rgbrefA1_904[0], S1rgbrefA1_905[0],S1rgbrefA1_906[0], S1rgbrefA1_907[0], S1rgbrefA1_908[0], S1rgbrefA1_909[0], S1rgbrefA1_910[0],
S1rgbrefA1_10[0], S1rgbrefA1_1002[0], S1rgbrefA1_1003[0], S1rgbrefA1_1004[0], S1rgbrefA1_1005[0],  S1rgbrefA1_1006[0], S1rgbrefA1_1007[0], S1rgbrefA1_1008[0], S1rgbrefA1_1009[0], S1rgbrefA1_1010[0],        
S1rgbrefA1_11[0], S1rgbrefA1_1102[0], S1rgbrefA1_1103[0], S1rgbrefA1_1104[0], S1rgbrefA1_1105[0],S1rgbrefA1_1106[0],S1rgbrefA1_1107[0], S1rgbrefA1_1108[0], S1rgbrefA1_1109[0], S1rgbrefA1_1110[0],
S1rgbrefA1_12[0], S1rgbrefA1_1202[0], S1rgbrefA1_1203[0], S1rgbrefA1_1204[0], S1rgbrefA1_1205[0],S1rgbrefA1_1206[0],S1rgbrefA1_1207[0], S1rgbrefA1_1208[0], S1rgbrefA1_1209[0], S1rgbrefA1_1210[0],
S1rgbrefA1_13[0], S1rgbrefA1_1302[0], S1rgbrefA1_1303[0], S1rgbrefA1_1304[0], S1rgbrefA1_1305[0], S1rgbrefA1_1306[0], S1rgbrefA1_1307[0], S1rgbrefA1_1308[0], S1rgbrefA1_1309[0], S1rgbrefA1_1310[0],
S1rgbrefA1_14[0], S1rgbrefA1_1402[0], S1rgbrefA1_1403[0], S1rgbrefA1_1404[0], S1rgbrefA1_1405[0],  S1rgbrefA1_1406[0], S1rgbrefA1_1407[0], S1rgbrefA1_1408[0], S1rgbrefA1_1409[0], S1rgbrefA1_1410[0], 
S1rgbrefA1_15[0], S1rgbrefA1_1502[0], S1rgbrefA1_1503[0], S1rgbrefA1_1504[0], S1rgbrefA1_1505[0], S1rgbrefA1_1506[0], S1rgbrefA1_1507[0], S1rgbrefA1_1508[0], S1rgbrefA1_1509[0], S1rgbrefA1_1510[0], 
S1rgbrefA1_16[0], S1rgbrefA1_1602[0], S1rgbrefA1_1603[0], S1rgbrefA1_1604[0], S1rgbrefA1_1605[0], S1rgbrefA1_1606[0], S1rgbrefA1_1607[0], S1rgbrefA1_1608[0], S1rgbrefA1_1609[0], S1rgbrefA1_1610[0], 
S1rgbrefA1_17[0], S1rgbrefA1_1702[0], S1rgbrefA1_1703[0], S1rgbrefA1_1704[0], S1rgbrefA1_1705[0], S1rgbrefA1_1706[0], S1rgbrefA1_1707[0], S1rgbrefA1_1708[0], S1rgbrefA1_1709[0], S1rgbrefA1_1710[0]], 
'G-ref': [S1rgbrefA1_1[1],S1rgbrefA1_102[1],S1rgbrefA1_103[1],S1rgbrefA1_104[1],S1rgbrefA1_105[1],S1rgbrefA1_106[1],S1rgbrefA1_107[1],S1rgbrefA1_108[1],S1rgbrefA1_109[1],S1rgbrefA1_110[1],
S1rgbrefA1_3[1],S1rgbrefA1_302[1],S1rgbrefA1_303[1],S1rgbrefA1_304[1],S1rgbrefA1_305[1], S1rgbrefA1_306[1],S1rgbrefA1_307[1],S1rgbrefA1_308[1],S1rgbrefA1_309[1],S1rgbrefA1_3010[1],
S1rgbrefA1_4[1], S1rgbrefA1_402[1], S1rgbrefA1_403[1], S1rgbrefA1_404[1], S1rgbrefA1_405[1],S1rgbrefA1_406[1], S1rgbrefA1_407[1], S1rgbrefA1_408[1], S1rgbrefA1_409[1], S1rgbrefA1_410[1],
S1rgbrefA1_5[1], S1rgbrefA1_502[1], S1rgbrefA1_503[1], S1rgbrefA1_504[1], S1rgbrefA1_505[1],S1rgbrefA1_506[1], S1rgbrefA1_507[1], S1rgbrefA1_508[1], S1rgbrefA1_509[1], S1rgbrefA1_510[1],
S1rgbrefA1_6[1], S1rgbrefA1_602[1], S1rgbrefA1_603[1], S1rgbrefA1_604[1], S1rgbrefA1_605[1],S1rgbrefA1_606[1], S1rgbrefA1_607[1], S1rgbrefA1_608[1], S1rgbrefA1_609[1], S1rgbrefA1_610[1],
S1rgbrefA1_7[1], S1rgbrefA1_702[1], S1rgbrefA1_703[1], S1rgbrefA1_704[1],S1rgbrefA1_705[1], S1rgbrefA1_706[1], S1rgbrefA1_707[1], S1rgbrefA1_708[1], S1rgbrefA1_709[1], S1rgbrefA1_710[1],
S1rgbrefA1_8[1], S1rgbrefA1_802[1],S1rgbrefA1_803[1], S1rgbrefA1_804[1], S1rgbrefA1_805[1],S1rgbrefA1_806[1], S1rgbrefA1_807[1], S1rgbrefA1_808[1], S1rgbrefA1_809[1], S1rgbrefA1_810[1],
S1rgbrefA1_9[1], S1rgbrefA1_902[1], S1rgbrefA1_903[1], S1rgbrefA1_904[1], S1rgbrefA1_905[1],S1rgbrefA1_906[1],S1rgbrefA1_907[1], S1rgbrefA1_908[1], S1rgbrefA1_909[1], S1rgbrefA1_910[1],
S1rgbrefA1_10[1], S1rgbrefA1_1002[1], S1rgbrefA1_1003[1], S1rgbrefA1_1004[1], S1rgbrefA1_1005[1],  S1rgbrefA1_1006[1], S1rgbrefA1_1007[1], S1rgbrefA1_1008[1], S1rgbrefA1_1009[1], S1rgbrefA1_1010[1],        
S1rgbrefA1_11[1], S1rgbrefA1_1102[1], S1rgbrefA1_1103[1], S1rgbrefA1_1104[1], S1rgbrefA1_1105[1],S1rgbrefA1_1106[1],S1rgbrefA1_1107[1], S1rgbrefA1_1108[1], S1rgbrefA1_1109[1], S1rgbrefA1_1110[1],
S1rgbrefA1_12[1],S1rgbrefA1_1202[1], S1rgbrefA1_1203[1], S1rgbrefA1_1204[1], S1rgbrefA1_1205[1],S1rgbrefA1_1206[1], S1rgbrefA1_1207[1],S1rgbrefA1_1208[1], S1rgbrefA1_1209[1], S1rgbrefA1_1210[1],
S1rgbrefA1_13[1], S1rgbrefA1_1302[1], S1rgbrefA1_1303[1], S1rgbrefA1_1304[1], S1rgbrefA1_1305[1], S1rgbrefA1_1306[1], S1rgbrefA1_1307[1], S1rgbrefA1_1308[1], S1rgbrefA1_1309[1], S1rgbrefA1_1310[1],
S1rgbrefA1_14[1], S1rgbrefA1_1402[1], S1rgbrefA1_1403[1], S1rgbrefA1_1404[1], S1rgbrefA1_1405[1],  S1rgbrefA1_1406[1], S1rgbrefA1_1407[1], S1rgbrefA1_1408[1], S1rgbrefA1_1409[1], S1rgbrefA1_1410[1], 
S1rgbrefA1_15[1], S1rgbrefA1_1502[1], S1rgbrefA1_1503[1], S1rgbrefA1_1504[1], S1rgbrefA1_1505[1], S1rgbrefA1_1506[1], S1rgbrefA1_1507[1], S1rgbrefA1_1508[1], S1rgbrefA1_1509[1], S1rgbrefA1_1510[1], 
S1rgbrefA1_16[1], S1rgbrefA1_1602[1], S1rgbrefA1_1603[1], S1rgbrefA1_1604[1], S1rgbrefA1_1605[1], S1rgbrefA1_1606[1], S1rgbrefA1_1607[1], S1rgbrefA1_1608[1], S1rgbrefA1_1609[1], S1rgbrefA1_1610[1], 
S1rgbrefA1_17[1], S1rgbrefA1_1702[1], S1rgbrefA1_1703[1], S1rgbrefA1_1704[1], S1rgbrefA1_1705[1], S1rgbrefA1_1706[1], S1rgbrefA1_1707[1], S1rgbrefA1_1708[1], S1rgbrefA1_1709[1], S1rgbrefA1_1710[1]], 
'B-ref': [S1rgbrefA1_1[2],S1rgbrefA1_102[2],S1rgbrefA1_103[2],S1rgbrefA1_104[2],S1rgbrefA1_105[2],S1rgbrefA1_106[2],S1rgbrefA1_107[2],S1rgbrefA1_108[2],S1rgbrefA1_109[2],S1rgbrefA1_110[2],
S1rgbrefA1_3[2],S1rgbrefA1_302[2],S1rgbrefA1_303[2],S1rgbrefA1_304[2],S1rgbrefA1_305[2], S1rgbrefA1_306[2],S1rgbrefA1_307[2],S1rgbrefA1_308[2],S1rgbrefA1_309[2],S1rgbrefA1_3010[2],
S1rgbrefA1_4[2], S1rgbrefA1_402[2], S1rgbrefA1_403[2], S1rgbrefA1_404[2], S1rgbrefA1_405[2],S1rgbrefA1_406[2], S1rgbrefA1_407[2],S1rgbrefA1_408[2], S1rgbrefA1_409[2], S1rgbrefA1_410[2],
S1rgbrefA1_5[2], S1rgbrefA1_502[2], S1rgbrefA1_503[2], S1rgbrefA1_504[2], S1rgbrefA1_505[2],S1rgbrefA1_506[2], S1rgbrefA1_507[2], S1rgbrefA1_508[2], S1rgbrefA1_509[2], S1rgbrefA1_510[2],
S1rgbrefA1_6[2], S1rgbrefA1_602[2], S1rgbrefA1_603[2], S1rgbrefA1_604[2], S1rgbrefA1_605[2],S1rgbrefA1_606[2], S1rgbrefA1_607[2], S1rgbrefA1_608[2], S1rgbrefA1_609[2], S1rgbrefA1_610[2],
S1rgbrefA1_7[2], S1rgbrefA1_702[2], S1rgbrefA1_703[2], S1rgbrefA1_704[2],S1rgbrefA1_705[2], S1rgbrefA1_706[2], S1rgbrefA1_707[2], S1rgbrefA1_708[2], S1rgbrefA1_709[2], S1rgbrefA1_710[2],
S1rgbrefA1_8[2], S1rgbrefA1_802[2], S1rgbrefA1_803[2], S1rgbrefA1_804[2], S1rgbrefA1_805[2],S1rgbrefA1_806[2], S1rgbrefA1_807[2], S1rgbrefA1_808[2], S1rgbrefA1_809[2], S1rgbrefA1_810[2],
S1rgbrefA1_9[2], S1rgbrefA1_902[2], S1rgbrefA1_903[2], S1rgbrefA1_904[2], S1rgbrefA1_905[2],S1rgbrefA1_906[2], S1rgbrefA1_907[2], S1rgbrefA1_908[2], S1rgbrefA1_909[2], S1rgbrefA1_910[2],
S1rgbrefA1_10[2], S1rgbrefA1_1002[2], S1rgbrefA1_1003[2], S1rgbrefA1_1004[2], S1rgbrefA1_1005[2],  S1rgbrefA1_1006[2], S1rgbrefA1_1007[2], S1rgbrefA1_1008[2], S1rgbrefA1_1009[2], S1rgbrefA1_1010[2],        
S1rgbrefA1_11[2], S1rgbrefA1_1102[2], S1rgbrefA1_1103[2], S1rgbrefA1_1104[2], S1rgbrefA1_1105[2],S1rgbrefA1_1106[2],S1rgbrefA1_1107[2], S1rgbrefA1_1108[2], S1rgbrefA1_1109[2], S1rgbrefA1_1110[2],
S1rgbrefA1_12[2], S1rgbrefA1_1202[2], S1rgbrefA1_1203[2], S1rgbrefA1_1204[2], S1rgbrefA1_1205[2],S1rgbrefA1_1206[2], S1rgbrefA1_1207[2], S1rgbrefA1_1208[2], S1rgbrefA1_1209[2], S1rgbrefA1_1210[2],
S1rgbrefA1_13[2], S1rgbrefA1_1302[2], S1rgbrefA1_1303[2], S1rgbrefA1_1304[2], S1rgbrefA1_1305[2], S1rgbrefA1_1306[2], S1rgbrefA1_1307[2], S1rgbrefA1_1308[2], S1rgbrefA1_1309[2], S1rgbrefA1_1310[2],
S1rgbrefA1_14[2], S1rgbrefA1_1402[2], S1rgbrefA1_1403[2], S1rgbrefA1_1404[2], S1rgbrefA1_1405[2],  S1rgbrefA1_1406[2], S1rgbrefA1_1407[2], S1rgbrefA1_1408[2], S1rgbrefA1_1409[2], S1rgbrefA1_1410[2], 
S1rgbrefA1_15[2], S1rgbrefA1_1502[2], S1rgbrefA1_1503[2], S1rgbrefA1_1504[2], S1rgbrefA1_1505[2], S1rgbrefA1_1506[2], S1rgbrefA1_1507[2], S1rgbrefA1_1508[2], S1rgbrefA1_1509[2], S1rgbrefA1_1510[2], 
S1rgbrefA1_16[2], S1rgbrefA1_1602[2], S1rgbrefA1_1603[2], S1rgbrefA1_1604[2], S1rgbrefA1_1605[2], S1rgbrefA1_1606[2], S1rgbrefA1_1607[2], S1rgbrefA1_1608[2], S1rgbrefA1_1609[2], S1rgbrefA1_1610[2], 
S1rgbrefA1_17[2], S1rgbrefA1_1702[2], S1rgbrefA1_1703[2], S1rgbrefA1_1704[2], S1rgbrefA1_1705[2], S1rgbrefA1_1706[2], S1rgbrefA1_1707[2], S1rgbrefA1_1708[2], S1rgbrefA1_1709[2], S1rgbrefA1_1710[2]], 
'R-Shad':  [S1rgbA1_2[0], S1rgbA1_202[0], S1rgbA1_203[0], S1rgbA1_204[0], S1rgbA1_205[0], S1rgbA1_206[0],S1rgbA1_207[0],S1rgbA1_208[0],S1rgbA1_209[0],S1rgbA1_210[0],
S1rgbA2_1[0], S1rgbA2_102[0],  S1rgbA2_103[0], S1rgbA2_104[0], S1rgbA2_105[0], S1rgbA2_106[0],  S1rgbA2_107[0],  S1rgbA2_108[0],  S1rgbA2_109[0],S1rgbA2_110[0],
S1rgbA3_1[0], S1rgbA3_102[0],S1rgbA3_103[0],S1rgbA3_104[0],S1rgbA3_105[0],S1rgbA3_106[0],S1rgbA3_107[0],S1rgbA3_108[0], S1rgbA3_109[0], S1rgbA3_110[0],
S1rgbA3_51[0],S1rgbA3_5102[0],S1rgbA3_5103[0],S1rgbA3_5104[0],  S1rgbA3_5105[0],S1rgbA3_5106[0],S1rgbA3_5107[0],S1rgbA3_5108[0],S1rgbA3_5109[0],  S1rgbA3_5110[0],
S1rgbA4_1[0],S1rgbA4_102[0], S1rgbA4_103[0],S1rgbA4_104[0],S1rgbA4_105[0],S1rgbA4_106[0], S1rgbA4_107[0], S1rgbA4_108[0],S1rgbA4_109[0],S1rgbA4_110[0],
S1rgbB1_1[0],S1rgbB1_102[0],S1rgbB1_103[0],S1rgbB1_104[0],S1rgbB1_105[0],S1rgbB1_106[0],S1rgbB1_107[0],S1rgbB1_108[0],S1rgbB1_109[0],S1rgbB1_110[0],
S1rgbB2_1[0],S1rgbB2_102[0],S1rgbB2_103[0],S1rgbB2_104[0],S1rgbB2_105[0],S1rgbB2_106[0],S1rgbB2_107[0],S1rgbB2_108[0],S1rgbB2_109[0],S1rgbB2_110[0],
S1rgbB3_1[0],S1rgbB3_102[0],S1rgbB3_103[0],S1rgbB3_104[0],S1rgbB3_105[0],S1rgbB3_106[0],S1rgbB3_107[0],S1rgbB3_108[0],S1rgbB3_109[0],S1rgbB3_110[0],
S1rgbB4_1[0],S1rgbB4_102[0],S1rgbB4_103[0],S1rgbB4_104[0],S1rgbB4_105[0],S1rgbB4_106[0],S1rgbB4_107[0],S1rgbB4_108[0],S1rgbB4_109[0],S1rgbB4_110[0],
S1rgbC1_1[0],S1rgbC1_102[0],S1rgbC1_103[0],S1rgbC1_104[0],S1rgbC1_105[0],S1rgbC1_106[0],S1rgbC1_107[0],S1rgbC1_108[0],S1rgbC1_109[0],S1rgbC1_110[0],
S1rgbC2_1[0],S1rgbC2_102[0],S1rgbC2_103[0],S1rgbC2_104[0],S1rgbC2_105[0],S1rgbC2_106[0],S1rgbC2_107[0],S1rgbC2_108[0],S1rgbC2_109[0],S1rgbC2_110[0],
S1rgbC3_1[0],S1rgbC3_102[0],S1rgbC3_103[0],S1rgbC3_104[0],S1rgbC3_105[0],S1rgbC3_106[0],S1rgbC3_107[0],S1rgbC3_108[0],S1rgbC3_109[0],S1rgbC3_110[0],
S1rgbC4_1[0],S1rgbC4_102[0],S1rgbC4_103[0],S1rgbC4_104[0],S1rgbC4_105[0],S1rgbC4_106[0],S1rgbC4_107[0],S1rgbC4_108[0],S1rgbC4_109[0],S1rgbC4_110[0],
S1rgbD2_1[0],S1rgbD2_102[0],S1rgbD2_103[0],S1rgbD2_104[0],S1rgbD2_105[0],S1rgbD2_106[0],S1rgbD2_107[0],S1rgbD2_108[0],S1rgbD2_109[0],S1rgbD2_110[0],
S1rgbD3_1[0],S1rgbD3_102[0],S1rgbD3_103[0],S1rgbD3_104[0],S1rgbD3_105[0],S1rgbD3_106[0],S1rgbD3_107[0],S1rgbD3_108[0],S1rgbD3_109[0],S1rgbD3_110[0],
S1rgbD4_1[0],S1rgbD4_102[0],S1rgbD4_103[0],S1rgbD4_104[0],S1rgbD4_105[0],S1rgbD4_106[0],S1rgbD4_107[0],S1rgbD4_108[0],S1rgbD4_109[0],S1rgbD4_110[0]],
'G-Shad':[S1rgbA1_2[1],S1rgbA1_202[1],S1rgbA1_203[1],S1rgbA1_204[1],S1rgbA1_205[1],S1rgbA1_206[1],S1rgbA1_207[1],S1rgbA1_208[1],S1rgbA1_209[1],S1rgbA1_210[1],
S1rgbA2_1[1],S1rgbA2_102[1],S1rgbA2_103[1],S1rgbA2_104[1],S1rgbA2_105[1],S1rgbA2_106[1],S1rgbA2_107[1],S1rgbA2_108[1],S1rgbA2_109[1],S1rgbA2_110[1],
S1rgbA3_1[1],S1rgbA3_102[1],S1rgbA3_103[1],S1rgbA3_104[1],S1rgbA3_105[1],S1rgbA3_106[1],S1rgbA3_107[1],S1rgbA3_108[1],S1rgbA3_109[1], S1rgbA3_110[1],
S1rgbA3_51[1], S1rgbA3_5102[1], S1rgbA3_5103[1],S1rgbA3_5104[1],  S1rgbA3_5105[1],S1rgbA3_5106[1], S1rgbA3_5107[1],S1rgbA3_5108[1],S1rgbA3_5109[1],  S1rgbA3_5110[1],
S1rgbA4_1[1],S1rgbA4_102[1],S1rgbA4_103[1],S1rgbA4_104[1],S1rgbA4_105[1],S1rgbA4_106[1],S1rgbA4_107[1],S1rgbA4_108[1],S1rgbA4_109[1],S1rgbA4_110[1],
S1rgbB1_1[1],S1rgbB1_102[1],S1rgbB1_103[1],S1rgbB1_104[1],S1rgbB1_105[1],S1rgbB1_106[1],S1rgbB1_107[1],S1rgbB1_108[1],S1rgbB1_109[1],S1rgbB1_110[1],
S1rgbB2_1[1],S1rgbB2_102[1],S1rgbB2_103[1],S1rgbB2_104[1],S1rgbB2_105[1],S1rgbB2_106[1],S1rgbB2_107[1],S1rgbB2_108[1],S1rgbB2_109[1],S1rgbB2_110[1],
S1rgbB3_1[1],S1rgbB3_102[1],S1rgbB3_103[1],S1rgbB3_104[1],S1rgbB3_105[1],S1rgbB3_106[1],S1rgbB3_107[1],S1rgbB3_108[1],S1rgbB3_109[1],S1rgbB3_110[1],
S1rgbB4_1[1],S1rgbB4_102[1],S1rgbB4_103[1],S1rgbB4_104[1],S1rgbB4_105[1],S1rgbB4_106[1],S1rgbB4_107[1],S1rgbB4_108[1],S1rgbB4_109[1],S1rgbB4_110[1],
S1rgbC1_1[1],S1rgbC1_102[1],S1rgbC1_103[1],S1rgbC1_104[1],S1rgbC1_105[1],S1rgbC1_106[1],S1rgbC1_107[1],S1rgbC1_108[1],S1rgbC1_109[1],S1rgbC1_110[1],
S1rgbC2_1[1],S1rgbC2_102[1],S1rgbC2_103[1],S1rgbC2_104[1],S1rgbC2_105[1],S1rgbC2_106[1],S1rgbC2_107[1],S1rgbC2_108[1],S1rgbC2_109[1],S1rgbC2_110[1],
S1rgbC3_1[1],S1rgbC3_102[1],S1rgbC3_103[1],S1rgbC3_104[1],S1rgbC3_105[1],S1rgbC3_106[1],S1rgbC3_107[1],S1rgbC3_108[1],S1rgbC3_109[1],S1rgbC3_110[1],
S1rgbC4_1[1],S1rgbC4_102[1],S1rgbC4_103[1],S1rgbC4_104[1],S1rgbC4_105[1],S1rgbC4_106[1],S1rgbC4_107[1],S1rgbC4_108[1],S1rgbC4_109[1],S1rgbC4_110[1],
S1rgbD2_1[1],S1rgbD2_102[1],S1rgbD2_103[1],S1rgbD2_104[1],S1rgbD2_105[1],S1rgbD2_106[1],S1rgbD2_107[1],S1rgbD2_108[1],S1rgbD2_109[1],S1rgbD2_110[1],
S1rgbD3_1[1],S1rgbD3_102[1],S1rgbD3_103[1],S1rgbD3_104[1],S1rgbD3_105[1],S1rgbD3_106[1],S1rgbD3_107[1],S1rgbD3_108[1],S1rgbD3_109[1],S1rgbD3_110[1],
S1rgbD4_1[1],S1rgbD4_102[1],S1rgbD4_103[1],S1rgbD4_104[1],S1rgbD4_105[1],S1rgbD4_106[1],S1rgbD4_107[1],S1rgbD4_108[1],S1rgbD4_109[1],S1rgbD4_110[1]],
'B-Shad': [S1rgbA1_2[2],S1rgbA1_202[2],S1rgbA1_203[2],S1rgbA1_204[2],S1rgbA1_205[2],S1rgbA1_206[2],S1rgbA1_207[2],S1rgbA1_208[2],S1rgbA1_209[2],S1rgbA1_210[2],
S1rgbA2_1[2],S1rgbA2_102[2],S1rgbA2_103[2],S1rgbA2_104[2],S1rgbA2_105[2],S1rgbA2_106[2],S1rgbA2_107[2],S1rgbA2_108[2],S1rgbA2_109[2],S1rgbA2_110[2],
S1rgbA3_1[2],S1rgbA3_102[2],S1rgbA3_103[2],S1rgbA3_104[2],S1rgbA3_105[2], S1rgbA3_106[2], S1rgbA3_107[2],S1rgbA3_108[2],S1rgbA3_109[2],S1rgbA3_110[2],
S1rgbA3_51[2],S1rgbA3_5102[2],S1rgbA3_5103[2], S1rgbA3_5104[2],  S1rgbA3_5105[2],S1rgbA3_5106[2], S1rgbA3_5107[2],S1rgbA3_5108[2],S1rgbA3_5109[2],  S1rgbA3_5110[2],
S1rgbA4_1[2],S1rgbA4_102[2], S1rgbA4_103[2],S1rgbA4_104[2],S1rgbA4_105[2],S1rgbA4_106[2],S1rgbA4_107[2],S1rgbA4_108[2],S1rgbA4_109[2],S1rgbA4_110[2],
S1rgbB1_1[2],S1rgbB1_102[2],S1rgbB1_103[2],S1rgbB1_104[2],S1rgbB1_105[2],S1rgbB1_106[2],S1rgbB1_107[2],S1rgbB1_108[2],S1rgbB1_109[2],S1rgbB1_110[2],
S1rgbB2_1[2],S1rgbB2_102[2],S1rgbB2_103[2],S1rgbB2_104[2],S1rgbB2_105[2],S1rgbB2_106[2],S1rgbB2_107[2],S1rgbB2_108[2],S1rgbB2_109[2],S1rgbB2_110[2],
S1rgbB3_1[2],S1rgbB3_102[2],S1rgbB3_103[2],S1rgbB3_104[2],S1rgbB3_105[2],S1rgbB3_106[2],S1rgbB3_107[2],S1rgbB3_108[2],S1rgbB3_109[2],S1rgbB3_110[2],
S1rgbB4_1[2],S1rgbB4_102[2],S1rgbB4_103[2],S1rgbB4_104[2],S1rgbB4_105[2],S1rgbB4_106[2],S1rgbB4_107[2],S1rgbB4_108[2],S1rgbB4_109[2],S1rgbB4_110[2],
S1rgbC1_1[2],S1rgbC1_102[2],S1rgbC1_103[2],S1rgbC1_104[2],S1rgbC1_105[2],S1rgbC1_106[2],S1rgbC1_107[2],S1rgbC1_108[2],S1rgbC1_109[2],S1rgbC1_110[2],
S1rgbC2_1[2],S1rgbC2_102[2],S1rgbC2_103[2],S1rgbC2_104[2],S1rgbC2_105[2],S1rgbC2_106[2],S1rgbC2_107[2],S1rgbC2_108[2],S1rgbC2_109[2],S1rgbC2_110[2],
S1rgbC3_1[2],S1rgbC3_102[2],S1rgbC3_103[2],S1rgbC3_104[2],S1rgbC3_105[2],S1rgbC3_106[2],S1rgbC3_107[2],S1rgbC3_108[2],S1rgbC3_109[2],S1rgbC3_110[2],
S1rgbC4_1[2],S1rgbC4_102[2],S1rgbC4_103[2],S1rgbC4_104[2],S1rgbC4_105[2],S1rgbC4_106[2],S1rgbC4_107[2],S1rgbC4_108[2],S1rgbC4_109[2],S1rgbC4_110[2],
S1rgbD2_1[2],S1rgbD2_102[2],S1rgbD2_103[2],S1rgbD2_104[2],S1rgbD2_105[2],S1rgbD2_106[2],S1rgbD2_107[2],S1rgbD2_108[2],S1rgbD2_109[2],S1rgbD2_110[2],
S1rgbD3_1[2],S1rgbD3_102[2],S1rgbD3_103[2],S1rgbD3_104[2],S1rgbD3_105[2],S1rgbD3_106[2],S1rgbD3_107[2],S1rgbD3_108[2],S1rgbD3_109[2],S1rgbD3_110[2],
S1rgbD4_1[2],S1rgbD4_102[2],S1rgbD4_103[2],S1rgbD4_104[2],S1rgbD4_105[2],S1rgbD4_106[2],S1rgbD4_107[2],S1rgbD4_108[2],S1rgbD4_109[2],S1rgbD4_110[2]],
'H-ref':[S1hsvrefA1_1[0],S1hsvrefA1_102[0],S1hsvrefA1_103[0],S1hsvrefA1_104[0],S1hsvrefA1_105[0],S1hsvrefA1_106[0],S1hsvrefA1_107[0],S1hsvrefA1_108[0],S1hsvrefA1_109[0],S1hsvrefA1_110[0],
S1hsvrefA1_3[0],S1hsvrefA1_302[0],S1hsvrefA1_303[0],S1hsvrefA1_304[0],S1hsvrefA1_305[0], S1hsvrefA1_306[0],S1hsvrefA1_307[0],S1hsvrefA1_308[0],S1hsvrefA1_309[0],S1hsvrefA1_3010[0],
S1hsvrefA1_4[0], S1hsvrefA1_402[0], S1hsvrefA1_403[0], S1hsvrefA1_404[0], S1hsvrefA1_405[0],S1hsvrefA1_406[0], S1hsvrefA1_407[0], S1hsvrefA1_408[0], S1hsvrefA1_409[0], S1hsvrefA1_410[0],
S1hsvrefA1_5[0], S1hsvrefA1_502[0], S1hsvrefA1_503[0], S1hsvrefA1_504[0], S1hsvrefA1_505[0],S1hsvrefA1_506[0], S1hsvrefA1_507[0], S1hsvrefA1_508[0], S1hsvrefA1_509[0], S1hsvrefA1_510[0],
S1hsvrefA1_6[0], S1hsvrefA1_602[0], S1hsvrefA1_603[0], S1hsvrefA1_604[0], S1hsvrefA1_605[0],S1hsvrefA1_606[0], S1hsvrefA1_607[0], S1hsvrefA1_608[0], S1hsvrefA1_609[0], S1hsvrefA1_610[0],
S1hsvrefA1_7[0], S1hsvrefA1_702[0], S1hsvrefA1_703[0], S1hsvrefA1_704[0],S1hsvrefA1_705[0], S1hsvrefA1_706[0], S1hsvrefA1_707[0], S1hsvrefA1_708[0], S1hsvrefA1_709[0], S1hsvrefA1_710[0],
S1hsvrefA1_8[0], S1hsvrefA1_802[0], S1hsvrefA1_803[0], S1hsvrefA1_804[0], S1hsvrefA1_805[0],S1hsvrefA1_806[0], S1hsvrefA1_807[0], S1hsvrefA1_808[0], S1hsvrefA1_809[0], S1hsvrefA1_810[0],
S1hsvrefA1_9[0], S1hsvrefA1_902[0], S1hsvrefA1_903[0], S1hsvrefA1_904[0], S1hsvrefA1_905[0],S1hsvrefA1_906[0], S1hsvrefA1_907[0], S1hsvrefA1_908[0], S1hsvrefA1_909[0], S1hsvrefA1_910[0],
S1hsvrefA1_10[0], S1hsvrefA1_1002[0], S1hsvrefA1_1003[0], S1hsvrefA1_1004[0], S1hsvrefA1_1005[0],  S1hsvrefA1_1006[0], S1hsvrefA1_1007[0], S1hsvrefA1_1008[0], S1hsvrefA1_1009[0], S1hsvrefA1_1010[0],        
S1hsvrefA1_11[0], S1hsvrefA1_1102[0], S1hsvrefA1_1103[0], S1hsvrefA1_1104[0], S1hsvrefA1_1105[0],S1hsvrefA1_1106[0],S1hsvrefA1_1107[0], S1hsvrefA1_1108[0], S1hsvrefA1_1109[0], S1hsvrefA1_1110[0],
S1hsvrefA1_12[0], S1hsvrefA1_1202[0], S1hsvrefA1_1203[0], S1hsvrefA1_1204[0], S1hsvrefA1_1205[0],S1hsvrefA1_1206[0], S1hsvrefA1_1207[0], S1hsvrefA1_1208[0], S1hsvrefA1_1209[0], S1hsvrefA1_1210[0],
S1hsvrefA1_13[0], S1hsvrefA1_1302[0], S1hsvrefA1_1303[0], S1hsvrefA1_1304[0], S1hsvrefA1_1305[0], S1hsvrefA1_1306[0], S1hsvrefA1_1307[0], S1hsvrefA1_1308[0], S1hsvrefA1_1309[0], S1hsvrefA1_1310[0],
S1hsvrefA1_14[0], S1hsvrefA1_1402[0], S1hsvrefA1_1403[0], S1hsvrefA1_1404[0], S1hsvrefA1_1405[0],  S1hsvrefA1_1406[0], S1hsvrefA1_1407[0], S1hsvrefA1_1408[0], S1hsvrefA1_1409[0], S1hsvrefA1_1410[0], 
S1hsvrefA1_15[0], S1hsvrefA1_1502[0], S1hsvrefA1_1503[0], S1hsvrefA1_1504[0], S1hsvrefA1_1505[0], S1hsvrefA1_1506[0], S1hsvrefA1_1507[0], S1hsvrefA1_1508[0], S1hsvrefA1_1509[0], S1hsvrefA1_1510[0], 
S1hsvrefA1_16[0], S1hsvrefA1_1602[0], S1hsvrefA1_1603[0], S1hsvrefA1_1604[0], S1hsvrefA1_1605[0], S1hsvrefA1_1606[0], S1hsvrefA1_1607[0], S1hsvrefA1_1608[0], S1hsvrefA1_1609[0], S1hsvrefA1_1610[0], 
S1hsvrefA1_17[0], S1hsvrefA1_1702[0], S1hsvrefA1_1703[0], S1hsvrefA1_1704[0], S1hsvrefA1_1705[0], S1hsvrefA1_1706[0], S1hsvrefA1_1707[0], S1hsvrefA1_1708[0], S1hsvrefA1_1709[0], S1hsvrefA1_1710[0]], 
'S-ref':[S1hsvrefA1_1[1],S1hsvrefA1_102[1],S1hsvrefA1_103[1],S1hsvrefA1_104[1],S1hsvrefA1_105[1],S1hsvrefA1_106[1],S1hsvrefA1_107[1],S1hsvrefA1_108[1],S1hsvrefA1_109[1],S1hsvrefA1_110[1],
S1hsvrefA1_3[1],S1hsvrefA1_302[1],S1hsvrefA1_303[1],S1hsvrefA1_304[1],S1hsvrefA1_305[1], S1hsvrefA1_306[1],S1hsvrefA1_307[1],S1hsvrefA1_308[1],S1hsvrefA1_309[1],S1hsvrefA1_310[1],
S1hsvrefA1_4[1], S1hsvrefA1_402[1], S1hsvrefA1_403[1], S1hsvrefA1_404[1], S1hsvrefA1_405[1],S1hsvrefA1_406[1], S1hsvrefA1_407[1], S1hsvrefA1_408[1], S1hsvrefA1_409[1], S1hsvrefA1_410[1],
S1hsvrefA1_5[1], S1hsvrefA1_502[1], S1hsvrefA1_503[1], S1hsvrefA1_504[1], S1hsvrefA1_505[1],S1hsvrefA1_506[1], S1hsvrefA1_507[1], S1hsvrefA1_508[1], S1hsvrefA1_509[1], S1hsvrefA1_510[1],
S1hsvrefA1_6[1], S1hsvrefA1_602[1], S1hsvrefA1_603[1], S1hsvrefA1_604[1], S1hsvrefA1_605[1],S1hsvrefA1_606[1], S1hsvrefA1_607[1], S1hsvrefA1_608[1], S1hsvrefA1_609[1], S1hsvrefA1_610[1],
S1hsvrefA1_7[1], S1hsvrefA1_702[1], S1hsvrefA1_703[1], S1hsvrefA1_704[1],S1hsvrefA1_705[1], S1hsvrefA1_706[1], S1hsvrefA1_707[1], S1hsvrefA1_708[1], S1hsvrefA1_709[1], S1hsvrefA1_710[1],
S1hsvrefA1_8[1], S1hsvrefA1_802[1], S1hsvrefA1_803[1], S1hsvrefA1_804[1], S1hsvrefA1_805[1],S1hsvrefA1_806[1], S1hsvrefA1_807[1], S1hsvrefA1_808[1], S1hsvrefA1_809[1], S1hsvrefA1_810[1],
S1hsvrefA1_9[1], S1hsvrefA1_902[1], S1hsvrefA1_903[1], S1hsvrefA1_904[1], S1hsvrefA1_905[1],S1hsvrefA1_906[1], S1hsvrefA1_907[1], S1hsvrefA1_908[1], S1hsvrefA1_909[1], S1hsvrefA1_910[1],
S1hsvrefA1_10[1], S1hsvrefA1_1002[1], S1hsvrefA1_1003[1], S1hsvrefA1_1004[1], S1hsvrefA1_1005[1],  S1hsvrefA1_1006[1], S1hsvrefA1_1007[1], S1hsvrefA1_1008[1], S1hsvrefA1_1009[1], S1hsvrefA1_1010[1],        
S1hsvrefA1_11[1], S1hsvrefA1_1102[1], S1hsvrefA1_1103[1], S1hsvrefA1_1104[1], S1hsvrefA1_1105[1],S1hsvrefA1_1106[1],S1hsvrefA1_1107[1], S1hsvrefA1_1108[1], S1hsvrefA1_1109[1], S1hsvrefA1_1110[1],
S1hsvrefA1_12[1], S1hsvrefA1_1202[1], S1hsvrefA1_1203[1], S1hsvrefA1_1204[1], S1hsvrefA1_1205[1],S1hsvrefA1_1206[1], S1hsvrefA1_1207[1], S1hsvrefA1_1208[1], S1hsvrefA1_1209[1], S1hsvrefA1_1210[1],
S1hsvrefA1_13[1], S1hsvrefA1_1302[1], S1hsvrefA1_1303[1],S1hsvrefA1_1304[1], S1hsvrefA1_1305[1], S1hsvrefA1_1306[1], S1hsvrefA1_1307[1], S1hsvrefA1_1308[1], S1hsvrefA1_1309[1], S1hsvrefA1_1310[1],
S1hsvrefA1_14[1], S1hsvrefA1_1402[1], S1hsvrefA1_1403[1], S1hsvrefA1_1404[1], S1hsvrefA1_1405[1],  S1hsvrefA1_1406[1], S1hsvrefA1_1407[1], S1hsvrefA1_1408[1], S1hsvrefA1_1409[1], S1hsvrefA1_1410[1], 
S1hsvrefA1_15[1], S1hsvrefA1_1502[1], S1hsvrefA1_1503[1], S1hsvrefA1_1504[1], S1hsvrefA1_1505[1], S1hsvrefA1_1506[1], S1hsvrefA1_1507[1], S1hsvrefA1_1508[1], S1hsvrefA1_1509[1], S1hsvrefA1_1510[1], 
S1hsvrefA1_16[1], S1hsvrefA1_1602[1], S1hsvrefA1_1603[1], S1hsvrefA1_1604[1], S1hsvrefA1_1605[1], S1hsvrefA1_1606[1], S1hsvrefA1_1607[1], S1hsvrefA1_1608[1], S1hsvrefA1_1609[1], S1hsvrefA1_1610[1], 
S1hsvrefA1_17[1], S1hsvrefA1_1702[1], S1hsvrefA1_1703[1], S1hsvrefA1_1704[1], S1hsvrefA1_1705[1], S1hsvrefA1_1706[1], S1hsvrefA1_1707[1], S1hsvrefA1_1708[1], S1hsvrefA1_1709[1], S1hsvrefA1_1710[1]], 
'V-ref':[S1hsvrefA1_1[2],S1hsvrefA1_102[2],S1hsvrefA1_103[2],S1hsvrefA1_104[2],S1hsvrefA1_105[2],S1hsvrefA1_106[2],S1hsvrefA1_107[2],S1hsvrefA1_108[2],S1hsvrefA1_109[2],S1hsvrefA1_110[2],
S1hsvrefA1_3[1],S1hsvrefA1_302[1],S1hsvrefA1_303[1],S1hsvrefA1_304[1],S1hsvrefA1_305[1], S1hsvrefA1_306[1],S1hsvrefA1_307[1],S1hsvrefA1_308[1],S1hsvrefA1_309[1],S1hsvrefA1_310[1],
S1hsvrefA1_4[2], S1hsvrefA1_402[2], S1hsvrefA1_403[2], S1hsvrefA1_404[2], S1hsvrefA1_405[2],S1hsvrefA1_406[2], S1hsvrefA1_407[2], S1hsvrefA1_408[2], S1hsvrefA1_409[2], S1hsvrefA1_410[2],
S1hsvrefA1_5[2], S1hsvrefA1_502[2], S1hsvrefA1_503[2], S1hsvrefA1_504[2], S1hsvrefA1_505[2],S1hsvrefA1_506[2], S1hsvrefA1_507[2], S1hsvrefA1_508[2], S1hsvrefA1_509[2], S1hsvrefA1_510[2],
S1hsvrefA1_6[2], S1hsvrefA1_602[2], S1hsvrefA1_603[2], S1hsvrefA1_604[2], S1hsvrefA1_605[2],S1hsvrefA1_606[2], S1hsvrefA1_607[2], S1hsvrefA1_608[2], S1hsvrefA1_609[2], S1hsvrefA1_610[1],
S1hsvrefA1_7[2], S1hsvrefA1_702[2], S1hsvrefA1_703[2], S1hsvrefA1_704[2],S1hsvrefA1_705[2], S1hsvrefA1_706[2], S1hsvrefA1_707[2], S1hsvrefA1_708[2], S1hsvrefA1_709[2], S1hsvrefA1_710[2],
S1hsvrefA1_8[2], S1hsvrefA1_802[2], S1hsvrefA1_803[2], S1hsvrefA1_804[2], S1hsvrefA1_805[2],S1hsvrefA1_806[2], S1hsvrefA1_807[2], S1hsvrefA1_808[2], S1hsvrefA1_809[2], S1hsvrefA1_810[2],
S1hsvrefA1_9[2], S1hsvrefA1_902[2], S1hsvrefA1_903[2], S1hsvrefA1_904[2], S1hsvrefA1_905[2],S1hsvrefA1_906[2], S1hsvrefA1_907[2], S1hsvrefA1_908[2], S1hsvrefA1_909[2], S1hsvrefA1_910[2],
S1hsvrefA1_10[2], S1hsvrefA1_1002[2], S1hsvrefA1_1003[2], S1hsvrefA1_1004[2], S1hsvrefA1_1005[2],  S1hsvrefA1_1006[2], S1hsvrefA1_1007[2], S1hsvrefA1_1008[2], S1hsvrefA1_1009[2], S1hsvrefA1_1010[2],        
S1hsvrefA1_11[2], S1hsvrefA1_1102[2], S1hsvrefA1_1103[2], S1hsvrefA1_1104[2], S1hsvrefA1_1105[2],S1hsvrefA1_1106[2],S1hsvrefA1_1107[2], S1hsvrefA1_1108[2], S1hsvrefA1_1109[2], S1hsvrefA1_1110[2],
S1hsvrefA1_12[2], S1hsvrefA1_1202[2], S1hsvrefA1_1203[2], S1hsvrefA1_1204[2], S1hsvrefA1_1205[2],S1hsvrefA1_1206[2], S1hsvrefA1_1207[2], S1hsvrefA1_1208[2], S1hsvrefA1_1209[2], S1hsvrefA1_1210[2],
S1hsvrefA1_13[2], S1hsvrefA1_1302[2], S1hsvrefA1_1303[2], S1hsvrefA1_1304[2], S1hsvrefA1_1305[2], S1hsvrefA1_1306[2], S1hsvrefA1_1307[2], S1hsvrefA1_1308[2], S1hsvrefA1_1309[2], S1hsvrefA1_1310[2],
S1hsvrefA1_14[2], S1hsvrefA1_1402[2], S1hsvrefA1_1403[2], S1hsvrefA1_1404[2], S1hsvrefA1_1405[2],  S1hsvrefA1_1406[2], S1hsvrefA1_1407[2], S1hsvrefA1_1408[2], S1hsvrefA1_1409[2], S1hsvrefA1_1410[2], 
S1hsvrefA1_15[2], S1hsvrefA1_1502[2], S1hsvrefA1_1503[2], S1hsvrefA1_1504[2], S1hsvrefA1_1505[2], S1hsvrefA1_1506[2], S1hsvrefA1_1507[2], S1hsvrefA1_1508[2], S1hsvrefA1_1509[2], S1hsvrefA1_1510[2], 
S1hsvrefA1_16[2], S1hsvrefA1_1602[2], S1hsvrefA1_1603[2], S1hsvrefA1_1604[2], S1hsvrefA1_1605[2], S1hsvrefA1_1606[2], S1hsvrefA1_1607[2], S1hsvrefA1_1608[2], S1hsvrefA1_1609[2], S1hsvrefA1_1610[2], 
S1hsvrefA1_17[2], S1hsvrefA1_1702[2], S1hsvrefA1_1703[2], S1hsvrefA1_1704[2], S1hsvrefA1_1705[2], S1hsvrefA1_1706[2], S1hsvrefA1_1707[2], S1hsvrefA1_1708[2], S1hsvrefA1_1709[2], S1hsvrefA1_1710[2]], 
'H-Shad':[S1hsvA1_2[0],S1hsvA1_202[0],S1hsvA1_203[0],S1hsvA1_204[0],S1hsvA1_205[0],S1hsvA1_206[0],S1hsvA1_207[0],S1hsvA1_208[0],S1hsvA1_209[0],S1hsvA1_210[0],
S1hsvA2_1[0],S1hsvA2_102[0],S1hsvA2_103[0],S1hsvA2_104[0],S1hsvA2_105[0],S1hsvA2_106[0],S1hsvA2_107[0],S1hsvA2_108[0],S1hsvA2_109[0],S1hsvA2_110[0],
S1hsvA3_1[0],S1hsvA3_102[0],S1hsvA3_103[0],S1hsvA3_104[0],S1hsvA3_105[0],S1hsvA3_106[0],S1hsvA3_107[0],S1hsvA3_108[0],S1hsvA3_109[0],S1hsvA3_110[0],
S1hsvA3_51[0],S1hsvA3_5102[0],S1hsvA3_5103[0],S1hsv3_5104[0],  S1hsvA3_5105[0],S1hsvA3_5106[0],S1hsvA3_5107[0],S1hsvA3_5108[0],S1hsvA3_5109[0],  S1hsvA3_5110[0],
S1hsvA4_1[0],S1hsvA4_102[0],S1hsvA4_103[0],S1hsvA4_104[0],S1hsvA4_105[0],S1hsvA4_106[0],S1hsvA4_107[0],S1hsvA4_108[0],S1hsvA4_109[0],S1hsvA4_110[0],
S1hsvB1_1[0],S1hsvB1_102[0],S1hsvB1_103[0],S1hsvB1_104[0],S1hsvB1_105[0],S1hsvB1_106[0],S1hsvB1_107[0],S1hsvB1_108[0],S1hsvB1_109[0],S1hsvB1_110[0],
S1hsvB2_1[0],S1hsvB2_102[0],S1hsvB2_103[0],S1hsvB2_104[0],S1hsvB2_105[0],S1hsvB2_106[0],S1hsvB2_107[0],S1hsvB2_108[0],S1hsvB2_109[0],S1hsvB2_110[0],
S1hsvB3_1[0],S1hsvB3_102[0],S1hsvB3_103[0],S1hsvB3_104[0],S1hsvB3_105[0],S1hsvB3_106[0],S1hsvB3_107[0],S1hsvB3_108[0],S1hsvB3_109[0],S1hsvB3_110[0],
S1hsvB4_1[0],S1hsvB4_102[0],S1hsvB4_103[0],S1hsvB4_104[0],S1hsvB4_105[0],S1hsvB4_106[0],S1hsvB4_107[0],S1hsvB4_108[0],S1hsvB4_109[0],S1hsvB4_110[0],
S1hsvC1_1[0],S1hsvC1_102[0],S1hsvC1_103[0],S1hsvC1_104[0],S1hsvC1_105[0],S1hsvC1_106[0],S1hsvC1_107[0],S1hsvC1_108[0],S1hsvC1_109[0],S1hsvC1_110[0],
S1hsvC2_1[0],S1hsvC2_102[0],S1hsvC2_103[0],S1hsvC2_104[0],S1hsvC2_105[0],S1hsvC2_106[0],S1hsvC2_107[0],S1hsvC2_108[0],S1hsvC2_109[0],S1hsvC2_110[0],
S1hsvC3_1[0],S1hsvC3_102[0],S1hsvC3_103[0],S1hsvC3_104[0],S1hsvC3_105[0],S1hsvC3_106[0],S1hsvC3_107[0],S1hsvC3_108[0],S1hsvC3_109[0],S1hsvC3_110[0],
S1hsvC4_1[0],S1hsvC4_102[0],S1hsvC4_103[0],S1hsvC4_104[0],S1hsvC4_105[0],S1hsvC4_106[0],S1hsvC4_107[0],S1hsvC4_108[0],S1hsvC4_109[0],S1hsvC4_110[0],
S1hsvD2_1[0],S1hsvD2_102[0],S1hsvD2_103[0],S1hsvD2_104[0],S1hsvD2_105[0],S1hsvD2_106[0],S1hsvD2_107[0],S1hsvD2_108[0],S1hsvD2_109[0],S1hsvD2_110[0],
S1hsvD3_1[0],S1hsvD3_102[0],S1hsvD3_103[0],S1hsvD3_104[0],S1hsvD3_105[0],S1hsvD3_106[0],S1hsvD3_107[0],S1hsvD3_108[0],S1hsvD3_109[0],S1hsvD3_110[0],
S1hsvD4_1[0],S1hsvD4_102[0],S1hsvD4_103[0],S1hsvD4_104[0],S1hsvD4_105[0],S1hsvD4_106[0],S1hsvD4_107[0],S1hsvD4_108[0],S1hsvD4_109[0],S1hsvD4_110[0]],
'S-Shad':[S1hsvA1_2[1],S1hsvA1_202[1],S1hsvA1_203[1], S1hsvA1_204[1],S1hsvA1_205[1],S1hsvA1_206[1],S1hsvA1_207[1],S1hsvA1_208[1],S1hsvA1_209[1],S1hsvA1_210[1],
S1hsvA2_1[1],S1hsvA2_102[],S1hsvA2_103[1],S1hsvA2_104[1],S1hsvA2_105[1],S1hsvA2_106[1],S1hsvA2_107[1],S1hsvA2_108[1],S1hsvA2_109[1],S1hsvA2_110[1],
S1hsvA3_1[1],S1hsvA3_102[1], S1hsvA3_103[1],S1hsvA3_104[1],S1hsvA3_105[1],S1hsvA3_106[1],S1hsvA3_107[1],S1hsvA3_108[1],S1hsvA3_109[1],S1hsvA3_110[1],
S1hsvA3_51[1],S1hsvA3_5102[1],S1hsvA3_5103[1],S1hsvA3_5104[1],  S1hsvA3_5105[1],S1hsvA3_5106[1],S1hsvA3_5107[1],S1hsvA3_5108[1],S1hsvA3_5109[1],  S1hsvA3_5110[1],
S1hsvA4_1[1],S1hsvA4_102[1],S1hsvA4_103[1],S1hsvA4_104[1],S1hsvA4_105[1],S1hsvA4_106[1], S1hsvA4_107[1],S1hsvA4_108[1],S1hsvA4_109[1],S1hsvA4_110[1],
S1hsvB1_1[1],S1hsvB1_102[1],S1hsvB1_103[1],S1hsvB1_104[1],S1hsvB1_105[1],S1hsvB1_106[1],S1hsvB1_107[1],S1hsvB1_108[1],S1hsvB1_109[1],S1hsvB1_110[1],
S1hsvB2_1[1],S1hsvB2_102[1],S1hsvB2_103[1],S1hsvB2_104[1],S1hsvB2_105[1],S1hsvB2_106[1],S1hsvB2_107[1],S1hsvB2_108[1],S1hsvB2_109[1],S1hsvB2_110[1],
S1hsvB3_1[1],S1hsvB3_102[1],S1hsvB3_103[1],S1hsvB3_104[1],S1hsvB3_105[1],S1hsvB3_106[1],S1hsvB3_107[1],S1hsvB3_108[1],S1hsvB3_109[1],S1hsvB3_110[1],
S1hsvB4_1[1],S1hsvB4_102[1],S1hsvB4_103[1],S1hsvB4_104[1],S1hsvB4_105[1],S1hsvB4_106[1],S1hsvB4_107[1],S1hsvB4_108[1],S1hsvB4_109[1],S1hsvB4_110[1],
S1hsvC1_1[1],S1hsvC1_102[1],S1hsvC1_103[1],S1hsvC1_104[1],S1hsvC1_105[1],S1hsvC1_106[1],S1hsvC1_107[1],S1hsvC1_108[1],S1hsvC1_109[1],S1hsvC1_110[1],
S1hsvC2_1[1],S1hsvC2_102[1],S1hsvC2_103[1],S1hsvC2_104[1],S1hsvC2_105[1],S1hsvC2_106[1],S1hsvC2_107[1],S1hsvC2_108[1],S1hsvC2_109[1],S1hsvC2_110[1],
S1hsvC3_1[1],S1hsvC3_102[1],S1hsvC3_103[1],S1hsvC3_104[1],S1hsvC3_105[1],S1hsvC3_106[1],S1hsvC3_107[1],S1hsvC3_108[1],S1hsvC3_109[1],S1hsvC3_110[1],
S1hsvC4_1[1],S1hsvC4_102[1],S1hsvC4_103[1],S1hsvC4_104[1],S1hsvC4_105[1],S1hsvC4_106[1],S1hsvC4_107[1],S1hsvC4_108[1],S1hsvC4_109[1],S1hsvC4_110[1],
S1hsvD2_1[1],S1hsvD2_102[1],S1hsvD2_103[1],S1hsvD2_104[1],S1hsvD2_105[1],S1hsvD2_106[1],S1hsvD2_107[1],S1hsvD2_108[1],S1hsvD2_109[1],S1hsvD2_110[1],
S1hsvD3_1[1],S1hsvD3_102[1],S1hsvD3_103[1],S1hsvD3_104[1],S1hsvD3_105[1],S1hsvD3_106[1],S1hsvD3_107[1],S1hsvD3_108[1],S1hsvD3_109[1],S1hsvD3_110[1],
S1hsvD4_1[1],S1hsvD4_102[1],S1hsvD4_103[1],S1hsvD4_104[1],S1hsvD4_105[1],S1hsvD4_106[1],S1hsvD4_107[1],S1hsvD4_108[1],S1hsvD4_109[1],S1hsvD4_110[1]],
'V-Shad':[S1hsvA1_2[2],S1hsvA1_202[2],S1hsvA1_203[2],S1hsvA1_204[2],S1hsvA1_205[2],S1hsvA1_206[2],S1hsvA1_207[2],S1hsvA1_208[2],S1hsvA1_209[2],S1hsvA1_210[2],
S1hsvA2_1[2],S1hsvA2_102[2],S1hsvA2_103[2],S1hsvA2_104[2],S1hsvA2_105[2],S1hsvA2_106[2],S1hsvA2_107[2],S1hsvA2_108[2],S1hsvA2_109[2],S1hsvA2_110[2],
S1hsvA3_1[2],S1hsvA3_102[2],S1hsvA3_103[2],S1hsvA3_104[2],S1hsvA3_105[2],S1hsvA3_106[2],S1hsvA3_107[2],S1hsvA3_108[2],S1hsvA3_109[2],S1hsvA3_110[2],
S1hsvA3_51[2],S1hsvA3_5102[2],S1hsvA3_5103[2],S1hsvA3_5104[2],  S1hsvA3_5105[2],S1hsvA3_5106[2],S1hsvA3_5107[2],S1hsvA3_5108[2],S1hsvA3_5109[2],  S1hsvA3_5110[2],
S1hsvA4_1[2],S1hsvA4_102[2],S1hsvA4_103[2],S1hsvA4_104[2],S1hsvA4_105[2],S1hsvA4_106[2],S1hsvA4_107[2],S1hsvA4_108[2],S1hsvA4_109[2],S1hsvA4_110[2],
S1hsvB1_1[2],S1hsvB1_102[2],S1hsvB1_103[2],S1hsvB1_104[2],S1hsvB1_105[2],S1hsvB1_106[2],S1hsvB1_107[2],S1hsvB1_108[2],S1hsvB1_109[2],S1hsvB1_110[2],
S1hsvB2_1[2],S1hsvB2_102[2],S1hsvB2_103[2],S1hsvB2_104[2],S1hsvB2_105[2],S1hsvB2_106[2],S1hsvB2_107[2],S1hsvB2_108[2],S1hsvB2_109[2],S1hsvB2_110[2],
S1hsvB3_1[2],S1hsvB3_102[2],S1hsvB3_103[2],S1hsvB3_104[2],S1hsvB3_105[2],S1hsvB3_106[2],S1hsvB3_107[2],S1hsvB3_108[2],S1hsvB3_109[2],S1hsvB3_110[2],
S1hsvB4_1[2],S1hsvB4_102[2],S1hsvB4_103[2],S1hsvB4_104[2],S1hsvB4_105[2],S1hsvB4_106[2],S1hsvB4_107[2],S1hsvB4_108[2],S1hsvB4_109[2],S1hsvB4_110[2],
S1hsvC1_1[2],S1hsvC1_102[2],S1hsvC1_103[2],S1hsvC1_104[2],S1hsvC1_105[2],S1hsvC1_106[2],S1hsvC1_107[2],S1hsvC1_108[2],S1hsvC1_109[2],S1hsvC1_110[2],
S1hsvC2_1[2],S1hsvC2_102[2],S1hsvC2_103[2],S1hsvC2_104[2],S1hsvC2_105[2],S1hsvC2_106[2],S1hsvC2_107[2],S1hsvC2_108[2],S1hsvC2_109[2],S1hsvC2_110[2],
S1hsvC3_1[2],S1hsvC3_102[2],S1hsvC3_103[2],S1hsvC3_104[2],S1hsvC3_105[2],S1hsvC3_106[2],S1hsvC3_107[2],S1hsvC3_108[2],S1hsvC3_109[2],S1hsvC3_110[2],
S1hsvC4_1[2],S1hsvC4_102[2],S1hsvC4_103[2],S1hsvC4_104[2],S1hsvC4_105[2],S1hsvC4_106[2],S1hsvC4_107[2],S1hsvC4_108[2],S1hsvC4_109[2],S1hsvC4_110[2],
S1hsvD2_1[2],S1hsvD2_102[2],S1hsvD2_103[2],S1hsvD2_104[2],S1hsvD2_105[2],S1hsvD2_106[2],S1hsvD2_107[2],S1hsvD2_108[2],S1hsvD2_109[2],S1hsvD2_110[2],
S1hsvD3_1[2],S1hsvD3_102[2],S1hsvD3_103[2],S1hsvD3_104[2],S1hsvD3_105[2],S1hsvD3_106[2],S1hsvD3_107[2],S1hsvD3_108[2],S1hsvD3_109[2],S1hsvD3_110[2],
S1hsvD4_1[2],S1hsvD4_102[2],S1hsvD4_103[2],S1hsvD4_104[2],S1hsvD4_105[2],S1hsvD4_106[2],S1hsvD4_107[2],S1hsvD4_108[2],S1hsvD4_109[2],S1hsvD4_110[2]],
'Shade-ref':['A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1','A1', 'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1', 'A1', 'A1',  'A1', 'A1', 'A1',  'A1', 'A1'],
'Shade': ['A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A1', 'A2', 'A2', 'A2',  'A2','A2', 'A2', 'A2',  'A2' 'A2',  'A2', 'A3', 'A3', 'A3', 'A3', 'A3', 'A3','A3', 'A3',  ,'A3', 'A3','A3_5', 'A3_5', 'A3_5', 'A3_5', 'A3_5', 'A3_5', 'A3_5', 'A3_5', 'A3_5', 'A3_5', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4', 'A4',  'B1', 'B1', 'B1', 'B1', 'B1', 'B1','B1', 'B1', 'B1', 'B1',    'B2', 'B2', 'B2', 'B2', 'B2', 'B2','B2', 'B2','B2', 'B2', 'B3',  'B3', 'B3', 'B3', 'B3', 'B3', 'B3', 'B3', 'B3', 'B3', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'B4', 'C1', 'C1', 'C1', 'C1', 'C1', 'C1', 'C1', 'C1', 'C1', 'C1', 'C2', 'C2', 'C2', 'C2', 'C2', 'C2', 'C2', 'C2', 'C2', 'C2','C3', 'C3', 'C3', 'C3', 'C3', 'C3', 'C3', 'C3','C3', 'C3','C4', 'C4', 'C4', 'C4', 'C4', 'C4', 'C4', 'C4', 'C4', 'C4','D2', 'D2', 'D2', 'D2', 'D2', 'D2', 'D2', 'D2', 'D2', 'D2',  'D3', 'D3', 'D3', 'D3', 'D3','D3', 'D3', 'D3', 'D3','D3','D4', 'D4'  'D4', 'D4', 'D4','D4','D4','D4','D4','D4'], 
'Setting':['Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1','Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1', 'Set1'],
'Img' :[S1_doubleA1A1_1,S1_doubleA1A1_102,S1_doubleA1A1_103,S1_doubleA1A1_104,S1_doubleA1A1_105,S1_doubleA1A1_106,S1_doubleA1A1_107,S1_doubleA1A1_108,S1_doubleA1A1_109,S1_doubleA1A1_110,
S1_doubleA1A2_1, S1_doubleA1A2_102, S1_doubleA1A2_103, S1_doubleA1A2_104, S1_doubleA1A2_105, S1_doubleA1A2_106, S1_doubleA1A2_107, S1_doubleA1A2_108, S1_doubleA1A2_109, S1_doubleA1A2_110, 
S1_doubleA1A3_1, S1_doubleA1A3_102, S1_doubleA1A3_103, S1_doubleA1A3_104, S1_doubleA1A3_105, S1_doubleA1A3_106, S1_doubleA1A3_107, S1_doubleA1A3_108, S1_doubleA1A3_109, S1_doubleA1A3_110, 
S1_doubleA1A3_51, S1_doubleA1A3_5102,S1_doubleA1A3_5103,S1_doubleA1A3_5104,S1_doubleA1A3_5105,S1_doubleA1A3_5106,S1_doubleA1A3_5107, S1_doubleA1A3_5108,S1_doubleA1A3_5109,S1_doubleA1A3_5110,
S1_doubleA1A4_1, S1_doubleA1A4_102, S1_doubleA1A4_103, S1_doubleA1A4_104, S1_doubleA1A4_105, S1_doubleA1A4_106, S1_doubleA1A4_107, S1_doubleA1A4_108, S1_doubleA1A4_109, S1_doubleA1A4_110, 
S1_doubleA1B1_1,S1_doubleA1B1_102,S1_doubleA1B1_103,S1_doubleA1B1_104,S1_doubleA1B1_105,S1_doubleA1B1_106,S1_doubleA1B1_107,S1_doubleA1B1_108,S1_doubleA1B1_109,S1_doubleA1B1_110,
S1_doubleA1B2_1, S1_doubleA1B2_102,S1_doubleA1B2_103,S1_doubleA1B2_104,S1_doubleA1B2_105,S1_doubleA1B2_106, S1_doubleA1B2_107,S1_doubleA1B2_108,S1_doubleA1B2_109,S1_doubleA1B2_110,
S1_doubleA1B3_1, S1_doubleA1B3_102,S1_doubleA1B3_103,S1_doubleA1B3_104,S1_doubleA1B3_105,S1_doubleA1B3_106, S1_doubleA1B3_107,S1_doubleA1B3_108,S1_doubleA1B3_109,S1_doubleA1B3_110,
S1_doubleA1B4_1,S1_doubleA1B4_102,S1_doubleA1B4_103,S1_doubleA1B4_104,S1_doubleA1B4_105,S1_doubleA1B4_106,S1_doubleA1B4_107,S1_doubleA1B4_108,S1_doubleA1B4_109,S1_doubleA1B4_110,
S1_doubleA1C1_1 ,S1_doubleA1C1_102,S1_doubleA1C1_103,S1_doubleA1C1_104,S1_doubleA1C1_105,S1_doubleA1C1_106,S1_doubleA1C1_107,S1_doubleA1C1_108,S1_doubleA1C1_109,S1_doubleA1C1_110,
S1_doubleA1C2_1, S1_doubleA1C2_102, S1_doubleA1C2_103, S1_doubleA1C2_104, S1_doubleA1C2_105,S1_doubleA1C2_106, S1_doubleA1C2_107, S1_doubleA1C2_108, S1_doubleA1C2_109, S1_doubleA1C2_110, 
S1_doubleA1C3_1,S1_doubleA1C3_102, S1_doubleA1C3_103,S1_doubleA1C3_104,S1_doubleA1C3_105,S1_doubleA1C3_106,S1_doubleA1C3_107,S1_doubleA1C3_108,S1_doubleA1C3_109,S1_doubleA1C3_110,
S1_doubleA1C4_1, S1_doubleA1C4_102,S1_doubleA1C4_103,S1_doubleA1C4_104,S1_doubleA1C4_105,S1_doubleA1C4_106,S1_doubleA1C4_107,S1_doubleA1C4_108,S1_doubleA1C4_109,S1_doubleA1C4_110,
S1_doubleA1D2_1,S1_doubleA1D2_102, S1_doubleA1D2_103,S1_doubleA1D2_104,  S1_doubleA1D2_105, S1_doubleA1D2_106,S1_doubleA1D2_107, S1_doubleA1D2_108,S1_doubleA1D2_109,  S1_doubleA1D2_110, 
S1_doubleA1D3_1,S1_doubleA1D3_102,S1_doubleA1D3_103,S1_doubleA1D3_104,S1_doubleA1D3_105, S1_doubleA1D3_106,S1_doubleA1D3_107,S1_doubleA1D3_108,S1_doubleA1D3_109,S1_doubleA1D3_110,
S1_doubleA1D4_1,S1_doubleA1D4_102,S1_doubleA1D4_103,S1_doubleA1D4_104,S1_doubleA1D4_105,S1_doubleA1D4_106,S1_doubleA1D4_107,S1_doubleA1D4_108,S1_doubleA1D4_109,S1_doubleA1D4_110,]})
